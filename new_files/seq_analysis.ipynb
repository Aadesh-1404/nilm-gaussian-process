# %%
import os
os.chdir("../")
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %%
import torch
from gpytorch.kernels import RBFKernel, ScaleKernel, PeriodicKernel, MaternKernel, CosineKernel
from skgpytorch.models import SVGPRegressor, SGPRegressor

# %%
import jax.numpy as jnp
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from utilities.fits import fit
# from utilities import plot
import tensorflow_probability.substrates.jax as tfp
dist = tfp.distributions
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from gpytorch.constraints import GreaterThan
from skgpytorch.metrics import mean_squared_error, negative_log_predictive_density
import time
import numpy as np

# from datasets.dataset_load import dataset_loader
from utilities import plot,fits,gmm,errors,predict,preprocess

# device = "cpu"
# torch.set_default_dtype(torch.float32)
# torch.set_default_tensor_type(torch.FloatTensor)

# %%
train ={1:{
                    'start_time': "2011-04-21" ,
                    'end_time': "2011-05-21"
                },
                5: {
                    'start_time': "2011-04-22" ,
                    'end_time': "2011-06-01"
                }  ,3: {
                    'start_time': "2011-04-19" ,
                    'end_time': "2011-05-22"
                } ,
                  
              
                  2: {
                    'start_time': "2011-04-21" ,
                    'end_time': "2011-05-21"
                }
               
                
               
                }
test = { 6: {
                    'start_time': "2011-05-25" ,
                    'end_time': "2011-06-13"
                }
           }
appliances = ["Refrigerator"]

# %%
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler


def dataset_load(appliances, train, test=None):
    x_train = []
    y_train = []
    x_train_timestamp = []
    n = 129
    units_to_pad = n // 2
    scaler_x = StandardScaler()
    scaler_y = StandardScaler()
    scaler_time = StandardScaler()
    # train
    for key, values in train.items():
        df = pd.read_csv(
            f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[0]])
        df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
        startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
        endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

        if startDate > endDate:
            raise "Start Date must be smaller than Enddate."

        df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
        df.dropna(inplace=True)
        x = df["main"].values
        y = df[appliances[0]].values
        timestamp_train = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])
        x_train.extend(x)
        y_train.extend(y)
        x_train_timestamp.extend(torch.tensor(timestamp_train))


    x_train = jnp.array(x_train)
    y_train = jnp.array(y_train).reshape(-1, 1)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(-1,1)
    x_train = scaler_x.fit_transform(x_train)
    y_train = scaler_y.fit_transform(y_train)
    x_train_timestamp = scaler_time.fit_transform(x_train_timestamp)


    # test
    x_test = []
    y_test = []
    x_test_timestamp = []
    x_test_timestamp_true =[]
    for key, values in test.items():
        df = pd.read_csv(
            f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[0]])
        df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
        startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
        endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

        if startDate > endDate:
            raise "Start Date must be smaller than Enddate."

        df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
        df.dropna(inplace=True)
        x = df["main"].values
        y = df[appliances[0]].values
        timestamp_true = df["Timestamp"].values
        timestamp = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])
        x_test.extend(x)
        y_test.extend(y)
        x_test_timestamp_true.extend(timestamp_true)
        x_test_timestamp.extend(timestamp)

    x_test = jnp.array(x_test)
    y_test = jnp.array(y_test).reshape(-1, 1)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(-1,1)

    x_test = scaler_x.transform(x_test)
    x_test_timestamp = scaler_time.transform(x_test_timestamp)
#     y_test = scaler_y.transform(y_test)

    x_train = jnp.array(x_train).reshape(x_train.shape[0], n, 1)
    y_train = jnp.array(y_train)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(x_train_timestamp.shape[0], 1)
    x_test = jnp.array(x_test).reshape(x_test.shape[0], n, 1)
    y_test = jnp.array(y_test)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(x_test_timestamp.shape[0], 1).to(torch.float64)

    return x_train, y_train, x_test, y_test, x_train_timestamp, x_test_timestamp, x_test_timestamp_true, scaler_x, scaler_y, scaler_time

# %%
x_train, y_train, x_test, y_test, x_train_timstamp, x_test_timestamp, test_timestamp_orig, scaler_x, scaler_y, scaler_time = dataset_load(appliances, train, test)

# %%
n = 129
# x_train_full = jnp.concatenate((x_train.reshape(-1,n), jnp.array(np.array(x_train_timstamp))), axis=1)
# x_test_full = jnp.concatenate((x_test.reshape(-1,n), jnp.array(np.array(x_test_timestamp))), axis=1)
# x_train_full.shape, x_test_full.shape

# %%
x_train.reshape(-1,n).shape, x_test.reshape(-1,n).shape, y_train.shape, y_test.shape
# Out:
# ((53456, 129), (16781, 129), (53456, 1), (16781, 1))

# %%
indexes = 53456
x = torch.tensor(np.array(x_train).reshape(-1,n)).to(torch.float64)
y = torch.tensor(np.array(y_train)).reshape(-1,).to(torch.float64)
xt = torch.tensor(np.array(x_test).reshape(-1,n)).to(torch.float64)
yt = torch.tensor(np.array(y_test)).reshape(-1,).to(torch.float64)

if x.shape[0]>indexes:
  x = x[:indexes]
  y = y[:indexes]

# xt = xt[:16000]
# yt = yt[:16000]

# %%
mae_arr =[]
rms_arr = []
y_pred_arr = []

batch = 512

# x_train = x_train[:4500]
# y_train = y_train[:4500]

# y_test_trans = torch.tensor(torch.tensor(scaler_x.transform(y_test.reshape(-1,1))).reshape(-1,)).contiguous().to(torch.float64)
for i in range(1):


   #nu=2.5,

  kernel1 = ScaleKernel(RBFKernel(ard_num_dims=n))
  # kernel2 = ScaleKernel(RBFKernel(ard_num_dims=1,active_dims=(49)))
  # kernel3 = ScaleKernel(CosineKernel(ard_num_dims=1,active_dims=(49)))

  # kernel4 = kernel2*kernel3
  kernel = kernel1 # + kernel4
  # induce_points = 512
  inducing_points =  x[np.arange(0,x.shape[0],33)] 
  # inducing_points = x[torch.randperm(x.shape[0])[: 1500]]
  
  model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                       inducing_points).to("cuda")
  # model.mll.likelihood.noise_covar.register_constraint("raw_noise", GreaterThan(1e-2))
  # for param in model.parameters():
  #   # print(param)
  #   torch.nn.init.normal_(param, 0, 1)
  # theta1 = {'likelihood.noise_covar.noise': torch.tensor(3),
  #       'covar_module.base_kernel.lengthscale': torch.tensor(0.1),
  #       'covar_module.outputscale': torch.tensor(5),}
  loss = model.fit(lr=0.01, n_epochs=1500,verbose=2,
          random_state=0, n_restarts=1)
#   loss_arr.append(loss)
  # print(loss)
  plt.plot(np.asarray(loss[0]))
  # plt.plot(np.asarray(test_loss[0]))






  # y_pred_arr.append(pred_dist.loc)
# Out:
# restart: 0, epoch: 1, iter: 1, loss: 1.5107
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/kernels/inducing_point_kernel.py:61: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352645774/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   inv_root = torch.triangular_solve(eye, chol)[0]
# restart: 0, epoch: 2, iter: 1, loss: 1.4924
# restart: 0, epoch: 3, iter: 1, loss: 1.4777
# restart: 0, epoch: 4, iter: 1, loss: 1.4656
# restart: 0, epoch: 5, iter: 1, loss: 1.4551
# restart: 0, epoch: 6, iter: 1, loss: 1.4457
# restart: 0, epoch: 7, iter: 1, loss: 1.4373
# restart: 0, epoch: 8, iter: 1, loss: 1.4296
# restart: 0, epoch: 9, iter: 1, loss: 1.4224
# restart: 0, epoch: 10, iter: 1, loss: 1.4158
# restart: 0, epoch: 11, iter: 1, loss: 1.4095
# restart: 0, epoch: 12, iter: 1, loss: 1.4035
# restart: 0, epoch: 13, iter: 1, loss: 1.3979
# restart: 0, epoch: 14, iter: 1, loss: 1.3925
# restart: 0, epoch: 15, iter: 1, loss: 1.3873
# restart: 0, epoch: 16, iter: 1, loss: 1.3823
# restart: 0, epoch: 17, iter: 1, loss: 1.3775
# restart: 0, epoch: 18, iter: 1, loss: 1.3729
# restart: 0, epoch: 19, iter: 1, loss: 1.3685
# restart: 0, epoch: 20, iter: 1, loss: 1.3642
# restart: 0, epoch: 21, iter: 1, loss: 1.3601
# restart: 0, epoch: 22, iter: 1, loss: 1.3561
# restart: 0, epoch: 23, iter: 1, loss: 1.3523
# restart: 0, epoch: 24, iter: 1, loss: 1.3487
# restart: 0, epoch: 25, iter: 1, loss: 1.3451
# restart: 0, epoch: 26, iter: 1, loss: 1.3417
# restart: 0, epoch: 27, iter: 1, loss: 1.3384
# restart: 0, epoch: 28, iter: 1, loss: 1.3352
# restart: 0, epoch: 29, iter: 1, loss: 1.3322
# restart: 0, epoch: 30, iter: 1, loss: 1.3291
# restart: 0, epoch: 31, iter: 1, loss: 1.3262
# restart: 0, epoch: 32, iter: 1, loss: 1.3234
# restart: 0, epoch: 33, iter: 1, loss: 1.3206
# restart: 0, epoch: 34, iter: 1, loss: 1.3178
# restart: 0, epoch: 35, iter: 1, loss: 1.3151
# restart: 0, epoch: 36, iter: 1, loss: 1.3125
# restart: 0, epoch: 37, iter: 1, loss: 1.3099
# restart: 0, epoch: 38, iter: 1, loss: 1.3073
# restart: 0, epoch: 39, iter: 1, loss: 1.3048
# restart: 0, epoch: 40, iter: 1, loss: 1.3023
# restart: 0, epoch: 41, iter: 1, loss: 1.2998
# restart: 0, epoch: 42, iter: 1, loss: 1.2973
# restart: 0, epoch: 43, iter: 1, loss: 1.2949
# restart: 0, epoch: 44, iter: 1, loss: 1.2925
# restart: 0, epoch: 45, iter: 1, loss: 1.2901
# restart: 0, epoch: 46, iter: 1, loss: 1.2877
# restart: 0, epoch: 47, iter: 1, loss: 1.2853
# restart: 0, epoch: 48, iter: 1, loss: 1.2829
# restart: 0, epoch: 49, iter: 1, loss: 1.2805
# restart: 0, epoch: 50, iter: 1, loss: 1.2782
# restart: 0, epoch: 51, iter: 1, loss: 1.2758
# restart: 0, epoch: 52, iter: 1, loss: 1.2735
# restart: 0, epoch: 53, iter: 1, loss: 1.2711
# restart: 0, epoch: 54, iter: 1, loss: 1.2688
# restart: 0, epoch: 55, iter: 1, loss: 1.2664
# restart: 0, epoch: 56, iter: 1, loss: 1.2641
# restart: 0, epoch: 57, iter: 1, loss: 1.2617
# restart: 0, epoch: 58, iter: 1, loss: 1.2594
# restart: 0, epoch: 59, iter: 1, loss: 1.2570
# restart: 0, epoch: 60, iter: 1, loss: 1.2547
# restart: 0, epoch: 61, iter: 1, loss: 1.2523
# restart: 0, epoch: 62, iter: 1, loss: 1.2500
# restart: 0, epoch: 63, iter: 1, loss: 1.2476
# restart: 0, epoch: 64, iter: 1, loss: 1.2453
# restart: 0, epoch: 65, iter: 1, loss: 1.2429
# restart: 0, epoch: 66, iter: 1, loss: 1.2405
# restart: 0, epoch: 67, iter: 1, loss: 1.2382
# restart: 0, epoch: 68, iter: 1, loss: 1.2358
# restart: 0, epoch: 69, iter: 1, loss: 1.2334
# restart: 0, epoch: 70, iter: 1, loss: 1.2310
# restart: 0, epoch: 71, iter: 1, loss: 1.2286
# restart: 0, epoch: 72, iter: 1, loss: 1.2262
# restart: 0, epoch: 73, iter: 1, loss: 1.2238
# restart: 0, epoch: 74, iter: 1, loss: 1.2214
# restart: 0, epoch: 75, iter: 1, loss: 1.2189
# restart: 0, epoch: 76, iter: 1, loss: 1.2165
# restart: 0, epoch: 77, iter: 1, loss: 1.2141
# restart: 0, epoch: 78, iter: 1, loss: 1.2116
# restart: 0, epoch: 79, iter: 1, loss: 1.2091
# restart: 0, epoch: 80, iter: 1, loss: 1.2067
# restart: 0, epoch: 81, iter: 1, loss: 1.2042
# restart: 0, epoch: 82, iter: 1, loss: 1.2017
# restart: 0, epoch: 83, iter: 1, loss: 1.1993
# restart: 0, epoch: 84, iter: 1, loss: 1.1968
# restart: 0, epoch: 85, iter: 1, loss: 1.1943
# restart: 0, epoch: 86, iter: 1, loss: 1.1918
# restart: 0, epoch: 87, iter: 1, loss: 1.1893
# restart: 0, epoch: 88, iter: 1, loss: 1.1868
# restart: 0, epoch: 89, iter: 1, loss: 1.1843
# restart: 0, epoch: 90, iter: 1, loss: 1.1818
# restart: 0, epoch: 91, iter: 1, loss: 1.1792
# restart: 0, epoch: 92, iter: 1, loss: 1.1767
# restart: 0, epoch: 93, iter: 1, loss: 1.1742
# restart: 0, epoch: 94, iter: 1, loss: 1.1717
# restart: 0, epoch: 95, iter: 1, loss: 1.1691
# restart: 0, epoch: 96, iter: 1, loss: 1.1666
# restart: 0, epoch: 97, iter: 1, loss: 1.1641
# restart: 0, epoch: 98, iter: 1, loss: 1.1616
# restart: 0, epoch: 99, iter: 1, loss: 1.1590
# restart: 0, epoch: 100, iter: 1, loss: 1.1564
# restart: 0, epoch: 101, iter: 1, loss: 1.1539
# restart: 0, epoch: 102, iter: 1, loss: 1.1513
# restart: 0, epoch: 103, iter: 1, loss: 1.1487
# restart: 0, epoch: 104, iter: 1, loss: 1.1461
# restart: 0, epoch: 105, iter: 1, loss: 1.1435
# restart: 0, epoch: 106, iter: 1, loss: 1.1409
# restart: 0, epoch: 107, iter: 1, loss: 1.1383
# restart: 0, epoch: 108, iter: 1, loss: 1.1356
# restart: 0, epoch: 109, iter: 1, loss: 1.1330
# restart: 0, epoch: 110, iter: 1, loss: 1.1304
# restart: 0, epoch: 111, iter: 1, loss: 1.1279
# restart: 0, epoch: 112, iter: 1, loss: 1.1252
# restart: 0, epoch: 113, iter: 1, loss: 1.1226
# restart: 0, epoch: 114, iter: 1, loss: 1.1200
# restart: 0, epoch: 115, iter: 1, loss: 1.1174
# restart: 0, epoch: 116, iter: 1, loss: 1.1147
# restart: 0, epoch: 117, iter: 1, loss: 1.1121
# restart: 0, epoch: 118, iter: 1, loss: 1.1095
# restart: 0, epoch: 119, iter: 1, loss: 1.1068
# restart: 0, epoch: 120, iter: 1, loss: 1.1041
# restart: 0, epoch: 121, iter: 1, loss: 1.1014
# restart: 0, epoch: 122, iter: 1, loss: 1.0987
# restart: 0, epoch: 123, iter: 1, loss: 1.0961
# restart: 0, epoch: 124, iter: 1, loss: 1.0933
# restart: 0, epoch: 125, iter: 1, loss: 1.0907
# restart: 0, epoch: 126, iter: 1, loss: 1.0879
# restart: 0, epoch: 127, iter: 1, loss: 1.0853
# restart: 0, epoch: 128, iter: 1, loss: 1.0825
# restart: 0, epoch: 129, iter: 1, loss: 1.0798
# restart: 0, epoch: 130, iter: 1, loss: 1.0771
# restart: 0, epoch: 131, iter: 1, loss: 1.0744
# restart: 0, epoch: 132, iter: 1, loss: 1.0718
# restart: 0, epoch: 133, iter: 1, loss: 1.0691
# restart: 0, epoch: 134, iter: 1, loss: 1.0664
# restart: 0, epoch: 135, iter: 1, loss: 1.0638
# restart: 0, epoch: 136, iter: 1, loss: 1.0611
# restart: 0, epoch: 137, iter: 1, loss: 1.0585
# restart: 0, epoch: 138, iter: 1, loss: 1.0559
# restart: 0, epoch: 139, iter: 1, loss: 1.0532
# restart: 0, epoch: 140, iter: 1, loss: 1.0505
# restart: 0, epoch: 141, iter: 1, loss: 1.0480
# restart: 0, epoch: 142, iter: 1, loss: 1.0454
# restart: 0, epoch: 143, iter: 1, loss: 1.0428
# restart: 0, epoch: 144, iter: 1, loss: 1.0402
# restart: 0, epoch: 145, iter: 1, loss: 1.0377
# restart: 0, epoch: 146, iter: 1, loss: 1.0351
# restart: 0, epoch: 147, iter: 1, loss: 1.0325
# restart: 0, epoch: 148, iter: 1, loss: 1.0300
# restart: 0, epoch: 149, iter: 1, loss: 1.0276
# restart: 0, epoch: 150, iter: 1, loss: 1.0250
# restart: 0, epoch: 151, iter: 1, loss: 1.0225
# restart: 0, epoch: 152, iter: 1, loss: 1.0201
# restart: 0, epoch: 153, iter: 1, loss: 1.0175
# restart: 0, epoch: 154, iter: 1, loss: 1.0152
# restart: 0, epoch: 155, iter: 1, loss: 1.0126
# restart: 0, epoch: 156, iter: 1, loss: 1.0101
# restart: 0, epoch: 157, iter: 1, loss: 1.0078
# restart: 0, epoch: 158, iter: 1, loss: 1.0054
# restart: 0, epoch: 159, iter: 1, loss: 1.0030
# restart: 0, epoch: 160, iter: 1, loss: 1.0007
# restart: 0, epoch: 161, iter: 1, loss: 0.9983
# restart: 0, epoch: 162, iter: 1, loss: 0.9959
# restart: 0, epoch: 163, iter: 1, loss: 0.9936
# restart: 0, epoch: 164, iter: 1, loss: 0.9913
# restart: 0, epoch: 165, iter: 1, loss: 0.9890
# restart: 0, epoch: 166, iter: 1, loss: 0.9867
# restart: 0, epoch: 167, iter: 1, loss: 0.9845
# restart: 0, epoch: 168, iter: 1, loss: 0.9822
# restart: 0, epoch: 169, iter: 1, loss: 0.9801
# restart: 0, epoch: 170, iter: 1, loss: 0.9777
# restart: 0, epoch: 171, iter: 1, loss: 0.9755
# restart: 0, epoch: 172, iter: 1, loss: 0.9733
# restart: 0, epoch: 173, iter: 1, loss: 0.9711
# restart: 0, epoch: 174, iter: 1, loss: 0.9688
# restart: 0, epoch: 175, iter: 1, loss: 0.9666
# restart: 0, epoch: 176, iter: 1, loss: 0.9644
# restart: 0, epoch: 177, iter: 1, loss: 0.9622
# restart: 0, epoch: 178, iter: 1, loss: 0.9600
# restart: 0, epoch: 179, iter: 1, loss: 0.9579
# restart: 0, epoch: 180, iter: 1, loss: 0.9558
# restart: 0, epoch: 181, iter: 1, loss: 0.9536
# restart: 0, epoch: 182, iter: 1, loss: 0.9514
# restart: 0, epoch: 183, iter: 1, loss: 0.9493
# restart: 0, epoch: 184, iter: 1, loss: 0.9471
# restart: 0, epoch: 185, iter: 1, loss: 0.9451
# restart: 0, epoch: 186, iter: 1, loss: 0.9430
# restart: 0, epoch: 187, iter: 1, loss: 0.9411
# restart: 0, epoch: 188, iter: 1, loss: 0.9391
# restart: 0, epoch: 189, iter: 1, loss: 0.9371
# restart: 0, epoch: 190, iter: 1, loss: 0.9351
# restart: 0, epoch: 191, iter: 1, loss: 0.9331
# restart: 0, epoch: 192, iter: 1, loss: 0.9311
# restart: 0, epoch: 193, iter: 1, loss: 0.9292
# restart: 0, epoch: 194, iter: 1, loss: 0.9273
# restart: 0, epoch: 195, iter: 1, loss: 0.9255
# restart: 0, epoch: 196, iter: 1, loss: 0.9236
# restart: 0, epoch: 197, iter: 1, loss: 0.9218
# restart: 0, epoch: 198, iter: 1, loss: 0.9200
# restart: 0, epoch: 199, iter: 1, loss: 0.9182
# restart: 0, epoch: 200, iter: 1, loss: 0.9164
# restart: 0, epoch: 201, iter: 1, loss: 0.9148
# restart: 0, epoch: 202, iter: 1, loss: 0.9129
# restart: 0, epoch: 203, iter: 1, loss: 0.9112
# restart: 0, epoch: 204, iter: 1, loss: 0.9095
# restart: 0, epoch: 205, iter: 1, loss: 0.9078
# restart: 0, epoch: 206, iter: 1, loss: 0.9061
# restart: 0, epoch: 207, iter: 1, loss: 0.9044
# restart: 0, epoch: 208, iter: 1, loss: 0.9028
# restart: 0, epoch: 209, iter: 1, loss: 0.9012
# restart: 0, epoch: 210, iter: 1, loss: 0.8997
# restart: 0, epoch: 211, iter: 1, loss: 0.8981
# restart: 0, epoch: 212, iter: 1, loss: 0.8966
# restart: 0, epoch: 213, iter: 1, loss: 0.8950
# restart: 0, epoch: 214, iter: 1, loss: 0.8935
# restart: 0, epoch: 215, iter: 1, loss: 0.8920
# restart: 0, epoch: 216, iter: 1, loss: 0.8905
# restart: 0, epoch: 217, iter: 1, loss: 0.8890
# restart: 0, epoch: 218, iter: 1, loss: 0.8875
# restart: 0, epoch: 219, iter: 1, loss: 0.8861
# restart: 0, epoch: 220, iter: 1, loss: 0.8846
# restart: 0, epoch: 221, iter: 1, loss: 0.8833
# restart: 0, epoch: 222, iter: 1, loss: 0.8818
# restart: 0, epoch: 223, iter: 1, loss: 0.8804
# restart: 0, epoch: 224, iter: 1, loss: 0.8789
# restart: 0, epoch: 225, iter: 1, loss: 0.8776
# restart: 0, epoch: 226, iter: 1, loss: 0.8762
# restart: 0, epoch: 227, iter: 1, loss: 0.8750
# restart: 0, epoch: 228, iter: 1, loss: 0.8739
# restart: 0, epoch: 229, iter: 1, loss: 0.8724
# restart: 0, epoch: 230, iter: 1, loss: 0.8710
# restart: 0, epoch: 231, iter: 1, loss: 0.8697
# restart: 0, epoch: 232, iter: 1, loss: 0.8686
# restart: 0, epoch: 233, iter: 1, loss: 0.8671
# restart: 0, epoch: 234, iter: 1, loss: 0.8658
# restart: 0, epoch: 235, iter: 1, loss: 0.8645
# restart: 0, epoch: 236, iter: 1, loss: 0.8633
# restart: 0, epoch: 237, iter: 1, loss: 0.8621
# restart: 0, epoch: 238, iter: 1, loss: 0.8608
# restart: 0, epoch: 239, iter: 1, loss: 0.8596
# restart: 0, epoch: 240, iter: 1, loss: 0.8584
# restart: 0, epoch: 241, iter: 1, loss: 0.8573
# restart: 0, epoch: 242, iter: 1, loss: 0.8561
# restart: 0, epoch: 243, iter: 1, loss: 0.8550
# restart: 0, epoch: 244, iter: 1, loss: 0.8540
# restart: 0, epoch: 245, iter: 1, loss: 0.8531
# restart: 0, epoch: 246, iter: 1, loss: 0.8519
# restart: 0, epoch: 247, iter: 1, loss: 0.8508
# restart: 0, epoch: 248, iter: 1, loss: 0.8497
# restart: 0, epoch: 249, iter: 1, loss: 0.8485
# restart: 0, epoch: 250, iter: 1, loss: 0.8474
# restart: 0, epoch: 251, iter: 1, loss: 0.8464
# restart: 0, epoch: 252, iter: 1, loss: 0.8454
# restart: 0, epoch: 253, iter: 1, loss: 0.8444
# restart: 0, epoch: 254, iter: 1, loss: 0.8434
# restart: 0, epoch: 255, iter: 1, loss: 0.8424
# restart: 0, epoch: 256, iter: 1, loss: 0.8413
# restart: 0, epoch: 257, iter: 1, loss: 0.8403
# restart: 0, epoch: 258, iter: 1, loss: 0.8392
# restart: 0, epoch: 259, iter: 1, loss: 0.8382
# restart: 0, epoch: 260, iter: 1, loss: 0.8373
# restart: 0, epoch: 261, iter: 1, loss: 0.8365
# restart: 0, epoch: 262, iter: 1, loss: 0.8354
# restart: 0, epoch: 263, iter: 1, loss: 0.8345
# restart: 0, epoch: 264, iter: 1, loss: 0.8336
# restart: 0, epoch: 265, iter: 1, loss: 0.8326
# restart: 0, epoch: 266, iter: 1, loss: 0.8317
# restart: 0, epoch: 267, iter: 1, loss: 0.8307
# restart: 0, epoch: 268, iter: 1, loss: 0.8298
# restart: 0, epoch: 269, iter: 1, loss: 0.8289
# restart: 0, epoch: 270, iter: 1, loss: 0.8279
# restart: 0, epoch: 271, iter: 1, loss: 0.8271
# restart: 0, epoch: 272, iter: 1, loss: 0.8262
# restart: 0, epoch: 273, iter: 1, loss: 0.8253
# restart: 0, epoch: 274, iter: 1, loss: 0.8245
# restart: 0, epoch: 275, iter: 1, loss: 0.8237
# restart: 0, epoch: 276, iter: 1, loss: 0.8229
# restart: 0, epoch: 277, iter: 1, loss: 0.8221
# restart: 0, epoch: 278, iter: 1, loss: 0.8213
# restart: 0, epoch: 279, iter: 1, loss: 0.8204
# restart: 0, epoch: 280, iter: 1, loss: 0.8195
# restart: 0, epoch: 281, iter: 1, loss: 0.8187
# restart: 0, epoch: 282, iter: 1, loss: 0.8179
# restart: 0, epoch: 283, iter: 1, loss: 0.8171
# restart: 0, epoch: 284, iter: 1, loss: 0.8163
# restart: 0, epoch: 285, iter: 1, loss: 0.8155
# restart: 0, epoch: 286, iter: 1, loss: 0.8148
# restart: 0, epoch: 287, iter: 1, loss: 0.8140
# restart: 0, epoch: 288, iter: 1, loss: 0.8134
# restart: 0, epoch: 289, iter: 1, loss: 0.8128
# restart: 0, epoch: 290, iter: 1, loss: 0.8119
# restart: 0, epoch: 291, iter: 1, loss: 0.8111
# restart: 0, epoch: 292, iter: 1, loss: 0.8103
# restart: 0, epoch: 293, iter: 1, loss: 0.8095
# restart: 0, epoch: 294, iter: 1, loss: 0.8087
# restart: 0, epoch: 295, iter: 1, loss: 0.8079
# restart: 0, epoch: 296, iter: 1, loss: 0.8072
# restart: 0, epoch: 297, iter: 1, loss: 0.8064
# restart: 0, epoch: 298, iter: 1, loss: 0.8057
# restart: 0, epoch: 299, iter: 1, loss: 0.8049
# restart: 0, epoch: 300, iter: 1, loss: 0.8042
# restart: 0, epoch: 301, iter: 1, loss: 0.8035
# restart: 0, epoch: 302, iter: 1, loss: 0.8028
# restart: 0, epoch: 303, iter: 1, loss: 0.8021
# restart: 0, epoch: 304, iter: 1, loss: 0.8014
# restart: 0, epoch: 305, iter: 1, loss: 0.8007
# restart: 0, epoch: 306, iter: 1, loss: 0.8001
# restart: 0, epoch: 307, iter: 1, loss: 0.7994
# restart: 0, epoch: 308, iter: 1, loss: 0.7987
# restart: 0, epoch: 309, iter: 1, loss: 0.7981
# restart: 0, epoch: 310, iter: 1, loss: 0.7975
# restart: 0, epoch: 311, iter: 1, loss: 0.7969
# restart: 0, epoch: 312, iter: 1, loss: 0.7963
# restart: 0, epoch: 313, iter: 1, loss: 0.7958
# restart: 0, epoch: 314, iter: 1, loss: 0.7953
# restart: 0, epoch: 315, iter: 1, loss: 0.7946
# restart: 0, epoch: 316, iter: 1, loss: 0.7940
# restart: 0, epoch: 317, iter: 1, loss: 0.7935
# restart: 0, epoch: 318, iter: 1, loss: 0.7929
# restart: 0, epoch: 319, iter: 1, loss: 0.7924
# restart: 0, epoch: 320, iter: 1, loss: 0.7919
# restart: 0, epoch: 321, iter: 1, loss: 0.7913
# restart: 0, epoch: 322, iter: 1, loss: 0.7908
# restart: 0, epoch: 323, iter: 1, loss: 0.7903
# restart: 0, epoch: 324, iter: 1, loss: 0.7898
# restart: 0, epoch: 325, iter: 1, loss: 0.7892
# restart: 0, epoch: 326, iter: 1, loss: 0.7887
# restart: 0, epoch: 327, iter: 1, loss: 0.7882
# restart: 0, epoch: 328, iter: 1, loss: 0.7877
# restart: 0, epoch: 329, iter: 1, loss: 0.7872
# restart: 0, epoch: 330, iter: 1, loss: 0.7868
# restart: 0, epoch: 331, iter: 1, loss: 0.7864
# restart: 0, epoch: 332, iter: 1, loss: 0.7860
# restart: 0, epoch: 333, iter: 1, loss: 0.7854
# restart: 0, epoch: 334, iter: 1, loss: 0.7849
# restart: 0, epoch: 335, iter: 1, loss: 0.7844
# restart: 0, epoch: 336, iter: 1, loss: 0.7840
# restart: 0, epoch: 337, iter: 1, loss: 0.7835
# restart: 0, epoch: 338, iter: 1, loss: 0.7831
# restart: 0, epoch: 339, iter: 1, loss: 0.7826
# restart: 0, epoch: 340, iter: 1, loss: 0.7822
# restart: 0, epoch: 341, iter: 1, loss: 0.7818
# restart: 0, epoch: 342, iter: 1, loss: 0.7813
# restart: 0, epoch: 343, iter: 1, loss: 0.7809
# restart: 0, epoch: 344, iter: 1, loss: 0.7805
# restart: 0, epoch: 345, iter: 1, loss: 0.7801
# restart: 0, epoch: 346, iter: 1, loss: 0.7797
# restart: 0, epoch: 347, iter: 1, loss: 0.7793
# restart: 0, epoch: 348, iter: 1, loss: 0.7789
# restart: 0, epoch: 349, iter: 1, loss: 0.7785
# restart: 0, epoch: 350, iter: 1, loss: 0.7781
# restart: 0, epoch: 351, iter: 1, loss: 0.7777
# restart: 0, epoch: 352, iter: 1, loss: 0.7773
# restart: 0, epoch: 353, iter: 1, loss: 0.7770
# restart: 0, epoch: 354, iter: 1, loss: 0.7766
# restart: 0, epoch: 355, iter: 1, loss: 0.7762
# restart: 0, epoch: 356, iter: 1, loss: 0.7758
# restart: 0, epoch: 357, iter: 1, loss: 0.7754
# restart: 0, epoch: 358, iter: 1, loss: 0.7750
# restart: 0, epoch: 359, iter: 1, loss: 0.7747
# restart: 0, epoch: 360, iter: 1, loss: 0.7743
# restart: 0, epoch: 361, iter: 1, loss: 0.7739
# restart: 0, epoch: 362, iter: 1, loss: 0.7736
# restart: 0, epoch: 363, iter: 1, loss: 0.7732
# restart: 0, epoch: 364, iter: 1, loss: 0.7728
# restart: 0, epoch: 365, iter: 1, loss: 0.7725
# restart: 0, epoch: 366, iter: 1, loss: 0.7722
# restart: 0, epoch: 367, iter: 1, loss: 0.7719
# restart: 0, epoch: 368, iter: 1, loss: 0.7716
# restart: 0, epoch: 369, iter: 1, loss: 0.7713
# restart: 0, epoch: 370, iter: 1, loss: 0.7710
# restart: 0, epoch: 371, iter: 1, loss: 0.7707
# restart: 0, epoch: 372, iter: 1, loss: 0.7704
# restart: 0, epoch: 373, iter: 1, loss: 0.7701
# restart: 0, epoch: 374, iter: 1, loss: 0.7698
# restart: 0, epoch: 375, iter: 1, loss: 0.7695
# restart: 0, epoch: 376, iter: 1, loss: 0.7692
# restart: 0, epoch: 377, iter: 1, loss: 0.7689
# restart: 0, epoch: 378, iter: 1, loss: 0.7686
# restart: 0, epoch: 379, iter: 1, loss: 0.7682
# restart: 0, epoch: 380, iter: 1, loss: 0.7680
# restart: 0, epoch: 381, iter: 1, loss: 0.7677
# restart: 0, epoch: 382, iter: 1, loss: 0.7673
# restart: 0, epoch: 383, iter: 1, loss: 0.7671
# restart: 0, epoch: 384, iter: 1, loss: 0.7667
# restart: 0, epoch: 385, iter: 1, loss: 0.7665
# restart: 0, epoch: 386, iter: 1, loss: 0.7662
# restart: 0, epoch: 387, iter: 1, loss: 0.7659
# restart: 0, epoch: 388, iter: 1, loss: 0.7657
# restart: 0, epoch: 389, iter: 1, loss: 0.7654
# restart: 0, epoch: 390, iter: 1, loss: 0.7651
# restart: 0, epoch: 391, iter: 1, loss: 0.7649
# restart: 0, epoch: 392, iter: 1, loss: 0.7646
# restart: 0, epoch: 393, iter: 1, loss: 0.7644
# restart: 0, epoch: 394, iter: 1, loss: 0.7642
# restart: 0, epoch: 395, iter: 1, loss: 0.7640
# restart: 0, epoch: 396, iter: 1, loss: 0.7638
# restart: 0, epoch: 397, iter: 1, loss: 0.7635
# restart: 0, epoch: 398, iter: 1, loss: 0.7634
# restart: 0, epoch: 399, iter: 1, loss: 0.7632
# restart: 0, epoch: 400, iter: 1, loss: 0.7628
# restart: 0, epoch: 401, iter: 1, loss: 0.7626
# restart: 0, epoch: 402, iter: 1, loss: 0.7623
# restart: 0, epoch: 403, iter: 1, loss: 0.7620
# restart: 0, epoch: 404, iter: 1, loss: 0.7617
# restart: 0, epoch: 405, iter: 1, loss: 0.7615
# restart: 0, epoch: 406, iter: 1, loss: 0.7612
# restart: 0, epoch: 407, iter: 1, loss: 0.7610
# restart: 0, epoch: 408, iter: 1, loss: 0.7607
# restart: 0, epoch: 409, iter: 1, loss: 0.7605
# restart: 0, epoch: 410, iter: 1, loss: 0.7602
# restart: 0, epoch: 411, iter: 1, loss: 0.7600
# restart: 0, epoch: 412, iter: 1, loss: 0.7598
# restart: 0, epoch: 413, iter: 1, loss: 0.7595
# restart: 0, epoch: 414, iter: 1, loss: 0.7593
# restart: 0, epoch: 415, iter: 1, loss: 0.7590
# restart: 0, epoch: 416, iter: 1, loss: 0.7588
# restart: 0, epoch: 417, iter: 1, loss: 0.7586
# restart: 0, epoch: 418, iter: 1, loss: 0.7584
# restart: 0, epoch: 419, iter: 1, loss: 0.7582
# restart: 0, epoch: 420, iter: 1, loss: 0.7580
# restart: 0, epoch: 421, iter: 1, loss: 0.7578
# restart: 0, epoch: 422, iter: 1, loss: 0.7575
# restart: 0, epoch: 423, iter: 1, loss: 0.7573
# restart: 0, epoch: 424, iter: 1, loss: 0.7571
# restart: 0, epoch: 425, iter: 1, loss: 0.7570
# restart: 0, epoch: 426, iter: 1, loss: 0.7568
# restart: 0, epoch: 427, iter: 1, loss: 0.7566
# restart: 0, epoch: 428, iter: 1, loss: 0.7564
# restart: 0, epoch: 429, iter: 1, loss: 0.7562
# restart: 0, epoch: 430, iter: 1, loss: 0.7563
# restart: 0, epoch: 431, iter: 1, loss: 0.7560
# restart: 0, epoch: 432, iter: 1, loss: 0.7556
# restart: 0, epoch: 433, iter: 1, loss: 0.7554
# restart: 0, epoch: 434, iter: 1, loss: 0.7552
# restart: 0, epoch: 435, iter: 1, loss: 0.7550
# restart: 0, epoch: 436, iter: 1, loss: 0.7548
# restart: 0, epoch: 437, iter: 1, loss: 0.7546
# restart: 0, epoch: 438, iter: 1, loss: 0.7544
# restart: 0, epoch: 439, iter: 1, loss: 0.7542
# restart: 0, epoch: 440, iter: 1, loss: 0.7540
# restart: 0, epoch: 441, iter: 1, loss: 0.7538
# restart: 0, epoch: 442, iter: 1, loss: 0.7537
# restart: 0, epoch: 443, iter: 1, loss: 0.7535
# restart: 0, epoch: 444, iter: 1, loss: 0.7534
# restart: 0, epoch: 445, iter: 1, loss: 0.7532
# restart: 0, epoch: 446, iter: 1, loss: 0.7529
# restart: 0, epoch: 447, iter: 1, loss: 0.7527
# restart: 0, epoch: 448, iter: 1, loss: 0.7526
# restart: 0, epoch: 449, iter: 1, loss: 0.7524
# restart: 0, epoch: 450, iter: 1, loss: 0.7522
# restart: 0, epoch: 451, iter: 1, loss: 0.7520
# restart: 0, epoch: 452, iter: 1, loss: 0.7519
# restart: 0, epoch: 453, iter: 1, loss: 0.7517
# restart: 0, epoch: 454, iter: 1, loss: 0.7515
# restart: 0, epoch: 455, iter: 1, loss: 0.7514
# restart: 0, epoch: 456, iter: 1, loss: 0.7514
# restart: 0, epoch: 457, iter: 1, loss: 0.7515
# restart: 0, epoch: 458, iter: 1, loss: 0.7512
# restart: 0, epoch: 459, iter: 1, loss: 0.7509
# restart: 0, epoch: 460, iter: 1, loss: 0.7508
# restart: 0, epoch: 461, iter: 1, loss: 0.7506
# restart: 0, epoch: 462, iter: 1, loss: 0.7503
# restart: 0, epoch: 463, iter: 1, loss: 0.7501
# restart: 0, epoch: 464, iter: 1, loss: 0.7500
# restart: 0, epoch: 465, iter: 1, loss: 0.7498
# restart: 0, epoch: 466, iter: 1, loss: 0.7496
# restart: 0, epoch: 467, iter: 1, loss: 0.7495
# restart: 0, epoch: 468, iter: 1, loss: 0.7493
# restart: 0, epoch: 469, iter: 1, loss: 0.7492
# restart: 0, epoch: 470, iter: 1, loss: 0.7492
# restart: 0, epoch: 471, iter: 1, loss: 0.7491
# restart: 0, epoch: 472, iter: 1, loss: 0.7488
# restart: 0, epoch: 473, iter: 1, loss: 0.7486
# restart: 0, epoch: 474, iter: 1, loss: 0.7485
# restart: 0, epoch: 475, iter: 1, loss: 0.7483
# restart: 0, epoch: 476, iter: 1, loss: 0.7482
# restart: 0, epoch: 477, iter: 1, loss: 0.7480
# restart: 0, epoch: 478, iter: 1, loss: 0.7479
# restart: 0, epoch: 479, iter: 1, loss: 0.7477
# restart: 0, epoch: 480, iter: 1, loss: 0.7476
# restart: 0, epoch: 481, iter: 1, loss: 0.7474
# restart: 0, epoch: 482, iter: 1, loss: 0.7473
# restart: 0, epoch: 483, iter: 1, loss: 0.7471
# restart: 0, epoch: 484, iter: 1, loss: 0.7471
# restart: 0, epoch: 485, iter: 1, loss: 0.7470
# restart: 0, epoch: 486, iter: 1, loss: 0.7468
# restart: 0, epoch: 487, iter: 1, loss: 0.7467
# restart: 0, epoch: 488, iter: 1, loss: 0.7466
# restart: 0, epoch: 489, iter: 1, loss: 0.7465
# restart: 0, epoch: 490, iter: 1, loss: 0.7464
# restart: 0, epoch: 491, iter: 1, loss: 0.7462
# restart: 0, epoch: 492, iter: 1, loss: 0.7461
# restart: 0, epoch: 493, iter: 1, loss: 0.7459
# restart: 0, epoch: 494, iter: 1, loss: 0.7458
# restart: 0, epoch: 495, iter: 1, loss: 0.7457
# restart: 0, epoch: 496, iter: 1, loss: 0.7455
# restart: 0, epoch: 497, iter: 1, loss: 0.7454
# restart: 0, epoch: 498, iter: 1, loss: 0.7453
# restart: 0, epoch: 499, iter: 1, loss: 0.7452
# restart: 0, epoch: 500, iter: 1, loss: 0.7452
# restart: 0, epoch: 501, iter: 1, loss: 0.7451
# restart: 0, epoch: 502, iter: 1, loss: 0.7450
# restart: 0, epoch: 503, iter: 1, loss: 0.7449
# restart: 0, epoch: 504, iter: 1, loss: 0.7447
# restart: 0, epoch: 505, iter: 1, loss: 0.7445
# restart: 0, epoch: 506, iter: 1, loss: 0.7444
# restart: 0, epoch: 507, iter: 1, loss: 0.7443
# restart: 0, epoch: 508, iter: 1, loss: 0.7441
# restart: 0, epoch: 509, iter: 1, loss: 0.7440
# restart: 0, epoch: 510, iter: 1, loss: 0.7439
# restart: 0, epoch: 511, iter: 1, loss: 0.7438
# restart: 0, epoch: 512, iter: 1, loss: 0.7436
# restart: 0, epoch: 513, iter: 1, loss: 0.7435
# restart: 0, epoch: 514, iter: 1, loss: 0.7434
# restart: 0, epoch: 515, iter: 1, loss: 0.7433
# restart: 0, epoch: 516, iter: 1, loss: 0.7432
# restart: 0, epoch: 517, iter: 1, loss: 0.7430
# restart: 0, epoch: 518, iter: 1, loss: 0.7429
# restart: 0, epoch: 519, iter: 1, loss: 0.7428
# restart: 0, epoch: 520, iter: 1, loss: 0.7427
# restart: 0, epoch: 521, iter: 1, loss: 0.7426
# restart: 0, epoch: 522, iter: 1, loss: 0.7425
# restart: 0, epoch: 523, iter: 1, loss: 0.7424
# restart: 0, epoch: 524, iter: 1, loss: 0.7423
# restart: 0, epoch: 525, iter: 1, loss: 0.7422
# restart: 0, epoch: 526, iter: 1, loss: 0.7421
# restart: 0, epoch: 527, iter: 1, loss: 0.7420
# restart: 0, epoch: 528, iter: 1, loss: 0.7419
# restart: 0, epoch: 529, iter: 1, loss: 0.7418
# restart: 0, epoch: 530, iter: 1, loss: 0.7418
# restart: 0, epoch: 531, iter: 1, loss: 0.7416
# restart: 0, epoch: 532, iter: 1, loss: 0.7415
# restart: 0, epoch: 533, iter: 1, loss: 0.7414
# restart: 0, epoch: 534, iter: 1, loss: 0.7414
# restart: 0, epoch: 535, iter: 1, loss: 0.7413
# restart: 0, epoch: 536, iter: 1, loss: 0.7411
# restart: 0, epoch: 537, iter: 1, loss: 0.7410
# restart: 0, epoch: 538, iter: 1, loss: 0.7410
# restart: 0, epoch: 539, iter: 1, loss: 0.7409
# restart: 0, epoch: 540, iter: 1, loss: 0.7408
# restart: 0, epoch: 541, iter: 1, loss: 0.7407
# restart: 0, epoch: 542, iter: 1, loss: 0.7406
# restart: 0, epoch: 543, iter: 1, loss: 0.7405
# restart: 0, epoch: 544, iter: 1, loss: 0.7404
# restart: 0, epoch: 545, iter: 1, loss: 0.7403
# restart: 0, epoch: 546, iter: 1, loss: 0.7402
# restart: 0, epoch: 547, iter: 1, loss: 0.7401
# restart: 0, epoch: 548, iter: 1, loss: 0.7400
# restart: 0, epoch: 549, iter: 1, loss: 0.7399
# restart: 0, epoch: 550, iter: 1, loss: 0.7398
# restart: 0, epoch: 551, iter: 1, loss: 0.7397
# restart: 0, epoch: 552, iter: 1, loss: 0.7396
# restart: 0, epoch: 553, iter: 1, loss: 0.7395
# restart: 0, epoch: 554, iter: 1, loss: 0.7394
# restart: 0, epoch: 555, iter: 1, loss: 0.7393
# restart: 0, epoch: 556, iter: 1, loss: 0.7392
# restart: 0, epoch: 557, iter: 1, loss: 0.7391
# restart: 0, epoch: 558, iter: 1, loss: 0.7390
# restart: 0, epoch: 559, iter: 1, loss: 0.7389
# restart: 0, epoch: 560, iter: 1, loss: 0.7388
# restart: 0, epoch: 561, iter: 1, loss: 0.7387
# restart: 0, epoch: 562, iter: 1, loss: 0.7386
# restart: 0, epoch: 563, iter: 1, loss: 0.7386
# restart: 0, epoch: 564, iter: 1, loss: 0.7385
# restart: 0, epoch: 565, iter: 1, loss: 0.7384
# restart: 0, epoch: 566, iter: 1, loss: 0.7383
# restart: 0, epoch: 567, iter: 1, loss: 0.7382
# restart: 0, epoch: 568, iter: 1, loss: 0.7380
# restart: 0, epoch: 569, iter: 1, loss: 0.7379
# restart: 0, epoch: 570, iter: 1, loss: 0.7378
# restart: 0, epoch: 571, iter: 1, loss: 0.7377
# restart: 0, epoch: 572, iter: 1, loss: 0.7376
# restart: 0, epoch: 573, iter: 1, loss: 0.7375
# restart: 0, epoch: 574, iter: 1, loss: 0.7375
# restart: 0, epoch: 575, iter: 1, loss: 0.7374
# restart: 0, epoch: 576, iter: 1, loss: 0.7373
# restart: 0, epoch: 577, iter: 1, loss: 0.7372
# restart: 0, epoch: 578, iter: 1, loss: 0.7370
# restart: 0, epoch: 579, iter: 1, loss: 0.7369
# restart: 0, epoch: 580, iter: 1, loss: 0.7368
# restart: 0, epoch: 581, iter: 1, loss: 0.7367
# restart: 0, epoch: 582, iter: 1, loss: 0.7366
# restart: 0, epoch: 583, iter: 1, loss: 0.7365
# restart: 0, epoch: 584, iter: 1, loss: 0.7364
# restart: 0, epoch: 585, iter: 1, loss: 0.7363
# restart: 0, epoch: 586, iter: 1, loss: 0.7367
# restart: 0, epoch: 587, iter: 1, loss: 0.7376
# restart: 0, epoch: 588, iter: 1, loss: 0.7368
# restart: 0, epoch: 589, iter: 1, loss: 0.7365
# restart: 0, epoch: 590, iter: 1, loss: 0.7364
# restart: 0, epoch: 591, iter: 1, loss: 0.7362
# restart: 0, epoch: 592, iter: 1, loss: 0.7361
# restart: 0, epoch: 593, iter: 1, loss: 0.7359
# restart: 0, epoch: 594, iter: 1, loss: 0.7358
# restart: 0, epoch: 595, iter: 1, loss: 0.7357
# restart: 0, epoch: 596, iter: 1, loss: 0.7356
# restart: 0, epoch: 597, iter: 1, loss: 0.7355
# restart: 0, epoch: 598, iter: 1, loss: 0.7354
# restart: 0, epoch: 599, iter: 1, loss: 0.7353
# restart: 0, epoch: 600, iter: 1, loss: 0.7352
# restart: 0, epoch: 601, iter: 1, loss: 0.7351
# restart: 0, epoch: 602, iter: 1, loss: 0.7350
# restart: 0, epoch: 603, iter: 1, loss: 0.7349
# restart: 0, epoch: 604, iter: 1, loss: 0.7348
# restart: 0, epoch: 605, iter: 1, loss: 0.7347
# restart: 0, epoch: 606, iter: 1, loss: 0.7346
# restart: 0, epoch: 607, iter: 1, loss: 0.7346
# restart: 0, epoch: 608, iter: 1, loss: 0.7345
# restart: 0, epoch: 609, iter: 1, loss: 0.7344
# restart: 0, epoch: 610, iter: 1, loss: 0.7343
# restart: 0, epoch: 611, iter: 1, loss: 0.7342
# restart: 0, epoch: 612, iter: 1, loss: 0.7341
# restart: 0, epoch: 613, iter: 1, loss: 0.7341
# restart: 0, epoch: 614, iter: 1, loss: 0.7340
# restart: 0, epoch: 615, iter: 1, loss: 0.7339
# restart: 0, epoch: 616, iter: 1, loss: 0.7339
# restart: 0, epoch: 617, iter: 1, loss: 0.7338
# restart: 0, epoch: 618, iter: 1, loss: 0.7337
# restart: 0, epoch: 619, iter: 1, loss: 0.7337
# restart: 0, epoch: 620, iter: 1, loss: 0.7336
# restart: 0, epoch: 621, iter: 1, loss: 0.7335
# restart: 0, epoch: 622, iter: 1, loss: 0.7336
# restart: 0, epoch: 623, iter: 1, loss: 0.7335
# restart: 0, epoch: 624, iter: 1, loss: 0.7334
# restart: 0, epoch: 625, iter: 1, loss: 0.7334
# restart: 0, epoch: 626, iter: 1, loss: 0.7333
# restart: 0, epoch: 627, iter: 1, loss: 0.7333
# restart: 0, epoch: 628, iter: 1, loss: 0.7332
# restart: 0, epoch: 629, iter: 1, loss: 0.7332
# restart: 0, epoch: 630, iter: 1, loss: 0.7331
# restart: 0, epoch: 631, iter: 1, loss: 0.7330
# restart: 0, epoch: 632, iter: 1, loss: 0.7329
# restart: 0, epoch: 633, iter: 1, loss: 0.7328
# restart: 0, epoch: 634, iter: 1, loss: 0.7328
# restart: 0, epoch: 635, iter: 1, loss: 0.7327
# restart: 0, epoch: 636, iter: 1, loss: 0.7327
# restart: 0, epoch: 637, iter: 1, loss: 0.7326
# restart: 0, epoch: 638, iter: 1, loss: 0.7326
# restart: 0, epoch: 639, iter: 1, loss: 0.7325
# restart: 0, epoch: 640, iter: 1, loss: 0.7324
# restart: 0, epoch: 641, iter: 1, loss: 0.7323
# restart: 0, epoch: 642, iter: 1, loss: 0.7322
# restart: 0, epoch: 643, iter: 1, loss: 0.7321
# restart: 0, epoch: 644, iter: 1, loss: 0.7321
# restart: 0, epoch: 645, iter: 1, loss: 0.7320
# restart: 0, epoch: 646, iter: 1, loss: 0.7319
# restart: 0, epoch: 647, iter: 1, loss: 0.7319
# restart: 0, epoch: 648, iter: 1, loss: 0.7318
# restart: 0, epoch: 649, iter: 1, loss: 0.7317
# restart: 0, epoch: 650, iter: 1, loss: 0.7316
# restart: 0, epoch: 651, iter: 1, loss: 0.7316
# restart: 0, epoch: 652, iter: 1, loss: 0.7315
# restart: 0, epoch: 653, iter: 1, loss: 0.7315
# restart: 0, epoch: 654, iter: 1, loss: 0.7314
# restart: 0, epoch: 655, iter: 1, loss: 0.7314
# restart: 0, epoch: 656, iter: 1, loss: 0.7315
# restart: 0, epoch: 657, iter: 1, loss: 0.7315
# restart: 0, epoch: 658, iter: 1, loss: 0.7314
# restart: 0, epoch: 659, iter: 1, loss: 0.7313
# restart: 0, epoch: 660, iter: 1, loss: 0.7312
# restart: 0, epoch: 661, iter: 1, loss: 0.7311
# restart: 0, epoch: 662, iter: 1, loss: 0.7310
# restart: 0, epoch: 663, iter: 1, loss: 0.7311
# restart: 0, epoch: 664, iter: 1, loss: 0.7318
# restart: 0, epoch: 665, iter: 1, loss: 0.7317
# restart: 0, epoch: 666, iter: 1, loss: 0.7311
# restart: 0, epoch: 667, iter: 1, loss: 0.7311
# restart: 0, epoch: 668, iter: 1, loss: 0.7309
# restart: 0, epoch: 669, iter: 1, loss: 0.7309
# restart: 0, epoch: 670, iter: 1, loss: 0.7308
# restart: 0, epoch: 671, iter: 1, loss: 0.7307
# restart: 0, epoch: 672, iter: 1, loss: 0.7306
# restart: 0, epoch: 673, iter: 1, loss: 0.7305
# restart: 0, epoch: 674, iter: 1, loss: 0.7304
# restart: 0, epoch: 675, iter: 1, loss: 0.7303
# restart: 0, epoch: 676, iter: 1, loss: 0.7302
# restart: 0, epoch: 677, iter: 1, loss: 0.7301
# restart: 0, epoch: 678, iter: 1, loss: 0.7301
# restart: 0, epoch: 679, iter: 1, loss: 0.7300
# restart: 0, epoch: 680, iter: 1, loss: 0.7299
# restart: 0, epoch: 681, iter: 1, loss: 0.7299
# restart: 0, epoch: 682, iter: 1, loss: 0.7298
# restart: 0, epoch: 683, iter: 1, loss: 0.7298
# restart: 0, epoch: 684, iter: 1, loss: 0.7297
# restart: 0, epoch: 685, iter: 1, loss: 0.7296
# restart: 0, epoch: 686, iter: 1, loss: 0.7295
# restart: 0, epoch: 687, iter: 1, loss: 0.7295
# restart: 0, epoch: 688, iter: 1, loss: 0.7294
# restart: 0, epoch: 689, iter: 1, loss: 0.7293
# restart: 0, epoch: 690, iter: 1, loss: 0.7293
# restart: 0, epoch: 691, iter: 1, loss: 0.7292
# restart: 0, epoch: 692, iter: 1, loss: 0.7292
# restart: 0, epoch: 693, iter: 1, loss: 0.7291
# restart: 0, epoch: 694, iter: 1, loss: 0.7291
# restart: 0, epoch: 695, iter: 1, loss: 0.7290
# restart: 0, epoch: 696, iter: 1, loss: 0.7290
# restart: 0, epoch: 697, iter: 1, loss: 0.7289
# restart: 0, epoch: 698, iter: 1, loss: 0.7288
# restart: 0, epoch: 699, iter: 1, loss: 0.7288
# restart: 0, epoch: 700, iter: 1, loss: 0.7287
# restart: 0, epoch: 701, iter: 1, loss: 0.7287
# restart: 0, epoch: 702, iter: 1, loss: 0.7286
# restart: 0, epoch: 703, iter: 1, loss: 0.7286
# restart: 0, epoch: 704, iter: 1, loss: 0.7285
# restart: 0, epoch: 705, iter: 1, loss: 0.7285
# restart: 0, epoch: 706, iter: 1, loss: 0.7285
# restart: 0, epoch: 707, iter: 1, loss: 0.7285
# restart: 0, epoch: 708, iter: 1, loss: 0.7284
# restart: 0, epoch: 709, iter: 1, loss: 0.7283
# restart: 0, epoch: 710, iter: 1, loss: 0.7283
# restart: 0, epoch: 711, iter: 1, loss: 0.7283
# restart: 0, epoch: 712, iter: 1, loss: 0.7283
# restart: 0, epoch: 713, iter: 1, loss: 0.7284
# restart: 0, epoch: 714, iter: 1, loss: 0.7284
# restart: 0, epoch: 715, iter: 1, loss: 0.7282
# restart: 0, epoch: 716, iter: 1, loss: 0.7281
# restart: 0, epoch: 717, iter: 1, loss: 0.7281
# restart: 0, epoch: 718, iter: 1, loss: 0.7280
# restart: 0, epoch: 719, iter: 1, loss: 0.7279
# restart: 0, epoch: 720, iter: 1, loss: 0.7278
# restart: 0, epoch: 721, iter: 1, loss: 0.7278
# restart: 0, epoch: 722, iter: 1, loss: 0.7278
# restart: 0, epoch: 723, iter: 1, loss: 0.7277
# restart: 0, epoch: 724, iter: 1, loss: 0.7276
# restart: 0, epoch: 725, iter: 1, loss: 0.7276
# restart: 0, epoch: 726, iter: 1, loss: 0.7275
# restart: 0, epoch: 727, iter: 1, loss: 0.7274
# restart: 0, epoch: 728, iter: 1, loss: 0.7274
# restart: 0, epoch: 729, iter: 1, loss: 0.7273
# restart: 0, epoch: 730, iter: 1, loss: 0.7273
# restart: 0, epoch: 731, iter: 1, loss: 0.7272
# restart: 0, epoch: 732, iter: 1, loss: 0.7272
# restart: 0, epoch: 733, iter: 1, loss: 0.7271
# restart: 0, epoch: 734, iter: 1, loss: 0.7271
# restart: 0, epoch: 735, iter: 1, loss: 0.7270
# restart: 0, epoch: 736, iter: 1, loss: 0.7270
# restart: 0, epoch: 737, iter: 1, loss: 0.7269
# restart: 0, epoch: 738, iter: 1, loss: 0.7269
# restart: 0, epoch: 739, iter: 1, loss: 0.7268
# restart: 0, epoch: 740, iter: 1, loss: 0.7268
# restart: 0, epoch: 741, iter: 1, loss: 0.7268
# restart: 0, epoch: 742, iter: 1, loss: 0.7267
# restart: 0, epoch: 743, iter: 1, loss: 0.7267
# restart: 0, epoch: 744, iter: 1, loss: 0.7267
# restart: 0, epoch: 745, iter: 1, loss: 0.7267
# restart: 0, epoch: 746, iter: 1, loss: 0.7266
# restart: 0, epoch: 747, iter: 1, loss: 0.7266
# restart: 0, epoch: 748, iter: 1, loss: 0.7265
# restart: 0, epoch: 749, iter: 1, loss: 0.7265
# restart: 0, epoch: 750, iter: 1, loss: 0.7264
# restart: 0, epoch: 751, iter: 1, loss: 0.7264
# restart: 0, epoch: 752, iter: 1, loss: 0.7263
# restart: 0, epoch: 753, iter: 1, loss: 0.7263
# restart: 0, epoch: 754, iter: 1, loss: 0.7263
# restart: 0, epoch: 755, iter: 1, loss: 0.7262
# restart: 0, epoch: 756, iter: 1, loss: 0.7262
# restart: 0, epoch: 757, iter: 1, loss: 0.7261
# restart: 0, epoch: 758, iter: 1, loss: 0.7261
# restart: 0, epoch: 759, iter: 1, loss: 0.7261
# restart: 0, epoch: 760, iter: 1, loss: 0.7260
# restart: 0, epoch: 761, iter: 1, loss: 0.7259
# restart: 0, epoch: 762, iter: 1, loss: 0.7258
# restart: 0, epoch: 763, iter: 1, loss: 0.7258
# restart: 0, epoch: 764, iter: 1, loss: 0.7258
# restart: 0, epoch: 765, iter: 1, loss: 0.7257
# restart: 0, epoch: 766, iter: 1, loss: 0.7257
# restart: 0, epoch: 767, iter: 1, loss: 0.7256
# restart: 0, epoch: 768, iter: 1, loss: 0.7256
# restart: 0, epoch: 769, iter: 1, loss: 0.7256
# restart: 0, epoch: 770, iter: 1, loss: 0.7255
# restart: 0, epoch: 771, iter: 1, loss: 0.7255
# restart: 0, epoch: 772, iter: 1, loss: 0.7255
# restart: 0, epoch: 773, iter: 1, loss: 0.7254
# restart: 0, epoch: 774, iter: 1, loss: 0.7254
# restart: 0, epoch: 775, iter: 1, loss: 0.7253
# restart: 0, epoch: 776, iter: 1, loss: 0.7253
# restart: 0, epoch: 777, iter: 1, loss: 0.7252
# restart: 0, epoch: 778, iter: 1, loss: 0.7252
# restart: 0, epoch: 779, iter: 1, loss: 0.7252
# restart: 0, epoch: 780, iter: 1, loss: 0.7251
# restart: 0, epoch: 781, iter: 1, loss: 0.7251
# restart: 0, epoch: 782, iter: 1, loss: 0.7250
# restart: 0, epoch: 783, iter: 1, loss: 0.7249
# restart: 0, epoch: 784, iter: 1, loss: 0.7249
# restart: 0, epoch: 785, iter: 1, loss: 0.7250
# restart: 0, epoch: 786, iter: 1, loss: 0.7250
# restart: 0, epoch: 787, iter: 1, loss: 0.7249
# restart: 0, epoch: 788, iter: 1, loss: 0.7248
# restart: 0, epoch: 789, iter: 1, loss: 0.7247
# restart: 0, epoch: 790, iter: 1, loss: 0.7246
# restart: 0, epoch: 791, iter: 1, loss: 0.7246
# restart: 0, epoch: 792, iter: 1, loss: 0.7245
# restart: 0, epoch: 793, iter: 1, loss: 0.7244
# restart: 0, epoch: 794, iter: 1, loss: 0.7244
# restart: 0, epoch: 795, iter: 1, loss: 0.7243
# restart: 0, epoch: 796, iter: 1, loss: 0.7242
# restart: 0, epoch: 797, iter: 1, loss: 0.7242
# restart: 0, epoch: 798, iter: 1, loss: 0.7241
# restart: 0, epoch: 799, iter: 1, loss: 0.7241
# restart: 0, epoch: 800, iter: 1, loss: 0.7240
# restart: 0, epoch: 801, iter: 1, loss: 0.7240
# restart: 0, epoch: 802, iter: 1, loss: 0.7239
# restart: 0, epoch: 803, iter: 1, loss: 0.7239
# restart: 0, epoch: 804, iter: 1, loss: 0.7239
# restart: 0, epoch: 805, iter: 1, loss: 0.7239
# restart: 0, epoch: 806, iter: 1, loss: 0.7238
# restart: 0, epoch: 807, iter: 1, loss: 0.7237
# restart: 0, epoch: 808, iter: 1, loss: 0.7237
# restart: 0, epoch: 809, iter: 1, loss: 0.7236
# restart: 0, epoch: 810, iter: 1, loss: 0.7236
# restart: 0, epoch: 811, iter: 1, loss: 0.7236
# restart: 0, epoch: 812, iter: 1, loss: 0.7235
# restart: 0, epoch: 813, iter: 1, loss: 0.7234
# restart: 0, epoch: 814, iter: 1, loss: 0.7233
# restart: 0, epoch: 815, iter: 1, loss: 0.7233
# restart: 0, epoch: 816, iter: 1, loss: 0.7233
# restart: 0, epoch: 817, iter: 1, loss: 0.7232
# restart: 0, epoch: 818, iter: 1, loss: 0.7232
# restart: 0, epoch: 819, iter: 1, loss: 0.7232
# restart: 0, epoch: 820, iter: 1, loss: 0.7232
# restart: 0, epoch: 821, iter: 1, loss: 0.7231
# restart: 0, epoch: 822, iter: 1, loss: 0.7230
# restart: 0, epoch: 823, iter: 1, loss: 0.7230
# restart: 0, epoch: 824, iter: 1, loss: 0.7229
# restart: 0, epoch: 825, iter: 1, loss: 0.7229
# restart: 0, epoch: 826, iter: 1, loss: 0.7229
# restart: 0, epoch: 827, iter: 1, loss: 0.7228
# restart: 0, epoch: 828, iter: 1, loss: 0.7228
# restart: 0, epoch: 829, iter: 1, loss: 0.7227
# restart: 0, epoch: 830, iter: 1, loss: 0.7226
# restart: 0, epoch: 831, iter: 1, loss: 0.7226
# restart: 0, epoch: 832, iter: 1, loss: 0.7225
# restart: 0, epoch: 833, iter: 1, loss: 0.7225
# restart: 0, epoch: 834, iter: 1, loss: 0.7224
# restart: 0, epoch: 835, iter: 1, loss: 0.7224
# restart: 0, epoch: 836, iter: 1, loss: 0.7223
# restart: 0, epoch: 837, iter: 1, loss: 0.7223
# restart: 0, epoch: 838, iter: 1, loss: 0.7223
# restart: 0, epoch: 839, iter: 1, loss: 0.7223
# restart: 0, epoch: 840, iter: 1, loss: 0.7222
# restart: 0, epoch: 841, iter: 1, loss: 0.7222
# restart: 0, epoch: 842, iter: 1, loss: 0.7222
# restart: 0, epoch: 843, iter: 1, loss: 0.7222
# restart: 0, epoch: 844, iter: 1, loss: 0.7222
# restart: 0, epoch: 845, iter: 1, loss: 0.7221
# restart: 0, epoch: 846, iter: 1, loss: 0.7220
# restart: 0, epoch: 847, iter: 1, loss: 0.7220
# restart: 0, epoch: 848, iter: 1, loss: 0.7219
# restart: 0, epoch: 849, iter: 1, loss: 0.7219
# restart: 0, epoch: 850, iter: 1, loss: 0.7219
# restart: 0, epoch: 851, iter: 1, loss: 0.7218
# restart: 0, epoch: 852, iter: 1, loss: 0.7217
# restart: 0, epoch: 853, iter: 1, loss: 0.7217
# restart: 0, epoch: 854, iter: 1, loss: 0.7217
# restart: 0, epoch: 855, iter: 1, loss: 0.7217
# restart: 0, epoch: 856, iter: 1, loss: 0.7216
# restart: 0, epoch: 857, iter: 1, loss: 0.7216
# restart: 0, epoch: 858, iter: 1, loss: 0.7215
# restart: 0, epoch: 859, iter: 1, loss: 0.7215
# restart: 0, epoch: 860, iter: 1, loss: 0.7214
# restart: 0, epoch: 861, iter: 1, loss: 0.7213
# restart: 0, epoch: 862, iter: 1, loss: 0.7213
# restart: 0, epoch: 863, iter: 1, loss: 0.7212
# restart: 0, epoch: 864, iter: 1, loss: 0.7212
# restart: 0, epoch: 865, iter: 1, loss: 0.7212
# restart: 0, epoch: 866, iter: 1, loss: 0.7211
# restart: 0, epoch: 867, iter: 1, loss: 0.7211
# restart: 0, epoch: 868, iter: 1, loss: 0.7211
# restart: 0, epoch: 869, iter: 1, loss: 0.7211
# restart: 0, epoch: 870, iter: 1, loss: 0.7211
# restart: 0, epoch: 871, iter: 1, loss: 0.7211
# restart: 0, epoch: 872, iter: 1, loss: 0.7211
# restart: 0, epoch: 873, iter: 1, loss: 0.7211
# restart: 0, epoch: 874, iter: 1, loss: 0.7211
# restart: 0, epoch: 875, iter: 1, loss: 0.7210
# restart: 0, epoch: 876, iter: 1, loss: 0.7209
# restart: 0, epoch: 877, iter: 1, loss: 0.7209
# restart: 0, epoch: 878, iter: 1, loss: 0.7209
# restart: 0, epoch: 879, iter: 1, loss: 0.7208
# restart: 0, epoch: 880, iter: 1, loss: 0.7208
# restart: 0, epoch: 881, iter: 1, loss: 0.7207
# restart: 0, epoch: 882, iter: 1, loss: 0.7207
# restart: 0, epoch: 883, iter: 1, loss: 0.7206
# restart: 0, epoch: 884, iter: 1, loss: 0.7205
# restart: 0, epoch: 885, iter: 1, loss: 0.7205
# restart: 0, epoch: 886, iter: 1, loss: 0.7205
# restart: 0, epoch: 887, iter: 1, loss: 0.7204
# restart: 0, epoch: 888, iter: 1, loss: 0.7204
# restart: 0, epoch: 889, iter: 1, loss: 0.7203
# restart: 0, epoch: 890, iter: 1, loss: 0.7203
# restart: 0, epoch: 891, iter: 1, loss: 0.7203
# restart: 0, epoch: 892, iter: 1, loss: 0.7202
# restart: 0, epoch: 893, iter: 1, loss: 0.7202
# restart: 0, epoch: 894, iter: 1, loss: 0.7202
# restart: 0, epoch: 895, iter: 1, loss: 0.7202
# restart: 0, epoch: 896, iter: 1, loss: 0.7202
# restart: 0, epoch: 897, iter: 1, loss: 0.7202
# restart: 0, epoch: 898, iter: 1, loss: 0.7201
# restart: 0, epoch: 899, iter: 1, loss: 0.7200
# restart: 0, epoch: 900, iter: 1, loss: 0.7200
# restart: 0, epoch: 901, iter: 1, loss: 0.7199
# restart: 0, epoch: 902, iter: 1, loss: 0.7199
# restart: 0, epoch: 903, iter: 1, loss: 0.7199
# restart: 0, epoch: 904, iter: 1, loss: 0.7199
# restart: 0, epoch: 905, iter: 1, loss: 0.7199
# restart: 0, epoch: 906, iter: 1, loss: 0.7199
# restart: 0, epoch: 907, iter: 1, loss: 0.7199
# restart: 0, epoch: 908, iter: 1, loss: 0.7198
# restart: 0, epoch: 909, iter: 1, loss: 0.7198
# restart: 0, epoch: 910, iter: 1, loss: 0.7197
# restart: 0, epoch: 911, iter: 1, loss: 0.7197
# restart: 0, epoch: 912, iter: 1, loss: 0.7196
# restart: 0, epoch: 913, iter: 1, loss: 0.7196
# restart: 0, epoch: 914, iter: 1, loss: 0.7195
# restart: 0, epoch: 915, iter: 1, loss: 0.7195
# restart: 0, epoch: 916, iter: 1, loss: 0.7195
# restart: 0, epoch: 917, iter: 1, loss: 0.7195
# restart: 0, epoch: 918, iter: 1, loss: 0.7194
# restart: 0, epoch: 919, iter: 1, loss: 0.7194
# restart: 0, epoch: 920, iter: 1, loss: 0.7194
# restart: 0, epoch: 921, iter: 1, loss: 0.7194
# restart: 0, epoch: 922, iter: 1, loss: 0.7193
# restart: 0, epoch: 923, iter: 1, loss: 0.7193
# restart: 0, epoch: 924, iter: 1, loss: 0.7193
# restart: 0, epoch: 925, iter: 1, loss: 0.7192
# restart: 0, epoch: 926, iter: 1, loss: 0.7192
# restart: 0, epoch: 927, iter: 1, loss: 0.7191
# restart: 0, epoch: 928, iter: 1, loss: 0.7190
# restart: 0, epoch: 929, iter: 1, loss: 0.7190
# restart: 0, epoch: 930, iter: 1, loss: 0.7190
# restart: 0, epoch: 931, iter: 1, loss: 0.7189
# restart: 0, epoch: 932, iter: 1, loss: 0.7189
# restart: 0, epoch: 933, iter: 1, loss: 0.7188
# restart: 0, epoch: 934, iter: 1, loss: 0.7188
# restart: 0, epoch: 935, iter: 1, loss: 0.7188
# restart: 0, epoch: 936, iter: 1, loss: 0.7187
# restart: 0, epoch: 937, iter: 1, loss: 0.7186
# restart: 0, epoch: 938, iter: 1, loss: 0.7186
# restart: 0, epoch: 939, iter: 1, loss: 0.7186
# restart: 0, epoch: 940, iter: 1, loss: 0.7186
# restart: 0, epoch: 941, iter: 1, loss: 0.7187
# restart: 0, epoch: 942, iter: 1, loss: 0.7188
# restart: 0, epoch: 943, iter: 1, loss: 0.7187
# restart: 0, epoch: 944, iter: 1, loss: 0.7185
# restart: 0, epoch: 945, iter: 1, loss: 0.7184
# restart: 0, epoch: 946, iter: 1, loss: 0.7184
# restart: 0, epoch: 947, iter: 1, loss: 0.7183
# restart: 0, epoch: 948, iter: 1, loss: 0.7183
# restart: 0, epoch: 949, iter: 1, loss: 0.7183
# restart: 0, epoch: 950, iter: 1, loss: 0.7182
# restart: 0, epoch: 951, iter: 1, loss: 0.7182
# restart: 0, epoch: 952, iter: 1, loss: 0.7182
# restart: 0, epoch: 953, iter: 1, loss: 0.7182
# restart: 0, epoch: 954, iter: 1, loss: 0.7181
# restart: 0, epoch: 955, iter: 1, loss: 0.7181
# restart: 0, epoch: 956, iter: 1, loss: 0.7181
# restart: 0, epoch: 957, iter: 1, loss: 0.7180
# restart: 0, epoch: 958, iter: 1, loss: 0.7180
# restart: 0, epoch: 959, iter: 1, loss: 0.7179
# restart: 0, epoch: 960, iter: 1, loss: 0.7179
# restart: 0, epoch: 961, iter: 1, loss: 0.7178
# restart: 0, epoch: 962, iter: 1, loss: 0.7178
# restart: 0, epoch: 963, iter: 1, loss: 0.7178
# restart: 0, epoch: 964, iter: 1, loss: 0.7177
# restart: 0, epoch: 965, iter: 1, loss: 0.7177
# restart: 0, epoch: 966, iter: 1, loss: 0.7177
# restart: 0, epoch: 967, iter: 1, loss: 0.7177
# restart: 0, epoch: 968, iter: 1, loss: 0.7177
# restart: 0, epoch: 969, iter: 1, loss: 0.7176
# restart: 0, epoch: 970, iter: 1, loss: 0.7175
# restart: 0, epoch: 971, iter: 1, loss: 0.7175
# restart: 0, epoch: 972, iter: 1, loss: 0.7174
# restart: 0, epoch: 973, iter: 1, loss: 0.7174
# restart: 0, epoch: 974, iter: 1, loss: 0.7174
# restart: 0, epoch: 975, iter: 1, loss: 0.7173
# restart: 0, epoch: 976, iter: 1, loss: 0.7173
# restart: 0, epoch: 977, iter: 1, loss: 0.7173
# restart: 0, epoch: 978, iter: 1, loss: 0.7172
# restart: 0, epoch: 979, iter: 1, loss: 0.7172
# restart: 0, epoch: 980, iter: 1, loss: 0.7172
# restart: 0, epoch: 981, iter: 1, loss: 0.7171
# restart: 0, epoch: 982, iter: 1, loss: 0.7171
# restart: 0, epoch: 983, iter: 1, loss: 0.7171
# restart: 0, epoch: 984, iter: 1, loss: 0.7171
# restart: 0, epoch: 985, iter: 1, loss: 0.7171
# restart: 0, epoch: 986, iter: 1, loss: 0.7170
# restart: 0, epoch: 987, iter: 1, loss: 0.7170
# restart: 0, epoch: 988, iter: 1, loss: 0.7169
# restart: 0, epoch: 989, iter: 1, loss: 0.7169
# restart: 0, epoch: 990, iter: 1, loss: 0.7169
# restart: 0, epoch: 991, iter: 1, loss: 0.7169
# restart: 0, epoch: 992, iter: 1, loss: 0.7169
# restart: 0, epoch: 993, iter: 1, loss: 0.7168
# restart: 0, epoch: 994, iter: 1, loss: 0.7168
# restart: 0, epoch: 995, iter: 1, loss: 0.7169
# restart: 0, epoch: 996, iter: 1, loss: 0.7168
# restart: 0, epoch: 997, iter: 1, loss: 0.7168
# restart: 0, epoch: 998, iter: 1, loss: 0.7167
# restart: 0, epoch: 999, iter: 1, loss: 0.7167
# restart: 0, epoch: 1000, iter: 1, loss: 0.7168
# restart: 0, epoch: 1001, iter: 1, loss: 0.7176
# restart: 0, epoch: 1002, iter: 1, loss: 0.7171
# restart: 0, epoch: 1003, iter: 1, loss: 0.7169
# restart: 0, epoch: 1004, iter: 1, loss: 0.7168
# restart: 0, epoch: 1005, iter: 1, loss: 0.7168
# restart: 0, epoch: 1006, iter: 1, loss: 0.7168
# restart: 0, epoch: 1007, iter: 1, loss: 0.7169
# restart: 0, epoch: 1008, iter: 1, loss: 0.7170
# restart: 0, epoch: 1009, iter: 1, loss: 0.7169
# restart: 0, epoch: 1010, iter: 1, loss: 0.7168
# restart: 0, epoch: 1011, iter: 1, loss: 0.7172
# restart: 0, epoch: 1012, iter: 1, loss: 0.7171
# restart: 0, epoch: 1013, iter: 1, loss: 0.7167
# restart: 0, epoch: 1014, iter: 1, loss: 0.7169
# restart: 0, epoch: 1015, iter: 1, loss: 0.7172
# restart: 0, epoch: 1016, iter: 1, loss: 0.7167
# restart: 0, epoch: 1017, iter: 1, loss: 0.7166
# restart: 0, epoch: 1018, iter: 1, loss: 0.7167
# restart: 0, epoch: 1019, iter: 1, loss: 0.7168
# restart: 0, epoch: 1020, iter: 1, loss: 0.7167
# restart: 0, epoch: 1021, iter: 1, loss: 0.7165
# restart: 0, epoch: 1022, iter: 1, loss: 0.7164
# restart: 0, epoch: 1023, iter: 1, loss: 0.7163
# restart: 0, epoch: 1024, iter: 1, loss: 0.7163
# restart: 0, epoch: 1025, iter: 1, loss: 0.7163
# restart: 0, epoch: 1026, iter: 1, loss: 0.7164
# restart: 0, epoch: 1027, iter: 1, loss: 0.7166
# restart: 0, epoch: 1028, iter: 1, loss: 0.7161
# restart: 0, epoch: 1029, iter: 1, loss: 0.7161
# restart: 0, epoch: 1030, iter: 1, loss: 0.7161
# restart: 0, epoch: 1031, iter: 1, loss: 0.7160
# ...
# restart: 0, epoch: 1161, iter: 1, loss: 0.7115
# restart: 0, epoch: 1162, iter: 1, loss: 0.7114
# restart: 0, epoch: 1163, iter: 1, loss: 0.7114
# restart: 0, epoch: 1164, iter: 1, loss: 0.7114
# restart: 0, epoch: 1165, iter: 1, loss: 0.7114
# restart: 0, epoch: 1166, iter: 1, loss: 0.7113
# restart: 0, epoch: 1167, iter: 1, loss: 0.7113
# restart: 0, epoch: 1168, iter: 1, loss: 0.7112
# restart: 0, epoch: 1169, iter: 1, loss: 0.7112
# restart: 0, epoch: 1170, iter: 1, loss: 0.7111
# restart: 0, epoch: 1171, iter: 1, loss: 0.7111
# restart: 0, epoch: 1172, iter: 1, loss: 0.7111
# restart: 0, epoch: 1173, iter: 1, loss: 0.7110
# restart: 0, epoch: 1174, iter: 1, loss: 0.7110
# restart: 0, epoch: 1175, iter: 1, loss: 0.7109
# restart: 0, epoch: 1176, iter: 1, loss: 0.7109
# restart: 0, epoch: 1177, iter: 1, loss: 0.7109
# restart: 0, epoch: 1178, iter: 1, loss: 0.7108
# restart: 0, epoch: 1179, iter: 1, loss: 0.7108
# restart: 0, epoch: 1180, iter: 1, loss: 0.7108
# restart: 0, epoch: 1181, iter: 1, loss: 0.7107
# restart: 0, epoch: 1182, iter: 1, loss: 0.7106
# restart: 0, epoch: 1183, iter: 1, loss: 0.7106
# restart: 0, epoch: 1184, iter: 1, loss: 0.7105
# restart: 0, epoch: 1185, iter: 1, loss: 0.7105
# restart: 0, epoch: 1186, iter: 1, loss: 0.7104
# restart: 0, epoch: 1187, iter: 1, loss: 0.7104
# restart: 0, epoch: 1188, iter: 1, loss: 0.7103
# restart: 0, epoch: 1189, iter: 1, loss: 0.7103
# restart: 0, epoch: 1190, iter: 1, loss: 0.7103
# restart: 0, epoch: 1191, iter: 1, loss: 0.7102
# restart: 0, epoch: 1192, iter: 1, loss: 0.7103
# restart: 0, epoch: 1193, iter: 1, loss: 0.7103
# restart: 0, epoch: 1194, iter: 1, loss: 0.7103
# restart: 0, epoch: 1195, iter: 1, loss: 0.7101
# restart: 0, epoch: 1196, iter: 1, loss: 0.7100
# restart: 0, epoch: 1197, iter: 1, loss: 0.7099
# restart: 0, epoch: 1198, iter: 1, loss: 0.7099
# restart: 0, epoch: 1199, iter: 1, loss: 0.7098
# restart: 0, epoch: 1200, iter: 1, loss: 0.7097
# restart: 0, epoch: 1201, iter: 1, loss: 0.7096
# restart: 0, epoch: 1202, iter: 1, loss: 0.7096
# restart: 0, epoch: 1203, iter: 1, loss: 0.7095
# restart: 0, epoch: 1204, iter: 1, loss: 0.7094
# restart: 0, epoch: 1205, iter: 1, loss: 0.7094
# restart: 0, epoch: 1206, iter: 1, loss: 0.7093
# restart: 0, epoch: 1207, iter: 1, loss: 0.7092
# restart: 0, epoch: 1208, iter: 1, loss: 0.7092
# restart: 0, epoch: 1209, iter: 1, loss: 0.7093
# restart: 0, epoch: 1210, iter: 1, loss: 0.7093
# restart: 0, epoch: 1211, iter: 1, loss: 0.7092
# restart: 0, epoch: 1212, iter: 1, loss: 0.7092
# restart: 0, epoch: 1213, iter: 1, loss: 0.7091
# restart: 0, epoch: 1214, iter: 1, loss: 0.7090
# restart: 0, epoch: 1215, iter: 1, loss: 0.7088
# restart: 0, epoch: 1216, iter: 1, loss: 0.7087
# restart: 0, epoch: 1217, iter: 1, loss: 0.7086
# restart: 0, epoch: 1218, iter: 1, loss: 0.7085
# restart: 0, epoch: 1219, iter: 1, loss: 0.7084
# restart: 0, epoch: 1220, iter: 1, loss: 0.7083
# restart: 0, epoch: 1221, iter: 1, loss: 0.7082
# restart: 0, epoch: 1222, iter: 1, loss: 0.7081
# restart: 0, epoch: 1223, iter: 1, loss: 0.7080
# restart: 0, epoch: 1224, iter: 1, loss: 0.7079
# restart: 0, epoch: 1225, iter: 1, loss: 0.7079
# restart: 0, epoch: 1226, iter: 1, loss: 0.7078
# restart: 0, epoch: 1227, iter: 1, loss: 0.7078
# restart: 0, epoch: 1228, iter: 1, loss: 0.7078
# restart: 0, epoch: 1229, iter: 1, loss: 0.7075
# restart: 0, epoch: 1230, iter: 1, loss: 0.7074
# restart: 0, epoch: 1231, iter: 1, loss: 0.7073
# restart: 0, epoch: 1232, iter: 1, loss: 0.7072
# restart: 0, epoch: 1233, iter: 1, loss: 0.7071
# restart: 0, epoch: 1234, iter: 1, loss: 0.7070
# restart: 0, epoch: 1235, iter: 1, loss: 0.7069
# restart: 0, epoch: 1236, iter: 1, loss: 0.7068
# restart: 0, epoch: 1237, iter: 1, loss: 0.7066
# restart: 0, epoch: 1238, iter: 1, loss: 0.7065
# restart: 0, epoch: 1239, iter: 1, loss: 0.7063
# restart: 0, epoch: 1240, iter: 1, loss: 0.7062
# restart: 0, epoch: 1241, iter: 1, loss: 0.7061
# restart: 0, epoch: 1242, iter: 1, loss: 0.7059
# restart: 0, epoch: 1243, iter: 1, loss: 0.7058
# restart: 0, epoch: 1244, iter: 1, loss: 0.7056
# restart: 0, epoch: 1245, iter: 1, loss: 0.7055
# restart: 0, epoch: 1246, iter: 1, loss: 0.7054
# restart: 0, epoch: 1247, iter: 1, loss: 0.7052
# restart: 0, epoch: 1248, iter: 1, loss: 0.7051
# restart: 0, epoch: 1249, iter: 1, loss: 0.7050
# restart: 0, epoch: 1250, iter: 1, loss: 0.7049
# restart: 0, epoch: 1251, iter: 1, loss: 0.7048
# restart: 0, epoch: 1252, iter: 1, loss: 0.7046
# restart: 0, epoch: 1253, iter: 1, loss: 0.7045
# restart: 0, epoch: 1254, iter: 1, loss: 0.7044
# restart: 0, epoch: 1255, iter: 1, loss: 0.7043
# restart: 0, epoch: 1256, iter: 1, loss: 0.7041
# restart: 0, epoch: 1257, iter: 1, loss: 0.7039
# restart: 0, epoch: 1258, iter: 1, loss: 0.7038
# restart: 0, epoch: 1259, iter: 1, loss: 0.7037
# restart: 0, epoch: 1260, iter: 1, loss: 0.7035
# restart: 0, epoch: 1261, iter: 1, loss: 0.7034
# restart: 0, epoch: 1262, iter: 1, loss: 0.7033
# restart: 0, epoch: 1263, iter: 1, loss: 0.7032
# restart: 0, epoch: 1264, iter: 1, loss: 0.7031
# restart: 0, epoch: 1265, iter: 1, loss: 0.7029
# restart: 0, epoch: 1266, iter: 1, loss: 0.7028
# restart: 0, epoch: 1267, iter: 1, loss: 0.7027
# restart: 0, epoch: 1268, iter: 1, loss: 0.7026
# restart: 0, epoch: 1269, iter: 1, loss: 0.7025
# restart: 0, epoch: 1270, iter: 1, loss: 0.7024
# restart: 0, epoch: 1271, iter: 1, loss: 0.7023
# restart: 0, epoch: 1272, iter: 1, loss: 0.7022
# restart: 0, epoch: 1273, iter: 1, loss: 0.7021
# restart: 0, epoch: 1274, iter: 1, loss: 0.7021
# restart: 0, epoch: 1275, iter: 1, loss: 0.7020
# restart: 0, epoch: 1276, iter: 1, loss: 0.7021
# restart: 0, epoch: 1277, iter: 1, loss: 0.7019
# restart: 0, epoch: 1278, iter: 1, loss: 0.7018
# restart: 0, epoch: 1279, iter: 1, loss: 0.7017
# restart: 0, epoch: 1280, iter: 1, loss: 0.7016
# restart: 0, epoch: 1281, iter: 1, loss: 0.7015
# restart: 0, epoch: 1282, iter: 1, loss: 0.7014
# restart: 0, epoch: 1283, iter: 1, loss: 0.7013
# restart: 0, epoch: 1284, iter: 1, loss: 0.7012
# restart: 0, epoch: 1285, iter: 1, loss: 0.7011
# restart: 0, epoch: 1286, iter: 1, loss: 0.7011
# restart: 0, epoch: 1287, iter: 1, loss: 0.7010
# restart: 0, epoch: 1288, iter: 1, loss: 0.7009
# restart: 0, epoch: 1289, iter: 1, loss: 0.7008
# restart: 0, epoch: 1290, iter: 1, loss: 0.7007
# restart: 0, epoch: 1291, iter: 1, loss: 0.7006
# restart: 0, epoch: 1292, iter: 1, loss: 0.7006
# restart: 0, epoch: 1293, iter: 1, loss: 0.7005
# restart: 0, epoch: 1294, iter: 1, loss: 0.7004
# restart: 0, epoch: 1295, iter: 1, loss: 0.7003
# restart: 0, epoch: 1296, iter: 1, loss: 0.7003
# restart: 0, epoch: 1297, iter: 1, loss: 0.7002
# restart: 0, epoch: 1298, iter: 1, loss: 0.7001
# restart: 0, epoch: 1299, iter: 1, loss: 0.7001
# restart: 0, epoch: 1300, iter: 1, loss: 0.7000
# restart: 0, epoch: 1301, iter: 1, loss: 0.6999
# restart: 0, epoch: 1302, iter: 1, loss: 0.6999
# restart: 0, epoch: 1303, iter: 1, loss: 0.6998
# restart: 0, epoch: 1304, iter: 1, loss: 0.6997
# restart: 0, epoch: 1305, iter: 1, loss: 0.6997
# restart: 0, epoch: 1306, iter: 1, loss: 0.6996
# restart: 0, epoch: 1307, iter: 1, loss: 0.6995
# restart: 0, epoch: 1308, iter: 1, loss: 0.6995
# restart: 0, epoch: 1309, iter: 1, loss: 0.6994
# restart: 0, epoch: 1310, iter: 1, loss: 0.6994
# restart: 0, epoch: 1311, iter: 1, loss: 0.6993
# restart: 0, epoch: 1312, iter: 1, loss: 0.6993
# restart: 0, epoch: 1313, iter: 1, loss: 0.6992
# restart: 0, epoch: 1314, iter: 1, loss: 0.6992
# restart: 0, epoch: 1315, iter: 1, loss: 0.6991
# restart: 0, epoch: 1316, iter: 1, loss: 0.6990
# restart: 0, epoch: 1317, iter: 1, loss: 0.6990
# restart: 0, epoch: 1318, iter: 1, loss: 0.6989
# restart: 0, epoch: 1319, iter: 1, loss: 0.6989
# restart: 0, epoch: 1320, iter: 1, loss: 0.6988
# restart: 0, epoch: 1321, iter: 1, loss: 0.6987
# restart: 0, epoch: 1322, iter: 1, loss: 0.6986
# restart: 0, epoch: 1323, iter: 1, loss: 0.6986
# restart: 0, epoch: 1324, iter: 1, loss: 0.6985
# restart: 0, epoch: 1325, iter: 1, loss: 0.6984
# restart: 0, epoch: 1326, iter: 1, loss: 0.6984
# restart: 0, epoch: 1327, iter: 1, loss: 0.6983
# restart: 0, epoch: 1328, iter: 1, loss: 0.6982
# restart: 0, epoch: 1329, iter: 1, loss: 0.6982
# restart: 0, epoch: 1330, iter: 1, loss: 0.6981
# restart: 0, epoch: 1331, iter: 1, loss: 0.6980
# restart: 0, epoch: 1332, iter: 1, loss: 0.6980
# restart: 0, epoch: 1333, iter: 1, loss: 0.6979
# restart: 0, epoch: 1334, iter: 1, loss: 0.6979
# restart: 0, epoch: 1335, iter: 1, loss: 0.6978
# restart: 0, epoch: 1336, iter: 1, loss: 0.6978
# restart: 0, epoch: 1337, iter: 1, loss: 0.6977
# restart: 0, epoch: 1338, iter: 1, loss: 0.6977
# restart: 0, epoch: 1339, iter: 1, loss: 0.6976
# restart: 0, epoch: 1340, iter: 1, loss: 0.6976
# restart: 0, epoch: 1341, iter: 1, loss: 0.6976
# restart: 0, epoch: 1342, iter: 1, loss: 0.6975
# restart: 0, epoch: 1343, iter: 1, loss: 0.6975
# restart: 0, epoch: 1344, iter: 1, loss: 0.6974
# restart: 0, epoch: 1345, iter: 1, loss: 0.6974
# restart: 0, epoch: 1346, iter: 1, loss: 0.6973
# restart: 0, epoch: 1347, iter: 1, loss: 0.6973
# restart: 0, epoch: 1348, iter: 1, loss: 0.6972
# restart: 0, epoch: 1349, iter: 1, loss: 0.6972
# restart: 0, epoch: 1350, iter: 1, loss: 0.6971
# restart: 0, epoch: 1351, iter: 1, loss: 0.6971
# restart: 0, epoch: 1352, iter: 1, loss: 0.6971
# restart: 0, epoch: 1353, iter: 1, loss: 0.6970
# restart: 0, epoch: 1354, iter: 1, loss: 0.6969
# restart: 0, epoch: 1355, iter: 1, loss: 0.6969
# restart: 0, epoch: 1356, iter: 1, loss: 0.6969
# restart: 0, epoch: 1357, iter: 1, loss: 0.6968
# restart: 0, epoch: 1358, iter: 1, loss: 0.6968
# restart: 0, epoch: 1359, iter: 1, loss: 0.6967
# restart: 0, epoch: 1360, iter: 1, loss: 0.6967
# restart: 0, epoch: 1361, iter: 1, loss: 0.6966
# restart: 0, epoch: 1362, iter: 1, loss: 0.6966
# restart: 0, epoch: 1363, iter: 1, loss: 0.6965
# restart: 0, epoch: 1364, iter: 1, loss: 0.6965
# restart: 0, epoch: 1365, iter: 1, loss: 0.6964
# restart: 0, epoch: 1366, iter: 1, loss: 0.6964
# restart: 0, epoch: 1367, iter: 1, loss: 0.6963
# restart: 0, epoch: 1368, iter: 1, loss: 0.6963
# restart: 0, epoch: 1369, iter: 1, loss: 0.6962
# restart: 0, epoch: 1370, iter: 1, loss: 0.6962
# restart: 0, epoch: 1371, iter: 1, loss: 0.6962
# restart: 0, epoch: 1372, iter: 1, loss: 0.6961
# restart: 0, epoch: 1373, iter: 1, loss: 0.6961
# restart: 0, epoch: 1374, iter: 1, loss: 0.6960
# restart: 0, epoch: 1375, iter: 1, loss: 0.6960
# restart: 0, epoch: 1376, iter: 1, loss: 0.6959
# restart: 0, epoch: 1377, iter: 1, loss: 0.6959
# restart: 0, epoch: 1378, iter: 1, loss: 0.6959
# restart: 0, epoch: 1379, iter: 1, loss: 0.6958
# restart: 0, epoch: 1380, iter: 1, loss: 0.6958
# restart: 0, epoch: 1381, iter: 1, loss: 0.6958
# restart: 0, epoch: 1382, iter: 1, loss: 0.6958
# restart: 0, epoch: 1383, iter: 1, loss: 0.6958
# restart: 0, epoch: 1384, iter: 1, loss: 0.6957
# restart: 0, epoch: 1385, iter: 1, loss: 0.6957
# restart: 0, epoch: 1386, iter: 1, loss: 0.6956
# restart: 0, epoch: 1387, iter: 1, loss: 0.6956
# restart: 0, epoch: 1388, iter: 1, loss: 0.6955
# restart: 0, epoch: 1389, iter: 1, loss: 0.6955
# restart: 0, epoch: 1390, iter: 1, loss: 0.6955
# restart: 0, epoch: 1391, iter: 1, loss: 0.6954
# restart: 0, epoch: 1392, iter: 1, loss: 0.6954
# restart: 0, epoch: 1393, iter: 1, loss: 0.6953
# restart: 0, epoch: 1394, iter: 1, loss: 0.6953
# restart: 0, epoch: 1395, iter: 1, loss: 0.6953
# restart: 0, epoch: 1396, iter: 1, loss: 0.6952
# restart: 0, epoch: 1397, iter: 1, loss: 0.6951
# restart: 0, epoch: 1398, iter: 1, loss: 0.6951
# restart: 0, epoch: 1399, iter: 1, loss: 0.6951
# restart: 0, epoch: 1400, iter: 1, loss: 0.6950
# restart: 0, epoch: 1401, iter: 1, loss: 0.6950
# restart: 0, epoch: 1402, iter: 1, loss: 0.6949
# restart: 0, epoch: 1403, iter: 1, loss: 0.6949
# restart: 0, epoch: 1404, iter: 1, loss: 0.6948
# restart: 0, epoch: 1405, iter: 1, loss: 0.6948
# restart: 0, epoch: 1406, iter: 1, loss: 0.6947
# restart: 0, epoch: 1407, iter: 1, loss: 0.6947
# restart: 0, epoch: 1408, iter: 1, loss: 0.6947
# restart: 0, epoch: 1409, iter: 1, loss: 0.6946
# restart: 0, epoch: 1410, iter: 1, loss: 0.6946
# restart: 0, epoch: 1411, iter: 1, loss: 0.6945
# restart: 0, epoch: 1412, iter: 1, loss: 0.6945
# restart: 0, epoch: 1413, iter: 1, loss: 0.6945
# restart: 0, epoch: 1414, iter: 1, loss: 0.6945
# restart: 0, epoch: 1415, iter: 1, loss: 0.6945
# restart: 0, epoch: 1416, iter: 1, loss: 0.6944
# restart: 0, epoch: 1417, iter: 1, loss: 0.6944
# restart: 0, epoch: 1418, iter: 1, loss: 0.6944
# restart: 0, epoch: 1419, iter: 1, loss: 0.6943
# restart: 0, epoch: 1420, iter: 1, loss: 0.6943
# restart: 0, epoch: 1421, iter: 1, loss: 0.6942
# restart: 0, epoch: 1422, iter: 1, loss: 0.6942
# restart: 0, epoch: 1423, iter: 1, loss: 0.6941
# restart: 0, epoch: 1424, iter: 1, loss: 0.6941
# restart: 0, epoch: 1425, iter: 1, loss: 0.6942
# restart: 0, epoch: 1426, iter: 1, loss: 0.6941
# restart: 0, epoch: 1427, iter: 1, loss: 0.6940
# restart: 0, epoch: 1428, iter: 1, loss: 0.6940
# restart: 0, epoch: 1429, iter: 1, loss: 0.6939
# restart: 0, epoch: 1430, iter: 1, loss: 0.6939
# restart: 0, epoch: 1431, iter: 1, loss: 0.6939
# restart: 0, epoch: 1432, iter: 1, loss: 0.6938
# restart: 0, epoch: 1433, iter: 1, loss: 0.6938
# restart: 0, epoch: 1434, iter: 1, loss: 0.6937
# restart: 0, epoch: 1435, iter: 1, loss: 0.6937
# restart: 0, epoch: 1436, iter: 1, loss: 0.6936
# restart: 0, epoch: 1437, iter: 1, loss: 0.6936
# restart: 0, epoch: 1438, iter: 1, loss: 0.6936
# restart: 0, epoch: 1439, iter: 1, loss: 0.6935
# restart: 0, epoch: 1440, iter: 1, loss: 0.6935
# restart: 0, epoch: 1441, iter: 1, loss: 0.6934
# restart: 0, epoch: 1442, iter: 1, loss: 0.6934
# restart: 0, epoch: 1443, iter: 1, loss: 0.6934
# restart: 0, epoch: 1444, iter: 1, loss: 0.6934
# restart: 0, epoch: 1445, iter: 1, loss: 0.6934
# restart: 0, epoch: 1446, iter: 1, loss: 0.6933
# restart: 0, epoch: 1447, iter: 1, loss: 0.6933
# restart: 0, epoch: 1448, iter: 1, loss: 0.6932
# restart: 0, epoch: 1449, iter: 1, loss: 0.6932
# restart: 0, epoch: 1450, iter: 1, loss: 0.6931
# restart: 0, epoch: 1451, iter: 1, loss: 0.6931
# restart: 0, epoch: 1452, iter: 1, loss: 0.6930
# restart: 0, epoch: 1453, iter: 1, loss: 0.6930
# restart: 0, epoch: 1454, iter: 1, loss: 0.6930
# restart: 0, epoch: 1455, iter: 1, loss: 0.6929
# restart: 0, epoch: 1456, iter: 1, loss: 0.6929
# restart: 0, epoch: 1457, iter: 1, loss: 0.6929
# restart: 0, epoch: 1458, iter: 1, loss: 0.6929
# restart: 0, epoch: 1459, iter: 1, loss: 0.6929
# restart: 0, epoch: 1460, iter: 1, loss: 0.6929
# restart: 0, epoch: 1461, iter: 1, loss: 0.6928
# restart: 0, epoch: 1462, iter: 1, loss: 0.6928
# restart: 0, epoch: 1463, iter: 1, loss: 0.6928
# restart: 0, epoch: 1464, iter: 1, loss: 0.6928
# restart: 0, epoch: 1465, iter: 1, loss: 0.6927
# restart: 0, epoch: 1466, iter: 1, loss: 0.6927
# restart: 0, epoch: 1467, iter: 1, loss: 0.6927
# restart: 0, epoch: 1468, iter: 1, loss: 0.6926
# restart: 0, epoch: 1469, iter: 1, loss: 0.6925
# restart: 0, epoch: 1470, iter: 1, loss: 0.6925
# restart: 0, epoch: 1471, iter: 1, loss: 0.6924
# restart: 0, epoch: 1472, iter: 1, loss: 0.6924
# restart: 0, epoch: 1473, iter: 1, loss: 0.6924
# restart: 0, epoch: 1474, iter: 1, loss: 0.6923
# restart: 0, epoch: 1475, iter: 1, loss: 0.6922
# restart: 0, epoch: 1476, iter: 1, loss: 0.6922
# restart: 0, epoch: 1477, iter: 1, loss: 0.6922
# restart: 0, epoch: 1478, iter: 1, loss: 0.6921
# restart: 0, epoch: 1479, iter: 1, loss: 0.6921
# restart: 0, epoch: 1480, iter: 1, loss: 0.6921
# restart: 0, epoch: 1481, iter: 1, loss: 0.6921
# restart: 0, epoch: 1482, iter: 1, loss: 0.6920
# restart: 0, epoch: 1483, iter: 1, loss: 0.6920
# restart: 0, epoch: 1484, iter: 1, loss: 0.6919
# restart: 0, epoch: 1485, iter: 1, loss: 0.6919
# restart: 0, epoch: 1486, iter: 1, loss: 0.6918
# restart: 0, epoch: 1487, iter: 1, loss: 0.6918
# restart: 0, epoch: 1488, iter: 1, loss: 0.6918
# restart: 0, epoch: 1489, iter: 1, loss: 0.6917
# restart: 0, epoch: 1490, iter: 1, loss: 0.6917
# restart: 0, epoch: 1491, iter: 1, loss: 0.6917
# restart: 0, epoch: 1492, iter: 1, loss: 0.6917
# restart: 0, epoch: 1493, iter: 1, loss: 0.6917
# restart: 0, epoch: 1494, iter: 1, loss: 0.6916
# restart: 0, epoch: 1495, iter: 1, loss: 0.6916
# restart: 0, epoch: 1496, iter: 1, loss: 0.6916
# restart: 0, epoch: 1497, iter: 1, loss: 0.6916
# restart: 0, epoch: 1498, iter: 1, loss: 0.6915
# restart: 0, epoch: 1499, iter: 1, loss: 0.6915
# restart: 0, epoch: 1500, iter: 1, loss: 0.6914

# %%
model_name = "Refrigerator_seq129_final.pt"
torch.save(model.state_dict(), os.path.join(
   "./final_models/", model_name))

# %%
kernel1 = ScaleKernel(RBFKernel(ard_num_dims=n))
# kernel2 = ScaleKernel(RBFKernel(ard_num_dims=1,active_dims=(49)))
# kernel3 = ScaleKernel(CosineKernel(ard_num_dims=1,active_dims=(49)))

# kernel4 = kernel2*kernel3
kernel = kernel1 # + kernel4
# induce_points = 512
inducing_points =  x[np.arange(0,x.shape[0],33)] 
# inducing_points = x[torch.randperm(x.shape[0])[: 1500]]

model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                      inducing_points).to("cuda")

model_name =  "Refrigerator_seq129_final.pt"
model.load_state_dict(torch.load(
    os.path.join("./final_models/", model_name)))
# Out:
# <All keys matched successfully>

# %%
for name, params in model.named_parameters():
  print(name, params)
# Out:
# mll.likelihood.noise_covar.raw_noise Parameter containing:
# tensor([-1.5538], device='cuda:0', requires_grad=True)
# mll.model.mean_module.constant Parameter containing:
# tensor([0.0126], device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.raw_outputscale Parameter containing:
# tensor(-1.7591, device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.base_kernel.raw_lengthscale Parameter containing:
# tensor([[ 5.9733,  6.3306,  6.3278,  6.3485,  6.2217,  6.1562,  6.2884,  6.3609,
#           6.3545,  6.3789,  6.3586,  6.2352,  5.8830,  5.6910,  5.5332,  5.3200,
#           5.3669,  5.3269,  5.0265,  5.0899,  4.9920,  4.6267,  4.7099,  4.6545,
#           4.7312,  5.0843,  5.3574,  5.4364,  5.4348,  5.4537,  5.3976,  5.2529,
#           5.1835,  5.2500,  4.9212,  5.0325,  5.1863,  4.9208, -0.6172,  4.1590,
#           4.7654,  5.1253,  5.3624,  4.9950,  5.1157,  5.2546,  4.2594,  4.6275,
#           4.5851,  3.4854,  3.0987,  3.3935,  4.6263,  4.3426,  4.9059,  4.9015,
#           4.8236,  4.5499,  5.2558,  5.6524,  5.7601,  5.1403,  4.9231,  0.0917,
#          -1.9226,  1.0488,  5.0079,  4.8112,  4.9814,  4.3563,  4.2674,  5.0771,
#           5.5253,  5.3122,  4.9353,  4.7431,  4.2832,  4.4919,  4.5818,  3.6158,
#           3.7218, -0.4409,  4.6275,  4.8991,  5.1286,  5.1934,  5.5030,  4.9171,
#           5.1793,  5.0507,  4.5284,  4.6238,  4.6140,  4.1239,  4.4012,  5.0714,
#           5.3827,  5.3241,  5.5690,  6.0308,  5.7992,  5.7881,  6.0383,  6.1162,
#           5.9532,  5.9525,  5.9868,  5.9788,  6.0653,  6.1892,  5.8618,  6.0281,
#           6.1597,  6.1718,  6.1558,  5.8964,  5.8911,  6.1055,  6.1833,  6.3966,
#           6.3989,  6.1893,  6.1356,  6.2160,  6.2443,  6.1752,  6.2810,  6.2123,
#           5.9388]], device='cuda:0', requires_grad=True)
# mll.model.covar_module.inducing_points Parameter containing:
# tensor([[-0.6753, -0.6680, -0.5997,  ..., -0.1223, -0.1075, -0.1241],
#         [-0.4039, -0.4012, -0.4412,  ..., -0.2342, -0.2494, -0.2432],
#         [-0.2007, -0.2384, -0.2471,  ...,  0.3575,  0.2909,  0.2728],
#         ...,
#         [-0.3118, -0.3130, -0.2869,  ..., -0.2078, -0.2061, -0.2314],
#         [-0.1462, -0.0891, -0.0680,  ...,  0.3330,  0.3772,  0.4251],
#         [-0.2052, -0.1968, -0.2001,  ..., -0.2310, -0.2843, -0.2354]],
#        device='cuda:0', dtype=torch.float64, requires_grad=True)

# %%
arr = np.array([ 5.9733,  6.3306,  6.3278,  6.3485,  6.2217,  6.1562,  6.2884,  6.3609,
          6.3545,  6.3789,  6.3586,  6.2352,  5.8830,  5.6910,  5.5332,  5.3200,
          5.3669,  5.3269,  5.0265,  5.0899,  4.9920,  4.6267,  4.7099,  4.6545,
          4.7312,  5.0843,  5.3574,  5.4364,  5.4348,  5.4537,  5.3976,  5.2529,
          5.1835,  5.2500,  4.9212,  5.0325,  5.1863,  4.9208, -0.6172,  4.1590,
          4.7654,  5.1253,  5.3624,  4.9950,  5.1157,  5.2546,  4.2594,  4.6275,
          4.5851,  3.4854,  3.0987,  3.3935,  4.6263,  4.3426,  4.9059,  4.9015,
          4.8236,  4.5499,  5.2558,  5.6524,  5.7601,  5.1403,  4.9231,  0.0917,
         -1.9226,  1.0488,  5.0079,  4.8112,  4.9814,  4.3563,  4.2674,  5.0771,
          5.5253,  5.3122,  4.9353,  4.7431,  4.2832,  4.4919,  4.5818,  3.6158,
          3.7218, -0.4409,  4.6275,  4.8991,  5.1286,  5.1934,  5.5030,  4.9171,
          5.1793,  5.0507,  4.5284,  4.6238,  4.6140,  4.1239,  4.4012,  5.0714,
          5.3827,  5.3241,  5.5690,  6.0308,  5.7992,  5.7881,  6.0383,  6.1162,
          5.9532,  5.9525,  5.9868,  5.9788,  6.0653,  6.1892,  5.8618,  6.0281,
          6.1597,  6.1718,  6.1558,  5.8964,  5.8911,  6.1055,  6.1833,  6.3966,
          6.3989,  6.1893,  6.1356,  6.2160,  6.2443,  6.1752,  6.2810,  6.2123,
          5.9388])
arr[64]
# plt.plot(arr)
# plt.xlabel('ARD Coefficients')
# plt.ylabel('ARD Learned values')
# plt.title("Building 5 Test")
# plt.savefig("Building5_ARD.png")
# Out:
# -1.9226

# %%
pred_dist = model.predict(xt.to("cuda"))
# print("Done ", i)

y_mean = pred_dist.loc
# Out:
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/kernels/inducing_point_kernel.py:61: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352645774/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   inv_root = torch.triangular_solve(eye, chol)[0]

# %%
y_mean = scaler_y.inverse_transform(y_mean.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean.shape)
# Out:
# torch.Size([16781]) (16781,)

# %%
mae = np.mean(np.abs(np.array(yt) - y_mean))
rms = errors.rmse(jnp.array(yt), y_mean)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  28.84386884877805
# RMSE:  46.05177
