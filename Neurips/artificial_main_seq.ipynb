# %%
import os
os.chdir("../")
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %%
import torch
from gpytorch.kernels import RBFKernel, ScaleKernel, PeriodicKernel, MaternKernel, CosineKernel
from skgpytorch.models import SVGPRegressor, SGPRegressor

# %%
import jax.numpy as jnp
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from utilities.fits import fit
# from utilities import plot
import tensorflow_probability.substrates.jax as tfp
dist = tfp.distributions
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from gpytorch.constraints import GreaterThan
from skgpytorch.metrics import mean_squared_error, negative_log_predictive_density
import time
import numpy as np

# from datasets.dataset_load import dataset_loader
from utilities import plot,fits,gmm,errors,predict,preprocess

# device = "cpu"
# torch.set_default_dtype(torch.float32)
# torch.set_default_tensor_type(torch.FloatTensor)

# %%
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler


def dataset_load(appliances, train, test=None):
    x_train = []
    y_train = []
    x_train_timestamp = []
    n = 99
    units_to_pad = n // 2
    scaler_x = StandardScaler()
    scaler_y = StandardScaler()
    scaler_time = StandardScaler()
    # train
    for key, values in train.items():
        for app in range(len(appliances)):
            df = pd.read_csv(
                f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[app]])
            df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
            startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
            endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

            if startDate > endDate:
                raise "Start Date must be smaller than Enddate."

            df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
            df.dropna(inplace=True)
            if app == 0:
                x = df[appliances[app]].values
            else:
                # print(app)
                x += df[appliances[app]].values
            if appliances[app] == "Refrigerator":
                y = df[appliances[app]].values
            # x = df["main"].values
            # y = df[appliances[app]].values
        timestamp_train = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])
        x_train.extend(x)
        y_train.extend(y)
        x_train_timestamp.extend(torch.tensor(timestamp_train))


    x_train = jnp.array(x_train)
    y_train = jnp.array(y_train).reshape(-1, 1)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(-1,1)
    x_train = scaler_x.fit_transform(x_train)
    y_train = scaler_y.fit_transform(y_train)
    x_train_timestamp = scaler_time.fit_transform(x_train_timestamp)


    # test
    x_test = []
    y_test = []
    x_test_timestamp = []
    x_test_timestamp_true =[]
    for key, values in test.items():
        for app in range(len(appliances)):
            df = pd.read_csv(
                f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[app]])
            df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
            startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
            endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

            if startDate > endDate:
                raise "Start Date must be smaller than Enddate."

            df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
            df.dropna(inplace=True)
            if app == 0:
                    x = df[appliances[app]].values
            else:
                print(app)
                x += df[appliances[app]].values
            if appliances[app] == "Refrigerator":
                y = df[appliances[app]].values
            # x = df["main"].values
            # y = df[appliances[0]].values
        timestamp_true = df["Timestamp"].values
        timestamp = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])
        x_test.extend(x)
        y_test.extend(y)
        x_test_timestamp_true.extend(timestamp_true)
        x_test_timestamp.extend(timestamp)

    x_test = jnp.array(x_test)
    y_test = jnp.array(y_test).reshape(-1, 1)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(-1,1)

    x_test = scaler_x.transform(x_test)
    x_test_timestamp = scaler_time.transform(x_test_timestamp)
#     y_test = scaler_y.transform(y_test)

    x_train = jnp.array(x_train).reshape(x_train.shape[0], n, 1)
    y_train = jnp.array(y_train)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(x_train_timestamp.shape[0], 1)
    x_test = jnp.array(x_test).reshape(x_test.shape[0], n, 1)
    y_test = jnp.array(y_test)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(x_test_timestamp.shape[0], 1).to(torch.float64)

    return x_train, y_train, x_test, y_test, x_train_timestamp, x_test_timestamp, x_test_timestamp_true, scaler_x, scaler_y, scaler_time

# %%
# def dataset_load(appliances, train, test=None):
#     x_train = []
#     y_train = []
#     x_train_timestamp = []
#     scaler_x = StandardScaler()
#     scaler_y = StandardScaler()
#     scaler_time = StandardScaler()
#     app = 0
#     # train
#     torch.set_default_dtype(torch.float64)
#     for key, values in train.items():
#         for app in range(len(appliances)):
#             df = pd.read_csv(
#                 f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[app]])
#             df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
#             startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
#             endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()
            

#             if startDate > endDate:
#                 raise "Start Date must be smaller than Enddate."

#             df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
#             df.dropna(inplace=True)
#             if app == 0:
#                 x = df[appliances[app]].values
#             else:
#                 print(app)
#                 x += df[appliances[app]].values
#             if appliances[app] == "Refrigerator":
#                 y = df[appliances[app]].values
#             # x = df["main"].values
            
        
#         timestamp_train = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values

#         x_train.extend(torch.tensor(x))
#         y_train.extend(torch.tensor(y))
#         x_train_timestamp.extend(torch.tensor(timestamp_train))


#     x_train = torch.tensor(x_train).reshape(-1, 1)
#     y_train = torch.tensor(y_train).reshape(-1, 1)
#     x_train_timestamp = torch.tensor(x_train_timestamp).reshape(-1,1)
#     x_train = scaler_x.fit_transform(x_train)
#     y_train = scaler_y.fit_transform(y_train)
#     x_train_timestamp = scaler_time.fit_transform(x_train_timestamp)



#     # test
#     x_test = []
#     y_test = []
#     x_test_timestamp = []
#     app = 0
#     for key, values in test.items():
#         for app in range(len(appliances)):
#             df = pd.read_csv(
#                 f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[app]])
#             df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
#             startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
#             endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

#             if startDate > endDate:
#                 raise "Start Date must be smaller than Enddate."

#             df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
#             df.dropna(inplace=True)
#             if app == 0:
#                 x = df[appliances[app]].values
#             else:
#                 print(app)
#                 x += df[appliances[app]].values
#             if appliances[app] == "Refrigerator":
#                 y = df[appliances[app]].values
#             # x = df["main"].values
#             # y = df[appliances[app]].values
#         timestamp = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values

#         x_test.extend(torch.tensor(x))
#         y_test.extend(torch.tensor(y))
#         x_test_timestamp.extend(timestamp)

#     x_test = torch.tensor(x_test).reshape(-1, 1)
#     y_test = torch.tensor(y_test).reshape(-1, 1)
#     x_test_timestamp = torch.tensor(x_test_timestamp).reshape(-1,1)

#     x_test = scaler_x.transform(x_test)
#     x_test_timestamp = scaler_time.transform(x_test_timestamp)

#     x_train = torch.tensor(x_train).reshape(x_train.shape[0], 1).to(torch.float64)
#     y_train = torch.tensor(y_train).reshape(-1,).to(torch.float64)
#     x_train_timestamp = torch.tensor(x_train_timestamp).reshape(x_train_timestamp.shape[0], 1).to(torch.float64)
#     x_test = torch.tensor(x_test).reshape(x_test.shape[0], 1).to(torch.float64)
#     y_test = torch.tensor(y_test).reshape(-1,).to(torch.float64)
#     x_test_timestamp = torch.tensor(x_test_timestamp).reshape(x_test_timestamp.shape[0], 1).to(torch.float64)


#     return x_train, y_train, x_test, y_test, x_train_timestamp, x_test_timestamp, scaler_x, scaler_y, scaler_time

# %%
train ={1:{
                    'start_time': "2011-04-28" ,
                    'end_time': "2011-05-15"
                }, 3: {
                'start_time': "2011-04-19" ,
                'end_time': "2011-05-22"
            },
                
      
                }
test = {  2: {
                    'start_time': "2011-04-21" ,
                    'end_time': "2011-05-21"
                },
                }

# 6: {
#                     'start_time': "2011-05-25" ,
#                     'end_time': "2011-06-13"
#                 }

# 5: {
#                     'start_time': "2011-04-22" ,
#                     'end_time': "2011-06-01"
#                 }
appliances = ["Microwave", "Refrigerator",  "Dish Washer"] #

# %%
x_train, y_train, x_test, y_test, x_train_timestamp, x_test_timestamp, x_test_time_true, scaler_x, scaler_y, scaler_time = dataset_load(appliances, train, test)
# Out:
# 1
# 2

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((24918, 99, 1), (15656, 99, 1), (24918, 1), (15656, 1))

# %%
x_train = x_train.reshape(-1,99)
x_test = x_test.reshape(-1,99)

# %%
# plt.plot(x_train_timestamp, scaler_x.inverse_transform(x_train.reshape(-1,99)))
# plt.ylabel(f"Main Power Train")
# plt.xlabel(f"Timestamp Train")

# %%
plt.plot(x_train_timestamp, scaler_y.inverse_transform(y_train.reshape(-1,1)))
plt.ylabel(f"Ref Power Train")
plt.xlabel(f"Timestamp Train")

# %%
plt.plot(x_test_timestamp, scaler_x.inverse_transform(x_test.reshape(-1,1)))

plt.ylabel(f"Main Test")
plt.xlabel(f"Timestamp Test")

# %%
plt.plot(x_test_timestamp, y_test)
plt.ylabel(f"Ref Power test")
plt.xlabel(f"Timestamp test")

# %%
plt.scatter( scaler_x.inverse_transform(x_train), scaler_y.inverse_transform(y_train.reshape(-1,1)))
plt.xlabel("Main Train Power")
plt.ylabel("Fridge Train Power")

# %%
plt.scatter( scaler_x.inverse_transform(x_test),y_test.reshape(-1,1))
plt.xlabel("Main test Power")
plt.ylabel("Fridge test Power")

# %%
x = torch.tensor(np.array(x_train)).to(torch.float32)
y = torch.tensor(np.array(y_train)).reshape(-1,).to(torch.float32)
xt = torch.tensor(np.array(x_test)).to(torch.float32)
yt = torch.tensor(np.array(y_test)).reshape(-1,).to(torch.float32)

# %%
# x_train_full = torch.cat((x_train, x_train_timestamp), dim=1)
# x_test_full = torch.cat((x_test, x_test_timestamp), dim=1)
x_train_full = x_train
x_test_full =x_test
x_train_full.shape, x_test_full.shape
# Out:
# ((24918, 99), (15656, 99))

# %%
mae_arr =[]
rms_arr = []
y_pred_arr = []

batch = 512

# x_train = x_train[:4500]
# y_train = y_train[:4500]

# y_test_trans = torch.tensor(torch.tensor(scaler_x.transform(y_test.reshape(-1,1))).reshape(-1,)).contiguous().to(torch.float64)
for i in range(1):


  kernel1 = ScaleKernel(MaternKernel(nu=2.5,ard_num_dims=99)) #nu=2.5,
  # kernel2 = ScaleKernel(RBFKernel(ard_num_dims=1, active_dims=(1)))
  # kernel3 = ScaleKernel(PeriodicKernel(ard_num_dims=1, active_dims=(1)))
  # kernel4 = ScaleKernel(PeriodicKernel(ard_num_dims=2, active_dims=(0)))
  # kernel5 = ScaleKernel(CosineKernel(ard_num_dims=2, active_dims=(1)))

  kernel = kernel1# + kernel2*kernel3
  # induce_points = 512
  inducing_points =  x[np.arange(0,x.shape[0],20)] 
  #x[torch.randperm(x.shape[0])[: batch]].to("cuda")
  
  model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                       inducing_points).to("cuda")
  # model.mll.likelihood.noise_covar.register_constraint("raw_noise", GreaterThan(1e-2))
  # for param in model.parameters():
  #   # print(param)
  #   torch.nn.init.normal_(param, 0, 1)
  # theta1 = {'likelihood.noise_covar.noise': torch.tensor(3),
  #       'covar_module.base_kernel.lengthscale': torch.tensor(0.1),
  #       'covar_module.outputscale': torch.tensor(5),}
  loss = model.fit(lr=1e-2, n_epochs=1500,verbose=1,
          random_state=0)
#   loss_arr.append(loss)
  # print(loss)
  plt.plot(np.asarray(loss[0]))
  # plt.plot(np.asarray(test_loss[0]))
# Out:
# restart: 0, epoch: 1, iter: 1, loss: 1.6373
# restart: 0, epoch: 2, iter: 1, loss: 1.6256
# restart: 0, epoch: 3, iter: 1, loss: 1.6135
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/kernels/inducing_point_kernel.py:61: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352645774/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   inv_root = torch.triangular_solve(eye, chol)[0]
# restart: 0, epoch: 4, iter: 1, loss: 1.6028
# restart: 0, epoch: 5, iter: 1, loss: 1.5928
# restart: 0, epoch: 6, iter: 1, loss: 1.5831
# restart: 0, epoch: 7, iter: 1, loss: 1.5737
# restart: 0, epoch: 8, iter: 1, loss: 1.5649
# restart: 0, epoch: 9, iter: 1, loss: 1.5566
# restart: 0, epoch: 10, iter: 1, loss: 1.5486
# restart: 0, epoch: 11, iter: 1, loss: 1.5408
# restart: 0, epoch: 12, iter: 1, loss: 1.5333
# restart: 0, epoch: 13, iter: 1, loss: 1.5261
# restart: 0, epoch: 14, iter: 1, loss: 1.5192
# restart: 0, epoch: 15, iter: 1, loss: 1.5125
# restart: 0, epoch: 16, iter: 1, loss: 1.5060
# restart: 0, epoch: 17, iter: 1, loss: 1.4997
# restart: 0, epoch: 18, iter: 1, loss: 1.4936
# restart: 0, epoch: 19, iter: 1, loss: 1.4877
# restart: 0, epoch: 20, iter: 1, loss: 1.4819
# restart: 0, epoch: 21, iter: 1, loss: 1.4764
# restart: 0, epoch: 22, iter: 1, loss: 1.4710
# restart: 0, epoch: 23, iter: 1, loss: 1.4658
# restart: 0, epoch: 24, iter: 1, loss: 1.4607
# restart: 0, epoch: 25, iter: 1, loss: 1.4558
# restart: 0, epoch: 26, iter: 1, loss: 1.4511
# restart: 0, epoch: 27, iter: 1, loss: 1.4465
# restart: 0, epoch: 28, iter: 1, loss: 1.4420
# restart: 0, epoch: 29, iter: 1, loss: 1.4376
# restart: 0, epoch: 30, iter: 1, loss: 1.4333
# restart: 0, epoch: 31, iter: 1, loss: 1.4292
# restart: 0, epoch: 32, iter: 1, loss: 1.4252
# restart: 0, epoch: 33, iter: 1, loss: 1.4213
# restart: 0, epoch: 34, iter: 1, loss: 1.4174
# restart: 0, epoch: 35, iter: 1, loss: 1.4137
# restart: 0, epoch: 36, iter: 1, loss: 1.4100
# restart: 0, epoch: 37, iter: 1, loss: 1.4065
# restart: 0, epoch: 38, iter: 1, loss: 1.4030
# restart: 0, epoch: 39, iter: 1, loss: 1.3996
# restart: 0, epoch: 40, iter: 1, loss: 1.3962
# restart: 0, epoch: 41, iter: 1, loss: 1.3930
# restart: 0, epoch: 42, iter: 1, loss: 1.3898
# restart: 0, epoch: 791, iter: 1, loss: 0.0001
# restart: 0, epoch: 792, iter: 1, loss: -0.0009
# restart: 0, epoch: 793, iter: 1, loss: -0.0019
# restart: 0, epoch: 794, iter: 1, loss: -0.0030
# restart: 0, epoch: 795, iter: 1, loss: -0.0040
# restart: 0, epoch: 796, iter: 1, loss: -0.0050
# restart: 0, epoch: 797, iter: 1, loss: -0.0060
# restart: 0, epoch: 798, iter: 1, loss: -0.0071
# restart: 0, epoch: 799, iter: 1, loss: -0.0081
# restart: 0, epoch: 800, iter: 1, loss: -0.0091
# restart: 0, epoch: 801, iter: 1, loss: -0.0101
# restart: 0, epoch: 802, iter: 1, loss: -0.0111
# restart: 0, epoch: 803, iter: 1, loss: -0.0121
# restart: 0, epoch: 804, iter: 1, loss: -0.0131
# restart: 0, epoch: 805, iter: 1, loss: -0.0141
# restart: 0, epoch: 806, iter: 1, loss: -0.0151
# restart: 0, epoch: 807, iter: 1, loss: -0.0161
# restart: 0, epoch: 808, iter: 1, loss: -0.0171
# restart: 0, epoch: 809, iter: 1, loss: -0.0181
# restart: 0, epoch: 810, iter: 1, loss: -0.0192
# restart: 0, epoch: 811, iter: 1, loss: -0.0202
# restart: 0, epoch: 812, iter: 1, loss: -0.0212
# restart: 0, epoch: 813, iter: 1, loss: -0.0223
# restart: 0, epoch: 814, iter: 1, loss: -0.0233
# restart: 0, epoch: 815, iter: 1, loss: -0.0244
# restart: 0, epoch: 816, iter: 1, loss: -0.0255
# restart: 0, epoch: 817, iter: 1, loss: -0.0265
# restart: 0, epoch: 818, iter: 1, loss: -0.0275
# restart: 0, epoch: 819, iter: 1, loss: -0.0285
# restart: 0, epoch: 820, iter: 1, loss: -0.0295
# restart: 0, epoch: 821, iter: 1, loss: -0.0305
# restart: 0, epoch: 822, iter: 1, loss: -0.0315
# restart: 0, epoch: 823, iter: 1, loss: -0.0325
# restart: 0, epoch: 824, iter: 1, loss: -0.0335
# restart: 0, epoch: 825, iter: 1, loss: -0.0345
# restart: 0, epoch: 826, iter: 1, loss: -0.0355
# restart: 0, epoch: 827, iter: 1, loss: -0.0366
# restart: 0, epoch: 828, iter: 1, loss: -0.0376
# restart: 0, epoch: 829, iter: 1, loss: -0.0386
# restart: 0, epoch: 830, iter: 1, loss: -0.0396
# restart: 0, epoch: 831, iter: 1, loss: -0.0406
# restart: 0, epoch: 832, iter: 1, loss: -0.0415
# restart: 0, epoch: 833, iter: 1, loss: -0.0425
# restart: 0, epoch: 834, iter: 1, loss: -0.0435
# restart: 0, epoch: 835, iter: 1, loss: -0.0445
# restart: 0, epoch: 836, iter: 1, loss: -0.0455
# restart: 0, epoch: 837, iter: 1, loss: -0.0465
# restart: 0, epoch: 838, iter: 1, loss: -0.0474
# restart: 0, epoch: 839, iter: 1, loss: -0.0484
# restart: 0, epoch: 840, iter: 1, loss: -0.0493
# restart: 0, epoch: 841, iter: 1, loss: -0.0503
# restart: 0, epoch: 842, iter: 1, loss: -0.0512
# restart: 0, epoch: 843, iter: 1, loss: -0.0522
# restart: 0, epoch: 844, iter: 1, loss: -0.0531
# restart: 0, epoch: 845, iter: 1, loss: -0.0541
# restart: 0, epoch: 846, iter: 1, loss: -0.0550
# restart: 0, epoch: 847, iter: 1, loss: -0.0559
# restart: 0, epoch: 848, iter: 1, loss: -0.0569
# restart: 0, epoch: 849, iter: 1, loss: -0.0578
# restart: 0, epoch: 850, iter: 1, loss: -0.0587
# restart: 0, epoch: 851, iter: 1, loss: -0.0596
# restart: 0, epoch: 852, iter: 1, loss: -0.0605
# restart: 0, epoch: 853, iter: 1, loss: -0.0614
# restart: 0, epoch: 854, iter: 1, loss: -0.0623
# restart: 0, epoch: 855, iter: 1, loss: -0.0632
# restart: 0, epoch: 856, iter: 1, loss: -0.0641
# restart: 0, epoch: 857, iter: 1, loss: -0.0650
# restart: 0, epoch: 858, iter: 1, loss: -0.0659
# restart: 0, epoch: 859, iter: 1, loss: -0.0668
# restart: 0, epoch: 860, iter: 1, loss: -0.0677
# restart: 0, epoch: 861, iter: 1, loss: -0.0686
# restart: 0, epoch: 862, iter: 1, loss: -0.0694
# restart: 0, epoch: 863, iter: 1, loss: -0.0703
# restart: 0, epoch: 864, iter: 1, loss: -0.0712
# restart: 0, epoch: 865, iter: 1, loss: -0.0720
# restart: 0, epoch: 866, iter: 1, loss: -0.0729
# restart: 0, epoch: 867, iter: 1, loss: -0.0738
# restart: 0, epoch: 868, iter: 1, loss: -0.0746
# restart: 0, epoch: 869, iter: 1, loss: -0.0755
# restart: 0, epoch: 870, iter: 1, loss: -0.0763
# restart: 0, epoch: 871, iter: 1, loss: -0.0771
# restart: 0, epoch: 872, iter: 1, loss: -0.0780
# restart: 0, epoch: 873, iter: 1, loss: -0.0788
# restart: 0, epoch: 874, iter: 1, loss: -0.0797
# restart: 0, epoch: 875, iter: 1, loss: -0.0805
# restart: 0, epoch: 876, iter: 1, loss: -0.0813
# restart: 0, epoch: 877, iter: 1, loss: -0.0821
# restart: 0, epoch: 878, iter: 1, loss: -0.0830
# restart: 0, epoch: 879, iter: 1, loss: -0.0838
# restart: 0, epoch: 880, iter: 1, loss: -0.0846
# restart: 0, epoch: 881, iter: 1, loss: -0.0854
# restart: 0, epoch: 882, iter: 1, loss: -0.0862
# restart: 0, epoch: 883, iter: 1, loss: -0.0871
# restart: 0, epoch: 884, iter: 1, loss: -0.0879
# restart: 0, epoch: 885, iter: 1, loss: -0.0887
# restart: 0, epoch: 886, iter: 1, loss: -0.0895
# restart: 0, epoch: 887, iter: 1, loss: -0.0903
# restart: 0, epoch: 888, iter: 1, loss: -0.0911
# restart: 0, epoch: 889, iter: 1, loss: -0.0919
# restart: 0, epoch: 890, iter: 1, loss: -0.0928
# restart: 0, epoch: 891, iter: 1, loss: -0.0936
# restart: 0, epoch: 892, iter: 1, loss: -0.0944
# restart: 0, epoch: 893, iter: 1, loss: -0.0952
# restart: 0, epoch: 894, iter: 1, loss: -0.0960
# restart: 0, epoch: 895, iter: 1, loss: -0.0968
# restart: 0, epoch: 896, iter: 1, loss: -0.0976
# restart: 0, epoch: 897, iter: 1, loss: -0.0984
# restart: 0, epoch: 898, iter: 1, loss: -0.0992
# restart: 0, epoch: 899, iter: 1, loss: -0.1000
# restart: 0, epoch: 900, iter: 1, loss: -0.1007
# restart: 0, epoch: 901, iter: 1, loss: -0.1015
# restart: 0, epoch: 902, iter: 1, loss: -0.1023
# restart: 0, epoch: 903, iter: 1, loss: -0.1031
# restart: 0, epoch: 904, iter: 1, loss: -0.1039
# restart: 0, epoch: 905, iter: 1, loss: -0.1047
# restart: 0, epoch: 906, iter: 1, loss: -0.1054
# restart: 0, epoch: 907, iter: 1, loss: -0.1062
# restart: 0, epoch: 908, iter: 1, loss: -0.1070
# restart: 0, epoch: 909, iter: 1, loss: -0.1077
# restart: 0, epoch: 910, iter: 1, loss: -0.1085
# restart: 0, epoch: 911, iter: 1, loss: -0.1093
# restart: 0, epoch: 912, iter: 1, loss: -0.1100
# restart: 0, epoch: 913, iter: 1, loss: -0.1108
# restart: 0, epoch: 914, iter: 1, loss: -0.1115
# restart: 0, epoch: 915, iter: 1, loss: -0.1123
# restart: 0, epoch: 916, iter: 1, loss: -0.1131
# restart: 0, epoch: 917, iter: 1, loss: -0.1138
# restart: 0, epoch: 918, iter: 1, loss: -0.1145
# restart: 0, epoch: 919, iter: 1, loss: -0.1153
# restart: 0, epoch: 920, iter: 1, loss: -0.1160
# restart: 0, epoch: 921, iter: 1, loss: -0.1168
# restart: 0, epoch: 922, iter: 1, loss: -0.1175
# restart: 0, epoch: 923, iter: 1, loss: -0.1183
# restart: 0, epoch: 924, iter: 1, loss: -0.1190
# restart: 0, epoch: 925, iter: 1, loss: -0.1198
# restart: 0, epoch: 926, iter: 1, loss: -0.1205
# restart: 0, epoch: 927, iter: 1, loss: -0.1213
# restart: 0, epoch: 928, iter: 1, loss: -0.1220
# restart: 0, epoch: 929, iter: 1, loss: -0.1228
# restart: 0, epoch: 930, iter: 1, loss: -0.1235
# restart: 0, epoch: 931, iter: 1, loss: -0.1242
# restart: 0, epoch: 932, iter: 1, loss: -0.1250
# restart: 0, epoch: 933, iter: 1, loss: -0.1257
# restart: 0, epoch: 934, iter: 1, loss: -0.1265
# restart: 0, epoch: 935, iter: 1, loss: -0.1272
# restart: 0, epoch: 936, iter: 1, loss: -0.1280
# restart: 0, epoch: 937, iter: 1, loss: -0.1288
# restart: 0, epoch: 938, iter: 1, loss: -0.1295
# restart: 0, epoch: 939, iter: 1, loss: -0.1303
# restart: 0, epoch: 940, iter: 1, loss: -0.1310
# restart: 0, epoch: 941, iter: 1, loss: -0.1318
# restart: 0, epoch: 942, iter: 1, loss: -0.1325
# restart: 0, epoch: 943, iter: 1, loss: -0.1333
# restart: 0, epoch: 944, iter: 1, loss: -0.1341
# restart: 0, epoch: 945, iter: 1, loss: -0.1348
# restart: 0, epoch: 946, iter: 1, loss: -0.1356
# restart: 0, epoch: 947, iter: 1, loss: -0.1363
# restart: 0, epoch: 948, iter: 1, loss: -0.1371
# restart: 0, epoch: 949, iter: 1, loss: -0.1379
# restart: 0, epoch: 950, iter: 1, loss: -0.1386
# restart: 0, epoch: 951, iter: 1, loss: -0.1394
# restart: 0, epoch: 952, iter: 1, loss: -0.1401
# restart: 0, epoch: 953, iter: 1, loss: -0.1409
# restart: 0, epoch: 954, iter: 1, loss: -0.1416
# restart: 0, epoch: 955, iter: 1, loss: -0.1424
# restart: 0, epoch: 956, iter: 1, loss: -0.1432
# restart: 0, epoch: 957, iter: 1, loss: -0.1440
# restart: 0, epoch: 958, iter: 1, loss: -0.1447
# restart: 0, epoch: 959, iter: 1, loss: -0.1455
# restart: 0, epoch: 960, iter: 1, loss: -0.1463
# restart: 0, epoch: 961, iter: 1, loss: -0.1471
# restart: 0, epoch: 962, iter: 1, loss: -0.1479
# restart: 0, epoch: 963, iter: 1, loss: -0.1487
# restart: 0, epoch: 964, iter: 1, loss: -0.1495
# restart: 0, epoch: 965, iter: 1, loss: -0.1503
# restart: 0, epoch: 966, iter: 1, loss: -0.1511
# restart: 0, epoch: 967, iter: 1, loss: -0.1518
# restart: 0, epoch: 968, iter: 1, loss: -0.1526
# restart: 0, epoch: 969, iter: 1, loss: -0.1534
# restart: 0, epoch: 970, iter: 1, loss: -0.1541
# restart: 0, epoch: 971, iter: 1, loss: -0.1549
# restart: 0, epoch: 972, iter: 1, loss: -0.1557
# restart: 0, epoch: 973, iter: 1, loss: -0.1564
# restart: 0, epoch: 974, iter: 1, loss: -0.1572
# restart: 0, epoch: 975, iter: 1, loss: -0.1580
# restart: 0, epoch: 976, iter: 1, loss: -0.1587
# restart: 0, epoch: 977, iter: 1, loss: -0.1594
# restart: 0, epoch: 978, iter: 1, loss: -0.1602
# restart: 0, epoch: 979, iter: 1, loss: -0.1609
# restart: 0, epoch: 980, iter: 1, loss: -0.1617
# restart: 0, epoch: 981, iter: 1, loss: -0.1624
# restart: 0, epoch: 982, iter: 1, loss: -0.1631
# restart: 0, epoch: 983, iter: 1, loss: -0.1638
# restart: 0, epoch: 984, iter: 1, loss: -0.1646
# restart: 0, epoch: 985, iter: 1, loss: -0.1653
# restart: 0, epoch: 986, iter: 1, loss: -0.1660
# restart: 0, epoch: 987, iter: 1, loss: -0.1667
# restart: 0, epoch: 988, iter: 1, loss: -0.1674
# restart: 0, epoch: 989, iter: 1, loss: -0.1681
# restart: 0, epoch: 990, iter: 1, loss: -0.1688
# restart: 0, epoch: 991, iter: 1, loss: -0.1694
# restart: 0, epoch: 992, iter: 1, loss: -0.1701
# restart: 0, epoch: 993, iter: 1, loss: -0.1708
# restart: 0, epoch: 994, iter: 1, loss: -0.1715
# restart: 0, epoch: 995, iter: 1, loss: -0.1722
# restart: 0, epoch: 996, iter: 1, loss: -0.1728
# restart: 0, epoch: 997, iter: 1, loss: -0.1735
# restart: 0, epoch: 998, iter: 1, loss: -0.1741
# restart: 0, epoch: 999, iter: 1, loss: -0.1748
# restart: 0, epoch: 1000, iter: 1, loss: -0.1755
# restart: 0, epoch: 1001, iter: 1, loss: -0.1761
# restart: 0, epoch: 1002, iter: 1, loss: -0.1768
# restart: 0, epoch: 1003, iter: 1, loss: -0.1774
# restart: 0, epoch: 1004, iter: 1, loss: -0.1780
# restart: 0, epoch: 1005, iter: 1, loss: -0.1787
# restart: 0, epoch: 1006, iter: 1, loss: -0.1793
# restart: 0, epoch: 1007, iter: 1, loss: -0.1800
# restart: 0, epoch: 1008, iter: 1, loss: -0.1806
# restart: 0, epoch: 1009, iter: 1, loss: -0.1812
# restart: 0, epoch: 1010, iter: 1, loss: -0.1819
# restart: 0, epoch: 1011, iter: 1, loss: -0.1825
# restart: 0, epoch: 1012, iter: 1, loss: -0.1832
# restart: 0, epoch: 1013, iter: 1, loss: -0.1838
# restart: 0, epoch: 1014, iter: 1, loss: -0.1845
# restart: 0, epoch: 1015, iter: 1, loss: -0.1851
# restart: 0, epoch: 1016, iter: 1, loss: -0.1857
# restart: 0, epoch: 1017, iter: 1, loss: -0.1864
# restart: 0, epoch: 1018, iter: 1, loss: -0.1870
# restart: 0, epoch: 1019, iter: 1, loss: -0.1876
# restart: 0, epoch: 1020, iter: 1, loss: -0.1883
# restart: 0, epoch: 1021, iter: 1, loss: -0.1889
# restart: 0, epoch: 1022, iter: 1, loss: -0.1895
# restart: 0, epoch: 1023, iter: 1, loss: -0.1902
# restart: 0, epoch: 1024, iter: 1, loss: -0.1908
# restart: 0, epoch: 1025, iter: 1, loss: -0.1915
# restart: 0, epoch: 1026, iter: 1, loss: -0.1921
# ...
# restart: 0, epoch: 1168, iter: 1, loss: -0.2795
# restart: 0, epoch: 1169, iter: 1, loss: -0.2800
# restart: 0, epoch: 1170, iter: 1, loss: -0.2805
# restart: 0, epoch: 1171, iter: 1, loss: -0.2810
# restart: 0, epoch: 1172, iter: 1, loss: -0.2815
# restart: 0, epoch: 1173, iter: 1, loss: -0.2820
# restart: 0, epoch: 1174, iter: 1, loss: -0.2825
# restart: 0, epoch: 1175, iter: 1, loss: -0.2830
# restart: 0, epoch: 1176, iter: 1, loss: -0.2834
# restart: 0, epoch: 1177, iter: 1, loss: -0.2839
# restart: 0, epoch: 1178, iter: 1, loss: -0.2844
# restart: 0, epoch: 1179, iter: 1, loss: -0.2849
# restart: 0, epoch: 1180, iter: 1, loss: -0.2854
# restart: 0, epoch: 1181, iter: 1, loss: -0.2858
# restart: 0, epoch: 1182, iter: 1, loss: -0.2863
# restart: 0, epoch: 1183, iter: 1, loss: -0.2868
# restart: 0, epoch: 1184, iter: 1, loss: -0.2873
# restart: 0, epoch: 1185, iter: 1, loss: -0.2878
# restart: 0, epoch: 1186, iter: 1, loss: -0.2882
# restart: 0, epoch: 1187, iter: 1, loss: -0.2887
# restart: 0, epoch: 1188, iter: 1, loss: -0.2891
# restart: 0, epoch: 1189, iter: 1, loss: -0.2896
# restart: 0, epoch: 1190, iter: 1, loss: -0.2901
# restart: 0, epoch: 1191, iter: 1, loss: -0.2905
# restart: 0, epoch: 1192, iter: 1, loss: -0.2910
# restart: 0, epoch: 1193, iter: 1, loss: -0.2914
# restart: 0, epoch: 1194, iter: 1, loss: -0.2919
# restart: 0, epoch: 1195, iter: 1, loss: -0.2923
# restart: 0, epoch: 1196, iter: 1, loss: -0.2928
# restart: 0, epoch: 1197, iter: 1, loss: -0.2932
# restart: 0, epoch: 1198, iter: 1, loss: -0.2937
# restart: 0, epoch: 1199, iter: 1, loss: -0.2941
# restart: 0, epoch: 1200, iter: 1, loss: -0.2946
# restart: 0, epoch: 1201, iter: 1, loss: -0.2950
# restart: 0, epoch: 1202, iter: 1, loss: -0.2955
# restart: 0, epoch: 1203, iter: 1, loss: -0.2959
# restart: 0, epoch: 1204, iter: 1, loss: -0.2963
# restart: 0, epoch: 1205, iter: 1, loss: -0.2967
# restart: 0, epoch: 1206, iter: 1, loss: -0.2972
# restart: 0, epoch: 1207, iter: 1, loss: -0.2976
# restart: 0, epoch: 1208, iter: 1, loss: -0.2980
# restart: 0, epoch: 1209, iter: 1, loss: -0.2985
# restart: 0, epoch: 1210, iter: 1, loss: -0.2989
# restart: 0, epoch: 1211, iter: 1, loss: -0.2993
# restart: 0, epoch: 1212, iter: 1, loss: -0.2997
# restart: 0, epoch: 1213, iter: 1, loss: -0.3001
# restart: 0, epoch: 1214, iter: 1, loss: -0.3006
# restart: 0, epoch: 1215, iter: 1, loss: -0.3010
# restart: 0, epoch: 1216, iter: 1, loss: -0.3014
# restart: 0, epoch: 1217, iter: 1, loss: -0.3018
# restart: 0, epoch: 1218, iter: 1, loss: -0.3022
# restart: 0, epoch: 1219, iter: 1, loss: -0.3026
# restart: 0, epoch: 1220, iter: 1, loss: -0.3030
# restart: 0, epoch: 1221, iter: 1, loss: -0.3034
# restart: 0, epoch: 1222, iter: 1, loss: -0.3038
# restart: 0, epoch: 1223, iter: 1, loss: -0.3042
# restart: 0, epoch: 1224, iter: 1, loss: -0.3046
# restart: 0, epoch: 1225, iter: 1, loss: -0.3050
# restart: 0, epoch: 1226, iter: 1, loss: -0.3054
# restart: 0, epoch: 1227, iter: 1, loss: -0.3058
# restart: 0, epoch: 1228, iter: 1, loss: -0.3062
# restart: 0, epoch: 1229, iter: 1, loss: -0.3066
# restart: 0, epoch: 1230, iter: 1, loss: -0.3070
# restart: 0, epoch: 1231, iter: 1, loss: -0.3074
# restart: 0, epoch: 1232, iter: 1, loss: -0.3078
# restart: 0, epoch: 1233, iter: 1, loss: -0.3082
# restart: 0, epoch: 1234, iter: 1, loss: -0.3086
# restart: 0, epoch: 1235, iter: 1, loss: -0.3090
# restart: 0, epoch: 1236, iter: 1, loss: -0.3094
# restart: 0, epoch: 1237, iter: 1, loss: -0.3098
# restart: 0, epoch: 1238, iter: 1, loss: -0.3101
# restart: 0, epoch: 1239, iter: 1, loss: -0.3105
# restart: 0, epoch: 1240, iter: 1, loss: -0.3109
# restart: 0, epoch: 1241, iter: 1, loss: -0.3113
# restart: 0, epoch: 1242, iter: 1, loss: -0.3117
# restart: 0, epoch: 1243, iter: 1, loss: -0.3120
# restart: 0, epoch: 1244, iter: 1, loss: -0.3124
# restart: 0, epoch: 1245, iter: 1, loss: -0.3128
# restart: 0, epoch: 1246, iter: 1, loss: -0.3132
# restart: 0, epoch: 1247, iter: 1, loss: -0.3136
# restart: 0, epoch: 1248, iter: 1, loss: -0.3139
# restart: 0, epoch: 1249, iter: 1, loss: -0.3143
# restart: 0, epoch: 1250, iter: 1, loss: -0.3147
# restart: 0, epoch: 1251, iter: 1, loss: -0.3150
# restart: 0, epoch: 1252, iter: 1, loss: -0.3154
# restart: 0, epoch: 1253, iter: 1, loss: -0.3158
# restart: 0, epoch: 1254, iter: 1, loss: -0.3162
# restart: 0, epoch: 1255, iter: 1, loss: -0.3166
# restart: 0, epoch: 1256, iter: 1, loss: -0.3169
# restart: 0, epoch: 1257, iter: 1, loss: -0.3173
# restart: 0, epoch: 1258, iter: 1, loss: -0.3177
# restart: 0, epoch: 1259, iter: 1, loss: -0.3180
# restart: 0, epoch: 1260, iter: 1, loss: -0.3184
# restart: 0, epoch: 1261, iter: 1, loss: -0.3188
# restart: 0, epoch: 1262, iter: 1, loss: -0.3191
# restart: 0, epoch: 1263, iter: 1, loss: -0.3195
# restart: 0, epoch: 1264, iter: 1, loss: -0.3199
# restart: 0, epoch: 1265, iter: 1, loss: -0.3202
# restart: 0, epoch: 1266, iter: 1, loss: -0.3206
# restart: 0, epoch: 1267, iter: 1, loss: -0.3209
# restart: 0, epoch: 1268, iter: 1, loss: -0.3213
# restart: 0, epoch: 1269, iter: 1, loss: -0.3217
# restart: 0, epoch: 1270, iter: 1, loss: -0.3220
# restart: 0, epoch: 1271, iter: 1, loss: -0.3224
# restart: 0, epoch: 1272, iter: 1, loss: -0.3228
# restart: 0, epoch: 1273, iter: 1, loss: -0.3231
# restart: 0, epoch: 1274, iter: 1, loss: -0.3235
# restart: 0, epoch: 1275, iter: 1, loss: -0.3239
# restart: 0, epoch: 1276, iter: 1, loss: -0.3242
# restart: 0, epoch: 1277, iter: 1, loss: -0.3246
# restart: 0, epoch: 1278, iter: 1, loss: -0.3249
# restart: 0, epoch: 1279, iter: 1, loss: -0.3253
# restart: 0, epoch: 1280, iter: 1, loss: -0.3257
# restart: 0, epoch: 1281, iter: 1, loss: -0.3260
# restart: 0, epoch: 1282, iter: 1, loss: -0.3264
# restart: 0, epoch: 1283, iter: 1, loss: -0.3267
# restart: 0, epoch: 1284, iter: 1, loss: -0.3271
# restart: 0, epoch: 1285, iter: 1, loss: -0.3275
# restart: 0, epoch: 1286, iter: 1, loss: -0.3278
# restart: 0, epoch: 1287, iter: 1, loss: -0.3282
# restart: 0, epoch: 1288, iter: 1, loss: -0.3286
# restart: 0, epoch: 1289, iter: 1, loss: -0.3289
# restart: 0, epoch: 1290, iter: 1, loss: -0.3293
# restart: 0, epoch: 1291, iter: 1, loss: -0.3297
# restart: 0, epoch: 1292, iter: 1, loss: -0.3301
# restart: 0, epoch: 1293, iter: 1, loss: -0.3304
# restart: 0, epoch: 1294, iter: 1, loss: -0.3308
# restart: 0, epoch: 1295, iter: 1, loss: -0.3312
# restart: 0, epoch: 1296, iter: 1, loss: -0.3316
# restart: 0, epoch: 1297, iter: 1, loss: -0.3320
# restart: 0, epoch: 1298, iter: 1, loss: -0.3324
# restart: 0, epoch: 1299, iter: 1, loss: -0.3328
# restart: 0, epoch: 1300, iter: 1, loss: -0.3332
# restart: 0, epoch: 1301, iter: 1, loss: -0.3336
# restart: 0, epoch: 1302, iter: 1, loss: -0.3340
# restart: 0, epoch: 1303, iter: 1, loss: -0.3344
# restart: 0, epoch: 1304, iter: 1, loss: -0.3348
# restart: 0, epoch: 1305, iter: 1, loss: -0.3353
# restart: 0, epoch: 1306, iter: 1, loss: -0.3357
# restart: 0, epoch: 1307, iter: 1, loss: -0.3361
# restart: 0, epoch: 1308, iter: 1, loss: -0.3365
# restart: 0, epoch: 1309, iter: 1, loss: -0.3369
# restart: 0, epoch: 1310, iter: 1, loss: -0.3374
# restart: 0, epoch: 1311, iter: 1, loss: -0.3378
# restart: 0, epoch: 1312, iter: 1, loss: -0.3382
# restart: 0, epoch: 1313, iter: 1, loss: -0.3386
# restart: 0, epoch: 1314, iter: 1, loss: -0.3390
# restart: 0, epoch: 1315, iter: 1, loss: -0.3395
# restart: 0, epoch: 1316, iter: 1, loss: -0.3399
# restart: 0, epoch: 1317, iter: 1, loss: -0.3403
# restart: 0, epoch: 1318, iter: 1, loss: -0.3407
# restart: 0, epoch: 1319, iter: 1, loss: -0.3411
# restart: 0, epoch: 1320, iter: 1, loss: -0.3416
# restart: 0, epoch: 1321, iter: 1, loss: -0.3420
# restart: 0, epoch: 1322, iter: 1, loss: -0.3424
# restart: 0, epoch: 1323, iter: 1, loss: -0.3428
# restart: 0, epoch: 1324, iter: 1, loss: -0.3432
# restart: 0, epoch: 1325, iter: 1, loss: -0.3436
# restart: 0, epoch: 1326, iter: 1, loss: -0.3440
# restart: 0, epoch: 1327, iter: 1, loss: -0.3444
# restart: 0, epoch: 1328, iter: 1, loss: -0.3448
# restart: 0, epoch: 1329, iter: 1, loss: -0.3452
# restart: 0, epoch: 1330, iter: 1, loss: -0.3455
# restart: 0, epoch: 1331, iter: 1, loss: -0.3459
# restart: 0, epoch: 1332, iter: 1, loss: -0.3463
# restart: 0, epoch: 1333, iter: 1, loss: -0.3466
# restart: 0, epoch: 1334, iter: 1, loss: -0.3470
# restart: 0, epoch: 1335, iter: 1, loss: -0.3474
# restart: 0, epoch: 1336, iter: 1, loss: -0.3478
# restart: 0, epoch: 1337, iter: 1, loss: -0.3481
# restart: 0, epoch: 1338, iter: 1, loss: -0.3485
# restart: 0, epoch: 1339, iter: 1, loss: -0.3489
# restart: 0, epoch: 1340, iter: 1, loss: -0.3492
# restart: 0, epoch: 1341, iter: 1, loss: -0.3495
# restart: 0, epoch: 1342, iter: 1, loss: -0.3499
# restart: 0, epoch: 1343, iter: 1, loss: -0.3502
# restart: 0, epoch: 1344, iter: 1, loss: -0.3506
# restart: 0, epoch: 1345, iter: 1, loss: -0.3509
# restart: 0, epoch: 1346, iter: 1, loss: -0.3513
# restart: 0, epoch: 1347, iter: 1, loss: -0.3516
# restart: 0, epoch: 1348, iter: 1, loss: -0.3520
# restart: 0, epoch: 1349, iter: 1, loss: -0.3523
# restart: 0, epoch: 1350, iter: 1, loss: -0.3526
# restart: 0, epoch: 1351, iter: 1, loss: -0.3530
# restart: 0, epoch: 1352, iter: 1, loss: -0.3533
# restart: 0, epoch: 1353, iter: 1, loss: -0.3536
# restart: 0, epoch: 1354, iter: 1, loss: -0.3540
# restart: 0, epoch: 1355, iter: 1, loss: -0.3543
# restart: 0, epoch: 1356, iter: 1, loss: -0.3547
# restart: 0, epoch: 1357, iter: 1, loss: -0.3550
# restart: 0, epoch: 1358, iter: 1, loss: -0.3553
# restart: 0, epoch: 1359, iter: 1, loss: -0.3556
# restart: 0, epoch: 1360, iter: 1, loss: -0.3559
# restart: 0, epoch: 1361, iter: 1, loss: -0.3563
# restart: 0, epoch: 1362, iter: 1, loss: -0.3566
# restart: 0, epoch: 1363, iter: 1, loss: -0.3569
# restart: 0, epoch: 1364, iter: 1, loss: -0.3573
# restart: 0, epoch: 1365, iter: 1, loss: -0.3576
# restart: 0, epoch: 1366, iter: 1, loss: -0.3579
# restart: 0, epoch: 1367, iter: 1, loss: -0.3582
# restart: 0, epoch: 1368, iter: 1, loss: -0.3585
# restart: 0, epoch: 1369, iter: 1, loss: -0.3588
# restart: 0, epoch: 1370, iter: 1, loss: -0.3592
# restart: 0, epoch: 1371, iter: 1, loss: -0.3595
# restart: 0, epoch: 1372, iter: 1, loss: -0.3598
# restart: 0, epoch: 1373, iter: 1, loss: -0.3601
# restart: 0, epoch: 1374, iter: 1, loss: -0.3604
# restart: 0, epoch: 1375, iter: 1, loss: -0.3607
# restart: 0, epoch: 1376, iter: 1, loss: -0.3610
# restart: 0, epoch: 1377, iter: 1, loss: -0.3614
# restart: 0, epoch: 1378, iter: 1, loss: -0.3617
# restart: 0, epoch: 1379, iter: 1, loss: -0.3620
# restart: 0, epoch: 1380, iter: 1, loss: -0.3623
# restart: 0, epoch: 1381, iter: 1, loss: -0.3626
# restart: 0, epoch: 1382, iter: 1, loss: -0.3629
# restart: 0, epoch: 1383, iter: 1, loss: -0.3632
# restart: 0, epoch: 1384, iter: 1, loss: -0.3635
# restart: 0, epoch: 1385, iter: 1, loss: -0.3638
# restart: 0, epoch: 1386, iter: 1, loss: -0.3641
# restart: 0, epoch: 1387, iter: 1, loss: -0.3644
# restart: 0, epoch: 1388, iter: 1, loss: -0.3647
# restart: 0, epoch: 1389, iter: 1, loss: -0.3650
# restart: 0, epoch: 1390, iter: 1, loss: -0.3653
# restart: 0, epoch: 1391, iter: 1, loss: -0.3656
# restart: 0, epoch: 1392, iter: 1, loss: -0.3660
# restart: 0, epoch: 1393, iter: 1, loss: -0.3663
# restart: 0, epoch: 1394, iter: 1, loss: -0.3666
# restart: 0, epoch: 1395, iter: 1, loss: -0.3669
# restart: 0, epoch: 1396, iter: 1, loss: -0.3672
# restart: 0, epoch: 1397, iter: 1, loss: -0.3675
# restart: 0, epoch: 1398, iter: 1, loss: -0.3678
# restart: 0, epoch: 1399, iter: 1, loss: -0.3681
# restart: 0, epoch: 1400, iter: 1, loss: -0.3684
# restart: 0, epoch: 1401, iter: 1, loss: -0.3687
# restart: 0, epoch: 1402, iter: 1, loss: -0.3690
# restart: 0, epoch: 1403, iter: 1, loss: -0.3693
# restart: 0, epoch: 1404, iter: 1, loss: -0.3696
# restart: 0, epoch: 1405, iter: 1, loss: -0.3700
# restart: 0, epoch: 1406, iter: 1, loss: -0.3703
# restart: 0, epoch: 1407, iter: 1, loss: -0.3706
# restart: 0, epoch: 1408, iter: 1, loss: -0.3709
# restart: 0, epoch: 1409, iter: 1, loss: -0.3713
# restart: 0, epoch: 1410, iter: 1, loss: -0.3716
# restart: 0, epoch: 1411, iter: 1, loss: -0.3719
# restart: 0, epoch: 1412, iter: 1, loss: -0.3722
# restart: 0, epoch: 1413, iter: 1, loss: -0.3726
# restart: 0, epoch: 1414, iter: 1, loss: -0.3729
# restart: 0, epoch: 1415, iter: 1, loss: -0.3732
# restart: 0, epoch: 1416, iter: 1, loss: -0.3736
# restart: 0, epoch: 1417, iter: 1, loss: -0.3739
# restart: 0, epoch: 1418, iter: 1, loss: -0.3743
# restart: 0, epoch: 1419, iter: 1, loss: -0.3746
# restart: 0, epoch: 1420, iter: 1, loss: -0.3749
# restart: 0, epoch: 1421, iter: 1, loss: -0.3752
# restart: 0, epoch: 1422, iter: 1, loss: -0.3756
# restart: 0, epoch: 1423, iter: 1, loss: -0.3759
# restart: 0, epoch: 1424, iter: 1, loss: -0.3763
# restart: 0, epoch: 1425, iter: 1, loss: -0.3766
# restart: 0, epoch: 1426, iter: 1, loss: -0.3769
# restart: 0, epoch: 1427, iter: 1, loss: -0.3773
# restart: 0, epoch: 1428, iter: 1, loss: -0.3777
# restart: 0, epoch: 1429, iter: 1, loss: -0.3780
# restart: 0, epoch: 1430, iter: 1, loss: -0.3784
# restart: 0, epoch: 1431, iter: 1, loss: -0.3788
# restart: 0, epoch: 1432, iter: 1, loss: -0.3791
# restart: 0, epoch: 1433, iter: 1, loss: -0.3795
# restart: 0, epoch: 1434, iter: 1, loss: -0.3799
# restart: 0, epoch: 1435, iter: 1, loss: -0.3803
# restart: 0, epoch: 1436, iter: 1, loss: -0.3807
# restart: 0, epoch: 1437, iter: 1, loss: -0.3811
# restart: 0, epoch: 1438, iter: 1, loss: -0.3815
# restart: 0, epoch: 1439, iter: 1, loss: -0.3819
# restart: 0, epoch: 1440, iter: 1, loss: -0.3823
# restart: 0, epoch: 1441, iter: 1, loss: -0.3828
# restart: 0, epoch: 1442, iter: 1, loss: -0.3832
# restart: 0, epoch: 1443, iter: 1, loss: -0.3836
# restart: 0, epoch: 1444, iter: 1, loss: -0.3841
# restart: 0, epoch: 1445, iter: 1, loss: -0.3845
# restart: 0, epoch: 1446, iter: 1, loss: -0.3850
# restart: 0, epoch: 1447, iter: 1, loss: -0.3854
# restart: 0, epoch: 1448, iter: 1, loss: -0.3858
# restart: 0, epoch: 1449, iter: 1, loss: -0.3863
# restart: 0, epoch: 1450, iter: 1, loss: -0.3867
# restart: 0, epoch: 1451, iter: 1, loss: -0.3872
# restart: 0, epoch: 1452, iter: 1, loss: -0.3876
# restart: 0, epoch: 1453, iter: 1, loss: -0.3880
# restart: 0, epoch: 1454, iter: 1, loss: -0.3885
# restart: 0, epoch: 1455, iter: 1, loss: -0.3889
# restart: 0, epoch: 1456, iter: 1, loss: -0.3893
# restart: 0, epoch: 1457, iter: 1, loss: -0.3897
# restart: 0, epoch: 1458, iter: 1, loss: -0.3901
# restart: 0, epoch: 1459, iter: 1, loss: -0.3906
# restart: 0, epoch: 1460, iter: 1, loss: -0.3910
# restart: 0, epoch: 1461, iter: 1, loss: -0.3914
# restart: 0, epoch: 1462, iter: 1, loss: -0.3918
# restart: 0, epoch: 1463, iter: 1, loss: -0.3922
# restart: 0, epoch: 1464, iter: 1, loss: -0.3926
# restart: 0, epoch: 1465, iter: 1, loss: -0.3930
# restart: 0, epoch: 1466, iter: 1, loss: -0.3935
# restart: 0, epoch: 1467, iter: 1, loss: -0.3939
# restart: 0, epoch: 1468, iter: 1, loss: -0.3943
# restart: 0, epoch: 1469, iter: 1, loss: -0.3946
# restart: 0, epoch: 1470, iter: 1, loss: -0.3950
# restart: 0, epoch: 1471, iter: 1, loss: -0.3954
# restart: 0, epoch: 1472, iter: 1, loss: -0.3958
# restart: 0, epoch: 1473, iter: 1, loss: -0.3963
# restart: 0, epoch: 1474, iter: 1, loss: -0.3966
# restart: 0, epoch: 1475, iter: 1, loss: -0.3970
# restart: 0, epoch: 1476, iter: 1, loss: -0.3974
# restart: 0, epoch: 1477, iter: 1, loss: -0.3979
# restart: 0, epoch: 1478, iter: 1, loss: -0.3983
# restart: 0, epoch: 1479, iter: 1, loss: -0.3986
# restart: 0, epoch: 1480, iter: 1, loss: -0.3990
# restart: 0, epoch: 1481, iter: 1, loss: -0.3994
# restart: 0, epoch: 1482, iter: 1, loss: -0.3998
# restart: 0, epoch: 1483, iter: 1, loss: -0.4002
# restart: 0, epoch: 1484, iter: 1, loss: -0.4006
# restart: 0, epoch: 1485, iter: 1, loss: -0.4011
# restart: 0, epoch: 1486, iter: 1, loss: -0.4015
# restart: 0, epoch: 1487, iter: 1, loss: -0.4018
# restart: 0, epoch: 1488, iter: 1, loss: -0.4023
# restart: 0, epoch: 1489, iter: 1, loss: -0.4027
# restart: 0, epoch: 1490, iter: 1, loss: -0.4031
# restart: 0, epoch: 1491, iter: 1, loss: -0.4035
# restart: 0, epoch: 1492, iter: 1, loss: -0.4040
# restart: 0, epoch: 1493, iter: 1, loss: -0.4044
# restart: 0, epoch: 1494, iter: 1, loss: -0.4048
# restart: 0, epoch: 1495, iter: 1, loss: -0.4052
# restart: 0, epoch: 1496, iter: 1, loss: -0.4056
# restart: 0, epoch: 1497, iter: 1, loss: -0.4060
# restart: 0, epoch: 1498, iter: 1, loss: -0.4065
# restart: 0, epoch: 1499, iter: 1, loss: -0.4069
# restart: 0, epoch: 1500, iter: 1, loss: -0.4072

# %%
model_name = "Point_to_point_main_power_seq.pt"
torch.save(model.state_dict(), os.path.join(
  "Neurips/models", model_name))

# %%
# kernel1 = ScaleKernel(RBFKernel(ard_num_dims=1, active_dims=(0))) #nu=2.5,
# # kernel2 = ScaleKernel(RBFKernel(ard_num_dims=1, active_dims=(1)))
# # kernel3 = ScaleKernel(PeriodicKernel(ard_num_dims=1, active_dims=(1)))
# # kernel4 = ScaleKernel(PeriodicKernel(ard_num_dims=2, active_dims=(0)))
# # kernel5 = ScaleKernel(CosineKernel(ard_num_dims=2, active_dims=(1)))

# kernel = kernel1# + kernel2*kernel3
# # induce_points = 512
# inducing_points =  x_train[np.arange(0,x_train.shape[0],20)] 
# #x_train_full[torch.randperm(x_train_full.shape[0])[: batch]].to("cuda")

# model = SGPRegressor(x_train.to("cuda"), y_train.to("cuda"), kernel,
#                       inducing_points).to("cuda")

# model_name = "Refrigerator_trial_atrificial_main_only_main_fold3.pt"
# model.load_state_dict(torch.load(
#     os.path.join("models/", model_name)))

# %%
y_pred_arr =[]
pred_dist = model.predict(xt.to("cuda"))

y_pred_arr.append(pred_dist.loc)

# %%
y_pred_arr1 = []
for i in range(len(y_pred_arr)):
  y_pred_arr1.append(np.array(y_pred_arr[i].cpu()))

# %%
y_mean = np.mean(y_pred_arr1, axis =0)
# y_sigma = np.std(y_pred_arr1, axis=0)

y_mean.shape#, y_sigma.shape

y_mean = scaler_y.inverse_transform(y_mean.reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(y_test.shape, y_mean.shape)

y_mean = np.clip(y_mean,0,y_mean.max(),out=y_mean)
# Out:
# (15656, 1) (15656,)

# %%
mae = np.mean(np.abs(np.array(yt) - y_mean))
rms = errors.rmse(jnp.array(yt), y_mean)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  8.764452
# RMSE:  22.537382

# %%
idx = 1000
start = 9000
plt.figure(figsize=(10,6))
time_plot = scaler_time.inverse_transform(x_test_timestamp.reshape(-1,1))
# latexify(width_scale_factor=1.5, fig_height=2)
# plt.plot(time_plot[start : start + idx], scaler_x.inverse_transform(xt)[:,49][start : start + idx], label = "Main Power")
plt.plot(time_plot[start : start + idx], y_test[start : start + idx], label = "Ground Truth")
plt.plot(time_plot[start : start + idx], y_mean[start : start + idx], label = "Prediction")
# plt.legend(frameon=False, ncol=2)
plt.xlabel("Time ( in DateTime)")
plt.ylabel("Power")
sns.despine()
plt.show()
# savefig("Point_to_point_main_power_add100_sudden_pred")

# %%
for name, params in model.named_parameters():
  print(name, params)
# Out:
# mll.likelihood.noise_covar.raw_noise Parameter containing:
# tensor([-4.0766], device='cuda:0', requires_grad=True)
# mll.model.mean_module.constant Parameter containing:
# tensor([0.8700], device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.raw_outputscale Parameter containing:
# tensor(-2.5899, device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.base_kernel.raw_lengthscale Parameter containing:
# tensor([[10.4251, 10.8671, 11.2113, 11.2482, 11.2213, 11.3358, 11.2443, 11.4213,
#          11.6552, 11.6334, 11.7098, 11.4688, 11.5728, 11.4793, 11.4923, 11.6508,
#          11.8268, 11.9869, 11.7231, 11.9634, 11.8792, 11.9776, 12.0374, 12.1292,
#          12.1015, 12.1548, 12.1259, 12.0086, 12.0525, 12.0732, 12.0210, 11.6221,
#          11.8350, 11.9144, 11.9817, 11.5319, 11.4422, 11.4816, 11.4924, 11.5062,
#          11.4141, 11.4433, 11.4957, 11.4067, 11.4078, 11.1971, 11.1387,  9.9038,
#           8.8081, -0.1963,  6.7484, 11.8245, 12.2235, 12.3450, 12.8252, 12.1872,
#          12.1993, 12.0396, 12.1630, 11.7547, 11.5037, 11.1481, 11.4272, 11.5192,
#          11.4625, 11.7511, 11.4192, 11.2371, 11.6814, 11.8072, 11.7867, 11.9044,
#          12.2247, 12.2645, 12.2657, 11.9786, 11.9037, 11.9792, 11.9128, 11.7109,
#          12.0113, 12.0382, 11.9002, 11.5900, 10.9798, 11.7662, 11.2211, 11.6867,
#          11.5052, 11.4465, 11.4364, 11.4566, 11.3606, 11.3861, 11.5726, 11.5023,
#          11.0483, 10.5532,  9.8005]], device='cuda:0', requires_grad=True)
# mll.model.covar_module.inducing_points Parameter containing:
# tensor([[-0.2210, -0.2606, -0.2952,  ..., -0.1671, -0.1171, -0.0589],
#         [-0.2255, -0.1171, -0.1774,  ...,  9.6184, 11.4964, 11.0390],
#         [-0.3582, -0.3827, -0.3867,  ...,  2.4514,  2.2701,  2.0963],
#         ...,
#         [-0.3314, -0.3764, -0.4131,  ..., -0.4002, -0.3857, -0.3721],
#         [ 0.1381,  0.1713,  0.2650,  ...,  0.2451,  0.2893,  0.3004],
#         [-0.4053, -0.4652, -0.4698,  ..., -0.0496,  0.0306,  0.1052]],
#        device='cuda:0', requires_grad=True)

# %%
ar = np.arange(0,99,1)
print(ar.shape)
plt.plot(ar,model.mll.model.base_covar_module.base_kernel.lengthscale.cpu().detach().numpy().reshape(-1,))
plt.xlabel("# ARD")
plt.ylabel("Learned Lengthscale Values")
# Out:
# (99,)
# Text(0, 0.5, 'Learned Lengthscale Values')

# %%
pd.plotting.autocorrelation_plot(pd.Series(y[:500].reshape(-1,)))
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
pd.plotting.autocorrelation_plot(pd.Series(yt[:500].reshape(-1,)))
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %% [markdown]
# ## Decomposition

# %%
model1 = SGPRegressor(x_train_full.to("cuda"), y_train.to("cuda"), kernel1,
                      inducing_points).to("cuda")

# %%
pred_dist1 = model1.predict(x_test_full[:4000].to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc
# Out:
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(

# %%
y_pred_arr =[]

y_pred_arr.append(pred_dist1.loc)

# %%
y_mean1.shape
# Out:
# torch.Size([4000])

# %%
y_pred_arr1 = []
for i in range(len(y_pred_arr)):
  y_pred_arr1.append(np.array(y_pred_arr[i].cpu()))

# %%
y_mean1 = np.mean(y_pred_arr1, axis =0)
# y_sigma = np.std(y_pred_arr1, axis=0)

y_mean1.shape#, y_sigma.shape

y_mean1 = scaler_y.inverse_transform(y_mean1.reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(y_test.shape, y_mean1.shape)

y_mean1 = np.clip(y_mean1,0,y_mean1.max(),out=y_mean1)
# Out:
# torch.Size([15656]) (4000,)

# %%
mae = np.mean(np.abs(np.array(y_test[:4000]) - y_mean1))
rms = errors.rmse(jnp.array(y_test[:4000]), y_mean1)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  13.221285980073695
# RMSE:  23.772297

# %%
idx = 3000
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp[:idx], y_test.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean1[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()

# %%
model2 = SGPRegressor(x_train_full.to("cuda"), y_train.to("cuda"), kernel2*kernel3,
                      inducing_points).to("cuda")

# %%
pred_dist2 = model2.predict(x_test_full[:4000].to("cuda"))
# print("Done ", i)

y_mean2 = pred_dist2.loc

# %%
y_pred_arr =[]

y_pred_arr.append(pred_dist2.loc)

# %%
y_pred_arr1 = []
for i in range(len(y_pred_arr)):
  y_pred_arr1.append(np.array(y_pred_arr[i].cpu()))

# %%
y_mean2 = np.mean(y_pred_arr1, axis =0)
# y_sigma = np.std(y_pred_arr2, axis=0)

y_mean2.shape#, y_sigma.shape

y_mean2 = scaler_y.inverse_transform(y_mean2.reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(y_test.shape, y_mean2.shape)

y_mean2 = np.clip(y_mean2,0,y_mean2.max(),out=y_mean2)
# Out:
# torch.Size([15656]) (4000,)

# %%
mae = np.mean(np.abs(np.array(y_test[:4000]) - y_mean2))
rms = errors.rmse(jnp.array(y_test[:4000]), y_mean2)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  66.97996230941146
# RMSE:  83.967285

# %%
idx = 3000
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp[:idx], y_test.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean2[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
