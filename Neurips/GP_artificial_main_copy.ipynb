# %%
import os
os.chdir("../")
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %%
import torch
from gpytorch.kernels import RBFKernel, ScaleKernel, PeriodicKernel, MaternKernel, CosineKernel
from skgpytorch.models import SVGPRegressor, SGPRegressor, ExactGPRegressor

# %%
import jax.numpy as jnp
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from utilities.fits import fit
# from utilities import plot
import tensorflow_probability.substrates.jax as tfp
dist = tfp.distributions
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from gpytorch.constraints import GreaterThan
from skgpytorch.metrics import mean_squared_error, negative_log_predictive_density
import time
import numpy as np

# from datasets.dataset_load import dataset_loader
from utilities import plot,fits,gmm,errors,predict,preprocess

# device = "cpu"
# torch.set_default_dtype(torch.float32)
# torch.set_default_tensor_type(torch.FloatTensor)

# %%
try:
    from probml_utils import latexify, savefig, is_latexify_enabled
except ModuleNotFoundError:
    # %pip install git+https://github.com/probml/probml-utils.git
    from probml_utils import latexify, savefig, is_latexify_enabled

# %%
os.environ["LATEXIFY"] = "1"
os.environ["FIG_DIR"] = "Neurips/Plots/"

# %%
def dataset_load(appliances, train, test=None):
    x_train = []
    y_train = []
    x_train_timestamp = []
    scaler_x = StandardScaler()
    scaler_y = StandardScaler()
    scaler_time = StandardScaler()
    app = 0
    # train
    torch.set_default_dtype(torch.float64)
    for key, values in train.items():
        for app in range(len(appliances)):
            df = pd.read_csv(
                f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[app]])
            df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
            startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
            endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()
            

            if startDate > endDate:
                raise "Start Date must be smaller than Enddate."

            df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
            df.dropna(inplace=True)
            if app == 0:
                x = df[appliances[app]].values
            else:
                x += df[appliances[app]].values
            if appliances[app] == "Refrigerator":
                y = df[appliances[app]].values
            # x = df["main"].values
            
        # x = x + 100*np.ones(x.shape[0])
        timestamp_train = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values

        x_train.extend(torch.tensor(x))
        y_train.extend(torch.tensor(y))
        x_train_timestamp.extend(torch.tensor(timestamp_train))


    x_train = torch.tensor(x_train).reshape(-1, 1)
    y_train = torch.tensor(y_train).reshape(-1, 1)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(-1,1)
    x_train = scaler_x.fit_transform(x_train)
    y_train = scaler_y.fit_transform(y_train)
    x_train_timestamp = scaler_time.fit_transform(x_train_timestamp)


    # test
    x_test = []
    y_test = []
    x_test_timestamp = []
    app = 0
    for key, values in test.items():
        for app in range(len(appliances)):
            df = pd.read_csv(
                f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[app]])
            df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
            startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
            endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

            if startDate > endDate:
                raise "Start Date must be smaller than Enddate."

            df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
            df.dropna(inplace=True)
            if app == 0:
                x = df[appliances[app]].values
            else:
                x += df[appliances[app]].values
            if appliances[app] == "Refrigerator":
                y = df[appliances[app]].values
            # x = df["main"].values
            # y = df[appliances[app]].values
        timestamp = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        
        # x = x + 100*np.ones(x.shape[0])
        x_test.extend(torch.tensor(x))
        y_test.extend(torch.tensor(y))
        x_test_timestamp.extend(timestamp)

    x_test = torch.tensor(x_test).reshape(-1, 1)
    y_test = torch.tensor(y_test).reshape(-1, 1)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(-1,1)

    x_test = scaler_x.transform(x_test)
    x_test_timestamp = scaler_time.transform(x_test_timestamp)

    x_train = torch.tensor(x_train).reshape(x_train.shape[0], 1).to(torch.float32)
    y_train = torch.tensor(y_train).reshape(-1,).to(torch.float32)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(x_train_timestamp.shape[0], 1).to(torch.float32)
    x_test = torch.tensor(x_test).reshape(x_test.shape[0], 1).to(torch.float32)
    y_test = torch.tensor(y_test).reshape(-1,).to(torch.float32)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(x_test_timestamp.shape[0], 1).to(torch.float32)


    return x_train, y_train, x_test, y_test, x_train_timestamp, x_test_timestamp, scaler_x, scaler_y, scaler_time

# %%
train ={1:{
                    'start_time': "2011-04-28" ,
                    'end_time': "2011-05-15"
                },
        3: {
                'start_time': "2011-04-19" ,
                'end_time': "2011-05-22"
            }
                }
test = { 2: {
                    'start_time': "2011-04-21" ,
                    'end_time': "2011-05-21"
                },
                }

# 6: {
#                     'start_time': "2011-05-25" ,
#                     'end_time': "2011-06-13"
#                 }

# 5: {
#                     'start_time': "2011-04-22" ,
#                     'end_time': "2011-06-01"
#                 }
appliances = ["Microwave", "Refrigerator",  "Dish Washer"] #

# %%
x_train, y_train, x_test, y_test, x_train_timestamp, x_test_timestamp, scaler_x, scaler_y, scaler_time = dataset_load(appliances, train, test)
# Out:
# /tmp/ipykernel_2158467/2465541311.py:93: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y_test).reshape(-1,).to(torch.float32)

# %%
# pd.plotting.autocorrelation_plot(pd.Series(x_train[:290].reshape(-1,)))

# %%
x_train.shape, x_train_timestamp.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# (torch.Size([24918, 1]),
#  torch.Size([24918, 1]),
#  torch.Size([15656, 1]),
#  torch.Size([24918]),
#  torch.Size([15656]))

# %%
# plt.plot(x_train_timestamp, scaler_x.inverse_transform(x_train.reshape(-1,1)))
# plt.ylabel(f"Main Power Train")
# plt.xlabel(f"Timestamp Train")

# %%
# plt.plot(x_train_timestamp, scaler_y.inverse_transform(y_train.reshape(-1,1)))
# plt.ylabel(f"Ref Power Train")
# plt.xlabel(f"Timestamp Train")

# %%
# plt.plot(x_test_timestamp, scaler_x.inverse_transform(x_test.reshape(-1,1)))

# plt.ylabel(f"Main Test")
# plt.xlabel(f"Timestamp Test")

# %%
# plt.plot(x_test_timestamp, y_test)
# plt.ylabel(f"Ref Power test")
# plt.xlabel(f"Timestamp test")

# %%
# plt.scatter( scaler_x.inverse_transform(x_train), scaler_y.inverse_transform(y_train.reshape(-1,1)))
# plt.xlabel("Main Train Power")
# plt.ylabel("Fridge Train Power")

# %%
# plt.scatter( scaler_x.inverse_transform(x_test),y_test.reshape(-1,1))
# plt.xlabel("Main test Power")
# plt.ylabel("Fridge test Power")

# %%
# x_train_full = torch.cat((x_train, x_train_timestamp), dim=1)
# x_test_full = torch.cat((x_test, x_test_timestamp), dim=1)

x_train_full = x_train
y_train = y_train
x_test_full = x_test
x_train_full.shape, x_test_full.dtype
# Out:
# (torch.Size([24918, 1]), torch.float32)

# %%
mae_arr =[]
rms_arr = []
y_pred_arr = []

batch = 512

# x_train = x_train[:4500]
# y_train = y_train[:4500]

# y_test_trans = torch.tensor(torch.tensor(scaler_x.transform(y_test.reshape(-1,1))).reshape(-1,)).contiguous().to(torch.float64)
# for i in range(1):


kernel1 = ScaleKernel(MaternKernel(nu=2.5, ard_num_dims=1, active_dims=(0))) #nu=2.5,ard_num_dims=1, active_dims=(0))
kernel2 = ScaleKernel(PeriodicKernel(ard_num_dims=1, active_dims=(1)))
kernel3 = ScaleKernel(PeriodicKernel(ard_num_dims=1, active_dims=(1)))
kernel4 = ScaleKernel(MaternKernel(nu =0.5, ard_num_dims=1, active_dims=(1)))
# kernel5 = ScaleKernel(CosineKernel(ard_num_dims=2, active_dims=(1)))

theta = { 'base_covar_module.kernels.2.kernels.0.base_kernel.period_length': torch.tensor(0.01),
      'base_covar_module.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
kernel5 = kernel2+ kernel3*kernel4
kernel = kernel1 + kernel5
inducing_points =  x_train_full[np.arange(0,x_train_full.shape[0],30)] 
#x_train_full[torch.randperm(x_train_full.shape[0])[: batch]].to("cuda")

# model = ExactGPRegressor(x_train_full.to("cuda"), y_train.to("cuda"), kernel).to("cuda")
model = SGPRegressor(x_train_full.to("cuda"), y_train.to("cuda"), kernel,
                     inducing_points).to("cuda")
# model.mll.likelihood.noise_covar.register_constraint("raw_noise", GreaterThan(1e-2))
# for param in model.parameters():
#   # print(param)
#   torch.nn.init.normal_(param, 0, 1)
# theta1 = {'likelihood.noise_covar.noise': torch.tensor(3),
#       'covar_module.base_kernel.lengthscale': torch.tensor(0.1),
#       'covar_module.outputscale': torch.tensor(5),}
loss = model.fit(lr=1e-3, n_epochs=3000,verbose=1,thetas=theta,
        random_state=0)
#   loss_arr.append(loss)
# print(loss)
plt.plot(np.asarray(loss[0]))
# plt.plot(np.asarray(test_loss[0]))
# Out:
# restart: 0, epoch: 1, iter: 1, loss: 0.8139
# restart: 0, epoch: 2, iter: 1, loss: 0.8140
# restart: 0, epoch: 3, iter: 1, loss: 0.8131
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/kernels/inducing_point_kernel.py:61: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352645774/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   inv_root = torch.triangular_solve(eye, chol)[0]
# restart: 0, epoch: 4, iter: 1, loss: 0.8125
# restart: 0, epoch: 5, iter: 1, loss: 0.8122
# restart: 0, epoch: 6, iter: 1, loss: 0.8115
# restart: 0, epoch: 7, iter: 1, loss: 0.8112
# restart: 0, epoch: 8, iter: 1, loss: 0.8109
# restart: 0, epoch: 9, iter: 1, loss: 0.8105
# restart: 0, epoch: 10, iter: 1, loss: 0.8101
# restart: 0, epoch: 11, iter: 1, loss: 0.8097
# restart: 0, epoch: 12, iter: 1, loss: 0.8093
# restart: 0, epoch: 13, iter: 1, loss: 0.8089
# restart: 0, epoch: 14, iter: 1, loss: 0.8085
# restart: 0, epoch: 15, iter: 1, loss: 0.8081
# restart: 0, epoch: 16, iter: 1, loss: 0.8078
# restart: 0, epoch: 17, iter: 1, loss: 0.8074
# restart: 0, epoch: 18, iter: 1, loss: 0.8070
# restart: 0, epoch: 19, iter: 1, loss: 0.8067
# restart: 0, epoch: 20, iter: 1, loss: 0.8064
# restart: 0, epoch: 21, iter: 1, loss: 0.8060
# restart: 0, epoch: 22, iter: 1, loss: 0.8057
# restart: 0, epoch: 23, iter: 1, loss: 0.8053
# restart: 0, epoch: 24, iter: 1, loss: 0.8049
# restart: 0, epoch: 25, iter: 1, loss: 0.8046
# restart: 0, epoch: 26, iter: 1, loss: 0.8043
# restart: 0, epoch: 27, iter: 1, loss: 0.8039
# restart: 0, epoch: 28, iter: 1, loss: 0.8036
# restart: 0, epoch: 29, iter: 1, loss: 0.8032
# restart: 0, epoch: 30, iter: 1, loss: 0.8029
# restart: 0, epoch: 31, iter: 1, loss: 0.8025
# restart: 0, epoch: 32, iter: 1, loss: 0.8022
# restart: 0, epoch: 33, iter: 1, loss: 0.8018
# restart: 0, epoch: 34, iter: 1, loss: 0.8015
# restart: 0, epoch: 35, iter: 1, loss: 0.8012
# restart: 0, epoch: 36, iter: 1, loss: 0.8008
# restart: 0, epoch: 37, iter: 1, loss: 0.8004
# restart: 0, epoch: 38, iter: 1, loss: 0.8001
# restart: 0, epoch: 39, iter: 1, loss: 0.7998
# restart: 0, epoch: 40, iter: 1, loss: 0.7994
# restart: 0, epoch: 41, iter: 1, loss: 0.7991
# restart: 0, epoch: 42, iter: 1, loss: 0.7988
# restart: 0, epoch: 43, iter: 1, loss: 0.7984
# restart: 0, epoch: 44, iter: 1, loss: 0.7981
# restart: 0, epoch: 45, iter: 1, loss: 0.7977
# restart: 0, epoch: 46, iter: 1, loss: 0.7974
# restart: 0, epoch: 47, iter: 1, loss: 0.7971
# restart: 0, epoch: 48, iter: 1, loss: 0.7967
# restart: 0, epoch: 49, iter: 1, loss: 0.7964
# restart: 0, epoch: 50, iter: 1, loss: 0.7960
# restart: 0, epoch: 51, iter: 1, loss: 0.7957
# restart: 0, epoch: 52, iter: 1, loss: 0.7954
# restart: 0, epoch: 53, iter: 1, loss: 0.7950
# restart: 0, epoch: 54, iter: 1, loss: 0.7947
# restart: 0, epoch: 55, iter: 1, loss: 0.7943
# restart: 0, epoch: 56, iter: 1, loss: 0.7940
# restart: 0, epoch: 57, iter: 1, loss: 0.7936
# restart: 0, epoch: 58, iter: 1, loss: 0.7933
# restart: 0, epoch: 59, iter: 1, loss: 0.7929
# restart: 0, epoch: 60, iter: 1, loss: 0.7926
# restart: 0, epoch: 61, iter: 1, loss: 0.7922
# restart: 0, epoch: 62, iter: 1, loss: 0.7919
# restart: 0, epoch: 63, iter: 1, loss: 0.7916
# restart: 0, epoch: 64, iter: 1, loss: 0.7912
# restart: 0, epoch: 65, iter: 1, loss: 0.7909
# restart: 0, epoch: 66, iter: 1, loss: 0.7905
# restart: 0, epoch: 67, iter: 1, loss: 0.7902
# restart: 0, epoch: 68, iter: 1, loss: 0.7898
# restart: 0, epoch: 69, iter: 1, loss: 0.7895
# restart: 0, epoch: 70, iter: 1, loss: 0.7892
# restart: 0, epoch: 71, iter: 1, loss: 0.7889
# restart: 0, epoch: 72, iter: 1, loss: 0.7885
# restart: 0, epoch: 73, iter: 1, loss: 0.7882
# restart: 0, epoch: 74, iter: 1, loss: 0.7878
# restart: 0, epoch: 75, iter: 1, loss: 0.7875
# restart: 0, epoch: 76, iter: 1, loss: 0.7872
# restart: 0, epoch: 77, iter: 1, loss: 0.7868
# restart: 0, epoch: 78, iter: 1, loss: 0.7865
# restart: 0, epoch: 79, iter: 1, loss: 0.7861
# restart: 0, epoch: 80, iter: 1, loss: 0.7858
# restart: 0, epoch: 81, iter: 1, loss: 0.7855
# restart: 0, epoch: 82, iter: 1, loss: 0.7851
# restart: 0, epoch: 83, iter: 1, loss: 0.7848
# restart: 0, epoch: 84, iter: 1, loss: 0.7845
# restart: 0, epoch: 85, iter: 1, loss: 0.7841
# restart: 0, epoch: 86, iter: 1, loss: 0.7838
# restart: 0, epoch: 87, iter: 1, loss: 0.7834
# restart: 0, epoch: 88, iter: 1, loss: 0.7831
# restart: 0, epoch: 89, iter: 1, loss: 0.7828
# restart: 0, epoch: 90, iter: 1, loss: 0.7825
# restart: 0, epoch: 91, iter: 1, loss: 0.7821
# restart: 0, epoch: 92, iter: 1, loss: 0.7818
# restart: 0, epoch: 93, iter: 1, loss: 0.7814
# restart: 0, epoch: 94, iter: 1, loss: 0.7811
# restart: 0, epoch: 95, iter: 1, loss: 0.7808
# restart: 0, epoch: 96, iter: 1, loss: 0.7804
# restart: 0, epoch: 97, iter: 1, loss: 0.7801
# restart: 0, epoch: 98, iter: 1, loss: 0.7797
# restart: 0, epoch: 99, iter: 1, loss: 0.7794
# restart: 0, epoch: 100, iter: 1, loss: 0.7791
# restart: 0, epoch: 101, iter: 1, loss: 0.7787
# restart: 0, epoch: 102, iter: 1, loss: 0.7784
# restart: 0, epoch: 103, iter: 1, loss: 0.7780
# restart: 0, epoch: 104, iter: 1, loss: 0.7777
# restart: 0, epoch: 105, iter: 1, loss: 0.7774
# restart: 0, epoch: 106, iter: 1, loss: 0.7771
# restart: 0, epoch: 107, iter: 1, loss: 0.7767
# restart: 0, epoch: 108, iter: 1, loss: 0.7764
# restart: 0, epoch: 109, iter: 1, loss: 0.7760
# restart: 0, epoch: 110, iter: 1, loss: 0.7757
# restart: 0, epoch: 111, iter: 1, loss: 0.7753
# restart: 0, epoch: 112, iter: 1, loss: 0.7750
# restart: 0, epoch: 113, iter: 1, loss: 0.7747
# restart: 0, epoch: 114, iter: 1, loss: 0.7743
# restart: 0, epoch: 115, iter: 1, loss: 0.7740
# restart: 0, epoch: 116, iter: 1, loss: 0.7737
# restart: 0, epoch: 117, iter: 1, loss: 0.7733
# restart: 0, epoch: 118, iter: 1, loss: 0.7730
# restart: 0, epoch: 119, iter: 1, loss: 0.7727
# restart: 0, epoch: 120, iter: 1, loss: 0.7723
# restart: 0, epoch: 121, iter: 1, loss: 0.7720
# restart: 0, epoch: 122, iter: 1, loss: 0.7717
# restart: 0, epoch: 123, iter: 1, loss: 0.7713
# restart: 0, epoch: 124, iter: 1, loss: 0.7710
# restart: 0, epoch: 125, iter: 1, loss: 0.7706
# restart: 0, epoch: 126, iter: 1, loss: 0.7703
# restart: 0, epoch: 127, iter: 1, loss: 0.7700
# restart: 0, epoch: 128, iter: 1, loss: 0.7696
# restart: 0, epoch: 129, iter: 1, loss: 0.7693
# restart: 0, epoch: 130, iter: 1, loss: 0.7689
# restart: 0, epoch: 131, iter: 1, loss: 0.7686
# restart: 0, epoch: 132, iter: 1, loss: 0.7683
# restart: 0, epoch: 133, iter: 1, loss: 0.7679
# restart: 0, epoch: 134, iter: 1, loss: 0.7676
# restart: 0, epoch: 135, iter: 1, loss: 0.7672
# restart: 0, epoch: 136, iter: 1, loss: 0.7669
# restart: 0, epoch: 137, iter: 1, loss: 0.7666
# restart: 0, epoch: 138, iter: 1, loss: 0.7662
# restart: 0, epoch: 139, iter: 1, loss: 0.7659
# restart: 0, epoch: 140, iter: 1, loss: 0.7655
# restart: 0, epoch: 141, iter: 1, loss: 0.7652
# restart: 0, epoch: 142, iter: 1, loss: 0.7649
# restart: 0, epoch: 143, iter: 1, loss: 0.7645
# restart: 0, epoch: 144, iter: 1, loss: 0.7642
# restart: 0, epoch: 145, iter: 1, loss: 0.7639
# restart: 0, epoch: 146, iter: 1, loss: 0.7635
# restart: 0, epoch: 147, iter: 1, loss: 0.7632
# restart: 0, epoch: 148, iter: 1, loss: 0.7628
# restart: 0, epoch: 149, iter: 1, loss: 0.7625
# restart: 0, epoch: 150, iter: 1, loss: 0.7621
# restart: 0, epoch: 151, iter: 1, loss: 0.7618
# restart: 0, epoch: 152, iter: 1, loss: 0.7615
# restart: 0, epoch: 153, iter: 1, loss: 0.7611
# restart: 0, epoch: 154, iter: 1, loss: 0.7608
# restart: 0, epoch: 155, iter: 1, loss: 0.7605
# restart: 0, epoch: 156, iter: 1, loss: 0.7602
# restart: 0, epoch: 157, iter: 1, loss: 0.7598
# restart: 0, epoch: 158, iter: 1, loss: 0.7594
# restart: 0, epoch: 159, iter: 1, loss: 0.7591
# restart: 0, epoch: 160, iter: 1, loss: 0.7588
# restart: 0, epoch: 161, iter: 1, loss: 0.7584
# restart: 0, epoch: 162, iter: 1, loss: 0.7581
# restart: 0, epoch: 163, iter: 1, loss: 0.7578
# restart: 0, epoch: 164, iter: 1, loss: 0.7574
# restart: 0, epoch: 165, iter: 1, loss: 0.7571
# restart: 0, epoch: 166, iter: 1, loss: 0.7568
# restart: 0, epoch: 167, iter: 1, loss: 0.7564
# restart: 0, epoch: 168, iter: 1, loss: 0.7561
# restart: 0, epoch: 169, iter: 1, loss: 0.7557
# restart: 0, epoch: 170, iter: 1, loss: 0.7554
# restart: 0, epoch: 171, iter: 1, loss: 0.7550
# restart: 0, epoch: 172, iter: 1, loss: 0.7547
# restart: 0, epoch: 173, iter: 1, loss: 0.7544
# restart: 0, epoch: 174, iter: 1, loss: 0.7540
# restart: 0, epoch: 175, iter: 1, loss: 0.7537
# restart: 0, epoch: 176, iter: 1, loss: 0.7533
# restart: 0, epoch: 177, iter: 1, loss: 0.7530
# restart: 0, epoch: 178, iter: 1, loss: 0.7526
# restart: 0, epoch: 179, iter: 1, loss: 0.7523
# restart: 0, epoch: 180, iter: 1, loss: 0.7520
# restart: 0, epoch: 181, iter: 1, loss: 0.7517
# restart: 0, epoch: 182, iter: 1, loss: 0.7513
# restart: 0, epoch: 183, iter: 1, loss: 0.7509
# restart: 0, epoch: 184, iter: 1, loss: 0.7506
# restart: 0, epoch: 185, iter: 1, loss: 0.7503
# restart: 0, epoch: 186, iter: 1, loss: 0.7500
# restart: 0, epoch: 187, iter: 1, loss: 0.7496
# restart: 0, epoch: 188, iter: 1, loss: 0.7493
# restart: 0, epoch: 189, iter: 1, loss: 0.7489
# restart: 0, epoch: 190, iter: 1, loss: 0.7486
# restart: 0, epoch: 191, iter: 1, loss: 0.7483
# restart: 0, epoch: 192, iter: 1, loss: 0.7479
# restart: 0, epoch: 193, iter: 1, loss: 0.7476
# restart: 0, epoch: 194, iter: 1, loss: 0.7472
# restart: 0, epoch: 195, iter: 1, loss: 0.7469
# restart: 0, epoch: 196, iter: 1, loss: 0.7466
# restart: 0, epoch: 197, iter: 1, loss: 0.7462
# restart: 0, epoch: 198, iter: 1, loss: 0.7459
# restart: 0, epoch: 199, iter: 1, loss: 0.7456
# restart: 0, epoch: 200, iter: 1, loss: 0.7453
# restart: 0, epoch: 201, iter: 1, loss: 0.7449
# restart: 0, epoch: 202, iter: 1, loss: 0.7446
# restart: 0, epoch: 203, iter: 1, loss: 0.7442
# restart: 0, epoch: 204, iter: 1, loss: 0.7438
# restart: 0, epoch: 205, iter: 1, loss: 0.7435
# restart: 0, epoch: 206, iter: 1, loss: 0.7432
# restart: 0, epoch: 207, iter: 1, loss: 0.7428
# restart: 0, epoch: 208, iter: 1, loss: 0.7425
# restart: 0, epoch: 209, iter: 1, loss: 0.7421
# restart: 0, epoch: 210, iter: 1, loss: 0.7418
# restart: 0, epoch: 211, iter: 1, loss: 0.7415
# restart: 0, epoch: 212, iter: 1, loss: 0.7411
# restart: 0, epoch: 213, iter: 1, loss: 0.7408
# restart: 0, epoch: 214, iter: 1, loss: 0.7404
# restart: 0, epoch: 215, iter: 1, loss: 0.7401
# restart: 0, epoch: 216, iter: 1, loss: 0.7397
# restart: 0, epoch: 217, iter: 1, loss: 0.7394
# restart: 0, epoch: 218, iter: 1, loss: 0.7391
# restart: 0, epoch: 219, iter: 1, loss: 0.7388
# restart: 0, epoch: 220, iter: 1, loss: 0.7384
# restart: 0, epoch: 221, iter: 1, loss: 0.7380
# restart: 0, epoch: 222, iter: 1, loss: 0.7377
# restart: 0, epoch: 223, iter: 1, loss: 0.7374
# restart: 0, epoch: 224, iter: 1, loss: 0.7370
# restart: 0, epoch: 225, iter: 1, loss: 0.7367
# restart: 0, epoch: 226, iter: 1, loss: 0.7363
# restart: 0, epoch: 227, iter: 1, loss: 0.7360
# restart: 0, epoch: 228, iter: 1, loss: 0.7356
# restart: 0, epoch: 229, iter: 1, loss: 0.7353
# restart: 0, epoch: 230, iter: 1, loss: 0.7349
# restart: 0, epoch: 231, iter: 1, loss: 0.7346
# restart: 0, epoch: 232, iter: 1, loss: 0.7343
# restart: 0, epoch: 233, iter: 1, loss: 0.7339
# restart: 0, epoch: 234, iter: 1, loss: 0.7336
# restart: 0, epoch: 235, iter: 1, loss: 0.7332
# restart: 0, epoch: 236, iter: 1, loss: 0.7329
# restart: 0, epoch: 237, iter: 1, loss: 0.7325
# restart: 0, epoch: 238, iter: 1, loss: 0.7322
# restart: 0, epoch: 239, iter: 1, loss: 0.7318
# restart: 0, epoch: 240, iter: 1, loss: 0.7315
# restart: 0, epoch: 241, iter: 1, loss: 0.7312
# restart: 0, epoch: 242, iter: 1, loss: 0.7308
# restart: 0, epoch: 243, iter: 1, loss: 0.7305
# restart: 0, epoch: 244, iter: 1, loss: 0.7301
# restart: 0, epoch: 245, iter: 1, loss: 0.7298
# restart: 0, epoch: 246, iter: 1, loss: 0.7294
# restart: 0, epoch: 247, iter: 1, loss: 0.7291
# restart: 0, epoch: 248, iter: 1, loss: 0.7288
# restart: 0, epoch: 249, iter: 1, loss: 0.7284
# restart: 0, epoch: 250, iter: 1, loss: 0.7281
# restart: 0, epoch: 251, iter: 1, loss: 0.7277
# restart: 0, epoch: 252, iter: 1, loss: 0.7274
# restart: 0, epoch: 253, iter: 1, loss: 0.7270
# restart: 0, epoch: 254, iter: 1, loss: 0.7267
# restart: 0, epoch: 255, iter: 1, loss: 0.7264
# restart: 0, epoch: 256, iter: 1, loss: 0.7261
# restart: 0, epoch: 257, iter: 1, loss: 0.7257
# restart: 0, epoch: 258, iter: 1, loss: 0.7253
# restart: 0, epoch: 259, iter: 1, loss: 0.7250
# restart: 0, epoch: 260, iter: 1, loss: 0.7247
# restart: 0, epoch: 261, iter: 1, loss: 0.7244
# restart: 0, epoch: 262, iter: 1, loss: 0.7240
# restart: 0, epoch: 263, iter: 1, loss: 0.7237
# restart: 0, epoch: 264, iter: 1, loss: 0.7233
# restart: 0, epoch: 265, iter: 1, loss: 0.7230
# restart: 0, epoch: 266, iter: 1, loss: 0.7227
# restart: 0, epoch: 267, iter: 1, loss: 0.7224
# restart: 0, epoch: 268, iter: 1, loss: 0.7220
# restart: 0, epoch: 269, iter: 1, loss: 0.7217
# restart: 0, epoch: 270, iter: 1, loss: 0.7213
# restart: 0, epoch: 271, iter: 1, loss: 0.7210
# restart: 0, epoch: 272, iter: 1, loss: 0.7206
# restart: 0, epoch: 273, iter: 1, loss: 0.7203
# restart: 0, epoch: 274, iter: 1, loss: 0.7199
# restart: 0, epoch: 275, iter: 1, loss: 0.7196
# restart: 0, epoch: 276, iter: 1, loss: 0.7192
# restart: 0, epoch: 277, iter: 1, loss: 0.7188
# restart: 0, epoch: 278, iter: 1, loss: 0.7186
# restart: 0, epoch: 279, iter: 1, loss: 0.7183
# restart: 0, epoch: 280, iter: 1, loss: 0.7179
# restart: 0, epoch: 281, iter: 1, loss: 0.7175
# restart: 0, epoch: 282, iter: 1, loss: 0.7171
# restart: 0, epoch: 283, iter: 1, loss: 0.7169
# restart: 0, epoch: 284, iter: 1, loss: 0.7165
# restart: 0, epoch: 285, iter: 1, loss: 0.7162
# restart: 0, epoch: 286, iter: 1, loss: 0.7158
# restart: 0, epoch: 287, iter: 1, loss: 0.7156
# restart: 0, epoch: 288, iter: 1, loss: 0.7152
# restart: 0, epoch: 289, iter: 1, loss: 0.7148
# restart: 0, epoch: 290, iter: 1, loss: 0.7144
# restart: 0, epoch: 291, iter: 1, loss: 0.7142
# restart: 0, epoch: 292, iter: 1, loss: 0.7138
# restart: 0, epoch: 293, iter: 1, loss: 0.7134
# restart: 0, epoch: 294, iter: 1, loss: 0.7131
# restart: 0, epoch: 295, iter: 1, loss: 0.7127
# restart: 0, epoch: 296, iter: 1, loss: 0.7124
# restart: 0, epoch: 297, iter: 1, loss: 0.7120
# restart: 0, epoch: 298, iter: 1, loss: 0.7117
# restart: 0, epoch: 299, iter: 1, loss: 0.7113
# restart: 0, epoch: 300, iter: 1, loss: 0.7111
# restart: 0, epoch: 301, iter: 1, loss: 0.7106
# restart: 0, epoch: 302, iter: 1, loss: 0.7103
# restart: 0, epoch: 303, iter: 1, loss: 0.7100
# restart: 0, epoch: 304, iter: 1, loss: 0.7097
# restart: 0, epoch: 305, iter: 1, loss: 0.7093
# restart: 0, epoch: 306, iter: 1, loss: 0.7090
# restart: 0, epoch: 307, iter: 1, loss: 0.7086
# restart: 0, epoch: 308, iter: 1, loss: 0.7083
# restart: 0, epoch: 309, iter: 1, loss: 0.7079
# restart: 0, epoch: 310, iter: 1, loss: 0.7075
# restart: 0, epoch: 311, iter: 1, loss: 0.7072
# restart: 0, epoch: 312, iter: 1, loss: 0.7069
# restart: 0, epoch: 313, iter: 1, loss: 0.7065
# restart: 0, epoch: 314, iter: 1, loss: 0.7062
# restart: 0, epoch: 315, iter: 1, loss: 0.7058
# restart: 0, epoch: 316, iter: 1, loss: 0.7055
# restart: 0, epoch: 317, iter: 1, loss: 0.7052
# restart: 0, epoch: 318, iter: 1, loss: 0.7048
# restart: 0, epoch: 319, iter: 1, loss: 0.7045
# restart: 0, epoch: 320, iter: 1, loss: 0.7041
# restart: 0, epoch: 321, iter: 1, loss: 0.7038
# restart: 0, epoch: 322, iter: 1, loss: 0.7034
# restart: 0, epoch: 323, iter: 1, loss: 0.7031
# restart: 0, epoch: 324, iter: 1, loss: 0.7027
# restart: 0, epoch: 325, iter: 1, loss: 0.7024
# restart: 0, epoch: 326, iter: 1, loss: 0.7020
# restart: 0, epoch: 327, iter: 1, loss: 0.7017
# restart: 0, epoch: 328, iter: 1, loss: 0.7013
# restart: 0, epoch: 329, iter: 1, loss: 0.7010
# restart: 0, epoch: 330, iter: 1, loss: 0.7006
# restart: 0, epoch: 331, iter: 1, loss: 0.7003
# restart: 0, epoch: 332, iter: 1, loss: 0.6999
# restart: 0, epoch: 333, iter: 1, loss: 0.6996
# restart: 0, epoch: 334, iter: 1, loss: 0.6992
# restart: 0, epoch: 335, iter: 1, loss: 0.6989
# restart: 0, epoch: 336, iter: 1, loss: 0.6985
# restart: 0, epoch: 337, iter: 1, loss: 0.6982
# restart: 0, epoch: 338, iter: 1, loss: 0.6978
# restart: 0, epoch: 339, iter: 1, loss: 0.6975
# restart: 0, epoch: 340, iter: 1, loss: 0.6972
# restart: 0, epoch: 341, iter: 1, loss: 0.6968
# restart: 0, epoch: 342, iter: 1, loss: 0.6965
# restart: 0, epoch: 343, iter: 1, loss: 0.6961
# restart: 0, epoch: 344, iter: 1, loss: 0.6958
# restart: 0, epoch: 345, iter: 1, loss: 0.6954
# restart: 0, epoch: 346, iter: 1, loss: 0.6951
# restart: 0, epoch: 347, iter: 1, loss: 0.6947
# restart: 0, epoch: 348, iter: 1, loss: 0.6944
# restart: 0, epoch: 349, iter: 1, loss: 0.6940
# restart: 0, epoch: 350, iter: 1, loss: 0.6937
# restart: 0, epoch: 351, iter: 1, loss: 0.6933
# restart: 0, epoch: 352, iter: 1, loss: 0.6930
# restart: 0, epoch: 353, iter: 1, loss: 0.6926
# restart: 0, epoch: 354, iter: 1, loss: 0.6923
# restart: 0, epoch: 355, iter: 1, loss: 0.6919
# restart: 0, epoch: 356, iter: 1, loss: 0.6916
# restart: 0, epoch: 357, iter: 1, loss: 0.6913
# restart: 0, epoch: 358, iter: 1, loss: 0.6909
# restart: 0, epoch: 359, iter: 1, loss: 0.6906
# restart: 0, epoch: 360, iter: 1, loss: 0.6902
# restart: 0, epoch: 361, iter: 1, loss: 0.6899
# restart: 0, epoch: 362, iter: 1, loss: 0.6895
# restart: 0, epoch: 363, iter: 1, loss: 0.6892
# restart: 0, epoch: 364, iter: 1, loss: 0.6888
# restart: 0, epoch: 365, iter: 1, loss: 0.6885
# restart: 0, epoch: 366, iter: 1, loss: 0.6882
# restart: 0, epoch: 367, iter: 1, loss: 0.6878
# restart: 0, epoch: 368, iter: 1, loss: 0.6875
# restart: 0, epoch: 369, iter: 1, loss: 0.6871
# restart: 0, epoch: 370, iter: 1, loss: 0.6868
# restart: 0, epoch: 371, iter: 1, loss: 0.6864
# restart: 0, epoch: 372, iter: 1, loss: 0.6861
# restart: 0, epoch: 373, iter: 1, loss: 0.6857
# restart: 0, epoch: 374, iter: 1, loss: 0.6854
# restart: 0, epoch: 375, iter: 1, loss: 0.6850
# restart: 0, epoch: 376, iter: 1, loss: 0.6847
# restart: 0, epoch: 377, iter: 1, loss: 0.6843
# restart: 0, epoch: 378, iter: 1, loss: 0.6840
# restart: 0, epoch: 379, iter: 1, loss: 0.6837
# restart: 0, epoch: 380, iter: 1, loss: 0.6833
# restart: 0, epoch: 381, iter: 1, loss: 0.6830
# restart: 0, epoch: 382, iter: 1, loss: 0.6826
# restart: 0, epoch: 383, iter: 1, loss: 0.6823
# restart: 0, epoch: 384, iter: 1, loss: 0.6819
# restart: 0, epoch: 385, iter: 1, loss: 0.6816
# restart: 0, epoch: 386, iter: 1, loss: 0.6813
# restart: 0, epoch: 387, iter: 1, loss: 0.6809
# restart: 0, epoch: 388, iter: 1, loss: 0.6806
# restart: 0, epoch: 389, iter: 1, loss: 0.6802
# restart: 0, epoch: 390, iter: 1, loss: 0.6799
# restart: 0, epoch: 391, iter: 1, loss: 0.6795
# restart: 0, epoch: 392, iter: 1, loss: 0.6792
# restart: 0, epoch: 393, iter: 1, loss: 0.6788
# restart: 0, epoch: 394, iter: 1, loss: 0.6785
# restart: 0, epoch: 395, iter: 1, loss: 0.6781
# restart: 0, epoch: 396, iter: 1, loss: 0.6778
# restart: 0, epoch: 397, iter: 1, loss: 0.6775
# restart: 0, epoch: 398, iter: 1, loss: 0.6771
# restart: 0, epoch: 399, iter: 1, loss: 0.6767
# restart: 0, epoch: 400, iter: 1, loss: 0.6764
# restart: 0, epoch: 401, iter: 1, loss: 0.6761
# restart: 0, epoch: 402, iter: 1, loss: 0.6757
# restart: 0, epoch: 403, iter: 1, loss: 0.6754
# restart: 0, epoch: 404, iter: 1, loss: 0.6750
# restart: 0, epoch: 405, iter: 1, loss: 0.6747
# restart: 0, epoch: 406, iter: 1, loss: 0.6744
# restart: 0, epoch: 407, iter: 1, loss: 0.6740
# restart: 0, epoch: 408, iter: 1, loss: 0.6737
# restart: 0, epoch: 409, iter: 1, loss: 0.6733
# restart: 0, epoch: 410, iter: 1, loss: 0.6730
# restart: 0, epoch: 411, iter: 1, loss: 0.6726
# restart: 0, epoch: 412, iter: 1, loss: 0.6723
# restart: 0, epoch: 413, iter: 1, loss: 0.6719
# restart: 0, epoch: 414, iter: 1, loss: 0.6716
# restart: 0, epoch: 415, iter: 1, loss: 0.6712
# restart: 0, epoch: 416, iter: 1, loss: 0.6709
# restart: 0, epoch: 417, iter: 1, loss: 0.6705
# restart: 0, epoch: 418, iter: 1, loss: 0.6702
# restart: 0, epoch: 419, iter: 1, loss: 0.6698
# restart: 0, epoch: 420, iter: 1, loss: 0.6695
# restart: 0, epoch: 421, iter: 1, loss: 0.6692
# restart: 0, epoch: 422, iter: 1, loss: 0.6688
# restart: 0, epoch: 423, iter: 1, loss: 0.6685
# restart: 0, epoch: 424, iter: 1, loss: 0.6681
# restart: 0, epoch: 425, iter: 1, loss: 0.6678
# restart: 0, epoch: 426, iter: 1, loss: 0.6674
# restart: 0, epoch: 427, iter: 1, loss: 0.6671
# restart: 0, epoch: 428, iter: 1, loss: 0.6667
# restart: 0, epoch: 429, iter: 1, loss: 0.6664
# restart: 0, epoch: 430, iter: 1, loss: 0.6660
# restart: 0, epoch: 431, iter: 1, loss: 0.6657
# restart: 0, epoch: 432, iter: 1, loss: 0.6653
# restart: 0, epoch: 433, iter: 1, loss: 0.6650
# restart: 0, epoch: 434, iter: 1, loss: 0.6647
# restart: 0, epoch: 435, iter: 1, loss: 0.6643
# restart: 0, epoch: 436, iter: 1, loss: 0.6640
# restart: 0, epoch: 437, iter: 1, loss: 0.6636
# restart: 0, epoch: 438, iter: 1, loss: 0.6633
# restart: 0, epoch: 439, iter: 1, loss: 0.6629
# restart: 0, epoch: 440, iter: 1, loss: 0.6626
# restart: 0, epoch: 441, iter: 1, loss: 0.6623
# restart: 0, epoch: 442, iter: 1, loss: 0.6619
# restart: 0, epoch: 443, iter: 1, loss: 0.6616
# restart: 0, epoch: 444, iter: 1, loss: 0.6612
# restart: 0, epoch: 445, iter: 1, loss: 0.6609
# restart: 0, epoch: 446, iter: 1, loss: 0.6605
# restart: 0, epoch: 447, iter: 1, loss: 0.6602
# restart: 0, epoch: 448, iter: 1, loss: 0.6598
# restart: 0, epoch: 449, iter: 1, loss: 0.6595
# restart: 0, epoch: 450, iter: 1, loss: 0.6591
# restart: 0, epoch: 451, iter: 1, loss: 0.6588
# restart: 0, epoch: 452, iter: 1, loss: 0.6584
# restart: 0, epoch: 453, iter: 1, loss: 0.6581
# restart: 0, epoch: 454, iter: 1, loss: 0.6578
# restart: 0, epoch: 455, iter: 1, loss: 0.6574
# restart: 0, epoch: 456, iter: 1, loss: 0.6571
# restart: 0, epoch: 457, iter: 1, loss: 0.6567
# restart: 0, epoch: 458, iter: 1, loss: 0.6564
# restart: 0, epoch: 459, iter: 1, loss: 0.6560
# restart: 0, epoch: 460, iter: 1, loss: 0.6557
# restart: 0, epoch: 461, iter: 1, loss: 0.6553
# restart: 0, epoch: 462, iter: 1, loss: 0.6550
# restart: 0, epoch: 463, iter: 1, loss: 0.6546
# restart: 0, epoch: 464, iter: 1, loss: 0.6543
# restart: 0, epoch: 465, iter: 1, loss: 0.6540
# restart: 0, epoch: 466, iter: 1, loss: 0.6536
# restart: 0, epoch: 467, iter: 1, loss: 0.6533
# restart: 0, epoch: 468, iter: 1, loss: 0.6529
# restart: 0, epoch: 469, iter: 1, loss: 0.6526
# restart: 0, epoch: 470, iter: 1, loss: 0.6522
# restart: 0, epoch: 471, iter: 1, loss: 0.6519
# restart: 0, epoch: 472, iter: 1, loss: 0.6515
# restart: 0, epoch: 473, iter: 1, loss: 0.6512
# restart: 0, epoch: 474, iter: 1, loss: 0.6509
# restart: 0, epoch: 475, iter: 1, loss: 0.6505
# restart: 0, epoch: 476, iter: 1, loss: 0.6502
# restart: 0, epoch: 477, iter: 1, loss: 0.6498
# restart: 0, epoch: 478, iter: 1, loss: 0.6495
# restart: 0, epoch: 479, iter: 1, loss: 0.6491
# restart: 0, epoch: 480, iter: 1, loss: 0.6488
# restart: 0, epoch: 481, iter: 1, loss: 0.6484
# restart: 0, epoch: 482, iter: 1, loss: 0.6481
# restart: 0, epoch: 483, iter: 1, loss: 0.6477
# restart: 0, epoch: 484, iter: 1, loss: 0.6474
# restart: 0, epoch: 485, iter: 1, loss: 0.6471
# restart: 0, epoch: 486, iter: 1, loss: 0.6467
# restart: 0, epoch: 487, iter: 1, loss: 0.6464
# restart: 0, epoch: 488, iter: 1, loss: 0.6460
# restart: 0, epoch: 489, iter: 1, loss: 0.6457
# restart: 0, epoch: 490, iter: 1, loss: 0.6453
# restart: 0, epoch: 491, iter: 1, loss: 0.6450
# restart: 0, epoch: 492, iter: 1, loss: 0.6447
# restart: 0, epoch: 493, iter: 1, loss: 0.6443
# restart: 0, epoch: 494, iter: 1, loss: 0.6440
# restart: 0, epoch: 495, iter: 1, loss: 0.6436
# restart: 0, epoch: 496, iter: 1, loss: 0.6433
# restart: 0, epoch: 497, iter: 1, loss: 0.6429
# restart: 0, epoch: 498, iter: 1, loss: 0.6426
# restart: 0, epoch: 499, iter: 1, loss: 0.6422
# restart: 0, epoch: 500, iter: 1, loss: 0.6419
# restart: 0, epoch: 501, iter: 1, loss: 0.6415
# restart: 0, epoch: 502, iter: 1, loss: 0.6412
# restart: 0, epoch: 503, iter: 1, loss: 0.6408
# restart: 0, epoch: 504, iter: 1, loss: 0.6405
# restart: 0, epoch: 505, iter: 1, loss: 0.6402
# restart: 0, epoch: 506, iter: 1, loss: 0.6398
# restart: 0, epoch: 507, iter: 1, loss: 0.6395
# restart: 0, epoch: 508, iter: 1, loss: 0.6391
# restart: 0, epoch: 509, iter: 1, loss: 0.6388
# restart: 0, epoch: 510, iter: 1, loss: 0.6384
# restart: 0, epoch: 511, iter: 1, loss: 0.6381
# restart: 0, epoch: 512, iter: 1, loss: 0.6377
# restart: 0, epoch: 513, iter: 1, loss: 0.6374
# restart: 0, epoch: 514, iter: 1, loss: 0.6370
# restart: 0, epoch: 515, iter: 1, loss: 0.6367
# restart: 0, epoch: 516, iter: 1, loss: 0.6364
# restart: 0, epoch: 517, iter: 1, loss: 0.6360
# restart: 0, epoch: 518, iter: 1, loss: 0.6357
# restart: 0, epoch: 519, iter: 1, loss: 0.6353
# restart: 0, epoch: 520, iter: 1, loss: 0.6350
# restart: 0, epoch: 521, iter: 1, loss: 0.6346
# restart: 0, epoch: 522, iter: 1, loss: 0.6343
# restart: 0, epoch: 523, iter: 1, loss: 0.6339
# restart: 0, epoch: 524, iter: 1, loss: 0.6336
# restart: 0, epoch: 525, iter: 1, loss: 0.6332
# restart: 0, epoch: 526, iter: 1, loss: 0.6329
# restart: 0, epoch: 527, iter: 1, loss: 0.6325
# restart: 0, epoch: 528, iter: 1, loss: 0.6322
# restart: 0, epoch: 529, iter: 1, loss: 0.6318
# restart: 0, epoch: 530, iter: 1, loss: 0.6315
# restart: 0, epoch: 531, iter: 1, loss: 0.6312
# restart: 0, epoch: 532, iter: 1, loss: 0.6308
# restart: 0, epoch: 533, iter: 1, loss: 0.6305
# restart: 0, epoch: 534, iter: 1, loss: 0.6301
# restart: 0, epoch: 535, iter: 1, loss: 0.6298
# restart: 0, epoch: 536, iter: 1, loss: 0.6294
# restart: 0, epoch: 537, iter: 1, loss: 0.6291
# restart: 0, epoch: 538, iter: 1, loss: 0.6287
# restart: 0, epoch: 539, iter: 1, loss: 0.6284
# restart: 0, epoch: 540, iter: 1, loss: 0.6280
# restart: 0, epoch: 541, iter: 1, loss: 0.6277
# restart: 0, epoch: 542, iter: 1, loss: 0.6273
# restart: 0, epoch: 543, iter: 1, loss: 0.6270
# restart: 0, epoch: 544, iter: 1, loss: 0.6267
# restart: 0, epoch: 545, iter: 1, loss: 0.6263
# restart: 0, epoch: 546, iter: 1, loss: 0.6260
# restart: 0, epoch: 547, iter: 1, loss: 0.6256
# restart: 0, epoch: 548, iter: 1, loss: 0.6253
# restart: 0, epoch: 549, iter: 1, loss: 0.6249
# restart: 0, epoch: 550, iter: 1, loss: 0.6246
# restart: 0, epoch: 551, iter: 1, loss: 0.6242
# restart: 0, epoch: 552, iter: 1, loss: 0.6239
# restart: 0, epoch: 553, iter: 1, loss: 0.6235
# restart: 0, epoch: 554, iter: 1, loss: 0.6232
# restart: 0, epoch: 555, iter: 1, loss: 0.6228
# restart: 0, epoch: 556, iter: 1, loss: 0.6225
# restart: 0, epoch: 557, iter: 1, loss: 0.6221
# restart: 0, epoch: 558, iter: 1, loss: 0.6218
# restart: 0, epoch: 559, iter: 1, loss: 0.6215
# restart: 0, epoch: 560, iter: 1, loss: 0.6211
# restart: 0, epoch: 561, iter: 1, loss: 0.6208
# restart: 0, epoch: 562, iter: 1, loss: 0.6204
# restart: 0, epoch: 563, iter: 1, loss: 0.6201
# restart: 0, epoch: 564, iter: 1, loss: 0.6197
# restart: 0, epoch: 565, iter: 1, loss: 0.6194
# restart: 0, epoch: 566, iter: 1, loss: 0.6190
# restart: 0, epoch: 567, iter: 1, loss: 0.6187
# restart: 0, epoch: 568, iter: 1, loss: 0.6183
# restart: 0, epoch: 569, iter: 1, loss: 0.6180
# restart: 0, epoch: 570, iter: 1, loss: 0.6176
# restart: 0, epoch: 571, iter: 1, loss: 0.6173
# restart: 0, epoch: 572, iter: 1, loss: 0.6170
# restart: 0, epoch: 573, iter: 1, loss: 0.6166
# restart: 0, epoch: 574, iter: 1, loss: 0.6163
# restart: 0, epoch: 575, iter: 1, loss: 0.6159
# restart: 0, epoch: 576, iter: 1, loss: 0.6156
# restart: 0, epoch: 577, iter: 1, loss: 0.6152
# restart: 0, epoch: 578, iter: 1, loss: 0.6149
# restart: 0, epoch: 579, iter: 1, loss: 0.6145
# restart: 0, epoch: 580, iter: 1, loss: 0.6142
# restart: 0, epoch: 581, iter: 1, loss: 0.6138
# restart: 0, epoch: 582, iter: 1, loss: 0.6135
# restart: 0, epoch: 583, iter: 1, loss: 0.6132
# restart: 0, epoch: 584, iter: 1, loss: 0.6128
# restart: 0, epoch: 585, iter: 1, loss: 0.6125
# restart: 0, epoch: 586, iter: 1, loss: 0.6121
# restart: 0, epoch: 587, iter: 1, loss: 0.6118
# restart: 0, epoch: 588, iter: 1, loss: 0.6114
# restart: 0, epoch: 589, iter: 1, loss: 0.6111
# restart: 0, epoch: 590, iter: 1, loss: 0.6107
# restart: 0, epoch: 591, iter: 1, loss: 0.6104
# restart: 0, epoch: 592, iter: 1, loss: 0.6100
# restart: 0, epoch: 593, iter: 1, loss: 0.6097
# restart: 0, epoch: 594, iter: 1, loss: 0.6094
# restart: 0, epoch: 595, iter: 1, loss: 0.6090
# restart: 0, epoch: 596, iter: 1, loss: 0.6087
# restart: 0, epoch: 597, iter: 1, loss: 0.6083
# restart: 0, epoch: 598, iter: 1, loss: 0.6080
# restart: 0, epoch: 599, iter: 1, loss: 0.6076
# restart: 0, epoch: 600, iter: 1, loss: 0.6073
# restart: 0, epoch: 601, iter: 1, loss: 0.6069
# restart: 0, epoch: 602, iter: 1, loss: 0.6066
# restart: 0, epoch: 603, iter: 1, loss: 0.6062
# restart: 0, epoch: 604, iter: 1, loss: 0.6059
# restart: 0, epoch: 605, iter: 1, loss: 0.6055
# restart: 0, epoch: 606, iter: 1, loss: 0.6052
# restart: 0, epoch: 607, iter: 1, loss: 0.6049
# restart: 0, epoch: 608, iter: 1, loss: 0.6045
# restart: 0, epoch: 609, iter: 1, loss: 0.6042
# restart: 0, epoch: 610, iter: 1, loss: 0.6038
# restart: 0, epoch: 611, iter: 1, loss: 0.6035
# restart: 0, epoch: 612, iter: 1, loss: 0.6031
# restart: 0, epoch: 613, iter: 1, loss: 0.6028
# restart: 0, epoch: 614, iter: 1, loss: 0.6024
# restart: 0, epoch: 615, iter: 1, loss: 0.6021
# restart: 0, epoch: 616, iter: 1, loss: 0.6017
# restart: 0, epoch: 617, iter: 1, loss: 0.6014
# restart: 0, epoch: 618, iter: 1, loss: 0.6010
# restart: 0, epoch: 619, iter: 1, loss: 0.6007
# restart: 0, epoch: 620, iter: 1, loss: 0.6004
# restart: 0, epoch: 621, iter: 1, loss: 0.6000
# restart: 0, epoch: 622, iter: 1, loss: 0.5997
# restart: 0, epoch: 623, iter: 1, loss: 0.5993
# restart: 0, epoch: 624, iter: 1, loss: 0.5990
# restart: 0, epoch: 625, iter: 1, loss: 0.5986
# restart: 0, epoch: 626, iter: 1, loss: 0.5983
# restart: 0, epoch: 627, iter: 1, loss: 0.5979
# restart: 0, epoch: 628, iter: 1, loss: 0.5976
# restart: 0, epoch: 629, iter: 1, loss: 0.5973
# restart: 0, epoch: 630, iter: 1, loss: 0.5969
# restart: 0, epoch: 631, iter: 1, loss: 0.5966
# restart: 0, epoch: 632, iter: 1, loss: 0.5962
# restart: 0, epoch: 633, iter: 1, loss: 0.5959
# restart: 0, epoch: 634, iter: 1, loss: 0.5955
# restart: 0, epoch: 635, iter: 1, loss: 0.5952
# restart: 0, epoch: 636, iter: 1, loss: 0.5948
# restart: 0, epoch: 637, iter: 1, loss: 0.5945
# restart: 0, epoch: 638, iter: 1, loss: 0.5941
# restart: 0, epoch: 639, iter: 1, loss: 0.5938
# restart: 0, epoch: 640, iter: 1, loss: 0.5934
# restart: 0, epoch: 641, iter: 1, loss: 0.5931
# restart: 0, epoch: 642, iter: 1, loss: 0.5928
# restart: 0, epoch: 643, iter: 1, loss: 0.5924
# restart: 0, epoch: 644, iter: 1, loss: 0.5921
# restart: 0, epoch: 645, iter: 1, loss: 0.5917
# restart: 0, epoch: 646, iter: 1, loss: 0.5914
# restart: 0, epoch: 647, iter: 1, loss: 0.5910
# restart: 0, epoch: 648, iter: 1, loss: 0.5907
# restart: 0, epoch: 649, iter: 1, loss: 0.5904
# restart: 0, epoch: 650, iter: 1, loss: 0.5900
# restart: 0, epoch: 651, iter: 1, loss: 0.5897
# restart: 0, epoch: 652, iter: 1, loss: 0.5893
# restart: 0, epoch: 653, iter: 1, loss: 0.5890
# restart: 0, epoch: 654, iter: 1, loss: 0.5886
# restart: 0, epoch: 655, iter: 1, loss: 0.5883
# restart: 0, epoch: 656, iter: 1, loss: 0.5879
# restart: 0, epoch: 657, iter: 1, loss: 0.5876
# restart: 0, epoch: 658, iter: 1, loss: 0.5872
# restart: 0, epoch: 659, iter: 1, loss: 0.5869
# restart: 0, epoch: 660, iter: 1, loss: 0.5866
# restart: 0, epoch: 661, iter: 1, loss: 0.5862
# restart: 0, epoch: 662, iter: 1, loss: 0.5859
# restart: 0, epoch: 663, iter: 1, loss: 0.5855
# restart: 0, epoch: 664, iter: 1, loss: 0.5852
# restart: 0, epoch: 665, iter: 1, loss: 0.5848
# restart: 0, epoch: 666, iter: 1, loss: 0.5845
# restart: 0, epoch: 667, iter: 1, loss: 0.5841
# restart: 0, epoch: 668, iter: 1, loss: 0.5838
# restart: 0, epoch: 669, iter: 1, loss: 0.5834
# restart: 0, epoch: 670, iter: 1, loss: 0.5831
# restart: 0, epoch: 671, iter: 1, loss: 0.5827
# restart: 0, epoch: 672, iter: 1, loss: 0.5824
# restart: 0, epoch: 673, iter: 1, loss: 0.5821
# restart: 0, epoch: 674, iter: 1, loss: 0.5817
# restart: 0, epoch: 675, iter: 1, loss: 0.5814
# restart: 0, epoch: 676, iter: 1, loss: 0.5810
# restart: 0, epoch: 677, iter: 1, loss: 0.5807
# restart: 0, epoch: 678, iter: 1, loss: 0.5803
# restart: 0, epoch: 679, iter: 1, loss: 0.5800
# restart: 0, epoch: 680, iter: 1, loss: 0.5797
# restart: 0, epoch: 681, iter: 1, loss: 0.5793
# restart: 0, epoch: 682, iter: 1, loss: 0.5790
# restart: 0, epoch: 683, iter: 1, loss: 0.5786
# restart: 0, epoch: 684, iter: 1, loss: 0.5783
# restart: 0, epoch: 685, iter: 1, loss: 0.5779
# restart: 0, epoch: 686, iter: 1, loss: 0.5776
# restart: 0, epoch: 687, iter: 1, loss: 0.5772
# restart: 0, epoch: 688, iter: 1, loss: 0.5769
# restart: 0, epoch: 689, iter: 1, loss: 0.5765
# restart: 0, epoch: 690, iter: 1, loss: 0.5762
# restart: 0, epoch: 691, iter: 1, loss: 0.5759
# restart: 0, epoch: 692, iter: 1, loss: 0.5755
# restart: 0, epoch: 693, iter: 1, loss: 0.5752
# restart: 0, epoch: 694, iter: 1, loss: 0.5748
# restart: 0, epoch: 695, iter: 1, loss: 0.5745
# restart: 0, epoch: 696, iter: 1, loss: 0.5741
# restart: 0, epoch: 697, iter: 1, loss: 0.5738
# restart: 0, epoch: 698, iter: 1, loss: 0.5734
# restart: 0, epoch: 699, iter: 1, loss: 0.5731
# restart: 0, epoch: 700, iter: 1, loss: 0.5728
# restart: 0, epoch: 701, iter: 1, loss: 0.5724
# restart: 0, epoch: 702, iter: 1, loss: 0.5721
# restart: 0, epoch: 703, iter: 1, loss: 0.5717
# restart: 0, epoch: 704, iter: 1, loss: 0.5714
# restart: 0, epoch: 705, iter: 1, loss: 0.5710
# restart: 0, epoch: 706, iter: 1, loss: 0.5707
# restart: 0, epoch: 707, iter: 1, loss: 0.5703
# restart: 0, epoch: 708, iter: 1, loss: 0.5700
# restart: 0, epoch: 709, iter: 1, loss: 0.5696
# restart: 0, epoch: 710, iter: 1, loss: 0.5693
# restart: 0, epoch: 711, iter: 1, loss: 0.5690
# restart: 0, epoch: 712, iter: 1, loss: 0.5686
# restart: 0, epoch: 713, iter: 1, loss: 0.5683
# restart: 0, epoch: 714, iter: 1, loss: 0.5679
# restart: 0, epoch: 715, iter: 1, loss: 0.5676
# restart: 0, epoch: 716, iter: 1, loss: 0.5672
# restart: 0, epoch: 717, iter: 1, loss: 0.5669
# restart: 0, epoch: 718, iter: 1, loss: 0.5665
# restart: 0, epoch: 719, iter: 1, loss: 0.5662
# restart: 0, epoch: 720, iter: 1, loss: 0.5658
# restart: 0, epoch: 721, iter: 1, loss: 0.5655
# restart: 0, epoch: 722, iter: 1, loss: 0.5652
# restart: 0, epoch: 723, iter: 1, loss: 0.5648
# restart: 0, epoch: 724, iter: 1, loss: 0.5645
# restart: 0, epoch: 725, iter: 1, loss: 0.5641
# restart: 0, epoch: 726, iter: 1, loss: 0.5638
# restart: 0, epoch: 727, iter: 1, loss: 0.5634
# restart: 0, epoch: 728, iter: 1, loss: 0.5631
# restart: 0, epoch: 729, iter: 1, loss: 0.5627
# restart: 0, epoch: 730, iter: 1, loss: 0.5624
# restart: 0, epoch: 731, iter: 1, loss: 0.5620
# restart: 0, epoch: 732, iter: 1, loss: 0.5617
# restart: 0, epoch: 733, iter: 1, loss: 0.5614
# restart: 0, epoch: 734, iter: 1, loss: 0.5610
# restart: 0, epoch: 735, iter: 1, loss: 0.5607
# restart: 0, epoch: 736, iter: 1, loss: 0.5604
# restart: 0, epoch: 737, iter: 1, loss: 0.5600
# restart: 0, epoch: 738, iter: 1, loss: 0.5596
# restart: 0, epoch: 739, iter: 1, loss: 0.5593
# restart: 0, epoch: 740, iter: 1, loss: 0.5590
# restart: 0, epoch: 741, iter: 1, loss: 0.5586
# restart: 0, epoch: 742, iter: 1, loss: 0.5583
# restart: 0, epoch: 743, iter: 1, loss: 0.5579
# restart: 0, epoch: 744, iter: 1, loss: 0.5576
# restart: 0, epoch: 745, iter: 1, loss: 0.5572
# restart: 0, epoch: 746, iter: 1, loss: 0.5569
# restart: 0, epoch: 747, iter: 1, loss: 0.5565
# restart: 0, epoch: 748, iter: 1, loss: 0.5562
# restart: 0, epoch: 749, iter: 1, loss: 0.5559
# restart: 0, epoch: 750, iter: 1, loss: 0.5555
# restart: 0, epoch: 751, iter: 1, loss: 0.5552
# restart: 0, epoch: 752, iter: 1, loss: 0.5548
# restart: 0, epoch: 753, iter: 1, loss: 0.5545
# restart: 0, epoch: 754, iter: 1, loss: 0.5541
# restart: 0, epoch: 755, iter: 1, loss: 0.5538
# restart: 0, epoch: 756, iter: 1, loss: 0.5534
# restart: 0, epoch: 757, iter: 1, loss: 0.5531
# restart: 0, epoch: 758, iter: 1, loss: 0.5528
# restart: 0, epoch: 759, iter: 1, loss: 0.5524
# restart: 0, epoch: 760, iter: 1, loss: 0.5521
# restart: 0, epoch: 761, iter: 1, loss: 0.5517
# restart: 0, epoch: 762, iter: 1, loss: 0.5514
# restart: 0, epoch: 763, iter: 1, loss: 0.5510
# restart: 0, epoch: 764, iter: 1, loss: 0.5507
# restart: 0, epoch: 765, iter: 1, loss: 0.5504
# restart: 0, epoch: 766, iter: 1, loss: 0.5500
# restart: 0, epoch: 767, iter: 1, loss: 0.5497
# restart: 0, epoch: 768, iter: 1, loss: 0.5493
# restart: 0, epoch: 769, iter: 1, loss: 0.5490
# restart: 0, epoch: 770, iter: 1, loss: 0.5487
# restart: 0, epoch: 771, iter: 1, loss: 0.5483
# restart: 0, epoch: 772, iter: 1, loss: 0.5480
# restart: 0, epoch: 773, iter: 1, loss: 0.5476
# restart: 0, epoch: 774, iter: 1, loss: 0.5473
# restart: 0, epoch: 775, iter: 1, loss: 0.5469
# restart: 0, epoch: 776, iter: 1, loss: 0.5466
# restart: 0, epoch: 777, iter: 1, loss: 0.5462
# restart: 0, epoch: 778, iter: 1, loss: 0.5459
# restart: 0, epoch: 779, iter: 1, loss: 0.5456
# restart: 0, epoch: 780, iter: 1, loss: 0.5452
# restart: 0, epoch: 781, iter: 1, loss: 0.5450
# restart: 0, epoch: 782, iter: 1, loss: 0.5446
# restart: 0, epoch: 783, iter: 1, loss: 0.5443
# restart: 0, epoch: 784, iter: 1, loss: 0.5441
# restart: 0, epoch: 785, iter: 1, loss: 0.5436
# restart: 0, epoch: 786, iter: 1, loss: 0.5433
# restart: 0, epoch: 787, iter: 1, loss: 0.5429
# restart: 0, epoch: 788, iter: 1, loss: 0.5426
# restart: 0, epoch: 789, iter: 1, loss: 0.5423
# restart: 0, epoch: 790, iter: 1, loss: 0.5420
# restart: 0, epoch: 791, iter: 1, loss: 0.5419
# restart: 0, epoch: 792, iter: 1, loss: 0.5415
# restart: 0, epoch: 793, iter: 1, loss: 0.5413
# restart: 0, epoch: 794, iter: 1, loss: 0.5409
# restart: 0, epoch: 795, iter: 1, loss: 0.5406
# restart: 0, epoch: 796, iter: 1, loss: 0.5401
# restart: 0, epoch: 797, iter: 1, loss: 0.5398
# restart: 0, epoch: 798, iter: 1, loss: 0.5397
# restart: 0, epoch: 799, iter: 1, loss: 0.5391
# restart: 0, epoch: 800, iter: 1, loss: 0.5388
# restart: 0, epoch: 801, iter: 1, loss: 0.5387
# restart: 0, epoch: 802, iter: 1, loss: 0.5381
# restart: 0, epoch: 803, iter: 1, loss: 0.5376
# restart: 0, epoch: 804, iter: 1, loss: 0.5376
# restart: 0, epoch: 805, iter: 1, loss: 0.5374
# restart: 0, epoch: 806, iter: 1, loss: 0.5368
# restart: 0, epoch: 807, iter: 1, loss: 0.5365
# restart: 0, epoch: 808, iter: 1, loss: 0.5362
# restart: 0, epoch: 809, iter: 1, loss: 0.5359
# restart: 0, epoch: 810, iter: 1, loss: 0.5354
# restart: 0, epoch: 811, iter: 1, loss: 0.5352
# restart: 0, epoch: 812, iter: 1, loss: 0.5349
# restart: 0, epoch: 813, iter: 1, loss: 0.5342
# restart: 0, epoch: 814, iter: 1, loss: 0.5340
# restart: 0, epoch: 815, iter: 1, loss: 0.5337
# restart: 0, epoch: 816, iter: 1, loss: 0.5334
# restart: 0, epoch: 817, iter: 1, loss: 0.5330
# restart: 0, epoch: 818, iter: 1, loss: 0.5327
# restart: 0, epoch: 819, iter: 1, loss: 0.5323
# restart: 0, epoch: 820, iter: 1, loss: 0.5320
# restart: 0, epoch: 821, iter: 1, loss: 0.5317
# restart: 0, epoch: 822, iter: 1, loss: 0.5312
# restart: 0, epoch: 823, iter: 1, loss: 0.5309
# restart: 0, epoch: 824, iter: 1, loss: 0.5306
# restart: 0, epoch: 825, iter: 1, loss: 0.5302
# restart: 0, epoch: 826, iter: 1, loss: 0.5298
# restart: 0, epoch: 827, iter: 1, loss: 0.5295
# restart: 0, epoch: 828, iter: 1, loss: 0.5292
# restart: 0, epoch: 829, iter: 1, loss: 0.5289
# restart: 0, epoch: 830, iter: 1, loss: 0.5285
# restart: 0, epoch: 831, iter: 1, loss: 0.5279
# restart: 0, epoch: 832, iter: 1, loss: 0.5277
# restart: 0, epoch: 833, iter: 1, loss: 0.5274
# restart: 0, epoch: 834, iter: 1, loss: 0.5270
# restart: 0, epoch: 835, iter: 1, loss: 0.5267
# restart: 0, epoch: 836, iter: 1, loss: 0.5263
# restart: 0, epoch: 837, iter: 1, loss: 0.5260
# restart: 0, epoch: 838, iter: 1, loss: 0.5257
# restart: 0, epoch: 839, iter: 1, loss: 0.5253
# restart: 0, epoch: 840, iter: 1, loss: 0.5249
# restart: 0, epoch: 841, iter: 1, loss: 0.5247
# restart: 0, epoch: 842, iter: 1, loss: 0.5243
# restart: 0, epoch: 843, iter: 1, loss: 0.5239
# restart: 0, epoch: 844, iter: 1, loss: 0.5236
# restart: 0, epoch: 845, iter: 1, loss: 0.5233
# restart: 0, epoch: 846, iter: 1, loss: 0.5229
# restart: 0, epoch: 847, iter: 1, loss: 0.5225
# restart: 0, epoch: 848, iter: 1, loss: 0.5222
# restart: 0, epoch: 849, iter: 1, loss: 0.5219
# restart: 0, epoch: 850, iter: 1, loss: 0.5215
# restart: 0, epoch: 851, iter: 1, loss: 0.5211
# restart: 0, epoch: 852, iter: 1, loss: 0.5209
# restart: 0, epoch: 853, iter: 1, loss: 0.5206
# restart: 0, epoch: 854, iter: 1, loss: 0.5205
# restart: 0, epoch: 855, iter: 1, loss: 0.5199
# restart: 0, epoch: 856, iter: 1, loss: 0.5198
# restart: 0, epoch: 857, iter: 1, loss: 0.5194
# restart: 0, epoch: 858, iter: 1, loss: 0.5189
# restart: 0, epoch: 859, iter: 1, loss: 0.5190
# restart: 0, epoch: 860, iter: 1, loss: 0.5184
# restart: 0, epoch: 861, iter: 1, loss: 0.5181
# restart: 0, epoch: 862, iter: 1, loss: 0.5177
# restart: 0, epoch: 863, iter: 1, loss: 0.5174
# restart: 0, epoch: 864, iter: 1, loss: 0.5170
# restart: 0, epoch: 865, iter: 1, loss: 0.5166
# restart: 0, epoch: 866, iter: 1, loss: 0.5164
# restart: 0, epoch: 867, iter: 1, loss: 0.5160
# restart: 0, epoch: 868, iter: 1, loss: 0.5155
# restart: 0, epoch: 869, iter: 1, loss: 0.5153
# restart: 0, epoch: 870, iter: 1, loss: 0.5149
# restart: 0, epoch: 871, iter: 1, loss: 0.5148
# restart: 0, epoch: 872, iter: 1, loss: 0.5147
# restart: 0, epoch: 873, iter: 1, loss: 0.5139
# restart: 0, epoch: 874, iter: 1, loss: 0.5135
# restart: 0, epoch: 875, iter: 1, loss: 0.5132
# restart: 0, epoch: 876, iter: 1, loss: 0.5128
# restart: 0, epoch: 877, iter: 1, loss: 0.5124
# restart: 0, epoch: 878, iter: 1, loss: 0.5120
# restart: 0, epoch: 879, iter: 1, loss: 0.5116
# restart: 0, epoch: 880, iter: 1, loss: 0.5113
# restart: 0, epoch: 881, iter: 1, loss: 0.5109
# restart: 0, epoch: 882, iter: 1, loss: 0.5105
# restart: 0, epoch: 883, iter: 1, loss: 0.5102
# restart: 0, epoch: 884, iter: 1, loss: 0.5100
# restart: 0, epoch: 885, iter: 1, loss: 0.5096
# restart: 0, epoch: 886, iter: 1, loss: 0.5091
# restart: 0, epoch: 887, iter: 1, loss: 0.5088
# restart: 0, epoch: 888, iter: 1, loss: 0.5084
# restart: 0, epoch: 889, iter: 1, loss: 0.5080
# restart: 0, epoch: 890, iter: 1, loss: 0.5081
# restart: 0, epoch: 891, iter: 1, loss: 0.5074
# restart: 0, epoch: 892, iter: 1, loss: 0.5071
# restart: 0, epoch: 893, iter: 1, loss: 0.5073
# restart: 0, epoch: 894, iter: 1, loss: 0.5066
# restart: 0, epoch: 895, iter: 1, loss: 0.5063
# restart: 0, epoch: 896, iter: 1, loss: 0.5060
# restart: 0, epoch: 897, iter: 1, loss: 0.5054
# restart: 0, epoch: 898, iter: 1, loss: 0.5050
# restart: 0, epoch: 899, iter: 1, loss: 0.5047
# restart: 0, epoch: 900, iter: 1, loss: 0.5043
# restart: 0, epoch: 901, iter: 1, loss: 0.5039
# restart: 0, epoch: 902, iter: 1, loss: 0.5036
# restart: 0, epoch: 903, iter: 1, loss: 0.5033
# restart: 0, epoch: 904, iter: 1, loss: 0.5029
# restart: 0, epoch: 905, iter: 1, loss: 0.5026
# restart: 0, epoch: 906, iter: 1, loss: 0.5024
# restart: 0, epoch: 907, iter: 1, loss: 0.5022
# restart: 0, epoch: 908, iter: 1, loss: 0.5017
# restart: 0, epoch: 909, iter: 1, loss: 0.5012
# restart: 0, epoch: 910, iter: 1, loss: 0.5009
# restart: 0, epoch: 911, iter: 1, loss: 0.5006
# restart: 0, epoch: 912, iter: 1, loss: 0.5002
# restart: 0, epoch: 913, iter: 1, loss: 0.5002
# restart: 0, epoch: 914, iter: 1, loss: 0.5000
# restart: 0, epoch: 915, iter: 1, loss: 0.4996
# restart: 0, epoch: 916, iter: 1, loss: 0.4989
# restart: 0, epoch: 917, iter: 1, loss: 0.4988
# restart: 0, epoch: 918, iter: 1, loss: 0.4984
# restart: 0, epoch: 919, iter: 1, loss: 0.4980
# restart: 0, epoch: 920, iter: 1, loss: 0.4978
# restart: 0, epoch: 921, iter: 1, loss: 0.4972
# restart: 0, epoch: 922, iter: 1, loss: 0.4969
# restart: 0, epoch: 923, iter: 1, loss: 0.4965
# restart: 0, epoch: 924, iter: 1, loss: 0.4963
# restart: 0, epoch: 925, iter: 1, loss: 0.4961
# restart: 0, epoch: 926, iter: 1, loss: 0.4957
# restart: 0, epoch: 927, iter: 1, loss: 0.4953
# restart: 0, epoch: 928, iter: 1, loss: 0.4947
# restart: 0, epoch: 929, iter: 1, loss: 0.4943
# restart: 0, epoch: 930, iter: 1, loss: 0.4940
# restart: 0, epoch: 931, iter: 1, loss: 0.4939
# restart: 0, epoch: 932, iter: 1, loss: 0.4936
# restart: 0, epoch: 933, iter: 1, loss: 0.4931
# restart: 0, epoch: 934, iter: 1, loss: 0.4926
# restart: 0, epoch: 935, iter: 1, loss: 0.4922
# restart: 0, epoch: 936, iter: 1, loss: 0.4920
# restart: 0, epoch: 937, iter: 1, loss: 0.4918
# restart: 0, epoch: 938, iter: 1, loss: 0.4915
# restart: 0, epoch: 939, iter: 1, loss: 0.4911
# restart: 0, epoch: 940, iter: 1, loss: 0.4907
# restart: 0, epoch: 941, iter: 1, loss: 0.4903
# restart: 0, epoch: 942, iter: 1, loss: 0.4899
# restart: 0, epoch: 943, iter: 1, loss: 0.4895
# restart: 0, epoch: 944, iter: 1, loss: 0.4892
# restart: 0, epoch: 945, iter: 1, loss: 0.4888
# restart: 0, epoch: 946, iter: 1, loss: 0.4884
# restart: 0, epoch: 947, iter: 1, loss: 0.4881
# restart: 0, epoch: 948, iter: 1, loss: 0.4878
# restart: 0, epoch: 949, iter: 1, loss: 0.4874
# restart: 0, epoch: 950, iter: 1, loss: 0.4870
# restart: 0, epoch: 951, iter: 1, loss: 0.4866
# restart: 0, epoch: 952, iter: 1, loss: 0.4863
# restart: 0, epoch: 953, iter: 1, loss: 0.4859
# restart: 0, epoch: 954, iter: 1, loss: 0.4856
# restart: 0, epoch: 955, iter: 1, loss: 0.4852
# restart: 0, epoch: 956, iter: 1, loss: 0.4849
# restart: 0, epoch: 957, iter: 1, loss: 0.4846
# restart: 0, epoch: 958, iter: 1, loss: 0.4842
# restart: 0, epoch: 959, iter: 1, loss: 0.4839
# restart: 0, epoch: 960, iter: 1, loss: 0.4835
# restart: 0, epoch: 961, iter: 1, loss: 0.4832
# restart: 0, epoch: 962, iter: 1, loss: 0.4828
# restart: 0, epoch: 963, iter: 1, loss: 0.4825
# restart: 0, epoch: 964, iter: 1, loss: 0.4821
# restart: 0, epoch: 965, iter: 1, loss: 0.4818
# restart: 0, epoch: 966, iter: 1, loss: 0.4814
# restart: 0, epoch: 967, iter: 1, loss: 0.4811
# restart: 0, epoch: 968, iter: 1, loss: 0.4807
# restart: 0, epoch: 969, iter: 1, loss: 0.4804
# restart: 0, epoch: 970, iter: 1, loss: 0.4801
# restart: 0, epoch: 971, iter: 1, loss: 0.4797
# restart: 0, epoch: 972, iter: 1, loss: 0.4793
# restart: 0, epoch: 973, iter: 1, loss: 0.4790
# restart: 0, epoch: 974, iter: 1, loss: 0.4787
# restart: 0, epoch: 975, iter: 1, loss: 0.4783
# restart: 0, epoch: 976, iter: 1, loss: 0.4780
# restart: 0, epoch: 977, iter: 1, loss: 0.4776
# restart: 0, epoch: 978, iter: 1, loss: 0.4773
# restart: 0, epoch: 979, iter: 1, loss: 0.4770
# restart: 0, epoch: 980, iter: 1, loss: 0.4766
# restart: 0, epoch: 981, iter: 1, loss: 0.4762
# restart: 0, epoch: 982, iter: 1, loss: 0.4759
# restart: 0, epoch: 983, iter: 1, loss: 0.4756
# restart: 0, epoch: 984, iter: 1, loss: 0.4752
# restart: 0, epoch: 985, iter: 1, loss: 0.4749
# restart: 0, epoch: 986, iter: 1, loss: 0.4745
# restart: 0, epoch: 987, iter: 1, loss: 0.4742
# restart: 0, epoch: 988, iter: 1, loss: 0.4738
# restart: 0, epoch: 989, iter: 1, loss: 0.4735
# restart: 0, epoch: 990, iter: 1, loss: 0.4731
# restart: 0, epoch: 991, iter: 1, loss: 0.4728
# restart: 0, epoch: 992, iter: 1, loss: 0.4724
# restart: 0, epoch: 993, iter: 1, loss: 0.4721
# restart: 0, epoch: 994, iter: 1, loss: 0.4718
# restart: 0, epoch: 995, iter: 1, loss: 0.4714
# restart: 0, epoch: 996, iter: 1, loss: 0.4711
# restart: 0, epoch: 997, iter: 1, loss: 0.4709
# restart: 0, epoch: 998, iter: 1, loss: 0.4704
# restart: 0, epoch: 999, iter: 1, loss: 0.4701
# restart: 0, epoch: 1000, iter: 1, loss: 0.4697
# restart: 0, epoch: 1001, iter: 1, loss: 0.4694
# restart: 0, epoch: 1002, iter: 1, loss: 0.4691
# restart: 0, epoch: 1003, iter: 1, loss: 0.4688
# restart: 0, epoch: 1004, iter: 1, loss: 0.4684
# restart: 0, epoch: 1005, iter: 1, loss: 0.4681
# restart: 0, epoch: 1006, iter: 1, loss: 0.4677
# restart: 0, epoch: 1007, iter: 1, loss: 0.4674
# restart: 0, epoch: 1008, iter: 1, loss: 0.4670
# restart: 0, epoch: 1009, iter: 1, loss: 0.4667
# restart: 0, epoch: 1010, iter: 1, loss: 0.4663
# restart: 0, epoch: 1011, iter: 1, loss: 0.4660
# restart: 0, epoch: 1012, iter: 1, loss: 0.4656
# restart: 0, epoch: 1013, iter: 1, loss: 0.4653
# restart: 0, epoch: 1014, iter: 1, loss: 0.4650
# restart: 0, epoch: 1015, iter: 1, loss: 0.4646
# restart: 0, epoch: 1016, iter: 1, loss: 0.4643
# restart: 0, epoch: 1017, iter: 1, loss: 0.4639
# restart: 0, epoch: 1018, iter: 1, loss: 0.4636
# restart: 0, epoch: 1019, iter: 1, loss: 0.4632
# restart: 0, epoch: 1020, iter: 1, loss: 0.4629
# restart: 0, epoch: 1021, iter: 1, loss: 0.4625
# restart: 0, epoch: 1022, iter: 1, loss: 0.4621
# restart: 0, epoch: 1023, iter: 1, loss: 0.4618
# restart: 0, epoch: 1024, iter: 1, loss: 0.4615
# restart: 0, epoch: 1025, iter: 1, loss: 0.4611
# restart: 0, epoch: 1026, iter: 1, loss: 0.4608
# restart: 0, epoch: 1027, iter: 1, loss: 0.4605
# restart: 0, epoch: 1028, iter: 1, loss: 0.4601
# restart: 0, epoch: 1029, iter: 1, loss: 0.4598
# restart: 0, epoch: 1030, iter: 1, loss: 0.4595
# restart: 0, epoch: 1031, iter: 1, loss: 0.4591
# ...
# restart: 0, epoch: 2661, iter: 1, loss: 0.0384
# restart: 0, epoch: 2662, iter: 1, loss: 0.0381
# restart: 0, epoch: 2663, iter: 1, loss: 0.0379
# restart: 0, epoch: 2664, iter: 1, loss: 0.0379
# restart: 0, epoch: 2665, iter: 1, loss: 0.0379
# restart: 0, epoch: 2666, iter: 1, loss: 0.0376
# restart: 0, epoch: 2667, iter: 1, loss: 0.0374
# restart: 0, epoch: 2668, iter: 1, loss: 0.0373
# restart: 0, epoch: 2669, iter: 1, loss: 0.0370
# restart: 0, epoch: 2670, iter: 1, loss: 0.0367
# restart: 0, epoch: 2671, iter: 1, loss: 0.0368
# restart: 0, epoch: 2672, iter: 1, loss: 0.0369
# restart: 0, epoch: 2673, iter: 1, loss: 0.0372
# restart: 0, epoch: 2674, iter: 1, loss: 0.0370
# restart: 0, epoch: 2675, iter: 1, loss: 0.0366
# restart: 0, epoch: 2676, iter: 1, loss: 0.0364
# restart: 0, epoch: 2677, iter: 1, loss: 0.0367
# restart: 0, epoch: 2678, iter: 1, loss: 0.0368
# restart: 0, epoch: 2679, iter: 1, loss: 0.0367
# restart: 0, epoch: 2680, iter: 1, loss: 0.0365
# restart: 0, epoch: 2681, iter: 1, loss: 0.0363
# restart: 0, epoch: 2682, iter: 1, loss: 0.0363
# restart: 0, epoch: 2683, iter: 1, loss: 0.0360
# restart: 0, epoch: 2684, iter: 1, loss: 0.0356
# restart: 0, epoch: 2685, iter: 1, loss: 0.0354
# restart: 0, epoch: 2686, iter: 1, loss: 0.0354
# restart: 0, epoch: 2687, iter: 1, loss: 0.0352
# restart: 0, epoch: 2688, iter: 1, loss: 0.0349
# restart: 0, epoch: 2689, iter: 1, loss: 0.0346
# restart: 0, epoch: 2690, iter: 1, loss: 0.0345
# restart: 0, epoch: 2691, iter: 1, loss: 0.0347
# restart: 0, epoch: 2692, iter: 1, loss: 0.0343
# restart: 0, epoch: 2693, iter: 1, loss: 0.0344
# restart: 0, epoch: 2694, iter: 1, loss: 0.0342
# restart: 0, epoch: 2695, iter: 1, loss: 0.0338
# restart: 0, epoch: 2696, iter: 1, loss: 0.0336
# restart: 0, epoch: 2697, iter: 1, loss: 0.0334
# restart: 0, epoch: 2698, iter: 1, loss: 0.0333
# restart: 0, epoch: 2699, iter: 1, loss: 0.0330
# restart: 0, epoch: 2700, iter: 1, loss: 0.0328
# restart: 0, epoch: 2701, iter: 1, loss: 0.0328
# restart: 0, epoch: 2702, iter: 1, loss: 0.0326
# restart: 0, epoch: 2703, iter: 1, loss: 0.0326
# restart: 0, epoch: 2704, iter: 1, loss: 0.0324
# restart: 0, epoch: 2705, iter: 1, loss: 0.0325
# restart: 0, epoch: 2706, iter: 1, loss: 0.0321
# restart: 0, epoch: 2707, iter: 1, loss: 0.0323
# restart: 0, epoch: 2708, iter: 1, loss: 0.0321
# restart: 0, epoch: 2709, iter: 1, loss: 0.0320
# restart: 0, epoch: 2710, iter: 1, loss: 0.0315
# restart: 0, epoch: 2711, iter: 1, loss: 0.0315
# restart: 0, epoch: 2712, iter: 1, loss: 0.0315
# restart: 0, epoch: 2713, iter: 1, loss: 0.0312
# restart: 0, epoch: 2714, iter: 1, loss: 0.0311
# restart: 0, epoch: 2715, iter: 1, loss: 0.0309
# restart: 0, epoch: 2716, iter: 1, loss: 0.0309
# restart: 0, epoch: 2717, iter: 1, loss: 0.0306
# restart: 0, epoch: 2718, iter: 1, loss: 0.0305
# restart: 0, epoch: 2719, iter: 1, loss: 0.0303
# restart: 0, epoch: 2720, iter: 1, loss: 0.0303
# restart: 0, epoch: 2721, iter: 1, loss: 0.0300
# restart: 0, epoch: 2722, iter: 1, loss: 0.0299
# restart: 0, epoch: 2723, iter: 1, loss: 0.0297
# restart: 0, epoch: 2724, iter: 1, loss: 0.0297
# restart: 0, epoch: 2725, iter: 1, loss: 0.0293
# restart: 0, epoch: 2726, iter: 1, loss: 0.0294
# restart: 0, epoch: 2727, iter: 1, loss: 0.0293
# restart: 0, epoch: 2728, iter: 1, loss: 0.0291
# restart: 0, epoch: 2729, iter: 1, loss: 0.0287
# restart: 0, epoch: 2730, iter: 1, loss: 0.0289
# restart: 0, epoch: 2731, iter: 1, loss: 0.0287
# restart: 0, epoch: 2732, iter: 1, loss: 0.0286
# restart: 0, epoch: 2733, iter: 1, loss: 0.0283
# restart: 0, epoch: 2734, iter: 1, loss: 0.0285
# restart: 0, epoch: 2735, iter: 1, loss: 0.0281
# restart: 0, epoch: 2736, iter: 1, loss: 0.0283
# restart: 0, epoch: 2737, iter: 1, loss: 0.0281
# restart: 0, epoch: 2738, iter: 1, loss: 0.0281
# restart: 0, epoch: 2739, iter: 1, loss: 0.0278
# restart: 0, epoch: 2740, iter: 1, loss: 0.0279
# restart: 0, epoch: 2741, iter: 1, loss: 0.0277
# restart: 0, epoch: 2742, iter: 1, loss: 0.0274
# restart: 0, epoch: 2743, iter: 1, loss: 0.0274
# restart: 0, epoch: 2744, iter: 1, loss: 0.0275
# restart: 0, epoch: 2745, iter: 1, loss: 0.0272
# restart: 0, epoch: 2746, iter: 1, loss: 0.0270
# restart: 0, epoch: 2747, iter: 1, loss: 0.0270
# restart: 0, epoch: 2748, iter: 1, loss: 0.0271
# restart: 0, epoch: 2749, iter: 1, loss: 0.0269
# restart: 0, epoch: 2750, iter: 1, loss: 0.0267
# restart: 0, epoch: 2751, iter: 1, loss: 0.0265
# restart: 0, epoch: 2752, iter: 1, loss: 0.0265
# restart: 0, epoch: 2753, iter: 1, loss: 0.0265
# restart: 0, epoch: 2754, iter: 1, loss: 0.0266
# restart: 0, epoch: 2755, iter: 1, loss: 0.0264
# restart: 0, epoch: 2756, iter: 1, loss: 0.0262
# restart: 0, epoch: 2757, iter: 1, loss: 0.0264
# restart: 0, epoch: 2758, iter: 1, loss: 0.0266
# restart: 0, epoch: 2759, iter: 1, loss: 0.0260
# restart: 0, epoch: 2760, iter: 1, loss: 0.0261
# restart: 0, epoch: 2761, iter: 1, loss: 0.0262
# restart: 0, epoch: 2762, iter: 1, loss: 0.0260
# restart: 0, epoch: 2763, iter: 1, loss: 0.0257
# restart: 0, epoch: 2764, iter: 1, loss: 0.0256
# restart: 0, epoch: 2765, iter: 1, loss: 0.0253
# restart: 0, epoch: 2766, iter: 1, loss: 0.0252
# restart: 0, epoch: 2767, iter: 1, loss: 0.0247
# restart: 0, epoch: 2768, iter: 1, loss: 0.0249
# restart: 0, epoch: 2769, iter: 1, loss: 0.0247
# restart: 0, epoch: 2770, iter: 1, loss: 0.0246
# restart: 0, epoch: 2771, iter: 1, loss: 0.0245
# restart: 0, epoch: 2772, iter: 1, loss: 0.0241
# restart: 0, epoch: 2773, iter: 1, loss: 0.0244
# restart: 0, epoch: 2774, iter: 1, loss: 0.0244
# restart: 0, epoch: 2775, iter: 1, loss: 0.0239
# restart: 0, epoch: 2776, iter: 1, loss: 0.0239
# restart: 0, epoch: 2777, iter: 1, loss: 0.0239
# restart: 0, epoch: 2778, iter: 1, loss: 0.0238
# restart: 0, epoch: 2779, iter: 1, loss: 0.0238
# restart: 0, epoch: 2780, iter: 1, loss: 0.0235
# restart: 0, epoch: 2781, iter: 1, loss: 0.0237
# restart: 0, epoch: 2782, iter: 1, loss: 0.0236
# restart: 0, epoch: 2783, iter: 1, loss: 0.0234
# restart: 0, epoch: 2784, iter: 1, loss: 0.0233
# restart: 0, epoch: 2785, iter: 1, loss: 0.0233
# restart: 0, epoch: 2786, iter: 1, loss: 0.0236
# restart: 0, epoch: 2787, iter: 1, loss: 0.0233
# restart: 0, epoch: 2788, iter: 1, loss: 0.0234
# restart: 0, epoch: 2789, iter: 1, loss: 0.0234
# restart: 0, epoch: 2790, iter: 1, loss: 0.0231
# restart: 0, epoch: 2791, iter: 1, loss: 0.0230
# restart: 0, epoch: 2792, iter: 1, loss: 0.0227
# restart: 0, epoch: 2793, iter: 1, loss: 0.0223
# restart: 0, epoch: 2794, iter: 1, loss: 0.0223
# restart: 0, epoch: 2795, iter: 1, loss: 0.0224
# restart: 0, epoch: 2796, iter: 1, loss: 0.0223
# restart: 0, epoch: 2797, iter: 1, loss: 0.0225
# restart: 0, epoch: 2798, iter: 1, loss: 0.0219
# restart: 0, epoch: 2799, iter: 1, loss: 0.0219
# restart: 0, epoch: 2800, iter: 1, loss: 0.0220
# restart: 0, epoch: 2801, iter: 1, loss: 0.0228
# restart: 0, epoch: 2802, iter: 1, loss: 0.0224
# restart: 0, epoch: 2803, iter: 1, loss: 0.0221
# restart: 0, epoch: 2804, iter: 1, loss: 0.0219
# restart: 0, epoch: 2805, iter: 1, loss: 0.0221
# restart: 0, epoch: 2806, iter: 1, loss: 0.0223
# restart: 0, epoch: 2807, iter: 1, loss: 0.0218
# restart: 0, epoch: 2808, iter: 1, loss: 0.0224
# restart: 0, epoch: 2809, iter: 1, loss: 0.0224
# restart: 0, epoch: 2810, iter: 1, loss: 0.0227
# restart: 0, epoch: 2811, iter: 1, loss: 0.0222
# restart: 0, epoch: 2812, iter: 1, loss: 0.0218
# restart: 0, epoch: 2813, iter: 1, loss: 0.0216
# restart: 0, epoch: 2814, iter: 1, loss: 0.0216
# restart: 0, epoch: 2815, iter: 1, loss: 0.0208
# restart: 0, epoch: 2816, iter: 1, loss: 0.0215
# restart: 0, epoch: 2817, iter: 1, loss: 0.0213
# restart: 0, epoch: 2818, iter: 1, loss: 0.0211
# restart: 0, epoch: 2819, iter: 1, loss: 0.0214
# restart: 0, epoch: 2820, iter: 1, loss: 0.0216
# restart: 0, epoch: 2821, iter: 1, loss: 0.0216
# restart: 0, epoch: 2822, iter: 1, loss: 0.0220
# restart: 0, epoch: 2823, iter: 1, loss: 0.0211
# restart: 0, epoch: 2824, iter: 1, loss: 0.0212
# restart: 0, epoch: 2825, iter: 1, loss: 0.0206
# restart: 0, epoch: 2826, iter: 1, loss: 0.0207
# restart: 0, epoch: 2827, iter: 1, loss: 0.0203
# restart: 0, epoch: 2828, iter: 1, loss: 0.0202
# restart: 0, epoch: 2829, iter: 1, loss: 0.0202
# restart: 0, epoch: 2830, iter: 1, loss: 0.0198
# restart: 0, epoch: 2831, iter: 1, loss: 0.0207
# restart: 0, epoch: 2832, iter: 1, loss: 0.0202
# restart: 0, epoch: 2833, iter: 1, loss: 0.0194
# restart: 0, epoch: 2834, iter: 1, loss: 0.0199
# restart: 0, epoch: 2835, iter: 1, loss: 0.0193
# restart: 0, epoch: 2836, iter: 1, loss: 0.0193
# restart: 0, epoch: 2837, iter: 1, loss: 0.0191
# restart: 0, epoch: 2838, iter: 1, loss: 0.0189
# restart: 0, epoch: 2839, iter: 1, loss: 0.0185
# restart: 0, epoch: 2840, iter: 1, loss: 0.0183
# restart: 0, epoch: 2841, iter: 1, loss: 0.0185
# restart: 0, epoch: 2842, iter: 1, loss: 0.0179
# restart: 0, epoch: 2843, iter: 1, loss: 0.0180
# restart: 0, epoch: 2844, iter: 1, loss: 0.0180
# restart: 0, epoch: 2845, iter: 1, loss: 0.0176
# restart: 0, epoch: 2846, iter: 1, loss: 0.0177
# restart: 0, epoch: 2847, iter: 1, loss: 0.0178
# restart: 0, epoch: 2848, iter: 1, loss: 0.0173
# restart: 0, epoch: 2849, iter: 1, loss: 0.0174
# restart: 0, epoch: 2850, iter: 1, loss: 0.0172
# restart: 0, epoch: 2851, iter: 1, loss: 0.0172
# restart: 0, epoch: 2852, iter: 1, loss: 0.0174
# restart: 0, epoch: 2853, iter: 1, loss: 0.0169
# restart: 0, epoch: 2854, iter: 1, loss: 0.0167
# restart: 0, epoch: 2855, iter: 1, loss: 0.0168
# restart: 0, epoch: 2856, iter: 1, loss: 0.0163
# restart: 0, epoch: 2857, iter: 1, loss: 0.0165
# restart: 0, epoch: 2858, iter: 1, loss: 0.0163
# restart: 0, epoch: 2859, iter: 1, loss: 0.0161
# restart: 0, epoch: 2860, iter: 1, loss: 0.0161
# restart: 0, epoch: 2861, iter: 1, loss: 0.0160
# restart: 0, epoch: 2862, iter: 1, loss: 0.0161
# restart: 0, epoch: 2863, iter: 1, loss: 0.0157
# restart: 0, epoch: 2864, iter: 1, loss: 0.0157
# restart: 0, epoch: 2865, iter: 1, loss: 0.0164
# restart: 0, epoch: 2866, iter: 1, loss: 0.0161
# restart: 0, epoch: 2867, iter: 1, loss: 0.0157
# restart: 0, epoch: 2868, iter: 1, loss: 0.0157
# restart: 0, epoch: 2869, iter: 1, loss: 0.0153
# restart: 0, epoch: 2870, iter: 1, loss: 0.0155
# restart: 0, epoch: 2871, iter: 1, loss: 0.0156
# restart: 0, epoch: 2872, iter: 1, loss: 0.0157
# restart: 0, epoch: 2873, iter: 1, loss: 0.0156
# restart: 0, epoch: 2874, iter: 1, loss: 0.0147
# restart: 0, epoch: 2875, iter: 1, loss: 0.0155
# restart: 0, epoch: 2876, iter: 1, loss: 0.0154
# restart: 0, epoch: 2877, iter: 1, loss: 0.0151
# restart: 0, epoch: 2878, iter: 1, loss: 0.0153
# restart: 0, epoch: 2879, iter: 1, loss: 0.0151
# restart: 0, epoch: 2880, iter: 1, loss: 0.0148
# restart: 0, epoch: 2881, iter: 1, loss: 0.0142
# restart: 0, epoch: 2882, iter: 1, loss: 0.0141
# restart: 0, epoch: 2883, iter: 1, loss: 0.0140
# restart: 0, epoch: 2884, iter: 1, loss: 0.0135
# restart: 0, epoch: 2885, iter: 1, loss: 0.0142
# restart: 0, epoch: 2886, iter: 1, loss: 0.0140
# restart: 0, epoch: 2887, iter: 1, loss: 0.0137
# restart: 0, epoch: 2888, iter: 1, loss: 0.0141
# restart: 0, epoch: 2889, iter: 1, loss: 0.0136
# restart: 0, epoch: 2890, iter: 1, loss: 0.0132
# restart: 0, epoch: 2891, iter: 1, loss: 0.0134
# restart: 0, epoch: 2892, iter: 1, loss: 0.0132
# restart: 0, epoch: 2893, iter: 1, loss: 0.0130
# restart: 0, epoch: 2894, iter: 1, loss: 0.0128
# restart: 0, epoch: 2895, iter: 1, loss: 0.0127
# restart: 0, epoch: 2896, iter: 1, loss: 0.0127
# restart: 0, epoch: 2897, iter: 1, loss: 0.0122
# restart: 0, epoch: 2898, iter: 1, loss: 0.0125
# restart: 0, epoch: 2899, iter: 1, loss: 0.0122
# restart: 0, epoch: 2900, iter: 1, loss: 0.0120
# restart: 0, epoch: 2901, iter: 1, loss: 0.0116
# restart: 0, epoch: 2902, iter: 1, loss: 0.0115
# restart: 0, epoch: 2903, iter: 1, loss: 0.0112
# restart: 0, epoch: 2904, iter: 1, loss: 0.0116
# restart: 0, epoch: 2905, iter: 1, loss: 0.0115
# restart: 0, epoch: 2906, iter: 1, loss: 0.0109
# restart: 0, epoch: 2907, iter: 1, loss: 0.0111
# restart: 0, epoch: 2908, iter: 1, loss: 0.0107
# restart: 0, epoch: 2909, iter: 1, loss: 0.0110
# restart: 0, epoch: 2910, iter: 1, loss: 0.0107
# restart: 0, epoch: 2911, iter: 1, loss: 0.0107
# restart: 0, epoch: 2912, iter: 1, loss: 0.0103
# restart: 0, epoch: 2913, iter: 1, loss: 0.0104
# restart: 0, epoch: 2914, iter: 1, loss: 0.0105
# restart: 0, epoch: 2915, iter: 1, loss: 0.0102
# restart: 0, epoch: 2916, iter: 1, loss: 0.0103
# restart: 0, epoch: 2917, iter: 1, loss: 0.0100
# restart: 0, epoch: 2918, iter: 1, loss: 0.0100
# restart: 0, epoch: 2919, iter: 1, loss: 0.0102
# restart: 0, epoch: 2920, iter: 1, loss: 0.0100
# restart: 0, epoch: 2921, iter: 1, loss: 0.0101
# restart: 0, epoch: 2922, iter: 1, loss: 0.0096
# restart: 0, epoch: 2923, iter: 1, loss: 0.0095
# restart: 0, epoch: 2924, iter: 1, loss: 0.0095
# restart: 0, epoch: 2925, iter: 1, loss: 0.0095
# restart: 0, epoch: 2926, iter: 1, loss: 0.0092
# restart: 0, epoch: 2927, iter: 1, loss: 0.0098
# restart: 0, epoch: 2928, iter: 1, loss: 0.0102
# restart: 0, epoch: 2929, iter: 1, loss: 0.0094
# restart: 0, epoch: 2930, iter: 1, loss: 0.0099
# restart: 0, epoch: 2931, iter: 1, loss: 0.0095
# restart: 0, epoch: 2932, iter: 1, loss: 0.0096
# restart: 0, epoch: 2933, iter: 1, loss: 0.0093
# restart: 0, epoch: 2934, iter: 1, loss: 0.0096
# restart: 0, epoch: 2935, iter: 1, loss: 0.0090
# restart: 0, epoch: 2936, iter: 1, loss: 0.0092
# restart: 0, epoch: 2937, iter: 1, loss: 0.0097
# restart: 0, epoch: 2938, iter: 1, loss: 0.0086
# restart: 0, epoch: 2939, iter: 1, loss: 0.0091
# restart: 0, epoch: 2940, iter: 1, loss: 0.0091
# restart: 0, epoch: 2941, iter: 1, loss: 0.0087
# restart: 0, epoch: 2942, iter: 1, loss: 0.0086
# restart: 0, epoch: 2943, iter: 1, loss: 0.0094
# restart: 0, epoch: 2944, iter: 1, loss: 0.0097
# restart: 0, epoch: 2945, iter: 1, loss: 0.0111
# restart: 0, epoch: 2946, iter: 1, loss: 0.0109
# restart: 0, epoch: 2947, iter: 1, loss: 0.0098
# restart: 0, epoch: 2948, iter: 1, loss: 0.0094
# restart: 0, epoch: 2949, iter: 1, loss: 0.0097
# restart: 0, epoch: 2950, iter: 1, loss: 0.0100
# restart: 0, epoch: 2951, iter: 1, loss: 0.0096
# restart: 0, epoch: 2952, iter: 1, loss: 0.0094
# restart: 0, epoch: 2953, iter: 1, loss: 0.0094
# restart: 0, epoch: 2954, iter: 1, loss: 0.0094
# restart: 0, epoch: 2955, iter: 1, loss: 0.0095
# restart: 0, epoch: 2956, iter: 1, loss: 0.0094
# restart: 0, epoch: 2957, iter: 1, loss: 0.0095
# restart: 0, epoch: 2958, iter: 1, loss: 0.0090
# restart: 0, epoch: 2959, iter: 1, loss: 0.0091
# restart: 0, epoch: 2960, iter: 1, loss: 0.0087
# restart: 0, epoch: 2961, iter: 1, loss: 0.0091
# restart: 0, epoch: 2962, iter: 1, loss: 0.0090
# restart: 0, epoch: 2963, iter: 1, loss: 0.0084
# restart: 0, epoch: 2964, iter: 1, loss: 0.0086
# restart: 0, epoch: 2965, iter: 1, loss: 0.0085
# restart: 0, epoch: 2966, iter: 1, loss: 0.0083
# restart: 0, epoch: 2967, iter: 1, loss: 0.0073
# restart: 0, epoch: 2968, iter: 1, loss: 0.0076
# restart: 0, epoch: 2969, iter: 1, loss: 0.0075
# restart: 0, epoch: 2970, iter: 1, loss: 0.0075
# restart: 0, epoch: 2971, iter: 1, loss: 0.0070
# restart: 0, epoch: 2972, iter: 1, loss: 0.0073
# restart: 0, epoch: 2973, iter: 1, loss: 0.0072
# restart: 0, epoch: 2974, iter: 1, loss: 0.0067
# restart: 0, epoch: 2975, iter: 1, loss: 0.0065
# restart: 0, epoch: 2976, iter: 1, loss: 0.0063
# restart: 0, epoch: 2977, iter: 1, loss: 0.0061
# restart: 0, epoch: 2978, iter: 1, loss: 0.0061
# restart: 0, epoch: 2979, iter: 1, loss: 0.0063
# restart: 0, epoch: 2980, iter: 1, loss: 0.0062
# restart: 0, epoch: 2981, iter: 1, loss: 0.0058
# restart: 0, epoch: 2982, iter: 1, loss: 0.0060
# restart: 0, epoch: 2983, iter: 1, loss: 0.0059
# restart: 0, epoch: 2984, iter: 1, loss: 0.0055
# restart: 0, epoch: 2985, iter: 1, loss: 0.0060
# restart: 0, epoch: 2986, iter: 1, loss: 0.0057
# restart: 0, epoch: 2987, iter: 1, loss: 0.0058
# restart: 0, epoch: 2988, iter: 1, loss: 0.0055
# restart: 0, epoch: 2989, iter: 1, loss: 0.0051
# restart: 0, epoch: 2990, iter: 1, loss: 0.0050
# restart: 0, epoch: 2991, iter: 1, loss: 0.0053
# restart: 0, epoch: 2992, iter: 1, loss: 0.0055
# restart: 0, epoch: 2993, iter: 1, loss: 0.0051
# restart: 0, epoch: 2994, iter: 1, loss: 0.0050
# restart: 0, epoch: 2995, iter: 1, loss: 0.0047
# restart: 0, epoch: 2996, iter: 1, loss: 0.0046
# restart: 0, epoch: 2997, iter: 1, loss: 0.0050
# restart: 0, epoch: 2998, iter: 1, loss: 0.0042
# restart: 0, epoch: 2999, iter: 1, loss: 0.0048
# restart: 0, epoch: 3000, iter: 1, loss: 0.0044

# %%
model_name = "Point_to_point_main_power_time.pt"
torch.save(model.state_dict(), os.path.join(
  "Neurips/models", model_name))

# %%
kernel1 = ScaleKernel(MaternKernel(nu=2.5)) #nu=2.5,
# # kernel2 = ScaleKernel(RBFKernel(ard_num_dims=1, active_dims=(1)))
# # kernel3 = ScaleKernel(PeriodicKernel(ard_num_dims=1, active_dims=(1)))
# # kernel4 = ScaleKernel(PeriodicKernel(ard_num_dims=2, active_dims=(0)))
# # kernel5 = ScaleKernel(CosineKernel(ard_num_dims=2, active_dims=(1)))

kernel = kernel1# + kernel2*kernel3
# # induce_points = 512
inducing_points =  x_train[np.arange(0,x_train.shape[0],20)] 
# #x_train_full[torch.randperm(x_train_full.shape[0])[: batch]].to("cuda")

model = SGPRegressor(x_train.to("cuda"), y_train.to("cuda"), kernel,
                      inducing_points).to("cuda")

model_name = "Point_to_point_main_power.pt"
model.load_state_dict(torch.load(
    os.path.join("Neurips/models", model_name)))
# Out:
# <All keys matched successfully>

# %%
# y_pred_arr =[]

# y_pred_arr.append(pred_dist.loc)

# %%
# y_pred_arr1 = []
# for i in range(len(y_pred_arr)):
#   y_pred_arr1.append(np.array(y_pred_arr[i].cpu()))

# %%
# y_mean = np.mean(y_pred_arr1, axis =0)
# y_sigma = np.std(y_pred_arr1, axis=0)
pred_dist = model.predict(x_test_full.to("cuda"))

y_mean = pred_dist.loc
# Out:
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/kernels/inducing_point_kernel.py:61: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352645774/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   inv_root = torch.triangular_solve(eye, chol)[0]

# %%
y_mean = scaler_y.inverse_transform(y_mean.reshape(-1,1).cpu()).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(y_test.shape, y_mean.shape)

y_mean = np.clip(y_mean,0,y_mean.max(),out=y_mean)
# Out:
# torch.Size([15656]) (15656,)

# %%
mae = np.mean(np.abs(np.array(y_test) - y_mean))
rms = errors.rmse(jnp.array(y_test), y_mean)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  18.436558134364407
# RMSE:  38.672264

# %%
idx = 1000
start = 13000
plt.figure(figsize=(10,6))
time_plot = scaler_time.inverse_transform(x_test_timestamp.cpu().reshape(-1,1))
latexify(width_scale_factor=2, fig_height=2)
# plt.plot(time_plot[start : start + idx], scaler_x.inverse_transform(x_test[start : start + idx].cpu().reshape(-1,1) ), label = "Main Power")
plt.plot(time_plot[start : start + idx], y_test.cpu()[start : start + idx], label = "Ground Truth")
plt.plot(time_plot[start : start + idx], y_mean[start : start + idx], label = "Prediction")
# plt.legend(frameon=False, ncol=2)
plt.xlabel("Time ( in DateTime)",  loc='left')
plt.ylabel("Power")
sns.despine()
plt.show()
# savefig("Point_to_point_main_power_follow_main_pred")

# %%
for name, params in model.named_parameters():
  print(name, params)
# Out:
# mll.likelihood.noise_covar.raw_noise Parameter containing:
# tensor([-2.4230], device='cuda:0', requires_grad=True)
# mll.model.mean_module.constant Parameter containing:
# tensor([0.7693], device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.raw_outputscale Parameter containing:
# tensor(-1.6767, device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.base_kernel.raw_lengthscale Parameter containing:
# tensor([[-3.0339]], device='cuda:0', requires_grad=True)
# mll.model.covar_module.inducing_points Parameter containing:
# tensor([[-0.2423],
#         [-0.4043],
#         [-0.4716],
#         ...,
#         [ 0.4216],
#         [-0.5382],
#         [ 0.3627]], device='cuda:0', dtype=torch.float32, requires_grad=True)

# %%
model.mll.model.base_covar_module.outputscale
# Out:
# tensor(0.5497, device='cuda:0', grad_fn=<SoftplusBackward0>)

# %%
model.mll.model.mean_module.constant
# Out:
# Parameter containing:
# tensor([0.7693], device='cuda:0', requires_grad=True)

# %% [markdown]
# ## Decomposition

# %%
model1 = SGPRegressor(x_train_full.to("cuda"), y_train.to("cuda"), kernel1,
                      inducing_points).to("cuda")

# %%
pred_dist1 = model1.predict(x_test_full[:4000].to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_pred_arr =[]

y_pred_arr.append(pred_dist1.loc)

# %%
y_mean1.shape

# %%
y_pred_arr1 = []
for i in range(len(y_pred_arr)):
  y_pred_arr1.append(np.array(y_pred_arr[i].cpu()))

# %%
y_mean1 = np.mean(y_pred_arr1, axis =0)
# y_sigma = np.std(y_pred_arr1, axis=0)

y_mean1.shape#, y_sigma.shape

y_mean1 = scaler_y.inverse_transform(y_mean1.reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(y_test.shape, y_mean1.shape)

y_mean1 = np.clip(y_mean1,0,y_mean1.max(),out=y_mean1)

# %%
mae = np.mean(np.abs(np.array(y_test[:4000]) - y_mean1))
rms = errors.rmse(jnp.array(y_test[:4000]), y_mean1)

print("MAE: ", mae)
print("RMSE: ", rms)

# %%
idx = 3000
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp[:idx], y_test.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean1[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()

# %%
model2 = SGPRegressor(x_train_full.to("cuda"), y_train.to("cuda"), kernel2*kernel3,
                      inducing_points).to("cuda")

# %%
pred_dist2 = model2.predict(x_test_full[:4000].to("cuda"))
# print("Done ", i)

y_mean2 = pred_dist2.loc

# %%
y_pred_arr =[]

y_pred_arr.append(pred_dist2.loc)

# %%
y_pred_arr1 = []
for i in range(len(y_pred_arr)):
  y_pred_arr1.append(np.array(y_pred_arr[i].cpu()))

# %%
y_mean2 = np.mean(y_pred_arr1, axis =0)
# y_sigma = np.std(y_pred_arr2, axis=0)

y_mean2.shape#, y_sigma.shape

y_mean2 = scaler_y.inverse_transform(y_mean2.reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(y_test.shape, y_mean2.shape)

y_mean2 = np.clip(y_mean2,0,y_mean2.max(),out=y_mean2)

# %%
mae = np.mean(np.abs(np.array(y_test[:4000]) - y_mean2))
rms = errors.rmse(jnp.array(y_test[:4000]), y_mean2)

print("MAE: ", mae)
print("RMSE: ", rms)

# %%
idx = 3000
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp[:idx], y_test.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean2[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
