# %%
import os
os.chdir("../")
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import torch
from gpytorch.kernels import RBFKernel, ScaleKernel, PeriodicKernel, MaternKernel, CosineKernel
from skgpytorch.models import SVGPRegressor, SGPRegressor

# %%
import jax.numpy as jnp
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from utilities.fits import fit
# from utilities import plot
import tensorflow_probability.substrates.jax as tfp
dist = tfp.distributions
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from gpytorch.constraints import GreaterThan
from skgpytorch.metrics import mean_squared_error, negative_log_predictive_density
import time
import numpy as np

# from datasets.dataset_load import dataset_loader
from utilities import plot,fits,gmm,errors,predict,preprocess

# device = "cpu"
# torch.set_default_dtype(torch.float32)
# torch.set_default_tensor_type(torch.FloatTensor)

# %%
train ={1:{
                    'start_time': "2011-04-21" ,
                    'end_time': "2011-05-21"
                },2: {
                    'start_time': "2011-04-21" ,
                    'end_time': "2011-05-21"
                },
                3: {
                    'start_time': "2011-04-19" ,
                    'end_time': "2011-05-22"
                },
                6: {
                    'start_time': "2011-05-25" ,
                    'end_time': "2011-06-13"
                },
                
               
                }
test = { 5: {
                    'start_time': "2011-04-22" ,
                    'end_time': "2011-06-01"
                }}
appliances = ["Refrigerator"]

# %%
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler


def dataset_load(appliances, train, test=None):
    x_train = []
    y_train = []
    x_train_timestamp = []
    n = 99
    units_to_pad = n // 2
    scaler_x = StandardScaler()
    scaler_y = StandardScaler()
    scaler_time = StandardScaler()
    # train
    for key, values in train.items():
        df = pd.read_csv(
            f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[0]])
        df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
        startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
        endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

        if startDate > endDate:
            raise "Start Date must be smaller than Enddate."

        df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
        df.dropna(inplace=True)
        x = df["main"].values
        y = df[appliances[0]].values
        timestamp_train = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])
        x_train.extend(x)
        y_train.extend(y)
        x_train_timestamp.extend(torch.tensor(timestamp_train))


    x_train = jnp.array(x_train)
    y_train = jnp.array(y_train).reshape(-1, 1)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(-1,1)
    x_train = scaler_x.fit_transform(x_train)
    y_train = scaler_y.fit_transform(y_train)
    x_train_timestamp = scaler_time.fit_transform(x_train_timestamp)


    # test
    x_test = []
    y_test = []
    x_test_timestamp = []
    x_test_timestamp_true =[]
    for key, values in test.items():
        df = pd.read_csv(
            f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[0]])
        df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
        startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
        endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

        if startDate > endDate:
            raise "Start Date must be smaller than Enddate."

        df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
        df.dropna(inplace=True)
        x = df["main"].values
        y = df[appliances[0]].values
        timestamp_true = df["Timestamp"].values
        timestamp = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])
        x_test.extend(x)
        y_test.extend(y)
        x_test_timestamp_true.extend(timestamp_true)
        x_test_timestamp.extend(timestamp)

    x_test = jnp.array(x_test)
    y_test = jnp.array(y_test).reshape(-1, 1)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(-1,1)

    x_test = scaler_x.transform(x_test)
    x_test_timestamp = scaler_time.transform(x_test_timestamp)
#     y_test = scaler_y.transform(y_test)

    x_train = jnp.array(x_train).reshape(x_train.shape[0], n, 1)
    y_train = jnp.array(y_train)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(x_train_timestamp.shape[0], 1)
    x_test = jnp.array(x_test).reshape(x_test.shape[0], n, 1)
    y_test = jnp.array(y_test)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(x_test_timestamp.shape[0], 1).to(torch.float64)

    return x_train, y_train, x_test, y_test, x_train_timestamp, x_test_timestamp, x_test_timestamp_true, scaler_x, scaler_y, scaler_time

# %%
x_train, y_train, x_test, y_test, x_train_timstamp, x_test_timestamp, test_timestamp_orig, scaler_x, scaler_y, scaler_time = dataset_load(appliances, train, test)

# %%
n = 99
x_train_full = jnp.concatenate((x_train.reshape(-1,n), jnp.array(np.array(x_train_timstamp))), axis=1)
x_test_full = jnp.concatenate((x_test.reshape(-1,n), jnp.array(np.array(x_test_timestamp))), axis=1)
x_train_full.shape, x_test_full.shape
# Out:
# ((67134, 100), (3103, 100))

# %%
x_train.reshape(-1,n).shape, x_test.reshape(-1,n).shape, y_train.shape, y_test.shape
# Out:
# ((67134, 99), (3103, 99), (67134, 1), (3103, 1))

# %%
# x = x_train_full[:14000]
# y = y_train[:14000]
# xt = x_train_full[14000:]
# yt = y_train[14000:]

# %%
# x.shape, y.shape

# %%
import gpytorch
indexes = 53456
x = torch.tensor(np.array(x_train_full)).to(torch.float64)
y = torch.tensor(np.array(y_train)).reshape(-1,).to(torch.float64)
xt = torch.tensor(np.array(x_test_full)).to(torch.float64)
yt = torch.tensor(np.array(y_test)).reshape(-1,).to(torch.float64)

if x.shape[0]>indexes:
  x = x[:indexes]
  y = y[:indexes]

# xt = xt[:16000]
# yt = yt[:16000]

# %%
x.dtype
# Out:
# torch.float64

# %%
x.shape, y.shape, xt.shape, yt.shape
# Out:
# (torch.Size([53456, 100]),
#  torch.Size([53456]),
#  torch.Size([3103, 100]),
#  torch.Size([3103]))

# %%
x.dtype
# Out:
# torch.float64

# %%
len(range(99))
# Out:
# 99

# %%
mae_arr =[]
rms_arr = []
y_pred_arr = []

batch = 512

# x_train = x_train[:4500]
# y_train = y_train[:4500]

# y_test_trans = torch.tensor(torch.tensor(scaler_x.transform(y_test.reshape(-1,1))).reshape(-1,)).contiguous().to(torch.float64)
for i in range(1):


   #nu=2.5,

  kernel1 = ScaleKernel(MaternKernel(nu=2.5,ard_num_dims=n+1))
  kernel2 = ScaleKernel(MaternKernel(nu=0.5,ard_num_dims=1,active_dims=(99)))
  kernel3 = ScaleKernel(PeriodicKernel(ard_num_dims=1,active_dims=(99)))
  # kernel5 = ScaleKernel(gpytorch.kernels.SpectralDeltaKernel(num_dims=n,ard_num_dims=n))
#   theta =  {'base_covar_module.kernels.0.base_kernel.lengthscale': torch.tensor(0.5),
#         'base_covar_module.kernels.0.outputscale': torch.tensor(5.0),
#         'base_covar_module.kernels.1.kernels.0.outputscale':torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.0.base_kernel.lengthscale': torch.tensor(0.1),
#         'base_covar_module.kernels.1.kernels.1.outputscale':torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.1.base_kernel.lengthscale': torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
  theta = { 'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
  kernel4 = kernel2*kernel3
  kernel = kernel1 + kernel4
  # induce_points = 512
  inducing_points =  x[np.arange(0,x.shape[0],95)] 
  # inducing_points = x[torch.randperm(x.shape[0])[: 1500]]
  
  model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                       inducing_points).to("cuda")
  # model.base_covar_module.base_kernel.raw_lengthscale_constraint
  # model.mll.likelihood.noise_covar.register_constraint("raw_noise", GreaterThan(1e-2))
  # for param in model.parameters():
  #   # print(param)
  #   torch.nn.init.normal_(param, 0, 1)
  # theta1 = {'likelihood.noise_covar.noise': torch.tensor(3),
  #       'covar_module.base_kernel.lengthscale': torch.tensor(0.1),
  #       'covar_module.outputscale': torch.tensor(5),}
  loss = model.fit(lr=0.001, n_epochs=2000,verbose=1,thetas=theta,
          random_state=0, n_restarts=1)
#   loss_arr.append(loss)
  # print(loss)
  plt.plot(np.asarray(loss[0]))
  # plt.plot(np.asarray(test_loss[0]))







  # y_pred_arr.append(pred_dist.loc)
# Out:
# restart: 0, epoch: 1, iter: 1, loss: 1.5682
# restart: 0, epoch: 2, iter: 1, loss: 1.5688
# restart: 0, epoch: 3, iter: 1, loss: 1.5656
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/kernels/inducing_point_kernel.py:61: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352645774/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   inv_root = torch.triangular_solve(eye, chol)[0]
# restart: 0, epoch: 4, iter: 1, loss: 1.5612
# restart: 0, epoch: 5, iter: 1, loss: 1.5589
# restart: 0, epoch: 6, iter: 1, loss: 1.5564
# restart: 0, epoch: 7, iter: 1, loss: 1.5538
# restart: 0, epoch: 8, iter: 1, loss: 1.5507
# restart: 0, epoch: 9, iter: 1, loss: 1.5482
# restart: 0, epoch: 10, iter: 1, loss: 1.5458
# restart: 0, epoch: 11, iter: 1, loss: 1.5434
# restart: 0, epoch: 12, iter: 1, loss: 1.5411
# restart: 0, epoch: 13, iter: 1, loss: 1.5390
# restart: 0, epoch: 14, iter: 1, loss: 1.5371
# restart: 0, epoch: 15, iter: 1, loss: 1.5349
# restart: 0, epoch: 16, iter: 1, loss: 1.5328
# restart: 0, epoch: 17, iter: 1, loss: 1.5308
# restart: 0, epoch: 18, iter: 1, loss: 1.5289
# restart: 0, epoch: 19, iter: 1, loss: 1.5271
# restart: 0, epoch: 20, iter: 1, loss: 1.5252
# restart: 0, epoch: 21, iter: 1, loss: 1.5235
# restart: 0, epoch: 22, iter: 1, loss: 1.5218
# restart: 0, epoch: 23, iter: 1, loss: 1.5201
# restart: 0, epoch: 24, iter: 1, loss: 1.5184
# restart: 0, epoch: 25, iter: 1, loss: 1.5168
# restart: 0, epoch: 26, iter: 1, loss: 1.5151
# restart: 0, epoch: 27, iter: 1, loss: 1.5134
# restart: 0, epoch: 28, iter: 1, loss: 1.5118
# restart: 0, epoch: 29, iter: 1, loss: 1.5102
# restart: 0, epoch: 30, iter: 1, loss: 1.5087
# restart: 0, epoch: 31, iter: 1, loss: 1.5072
# restart: 0, epoch: 32, iter: 1, loss: 1.5058
# restart: 0, epoch: 33, iter: 1, loss: 1.5043
# restart: 0, epoch: 34, iter: 1, loss: 1.5029
# restart: 0, epoch: 35, iter: 1, loss: 1.5014
# restart: 0, epoch: 36, iter: 1, loss: 1.5000
# restart: 0, epoch: 37, iter: 1, loss: 1.4986
# restart: 0, epoch: 38, iter: 1, loss: 1.4973
# restart: 0, epoch: 39, iter: 1, loss: 1.4959
# restart: 0, epoch: 40, iter: 1, loss: 1.4946
# restart: 0, epoch: 41, iter: 1, loss: 1.4933
# restart: 0, epoch: 42, iter: 1, loss: 1.4920
# restart: 0, epoch: 43, iter: 1, loss: 1.4906
# restart: 0, epoch: 44, iter: 1, loss: 1.4893
# restart: 0, epoch: 45, iter: 1, loss: 1.4881
# restart: 0, epoch: 46, iter: 1, loss: 1.4869
# restart: 0, epoch: 47, iter: 1, loss: 1.4857
# restart: 0, epoch: 48, iter: 1, loss: 1.4844
# restart: 0, epoch: 49, iter: 1, loss: 1.4833
# restart: 0, epoch: 50, iter: 1, loss: 1.4822
# restart: 0, epoch: 51, iter: 1, loss: 1.4811
# restart: 0, epoch: 52, iter: 1, loss: 1.4797
# restart: 0, epoch: 53, iter: 1, loss: 1.4787
# restart: 0, epoch: 54, iter: 1, loss: 1.4777
# restart: 0, epoch: 55, iter: 1, loss: 1.4768
# restart: 0, epoch: 56, iter: 1, loss: 1.4756
# restart: 0, epoch: 57, iter: 1, loss: 1.4744
# restart: 0, epoch: 58, iter: 1, loss: 1.4736
# restart: 0, epoch: 59, iter: 1, loss: 1.4725
# restart: 0, epoch: 60, iter: 1, loss: 1.4712
# restart: 0, epoch: 61, iter: 1, loss: 1.4700
# restart: 0, epoch: 62, iter: 1, loss: 1.4689
# restart: 0, epoch: 63, iter: 1, loss: 1.4678
# restart: 0, epoch: 64, iter: 1, loss: 1.4668
# restart: 0, epoch: 65, iter: 1, loss: 1.4656
# restart: 0, epoch: 66, iter: 1, loss: 1.4645
# restart: 0, epoch: 67, iter: 1, loss: 1.4635
# restart: 0, epoch: 68, iter: 1, loss: 1.4624
# restart: 0, epoch: 69, iter: 1, loss: 1.4614
# restart: 0, epoch: 70, iter: 1, loss: 1.4603
# restart: 0, epoch: 71, iter: 1, loss: 1.4593
# restart: 0, epoch: 72, iter: 1, loss: 1.4583
# restart: 0, epoch: 73, iter: 1, loss: 1.4572
# restart: 0, epoch: 74, iter: 1, loss: 1.4562
# restart: 0, epoch: 75, iter: 1, loss: 1.4552
# restart: 0, epoch: 76, iter: 1, loss: 1.4542
# restart: 0, epoch: 77, iter: 1, loss: 1.4533
# restart: 0, epoch: 78, iter: 1, loss: 1.4523
# restart: 0, epoch: 79, iter: 1, loss: 1.4513
# restart: 0, epoch: 80, iter: 1, loss: 1.4504
# restart: 0, epoch: 81, iter: 1, loss: 1.4494
# restart: 0, epoch: 82, iter: 1, loss: 1.4485
# restart: 0, epoch: 83, iter: 1, loss: 1.4475
# restart: 0, epoch: 84, iter: 1, loss: 1.4466
# restart: 0, epoch: 85, iter: 1, loss: 1.4457
# restart: 0, epoch: 86, iter: 1, loss: 1.4448
# restart: 0, epoch: 87, iter: 1, loss: 1.4439
# restart: 0, epoch: 88, iter: 1, loss: 1.4430
# restart: 0, epoch: 89, iter: 1, loss: 1.4421
# restart: 0, epoch: 90, iter: 1, loss: 1.4412
# restart: 0, epoch: 91, iter: 1, loss: 1.4403
# restart: 0, epoch: 92, iter: 1, loss: 1.4395
# restart: 0, epoch: 93, iter: 1, loss: 1.4386
# restart: 0, epoch: 94, iter: 1, loss: 1.4377
# restart: 0, epoch: 95, iter: 1, loss: 1.4369
# restart: 0, epoch: 96, iter: 1, loss: 1.4360
# restart: 0, epoch: 97, iter: 1, loss: 1.4352
# restart: 0, epoch: 98, iter: 1, loss: 1.4345
# restart: 0, epoch: 99, iter: 1, loss: 1.4336
# restart: 0, epoch: 100, iter: 1, loss: 1.4327
# restart: 0, epoch: 101, iter: 1, loss: 1.4319
# restart: 0, epoch: 102, iter: 1, loss: 1.4312
# restart: 0, epoch: 103, iter: 1, loss: 1.4304
# restart: 0, epoch: 104, iter: 1, loss: 1.4297
# restart: 0, epoch: 105, iter: 1, loss: 1.4288
# restart: 0, epoch: 106, iter: 1, loss: 1.4281
# restart: 0, epoch: 107, iter: 1, loss: 1.4273
# restart: 0, epoch: 108, iter: 1, loss: 1.4266
# restart: 0, epoch: 109, iter: 1, loss: 1.4257
# restart: 0, epoch: 110, iter: 1, loss: 1.4250
# restart: 0, epoch: 111, iter: 1, loss: 1.4243
# restart: 0, epoch: 112, iter: 1, loss: 1.4235
# restart: 0, epoch: 113, iter: 1, loss: 1.4227
# restart: 0, epoch: 114, iter: 1, loss: 1.4220
# restart: 0, epoch: 115, iter: 1, loss: 1.4212
# restart: 0, epoch: 116, iter: 1, loss: 1.4205
# restart: 0, epoch: 117, iter: 1, loss: 1.4197
# restart: 0, epoch: 118, iter: 1, loss: 1.4190
# restart: 0, epoch: 119, iter: 1, loss: 1.4183
# restart: 0, epoch: 120, iter: 1, loss: 1.4176
# restart: 0, epoch: 121, iter: 1, loss: 1.4169
# restart: 0, epoch: 122, iter: 1, loss: 1.4162
# restart: 0, epoch: 123, iter: 1, loss: 1.4154
# restart: 0, epoch: 124, iter: 1, loss: 1.4147
# restart: 0, epoch: 125, iter: 1, loss: 1.4140
# restart: 0, epoch: 126, iter: 1, loss: 1.4133
# restart: 0, epoch: 127, iter: 1, loss: 1.4127
# restart: 0, epoch: 128, iter: 1, loss: 1.4122
# restart: 0, epoch: 129, iter: 1, loss: 1.4116
# restart: 0, epoch: 130, iter: 1, loss: 1.4109
# restart: 0, epoch: 131, iter: 1, loss: 1.4102
# restart: 0, epoch: 132, iter: 1, loss: 1.4099
# restart: 0, epoch: 133, iter: 1, loss: 1.4093
# restart: 0, epoch: 134, iter: 1, loss: 1.4089
# restart: 0, epoch: 135, iter: 1, loss: 1.4079
# restart: 0, epoch: 136, iter: 1, loss: 1.4074
# restart: 0, epoch: 137, iter: 1, loss: 1.4066
# restart: 0, epoch: 138, iter: 1, loss: 1.4059
# restart: 0, epoch: 139, iter: 1, loss: 1.4054
# restart: 0, epoch: 140, iter: 1, loss: 1.4048
# restart: 0, epoch: 141, iter: 1, loss: 1.4041
# restart: 0, epoch: 142, iter: 1, loss: 1.4034
# restart: 0, epoch: 143, iter: 1, loss: 1.4028
# restart: 0, epoch: 144, iter: 1, loss: 1.4022
# restart: 0, epoch: 145, iter: 1, loss: 1.4016
# restart: 0, epoch: 146, iter: 1, loss: 1.4009
# restart: 0, epoch: 147, iter: 1, loss: 1.4001
# restart: 0, epoch: 148, iter: 1, loss: 1.3996
# restart: 0, epoch: 149, iter: 1, loss: 1.3990
# restart: 0, epoch: 150, iter: 1, loss: 1.3984
# restart: 0, epoch: 151, iter: 1, loss: 1.3978
# restart: 0, epoch: 152, iter: 1, loss: 1.3972
# restart: 0, epoch: 153, iter: 1, loss: 1.3965
# restart: 0, epoch: 154, iter: 1, loss: 1.3960
# restart: 0, epoch: 155, iter: 1, loss: 1.3954
# restart: 0, epoch: 156, iter: 1, loss: 1.3948
# restart: 0, epoch: 157, iter: 1, loss: 1.3942
# restart: 0, epoch: 158, iter: 1, loss: 1.3936
# restart: 0, epoch: 159, iter: 1, loss: 1.3930
# restart: 0, epoch: 160, iter: 1, loss: 1.3924
# restart: 0, epoch: 161, iter: 1, loss: 1.3919
# restart: 0, epoch: 162, iter: 1, loss: 1.3913
# restart: 0, epoch: 163, iter: 1, loss: 1.3907
# restart: 0, epoch: 164, iter: 1, loss: 1.3902
# restart: 0, epoch: 165, iter: 1, loss: 1.3896
# restart: 0, epoch: 166, iter: 1, loss: 1.3891
# restart: 0, epoch: 167, iter: 1, loss: 1.3885
# restart: 0, epoch: 168, iter: 1, loss: 1.3880
# restart: 0, epoch: 169, iter: 1, loss: 1.3875
# restart: 0, epoch: 170, iter: 1, loss: 1.3870
# restart: 0, epoch: 171, iter: 1, loss: 1.3864
# restart: 0, epoch: 172, iter: 1, loss: 1.3859
# restart: 0, epoch: 173, iter: 1, loss: 1.3855
# restart: 0, epoch: 174, iter: 1, loss: 1.3851
# restart: 0, epoch: 175, iter: 1, loss: 1.3845
# restart: 0, epoch: 176, iter: 1, loss: 1.3847
# restart: 0, epoch: 177, iter: 1, loss: 1.3838
# restart: 0, epoch: 178, iter: 1, loss: 1.3839
# restart: 0, epoch: 179, iter: 1, loss: 1.3840
# restart: 0, epoch: 180, iter: 1, loss: 1.3834
# restart: 0, epoch: 181, iter: 1, loss: 1.3833
# restart: 0, epoch: 182, iter: 1, loss: 1.3826
# restart: 0, epoch: 183, iter: 1, loss: 1.3820
# restart: 0, epoch: 184, iter: 1, loss: 1.3815
# restart: 0, epoch: 185, iter: 1, loss: 1.3809
# restart: 0, epoch: 186, iter: 1, loss: 1.3804
# restart: 0, epoch: 187, iter: 1, loss: 1.3800
# restart: 0, epoch: 188, iter: 1, loss: 1.3792
# restart: 0, epoch: 189, iter: 1, loss: 1.3791
# restart: 0, epoch: 190, iter: 1, loss: 1.3783
# restart: 0, epoch: 191, iter: 1, loss: 1.3776
# restart: 0, epoch: 192, iter: 1, loss: 1.3771
# restart: 0, epoch: 193, iter: 1, loss: 1.3764
# restart: 0, epoch: 194, iter: 1, loss: 1.3759
# restart: 0, epoch: 195, iter: 1, loss: 1.3753
# restart: 0, epoch: 196, iter: 1, loss: 1.3748
# restart: 0, epoch: 197, iter: 1, loss: 1.3742
# restart: 0, epoch: 198, iter: 1, loss: 1.3736
# restart: 0, epoch: 199, iter: 1, loss: 1.3731
# restart: 0, epoch: 200, iter: 1, loss: 1.3725
# restart: 0, epoch: 201, iter: 1, loss: 1.3720
# restart: 0, epoch: 202, iter: 1, loss: 1.3715
# restart: 0, epoch: 203, iter: 1, loss: 1.3709
# restart: 0, epoch: 204, iter: 1, loss: 1.3705
# restart: 0, epoch: 205, iter: 1, loss: 1.3699
# restart: 0, epoch: 206, iter: 1, loss: 1.3694
# restart: 0, epoch: 207, iter: 1, loss: 1.3690
# restart: 0, epoch: 208, iter: 1, loss: 1.3685
# restart: 0, epoch: 209, iter: 1, loss: 1.3680
# restart: 0, epoch: 210, iter: 1, loss: 1.3677
# restart: 0, epoch: 211, iter: 1, loss: 1.3671
# restart: 0, epoch: 212, iter: 1, loss: 1.3666
# restart: 0, epoch: 213, iter: 1, loss: 1.3661
# restart: 0, epoch: 214, iter: 1, loss: 1.3656
# restart: 0, epoch: 215, iter: 1, loss: 1.3652
# restart: 0, epoch: 216, iter: 1, loss: 1.3648
# restart: 0, epoch: 217, iter: 1, loss: 1.3643
# restart: 0, epoch: 218, iter: 1, loss: 1.3638
# restart: 0, epoch: 219, iter: 1, loss: 1.3633
# restart: 0, epoch: 220, iter: 1, loss: 1.3629
# restart: 0, epoch: 221, iter: 1, loss: 1.3625
# restart: 0, epoch: 222, iter: 1, loss: 1.3620
# restart: 0, epoch: 223, iter: 1, loss: 1.3616
# restart: 0, epoch: 224, iter: 1, loss: 1.3611
# restart: 0, epoch: 225, iter: 1, loss: 1.3607
# restart: 0, epoch: 226, iter: 1, loss: 1.3602
# restart: 0, epoch: 227, iter: 1, loss: 1.3598
# restart: 0, epoch: 228, iter: 1, loss: 1.3593
# restart: 0, epoch: 229, iter: 1, loss: 1.3589
# restart: 0, epoch: 230, iter: 1, loss: 1.3585
# restart: 0, epoch: 231, iter: 1, loss: 1.3580
# restart: 0, epoch: 232, iter: 1, loss: 1.3576
# restart: 0, epoch: 233, iter: 1, loss: 1.3572
# restart: 0, epoch: 234, iter: 1, loss: 1.3568
# restart: 0, epoch: 235, iter: 1, loss: 1.3564
# restart: 0, epoch: 236, iter: 1, loss: 1.3559
# restart: 0, epoch: 237, iter: 1, loss: 1.3555
# restart: 0, epoch: 238, iter: 1, loss: 1.3551
# restart: 0, epoch: 239, iter: 1, loss: 1.3547
# restart: 0, epoch: 240, iter: 1, loss: 1.3543
# restart: 0, epoch: 241, iter: 1, loss: 1.3539
# restart: 0, epoch: 242, iter: 1, loss: 1.3535
# restart: 0, epoch: 243, iter: 1, loss: 1.3531
# restart: 0, epoch: 244, iter: 1, loss: 1.3527
# restart: 0, epoch: 245, iter: 1, loss: 1.3522
# restart: 0, epoch: 246, iter: 1, loss: 1.3518
# restart: 0, epoch: 247, iter: 1, loss: 1.3514
# restart: 0, epoch: 248, iter: 1, loss: 1.3510
# restart: 0, epoch: 249, iter: 1, loss: 1.3506
# restart: 0, epoch: 250, iter: 1, loss: 1.3503
# restart: 0, epoch: 251, iter: 1, loss: 1.3499
# restart: 0, epoch: 252, iter: 1, loss: 1.3495
# restart: 0, epoch: 253, iter: 1, loss: 1.3491
# restart: 0, epoch: 254, iter: 1, loss: 1.3487
# restart: 0, epoch: 255, iter: 1, loss: 1.3483
# restart: 0, epoch: 256, iter: 1, loss: 1.3479
# restart: 0, epoch: 257, iter: 1, loss: 1.3475
# restart: 0, epoch: 258, iter: 1, loss: 1.3471
# restart: 0, epoch: 259, iter: 1, loss: 1.3467
# restart: 0, epoch: 260, iter: 1, loss: 1.3463
# restart: 0, epoch: 261, iter: 1, loss: 1.3459
# restart: 0, epoch: 262, iter: 1, loss: 1.3455
# restart: 0, epoch: 263, iter: 1, loss: 1.3451
# restart: 0, epoch: 264, iter: 1, loss: 1.3447
# restart: 0, epoch: 265, iter: 1, loss: 1.3443
# restart: 0, epoch: 266, iter: 1, loss: 1.3439
# restart: 0, epoch: 267, iter: 1, loss: 1.3435
# restart: 0, epoch: 268, iter: 1, loss: 1.3432
# restart: 0, epoch: 269, iter: 1, loss: 1.3428
# restart: 0, epoch: 270, iter: 1, loss: 1.3424
# restart: 0, epoch: 271, iter: 1, loss: 1.3420
# restart: 0, epoch: 272, iter: 1, loss: 1.3416
# restart: 0, epoch: 273, iter: 1, loss: 1.3412
# restart: 0, epoch: 274, iter: 1, loss: 1.3409
# restart: 0, epoch: 275, iter: 1, loss: 1.3405
# restart: 0, epoch: 276, iter: 1, loss: 1.3401
# restart: 0, epoch: 277, iter: 1, loss: 1.3397
# restart: 0, epoch: 278, iter: 1, loss: 1.3394
# restart: 0, epoch: 279, iter: 1, loss: 1.3390
# restart: 0, epoch: 280, iter: 1, loss: 1.3386
# restart: 0, epoch: 281, iter: 1, loss: 1.3382
# restart: 0, epoch: 282, iter: 1, loss: 1.3379
# restart: 0, epoch: 283, iter: 1, loss: 1.3375
# restart: 0, epoch: 284, iter: 1, loss: 1.3371
# restart: 0, epoch: 285, iter: 1, loss: 1.3368
# restart: 0, epoch: 286, iter: 1, loss: 1.3364
# restart: 0, epoch: 287, iter: 1, loss: 1.3360
# restart: 0, epoch: 288, iter: 1, loss: 1.3357
# restart: 0, epoch: 289, iter: 1, loss: 1.3354
# restart: 0, epoch: 290, iter: 1, loss: 1.3350
# restart: 0, epoch: 291, iter: 1, loss: 1.3346
# restart: 0, epoch: 292, iter: 1, loss: 1.3343
# restart: 0, epoch: 293, iter: 1, loss: 1.3339
# restart: 0, epoch: 294, iter: 1, loss: 1.3335
# restart: 0, epoch: 295, iter: 1, loss: 1.3331
# restart: 0, epoch: 296, iter: 1, loss: 1.3328
# restart: 0, epoch: 297, iter: 1, loss: 1.3325
# restart: 0, epoch: 298, iter: 1, loss: 1.3321
# restart: 0, epoch: 299, iter: 1, loss: 1.3317
# restart: 0, epoch: 300, iter: 1, loss: 1.3315
# restart: 0, epoch: 301, iter: 1, loss: 1.3310
# restart: 0, epoch: 302, iter: 1, loss: 1.3306
# restart: 0, epoch: 303, iter: 1, loss: 1.3302
# restart: 0, epoch: 304, iter: 1, loss: 1.3299
# restart: 0, epoch: 305, iter: 1, loss: 1.3295
# restart: 0, epoch: 306, iter: 1, loss: 1.3291
# restart: 0, epoch: 307, iter: 1, loss: 1.3288
# restart: 0, epoch: 308, iter: 1, loss: 1.3284
# restart: 0, epoch: 309, iter: 1, loss: 1.3281
# restart: 0, epoch: 310, iter: 1, loss: 1.3277
# restart: 0, epoch: 311, iter: 1, loss: 1.3274
# restart: 0, epoch: 312, iter: 1, loss: 1.3270
# restart: 0, epoch: 313, iter: 1, loss: 1.3266
# restart: 0, epoch: 314, iter: 1, loss: 1.3262
# restart: 0, epoch: 315, iter: 1, loss: 1.3259
# restart: 0, epoch: 316, iter: 1, loss: 1.3255
# restart: 0, epoch: 317, iter: 1, loss: 1.3251
# restart: 0, epoch: 318, iter: 1, loss: 1.3248
# restart: 0, epoch: 319, iter: 1, loss: 1.3244
# restart: 0, epoch: 320, iter: 1, loss: 1.3240
# restart: 0, epoch: 321, iter: 1, loss: 1.3237
# restart: 0, epoch: 322, iter: 1, loss: 1.3233
# restart: 0, epoch: 323, iter: 1, loss: 1.3230
# restart: 0, epoch: 324, iter: 1, loss: 1.3228
# restart: 0, epoch: 325, iter: 1, loss: 1.3226
# restart: 0, epoch: 326, iter: 1, loss: 1.3220
# restart: 0, epoch: 327, iter: 1, loss: 1.3217
# restart: 0, epoch: 328, iter: 1, loss: 1.3213
# restart: 0, epoch: 329, iter: 1, loss: 1.3211
# restart: 0, epoch: 330, iter: 1, loss: 1.3206
# restart: 0, epoch: 331, iter: 1, loss: 1.3202
# restart: 0, epoch: 332, iter: 1, loss: 1.3200
# restart: 0, epoch: 333, iter: 1, loss: 1.3197
# restart: 0, epoch: 334, iter: 1, loss: 1.3192
# restart: 0, epoch: 335, iter: 1, loss: 1.3191
# restart: 0, epoch: 336, iter: 1, loss: 1.3187
# restart: 0, epoch: 337, iter: 1, loss: 1.3181
# restart: 0, epoch: 338, iter: 1, loss: 1.3180
# restart: 0, epoch: 339, iter: 1, loss: 1.3176
# restart: 0, epoch: 340, iter: 1, loss: 1.3174
# restart: 0, epoch: 341, iter: 1, loss: 1.3173
# restart: 0, epoch: 342, iter: 1, loss: 1.3172
# restart: 0, epoch: 343, iter: 1, loss: 1.3166
# restart: 0, epoch: 344, iter: 1, loss: 1.3165
# restart: 0, epoch: 345, iter: 1, loss: 1.3161
# restart: 0, epoch: 346, iter: 1, loss: 1.3158
# restart: 0, epoch: 347, iter: 1, loss: 1.3156
# restart: 0, epoch: 348, iter: 1, loss: 1.3151
# restart: 0, epoch: 349, iter: 1, loss: 1.3148
# restart: 0, epoch: 350, iter: 1, loss: 1.3144
# restart: 0, epoch: 351, iter: 1, loss: 1.3142
# restart: 0, epoch: 352, iter: 1, loss: 1.3136
# restart: 0, epoch: 353, iter: 1, loss: 1.3131
# restart: 0, epoch: 354, iter: 1, loss: 1.3129
# restart: 0, epoch: 355, iter: 1, loss: 1.3124
# restart: 0, epoch: 356, iter: 1, loss: 1.3122
# restart: 0, epoch: 357, iter: 1, loss: 1.3123
# restart: 0, epoch: 358, iter: 1, loss: 1.3115
# restart: 0, epoch: 359, iter: 1, loss: 1.3115
# restart: 0, epoch: 360, iter: 1, loss: 1.3114
# restart: 0, epoch: 361, iter: 1, loss: 1.3112
# restart: 0, epoch: 362, iter: 1, loss: 1.3104
# restart: 0, epoch: 363, iter: 1, loss: 1.3101
# restart: 0, epoch: 364, iter: 1, loss: 1.3097
# restart: 0, epoch: 365, iter: 1, loss: 1.3094
# restart: 0, epoch: 366, iter: 1, loss: 1.3091
# restart: 0, epoch: 367, iter: 1, loss: 1.3087
# restart: 0, epoch: 368, iter: 1, loss: 1.3082
# restart: 0, epoch: 369, iter: 1, loss: 1.3078
# restart: 0, epoch: 370, iter: 1, loss: 1.3075
# restart: 0, epoch: 371, iter: 1, loss: 1.3072
# restart: 0, epoch: 372, iter: 1, loss: 1.3069
# restart: 0, epoch: 373, iter: 1, loss: 1.3064
# restart: 0, epoch: 374, iter: 1, loss: 1.3060
# restart: 0, epoch: 375, iter: 1, loss: 1.3056
# restart: 0, epoch: 376, iter: 1, loss: 1.3053
# restart: 0, epoch: 377, iter: 1, loss: 1.3048
# restart: 0, epoch: 378, iter: 1, loss: 1.3045
# restart: 0, epoch: 379, iter: 1, loss: 1.3041
# restart: 0, epoch: 380, iter: 1, loss: 1.3038
# restart: 0, epoch: 381, iter: 1, loss: 1.3034
# restart: 0, epoch: 382, iter: 1, loss: 1.3031
# restart: 0, epoch: 383, iter: 1, loss: 1.3027
# restart: 0, epoch: 384, iter: 1, loss: 1.3024
# restart: 0, epoch: 385, iter: 1, loss: 1.3020
# restart: 0, epoch: 386, iter: 1, loss: 1.3017
# restart: 0, epoch: 387, iter: 1, loss: 1.3013
# restart: 0, epoch: 388, iter: 1, loss: 1.3010
# restart: 0, epoch: 389, iter: 1, loss: 1.3007
# restart: 0, epoch: 390, iter: 1, loss: 1.3003
# restart: 0, epoch: 391, iter: 1, loss: 1.3000
# restart: 0, epoch: 392, iter: 1, loss: 1.2997
# restart: 0, epoch: 393, iter: 1, loss: 1.2993
# restart: 0, epoch: 394, iter: 1, loss: 1.2990
# restart: 0, epoch: 395, iter: 1, loss: 1.2987
# restart: 0, epoch: 396, iter: 1, loss: 1.2983
# restart: 0, epoch: 397, iter: 1, loss: 1.2980
# restart: 0, epoch: 398, iter: 1, loss: 1.2977
# restart: 0, epoch: 399, iter: 1, loss: 1.2974
# restart: 0, epoch: 400, iter: 1, loss: 1.2970
# restart: 0, epoch: 401, iter: 1, loss: 1.2967
# restart: 0, epoch: 402, iter: 1, loss: 1.2964
# restart: 0, epoch: 403, iter: 1, loss: 1.2961
# restart: 0, epoch: 404, iter: 1, loss: 1.2958
# restart: 0, epoch: 405, iter: 1, loss: 1.2954
# restart: 0, epoch: 406, iter: 1, loss: 1.2951
# restart: 0, epoch: 407, iter: 1, loss: 1.2948
# restart: 0, epoch: 408, iter: 1, loss: 1.2945
# restart: 0, epoch: 409, iter: 1, loss: 1.2942
# restart: 0, epoch: 410, iter: 1, loss: 1.2939
# restart: 0, epoch: 411, iter: 1, loss: 1.2935
# restart: 0, epoch: 412, iter: 1, loss: 1.2932
# restart: 0, epoch: 413, iter: 1, loss: 1.2929
# restart: 0, epoch: 414, iter: 1, loss: 1.2926
# restart: 0, epoch: 415, iter: 1, loss: 1.2923
# restart: 0, epoch: 416, iter: 1, loss: 1.2920
# restart: 0, epoch: 417, iter: 1, loss: 1.2917
# restart: 0, epoch: 418, iter: 1, loss: 1.2914
# restart: 0, epoch: 419, iter: 1, loss: 1.2911
# restart: 0, epoch: 420, iter: 1, loss: 1.2907
# restart: 0, epoch: 421, iter: 1, loss: 1.2904
# restart: 0, epoch: 422, iter: 1, loss: 1.2901
# restart: 0, epoch: 423, iter: 1, loss: 1.2898
# restart: 0, epoch: 424, iter: 1, loss: 1.2895
# restart: 0, epoch: 425, iter: 1, loss: 1.2892
# restart: 0, epoch: 426, iter: 1, loss: 1.2889
# restart: 0, epoch: 427, iter: 1, loss: 1.2886
# restart: 0, epoch: 428, iter: 1, loss: 1.2883
# restart: 0, epoch: 429, iter: 1, loss: 1.2880
# restart: 0, epoch: 430, iter: 1, loss: 1.2877
# restart: 0, epoch: 431, iter: 1, loss: 1.2873
# restart: 0, epoch: 432, iter: 1, loss: 1.2870
# restart: 0, epoch: 433, iter: 1, loss: 1.2867
# restart: 0, epoch: 434, iter: 1, loss: 1.2864
# restart: 0, epoch: 435, iter: 1, loss: 1.2861
# restart: 0, epoch: 436, iter: 1, loss: 1.2858
# restart: 0, epoch: 437, iter: 1, loss: 1.2855
# restart: 0, epoch: 438, iter: 1, loss: 1.2852
# restart: 0, epoch: 439, iter: 1, loss: 1.2849
# restart: 0, epoch: 440, iter: 1, loss: 1.2846
# restart: 0, epoch: 441, iter: 1, loss: 1.2843
# restart: 0, epoch: 442, iter: 1, loss: 1.2840
# restart: 0, epoch: 443, iter: 1, loss: 1.2837
# restart: 0, epoch: 444, iter: 1, loss: 1.2834
# restart: 0, epoch: 445, iter: 1, loss: 1.2831
# restart: 0, epoch: 446, iter: 1, loss: 1.2828
# restart: 0, epoch: 447, iter: 1, loss: 1.2824
# restart: 0, epoch: 448, iter: 1, loss: 1.2821
# restart: 0, epoch: 449, iter: 1, loss: 1.2818
# restart: 0, epoch: 450, iter: 1, loss: 1.2815
# restart: 0, epoch: 451, iter: 1, loss: 1.2812
# restart: 0, epoch: 452, iter: 1, loss: 1.2809
# restart: 0, epoch: 453, iter: 1, loss: 1.2806
# restart: 0, epoch: 454, iter: 1, loss: 1.2803
# restart: 0, epoch: 455, iter: 1, loss: 1.2800
# restart: 0, epoch: 456, iter: 1, loss: 1.2797
# restart: 0, epoch: 457, iter: 1, loss: 1.2794
# restart: 0, epoch: 458, iter: 1, loss: 1.2791
# restart: 0, epoch: 459, iter: 1, loss: 1.2788
# restart: 0, epoch: 460, iter: 1, loss: 1.2785
# restart: 0, epoch: 461, iter: 1, loss: 1.2782
# restart: 0, epoch: 462, iter: 1, loss: 1.2779
# restart: 0, epoch: 463, iter: 1, loss: 1.2776
# restart: 0, epoch: 464, iter: 1, loss: 1.2773
# restart: 0, epoch: 465, iter: 1, loss: 1.2770
# restart: 0, epoch: 466, iter: 1, loss: 1.2767
# restart: 0, epoch: 467, iter: 1, loss: 1.2765
# restart: 0, epoch: 468, iter: 1, loss: 1.2762
# restart: 0, epoch: 469, iter: 1, loss: 1.2759
# restart: 0, epoch: 470, iter: 1, loss: 1.2756
# restart: 0, epoch: 471, iter: 1, loss: 1.2753
# restart: 0, epoch: 472, iter: 1, loss: 1.2750
# restart: 0, epoch: 473, iter: 1, loss: 1.2747
# restart: 0, epoch: 474, iter: 1, loss: 1.2744
# restart: 0, epoch: 475, iter: 1, loss: 1.2740
# restart: 0, epoch: 476, iter: 1, loss: 1.2738
# restart: 0, epoch: 477, iter: 1, loss: 1.2735
# restart: 0, epoch: 478, iter: 1, loss: 1.2731
# restart: 0, epoch: 479, iter: 1, loss: 1.2729
# restart: 0, epoch: 480, iter: 1, loss: 1.2726
# restart: 0, epoch: 481, iter: 1, loss: 1.2722
# restart: 0, epoch: 482, iter: 1, loss: 1.2720
# restart: 0, epoch: 483, iter: 1, loss: 1.2717
# restart: 0, epoch: 484, iter: 1, loss: 1.2713
# restart: 0, epoch: 485, iter: 1, loss: 1.2710
# restart: 0, epoch: 486, iter: 1, loss: 1.2708
# restart: 0, epoch: 487, iter: 1, loss: 1.2704
# restart: 0, epoch: 488, iter: 1, loss: 1.2701
# restart: 0, epoch: 489, iter: 1, loss: 1.2699
# restart: 0, epoch: 490, iter: 1, loss: 1.2696
# restart: 0, epoch: 491, iter: 1, loss: 1.2693
# restart: 0, epoch: 492, iter: 1, loss: 1.2690
# restart: 0, epoch: 493, iter: 1, loss: 1.2687
# restart: 0, epoch: 494, iter: 1, loss: 1.2684
# restart: 0, epoch: 495, iter: 1, loss: 1.2681
# restart: 0, epoch: 496, iter: 1, loss: 1.2678
# restart: 0, epoch: 497, iter: 1, loss: 1.2675
# restart: 0, epoch: 498, iter: 1, loss: 1.2672
# restart: 0, epoch: 499, iter: 1, loss: 1.2670
# restart: 0, epoch: 500, iter: 1, loss: 1.2668
# restart: 0, epoch: 501, iter: 1, loss: 1.2665
# restart: 0, epoch: 502, iter: 1, loss: 1.2662
# restart: 0, epoch: 503, iter: 1, loss: 1.2659
# restart: 0, epoch: 504, iter: 1, loss: 1.2656
# restart: 0, epoch: 505, iter: 1, loss: 1.2652
# restart: 0, epoch: 506, iter: 1, loss: 1.2649
# restart: 0, epoch: 507, iter: 1, loss: 1.2647
# restart: 0, epoch: 508, iter: 1, loss: 1.2645
# restart: 0, epoch: 509, iter: 1, loss: 1.2644
# restart: 0, epoch: 510, iter: 1, loss: 1.2639
# restart: 0, epoch: 511, iter: 1, loss: 1.2637
# restart: 0, epoch: 512, iter: 1, loss: 1.2634
# restart: 0, epoch: 513, iter: 1, loss: 1.2632
# restart: 0, epoch: 514, iter: 1, loss: 1.2628
# restart: 0, epoch: 515, iter: 1, loss: 1.2626
# restart: 0, epoch: 516, iter: 1, loss: 1.2624
# restart: 0, epoch: 517, iter: 1, loss: 1.2620
# restart: 0, epoch: 518, iter: 1, loss: 1.2618
# restart: 0, epoch: 519, iter: 1, loss: 1.2614
# restart: 0, epoch: 520, iter: 1, loss: 1.2611
# restart: 0, epoch: 521, iter: 1, loss: 1.2608
# restart: 0, epoch: 522, iter: 1, loss: 1.2605
# restart: 0, epoch: 523, iter: 1, loss: 1.2601
# restart: 0, epoch: 524, iter: 1, loss: 1.2598
# restart: 0, epoch: 525, iter: 1, loss: 1.2595
# restart: 0, epoch: 526, iter: 1, loss: 1.2592
# restart: 0, epoch: 527, iter: 1, loss: 1.2588
# restart: 0, epoch: 528, iter: 1, loss: 1.2585
# restart: 0, epoch: 529, iter: 1, loss: 1.2583
# restart: 0, epoch: 530, iter: 1, loss: 1.2581
# restart: 0, epoch: 531, iter: 1, loss: 1.2577
# restart: 0, epoch: 532, iter: 1, loss: 1.2574
# restart: 0, epoch: 533, iter: 1, loss: 1.2572
# restart: 0, epoch: 534, iter: 1, loss: 1.2569
# restart: 0, epoch: 535, iter: 1, loss: 1.2564
# restart: 0, epoch: 536, iter: 1, loss: 1.2561
# restart: 0, epoch: 537, iter: 1, loss: 1.2558
# restart: 0, epoch: 538, iter: 1, loss: 1.2555
# restart: 0, epoch: 539, iter: 1, loss: 1.2552
# restart: 0, epoch: 540, iter: 1, loss: 1.2550
# restart: 0, epoch: 541, iter: 1, loss: 1.2549
# restart: 0, epoch: 542, iter: 1, loss: 1.2545
# restart: 0, epoch: 543, iter: 1, loss: 1.2544
# restart: 0, epoch: 544, iter: 1, loss: 1.2543
# restart: 0, epoch: 545, iter: 1, loss: 1.2540
# restart: 0, epoch: 546, iter: 1, loss: 1.2539
# restart: 0, epoch: 547, iter: 1, loss: 1.2535
# restart: 0, epoch: 548, iter: 1, loss: 1.2532
# restart: 0, epoch: 549, iter: 1, loss: 1.2528
# restart: 0, epoch: 550, iter: 1, loss: 1.2525
# restart: 0, epoch: 551, iter: 1, loss: 1.2521
# restart: 0, epoch: 552, iter: 1, loss: 1.2518
# restart: 0, epoch: 553, iter: 1, loss: 1.2515
# restart: 0, epoch: 554, iter: 1, loss: 1.2514
# restart: 0, epoch: 555, iter: 1, loss: 1.2515
# restart: 0, epoch: 556, iter: 1, loss: 1.2516
# restart: 0, epoch: 557, iter: 1, loss: 1.2508
# restart: 0, epoch: 558, iter: 1, loss: 1.2506
# restart: 0, epoch: 559, iter: 1, loss: 1.2502
# restart: 0, epoch: 560, iter: 1, loss: 1.2502
# restart: 0, epoch: 561, iter: 1, loss: 1.2494
# restart: 0, epoch: 562, iter: 1, loss: 1.2491
# restart: 0, epoch: 563, iter: 1, loss: 1.2488
# restart: 0, epoch: 564, iter: 1, loss: 1.2484
# restart: 0, epoch: 565, iter: 1, loss: 1.2482
# restart: 0, epoch: 566, iter: 1, loss: 1.2479
# restart: 0, epoch: 567, iter: 1, loss: 1.2475
# restart: 0, epoch: 568, iter: 1, loss: 1.2471
# restart: 0, epoch: 569, iter: 1, loss: 1.2469
# restart: 0, epoch: 570, iter: 1, loss: 1.2466
# restart: 0, epoch: 571, iter: 1, loss: 1.2461
# restart: 0, epoch: 572, iter: 1, loss: 1.2459
# restart: 0, epoch: 573, iter: 1, loss: 1.2454
# restart: 0, epoch: 574, iter: 1, loss: 1.2451
# restart: 0, epoch: 575, iter: 1, loss: 1.2448
# restart: 0, epoch: 576, iter: 1, loss: 1.2445
# restart: 0, epoch: 577, iter: 1, loss: 1.2441
# restart: 0, epoch: 578, iter: 1, loss: 1.2439
# restart: 0, epoch: 579, iter: 1, loss: 1.2435
# restart: 0, epoch: 580, iter: 1, loss: 1.2433
# restart: 0, epoch: 581, iter: 1, loss: 1.2429
# restart: 0, epoch: 582, iter: 1, loss: 1.2426
# restart: 0, epoch: 583, iter: 1, loss: 1.2422
# restart: 0, epoch: 584, iter: 1, loss: 1.2419
# restart: 0, epoch: 585, iter: 1, loss: 1.2415
# restart: 0, epoch: 586, iter: 1, loss: 1.2412
# restart: 0, epoch: 587, iter: 1, loss: 1.2408
# restart: 0, epoch: 588, iter: 1, loss: 1.2406
# restart: 0, epoch: 589, iter: 1, loss: 1.2403
# restart: 0, epoch: 590, iter: 1, loss: 1.2401
# restart: 0, epoch: 591, iter: 1, loss: 1.2397
# restart: 0, epoch: 592, iter: 1, loss: 1.2394
# restart: 0, epoch: 593, iter: 1, loss: 1.2391
# restart: 0, epoch: 594, iter: 1, loss: 1.2387
# restart: 0, epoch: 595, iter: 1, loss: 1.2384
# restart: 0, epoch: 596, iter: 1, loss: 1.2381
# restart: 0, epoch: 597, iter: 1, loss: 1.2378
# restart: 0, epoch: 598, iter: 1, loss: 1.2374
# restart: 0, epoch: 599, iter: 1, loss: 1.2371
# restart: 0, epoch: 600, iter: 1, loss: 1.2368
# restart: 0, epoch: 601, iter: 1, loss: 1.2366
# restart: 0, epoch: 602, iter: 1, loss: 1.2364
# restart: 0, epoch: 603, iter: 1, loss: 1.2360
# restart: 0, epoch: 604, iter: 1, loss: 1.2357
# restart: 0, epoch: 605, iter: 1, loss: 1.2355
# restart: 0, epoch: 606, iter: 1, loss: 1.2351
# restart: 0, epoch: 607, iter: 1, loss: 1.2348
# restart: 0, epoch: 608, iter: 1, loss: 1.2345
# restart: 0, epoch: 609, iter: 1, loss: 1.2342
# restart: 0, epoch: 610, iter: 1, loss: 1.2339
# restart: 0, epoch: 611, iter: 1, loss: 1.2335
# restart: 0, epoch: 612, iter: 1, loss: 1.2332
# restart: 0, epoch: 613, iter: 1, loss: 1.2329
# restart: 0, epoch: 614, iter: 1, loss: 1.2326
# restart: 0, epoch: 615, iter: 1, loss: 1.2323
# restart: 0, epoch: 616, iter: 1, loss: 1.2320
# restart: 0, epoch: 617, iter: 1, loss: 1.2317
# restart: 0, epoch: 618, iter: 1, loss: 1.2314
# restart: 0, epoch: 619, iter: 1, loss: 1.2311
# restart: 0, epoch: 620, iter: 1, loss: 1.2308
# restart: 0, epoch: 621, iter: 1, loss: 1.2304
# restart: 0, epoch: 622, iter: 1, loss: 1.2302
# restart: 0, epoch: 623, iter: 1, loss: 1.2298
# restart: 0, epoch: 624, iter: 1, loss: 1.2296
# restart: 0, epoch: 625, iter: 1, loss: 1.2293
# restart: 0, epoch: 626, iter: 1, loss: 1.2291
# restart: 0, epoch: 627, iter: 1, loss: 1.2290
# restart: 0, epoch: 628, iter: 1, loss: 1.2285
# restart: 0, epoch: 629, iter: 1, loss: 1.2283
# restart: 0, epoch: 630, iter: 1, loss: 1.2279
# restart: 0, epoch: 631, iter: 1, loss: 1.2277
# restart: 0, epoch: 632, iter: 1, loss: 1.2274
# restart: 0, epoch: 633, iter: 1, loss: 1.2270
# restart: 0, epoch: 634, iter: 1, loss: 1.2268
# restart: 0, epoch: 635, iter: 1, loss: 1.2265
# restart: 0, epoch: 636, iter: 1, loss: 1.2262
# restart: 0, epoch: 637, iter: 1, loss: 1.2258
# restart: 0, epoch: 638, iter: 1, loss: 1.2255
# restart: 0, epoch: 639, iter: 1, loss: 1.2252
# restart: 0, epoch: 640, iter: 1, loss: 1.2249
# restart: 0, epoch: 641, iter: 1, loss: 1.2246
# restart: 0, epoch: 642, iter: 1, loss: 1.2243
# restart: 0, epoch: 643, iter: 1, loss: 1.2240
# restart: 0, epoch: 644, iter: 1, loss: 1.2237
# restart: 0, epoch: 645, iter: 1, loss: 1.2234
# restart: 0, epoch: 646, iter: 1, loss: 1.2232
# restart: 0, epoch: 647, iter: 1, loss: 1.2228
# restart: 0, epoch: 648, iter: 1, loss: 1.2225
# restart: 0, epoch: 649, iter: 1, loss: 1.2222
# restart: 0, epoch: 650, iter: 1, loss: 1.2218
# restart: 0, epoch: 651, iter: 1, loss: 1.2215
# restart: 0, epoch: 652, iter: 1, loss: 1.2212
# restart: 0, epoch: 653, iter: 1, loss: 1.2209
# restart: 0, epoch: 654, iter: 1, loss: 1.2206
# restart: 0, epoch: 655, iter: 1, loss: 1.2203
# restart: 0, epoch: 656, iter: 1, loss: 1.2200
# restart: 0, epoch: 657, iter: 1, loss: 1.2197
# restart: 0, epoch: 658, iter: 1, loss: 1.2195
# restart: 0, epoch: 659, iter: 1, loss: 1.2192
# restart: 0, epoch: 660, iter: 1, loss: 1.2189
# restart: 0, epoch: 661, iter: 1, loss: 1.2186
# restart: 0, epoch: 662, iter: 1, loss: 1.2183
# restart: 0, epoch: 663, iter: 1, loss: 1.2179
# restart: 0, epoch: 664, iter: 1, loss: 1.2176
# restart: 0, epoch: 665, iter: 1, loss: 1.2173
# restart: 0, epoch: 666, iter: 1, loss: 1.2170
# restart: 0, epoch: 667, iter: 1, loss: 1.2167
# restart: 0, epoch: 668, iter: 1, loss: 1.2165
# restart: 0, epoch: 669, iter: 1, loss: 1.2163
# restart: 0, epoch: 670, iter: 1, loss: 1.2159
# restart: 0, epoch: 671, iter: 1, loss: 1.2157
# restart: 0, epoch: 672, iter: 1, loss: 1.2154
# restart: 0, epoch: 673, iter: 1, loss: 1.2151
# restart: 0, epoch: 674, iter: 1, loss: 1.2148
# restart: 0, epoch: 675, iter: 1, loss: 1.2146
# restart: 0, epoch: 676, iter: 1, loss: 1.2143
# restart: 0, epoch: 677, iter: 1, loss: 1.2139
# restart: 0, epoch: 678, iter: 1, loss: 1.2137
# restart: 0, epoch: 679, iter: 1, loss: 1.2133
# restart: 0, epoch: 680, iter: 1, loss: 1.2129
# restart: 0, epoch: 681, iter: 1, loss: 1.2127
# restart: 0, epoch: 682, iter: 1, loss: 1.2123
# restart: 0, epoch: 683, iter: 1, loss: 1.2121
# restart: 0, epoch: 684, iter: 1, loss: 1.2117
# restart: 0, epoch: 685, iter: 1, loss: 1.2114
# restart: 0, epoch: 686, iter: 1, loss: 1.2111
# restart: 0, epoch: 687, iter: 1, loss: 1.2108
# restart: 0, epoch: 688, iter: 1, loss: 1.2105
# restart: 0, epoch: 689, iter: 1, loss: 1.2102
# restart: 0, epoch: 690, iter: 1, loss: 1.2099
# restart: 0, epoch: 691, iter: 1, loss: 1.2095
# restart: 0, epoch: 692, iter: 1, loss: 1.2092
# restart: 0, epoch: 693, iter: 1, loss: 1.2089
# restart: 0, epoch: 694, iter: 1, loss: 1.2086
# restart: 0, epoch: 695, iter: 1, loss: 1.2083
# restart: 0, epoch: 696, iter: 1, loss: 1.2081
# restart: 0, epoch: 697, iter: 1, loss: 1.2079
# restart: 0, epoch: 698, iter: 1, loss: 1.2076
# restart: 0, epoch: 699, iter: 1, loss: 1.2072
# restart: 0, epoch: 700, iter: 1, loss: 1.2069
# restart: 0, epoch: 701, iter: 1, loss: 1.2066
# restart: 0, epoch: 702, iter: 1, loss: 1.2063
# restart: 0, epoch: 703, iter: 1, loss: 1.2060
# restart: 0, epoch: 704, iter: 1, loss: 1.2056
# restart: 0, epoch: 705, iter: 1, loss: 1.2054
# restart: 0, epoch: 706, iter: 1, loss: 1.2050
# restart: 0, epoch: 707, iter: 1, loss: 1.2048
# restart: 0, epoch: 708, iter: 1, loss: 1.2045
# restart: 0, epoch: 709, iter: 1, loss: 1.2042
# restart: 0, epoch: 710, iter: 1, loss: 1.2039
# restart: 0, epoch: 711, iter: 1, loss: 1.2035
# restart: 0, epoch: 712, iter: 1, loss: 1.2032
# restart: 0, epoch: 713, iter: 1, loss: 1.2030
# restart: 0, epoch: 714, iter: 1, loss: 1.2026
# restart: 0, epoch: 715, iter: 1, loss: 1.2023
# restart: 0, epoch: 716, iter: 1, loss: 1.2020
# restart: 0, epoch: 717, iter: 1, loss: 1.2017
# restart: 0, epoch: 718, iter: 1, loss: 1.2014
# restart: 0, epoch: 719, iter: 1, loss: 1.2012
# restart: 0, epoch: 720, iter: 1, loss: 1.2011
# restart: 0, epoch: 721, iter: 1, loss: 1.2008
# restart: 0, epoch: 722, iter: 1, loss: 1.2007
# restart: 0, epoch: 723, iter: 1, loss: 1.2005
# restart: 0, epoch: 724, iter: 1, loss: 1.2000
# restart: 0, epoch: 725, iter: 1, loss: 1.1997
# restart: 0, epoch: 726, iter: 1, loss: 1.1995
# restart: 0, epoch: 727, iter: 1, loss: 1.1991
# restart: 0, epoch: 728, iter: 1, loss: 1.1988
# restart: 0, epoch: 729, iter: 1, loss: 1.1986
# restart: 0, epoch: 730, iter: 1, loss: 1.1990
# restart: 0, epoch: 731, iter: 1, loss: 1.1981
# restart: 0, epoch: 732, iter: 1, loss: 1.1980
# restart: 0, epoch: 733, iter: 1, loss: 1.1980
# restart: 0, epoch: 734, iter: 1, loss: 1.1977
# restart: 0, epoch: 735, iter: 1, loss: 1.1977
# restart: 0, epoch: 736, iter: 1, loss: 1.1980
# restart: 0, epoch: 737, iter: 1, loss: 1.1973
# restart: 0, epoch: 738, iter: 1, loss: 1.1967
# restart: 0, epoch: 739, iter: 1, loss: 1.1965
# restart: 0, epoch: 740, iter: 1, loss: 1.1962
# restart: 0, epoch: 741, iter: 1, loss: 1.1961
# restart: 0, epoch: 742, iter: 1, loss: 1.1957
# restart: 0, epoch: 743, iter: 1, loss: 1.1952
# restart: 0, epoch: 744, iter: 1, loss: 1.1951
# restart: 0, epoch: 745, iter: 1, loss: 1.1955
# restart: 0, epoch: 746, iter: 1, loss: 1.1945
# restart: 0, epoch: 747, iter: 1, loss: 1.1941
# restart: 0, epoch: 748, iter: 1, loss: 1.1943
# restart: 0, epoch: 749, iter: 1, loss: 1.1937
# restart: 0, epoch: 750, iter: 1, loss: 1.1935
# restart: 0, epoch: 751, iter: 1, loss: 1.1933
# restart: 0, epoch: 752, iter: 1, loss: 1.1930
# restart: 0, epoch: 753, iter: 1, loss: 1.1927
# restart: 0, epoch: 754, iter: 1, loss: 1.1925
# restart: 0, epoch: 755, iter: 1, loss: 1.1920
# restart: 0, epoch: 756, iter: 1, loss: 1.1916
# restart: 0, epoch: 757, iter: 1, loss: 1.1912
# restart: 0, epoch: 758, iter: 1, loss: 1.1908
# restart: 0, epoch: 759, iter: 1, loss: 1.1904
# restart: 0, epoch: 760, iter: 1, loss: 1.1901
# restart: 0, epoch: 761, iter: 1, loss: 1.1897
# restart: 0, epoch: 762, iter: 1, loss: 1.1894
# restart: 0, epoch: 763, iter: 1, loss: 1.1889
# restart: 0, epoch: 764, iter: 1, loss: 1.1886
# restart: 0, epoch: 765, iter: 1, loss: 1.1882
# restart: 0, epoch: 766, iter: 1, loss: 1.1879
# restart: 0, epoch: 767, iter: 1, loss: 1.1877
# restart: 0, epoch: 768, iter: 1, loss: 1.1874
# restart: 0, epoch: 769, iter: 1, loss: 1.1869
# restart: 0, epoch: 770, iter: 1, loss: 1.1866
# restart: 0, epoch: 771, iter: 1, loss: 1.1864
# restart: 0, epoch: 772, iter: 1, loss: 1.1863
# restart: 0, epoch: 773, iter: 1, loss: 1.1857
# restart: 0, epoch: 774, iter: 1, loss: 1.1860
# restart: 0, epoch: 775, iter: 1, loss: 1.1855
# restart: 0, epoch: 776, iter: 1, loss: 1.1855
# restart: 0, epoch: 777, iter: 1, loss: 1.1848
# restart: 0, epoch: 778, iter: 1, loss: 1.1846
# restart: 0, epoch: 779, iter: 1, loss: 1.1842
# restart: 0, epoch: 780, iter: 1, loss: 1.1838
# restart: 0, epoch: 781, iter: 1, loss: 1.1836
# restart: 0, epoch: 782, iter: 1, loss: 1.1832
# restart: 0, epoch: 783, iter: 1, loss: 1.1828
# restart: 0, epoch: 784, iter: 1, loss: 1.1824
# restart: 0, epoch: 785, iter: 1, loss: 1.1820
# restart: 0, epoch: 786, iter: 1, loss: 1.1818
# restart: 0, epoch: 787, iter: 1, loss: 1.1814
# restart: 0, epoch: 788, iter: 1, loss: 1.1812
# restart: 0, epoch: 789, iter: 1, loss: 1.1808
# restart: 0, epoch: 790, iter: 1, loss: 1.1804
# restart: 0, epoch: 791, iter: 1, loss: 1.1801
# restart: 0, epoch: 792, iter: 1, loss: 1.1798
# restart: 0, epoch: 793, iter: 1, loss: 1.1794
# restart: 0, epoch: 794, iter: 1, loss: 1.1791
# restart: 0, epoch: 795, iter: 1, loss: 1.1787
# restart: 0, epoch: 796, iter: 1, loss: 1.1785
# restart: 0, epoch: 797, iter: 1, loss: 1.1782
# restart: 0, epoch: 798, iter: 1, loss: 1.1777
# restart: 0, epoch: 799, iter: 1, loss: 1.1775
# restart: 0, epoch: 800, iter: 1, loss: 1.1771
# restart: 0, epoch: 801, iter: 1, loss: 1.1768
# restart: 0, epoch: 802, iter: 1, loss: 1.1765
# restart: 0, epoch: 803, iter: 1, loss: 1.1761
# restart: 0, epoch: 804, iter: 1, loss: 1.1758
# restart: 0, epoch: 805, iter: 1, loss: 1.1755
# restart: 0, epoch: 806, iter: 1, loss: 1.1752
# restart: 0, epoch: 807, iter: 1, loss: 1.1749
# restart: 0, epoch: 808, iter: 1, loss: 1.1746
# restart: 0, epoch: 809, iter: 1, loss: 1.1742
# restart: 0, epoch: 810, iter: 1, loss: 1.1739
# restart: 0, epoch: 811, iter: 1, loss: 1.1736
# restart: 0, epoch: 812, iter: 1, loss: 1.1733
# restart: 0, epoch: 813, iter: 1, loss: 1.1730
# restart: 0, epoch: 814, iter: 1, loss: 1.1727
# restart: 0, epoch: 815, iter: 1, loss: 1.1723
# restart: 0, epoch: 816, iter: 1, loss: 1.1720
# restart: 0, epoch: 817, iter: 1, loss: 1.1717
# restart: 0, epoch: 818, iter: 1, loss: 1.1714
# restart: 0, epoch: 819, iter: 1, loss: 1.1711
# restart: 0, epoch: 820, iter: 1, loss: 1.1708
# restart: 0, epoch: 821, iter: 1, loss: 1.1705
# restart: 0, epoch: 822, iter: 1, loss: 1.1702
# restart: 0, epoch: 823, iter: 1, loss: 1.1699
# restart: 0, epoch: 824, iter: 1, loss: 1.1696
# restart: 0, epoch: 825, iter: 1, loss: 1.1693
# restart: 0, epoch: 826, iter: 1, loss: 1.1690
# restart: 0, epoch: 827, iter: 1, loss: 1.1686
# restart: 0, epoch: 828, iter: 1, loss: 1.1683
# restart: 0, epoch: 829, iter: 1, loss: 1.1680
# restart: 0, epoch: 830, iter: 1, loss: 1.1677
# restart: 0, epoch: 831, iter: 1, loss: 1.1674
# restart: 0, epoch: 832, iter: 1, loss: 1.1671
# restart: 0, epoch: 833, iter: 1, loss: 1.1668
# restart: 0, epoch: 834, iter: 1, loss: 1.1665
# restart: 0, epoch: 835, iter: 1, loss: 1.1662
# restart: 0, epoch: 836, iter: 1, loss: 1.1659
# restart: 0, epoch: 837, iter: 1, loss: 1.1656
# restart: 0, epoch: 838, iter: 1, loss: 1.1653
# restart: 0, epoch: 839, iter: 1, loss: 1.1650
# restart: 0, epoch: 840, iter: 1, loss: 1.1647
# restart: 0, epoch: 841, iter: 1, loss: 1.1644
# restart: 0, epoch: 842, iter: 1, loss: 1.1641
# restart: 0, epoch: 843, iter: 1, loss: 1.1638
# restart: 0, epoch: 844, iter: 1, loss: 1.1635
# restart: 0, epoch: 845, iter: 1, loss: 1.1632
# restart: 0, epoch: 846, iter: 1, loss: 1.1628
# restart: 0, epoch: 847, iter: 1, loss: 1.1625
# restart: 0, epoch: 848, iter: 1, loss: 1.1622
# restart: 0, epoch: 849, iter: 1, loss: 1.1619
# restart: 0, epoch: 850, iter: 1, loss: 1.1616
# restart: 0, epoch: 851, iter: 1, loss: 1.1613
# restart: 0, epoch: 852, iter: 1, loss: 1.1610
# restart: 0, epoch: 853, iter: 1, loss: 1.1607
# restart: 0, epoch: 854, iter: 1, loss: 1.1604
# restart: 0, epoch: 855, iter: 1, loss: 1.1601
# restart: 0, epoch: 856, iter: 1, loss: 1.1598
# restart: 0, epoch: 857, iter: 1, loss: 1.1595
# restart: 0, epoch: 858, iter: 1, loss: 1.1592
# restart: 0, epoch: 859, iter: 1, loss: 1.1589
# restart: 0, epoch: 860, iter: 1, loss: 1.1586
# restart: 0, epoch: 861, iter: 1, loss: 1.1583
# restart: 0, epoch: 862, iter: 1, loss: 1.1580
# restart: 0, epoch: 863, iter: 1, loss: 1.1577
# restart: 0, epoch: 864, iter: 1, loss: 1.1574
# restart: 0, epoch: 865, iter: 1, loss: 1.1571
# restart: 0, epoch: 866, iter: 1, loss: 1.1568
# restart: 0, epoch: 867, iter: 1, loss: 1.1565
# restart: 0, epoch: 868, iter: 1, loss: 1.1562
# restart: 0, epoch: 869, iter: 1, loss: 1.1559
# restart: 0, epoch: 870, iter: 1, loss: 1.1556
# restart: 0, epoch: 871, iter: 1, loss: 1.1553
# restart: 0, epoch: 872, iter: 1, loss: 1.1550
# restart: 0, epoch: 873, iter: 1, loss: 1.1547
# restart: 0, epoch: 874, iter: 1, loss: 1.1545
# restart: 0, epoch: 875, iter: 1, loss: 1.1541
# restart: 0, epoch: 876, iter: 1, loss: 1.1538
# restart: 0, epoch: 877, iter: 1, loss: 1.1536
# restart: 0, epoch: 878, iter: 1, loss: 1.1532
# restart: 0, epoch: 879, iter: 1, loss: 1.1529
# restart: 0, epoch: 880, iter: 1, loss: 1.1526
# restart: 0, epoch: 881, iter: 1, loss: 1.1522
# restart: 0, epoch: 882, iter: 1, loss: 1.1520
# restart: 0, epoch: 883, iter: 1, loss: 1.1517
# restart: 0, epoch: 884, iter: 1, loss: 1.1514
# restart: 0, epoch: 885, iter: 1, loss: 1.1511
# restart: 0, epoch: 886, iter: 1, loss: 1.1508
# restart: 0, epoch: 887, iter: 1, loss: 1.1504
# restart: 0, epoch: 888, iter: 1, loss: 1.1502
# restart: 0, epoch: 889, iter: 1, loss: 1.1499
# restart: 0, epoch: 890, iter: 1, loss: 1.1495
# restart: 0, epoch: 891, iter: 1, loss: 1.1492
# restart: 0, epoch: 892, iter: 1, loss: 1.1489
# restart: 0, epoch: 893, iter: 1, loss: 1.1486
# restart: 0, epoch: 894, iter: 1, loss: 1.1483
# restart: 0, epoch: 895, iter: 1, loss: 1.1480
# restart: 0, epoch: 896, iter: 1, loss: 1.1477
# restart: 0, epoch: 897, iter: 1, loss: 1.1474
# restart: 0, epoch: 898, iter: 1, loss: 1.1471
# restart: 0, epoch: 899, iter: 1, loss: 1.1468
# restart: 0, epoch: 900, iter: 1, loss: 1.1464
# restart: 0, epoch: 901, iter: 1, loss: 1.1461
# restart: 0, epoch: 902, iter: 1, loss: 1.1458
# restart: 0, epoch: 903, iter: 1, loss: 1.1455
# restart: 0, epoch: 904, iter: 1, loss: 1.1453
# restart: 0, epoch: 905, iter: 1, loss: 1.1449
# restart: 0, epoch: 906, iter: 1, loss: 1.1447
# restart: 0, epoch: 907, iter: 1, loss: 1.1444
# restart: 0, epoch: 908, iter: 1, loss: 1.1441
# restart: 0, epoch: 909, iter: 1, loss: 1.1437
# restart: 0, epoch: 910, iter: 1, loss: 1.1434
# restart: 0, epoch: 911, iter: 1, loss: 1.1431
# restart: 0, epoch: 912, iter: 1, loss: 1.1428
# restart: 0, epoch: 913, iter: 1, loss: 1.1426
# restart: 0, epoch: 914, iter: 1, loss: 1.1424
# restart: 0, epoch: 915, iter: 1, loss: 1.1421
# restart: 0, epoch: 916, iter: 1, loss: 1.1420
# restart: 0, epoch: 917, iter: 1, loss: 1.1418
# restart: 0, epoch: 918, iter: 1, loss: 1.1415
# restart: 0, epoch: 919, iter: 1, loss: 1.1412
# restart: 0, epoch: 920, iter: 1, loss: 1.1410
# restart: 0, epoch: 921, iter: 1, loss: 1.1412
# restart: 0, epoch: 922, iter: 1, loss: 1.1410
# restart: 0, epoch: 923, iter: 1, loss: 1.1419
# restart: 0, epoch: 924, iter: 1, loss: 1.1412
# restart: 0, epoch: 925, iter: 1, loss: 1.1414
# restart: 0, epoch: 926, iter: 1, loss: 1.1420
# restart: 0, epoch: 927, iter: 1, loss: 1.1411
# restart: 0, epoch: 928, iter: 1, loss: 1.1407
# restart: 0, epoch: 929, iter: 1, loss: 1.1405
# restart: 0, epoch: 930, iter: 1, loss: 1.1401
# restart: 0, epoch: 931, iter: 1, loss: 1.1397
# restart: 0, epoch: 932, iter: 1, loss: 1.1393
# restart: 0, epoch: 933, iter: 1, loss: 1.1389
# restart: 0, epoch: 934, iter: 1, loss: 1.1390
# restart: 0, epoch: 935, iter: 1, loss: 1.1385
# restart: 0, epoch: 936, iter: 1, loss: 1.1384
# restart: 0, epoch: 937, iter: 1, loss: 1.1381
# restart: 0, epoch: 938, iter: 1, loss: 1.1378
# restart: 0, epoch: 939, iter: 1, loss: 1.1372
# restart: 0, epoch: 940, iter: 1, loss: 1.1365
# restart: 0, epoch: 941, iter: 1, loss: 1.1362
# restart: 0, epoch: 942, iter: 1, loss: 1.1359
# restart: 0, epoch: 943, iter: 1, loss: 1.1354
# restart: 0, epoch: 944, iter: 1, loss: 1.1352
# restart: 0, epoch: 945, iter: 1, loss: 1.1355
# restart: 0, epoch: 946, iter: 1, loss: 1.1348
# restart: 0, epoch: 947, iter: 1, loss: 1.1344
# restart: 0, epoch: 948, iter: 1, loss: 1.1339
# restart: 0, epoch: 949, iter: 1, loss: 1.1335
# restart: 0, epoch: 950, iter: 1, loss: 1.1331
# restart: 0, epoch: 951, iter: 1, loss: 1.1326
# restart: 0, epoch: 952, iter: 1, loss: 1.1324
# restart: 0, epoch: 953, iter: 1, loss: 1.1322
# restart: 0, epoch: 954, iter: 1, loss: 1.1319
# restart: 0, epoch: 955, iter: 1, loss: 1.1318
# restart: 0, epoch: 956, iter: 1, loss: 1.1319
# restart: 0, epoch: 957, iter: 1, loss: 1.1316
# restart: 0, epoch: 958, iter: 1, loss: 1.1308
# restart: 0, epoch: 959, iter: 1, loss: 1.1306
# restart: 0, epoch: 960, iter: 1, loss: 1.1301
# restart: 0, epoch: 961, iter: 1, loss: 1.1300
# restart: 0, epoch: 962, iter: 1, loss: 1.1299
# restart: 0, epoch: 963, iter: 1, loss: 1.1291
# restart: 0, epoch: 964, iter: 1, loss: 1.1286
# restart: 0, epoch: 965, iter: 1, loss: 1.1282
# restart: 0, epoch: 966, iter: 1, loss: 1.1278
# restart: 0, epoch: 967, iter: 1, loss: 1.1274
# restart: 0, epoch: 968, iter: 1, loss: 1.1271
# restart: 0, epoch: 969, iter: 1, loss: 1.1267
# restart: 0, epoch: 970, iter: 1, loss: 1.1263
# restart: 0, epoch: 971, iter: 1, loss: 1.1259
# restart: 0, epoch: 972, iter: 1, loss: 1.1255
# restart: 0, epoch: 973, iter: 1, loss: 1.1252
# restart: 0, epoch: 974, iter: 1, loss: 1.1249
# restart: 0, epoch: 975, iter: 1, loss: 1.1244
# restart: 0, epoch: 976, iter: 1, loss: 1.1244
# restart: 0, epoch: 977, iter: 1, loss: 1.1247
# restart: 0, epoch: 978, iter: 1, loss: 1.1239
# restart: 0, epoch: 979, iter: 1, loss: 1.1235
# restart: 0, epoch: 980, iter: 1, loss: 1.1233
# restart: 0, epoch: 981, iter: 1, loss: 1.1228
# restart: 0, epoch: 982, iter: 1, loss: 1.1226
# restart: 0, epoch: 983, iter: 1, loss: 1.1222
# restart: 0, epoch: 984, iter: 1, loss: 1.1220
# restart: 0, epoch: 985, iter: 1, loss: 1.1216
# restart: 0, epoch: 986, iter: 1, loss: 1.1210
# restart: 0, epoch: 987, iter: 1, loss: 1.1207
# restart: 0, epoch: 988, iter: 1, loss: 1.1205
# restart: 0, epoch: 989, iter: 1, loss: 1.1203
# restart: 0, epoch: 990, iter: 1, loss: 1.1200
# restart: 0, epoch: 991, iter: 1, loss: 1.1194
# restart: 0, epoch: 992, iter: 1, loss: 1.1192
# restart: 0, epoch: 993, iter: 1, loss: 1.1188
# restart: 0, epoch: 994, iter: 1, loss: 1.1186
# restart: 0, epoch: 995, iter: 1, loss: 1.1183
# restart: 0, epoch: 996, iter: 1, loss: 1.1181
# restart: 0, epoch: 997, iter: 1, loss: 1.1179
# restart: 0, epoch: 998, iter: 1, loss: 1.1176
# restart: 0, epoch: 999, iter: 1, loss: 1.1174
# restart: 0, epoch: 1000, iter: 1, loss: 1.1171
# restart: 0, epoch: 1001, iter: 1, loss: 1.1167
# restart: 0, epoch: 1002, iter: 1, loss: 1.1165
# restart: 0, epoch: 1003, iter: 1, loss: 1.1162
# restart: 0, epoch: 1004, iter: 1, loss: 1.1157
# restart: 0, epoch: 1005, iter: 1, loss: 1.1153
# restart: 0, epoch: 1006, iter: 1, loss: 1.1150
# restart: 0, epoch: 1007, iter: 1, loss: 1.1146
# restart: 0, epoch: 1008, iter: 1, loss: 1.1143
# restart: 0, epoch: 1009, iter: 1, loss: 1.1139
# restart: 0, epoch: 1010, iter: 1, loss: 1.1136
# restart: 0, epoch: 1011, iter: 1, loss: 1.1132
# restart: 0, epoch: 1012, iter: 1, loss: 1.1129
# restart: 0, epoch: 1013, iter: 1, loss: 1.1125
# restart: 0, epoch: 1014, iter: 1, loss: 1.1122
# restart: 0, epoch: 1015, iter: 1, loss: 1.1119
# restart: 0, epoch: 1016, iter: 1, loss: 1.1116
# restart: 0, epoch: 1017, iter: 1, loss: 1.1113
# restart: 0, epoch: 1018, iter: 1, loss: 1.1111
# restart: 0, epoch: 1019, iter: 1, loss: 1.1107
# restart: 0, epoch: 1020, iter: 1, loss: 1.1103
# restart: 0, epoch: 1021, iter: 1, loss: 1.1102
# restart: 0, epoch: 1022, iter: 1, loss: 1.1102
# restart: 0, epoch: 1023, iter: 1, loss: 1.1098
# restart: 0, epoch: 1024, iter: 1, loss: 1.1093
# restart: 0, epoch: 1025, iter: 1, loss: 1.1091
# restart: 0, epoch: 1026, iter: 1, loss: 1.1087
# restart: 0, epoch: 1027, iter: 1, loss: 1.1085
# restart: 0, epoch: 1028, iter: 1, loss: 1.1081
# restart: 0, epoch: 1029, iter: 1, loss: 1.1078
# restart: 0, epoch: 1030, iter: 1, loss: 1.1075
# restart: 0, epoch: 1031, iter: 1, loss: 1.1072
# ...
# restart: 0, epoch: 1661, iter: 1, loss: 0.9466
# restart: 0, epoch: 1662, iter: 1, loss: 0.9465
# restart: 0, epoch: 1663, iter: 1, loss: 0.9461
# restart: 0, epoch: 1664, iter: 1, loss: 0.9458
# restart: 0, epoch: 1665, iter: 1, loss: 0.9455
# restart: 0, epoch: 1666, iter: 1, loss: 0.9451
# restart: 0, epoch: 1667, iter: 1, loss: 0.9447
# restart: 0, epoch: 1668, iter: 1, loss: 0.9448
# restart: 0, epoch: 1669, iter: 1, loss: 0.9443
# restart: 0, epoch: 1670, iter: 1, loss: 0.9438
# restart: 0, epoch: 1671, iter: 1, loss: 0.9435
# restart: 0, epoch: 1672, iter: 1, loss: 0.9435
# restart: 0, epoch: 1673, iter: 1, loss: 0.9434
# restart: 0, epoch: 1674, iter: 1, loss: 0.9429
# restart: 0, epoch: 1675, iter: 1, loss: 0.9425
# restart: 0, epoch: 1676, iter: 1, loss: 0.9425
# restart: 0, epoch: 1677, iter: 1, loss: 0.9421
# restart: 0, epoch: 1678, iter: 1, loss: 0.9418
# restart: 0, epoch: 1679, iter: 1, loss: 0.9417
# restart: 0, epoch: 1680, iter: 1, loss: 0.9423
# restart: 0, epoch: 1681, iter: 1, loss: 0.9414
# restart: 0, epoch: 1682, iter: 1, loss: 0.9417
# restart: 0, epoch: 1683, iter: 1, loss: 0.9413
# restart: 0, epoch: 1684, iter: 1, loss: 0.9412
# restart: 0, epoch: 1685, iter: 1, loss: 0.9409
# restart: 0, epoch: 1686, iter: 1, loss: 0.9405
# restart: 0, epoch: 1687, iter: 1, loss: 0.9404
# restart: 0, epoch: 1688, iter: 1, loss: 0.9399
# restart: 0, epoch: 1689, iter: 1, loss: 0.9399
# restart: 0, epoch: 1690, iter: 1, loss: 0.9395
# restart: 0, epoch: 1691, iter: 1, loss: 0.9393
# restart: 0, epoch: 1692, iter: 1, loss: 0.9391
# restart: 0, epoch: 1693, iter: 1, loss: 0.9392
# restart: 0, epoch: 1694, iter: 1, loss: 0.9388
# restart: 0, epoch: 1695, iter: 1, loss: 0.9387
# restart: 0, epoch: 1696, iter: 1, loss: 0.9383
# restart: 0, epoch: 1697, iter: 1, loss: 0.9382
# restart: 0, epoch: 1698, iter: 1, loss: 0.9381
# restart: 0, epoch: 1699, iter: 1, loss: 0.9377
# restart: 0, epoch: 1700, iter: 1, loss: 0.9377
# restart: 0, epoch: 1701, iter: 1, loss: 0.9373
# restart: 0, epoch: 1702, iter: 1, loss: 0.9369
# restart: 0, epoch: 1703, iter: 1, loss: 0.9368
# restart: 0, epoch: 1704, iter: 1, loss: 0.9364
# restart: 0, epoch: 1705, iter: 1, loss: 0.9362
# restart: 0, epoch: 1706, iter: 1, loss: 0.9359
# restart: 0, epoch: 1707, iter: 1, loss: 0.9356
# restart: 0, epoch: 1708, iter: 1, loss: 0.9354
# restart: 0, epoch: 1709, iter: 1, loss: 0.9351
# restart: 0, epoch: 1710, iter: 1, loss: 0.9351
# restart: 0, epoch: 1711, iter: 1, loss: 0.9349
# restart: 0, epoch: 1712, iter: 1, loss: 0.9344
# restart: 0, epoch: 1713, iter: 1, loss: 0.9343
# restart: 0, epoch: 1714, iter: 1, loss: 0.9341
# restart: 0, epoch: 1715, iter: 1, loss: 0.9339
# restart: 0, epoch: 1716, iter: 1, loss: 0.9335
# restart: 0, epoch: 1717, iter: 1, loss: 0.9334
# restart: 0, epoch: 1718, iter: 1, loss: 0.9331
# restart: 0, epoch: 1719, iter: 1, loss: 0.9329
# restart: 0, epoch: 1720, iter: 1, loss: 0.9326
# restart: 0, epoch: 1721, iter: 1, loss: 0.9324
# restart: 0, epoch: 1722, iter: 1, loss: 0.9322
# restart: 0, epoch: 1723, iter: 1, loss: 0.9320
# restart: 0, epoch: 1724, iter: 1, loss: 0.9317
# restart: 0, epoch: 1725, iter: 1, loss: 0.9315
# restart: 0, epoch: 1726, iter: 1, loss: 0.9313
# restart: 0, epoch: 1727, iter: 1, loss: 0.9311
# restart: 0, epoch: 1728, iter: 1, loss: 0.9309
# restart: 0, epoch: 1729, iter: 1, loss: 0.9307
# restart: 0, epoch: 1730, iter: 1, loss: 0.9305
# restart: 0, epoch: 1731, iter: 1, loss: 0.9303
# restart: 0, epoch: 1732, iter: 1, loss: 0.9302
# restart: 0, epoch: 1733, iter: 1, loss: 0.9299
# restart: 0, epoch: 1734, iter: 1, loss: 0.9296
# restart: 0, epoch: 1735, iter: 1, loss: 0.9294
# restart: 0, epoch: 1736, iter: 1, loss: 0.9293
# restart: 0, epoch: 1737, iter: 1, loss: 0.9290
# restart: 0, epoch: 1738, iter: 1, loss: 0.9288
# restart: 0, epoch: 1739, iter: 1, loss: 0.9286
# restart: 0, epoch: 1740, iter: 1, loss: 0.9284
# restart: 0, epoch: 1741, iter: 1, loss: 0.9282
# restart: 0, epoch: 1742, iter: 1, loss: 0.9280
# restart: 0, epoch: 1743, iter: 1, loss: 0.9278
# restart: 0, epoch: 1744, iter: 1, loss: 0.9277
# restart: 0, epoch: 1745, iter: 1, loss: 0.9275
# restart: 0, epoch: 1746, iter: 1, loss: 0.9272
# restart: 0, epoch: 1747, iter: 1, loss: 0.9271
# restart: 0, epoch: 1748, iter: 1, loss: 0.9271
# restart: 0, epoch: 1749, iter: 1, loss: 0.9273
# restart: 0, epoch: 1750, iter: 1, loss: 0.9267
# restart: 0, epoch: 1751, iter: 1, loss: 0.9266
# restart: 0, epoch: 1752, iter: 1, loss: 0.9273
# restart: 0, epoch: 1753, iter: 1, loss: 0.9269
# restart: 0, epoch: 1754, iter: 1, loss: 0.9266
# restart: 0, epoch: 1755, iter: 1, loss: 0.9264
# restart: 0, epoch: 1756, iter: 1, loss: 0.9264
# restart: 0, epoch: 1757, iter: 1, loss: 0.9261
# restart: 0, epoch: 1758, iter: 1, loss: 0.9259
# restart: 0, epoch: 1759, iter: 1, loss: 0.9257
# restart: 0, epoch: 1760, iter: 1, loss: 0.9256
# restart: 0, epoch: 1761, iter: 1, loss: 0.9251
# restart: 0, epoch: 1762, iter: 1, loss: 0.9250
# restart: 0, epoch: 1763, iter: 1, loss: 0.9247
# restart: 0, epoch: 1764, iter: 1, loss: 0.9245
# restart: 0, epoch: 1765, iter: 1, loss: 0.9242
# restart: 0, epoch: 1766, iter: 1, loss: 0.9239
# restart: 0, epoch: 1767, iter: 1, loss: 0.9237
# restart: 0, epoch: 1768, iter: 1, loss: 0.9234
# restart: 0, epoch: 1769, iter: 1, loss: 0.9232
# restart: 0, epoch: 1770, iter: 1, loss: 0.9231
# restart: 0, epoch: 1771, iter: 1, loss: 0.9231
# restart: 0, epoch: 1772, iter: 1, loss: 0.9236
# restart: 0, epoch: 1773, iter: 1, loss: 0.9236
# restart: 0, epoch: 1774, iter: 1, loss: 0.9233
# restart: 0, epoch: 1775, iter: 1, loss: 0.9232
# restart: 0, epoch: 1776, iter: 1, loss: 0.9229
# restart: 0, epoch: 1777, iter: 1, loss: 0.9224
# restart: 0, epoch: 1778, iter: 1, loss: 0.9223
# restart: 0, epoch: 1779, iter: 1, loss: 0.9221
# restart: 0, epoch: 1780, iter: 1, loss: 0.9220
# restart: 0, epoch: 1781, iter: 1, loss: 0.9216
# restart: 0, epoch: 1782, iter: 1, loss: 0.9215
# restart: 0, epoch: 1783, iter: 1, loss: 0.9213
# restart: 0, epoch: 1784, iter: 1, loss: 0.9212
# restart: 0, epoch: 1785, iter: 1, loss: 0.9212
# restart: 0, epoch: 1786, iter: 1, loss: 0.9205
# restart: 0, epoch: 1787, iter: 1, loss: 0.9204
# restart: 0, epoch: 1788, iter: 1, loss: 0.9203
# restart: 0, epoch: 1789, iter: 1, loss: 0.9201
# restart: 0, epoch: 1790, iter: 1, loss: 0.9199
# restart: 0, epoch: 1791, iter: 1, loss: 0.9194
# restart: 0, epoch: 1792, iter: 1, loss: 0.9192
# restart: 0, epoch: 1793, iter: 1, loss: 0.9190
# restart: 0, epoch: 1794, iter: 1, loss: 0.9188
# restart: 0, epoch: 1795, iter: 1, loss: 0.9185
# restart: 0, epoch: 1796, iter: 1, loss: 0.9182
# restart: 0, epoch: 1797, iter: 1, loss: 0.9180
# restart: 0, epoch: 1798, iter: 1, loss: 0.9177
# restart: 0, epoch: 1799, iter: 1, loss: 0.9175
# restart: 0, epoch: 1800, iter: 1, loss: 0.9173
# restart: 0, epoch: 1801, iter: 1, loss: 0.9171
# restart: 0, epoch: 1802, iter: 1, loss: 0.9169
# restart: 0, epoch: 1803, iter: 1, loss: 0.9166
# restart: 0, epoch: 1804, iter: 1, loss: 0.9164
# restart: 0, epoch: 1805, iter: 1, loss: 0.9162
# restart: 0, epoch: 1806, iter: 1, loss: 0.9161
# restart: 0, epoch: 1807, iter: 1, loss: 0.9158
# restart: 0, epoch: 1808, iter: 1, loss: 0.9156
# restart: 0, epoch: 1809, iter: 1, loss: 0.9154
# restart: 0, epoch: 1810, iter: 1, loss: 0.9152
# restart: 0, epoch: 1811, iter: 1, loss: 0.9150
# restart: 0, epoch: 1812, iter: 1, loss: 0.9148
# restart: 0, epoch: 1813, iter: 1, loss: 0.9146
# restart: 0, epoch: 1814, iter: 1, loss: 0.9144
# restart: 0, epoch: 1815, iter: 1, loss: 0.9142
# restart: 0, epoch: 1816, iter: 1, loss: 0.9141
# restart: 0, epoch: 1817, iter: 1, loss: 0.9140
# restart: 0, epoch: 1818, iter: 1, loss: 0.9141
# restart: 0, epoch: 1819, iter: 1, loss: 0.9141
# restart: 0, epoch: 1820, iter: 1, loss: 0.9135
# restart: 0, epoch: 1821, iter: 1, loss: 0.9135
# restart: 0, epoch: 1822, iter: 1, loss: 0.9133
# restart: 0, epoch: 1823, iter: 1, loss: 0.9130
# restart: 0, epoch: 1824, iter: 1, loss: 0.9128
# restart: 0, epoch: 1825, iter: 1, loss: 0.9126
# restart: 0, epoch: 1826, iter: 1, loss: 0.9125
# restart: 0, epoch: 1827, iter: 1, loss: 0.9123
# restart: 0, epoch: 1828, iter: 1, loss: 0.9122
# restart: 0, epoch: 1829, iter: 1, loss: 0.9119
# restart: 0, epoch: 1830, iter: 1, loss: 0.9117
# restart: 0, epoch: 1831, iter: 1, loss: 0.9116
# restart: 0, epoch: 1832, iter: 1, loss: 0.9116
# restart: 0, epoch: 1833, iter: 1, loss: 0.9117
# restart: 0, epoch: 1834, iter: 1, loss: 0.9113
# restart: 0, epoch: 1835, iter: 1, loss: 0.9118
# restart: 0, epoch: 1836, iter: 1, loss: 0.9110
# restart: 0, epoch: 1837, iter: 1, loss: 0.9113
# restart: 0, epoch: 1838, iter: 1, loss: 0.9107
# restart: 0, epoch: 1839, iter: 1, loss: 0.9106
# restart: 0, epoch: 1840, iter: 1, loss: 0.9108
# restart: 0, epoch: 1841, iter: 1, loss: 0.9105
# restart: 0, epoch: 1842, iter: 1, loss: 0.9101
# restart: 0, epoch: 1843, iter: 1, loss: 0.9099
# restart: 0, epoch: 1844, iter: 1, loss: 0.9098
# restart: 0, epoch: 1845, iter: 1, loss: 0.9096
# restart: 0, epoch: 1846, iter: 1, loss: 0.9093
# restart: 0, epoch: 1847, iter: 1, loss: 0.9090
# restart: 0, epoch: 1848, iter: 1, loss: 0.9088
# restart: 0, epoch: 1849, iter: 1, loss: 0.9086
# restart: 0, epoch: 1850, iter: 1, loss: 0.9084
# restart: 0, epoch: 1851, iter: 1, loss: 0.9082
# restart: 0, epoch: 1852, iter: 1, loss: 0.9081
# restart: 0, epoch: 1853, iter: 1, loss: 0.9084
# restart: 0, epoch: 1854, iter: 1, loss: 0.9078
# restart: 0, epoch: 1855, iter: 1, loss: 0.9080
# restart: 0, epoch: 1856, iter: 1, loss: 0.9083
# restart: 0, epoch: 1857, iter: 1, loss: 0.9079
# restart: 0, epoch: 1858, iter: 1, loss: 0.9073
# restart: 0, epoch: 1859, iter: 1, loss: 0.9073
# restart: 0, epoch: 1860, iter: 1, loss: 0.9070
# restart: 0, epoch: 1861, iter: 1, loss: 0.9069
# restart: 0, epoch: 1862, iter: 1, loss: 0.9067
# restart: 0, epoch: 1863, iter: 1, loss: 0.9065
# restart: 0, epoch: 1864, iter: 1, loss: 0.9063
# restart: 0, epoch: 1865, iter: 1, loss: 0.9061
# restart: 0, epoch: 1866, iter: 1, loss: 0.9059
# restart: 0, epoch: 1867, iter: 1, loss: 0.9056
# restart: 0, epoch: 1868, iter: 1, loss: 0.9055
# restart: 0, epoch: 1869, iter: 1, loss: 0.9054
# restart: 0, epoch: 1870, iter: 1, loss: 0.9052
# restart: 0, epoch: 1871, iter: 1, loss: 0.9050
# restart: 0, epoch: 1872, iter: 1, loss: 0.9046
# restart: 0, epoch: 1873, iter: 1, loss: 0.9044
# restart: 0, epoch: 1874, iter: 1, loss: 0.9042
# restart: 0, epoch: 1875, iter: 1, loss: 0.9041
# restart: 0, epoch: 1876, iter: 1, loss: 0.9039
# restart: 0, epoch: 1877, iter: 1, loss: 0.9044
# restart: 0, epoch: 1878, iter: 1, loss: 0.9048
# restart: 0, epoch: 1879, iter: 1, loss: 0.9038
# restart: 0, epoch: 1880, iter: 1, loss: 0.9044
# restart: 0, epoch: 1881, iter: 1, loss: 0.9042
# restart: 0, epoch: 1882, iter: 1, loss: 0.9037
# restart: 0, epoch: 1883, iter: 1, loss: 0.9035
# restart: 0, epoch: 1884, iter: 1, loss: 0.9032
# restart: 0, epoch: 1885, iter: 1, loss: 0.9031
# restart: 0, epoch: 1886, iter: 1, loss: 0.9028
# restart: 0, epoch: 1887, iter: 1, loss: 0.9025
# restart: 0, epoch: 1888, iter: 1, loss: 0.9023
# restart: 0, epoch: 1889, iter: 1, loss: 0.9020
# restart: 0, epoch: 1890, iter: 1, loss: 0.9018
# restart: 0, epoch: 1891, iter: 1, loss: 0.9016
# restart: 0, epoch: 1892, iter: 1, loss: 0.9014
# restart: 0, epoch: 1893, iter: 1, loss: 0.9011
# restart: 0, epoch: 1894, iter: 1, loss: 0.9009
# restart: 0, epoch: 1895, iter: 1, loss: 0.9007
# restart: 0, epoch: 1896, iter: 1, loss: 0.9005
# restart: 0, epoch: 1897, iter: 1, loss: 0.9003
# restart: 0, epoch: 1898, iter: 1, loss: 0.9001
# restart: 0, epoch: 1899, iter: 1, loss: 0.8999
# restart: 0, epoch: 1900, iter: 1, loss: 0.8997
# restart: 0, epoch: 1901, iter: 1, loss: 0.8995
# restart: 0, epoch: 1902, iter: 1, loss: 0.8993
# restart: 0, epoch: 1903, iter: 1, loss: 0.8991
# restart: 0, epoch: 1904, iter: 1, loss: 0.8989
# restart: 0, epoch: 1905, iter: 1, loss: 0.8988
# restart: 0, epoch: 1906, iter: 1, loss: 0.8986
# restart: 0, epoch: 1907, iter: 1, loss: 0.8986
# restart: 0, epoch: 1908, iter: 1, loss: 0.8984
# restart: 0, epoch: 1909, iter: 1, loss: 0.8980
# restart: 0, epoch: 1910, iter: 1, loss: 0.8980
# restart: 0, epoch: 1911, iter: 1, loss: 0.8976
# restart: 0, epoch: 1912, iter: 1, loss: 0.8976
# restart: 0, epoch: 1913, iter: 1, loss: 0.8973
# restart: 0, epoch: 1914, iter: 1, loss: 0.8972
# restart: 0, epoch: 1915, iter: 1, loss: 0.8970
# restart: 0, epoch: 1916, iter: 1, loss: 0.8968
# restart: 0, epoch: 1917, iter: 1, loss: 0.8966
# restart: 0, epoch: 1918, iter: 1, loss: 0.8964
# restart: 0, epoch: 1919, iter: 1, loss: 0.8962
# restart: 0, epoch: 1920, iter: 1, loss: 0.8961
# restart: 0, epoch: 1921, iter: 1, loss: 0.8960
# restart: 0, epoch: 1922, iter: 1, loss: 0.8957
# restart: 0, epoch: 1923, iter: 1, loss: 0.8956
# restart: 0, epoch: 1924, iter: 1, loss: 0.8955
# restart: 0, epoch: 1925, iter: 1, loss: 0.8953
# restart: 0, epoch: 1926, iter: 1, loss: 0.8952
# restart: 0, epoch: 1927, iter: 1, loss: 0.8948
# restart: 0, epoch: 1928, iter: 1, loss: 0.8947
# restart: 0, epoch: 1929, iter: 1, loss: 0.8945
# restart: 0, epoch: 1930, iter: 1, loss: 0.8943
# restart: 0, epoch: 1931, iter: 1, loss: 0.8942
# restart: 0, epoch: 1932, iter: 1, loss: 0.8940
# restart: 0, epoch: 1933, iter: 1, loss: 0.8938
# restart: 0, epoch: 1934, iter: 1, loss: 0.8936
# restart: 0, epoch: 1935, iter: 1, loss: 0.8934
# restart: 0, epoch: 1936, iter: 1, loss: 0.8933
# restart: 0, epoch: 1937, iter: 1, loss: 0.8931
# restart: 0, epoch: 1938, iter: 1, loss: 0.8929
# restart: 0, epoch: 1939, iter: 1, loss: 0.8928
# restart: 0, epoch: 1940, iter: 1, loss: 0.8926
# restart: 0, epoch: 1941, iter: 1, loss: 0.8924
# restart: 0, epoch: 1942, iter: 1, loss: 0.8923
# restart: 0, epoch: 1943, iter: 1, loss: 0.8921
# restart: 0, epoch: 1944, iter: 1, loss: 0.8920
# restart: 0, epoch: 1945, iter: 1, loss: 0.8918
# restart: 0, epoch: 1946, iter: 1, loss: 0.8916
# restart: 0, epoch: 1947, iter: 1, loss: 0.8914
# restart: 0, epoch: 1948, iter: 1, loss: 0.8913
# restart: 0, epoch: 1949, iter: 1, loss: 0.8911
# restart: 0, epoch: 1950, iter: 1, loss: 0.8909
# restart: 0, epoch: 1951, iter: 1, loss: 0.8908
# restart: 0, epoch: 1952, iter: 1, loss: 0.8906
# restart: 0, epoch: 1953, iter: 1, loss: 0.8905
# restart: 0, epoch: 1954, iter: 1, loss: 0.8903
# restart: 0, epoch: 1955, iter: 1, loss: 0.8902
# restart: 0, epoch: 1956, iter: 1, loss: 0.8900
# restart: 0, epoch: 1957, iter: 1, loss: 0.8898
# restart: 0, epoch: 1958, iter: 1, loss: 0.8897
# restart: 0, epoch: 1959, iter: 1, loss: 0.8895
# restart: 0, epoch: 1960, iter: 1, loss: 0.8894
# restart: 0, epoch: 1961, iter: 1, loss: 0.8892
# restart: 0, epoch: 1962, iter: 1, loss: 0.8890
# restart: 0, epoch: 1963, iter: 1, loss: 0.8888
# restart: 0, epoch: 1964, iter: 1, loss: 0.8887
# restart: 0, epoch: 1965, iter: 1, loss: 0.8885
# restart: 0, epoch: 1966, iter: 1, loss: 0.8884
# restart: 0, epoch: 1967, iter: 1, loss: 0.8883
# restart: 0, epoch: 1968, iter: 1, loss: 0.8882
# restart: 0, epoch: 1969, iter: 1, loss: 0.8879
# restart: 0, epoch: 1970, iter: 1, loss: 0.8879
# restart: 0, epoch: 1971, iter: 1, loss: 0.8877
# restart: 0, epoch: 1972, iter: 1, loss: 0.8878
# restart: 0, epoch: 1973, iter: 1, loss: 0.8874
# restart: 0, epoch: 1974, iter: 1, loss: 0.8873
# restart: 0, epoch: 1975, iter: 1, loss: 0.8870
# restart: 0, epoch: 1976, iter: 1, loss: 0.8870
# restart: 0, epoch: 1977, iter: 1, loss: 0.8868
# restart: 0, epoch: 1978, iter: 1, loss: 0.8868
# restart: 0, epoch: 1979, iter: 1, loss: 0.8864
# restart: 0, epoch: 1980, iter: 1, loss: 0.8863
# restart: 0, epoch: 1981, iter: 1, loss: 0.8861
# restart: 0, epoch: 1982, iter: 1, loss: 0.8859
# restart: 0, epoch: 1983, iter: 1, loss: 0.8857
# restart: 0, epoch: 1984, iter: 1, loss: 0.8855
# restart: 0, epoch: 1985, iter: 1, loss: 0.8854
# restart: 0, epoch: 1986, iter: 1, loss: 0.8852
# restart: 0, epoch: 1987, iter: 1, loss: 0.8850
# restart: 0, epoch: 1988, iter: 1, loss: 0.8849
# restart: 0, epoch: 1989, iter: 1, loss: 0.8847
# restart: 0, epoch: 1990, iter: 1, loss: 0.8845
# restart: 0, epoch: 1991, iter: 1, loss: 0.8844
# restart: 0, epoch: 1992, iter: 1, loss: 0.8842
# restart: 0, epoch: 1993, iter: 1, loss: 0.8842
# restart: 0, epoch: 1994, iter: 1, loss: 0.8842
# restart: 0, epoch: 1995, iter: 1, loss: 0.8840
# restart: 0, epoch: 1996, iter: 1, loss: 0.8838
# restart: 0, epoch: 1997, iter: 1, loss: 0.8838
# restart: 0, epoch: 1998, iter: 1, loss: 0.8837
# restart: 0, epoch: 1999, iter: 1, loss: 0.8834
# restart: 0, epoch: 2000, iter: 1, loss: 0.8832

# %%
  model_name = "Refrigerator_trial_seq_time.pt"
  torch.save(model.state_dict(), os.path.join(
   "models/", model_name))

# %% [markdown]
# ## Decomp

# %%
kernel1 = ScaleKernel(RBFKernel(ard_num_dims=n))
# kernel2 = ScaleKernel(RBFKernel(ard_num_dims=1,active_dims=(99)))
# kernel3 = ScaleKernel(CosineKernel(ard_num_dims=1,active_dims=(99)))

# kernel4 = kernel2*kernel3
kernel = kernel1 #ernel4
# induce_points = 512
inducing_points =  x[np.arange(0,x.shape[0],70)] 
# inducing_points = x[torch.randperm(x.shape[0])[: 1500]]

model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                      inducing_points).to("cuda")

model_name =  "Refrigerator_rbf_building6_" + str(0) + ".pt"
model.load_state_dict(torch.load(
    os.path.join("./final_models/", model_name)))
# Out:
# <All keys matched successfully>

# %%
model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
                      inducing_points).to("cuda")

# %%
pred_dist1 = model1.predict(xt[:4000].to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_mean1.shape
# Out:
# torch.Size([4000])

# %%
pred_arr =[]
pred_arr.append(np.array(pred_dist1.mean.cpu()))

# %%
y_mean = np.mean(pred_arr, axis =0)

# y_Std = np.std(np.array(pred_arr), axis =0)

# %%
y_mean.shape, y_Std.shape
# Out:
# ((4000,), (4000,))

# %%
y_mean = scaler_y.inverse_transform(y_mean.reshape(-1,1)).squeeze()
# y_std = scaler_y.inverse_transform(y_Std.reshape(-1,1)).squeeze()

# %%
y_mean.shape
# Out:
# (16781,)

# %%
y_mean.any() < 0
# Out:
# False

# %%
y_mean_ = np.clip(y_mean,0,y_mean.max())
# y_sigma =  np.clip(y_mean,0,y_mean.max())

# %%
idx = 3000
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp[:idx], scaler_x.inverse_transform(xt.cpu().reshape(-1,1))[:idx], label = "Main")
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean_[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
# savefig("Uncertainity")

# %%
model2 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel4,
                      inducing_points).to("cuda")

# %%
pred_dist2 = model2.predict(xt[:4000].to("cuda"))
# print("Done ", i)

y_mean2 = pred_dist2.loc

# %%
y_mean = scaler_y.inverse_transform(y_mean2.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean.shape)
# Out:
# torch.Size([16781]) (4000,)

# %%
y_mean_ = np.clip(y_mean,0,y_mean.max())

# %%
idx = 3000
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp[:idx], scaler_y.inverse_transform(y.cpu().reshape(-1,1))[:idx], label = "Main")
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean_[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()

# %%
idx = 3000
# plt.figure(figsize=(10,6))
plt.plot(jnp.arange(idx),  yt.cpu().reshape(-1,1)[:idx], label = "Ground Truth", color="green")
plt.plot(jnp.arange(idx), y_mean_[:idx].reshape(-1,1), label = "Predicted")
# for i in range(2,3):
#     plt.fill_between(jnp.arange(idx), y_mean[:idx] - i*y_std[:idx], y_mean[:idx] + i*y_std[:idx],
#                     color="orange", alpha=(1/(i*3)), label=f"$\mu\pm{i}*\sigma$")
# plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.legend( prop={'size': 5.5})
plt.ylabel("Power")
sns.despine()

# %%
mae = np.mean(np.abs(np.array(yt) - y_mean))
rms = errors.rmse(jnp.array(yt), y_mean)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  27.80521506352558
# RMSE:  44.84471

# %%
try:
    from probml_utils import latexify, savefig, is_latexify_enabled
except ModuleNotFoundError:
    # %pip install git+https://github.com/probml/probml-utils.git
    from probml_utils import latexify, savefig, is_latexify_enabled

# %%
os.environ["LATEXIFY"] = "1"
os.environ["FIG_DIR"] = "./Final_plotss/"

# %%
latexify(width_scale_factor=2, fig_height=2)

# %%
idx = 2000
# plt.figure(figsize=(10,6))
plt.figure()
plt.plot(jnp.arange(idx), yt[300:idx+300], label = "Fridge True")
plt.plot(jnp.arange(idx), y_mean[300:idx+300], label = "Fridge Predicted")
plt.legend()
sns.despine()
savefig("CombinationKernel")
# Out:
# saving image to ./Final_plotss/CombinationKernel_latexified.pdf
# Figure size: [2. 2.]

# %%
model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
                       inducing_points).to("cuda")

# %%
pred_dist1 = model1.predict(xt.to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_mean1 = scaler_y.inverse_transform(y_mean1.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean1.shape)
# Out:
# torch.Size([14780]) (14780,)

# %%
idx = 2000
# plt.figure(figsize=(10,6))
plt.figure()
plt.plot(jnp.arange(idx), yt[300:idx+300], label = "Fridge True")
plt.plot(jnp.arange(idx), y_mean1[300:idx+300], label = "Fridge Predicted")
# plt.legend()
sns.despine()
savefig("RBFKernel")
# Out:
# saving image to ./Final_plotss/RBFKernel_latexified.pdf
# Figure size: [2. 2.]

# %%
# for name, params in model.named_parameters():
#   print(name, params)

# # model.mll.model.base_covar_module.kernels.base_kernel.raw_lengthscale

# %%
x.shape
# Out:
# torch.Size([55457, 100])

# %%
model2 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel4,
                       inducing_points).to("cuda")

# %%
pred_dist2 = model2.predict(xt.to("cuda"))
# print("Done ", i)

y_mean2 = pred_dist2.loc
# Out:
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/kernels/inducing_point_kernel.py:61: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352645774/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   inv_root = torch.triangular_solve(eye, chol)[0]

# %%
y_mean2 = scaler_y.inverse_transform(y_mean2.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean2.shape)
# Out:
# torch.Size([14780]) (14780,)

# %%
idx = 2000
plt.figure()
# plt.figure(figsize=(10,6))
plt.plot(jnp.arange(idx), yt[300:idx+300], label = "Fridge True")
plt.plot(jnp.arange(idx), y_mean2[300:idx+300], label = "Fridge Predicted")
# plt.legend()
sns.despine()
savefig("RBFxPeriodicKernel")
# Out:
# saving image to ./Final_plotss/RBFxPeriodicKernel_latexified.pdf
# Figure size: [2. 2.]

# %% [markdown]
# ## Normal

# %%
kernel1 = ScaleKernel(MaternKernel(nu=2.5,ard_num_dims=n+1))
kernel2 = ScaleKernel(MaternKernel(nu=0.5,ard_num_dims=1,active_dims=(99)))
kernel3 = ScaleKernel(PeriodicKernel(ard_num_dims=1,active_dims=(99)))
# kernel5 = ScaleKernel(gpytorch.kernels.SpectralDeltaKernel(num_dims=n,ard_num_dims=n))
#   theta =  {'base_covar_module.kernels.0.base_kernel.lengthscale': torch.tensor(0.5),
#         'base_covar_module.kernels.0.outputscale': torch.tensor(5.0),
#         'base_covar_module.kernels.1.kernels.0.outputscale':torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.0.base_kernel.lengthscale': torch.tensor(0.1),
#         'base_covar_module.kernels.1.kernels.1.outputscale':torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.1.base_kernel.lengthscale': torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
#theta = { 'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
kernel4 = kernel2*kernel3
kernel = kernel1 + kernel4
# induce_points = 512
inducing_points =  x[np.arange(0,x.shape[0],95)] 
# inducing_points = x[torch.randperm(x.shape[0])[: 1500]]

model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                    inducing_points).to("cuda")
model_name =  "Refrigerator_trial_seq_time.pt"
model.load_state_dict(torch.load(
    os.path.join("models/", model_name)))
# Out:
# <All keys matched successfully>

# %%
plt.plot(range(99),model.mll.model.base_covar_module.base_kernel.lengthscale.cpu().detach().reshape(-1,1))

# %%
plt.plot(range(100),model.mll.model.base_covar_module.kernels[0].base_kernel.lengthscale.cpu().detach().reshape(-1,1))

# %%
for name, params in model.named_parameters():
  print(name, params)
# Out:
# mll.likelihood.noise_covar.raw_noise Parameter containing:
# tensor([-1.0096], device='cuda:0', requires_grad=True)
# mll.model.mean_module.constant Parameter containing:
# tensor([0.0197], device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.raw_outputscale Parameter containing:
# tensor(-1.5955, device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.base_kernel.raw_lengthscale Parameter containing:
# tensor([[ 1.7127,  1.7136,  1.7333,  1.7442,  1.7402,  1.7397,  1.7466,  1.7686,
#           1.7576,  1.7448,  1.7657,  1.7839,  1.7661,  1.7749,  1.7550,  1.7648,
#           1.7573,  1.7221,  1.7115,  1.7185,  1.6733,  1.6714,  1.6615,  1.6700,
#           1.6799,  1.6863,  1.7105,  1.7212,  1.7603,  1.7713,  1.7818,  1.7861,
#           1.7688,  1.7527,  1.7599,  1.7722,  1.7489,  1.7463,  1.7318,  1.7100,
#           1.7155,  1.6706,  1.6410,  1.5965,  1.5681,  1.6244,  1.5938,  1.4162,
#           0.2203, -1.4909,  0.0535,  1.4510,  1.5215,  1.5698,  1.6006,  1.6280,
#           1.6671,  1.6821,  1.7016,  1.6944,  1.6971,  1.6882,  1.6921,  1.7159,
#           1.7157,  1.6974,  1.7069,  1.6999,  1.7339,  1.7361,  1.7167,  1.7287,
#           1.6913,  1.6827,  1.6938,  1.6913,  1.7128,  1.7178,  1.7077,  1.7121,
#           1.7120,  1.7142,  1.7503,  1.7616,  1.7721,  1.7581,  1.7720,  1.8044,
#           1.7999,  1.7919,  1.7882,  1.8062,  1.7990,  1.7895,  1.7841,  1.7576,
#           1.7464,  1.7140,  1.6581]], device='cuda:0', requires_grad=True)
# mll.model.covar_module.inducing_points Parameter containing:
# tensor([[-0.6021, -0.5980, -0.5893,  ..., -0.1777, -0.1897, -0.2090],
#         [-0.2090, -0.1555, -0.1075,  ..., -0.3205, -0.3206, -0.3176],
#         [-0.3468, -0.3521, -0.3654,  ..., -0.0812, -0.1101, -0.1276],
#         ...,
#         [ 4.7876,  5.2937,  5.2859,  ...,  5.0246,  5.0475,  5.0063],
#         [ 5.0424,  5.0300,  5.0493,  ...,  0.2325,  0.2275,  0.1431],
#         [ 0.1489,  0.2328,  0.2315,  ..., -0.2765, -0.2754, -0.2741]],
#        device='cuda:0', dtype=torch.float64, requires_grad=True)

# %%
import numpy as np
try:
    from probml_utils import latexify, savefig, is_latexify_enabled
except ModuleNotFoundError:
    # %pip install git+https://github.com/probml/probml-utils.git
    from probml_utils import latexify, savefig, is_latexify_enabled


os.environ["LATEXIFY"] = "1"
os.environ["FIG_DIR"] = "./Final_plotss/"

latexify(width_scale_factor=2, fig_height=2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# arr = np.array([3.8464, 4.5094, 4.7394, 4.9024, 4.9117, 5.0150, 4.8746, 4.9372, 4.3143,
#          4.5656, 5.0050, 5.1365, 5.1490, 5.2152, 5.2837, 5.2594, 5.1965, 5.0747,
#          5.1212, 4.8200, 4.6431, 4.8732, 4.7529, 0.3853, 4.4826, 4.9550, 5.0677,
#          5.2859, 4.9612, 5.1401, 5.2131, 4.4774, 4.5654, 4.5685, 3.8310, 3.0889,
#          2.7822, 4.0948, 4.0399, 4.6180, 4.5923, 4.5015, 4.0521, 4.8423, 5.2143,
#          5.4020, 4.8021, 4.5021, 0.6626, 0.1252, 1.3779, 4.8821, 4.6781, 4.8554,
#          4.5223, 4.5568, 5.0172, 5.4072, 5.0706, 4.5916, 4.5663, 4.1121, 4.2572,
#          4.2228, 3.7784, 0.4839, 3.6554, 4.3523, 4.6682, 4.6549, 4.8291, 5.0260,
#          4.7748, 4.5609, 4.4541, 4.4165, 4.4292, 4.1279, 3.6382, 4.1110, 4.7252,
#          5.0184, 5.0391, 5.2424, 5.5062, 5.4739, 5.5326, 5.6874, 5.6897, 5.4765,
#          5.4602, 5.4513, 5.5450, 5.6225, 5.5479, 5.3580, 5.3926, 5.1536, 4.6321])
# ar1 = np.arange(0,99,1)
# plt.plot(ar1,arr,'b')
# plt.xlabel('ARD')
# plt.ylabel('Learned ARD LengthScale values')
# # plt.title("Building 6 Test")

# plt.show()
# sns.despine()
# savefig("ARD_Ref")

# %%
pred_dist = model.predict(xt.to("cuda"))
# print("Done ", i)

y_mean = pred_dist.loc

# %%
y_mean = scaler_y.inverse_transform(y_mean.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean.shape)
# Out:
# torch.Size([3103]) (3103,)

# %%
y_mean = np.clip(y_mean,0,y_mean.max(),out=y_mean)

# %%
mae_arr = np.abs(np.array(yt) - y_mean)

# %%
mae_arr.shape
# Out:
# (3103,)

# %%
# val,count= np.unique(mae_arr, return_counts=True)
# val, np.where(count==count.max())
# Out:
# (array([0.00000000e+00, 8.51965495e-04, 1.99553289e-03, ...,
#         3.92172423e+02, 4.16037255e+02, 4.35113016e+02]),
#  (array([178]),))

# %%
# count[178], val[178]
# Out:
# (119, 0.4117647111415863)

# %%
# ar1 = np.where(mae_arr==val[178])

# %%
# x_trial = scaler_x.inverse_transform(xt[:,:99].cpu())
# x_trial[ar1,49].min(),x_trial[ar1,49].max()
# Out:
# (161.15515639024815, 235.42394003209563)

# %%
idx=xt.shape[0]
plt.plot(x_test_timestamp[:idx],mae_arr[:idx])
plt.xlabel("TimeStamp")
plt.ylabel("Absolute Error on Test")
# Out:
# Text(0, 0.5, 'Absolute Error on Test')

# %%
sns.kdeplot(mae_arr)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
mae_arr1 = []


for i in range(len(mae_arr)):
  if (mae_arr[i]>300):
    mae_arr1.append(0)
  else:
    mae_arr1.append(mae_arr[i])

# %%
np.mean(mae_arr1)
# Out:
# 45.0276760731509

# %%
idx=xt.shape[0]
plt.plot(x_test_timestamp[:idx],mae_arr1[:idx])

# %%
mae = np.mean(np.abs(np.array(yt) - y_mean))
rms = errors.rmse(jnp.array(yt), y_mean)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  46.3168694927852
# RMSE:  62.80439

# %%
#MAE:  28.1036

# %%
x1 = xt[:,49]

# %%
scaler_x.inverse_transform(x[:,:99]).min()
# Out:
# -2.8957800907392084e-05

# %%
scaler_x.inverse_transform(xt[:,:99].cpu())[:idx,49].min(), scaler_x.inverse_transform(xt[:,:99].cpu())[:idx,49].max()
# Out:
# (162.5966672844098, 2322.4141213168814)

# %%
idx = 3000
plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp[:idx], scaler_x.inverse_transform(xt[:,:99].cpu())[:idx,49], label = "Main")
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
plt.title("Building 5")
sns.despine()

# %%
idx = 3000
plt.figure(figsize=(10,6))
plt.plot(jnp.arange(idx), scaler_y.inverse_transform(y.cpu().reshape(-1,1))[:idx], label = "Main")
plt.plot(jnp.arange(idx), yt.cpu()[:idx], label = "Refri")
plt.plot(jnp.arange(idx), y_mean[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("Indexes")
plt.ylabel("Fridge Power")
sns.despine()

# %%
# plt.plot(np.array(test_timestamp_orig)[:300],np.array(yt)[:300])
# plt.plot(np.array(test_timestamp_orig)[:300],np.array(y_mean)[:300])

# %%
# plt.scatter(np.array(test_timestamp_orig)[:3000],np.array(y_mean)[:3000],label="True")
# plt.scatter(np.array(test_timestamp_orig)[:3000],np.array(yt)[:3000],label="Pred")
# plt.legend()
# plt.xlabel("TimeStamp")
# plt.xlabel("Refrogerator Power")

# %%
idx = x_test.shape[0]
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp, y_test[:idx], label = "Refri")
plt.plot(x_test_timestamp, y_mean[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
# savefig("CombinationKernel")
# plt.savefig("./Results/Refrigerator_building5.png", bbox_inches="tight")

# %%
model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
                      inducing_points).to("cuda")

# %%
pred_dist1 = model.predict(torch.tensor(np.array(x_train_full)).to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_mean1 = scaler_y.inverse_transform(y_mean1.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(y_train.shape, y_mean1.shape)

# %%
mae = np.mean(np.abs(np.array(y_train) - y_mean1))
rms = errors.rmse(jnp.array(y_train), y_mean1)

print("MAE: ", mae)
print("RMSE: ", rms)

# %%
idx = x_train.shape[0]
plt.figure(figsize=(10,6))
plt.plot(x_train_timstamp, y_train[:idx], label = "Refri")
plt.plot(x_train_timstamp, y_mean[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
# savefig("CombinationKernel")
# plt.savefig("./Results/Refrigerator_building5.png", bbox_inches="tight")

# %%
#MAE:  39.81858310475401 build 6
#MAE:  30.333733374869247 build 3
#MAE:  37.32115756605644 build 2
#MAE: 43.212248588857065 build 5
#MAE:  48.917852990726765

# %%
# MAE: Building 6 MAE: 35.07
# MAE: Building 3 MAE:  31.565
# MAE: Building 2 MAE: 31.089
# MAE: Building 1 MAE: 37.3657
# MAE: Building 5 MAE:  46.316869

# %%
# MAE: Building 6 MAE: 34.3709125
# MAE: Building 3 MAE: 30.919
# MAE: Building 2 MAE: 30.43776
# MAE: Building 1 MAE: 37.10209
# MAE: Building 5 MAE: 45.02767
