# %%
import os
os.chdir("../")
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import torch
from gpytorch.kernels import RBFKernel, ScaleKernel, PeriodicKernel, MaternKernel, CosineKernel
from skgpytorch.models import SVGPRegressor, SGPRegressor

# %%
import jax.numpy as jnp
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from utilities.fits import fit
# from utilities import plot
import tensorflow_probability.substrates.jax as tfp
dist = tfp.distributions
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from gpytorch.constraints import GreaterThan
from skgpytorch.metrics import mean_squared_error, negative_log_predictive_density
import time
import numpy as np

# from datasets.dataset_load import dataset_loader
from utilities import plot,fits,gmm,errors,predict,preprocess

# device = "cpu"
# torch.set_default_dtype(torch.float32)
# torch.set_default_tensor_type(torch.FloatTensor)

# %%
train ={1:{
                    'start_time': "2011-04-21" ,
                    'end_time': "2011-05-21"
                },
                3: {
                    'start_time': "2011-04-19" ,
                    'end_time': "2011-05-22"
                },
               
                
               2: {
                    'start_time': "2011-04-21" ,
                    'end_time': "2011-05-21"
                },6: {
                    'start_time': "2011-05-25" ,
                    'end_time': "2011-06-13"
                },
               
                }
test = { 5: {
                    'start_time': "2011-04-22" ,
                    'end_time': "2011-06-01"
                }
                ,}
appliances = ["Refrigerator"]

# %%
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler


def dataset_load(appliances, train, test=None):
    x_train = []
    y_train = []
    x_train_timestamp = []
    x_train_mean = []
    x_train_std = []
    x_train_max_min = []
    x_train_main = []
    x_train_main_dif = []
    n = 99
    units_to_pad = n // 2
    scaler_x = StandardScaler()
    scaler_y = StandardScaler()
    scaler_time = StandardScaler()
    scaler_mean = StandardScaler()
    scaler_std = StandardScaler()
    scaler_max_min = StandardScaler()
    scaler_main = StandardScaler()
    scaler_diff = StandardScaler()
    # train
    for key, values in train.items():
        df = pd.read_csv(
            f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[0]])
        df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
        startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
        endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

        if startDate > endDate:
            raise "Start Date must be smaller than Enddate."

        df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
        df.dropna(inplace=True)
        x = df["main"].values

        # x_diff = x
        # for i in range(1,len(x)):
        #     x_diff[i] = x_diff[i] - x_diff[i-1]

        x_train_main.extend(x)
        y = df[appliances[0]].values
        timestamp_train = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])
        # print(0)
        x_train_mean.extend(jnp.mean(x, axis=1))
        # print(0)
        x_train_std.extend(jnp.std(x, axis=1))
        x_train_max_min.extend(jnp.max(x, axis=1)-jnp.min(x,axis=1))
        x_train.extend(x)
        y_train.extend(y)
        x_train_timestamp.extend(torch.tensor(timestamp_train))
        # x_train_diff.extend(x_diff)

    # for i in range(1,len(x_train)):
    #     x_train[i] = x_train[i] - x_train[i-1]
    x_train = jnp.array(x_train)
    y_train = jnp.array(y_train).reshape(-1, 1)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(-1,1)
    x_train_main = jnp.array(x_train_main).reshape(-1,1)
    x_train_mean = jnp.array(x_train_mean).reshape(-1,1)
    x_train_std =  jnp.array(x_train_std).reshape(-1,1)
    x_train_max_min =  jnp.array(x_train_max_min).reshape(-1,1)
    # x_train_diff =  jnp.array(x_train_diff).reshape(-1,1)
   


    x_train = scaler_x.fit_transform(x_train)
    y_train = scaler_y.fit_transform(y_train)
    x_train_timestamp = scaler_time.fit_transform(x_train_timestamp)
    x_train_main = scaler_main.fit_transform(x_train_main)
    x_train_mean = scaler_mean.fit_transform(x_train_mean)
    x_train_std = scaler_std.fit_transform(x_train_std)
    x_train_max_min = scaler_max_min.fit_transform(x_train_max_min)
    # x_train_diff = scaler_diff.fit_transform(x_train_diff)

    # test
    x_test = []
    y_test = []
    x_test_timestamp = []
    x_test_mean = []
    x_test_std = []
    x_test_max_min = []
    x_test_timestamp_true =[]
    x_test_main = []


    for key, values in test.items():
        df = pd.read_csv(
            f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[0]])
        df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
        startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
        endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

        if startDate > endDate:
            raise "Start Date must be smaller than Enddate."

        df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
        df.dropna(inplace=True)
        x = df["main"].values 
        # x = x - 100
        # x_diff = x
        # for i in range(1,len(x)):
        #     x_diff[i] = x_diff[i] - x_diff[i-1]
        x_test_main.extend(x)
        y = df[appliances[0]].values

        timestamp_true = df["Timestamp"].values
        timestamp = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])

        x_test_mean.extend(jnp.mean(x, axis=1))
        x_test_std.extend(jnp.std(x, axis=1))
        x_test_max_min.extend(jnp.max(x, axis=1)-jnp.min(x, axis=1))
        x_test.extend(x)
        y_test.extend(y)
        x_test_timestamp_true.extend(timestamp_true)
        x_test_timestamp.extend(timestamp)
        # x_test_diff.extend(x_diff)

    # for i in range(1,len(x_test)):
    #     x_test[i] = x_test[i] - x_test[i-1]
    x_test = jnp.array(x_test)
    y_test = jnp.array(y_test).reshape(-1, 1)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(-1,1)
    x_test_main = jnp.array(x_test_main).reshape(-1,1)
    x_test_mean = jnp.array(x_test_mean).reshape(-1,1)
    x_test_std =  jnp.array(x_test_std).reshape(-1,1)
    x_test_max_min =  jnp.array(x_test_max_min).reshape(-1,1)

    x_test = scaler_x.transform(x_test)
    x_test_timestamp = scaler_time.transform(x_test_timestamp)
    x_test_mean = scaler_mean.transform(x_test_mean)
    x_test_std = scaler_std.transform(x_test_std)
    x_test_max_min = scaler_max_min.transform(x_test_max_min)
    x_test_main = scaler_main.transform(x_test_main)
    # x_test_diff = scaler_diff.transform(x_test_diff)
#     y_test = scaler_y.transform(y_test)

    # x_train_features = x_train_main_dif
    # x_test_features = x_test_main_dif

    x_train = jnp.array(x_train[:,1:]).reshape(x_train.shape[0], n-1)
    y_train = jnp.array(y_train)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(x_train_timestamp.shape[0], 1)
    x_test = jnp.array(x_test[:,1:]).reshape(x_test.shape[0], n-1)
    y_test = jnp.array(y_test)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(x_test_timestamp.shape[0], 1).to(torch.float64)

    
    x_train_features = jnp.concatenate((x_train_main, x_train_mean, x_train_max_min, x_train_std), axis=1).reshape(x_train.shape[0], 4)
    x_test_features = jnp.concatenate((x_test_main, x_test_mean, x_test_max_min, x_test_std), axis=1).reshape(x_test.shape[0], 4)

    scalers = np.array([scaler_x, scaler_y, scaler_time, scaler_main, scaler_mean, scaler_std, scaler_max_min])
    return x_train, y_train, x_test, y_test, x_train_features, x_test_features, x_train_timestamp, x_test_timestamp, scalers, x_test_main

# %%
x_train, y_train, x_test, y_test, x_train_features, x_test_features, x_train_timstamp, x_test_timestamp, scalers, x_test_main = dataset_load(appliances, train, test)

# %%
x_train_full = jnp.concatenate((x_train_features, jnp.array(np.array(x_train_timstamp))), axis=1)
x_test_full = jnp.concatenate((x_test_features, jnp.array(np.array(x_test_timestamp))), axis=1)

# %%
n = 4
# x_train_full = jnp.concatenate((x_train.reshape(-1,n), jnp.array(np.array(x_train_timstamp))), axis=1)
# x_test_full = jnp.concatenate((x_test.reshape(-1,n), jnp.array(np.array(x_test_timestamp))), axis=1)
# x_train_full.shape, x_test_full.shape

# %%
# x_train.reshape(-1,n).shape, x_test.reshape(-1,n).shape, y_train.shape, y_test.shape

# %%
# x = x_train_full[:14000]
# y = y_train[:14000]
# xt = x_train_full[14000:]
# yt = y_train[14000:]

# %%
# x.shape, y.shape

# %%
import gpytorch
indexes = 53456
x = torch.tensor(np.array(x_train_features)).to(torch.float64)
y = torch.tensor(np.array(y_train)).reshape(-1,).to(torch.float64)
xt = torch.tensor(np.array(x_test_features)).to(torch.float64)
yt = torch.tensor(np.array(y_test)).reshape(-1,).to(torch.float64)

if x.shape[0]>indexes:
  x = x[:indexes]
  y = y[:indexes]

# xt = xt[:16000]
# yt = yt[:16000]

# %%
x.dtype
# Out:
# torch.float64

# %%
x.shape, y.shape, xt.shape, yt.shape
# Out:
# (torch.Size([53456, 4]),
#  torch.Size([53456]),
#  torch.Size([3103, 4]),
#  torch.Size([3103]))

# %%
x.dtype
# Out:
# torch.float64

# %%
mae_arr =[]
rms_arr = []
y_pred_arr = []

batch = 512

# x_train = x_train[:4500]
# y_train = y_train[:4500]

# y_test_trans = torch.tensor(torch.tensor(scaler_x.transform(y_test.reshape(-1,1))).reshape(-1,)).contiguous().to(torch.float64)
for i in range(1):


   #nu=2.5,

  kernel1 = ScaleKernel(MaternKernel(nu=2.5, ard_num_dims=n))
  # kernel2 = ScaleKernel(MaternKernel(nu=0.5,ard_num_dims=1,active_dims=(n)))
  # kernel2 = ScaleKernel(RBFKernel(ard_num_dims=1, active_dims=(n)))
  # kernel3 = ScaleKernel(PeriodicKernel(ard_num_dims=1,active_dims=(n)))
  # kernel5 = ScaleKernel(gpytorch.kernels.SpectralDeltaKernel(num_dims=n,ard_num_dims=n))
#   theta =  {'base_covar_module.kernels.0.base_kernel.lengthscale': torch.tensor(0.5),
#         'base_covar_module.kernels.0.outputscale': torch.tensor(5.0),
#         'base_covar_module.kernels.1.kernels.0.outputscale':torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.0.base_kernel.lengthscale': torch.tensor(0.1),
#         'base_covar_module.kernels.1.kernels.1.outputscale':torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.1.base_kernel.lengthscale': torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
  # theta = { 'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
  # kernel4 = kernel2*kernel3
  kernel = kernel1 #+ kernel4
  # induce_points = 512
  inducing_points =  x[np.arange(0,x.shape[0],95)] 
  # inducing_points = x[torch.randperm(x.shape[0])[: 1500]]
  
  model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                       inducing_points).to("cuda")
  # model.base_covar_module.base_kernel.raw_lengthscale_constraint
  # model.mll.likelihood.noise_covar.register_constraint("raw_noise", GreaterThan(1e-2))
  # for param in model.parameters():
  #   # print(param)
  #   torch.nn.init.normal_(param, 0, 1)
  # theta1 = {'likelihood.noise_covar.noise': torch.tensor(3),
  #       'covar_module.base_kernel.lengthscale': torch.tensor(0.1),
  #       'covar_module.outputscale': torch.tensor(5),}
  loss = model.fit(lr=0.001, n_epochs=2000,verbose=1, thetas = None,
          random_state=0, n_restarts=1)
#   loss_arr.append(loss)
  # print(loss)
  plt.plot(np.asarray(loss[0]))
  # plt.plot(np.asarray(test_loss[0]))







  # y_pred_arr.append(pred_dist.loc)
# Out:
# restart: 0, epoch: 1, iter: 1, loss: 0.9614
# restart: 0, epoch: 2, iter: 1, loss: 0.9609
# restart: 0, epoch: 3, iter: 1, loss: 0.9605
# restart: 0, epoch: 4, iter: 1, loss: 0.9600
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/kernels/inducing_point_kernel.py:61: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352645774/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   inv_root = torch.triangular_solve(eye, chol)[0]
# restart: 0, epoch: 5, iter: 1, loss: 0.9596
# restart: 0, epoch: 6, iter: 1, loss: 0.9592
# restart: 0, epoch: 7, iter: 1, loss: 0.9588
# restart: 0, epoch: 8, iter: 1, loss: 0.9584
# restart: 0, epoch: 9, iter: 1, loss: 0.9580
# restart: 0, epoch: 10, iter: 1, loss: 0.9576
# restart: 0, epoch: 11, iter: 1, loss: 0.9572
# restart: 0, epoch: 12, iter: 1, loss: 0.9569
# restart: 0, epoch: 13, iter: 1, loss: 0.9565
# restart: 0, epoch: 14, iter: 1, loss: 0.9561
# restart: 0, epoch: 15, iter: 1, loss: 0.9558
# restart: 0, epoch: 16, iter: 1, loss: 0.9554
# restart: 0, epoch: 17, iter: 1, loss: 0.9551
# restart: 0, epoch: 18, iter: 1, loss: 0.9547
# restart: 0, epoch: 19, iter: 1, loss: 0.9544
# restart: 0, epoch: 20, iter: 1, loss: 0.9540
# restart: 0, epoch: 21, iter: 1, loss: 0.9537
# restart: 0, epoch: 22, iter: 1, loss: 0.9533
# restart: 0, epoch: 23, iter: 1, loss: 0.9530
# restart: 0, epoch: 24, iter: 1, loss: 0.9526
# restart: 0, epoch: 25, iter: 1, loss: 0.9523
# restart: 0, epoch: 26, iter: 1, loss: 0.9519
# restart: 0, epoch: 27, iter: 1, loss: 0.9516
# restart: 0, epoch: 28, iter: 1, loss: 0.9513
# restart: 0, epoch: 29, iter: 1, loss: 0.9509
# restart: 0, epoch: 30, iter: 1, loss: 0.9506
# restart: 0, epoch: 31, iter: 1, loss: 0.9503
# restart: 0, epoch: 32, iter: 1, loss: 0.9499
# restart: 0, epoch: 33, iter: 1, loss: 0.9496
# restart: 0, epoch: 34, iter: 1, loss: 0.9493
# restart: 0, epoch: 35, iter: 1, loss: 0.9490
# restart: 0, epoch: 36, iter: 1, loss: 0.9486
# restart: 0, epoch: 37, iter: 1, loss: 0.9483
# restart: 0, epoch: 38, iter: 1, loss: 0.9480
# restart: 0, epoch: 39, iter: 1, loss: 0.9477
# restart: 0, epoch: 40, iter: 1, loss: 0.9473
# restart: 0, epoch: 41, iter: 1, loss: 0.9470
# restart: 0, epoch: 42, iter: 1, loss: 0.9467
# restart: 0, epoch: 43, iter: 1, loss: 0.9464
# restart: 0, epoch: 44, iter: 1, loss: 0.9460
# restart: 0, epoch: 45, iter: 1, loss: 0.9457
# restart: 0, epoch: 46, iter: 1, loss: 0.9454
# restart: 0, epoch: 47, iter: 1, loss: 0.9451
# restart: 0, epoch: 48, iter: 1, loss: 0.9448
# restart: 0, epoch: 999, iter: 1, loss: 0.7315
# restart: 0, epoch: 1000, iter: 1, loss: 0.7313
# restart: 0, epoch: 1001, iter: 1, loss: 0.7311
# restart: 0, epoch: 1002, iter: 1, loss: 0.7309
# restart: 0, epoch: 1003, iter: 1, loss: 0.7307
# restart: 0, epoch: 1004, iter: 1, loss: 0.7305
# restart: 0, epoch: 1005, iter: 1, loss: 0.7303
# restart: 0, epoch: 1006, iter: 1, loss: 0.7302
# restart: 0, epoch: 1007, iter: 1, loss: 0.7300
# restart: 0, epoch: 1008, iter: 1, loss: 0.7298
# restart: 0, epoch: 1009, iter: 1, loss: 0.7296
# restart: 0, epoch: 1010, iter: 1, loss: 0.7294
# restart: 0, epoch: 1011, iter: 1, loss: 0.7292
# restart: 0, epoch: 1012, iter: 1, loss: 0.7290
# restart: 0, epoch: 1013, iter: 1, loss: 0.7289
# restart: 0, epoch: 1014, iter: 1, loss: 0.7287
# restart: 0, epoch: 1015, iter: 1, loss: 0.7285
# restart: 0, epoch: 1016, iter: 1, loss: 0.7283
# restart: 0, epoch: 1017, iter: 1, loss: 0.7281
# restart: 0, epoch: 1018, iter: 1, loss: 0.7279
# restart: 0, epoch: 1019, iter: 1, loss: 0.7277
# restart: 0, epoch: 1020, iter: 1, loss: 0.7275
# restart: 0, epoch: 1021, iter: 1, loss: 0.7273
# restart: 0, epoch: 1022, iter: 1, loss: 0.7272
# restart: 0, epoch: 1023, iter: 1, loss: 0.7270
# restart: 0, epoch: 1024, iter: 1, loss: 0.7268
# restart: 0, epoch: 1025, iter: 1, loss: 0.7266
# restart: 0, epoch: 1026, iter: 1, loss: 0.7264
# restart: 0, epoch: 1027, iter: 1, loss: 0.7262
# restart: 0, epoch: 1028, iter: 1, loss: 0.7260
# restart: 0, epoch: 1029, iter: 1, loss: 0.7258
# restart: 0, epoch: 1030, iter: 1, loss: 0.7256
# restart: 0, epoch: 1031, iter: 1, loss: 0.7254
# ...
# restart: 0, epoch: 1661, iter: 1, loss: 0.6508
# restart: 0, epoch: 1662, iter: 1, loss: 0.6507
# restart: 0, epoch: 1663, iter: 1, loss: 0.6507
# restart: 0, epoch: 1664, iter: 1, loss: 0.6506
# restart: 0, epoch: 1665, iter: 1, loss: 0.6506
# restart: 0, epoch: 1666, iter: 1, loss: 0.6505
# restart: 0, epoch: 1667, iter: 1, loss: 0.6505
# restart: 0, epoch: 1668, iter: 1, loss: 0.6504
# restart: 0, epoch: 1669, iter: 1, loss: 0.6504
# restart: 0, epoch: 1670, iter: 1, loss: 0.6503
# restart: 0, epoch: 1671, iter: 1, loss: 0.6503
# restart: 0, epoch: 1672, iter: 1, loss: 0.6502
# restart: 0, epoch: 1673, iter: 1, loss: 0.6502
# restart: 0, epoch: 1674, iter: 1, loss: 0.6501
# restart: 0, epoch: 1675, iter: 1, loss: 0.6501
# restart: 0, epoch: 1676, iter: 1, loss: 0.6501
# restart: 0, epoch: 1677, iter: 1, loss: 0.6500
# restart: 0, epoch: 1678, iter: 1, loss: 0.6500
# restart: 0, epoch: 1730, iter: 1, loss: 0.6475
# restart: 0, epoch: 1731, iter: 1, loss: 0.6475
# restart: 0, epoch: 1732, iter: 1, loss: 0.6474
# restart: 0, epoch: 1733, iter: 1, loss: 0.6474
# restart: 0, epoch: 1734, iter: 1, loss: 0.6473
# restart: 0, epoch: 1735, iter: 1, loss: 0.6473
# restart: 0, epoch: 1736, iter: 1, loss: 0.6472
# restart: 0, epoch: 1737, iter: 1, loss: 0.6472
# restart: 0, epoch: 1738, iter: 1, loss: 0.6472
# restart: 0, epoch: 1739, iter: 1, loss: 0.6471
# restart: 0, epoch: 1740, iter: 1, loss: 0.6471
# restart: 0, epoch: 1741, iter: 1, loss: 0.6470
# restart: 0, epoch: 1742, iter: 1, loss: 0.6470
# restart: 0, epoch: 1743, iter: 1, loss: 0.6470
# restart: 0, epoch: 1744, iter: 1, loss: 0.6469
# restart: 0, epoch: 1745, iter: 1, loss: 0.6469
# restart: 0, epoch: 1746, iter: 1, loss: 0.6469
# restart: 0, epoch: 1747, iter: 1, loss: 0.6468
# restart: 0, epoch: 1748, iter: 1, loss: 0.6468
# restart: 0, epoch: 1749, iter: 1, loss: 0.6467
# restart: 0, epoch: 1750, iter: 1, loss: 0.6467
# restart: 0, epoch: 1751, iter: 1, loss: 0.6467
# restart: 0, epoch: 1752, iter: 1, loss: 0.6466
# restart: 0, epoch: 1753, iter: 1, loss: 0.6466
# restart: 0, epoch: 1754, iter: 1, loss: 0.6466
# restart: 0, epoch: 1755, iter: 1, loss: 0.6465
# restart: 0, epoch: 1756, iter: 1, loss: 0.6465
# restart: 0, epoch: 1757, iter: 1, loss: 0.6465
# restart: 0, epoch: 1758, iter: 1, loss: 0.6464
# restart: 0, epoch: 1759, iter: 1, loss: 0.6464
# restart: 0, epoch: 1760, iter: 1, loss: 0.6464
# restart: 0, epoch: 1761, iter: 1, loss: 0.6463
# restart: 0, epoch: 1762, iter: 1, loss: 0.6463
# restart: 0, epoch: 1763, iter: 1, loss: 0.6462
# restart: 0, epoch: 1764, iter: 1, loss: 0.6462
# restart: 0, epoch: 1765, iter: 1, loss: 0.6462
# restart: 0, epoch: 1766, iter: 1, loss: 0.6462
# restart: 0, epoch: 1767, iter: 1, loss: 0.6461
# restart: 0, epoch: 1768, iter: 1, loss: 0.6461
# restart: 0, epoch: 1769, iter: 1, loss: 0.6461
# restart: 0, epoch: 1770, iter: 1, loss: 0.6460
# restart: 0, epoch: 1771, iter: 1, loss: 0.6460
# restart: 0, epoch: 1772, iter: 1, loss: 0.6460
# restart: 0, epoch: 1773, iter: 1, loss: 0.6459
# restart: 0, epoch: 1774, iter: 1, loss: 0.6459
# restart: 0, epoch: 1775, iter: 1, loss: 0.6459
# restart: 0, epoch: 1776, iter: 1, loss: 0.6458
# restart: 0, epoch: 1777, iter: 1, loss: 0.6458
# restart: 0, epoch: 1778, iter: 1, loss: 0.6458
# restart: 0, epoch: 1779, iter: 1, loss: 0.6457
# restart: 0, epoch: 1780, iter: 1, loss: 0.6457
# restart: 0, epoch: 1781, iter: 1, loss: 0.6457
# restart: 0, epoch: 1782, iter: 1, loss: 0.6456
# restart: 0, epoch: 1783, iter: 1, loss: 0.6456
# restart: 0, epoch: 1784, iter: 1, loss: 0.6456
# restart: 0, epoch: 1785, iter: 1, loss: 0.6455
# restart: 0, epoch: 1786, iter: 1, loss: 0.6455
# restart: 0, epoch: 1787, iter: 1, loss: 0.6455
# restart: 0, epoch: 1788, iter: 1, loss: 0.6455
# restart: 0, epoch: 1789, iter: 1, loss: 0.6454
# restart: 0, epoch: 1790, iter: 1, loss: 0.6454
# restart: 0, epoch: 1791, iter: 1, loss: 0.6454
# restart: 0, epoch: 1792, iter: 1, loss: 0.6453
# restart: 0, epoch: 1793, iter: 1, loss: 0.6453
# restart: 0, epoch: 1794, iter: 1, loss: 0.6453
# restart: 0, epoch: 1795, iter: 1, loss: 0.6452
# restart: 0, epoch: 1796, iter: 1, loss: 0.6452
# restart: 0, epoch: 1797, iter: 1, loss: 0.6452
# restart: 0, epoch: 1798, iter: 1, loss: 0.6452
# restart: 0, epoch: 1799, iter: 1, loss: 0.6451
# restart: 0, epoch: 1800, iter: 1, loss: 0.6451
# restart: 0, epoch: 1801, iter: 1, loss: 0.6451
# restart: 0, epoch: 1802, iter: 1, loss: 0.6450
# restart: 0, epoch: 1803, iter: 1, loss: 0.6450
# restart: 0, epoch: 1804, iter: 1, loss: 0.6450
# restart: 0, epoch: 1805, iter: 1, loss: 0.6450
# restart: 0, epoch: 1806, iter: 1, loss: 0.6449
# restart: 0, epoch: 1807, iter: 1, loss: 0.6449
# restart: 0, epoch: 1808, iter: 1, loss: 0.6449
# restart: 0, epoch: 1809, iter: 1, loss: 0.6449
# restart: 0, epoch: 1810, iter: 1, loss: 0.6448
# restart: 0, epoch: 1811, iter: 1, loss: 0.6448
# restart: 0, epoch: 1812, iter: 1, loss: 0.6448
# restart: 0, epoch: 1813, iter: 1, loss: 0.6447
# restart: 0, epoch: 1814, iter: 1, loss: 0.6447
# restart: 0, epoch: 1815, iter: 1, loss: 0.6447
# restart: 0, epoch: 1816, iter: 1, loss: 0.6447
# restart: 0, epoch: 1817, iter: 1, loss: 0.6446
# restart: 0, epoch: 1818, iter: 1, loss: 0.6446
# restart: 0, epoch: 1819, iter: 1, loss: 0.6446
# restart: 0, epoch: 1820, iter: 1, loss: 0.6446
# restart: 0, epoch: 1821, iter: 1, loss: 0.6445
# restart: 0, epoch: 1822, iter: 1, loss: 0.6445
# restart: 0, epoch: 1823, iter: 1, loss: 0.6445
# restart: 0, epoch: 1824, iter: 1, loss: 0.6445
# restart: 0, epoch: 1825, iter: 1, loss: 0.6444
# restart: 0, epoch: 1826, iter: 1, loss: 0.6444
# restart: 0, epoch: 1827, iter: 1, loss: 0.6444
# restart: 0, epoch: 1828, iter: 1, loss: 0.6443
# restart: 0, epoch: 1829, iter: 1, loss: 0.6443
# restart: 0, epoch: 1830, iter: 1, loss: 0.6443
# restart: 0, epoch: 1831, iter: 1, loss: 0.6443
# restart: 0, epoch: 1832, iter: 1, loss: 0.6442
# restart: 0, epoch: 1833, iter: 1, loss: 0.6442
# restart: 0, epoch: 1834, iter: 1, loss: 0.6442
# restart: 0, epoch: 1835, iter: 1, loss: 0.6442
# restart: 0, epoch: 1836, iter: 1, loss: 0.6441
# restart: 0, epoch: 1837, iter: 1, loss: 0.6441
# restart: 0, epoch: 1838, iter: 1, loss: 0.6441
# restart: 0, epoch: 1839, iter: 1, loss: 0.6441
# restart: 0, epoch: 1840, iter: 1, loss: 0.6440
# restart: 0, epoch: 1841, iter: 1, loss: 0.6440
# restart: 0, epoch: 1842, iter: 1, loss: 0.6440
# restart: 0, epoch: 1843, iter: 1, loss: 0.6440
# restart: 0, epoch: 1844, iter: 1, loss: 0.6439
# restart: 0, epoch: 1845, iter: 1, loss: 0.6439
# restart: 0, epoch: 1846, iter: 1, loss: 0.6439
# restart: 0, epoch: 1847, iter: 1, loss: 0.6439
# restart: 0, epoch: 1848, iter: 1, loss: 0.6438
# restart: 0, epoch: 1849, iter: 1, loss: 0.6438
# restart: 0, epoch: 1850, iter: 1, loss: 0.6438
# restart: 0, epoch: 1851, iter: 1, loss: 0.6438
# restart: 0, epoch: 1852, iter: 1, loss: 0.6437
# restart: 0, epoch: 1853, iter: 1, loss: 0.6437
# restart: 0, epoch: 1854, iter: 1, loss: 0.6437
# restart: 0, epoch: 1855, iter: 1, loss: 0.6437
# restart: 0, epoch: 1856, iter: 1, loss: 0.6436
# restart: 0, epoch: 1857, iter: 1, loss: 0.6436
# restart: 0, epoch: 1858, iter: 1, loss: 0.6436
# restart: 0, epoch: 1859, iter: 1, loss: 0.6436
# restart: 0, epoch: 1860, iter: 1, loss: 0.6435
# restart: 0, epoch: 1861, iter: 1, loss: 0.6435
# restart: 0, epoch: 1862, iter: 1, loss: 0.6435
# restart: 0, epoch: 1863, iter: 1, loss: 0.6435
# restart: 0, epoch: 1864, iter: 1, loss: 0.6434
# restart: 0, epoch: 1865, iter: 1, loss: 0.6434
# restart: 0, epoch: 1866, iter: 1, loss: 0.6434
# restart: 0, epoch: 1867, iter: 1, loss: 0.6434
# restart: 0, epoch: 1868, iter: 1, loss: 0.6433
# restart: 0, epoch: 1869, iter: 1, loss: 0.6433
# restart: 0, epoch: 1870, iter: 1, loss: 0.6433
# restart: 0, epoch: 1871, iter: 1, loss: 0.6433
# restart: 0, epoch: 1872, iter: 1, loss: 0.6433
# restart: 0, epoch: 1873, iter: 1, loss: 0.6432
# restart: 0, epoch: 1874, iter: 1, loss: 0.6432
# restart: 0, epoch: 1875, iter: 1, loss: 0.6432
# restart: 0, epoch: 1876, iter: 1, loss: 0.6432
# restart: 0, epoch: 1877, iter: 1, loss: 0.6432
# restart: 0, epoch: 1878, iter: 1, loss: 0.6431
# restart: 0, epoch: 1879, iter: 1, loss: 0.6431
# restart: 0, epoch: 1880, iter: 1, loss: 0.6431
# restart: 0, epoch: 1881, iter: 1, loss: 0.6431
# restart: 0, epoch: 1882, iter: 1, loss: 0.6431
# restart: 0, epoch: 1883, iter: 1, loss: 0.6430
# restart: 0, epoch: 1884, iter: 1, loss: 0.6430
# restart: 0, epoch: 1885, iter: 1, loss: 0.6430
# restart: 0, epoch: 1886, iter: 1, loss: 0.6430
# restart: 0, epoch: 1887, iter: 1, loss: 0.6430
# restart: 0, epoch: 1888, iter: 1, loss: 0.6429
# restart: 0, epoch: 1889, iter: 1, loss: 0.6429
# restart: 0, epoch: 1890, iter: 1, loss: 0.6429
# restart: 0, epoch: 1891, iter: 1, loss: 0.6429
# restart: 0, epoch: 1892, iter: 1, loss: 0.6429
# restart: 0, epoch: 1893, iter: 1, loss: 0.6428
# restart: 0, epoch: 1894, iter: 1, loss: 0.6428
# restart: 0, epoch: 1895, iter: 1, loss: 0.6428
# restart: 0, epoch: 1896, iter: 1, loss: 0.6428
# restart: 0, epoch: 1897, iter: 1, loss: 0.6428
# restart: 0, epoch: 1898, iter: 1, loss: 0.6428
# restart: 0, epoch: 1899, iter: 1, loss: 0.6427
# restart: 0, epoch: 1900, iter: 1, loss: 0.6427
# restart: 0, epoch: 1901, iter: 1, loss: 0.6427
# restart: 0, epoch: 1902, iter: 1, loss: 0.6427
# restart: 0, epoch: 1903, iter: 1, loss: 0.6427
# restart: 0, epoch: 1904, iter: 1, loss: 0.6426
# restart: 0, epoch: 1905, iter: 1, loss: 0.6426
# restart: 0, epoch: 1906, iter: 1, loss: 0.6426
# restart: 0, epoch: 1907, iter: 1, loss: 0.6426
# restart: 0, epoch: 1908, iter: 1, loss: 0.6425
# restart: 0, epoch: 1909, iter: 1, loss: 0.6425
# restart: 0, epoch: 1910, iter: 1, loss: 0.6425
# restart: 0, epoch: 1911, iter: 1, loss: 0.6425
# restart: 0, epoch: 1912, iter: 1, loss: 0.6425
# restart: 0, epoch: 1913, iter: 1, loss: 0.6424
# restart: 0, epoch: 1914, iter: 1, loss: 0.6424
# restart: 0, epoch: 1915, iter: 1, loss: 0.6424
# restart: 0, epoch: 1916, iter: 1, loss: 0.6424
# restart: 0, epoch: 1917, iter: 1, loss: 0.6424
# restart: 0, epoch: 1918, iter: 1, loss: 0.6424
# restart: 0, epoch: 1919, iter: 1, loss: 0.6423
# restart: 0, epoch: 1920, iter: 1, loss: 0.6423
# restart: 0, epoch: 1921, iter: 1, loss: 0.6423
# restart: 0, epoch: 1922, iter: 1, loss: 0.6423
# restart: 0, epoch: 1923, iter: 1, loss: 0.6423
# restart: 0, epoch: 1924, iter: 1, loss: 0.6422
# restart: 0, epoch: 1925, iter: 1, loss: 0.6422
# restart: 0, epoch: 1926, iter: 1, loss: 0.6422
# restart: 0, epoch: 1927, iter: 1, loss: 0.6422
# restart: 0, epoch: 1928, iter: 1, loss: 0.6422
# restart: 0, epoch: 1929, iter: 1, loss: 0.6422
# restart: 0, epoch: 1930, iter: 1, loss: 0.6421
# restart: 0, epoch: 1931, iter: 1, loss: 0.6421
# restart: 0, epoch: 1932, iter: 1, loss: 0.6421
# restart: 0, epoch: 1933, iter: 1, loss: 0.6421
# restart: 0, epoch: 1934, iter: 1, loss: 0.6421
# restart: 0, epoch: 1935, iter: 1, loss: 0.6421
# restart: 0, epoch: 1936, iter: 1, loss: 0.6420
# restart: 0, epoch: 1937, iter: 1, loss: 0.6420
# restart: 0, epoch: 1938, iter: 1, loss: 0.6420
# restart: 0, epoch: 1939, iter: 1, loss: 0.6420
# restart: 0, epoch: 1940, iter: 1, loss: 0.6420
# restart: 0, epoch: 1941, iter: 1, loss: 0.6420
# restart: 0, epoch: 1942, iter: 1, loss: 0.6419
# restart: 0, epoch: 1943, iter: 1, loss: 0.6419
# restart: 0, epoch: 1944, iter: 1, loss: 0.6419
# restart: 0, epoch: 1945, iter: 1, loss: 0.6419
# restart: 0, epoch: 1946, iter: 1, loss: 0.6419
# restart: 0, epoch: 1947, iter: 1, loss: 0.6419
# restart: 0, epoch: 1948, iter: 1, loss: 0.6419
# restart: 0, epoch: 1949, iter: 1, loss: 0.6418
# restart: 0, epoch: 1950, iter: 1, loss: 0.6418
# restart: 0, epoch: 1951, iter: 1, loss: 0.6418
# restart: 0, epoch: 1952, iter: 1, loss: 0.6418
# restart: 0, epoch: 1953, iter: 1, loss: 0.6418
# restart: 0, epoch: 1954, iter: 1, loss: 0.6418
# restart: 0, epoch: 1955, iter: 1, loss: 0.6417
# restart: 0, epoch: 1956, iter: 1, loss: 0.6417
# restart: 0, epoch: 1957, iter: 1, loss: 0.6417
# restart: 0, epoch: 1958, iter: 1, loss: 0.6417
# restart: 0, epoch: 1959, iter: 1, loss: 0.6417
# restart: 0, epoch: 1960, iter: 1, loss: 0.6417
# restart: 0, epoch: 1961, iter: 1, loss: 0.6417
# restart: 0, epoch: 1962, iter: 1, loss: 0.6416
# restart: 0, epoch: 1963, iter: 1, loss: 0.6416
# restart: 0, epoch: 1964, iter: 1, loss: 0.6416
# restart: 0, epoch: 1965, iter: 1, loss: 0.6416
# restart: 0, epoch: 1966, iter: 1, loss: 0.6416
# restart: 0, epoch: 1967, iter: 1, loss: 0.6416
# restart: 0, epoch: 1968, iter: 1, loss: 0.6416
# restart: 0, epoch: 1969, iter: 1, loss: 0.6416
# restart: 0, epoch: 1970, iter: 1, loss: 0.6415
# restart: 0, epoch: 1971, iter: 1, loss: 0.6415
# restart: 0, epoch: 1972, iter: 1, loss: 0.6415
# restart: 0, epoch: 1973, iter: 1, loss: 0.6415
# restart: 0, epoch: 1974, iter: 1, loss: 0.6415
# restart: 0, epoch: 1975, iter: 1, loss: 0.6415
# restart: 0, epoch: 1976, iter: 1, loss: 0.6415
# restart: 0, epoch: 1977, iter: 1, loss: 0.6414
# restart: 0, epoch: 1978, iter: 1, loss: 0.6414
# restart: 0, epoch: 1979, iter: 1, loss: 0.6414
# restart: 0, epoch: 1980, iter: 1, loss: 0.6414
# restart: 0, epoch: 1981, iter: 1, loss: 0.6414
# restart: 0, epoch: 1982, iter: 1, loss: 0.6414
# restart: 0, epoch: 1983, iter: 1, loss: 0.6414
# restart: 0, epoch: 1984, iter: 1, loss: 0.6413
# restart: 0, epoch: 1985, iter: 1, loss: 0.6413
# restart: 0, epoch: 1986, iter: 1, loss: 0.6413
# restart: 0, epoch: 1987, iter: 1, loss: 0.6413
# restart: 0, epoch: 1988, iter: 1, loss: 0.6413
# restart: 0, epoch: 1989, iter: 1, loss: 0.6413
# restart: 0, epoch: 1990, iter: 1, loss: 0.6413
# restart: 0, epoch: 1991, iter: 1, loss: 0.6413
# restart: 0, epoch: 1992, iter: 1, loss: 0.6412
# restart: 0, epoch: 1993, iter: 1, loss: 0.6412
# restart: 0, epoch: 1994, iter: 1, loss: 0.6412
# restart: 0, epoch: 1995, iter: 1, loss: 0.6412
# restart: 0, epoch: 1996, iter: 1, loss: 0.6412
# restart: 0, epoch: 1997, iter: 1, loss: 0.6412
# restart: 0, epoch: 1998, iter: 1, loss: 0.6412
# restart: 0, epoch: 1999, iter: 1, loss: 0.6412
# restart: 0, epoch: 2000, iter: 1, loss: 0.6411

# %%
  # model_name = "Refrigerator_trial_seq_time.pt"
  # torch.save(model.state_dict(), os.path.join(
  #  "models/", model_name))

# %% [markdown]
# ## Decomp

# %%
kernel1 = ScaleKernel(RBFKernel(ard_num_dims=n))
# kernel2 = ScaleKernel(RBFKernel(ard_num_dims=1,active_dims=(99)))
# kernel3 = ScaleKernel(CosineKernel(ard_num_dims=1,active_dims=(99)))

# kernel4 = kernel2*kernel3
kernel = kernel1 #ernel4
# induce_points = 512
inducing_points =  x[np.arange(0,x.shape[0],70)] 
# inducing_points = x[torch.randperm(x.shape[0])[: 1500]]

model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                      inducing_points).to("cuda")

model_name =  "Refrigerator_rbf_building6_" + str(0) + ".pt"
model.load_state_dict(torch.load(
    os.path.join("./final_models/", model_name)))
# Out:
# <All keys matched successfully>

# %%
model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
                      inducing_points).to("cuda")

# %%
pred_dist1 = model1.predict(xt[:4000].to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_mean1.shape
# Out:
# torch.Size([4000])

# %%
pred_arr =[]
pred_arr.append(np.array(pred_dist1.mean.cpu()))

# %%
y_mean1 = np.mean(pred_arr, axis =0)

# y_Std = np.std(np.array(pred_arr), axis =0)

# %%
y_mean1 = scalers[1].inverse_transform(y_mean1.reshape(-1,1)).squeeze()
# y_std = scaler_y.inverse_transform(y_Std.reshape(-1,1)).squeeze()

# %%
y_mean1.shape
# Out:
# (4000,)

# %%
y_mean_ = np.clip(y_mean1,0,y_mean1.max())
# y_sigma =  np.clip(y_mean,0,y_mean.max())

# %%
idx = 3000
plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp[:idx], scalers[].inverse_transform(xt.cpu().reshape(-1,1))[:idx], label = "Main")
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean_[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
# savefig("Uncertainity")

# %%
model2 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel4,
                      inducing_points).to("cuda")

# %%
pred_dist2 = model2.predict(xt[:4000].to("cuda"))
# print("Done ", i)

y_mean2 = pred_dist2.loc

# %%
y_mean2 = scalers[1].inverse_transform(y_mean2.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean2.shape)
# Out:
# torch.Size([16781]) (4000,)

# %%
y_mean_ = np.clip(y_mean2,0,y_mean2.max())

# %%
idx = 3000
plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp[:idx], scaler_y.inverse_transform(y.cpu().reshape(-1,1))[:idx], label = "Main")
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean_[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()

# %%
idx = 3000
# plt.figure(figsize=(10,6))
plt.plot(jnp.arange(idx),  yt.cpu().reshape(-1,1)[:idx], label = "Ground Truth", color="green")
plt.plot(jnp.arange(idx), y_mean_[:idx].reshape(-1,1), label = "Predicted")
# for i in range(2,3):
#     plt.fill_between(jnp.arange(idx), y_mean[:idx] - i*y_std[:idx], y_mean[:idx] + i*y_std[:idx],
#                     color="orange", alpha=(1/(i*3)), label=f"$\mu\pm{i}*\sigma$")
# plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.legend( prop={'size': 5.5})
plt.ylabel("Power")
sns.despine()

# %%
mae = np.mean(np.abs(np.array(yt) - y_mean))
rms = errors.rmse(jnp.array(yt), y_mean)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  27.80521506352558
# RMSE:  44.84471

# %%
try:
    from probml_utils import latexify, savefig, is_latexify_enabled
except ModuleNotFoundError:
    # %pip install git+https://github.com/probml/probml-utils.git
    from probml_utils import latexify, savefig, is_latexify_enabled

# %%
os.environ["LATEXIFY"] = "1"
os.environ["FIG_DIR"] = "./Final_plotss/"

# %%
latexify(width_scale_factor=2, fig_height=2)

# %%
idx = 2000
# plt.figure(figsize=(10,6))
plt.figure()
plt.plot(jnp.arange(idx), yt[300:idx+300], label = "Fridge True")
plt.plot(jnp.arange(idx), y_mean[300:idx+300], label = "Fridge Predicted")
plt.legend()
sns.despine()
savefig("CombinationKernel")
# Out:
# saving image to ./Final_plotss/CombinationKernel_latexified.pdf
# Figure size: [2. 2.]

# %%
model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
                       inducing_points).to("cuda")

# %%
pred_dist1 = model1.predict(xt.to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_mean1 = scalers[1].inverse_transform(y_mean1.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean1.shape)
# Out:
# torch.Size([14780]) (14780,)

# %%
idx = 2000
# plt.figure(figsize=(10,6))
plt.figure()
plt.plot(jnp.arange(idx), yt[300:idx+300], label = "Fridge True")
plt.plot(jnp.arange(idx), y_mean1[300:idx+300], label = "Fridge Predicted")
# plt.legend()
sns.despine()
savefig("RBFKernel")
# Out:
# saving image to ./Final_plotss/RBFKernel_latexified.pdf
# Figure size: [2. 2.]

# %%
# for name, params in model.named_parameters():
#   print(name, params)

# # model.mll.model.base_covar_module.kernels.base_kernel.raw_lengthscale

# %%
x.shape
# Out:
# torch.Size([55457, 100])

# %%
model2 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel4,
                       inducing_points).to("cuda")

# %%
pred_dist2 = model2.predict(xt.to("cuda"))
# print("Done ", i)

y_mean2 = pred_dist2.loc
# Out:
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/kernels/inducing_point_kernel.py:61: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352645774/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   inv_root = torch.triangular_solve(eye, chol)[0]

# %%
y_mean2 = scaler_y.inverse_transform(y_mean2.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean2.shape)
# Out:
# torch.Size([14780]) (14780,)

# %%
idx = 2000
plt.figure()
# plt.figure(figsize=(10,6))
plt.plot(jnp.arange(idx), yt[300:idx+300], label = "Fridge True")
plt.plot(jnp.arange(idx), y_mean2[300:idx+300], label = "Fridge Predicted")
# plt.legend()
sns.despine()
savefig("RBFxPeriodicKernel")
# Out:
# saving image to ./Final_plotss/RBFxPeriodicKernel_latexified.pdf
# Figure size: [2. 2.]

# %% [markdown]
# ## Normal

# %%
# kernel1 = ScaleKernel(MaternKernel(nu=2.5,ard_num_dims=n+1))
# kernel2 = ScaleKernel(MaternKernel(nu=0.5,ard_num_dims=1,active_dims=(99)))
# kernel3 = ScaleKernel(PeriodicKernel(ard_num_dims=1,active_dims=(99)))
# # kernel5 = ScaleKernel(gpytorch.kernels.SpectralDeltaKernel(num_dims=n,ard_num_dims=n))
# #   theta =  {'base_covar_module.kernels.0.base_kernel.lengthscale': torch.tensor(0.5),
# #         'base_covar_module.kernels.0.outputscale': torch.tensor(5.0),
# #         'base_covar_module.kernels.1.kernels.0.outputscale':torch.tensor(1.0),
# #         'base_covar_module.kernels.1.kernels.0.base_kernel.lengthscale': torch.tensor(0.1),
# #         'base_covar_module.kernels.1.kernels.1.outputscale':torch.tensor(1.0),
# #         'base_covar_module.kernels.1.kernels.1.base_kernel.lengthscale': torch.tensor(1.0),
# #         'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
# #theta = { 'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
# kernel4 = kernel2*kernel3
# kernel = kernel1 + kernel4
# # induce_points = 512
# inducing_points =  x[np.arange(0,x.shape[0],95)] 
# # inducing_points = x[torch.randperm(x.shape[0])[: 1500]]

# model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
#                     inducing_points).to("cuda")
# model_name =  "Refrigerator_trial_seq_time.pt"
# model.load_state_dict(torch.load(
#     os.path.join("models/", model_name)))
# Out:
# <All keys matched successfully>

# %%
plt.scatter(range(4),model.mll.model.base_covar_module.base_kernel.lengthscale.cpu().detach().reshape(-1,1))

# %%
plt.scatter(range(5),model.mll.model.base_covar_module.kernels[0].base_kernel.lengthscale.cpu().detach().reshape(-1,1)[:5])

# %%
for name, params in model.named_parameters():
  print(name, params)
# Out:
# mll.likelihood.noise_covar.raw_noise Parameter containing:
# tensor([-2.1231], device='cuda:0', requires_grad=True)
# mll.model.mean_module.constant Parameter containing:
# tensor([0.3088], device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.kernels.0.raw_outputscale Parameter containing:
# tensor(-1.0261, device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.kernels.0.base_kernel.raw_lengthscale Parameter containing:
# tensor([[0.2123, 2.0857, 1.7805, 0.1921, 1.8406]], device='cuda:0',
#        requires_grad=True)
# mll.model.base_covar_module.kernels.1.kernels.0.raw_outputscale Parameter containing:
# tensor(-1.6808, device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.kernels.1.kernels.0.base_kernel.raw_lengthscale Parameter containing:
# tensor([[1.3642]], device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.kernels.1.kernels.1.raw_outputscale Parameter containing:
# tensor(-1.6808, device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.kernels.1.kernels.1.base_kernel.raw_lengthscale Parameter containing:
# tensor([[0.7452]], device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.kernels.1.kernels.1.base_kernel.raw_period_length Parameter containing:
# tensor([[1.3606]], device='cuda:0', requires_grad=True)
# mll.model.covar_module.inducing_points Parameter containing:
# tensor([[-0.2777, -0.2465, -0.5519, -0.1870, -0.9639],
#         [-0.0758, -0.4629, -0.4894, -0.2404, -0.9346],
#         [-0.1859,  0.1687,  2.6663, -0.2663, -0.9415],
#         ...,
#         [ 0.3023,  0.4017,  2.3741,  0.4092,  0.1435],
#         [-0.1476, -0.1466, -0.5361, -0.3916,  0.1530],
#         [-0.0628, -0.3994, -0.4842, -0.2378,  0.1531]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)

# %%
# import numpy as np
# try:
#     from probml_utils import latexify, savefig, is_latexify_enabled
# except ModuleNotFoundError:
#     %pip install git+https://github.com/probml/probml-utils.git
#     from probml_utils import latexify, savefig, is_latexify_enabled


# os.environ["LATEXIFY"] = "1"
# os.environ["FIG_DIR"] = "./Final_plotss/"

# latexify(width_scale_factor=2, fig_height=2)

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
# arr = np.array([3.8464, 4.5094, 4.7394, 4.9024, 4.9117, 5.0150, 4.8746, 4.9372, 4.3143,
#          4.5656, 5.0050, 5.1365, 5.1490, 5.2152, 5.2837, 5.2594, 5.1965, 5.0747,
#          5.1212, 4.8200, 4.6431, 4.8732, 4.7529, 0.3853, 4.4826, 4.9550, 5.0677,
#          5.2859, 4.9612, 5.1401, 5.2131, 4.4774, 4.5654, 4.5685, 3.8310, 3.0889,
#          2.7822, 4.0948, 4.0399, 4.6180, 4.5923, 4.5015, 4.0521, 4.8423, 5.2143,
#          5.4020, 4.8021, 4.5021, 0.6626, 0.1252, 1.3779, 4.8821, 4.6781, 4.8554,
#          4.5223, 4.5568, 5.0172, 5.4072, 5.0706, 4.5916, 4.5663, 4.1121, 4.2572,
#          4.2228, 3.7784, 0.4839, 3.6554, 4.3523, 4.6682, 4.6549, 4.8291, 5.0260,
#          4.7748, 4.5609, 4.4541, 4.4165, 4.4292, 4.1279, 3.6382, 4.1110, 4.7252,
#          5.0184, 5.0391, 5.2424, 5.5062, 5.4739, 5.5326, 5.6874, 5.6897, 5.4765,
#          5.4602, 5.4513, 5.5450, 5.6225, 5.5479, 5.3580, 5.3926, 5.1536, 4.6321])
# ar1 = np.arange(0,99,1)
# plt.plot(ar1,arr,'b')
# plt.xlabel('ARD')
# plt.ylabel('Learned ARD LengthScale values')
# # plt.title("Building 6 Test")

# plt.show()
# sns.despine()
# savefig("ARD_Ref")

# %%
pred_dist = model.predict(xt.to("cuda"))
# print("Done ", i)

# %%
y_mean = pred_dist.loc

# %%
y_mean = scalers[1].inverse_transform(y_mean.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean.shape)
# Out:
# torch.Size([3103]) (3103,)

# %%
y_mean = np.clip(y_mean,0,y_mean.max(),out=y_mean)

# %%
idx=3000
mae_arr = (np.array(yt) - y_mean)
# mae_arr = np.abs(np.array(yt) - y_mean)
plt.plot(x_test_timestamp[:idx],mae_arr[:idx])
plt.xlabel("TimeStamp")
plt.ylabel("Raw Error on Test")
# Out:
# Text(0, 0.5, 'Raw Error on Test')

# %%
idx=yt.shape[0]
mae_arr = np.abs(np.array(yt) - y_mean)
plt.plot(x_test_timestamp[:idx],yt[:idx], label = "ref")
plt.plot(x_test_timestamp[:idx],mae_arr[:idx], label="Eror")
plt.xlabel("TimeStamp")
plt.ylabel("Power and Error")
plt.legend()

# %%
sns.kdeplot(mae_arr)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
mae_arr1 = []


for i in range(len(mae_arr)):
  if (mae_arr[i]>300):
    mae_arr1.append(0)
  else:
    mae_arr1.append(mae_arr[i])

np.mean(mae_arr1)

plt.plot(x_test_timestamp[:],mae_arr1[:])
plt.xlabel("TimeStamp")
plt.ylabel("Absolute Error on Test")
# Out:
# Text(0, 0.5, 'Absolute Error on Test')

# %%
mae = np.mean(np.abs(np.array(yt) - y_mean))
rms = errors.rmse(jnp.array(yt), y_mean)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  41.16818862841034
# RMSE:  60.691174

# %%
#MAE:  28.1036

# %%
# x1 = xt[:,49]

# %%
# scalers[0].inverse_transform(x[:,:99]).min()

# %%
x1 = x_test_features[:,0].reshape(-1,1)

# %%
x2 =  x_test_features[:,1].reshape(-1,1)

# %%
# x3 = x_train_features[:,0].reshape(-1,1)
# x4 =  x_train_features[:,1].reshape(-1,1)
# print(x4.min())
# idx = 5000
# plt.figure(figsize=(10,6))
# plt.plot(x_train_timstamp[:idx], scalers[3].inverse_transform(x3)[:idx], label = "Main")
# plt.legend()
# plt.title("Train")

# %%
# idx = 3000
# plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp[:idx], scalers[3].inverse_transform(x1)[:idx], label = "Main")
# plt.plot(x_test_timestamp[:idx], scalers[-1].inverse_transform(x2)[:idx], label = "Main Ref Dif")
# plt.legend()
# plt.title("Test")

# %%
y_mean.min()
# Out:
# 0.0

# %%
y_train1 = scalers[1].inverse_transform(y_train.reshape(-1,1))
print(y_train1.min())
plt.scatter(x_train_timstamp[:idx], y_train1[:idx], label = "Refri")
# Out:
# 4.4086485e-07

# %%
idx = 300#x2.shape[0]
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp[:idx], scalers[3].inverse_transform(x1)[:idx], label = "Main")
# plt.plot(x_test_timestamp[:idx], scalers[-1].inverse_transform(x2)[:idx], label = "Main Ref Dif")
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
plt.title("Building 6")
sns.despine()

# %%
value, count = np.unique(y_mean, return_counts=True)

Z = [x for _,x in sorted(zip(value,count))]

value[2000:2500].max(), count[2000:2500].max()
# Out:
# (142.32068477750337, 1)

# %%
y_mean1 = np.array(y_mean)
for i in range(len(y_mean)):

  if y_mean1[i]>500:
    y_mean1[i] = 200
  if y_mean1[i]<50:
    y_mean1[i] = 0

# %%
index = 3000
start = 2000
plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp[:idx], scalers[3].inverse_transform(x1)[:idx], label = "Main")
# plt.plot(x_test_timestamp[:idx], scalers[-1].inverse_transform(x2)[:idx], label = "Main Ref Dif")
plt.plot(x_test_timestamp[start:start+index], yt.cpu()[start:start+index], label = "Refri")
plt.plot(x_test_timestamp[start:start+index], y_mean1[start:start+index], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
plt.title("Building 6")
sns.despine()

# %%
mae = np.mean(np.abs(np.array(yt) - y_mean1))
rms = errors.rmse(jnp.array(yt), y_mean1)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  39.62071811847866
# RMSE:  61.95651

# %%
# idx = 3000
# plt.figure(figsize=(10,6))
# plt.plot(jnp.arange(idx), scaler_y.inverse_transform(y.cpu().reshape(-1,1))[:idx], label = "Main")
# plt.plot(jnp.arange(idx), yt.cpu()[:idx], label = "Refri")
# plt.plot(jnp.arange(idx), y_mean[:idx], label = "Predicted")
# plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
# plt.xlabel("Indexes")
# plt.ylabel("Fridge Power")
# sns.despine()

# %%
# plt.plot(np.array(test_timestamp_orig)[:300],np.array(yt)[:300])
# plt.plot(np.array(test_timestamp_orig)[:300],np.array(y_mean)[:300])

# %%
# plt.scatter(np.array(test_timestamp_orig)[:3000],np.array(y_mean)[:3000],label="True")
# plt.scatter(np.array(test_timestamp_orig)[:3000],np.array(yt)[:3000],label="Pred")
# plt.legend()
# plt.xlabel("TimeStamp")
# plt.xlabel("Refrogerator Power")

# %%
idx = x_test.shape[0]
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp, y_test[:idx], label = "Refri")
plt.plot(x_test_timestamp, y_mean[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
# savefig("CombinationKernel")
# plt.savefig("./Results/Refrigerator_building5.png", bbox_inches="tight")

# %%
model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
                      inducing_points).to("cuda")

# %%
pred_dist1 = model.predict(torch.tensor(np.array(x_train_full)).to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_mean1 = scaler_y.inverse_transform(y_mean1.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(y_train.shape, y_mean1.shape)

# %%
mae = np.mean(np.abs(np.array(y_train) - y_mean1))
rms = errors.rmse(jnp.array(y_train), y_mean1)

print("MAE: ", mae)
print("RMSE: ", rms)

# %%
idx = x_train.shape[0]
plt.figure(figsize=(10,6))
plt.plot(x_train_timstamp, y_train[:idx], label = "Refri")
plt.plot(x_train_timstamp, y_mean[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
# savefig("CombinationKernel")
# plt.savefig("./Results/Refrigerator_building5.png", bbox_inches="tight")

# %%
#MAE:  39.81858310475401 build 6
#MAE:  30.333733374869247 build 3
#MAE:  37.32115756605644 build 2
#MAE: 43.212248588857065 build 5
#MAE:  48.917852990726765

# %%
# MAE: Building 6 MAE: 35.07
# MAE: Building 3 MAE:  31.565
# MAE: Building 2 MAE: 31.089
# MAE: Building 1 MAE: 37.3657
# MAE: Building 5 MAE:  46.316869

# %%
# MAE: Building 6 MAE: 34.3709125
# MAE: Building 3 MAE: 30.919
# MAE: Building 2 MAE: 30.43776
# MAE: Building 1 MAE: 37.10209
# MAE: Building 5 MAE: 45.02767

# %%
26.442985, 27.0600
