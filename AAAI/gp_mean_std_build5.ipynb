# %%
import os
os.chdir("../")
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %%
import torch
from gpytorch.kernels import RBFKernel, ScaleKernel, PeriodicKernel, MaternKernel, CosineKernel
from skgpytorch.models import SVGPRegressor, SGPRegressor
from scipy.stats import kurtosis,skew

# %%
import jax.numpy as jnp
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from utilities.fits import fit
# from utilities import plot
import tensorflow_probability.substrates.jax as tfp
dist = tfp.distributions
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from gpytorch.constraints import GreaterThan
from skgpytorch.metrics import mean_squared_error, negative_log_predictive_density
import time
import numpy as np

# from datasets.dataset_load import dataset_loader
from utilities import plot,fits,gmm,errors,predict,preprocess

# device = "cpu"
# torch.set_default_dtype(torch.float32)
# torch.set_default_tensor_type(torch.FloatTensor)

# %%
train ={1:{
                    'start_time': "2011-04-21" ,
                    'end_time': "2011-05-21"
                },
                3: {
                    'start_time': "2011-04-19" ,
                    'end_time': "2011-05-22"
                },
               
                
               2: {
                    'start_time': "2011-04-21" ,
                    'end_time': "2011-05-21"
                }
                ,
                6: {
                    'start_time': "2011-05-25" ,
                    'end_time': "2011-06-13"
                }
               
                }
test = { 5: {
                    'start_time': "2011-04-22" ,
                    'end_time': "2011-06-01"
                },}
appliances = ["Refrigerator"]

# %%
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler


def dataset_load(appliances, train, test=None):
    x_train = []
    y_train = []
    x_train_timestamp = []
    x_train_mean = []
    x_train_std = []
    x_train_max_min = []
    x_train_main = []
    x_train_main_dif = []
    x_train_max = []
    x_train_min = []
    x_train_kurtosis = []
    x_train_skew = []
    n = 99
    m = 9
    units_to_pad = n // 2
    units_to_pad1 = m//2
    scaler_x = StandardScaler()
    scaler_y = StandardScaler()
    scaler_time = StandardScaler()
    scaler_mean = StandardScaler()
    scaler_std = StandardScaler()
    scaler_max_min = StandardScaler()
    scaler_main = StandardScaler()
    scaler_diff = StandardScaler()
    scaler_max = StandardScaler()
    scaler_min = StandardScaler()
    scaler_kurtosis = StandardScaler()
    scaler_skew = StandardScaler()
    # train
    for key, values in train.items():
        df = pd.read_csv(
            f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[0]])
        df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
        startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
        endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

        if startDate > endDate:
            raise "Start Date must be smaller than Enddate."

        df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
        df.dropna(inplace=True)
        x = df["main"].values

        # x_diff = x
        # for i in range(1,len(x)):
        #     x_diff[i] = x_diff[i] - x_diff[i-1]

        x_train_main.extend(x)
        y = df[appliances[0]].values
        timestamp_train = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x2 = x
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])
        # print(0)
        x_train_mean.extend(jnp.mean(x, axis=1))
        # print(0)
        x_train_std.extend(jnp.std(x, axis=1))
        x1 = jnp.pad(x2, (units_to_pad1, units_to_pad1),
                    'constant', constant_values=(0, 0))
        x1 = jnp.array([x1[i: i + m] for i in range(len(x1) - m + 1)])
        x_train_max_min.extend(jnp.max(x, axis=1)-jnp.min(x,axis=1))
        x_train_max.extend(jnp.max(x1, axis = 1))
        x_train_min.extend(jnp.min(x1, axis = 1))
        x_train_kurtosis.extend(kurtosis(x,axis=1))
        x_train_skew.extend(skew(x,axis = 1))
        x_train.extend(x)
        y_train.extend(y)
        x_train_timestamp.extend(torch.tensor(timestamp_train))
        # x_train_diff.extend(x_diff)

    # for i in range(1,len(x_train)):
    #     x_train[i] = x_train[i] - x_train[i-1]
    x_train = jnp.array(x_train)
    y_train = jnp.array(y_train).reshape(-1, 1)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(-1,1)
    x_train_main = jnp.array(x_train_main).reshape(-1,1)
    x_train_mean = jnp.array(x_train_mean).reshape(-1,1)
    x_train_std =  jnp.array(x_train_std).reshape(-1,1)
    x_train_max_min =  jnp.array(x_train_max_min).reshape(-1,1)
    x_train_max =  jnp.array(x_train_max).reshape(-1,1)
    x_train_skew = jnp.array(x_train_skew).reshape(-1,1)
    x_train_min =  jnp.array(x_train_min).reshape(-1,1)
    x_train_kurtosis = jnp.array(x_train_kurtosis).reshape(-1,1)
    # x_train_diff =  jnp.array(x_train_diff).reshape(-1,1)
   


    x_train = scaler_x.fit_transform(x_train)
    y_train = scaler_y.fit_transform(y_train)
    x_train_timestamp = scaler_time.fit_transform(x_train_timestamp)
    x_train_main = scaler_main.fit_transform(x_train_main)
    x_train_mean = scaler_mean.fit_transform(x_train_mean)
    x_train_std = scaler_std.fit_transform(x_train_std)
    x_train_max_min = scaler_max_min.fit_transform(x_train_max_min)
    x_train_max = scaler_max.fit_transform(x_train_max)
    x_train_min = scaler_min.fit_transform(x_train_min)
    x_train_kurtosis = scaler_kurtosis.fit_transform(x_train_kurtosis)
    x_train_skew = scaler_skew.fit_transform(x_train_skew)
    # x_train_diff = scaler_diff.fit_transform(x_train_diff)

    # test
    x_test = []
    y_test = []
    x_test_timestamp = []
    x_test_mean = []
    x_test_std = []
    x_test_max_min = []
    x_test_timestamp_true =[]
    x_test_main = []
    x_test_max = []
    x_test_min = []
    x_test_kurtosis = []
    x_test_skew = []

    for key, values in test.items():
        df = pd.read_csv(
            f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[0]])
        df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
        startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
        endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

        if startDate > endDate:
            raise "Start Date must be smaller than Enddate."

        df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
        df.dropna(inplace=True)
        x = df["main"].values 
        # x = x - 100
        # x_diff = x
        # for i in range(1,len(x)):
        #     x_diff[i] = x_diff[i] - x_diff[i-1]
        x_test_main.extend(x)
        y = df[appliances[0]].values

        timestamp_true = df["Timestamp"].values
        timestamp = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x2 = x
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])

        x_test_mean.extend(jnp.mean(x, axis=1))
        x_test_std.extend(jnp.std(x, axis=1))
        x1 = jnp.pad(x2, (units_to_pad1, units_to_pad1),
                    'constant', constant_values=(0, 0))
        x1 = jnp.array([x1[i: i + m] for i in range(len(x1) - m + 1)])
        x_test_max_min.extend(jnp.max(x, axis=1)-jnp.min(x, axis=1))
        x_test_max.extend(jnp.max(x1, axis=1))
        x_test_min.extend(jnp.min(x1, axis=1))
        x_test.extend(x)
        x_test_kurtosis.extend(kurtosis(x,axis=1))
        x_test_skew.extend(skew(x,axis=1))
        y_test.extend(y)
        x_test_timestamp_true.extend(timestamp_true)
        x_test_timestamp.extend(timestamp)
        # x_test_diff.extend(x_diff)

    # for i in range(1,len(x_test)):
    #     x_test[i] = x_test[i] - x_test[i-1]
    x_test = jnp.array(x_test)
    y_test = jnp.array(y_test).reshape(-1, 1)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(-1,1)
    x_test_main = jnp.array(x_test_main).reshape(-1,1)
    x_test_mean = jnp.array(x_test_mean).reshape(-1,1)
    x_test_std =  jnp.array(x_test_std).reshape(-1,1)
    x_test_max_min =  jnp.array(x_test_max_min).reshape(-1,1)
    x_test_max = jnp.array(x_test_max).reshape(-1,1)
    x_test_min = jnp.array(x_test_min).reshape(-1,1)
    x_test_kurtosis = jnp.array(x_test_kurtosis).reshape(-1,1)
    x_test_skew = jnp.array(x_test_skew).reshape(-1,1)

    x_test = scaler_x.transform(x_test)
    x_test_timestamp = scaler_time.transform(x_test_timestamp)
    x_test_mean = scaler_mean.transform(x_test_mean)
    x_test_std = scaler_std.transform(x_test_std)
    x_test_max_min = scaler_max_min.transform(x_test_max_min)
    x_test_main = scaler_main.transform(x_test_main)
    x_test_max =  scaler_max.transform(x_test_max)
    x_test_min = scaler_min.transform(x_test_min)
    x_test_kurtosis = scaler_kurtosis.transform(x_test_kurtosis)
    x_test_skew = scaler_skew.transform(x_test_skew)
    # x_test_diff = scaler_diff.transform(x_test_diff)
#     y_test = scaler_y.transform(y_test)

    # x_train_features = x_train_main_dif
    # x_test_features = x_test_main_dif

    x_train = jnp.array(x_train[:,1:]).reshape(x_train.shape[0], n-1)
    y_train = jnp.array(y_train)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(x_train_timestamp.shape[0], 1)
    x_test = jnp.array(x_test[:,1:]).reshape(x_test.shape[0], n-1)
    y_test = jnp.array(y_test)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(x_test_timestamp.shape[0], 1).to(torch.float64)

    #x_train_std, 
    #, x_test_std, x_test_max_min,
    num_features_selected = 6
    x_train_features = jnp.concatenate(( x_train_main, x_train_mean,  x_train_max_min,x_train_max, x_train_min, x_train_kurtosis), axis=1).reshape(x_train.shape[0], num_features_selected)
    x_test_features = jnp.concatenate((x_test_main, x_test_mean,  x_test_max_min, x_test_max, x_test_min,  x_test_kurtosis), axis=1).reshape(x_test.shape[0], num_features_selected)

    scalers = np.array([scaler_x, scaler_y, scaler_time, scaler_main, scaler_mean, scaler_std, scaler_max_min, scaler_max, scaler_min, scaler_kurtosis, scaler_skew])
    return x_train, y_train, x_test, y_test, x_train_features, x_test_features, x_train_timestamp, x_test_timestamp, scalers, x_test_main

# %%
x_train, y_train, x_test, y_test, x_train_features, x_test_features, x_train_timstamp, x_test_timestamp, scalers, x_test_main = dataset_load(appliances, train, test)

# %%
# x_train_full = jnp.concatenate((x_train_features, jnp.array(np.array(x_train_timstamp))), axis=1)
# x_test_full = jnp.concatenate((x_test_features, jnp.array(np.array(x_test_timestamp))), axis=1)

# %%
# x_train_full = jnp.concatenate((x_train.reshape(-1,n), jnp.array(np.array(x_train_timstamp))), axis=1)
# x_test_full = jnp.concatenate((x_test.reshape(-1,n), jnp.array(np.array(x_test_timestamp))), axis=1)
# x_train_full.shape, x_test_full.shape

# %%
# x_train.reshape(-1,n).shape, x_test.reshape(-1,n).shape, y_train.shape, y_test.shape

# %%
# x = x_train_full[:14000]
# y = y_train[:14000]
# xt = x_train_full[14000:]
# yt = y_train[14000:]

# %%
# x.shape, y.shape

# %%
x_train_diff = x_train_features[:,0]
diff = np.array(x_train_diff)
for i in range(1, len(x_train_diff)):
		value = x_train_diff[i] - x_train_diff[i - 1]
		diff[i] = value

x_test_diff = x_test_features[:,0]
diff = np.array(x_test_diff)
for i in range(1, len(x_test_diff)):
		value = x_test_diff[i] - x_test_diff[i - 1]
		diff[i] = value

# x_train_zeros = np.zeros(x_train_diff.shape)
# x_test_zeros = np.zeros(x_test_diff.shape)

# %%
# x1 = x_train_features[:,0]
# x2 = x_test_features[:,0]
# x_train_thresh = np.array(x1)
# x_test_thresh = np.array(x2)

# for i in range(len(x1)):
#   if x_train_thresh[i]<250:
#     x_train_thresh[i] = 0
#   if x_train_thresh[i]>340:
#     x_train_thresh[i] = 360
  

# for i in range(len(x2)):
#   if x_test_thresh[i]<250:
#     x_test_thresh[i] = 0
#   if x_test_thresh[i]>340:
#     x_test_thresh[i] = 360

# #jnp.array(np.array(x_train_thresh.reshape(-1,1))), jnp.array(np.array(x_test_thresh.reshape(-1,1))),

# %%
# x_train_fft = jnp.array(np.fft.fft(scalers[3].inverse_transform(x_train_features[:,0].reshape(-1,1))))
# x_test_fft = jnp.array(np.fft.fft(scalers[3].inverse_transform(x_test_features[:,0].reshape(-1,1))))

# plt.plot(np.fft.fft(scalers[3].inverse_transform(x_test_features[:,0].reshape(-1,1))))
# len(scalers[3].inverse_transform(x_train_features[:,0].reshape(-1,1)))
# Out:
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# 67134

# %%
x_train_features = jnp.concatenate(( x_train_features, jnp.array(np.array(x_train_diff.reshape(-1,1)))), axis=1)
x_test_features = jnp.concatenate((x_test_features, jnp.array(np.array(x_test_diff.reshape(-1,1)))), axis=1)

# %%
import gpytorch
indexes = 53456
n = 8
x = torch.tensor(np.array(x_train_features)).to(torch.float64)
y = torch.tensor(np.array(y_train)).reshape(-1,).to(torch.float64)
xt = torch.tensor(np.array(x_test_features)).to(torch.float64)
yt = torch.tensor(np.array(y_test)).reshape(-1,).to(torch.float64)

if x.shape[0]>indexes:
  x = x[:indexes]
  y = y[:indexes]

# xt = xt[:16000]
# yt = yt[:16000]
# Out:
# /tmp/ipykernel_1597205/1735454153.py:4: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352645774/work/aten/src/ATen/native/Copy.cpp:250.)
#   x = torch.tensor(np.array(x_train_features)).to(torch.float64)

# %%
x.dtype
# Out:
# torch.float64

# %%
x.shape, y.shape, xt.shape, yt.shape
# Out:
# (torch.Size([53456, 8]),
#  torch.Size([53456]),
#  torch.Size([3103, 8]),
#  torch.Size([3103]))

# %%
mae_arr =[]
rms_arr = []
y_pred_arr = []

batch = 512

# x_train = x_train[:4500]
# y_train = y_train[:4500]

# y_test_trans = torch.tensor(torch.tensor(scaler_x.transform(y_test.reshape(-1,1))).reshape(-1,)).contiguous().to(torch.float64)
for i in range(1):


   #nu=2.5,

  kernel1 = ScaleKernel(MaternKernel(nu=2.5, ard_num_dims=n))
  # kernel2 = ScaleKernel(MaternKernel(nu=0.5,ard_num_dims=1,active_dims=(n-1)))
  # kernel2 = ScaleKernel(RBFKernel(ard_num_dims=1, active_dims=(n)))
  # kernel3 = ScaleKernel(PeriodicKernel(ard_num_dims=1,active_dims=(n-1)))
  # kernel5 = ScaleKernel(gpytorch.kernels.SpectralDeltaKernel(num_dims=n,ard_num_dims=n))
#   theta =  {'base_covar_module.kernels.0.base_kernel.lengthscale': torch.tensor(0.5),
#         'base_covar_module.kernels.0.outputscale': torch.tensor(5.0),
#         'base_covar_module.kernels.1.kernels.0.outputscale':torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.0.base_kernel.lengthscale': torch.tensor(0.1),
#         'base_covar_module.kernels.1.kernels.1.outputscale':torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.1.base_kernel.lengthscale': torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
  theta = { 'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
  # kernel4 = kernel2*kernel3
  kernel = kernel1 #+ kernel4
  # induce_points = 512
  inducing_points =  x[np.arange(0,x.shape[0],95)] 
  # inducing_points = x[torch.randperm(x.shape[0])[: 1500]]
  
  model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                       inducing_points).to("cuda")
  # model.base_covar_module.base_kernel.raw_lengthscale_constraint
  # model.mll.likelihood.noise_covar.register_constraint("raw_noise", GreaterThan(1e-2))
  # for param in model.parameters():
  #   # print(param)
  #   torch.nn.init.normal_(param, 0, 1)
  # theta1 = {'likelihood.noise_covar.noise': torch.tensor(3),
  #       'covar_module.base_kernel.lengthscale': torch.tensor(0.1),
  #       'covar_module.outputscale': torch.tensor(5),}
  model.fit(lr=0.001, n_epochs=2500,verbose=1,
          random_state=0, n_restarts=1)
#   loss_arr.append(loss)
  # print(loss)
  # plt.plot(np.asarray(loss[0]))
  # plt.plot(np.asarray(test_loss[0]))







  # y_pred_arr.append(pred_dist.loc)
# Out:
# restart: 0, epoch: 1, iter: 1, loss: 1.4325
# restart: 0, epoch: 2, iter: 1, loss: 1.4234
# restart: 0, epoch: 3, iter: 1, loss: 1.4147
# restart: 0, epoch: 4, iter: 1, loss: 1.4069
# restart: 0, epoch: 5, iter: 1, loss: 1.3996
# restart: 0, epoch: 6, iter: 1, loss: 1.3926
# restart: 0, epoch: 7, iter: 1, loss: 1.3859
# restart: 0, epoch: 8, iter: 1, loss: 1.3796
# restart: 0, epoch: 9, iter: 1, loss: 1.3736
# restart: 0, epoch: 10, iter: 1, loss: 1.3679
# restart: 0, epoch: 11, iter: 1, loss: 1.3625
# restart: 0, epoch: 12, iter: 1, loss: 1.3573
# restart: 0, epoch: 13, iter: 1, loss: 1.3524
# restart: 0, epoch: 14, iter: 1, loss: 1.3476
# restart: 0, epoch: 15, iter: 1, loss: 1.3431
# restart: 0, epoch: 16, iter: 1, loss: 1.3388
# restart: 0, epoch: 17, iter: 1, loss: 1.3346
# restart: 0, epoch: 18, iter: 1, loss: 1.3306
# restart: 0, epoch: 19, iter: 1, loss: 1.3268
# restart: 0, epoch: 20, iter: 1, loss: 1.3231
# restart: 0, epoch: 21, iter: 1, loss: 1.3195
# restart: 0, epoch: 22, iter: 1, loss: 1.3160
# restart: 0, epoch: 23, iter: 1, loss: 1.3126
# restart: 0, epoch: 24, iter: 1, loss: 1.3093
# restart: 0, epoch: 25, iter: 1, loss: 1.3060
# restart: 0, epoch: 26, iter: 1, loss: 1.3029
# restart: 0, epoch: 27, iter: 1, loss: 1.2998
# restart: 0, epoch: 28, iter: 1, loss: 1.2967
# restart: 0, epoch: 29, iter: 1, loss: 1.2937
# restart: 0, epoch: 30, iter: 1, loss: 1.2907
# restart: 0, epoch: 31, iter: 1, loss: 1.2878
# restart: 0, epoch: 32, iter: 1, loss: 1.2849
# restart: 0, epoch: 33, iter: 1, loss: 1.2820
# restart: 0, epoch: 34, iter: 1, loss: 1.2792
# restart: 0, epoch: 35, iter: 1, loss: 1.2763
# restart: 0, epoch: 36, iter: 1, loss: 1.2735
# restart: 0, epoch: 37, iter: 1, loss: 1.2707
# restart: 0, epoch: 38, iter: 1, loss: 1.2679
# restart: 0, epoch: 39, iter: 1, loss: 1.2651
# restart: 0, epoch: 40, iter: 1, loss: 1.2623
# restart: 0, epoch: 41, iter: 1, loss: 1.2596
# restart: 0, epoch: 42, iter: 1, loss: 1.2568
# restart: 0, epoch: 43, iter: 1, loss: 1.2540
# restart: 0, epoch: 44, iter: 1, loss: 1.2513
# restart: 0, epoch: 45, iter: 1, loss: 1.2485
# restart: 0, epoch: 46, iter: 1, loss: 1.2458
# restart: 0, epoch: 47, iter: 1, loss: 1.2431
# restart: 0, epoch: 48, iter: 1, loss: 1.2403
# restart: 0, epoch: 49, iter: 1, loss: 1.2376
# restart: 0, epoch: 50, iter: 1, loss: 1.2349
# restart: 0, epoch: 51, iter: 1, loss: 1.2322
# restart: 0, epoch: 52, iter: 1, loss: 1.2295
# restart: 0, epoch: 53, iter: 1, loss: 1.2268
# restart: 0, epoch: 54, iter: 1, loss: 1.2241
# restart: 0, epoch: 55, iter: 1, loss: 1.2214
# restart: 0, epoch: 56, iter: 1, loss: 1.2187
# restart: 0, epoch: 57, iter: 1, loss: 1.2160
# restart: 0, epoch: 58, iter: 1, loss: 1.2134
# restart: 0, epoch: 59, iter: 1, loss: 1.2108
# restart: 0, epoch: 60, iter: 1, loss: 1.2081
# restart: 0, epoch: 61, iter: 1, loss: 1.2055
# restart: 0, epoch: 62, iter: 1, loss: 1.2030
# restart: 0, epoch: 63, iter: 1, loss: 1.2004
# restart: 0, epoch: 64, iter: 1, loss: 1.1978
# restart: 0, epoch: 65, iter: 1, loss: 1.1953
# restart: 0, epoch: 66, iter: 1, loss: 1.1927
# restart: 0, epoch: 67, iter: 1, loss: 1.1902
# restart: 0, epoch: 68, iter: 1, loss: 1.1877
# restart: 0, epoch: 69, iter: 1, loss: 1.1852
# restart: 0, epoch: 70, iter: 1, loss: 1.1827
# restart: 0, epoch: 71, iter: 1, loss: 1.1802
# restart: 0, epoch: 72, iter: 1, loss: 1.1778
# restart: 0, epoch: 73, iter: 1, loss: 1.1754
# restart: 0, epoch: 74, iter: 1, loss: 1.1730
# restart: 0, epoch: 75, iter: 1, loss: 1.1706
# restart: 0, epoch: 76, iter: 1, loss: 1.1682
# restart: 0, epoch: 77, iter: 1, loss: 1.1658
# restart: 0, epoch: 78, iter: 1, loss: 1.1635
# restart: 0, epoch: 79, iter: 1, loss: 1.1612
# restart: 0, epoch: 80, iter: 1, loss: 1.1588
# restart: 0, epoch: 81, iter: 1, loss: 1.1566
# restart: 0, epoch: 82, iter: 1, loss: 1.1543
# restart: 0, epoch: 83, iter: 1, loss: 1.1520
# restart: 0, epoch: 84, iter: 1, loss: 1.1498
# restart: 0, epoch: 85, iter: 1, loss: 1.1475
# restart: 0, epoch: 86, iter: 1, loss: 1.1453
# restart: 0, epoch: 87, iter: 1, loss: 1.1431
# restart: 0, epoch: 88, iter: 1, loss: 1.1409
# restart: 0, epoch: 89, iter: 1, loss: 1.1387
# restart: 0, epoch: 90, iter: 1, loss: 1.1366
# restart: 0, epoch: 91, iter: 1, loss: 1.1344
# restart: 0, epoch: 92, iter: 1, loss: 1.1323
# restart: 0, epoch: 93, iter: 1, loss: 1.1302
# restart: 0, epoch: 94, iter: 1, loss: 1.1281
# restart: 0, epoch: 95, iter: 1, loss: 1.1260
# restart: 0, epoch: 96, iter: 1, loss: 1.1239
# restart: 0, epoch: 97, iter: 1, loss: 1.1219
# restart: 0, epoch: 98, iter: 1, loss: 1.1198
# restart: 0, epoch: 99, iter: 1, loss: 1.1178
# restart: 0, epoch: 100, iter: 1, loss: 1.1158
# restart: 0, epoch: 101, iter: 1, loss: 1.1138
# restart: 0, epoch: 102, iter: 1, loss: 1.1118
# restart: 0, epoch: 103, iter: 1, loss: 1.1098
# restart: 0, epoch: 104, iter: 1, loss: 1.1078
# restart: 0, epoch: 105, iter: 1, loss: 1.1059
# restart: 0, epoch: 106, iter: 1, loss: 1.1040
# restart: 0, epoch: 107, iter: 1, loss: 1.1020
# restart: 0, epoch: 108, iter: 1, loss: 1.1001
# restart: 0, epoch: 109, iter: 1, loss: 1.0982
# restart: 0, epoch: 110, iter: 1, loss: 1.0963
# restart: 0, epoch: 111, iter: 1, loss: 1.0945
# restart: 0, epoch: 112, iter: 1, loss: 1.0926
# restart: 0, epoch: 113, iter: 1, loss: 1.0908
# restart: 0, epoch: 114, iter: 1, loss: 1.0889
# restart: 0, epoch: 115, iter: 1, loss: 1.0871
# restart: 0, epoch: 116, iter: 1, loss: 1.0853
# restart: 0, epoch: 117, iter: 1, loss: 1.0835
# restart: 0, epoch: 118, iter: 1, loss: 1.0817
# restart: 0, epoch: 119, iter: 1, loss: 1.0799
# restart: 0, epoch: 120, iter: 1, loss: 1.0782
# restart: 0, epoch: 121, iter: 1, loss: 1.0764
# restart: 0, epoch: 122, iter: 1, loss: 1.0747
# restart: 0, epoch: 123, iter: 1, loss: 1.0729
# restart: 0, epoch: 124, iter: 1, loss: 1.0712
# restart: 0, epoch: 125, iter: 1, loss: 1.0695
# restart: 0, epoch: 126, iter: 1, loss: 1.0678
# restart: 0, epoch: 127, iter: 1, loss: 1.0661
# restart: 0, epoch: 128, iter: 1, loss: 1.0645
# restart: 0, epoch: 129, iter: 1, loss: 1.0628
# restart: 0, epoch: 130, iter: 1, loss: 1.0612
# restart: 0, epoch: 131, iter: 1, loss: 1.0596
# restart: 0, epoch: 132, iter: 1, loss: 1.0580
# restart: 0, epoch: 133, iter: 1, loss: 1.0564
# restart: 0, epoch: 134, iter: 1, loss: 1.0548
# restart: 0, epoch: 135, iter: 1, loss: 1.0532
# restart: 0, epoch: 136, iter: 1, loss: 1.0516
# restart: 0, epoch: 137, iter: 1, loss: 1.0501
# restart: 0, epoch: 138, iter: 1, loss: 1.0486
# restart: 0, epoch: 139, iter: 1, loss: 1.0470
# restart: 0, epoch: 140, iter: 1, loss: 1.0455
# restart: 0, epoch: 141, iter: 1, loss: 1.0440
# restart: 0, epoch: 142, iter: 1, loss: 1.0425
# restart: 0, epoch: 143, iter: 1, loss: 1.0410
# restart: 0, epoch: 144, iter: 1, loss: 1.0395
# restart: 0, epoch: 145, iter: 1, loss: 1.0381
# restart: 0, epoch: 146, iter: 1, loss: 1.0366
# restart: 0, epoch: 147, iter: 1, loss: 1.0352
# restart: 0, epoch: 148, iter: 1, loss: 1.0337
# restart: 0, epoch: 149, iter: 1, loss: 1.0323
# restart: 0, epoch: 150, iter: 1, loss: 1.0309
# restart: 0, epoch: 151, iter: 1, loss: 1.0295
# restart: 0, epoch: 152, iter: 1, loss: 1.0281
# restart: 0, epoch: 153, iter: 1, loss: 1.0267
# restart: 0, epoch: 154, iter: 1, loss: 1.0254
# restart: 0, epoch: 155, iter: 1, loss: 1.0240
# restart: 0, epoch: 156, iter: 1, loss: 1.0227
# restart: 0, epoch: 157, iter: 1, loss: 1.0213
# restart: 0, epoch: 158, iter: 1, loss: 1.0200
# restart: 0, epoch: 159, iter: 1, loss: 1.0187
# restart: 0, epoch: 160, iter: 1, loss: 1.0174
# restart: 0, epoch: 161, iter: 1, loss: 1.0161
# restart: 0, epoch: 162, iter: 1, loss: 1.0148
# restart: 0, epoch: 163, iter: 1, loss: 1.0135
# restart: 0, epoch: 164, iter: 1, loss: 1.0123
# restart: 0, epoch: 165, iter: 1, loss: 1.0110
# restart: 0, epoch: 166, iter: 1, loss: 1.0098
# restart: 0, epoch: 167, iter: 1, loss: 1.0085
# restart: 0, epoch: 168, iter: 1, loss: 1.0073
# restart: 0, epoch: 169, iter: 1, loss: 1.0061
# restart: 0, epoch: 170, iter: 1, loss: 1.0049
# restart: 0, epoch: 171, iter: 1, loss: 1.0037
# restart: 0, epoch: 172, iter: 1, loss: 1.0025
# restart: 0, epoch: 173, iter: 1, loss: 1.0013
# restart: 0, epoch: 174, iter: 1, loss: 1.0001
# restart: 0, epoch: 175, iter: 1, loss: 0.9989
# restart: 0, epoch: 176, iter: 1, loss: 0.9978
# restart: 0, epoch: 177, iter: 1, loss: 0.9966
# restart: 0, epoch: 178, iter: 1, loss: 0.9955
# restart: 0, epoch: 179, iter: 1, loss: 0.9944
# restart: 0, epoch: 180, iter: 1, loss: 0.9932
# restart: 0, epoch: 181, iter: 1, loss: 0.9921
# restart: 0, epoch: 182, iter: 1, loss: 0.9910
# restart: 0, epoch: 183, iter: 1, loss: 0.9899
# restart: 0, epoch: 184, iter: 1, loss: 0.9888
# restart: 0, epoch: 185, iter: 1, loss: 0.9878
# restart: 0, epoch: 186, iter: 1, loss: 0.9867
# restart: 0, epoch: 187, iter: 1, loss: 0.9856
# restart: 0, epoch: 188, iter: 1, loss: 0.9846
# restart: 0, epoch: 189, iter: 1, loss: 0.9835
# restart: 0, epoch: 190, iter: 1, loss: 0.9825
# restart: 0, epoch: 191, iter: 1, loss: 0.9815
# restart: 0, epoch: 192, iter: 1, loss: 0.9805
# restart: 0, epoch: 193, iter: 1, loss: 0.9794
# restart: 0, epoch: 194, iter: 1, loss: 0.9784
# restart: 0, epoch: 195, iter: 1, loss: 0.9774
# restart: 0, epoch: 196, iter: 1, loss: 0.9764
# restart: 0, epoch: 197, iter: 1, loss: 0.9754
# restart: 0, epoch: 198, iter: 1, loss: 0.9745
# restart: 0, epoch: 199, iter: 1, loss: 0.9735
# restart: 0, epoch: 200, iter: 1, loss: 0.9725
# restart: 0, epoch: 201, iter: 1, loss: 0.9716
# restart: 0, epoch: 202, iter: 1, loss: 0.9706
# restart: 0, epoch: 203, iter: 1, loss: 0.9697
# restart: 0, epoch: 204, iter: 1, loss: 0.9687
# restart: 0, epoch: 205, iter: 1, loss: 0.9678
# restart: 0, epoch: 206, iter: 1, loss: 0.9669
# restart: 0, epoch: 207, iter: 1, loss: 0.9660
# restart: 0, epoch: 208, iter: 1, loss: 0.9651
# restart: 0, epoch: 209, iter: 1, loss: 0.9642
# restart: 0, epoch: 210, iter: 1, loss: 0.9633
# restart: 0, epoch: 211, iter: 1, loss: 0.9624
# restart: 0, epoch: 212, iter: 1, loss: 0.9615
# restart: 0, epoch: 213, iter: 1, loss: 0.9606
# restart: 0, epoch: 214, iter: 1, loss: 0.9597
# restart: 0, epoch: 215, iter: 1, loss: 0.9589
# restart: 0, epoch: 216, iter: 1, loss: 0.9580
# restart: 0, epoch: 217, iter: 1, loss: 0.9571
# restart: 0, epoch: 218, iter: 1, loss: 0.9563
# restart: 0, epoch: 219, iter: 1, loss: 0.9554
# restart: 0, epoch: 220, iter: 1, loss: 0.9546
# restart: 0, epoch: 221, iter: 1, loss: 0.9537
# restart: 0, epoch: 222, iter: 1, loss: 0.9529
# restart: 0, epoch: 223, iter: 1, loss: 0.9520
# restart: 0, epoch: 224, iter: 1, loss: 0.9512
# restart: 0, epoch: 225, iter: 1, loss: 0.9504
# restart: 0, epoch: 226, iter: 1, loss: 0.9496
# restart: 0, epoch: 227, iter: 1, loss: 0.9488
# restart: 0, epoch: 228, iter: 1, loss: 0.9480
# restart: 0, epoch: 229, iter: 1, loss: 0.9472
# restart: 0, epoch: 230, iter: 1, loss: 0.9463
# restart: 0, epoch: 231, iter: 1, loss: 0.9456
# restart: 0, epoch: 232, iter: 1, loss: 0.9448
# restart: 0, epoch: 233, iter: 1, loss: 0.9440
# restart: 0, epoch: 234, iter: 1, loss: 0.9432
# restart: 0, epoch: 235, iter: 1, loss: 0.9424
# restart: 0, epoch: 236, iter: 1, loss: 0.9416
# restart: 0, epoch: 237, iter: 1, loss: 0.9409
# restart: 0, epoch: 238, iter: 1, loss: 0.9401
# restart: 0, epoch: 239, iter: 1, loss: 0.9393
# restart: 0, epoch: 240, iter: 1, loss: 0.9386
# restart: 0, epoch: 241, iter: 1, loss: 0.9378
# restart: 0, epoch: 242, iter: 1, loss: 0.9370
# restart: 0, epoch: 243, iter: 1, loss: 0.9363
# restart: 0, epoch: 244, iter: 1, loss: 0.9355
# restart: 0, epoch: 245, iter: 1, loss: 0.9348
# restart: 0, epoch: 246, iter: 1, loss: 0.9340
# restart: 0, epoch: 247, iter: 1, loss: 0.9333
# restart: 0, epoch: 248, iter: 1, loss: 0.9325
# restart: 0, epoch: 249, iter: 1, loss: 0.9318
# restart: 0, epoch: 250, iter: 1, loss: 0.9311
# restart: 0, epoch: 251, iter: 1, loss: 0.9303
# restart: 0, epoch: 252, iter: 1, loss: 0.9296
# restart: 0, epoch: 253, iter: 1, loss: 0.9289
# restart: 0, epoch: 254, iter: 1, loss: 0.9282
# restart: 0, epoch: 255, iter: 1, loss: 0.9275
# restart: 0, epoch: 256, iter: 1, loss: 0.9268
# restart: 0, epoch: 257, iter: 1, loss: 0.9260
# restart: 0, epoch: 258, iter: 1, loss: 0.9253
# restart: 0, epoch: 259, iter: 1, loss: 0.9246
# restart: 0, epoch: 260, iter: 1, loss: 0.9239
# restart: 0, epoch: 261, iter: 1, loss: 0.9233
# restart: 0, epoch: 262, iter: 1, loss: 0.9226
# restart: 0, epoch: 263, iter: 1, loss: 0.9219
# restart: 0, epoch: 264, iter: 1, loss: 0.9212
# restart: 0, epoch: 265, iter: 1, loss: 0.9205
# restart: 0, epoch: 266, iter: 1, loss: 0.9199
# restart: 0, epoch: 267, iter: 1, loss: 0.9192
# restart: 0, epoch: 268, iter: 1, loss: 0.9185
# restart: 0, epoch: 269, iter: 1, loss: 0.9179
# restart: 0, epoch: 270, iter: 1, loss: 0.9172
# restart: 0, epoch: 271, iter: 1, loss: 0.9166
# restart: 0, epoch: 272, iter: 1, loss: 0.9159
# restart: 0, epoch: 273, iter: 1, loss: 0.9153
# restart: 0, epoch: 274, iter: 1, loss: 0.9147
# restart: 0, epoch: 275, iter: 1, loss: 0.9141
# restart: 0, epoch: 276, iter: 1, loss: 0.9134
# restart: 0, epoch: 277, iter: 1, loss: 0.9128
# restart: 0, epoch: 278, iter: 1, loss: 0.9122
# restart: 0, epoch: 279, iter: 1, loss: 0.9116
# restart: 0, epoch: 280, iter: 1, loss: 0.9110
# restart: 0, epoch: 281, iter: 1, loss: 0.9104
# restart: 0, epoch: 282, iter: 1, loss: 0.9098
# restart: 0, epoch: 283, iter: 1, loss: 0.9092
# restart: 0, epoch: 284, iter: 1, loss: 0.9087
# restart: 0, epoch: 285, iter: 1, loss: 0.9081
# restart: 0, epoch: 286, iter: 1, loss: 0.9075
# restart: 0, epoch: 287, iter: 1, loss: 0.9070
# restart: 0, epoch: 288, iter: 1, loss: 0.9064
# restart: 0, epoch: 289, iter: 1, loss: 0.9059
# restart: 0, epoch: 290, iter: 1, loss: 0.9053
# restart: 0, epoch: 291, iter: 1, loss: 0.9048
# restart: 0, epoch: 292, iter: 1, loss: 0.9043
# restart: 0, epoch: 293, iter: 1, loss: 0.9037
# restart: 0, epoch: 294, iter: 1, loss: 0.9032
# restart: 0, epoch: 295, iter: 1, loss: 0.9027
# restart: 0, epoch: 296, iter: 1, loss: 0.9022
# restart: 0, epoch: 297, iter: 1, loss: 0.9017
# restart: 0, epoch: 298, iter: 1, loss: 0.9012
# restart: 0, epoch: 299, iter: 1, loss: 0.9007
# restart: 0, epoch: 300, iter: 1, loss: 0.9002
# restart: 0, epoch: 301, iter: 1, loss: 0.8997
# restart: 0, epoch: 302, iter: 1, loss: 0.8992
# restart: 0, epoch: 303, iter: 1, loss: 0.8988
# restart: 0, epoch: 304, iter: 1, loss: 0.8983
# restart: 0, epoch: 305, iter: 1, loss: 0.8978
# restart: 0, epoch: 306, iter: 1, loss: 0.8974
# restart: 0, epoch: 307, iter: 1, loss: 0.8969
# restart: 0, epoch: 308, iter: 1, loss: 0.8965
# restart: 0, epoch: 309, iter: 1, loss: 0.8960
# restart: 0, epoch: 310, iter: 1, loss: 0.8956
# restart: 0, epoch: 311, iter: 1, loss: 0.8951
# restart: 0, epoch: 312, iter: 1, loss: 0.8947
# restart: 0, epoch: 313, iter: 1, loss: 0.8943
# restart: 0, epoch: 314, iter: 1, loss: 0.8939
# restart: 0, epoch: 315, iter: 1, loss: 0.8934
# restart: 0, epoch: 316, iter: 1, loss: 0.8930
# restart: 0, epoch: 317, iter: 1, loss: 0.8926
# restart: 0, epoch: 318, iter: 1, loss: 0.8922
# restart: 0, epoch: 319, iter: 1, loss: 0.8918
# restart: 0, epoch: 320, iter: 1, loss: 0.8914
# restart: 0, epoch: 321, iter: 1, loss: 0.8910
# restart: 0, epoch: 322, iter: 1, loss: 0.8906
# restart: 0, epoch: 323, iter: 1, loss: 0.8902
# restart: 0, epoch: 324, iter: 1, loss: 0.8898
# restart: 0, epoch: 325, iter: 1, loss: 0.8895
# restart: 0, epoch: 326, iter: 1, loss: 0.8891
# restart: 0, epoch: 327, iter: 1, loss: 0.8887
# restart: 0, epoch: 328, iter: 1, loss: 0.8883
# restart: 0, epoch: 329, iter: 1, loss: 0.8880
# restart: 0, epoch: 330, iter: 1, loss: 0.8876
# restart: 0, epoch: 331, iter: 1, loss: 0.8872
# restart: 0, epoch: 332, iter: 1, loss: 0.8869
# restart: 0, epoch: 333, iter: 1, loss: 0.8865
# restart: 0, epoch: 334, iter: 1, loss: 0.8862
# restart: 0, epoch: 335, iter: 1, loss: 0.8858
# restart: 0, epoch: 336, iter: 1, loss: 0.8855
# restart: 0, epoch: 337, iter: 1, loss: 0.8851
# restart: 0, epoch: 338, iter: 1, loss: 0.8848
# restart: 0, epoch: 339, iter: 1, loss: 0.8844
# restart: 0, epoch: 340, iter: 1, loss: 0.8841
# restart: 0, epoch: 341, iter: 1, loss: 0.8838
# restart: 0, epoch: 342, iter: 1, loss: 0.8834
# restart: 0, epoch: 343, iter: 1, loss: 0.8831
# restart: 0, epoch: 344, iter: 1, loss: 0.8828
# restart: 0, epoch: 345, iter: 1, loss: 0.8824
# restart: 0, epoch: 346, iter: 1, loss: 0.8821
# restart: 0, epoch: 347, iter: 1, loss: 0.8818
# restart: 0, epoch: 348, iter: 1, loss: 0.8815
# restart: 0, epoch: 349, iter: 1, loss: 0.8812
# restart: 0, epoch: 350, iter: 1, loss: 0.8808
# restart: 0, epoch: 351, iter: 1, loss: 0.8805
# restart: 0, epoch: 352, iter: 1, loss: 0.8802
# restart: 0, epoch: 353, iter: 1, loss: 0.8799
# restart: 0, epoch: 354, iter: 1, loss: 0.8796
# restart: 0, epoch: 355, iter: 1, loss: 0.8793
# restart: 0, epoch: 356, iter: 1, loss: 0.8790
# restart: 0, epoch: 357, iter: 1, loss: 0.8787
# restart: 0, epoch: 358, iter: 1, loss: 0.8784
# restart: 0, epoch: 359, iter: 1, loss: 0.8781
# restart: 0, epoch: 360, iter: 1, loss: 0.8778
# restart: 0, epoch: 361, iter: 1, loss: 0.8776
# restart: 0, epoch: 362, iter: 1, loss: 0.8773
# restart: 0, epoch: 363, iter: 1, loss: 0.8770
# restart: 0, epoch: 364, iter: 1, loss: 0.8767
# restart: 0, epoch: 365, iter: 1, loss: 0.8764
# restart: 0, epoch: 366, iter: 1, loss: 0.8762
# restart: 0, epoch: 367, iter: 1, loss: 0.8759
# restart: 0, epoch: 368, iter: 1, loss: 0.8756
# restart: 0, epoch: 369, iter: 1, loss: 0.8753
# restart: 0, epoch: 370, iter: 1, loss: 0.8751
# restart: 0, epoch: 371, iter: 1, loss: 0.8748
# restart: 0, epoch: 372, iter: 1, loss: 0.8746
# restart: 0, epoch: 373, iter: 1, loss: 0.8743
# restart: 0, epoch: 374, iter: 1, loss: 0.8740
# restart: 0, epoch: 375, iter: 1, loss: 0.8738
# restart: 0, epoch: 376, iter: 1, loss: 0.8735
# restart: 0, epoch: 377, iter: 1, loss: 0.8733
# restart: 0, epoch: 378, iter: 1, loss: 0.8730
# restart: 0, epoch: 379, iter: 1, loss: 0.8728
# restart: 0, epoch: 380, iter: 1, loss: 0.8725
# restart: 0, epoch: 381, iter: 1, loss: 0.8723
# restart: 0, epoch: 382, iter: 1, loss: 0.8720
# restart: 0, epoch: 383, iter: 1, loss: 0.8718
# restart: 0, epoch: 384, iter: 1, loss: 0.8716
# restart: 0, epoch: 385, iter: 1, loss: 0.8713
# restart: 0, epoch: 386, iter: 1, loss: 0.8711
# restart: 0, epoch: 387, iter: 1, loss: 0.8708
# restart: 0, epoch: 388, iter: 1, loss: 0.8706
# restart: 0, epoch: 389, iter: 1, loss: 0.8704
# restart: 0, epoch: 390, iter: 1, loss: 0.8702
# restart: 0, epoch: 391, iter: 1, loss: 0.8699
# restart: 0, epoch: 392, iter: 1, loss: 0.8697
# restart: 0, epoch: 393, iter: 1, loss: 0.8695
# restart: 0, epoch: 394, iter: 1, loss: 0.8693
# restart: 0, epoch: 395, iter: 1, loss: 0.8690
# restart: 0, epoch: 396, iter: 1, loss: 0.8688
# restart: 0, epoch: 397, iter: 1, loss: 0.8686
# restart: 0, epoch: 398, iter: 1, loss: 0.8684
# restart: 0, epoch: 399, iter: 1, loss: 0.8682
# restart: 0, epoch: 400, iter: 1, loss: 0.8679
# restart: 0, epoch: 401, iter: 1, loss: 0.8677
# restart: 0, epoch: 402, iter: 1, loss: 0.8675
# restart: 0, epoch: 403, iter: 1, loss: 0.8673
# restart: 0, epoch: 404, iter: 1, loss: 0.8671
# restart: 0, epoch: 405, iter: 1, loss: 0.8669
# restart: 0, epoch: 406, iter: 1, loss: 0.8667
# restart: 0, epoch: 407, iter: 1, loss: 0.8665
# restart: 0, epoch: 408, iter: 1, loss: 0.8663
# restart: 0, epoch: 409, iter: 1, loss: 0.8661
# restart: 0, epoch: 410, iter: 1, loss: 0.8659
# restart: 0, epoch: 411, iter: 1, loss: 0.8657
# restart: 0, epoch: 412, iter: 1, loss: 0.8655
# restart: 0, epoch: 413, iter: 1, loss: 0.8653
# restart: 0, epoch: 414, iter: 1, loss: 0.8651
# restart: 0, epoch: 415, iter: 1, loss: 0.8649
# restart: 0, epoch: 416, iter: 1, loss: 0.8647
# restart: 0, epoch: 417, iter: 1, loss: 0.8645
# restart: 0, epoch: 418, iter: 1, loss: 0.8643
# restart: 0, epoch: 419, iter: 1, loss: 0.8641
# restart: 0, epoch: 420, iter: 1, loss: 0.8639
# restart: 0, epoch: 421, iter: 1, loss: 0.8637
# restart: 0, epoch: 422, iter: 1, loss: 0.8635
# restart: 0, epoch: 423, iter: 1, loss: 0.8633
# restart: 0, epoch: 424, iter: 1, loss: 0.8632
# restart: 0, epoch: 425, iter: 1, loss: 0.8630
# restart: 0, epoch: 426, iter: 1, loss: 0.8628
# restart: 0, epoch: 427, iter: 1, loss: 0.8626
# restart: 0, epoch: 428, iter: 1, loss: 0.8624
# restart: 0, epoch: 429, iter: 1, loss: 0.8622
# restart: 0, epoch: 430, iter: 1, loss: 0.8621
# restart: 0, epoch: 431, iter: 1, loss: 0.8619
# restart: 0, epoch: 432, iter: 1, loss: 0.8617
# restart: 0, epoch: 433, iter: 1, loss: 0.8615
# restart: 0, epoch: 434, iter: 1, loss: 0.8614
# restart: 0, epoch: 435, iter: 1, loss: 0.8612
# restart: 0, epoch: 436, iter: 1, loss: 0.8610
# restart: 0, epoch: 437, iter: 1, loss: 0.8608
# restart: 0, epoch: 438, iter: 1, loss: 0.8607
# restart: 0, epoch: 439, iter: 1, loss: 0.8605
# restart: 0, epoch: 440, iter: 1, loss: 0.8603
# restart: 0, epoch: 441, iter: 1, loss: 0.8601
# restart: 0, epoch: 442, iter: 1, loss: 0.8600
# restart: 0, epoch: 443, iter: 1, loss: 0.8598
# restart: 0, epoch: 444, iter: 1, loss: 0.8596
# restart: 0, epoch: 445, iter: 1, loss: 0.8595
# restart: 0, epoch: 446, iter: 1, loss: 0.8593
# restart: 0, epoch: 447, iter: 1, loss: 0.8592
# restart: 0, epoch: 448, iter: 1, loss: 0.8590
# restart: 0, epoch: 449, iter: 1, loss: 0.8588
# restart: 0, epoch: 450, iter: 1, loss: 0.8587
# restart: 0, epoch: 451, iter: 1, loss: 0.8585
# restart: 0, epoch: 452, iter: 1, loss: 0.8584
# restart: 0, epoch: 453, iter: 1, loss: 0.8582
# restart: 0, epoch: 454, iter: 1, loss: 0.8580
# restart: 0, epoch: 455, iter: 1, loss: 0.8579
# restart: 0, epoch: 456, iter: 1, loss: 0.8577
# restart: 0, epoch: 457, iter: 1, loss: 0.8576
# restart: 0, epoch: 458, iter: 1, loss: 0.8574
# restart: 0, epoch: 459, iter: 1, loss: 0.8573
# restart: 0, epoch: 460, iter: 1, loss: 0.8571
# restart: 0, epoch: 461, iter: 1, loss: 0.8570
# restart: 0, epoch: 462, iter: 1, loss: 0.8568
# restart: 0, epoch: 463, iter: 1, loss: 0.8567
# restart: 0, epoch: 464, iter: 1, loss: 0.8565
# restart: 0, epoch: 465, iter: 1, loss: 0.8564
# restart: 0, epoch: 466, iter: 1, loss: 0.8562
# restart: 0, epoch: 467, iter: 1, loss: 0.8561
# restart: 0, epoch: 468, iter: 1, loss: 0.8559
# restart: 0, epoch: 469, iter: 1, loss: 0.8558
# restart: 0, epoch: 470, iter: 1, loss: 0.8556
# restart: 0, epoch: 471, iter: 1, loss: 0.8555
# restart: 0, epoch: 472, iter: 1, loss: 0.8553
# restart: 0, epoch: 473, iter: 1, loss: 0.8552
# restart: 0, epoch: 474, iter: 1, loss: 0.8550
# restart: 0, epoch: 475, iter: 1, loss: 0.8549
# restart: 0, epoch: 476, iter: 1, loss: 0.8547
# restart: 0, epoch: 477, iter: 1, loss: 0.8546
# restart: 0, epoch: 478, iter: 1, loss: 0.8545
# restart: 0, epoch: 479, iter: 1, loss: 0.8543
# restart: 0, epoch: 480, iter: 1, loss: 0.8542
# restart: 0, epoch: 481, iter: 1, loss: 0.8540
# restart: 0, epoch: 482, iter: 1, loss: 0.8539
# restart: 0, epoch: 483, iter: 1, loss: 0.8537
# restart: 0, epoch: 484, iter: 1, loss: 0.8536
# restart: 0, epoch: 485, iter: 1, loss: 0.8534
# restart: 0, epoch: 486, iter: 1, loss: 0.8533
# restart: 0, epoch: 487, iter: 1, loss: 0.8532
# restart: 0, epoch: 488, iter: 1, loss: 0.8530
# restart: 0, epoch: 489, iter: 1, loss: 0.8529
# restart: 0, epoch: 490, iter: 1, loss: 0.8527
# restart: 0, epoch: 491, iter: 1, loss: 0.8526
# restart: 0, epoch: 492, iter: 1, loss: 0.8525
# restart: 0, epoch: 493, iter: 1, loss: 0.8523
# restart: 0, epoch: 494, iter: 1, loss: 0.8522
# restart: 0, epoch: 495, iter: 1, loss: 0.8520
# restart: 0, epoch: 496, iter: 1, loss: 0.8519
# restart: 0, epoch: 497, iter: 1, loss: 0.8518
# restart: 0, epoch: 498, iter: 1, loss: 0.8516
# restart: 0, epoch: 499, iter: 1, loss: 0.8515
# restart: 0, epoch: 500, iter: 1, loss: 0.8514
# restart: 0, epoch: 501, iter: 1, loss: 0.8512
# restart: 0, epoch: 502, iter: 1, loss: 0.8511
# restart: 0, epoch: 503, iter: 1, loss: 0.8510
# restart: 0, epoch: 504, iter: 1, loss: 0.8508
# restart: 0, epoch: 505, iter: 1, loss: 0.8507
# restart: 0, epoch: 506, iter: 1, loss: 0.8506
# restart: 0, epoch: 507, iter: 1, loss: 0.8504
# restart: 0, epoch: 508, iter: 1, loss: 0.8503
# restart: 0, epoch: 509, iter: 1, loss: 0.8502
# restart: 0, epoch: 510, iter: 1, loss: 0.8500
# restart: 0, epoch: 511, iter: 1, loss: 0.8499
# restart: 0, epoch: 512, iter: 1, loss: 0.8498
# restart: 0, epoch: 513, iter: 1, loss: 0.8496
# restart: 0, epoch: 514, iter: 1, loss: 0.8495
# restart: 0, epoch: 515, iter: 1, loss: 0.8494
# restart: 0, epoch: 516, iter: 1, loss: 0.8493
# restart: 0, epoch: 517, iter: 1, loss: 0.8491
# restart: 0, epoch: 518, iter: 1, loss: 0.8490
# restart: 0, epoch: 519, iter: 1, loss: 0.8489
# restart: 0, epoch: 520, iter: 1, loss: 0.8488
# restart: 0, epoch: 521, iter: 1, loss: 0.8486
# restart: 0, epoch: 522, iter: 1, loss: 0.8485
# restart: 0, epoch: 523, iter: 1, loss: 0.8484
# restart: 0, epoch: 524, iter: 1, loss: 0.8483
# restart: 0, epoch: 525, iter: 1, loss: 0.8482
# restart: 0, epoch: 526, iter: 1, loss: 0.8480
# restart: 0, epoch: 527, iter: 1, loss: 0.8479
# restart: 0, epoch: 528, iter: 1, loss: 0.8478
# restart: 0, epoch: 529, iter: 1, loss: 0.8477
# restart: 0, epoch: 530, iter: 1, loss: 0.8476
# restart: 0, epoch: 531, iter: 1, loss: 0.8474
# restart: 0, epoch: 532, iter: 1, loss: 0.8473
# restart: 0, epoch: 533, iter: 1, loss: 0.8472
# restart: 0, epoch: 534, iter: 1, loss: 0.8471
# restart: 0, epoch: 535, iter: 1, loss: 0.8470
# restart: 0, epoch: 536, iter: 1, loss: 0.8468
# restart: 0, epoch: 537, iter: 1, loss: 0.8467
# restart: 0, epoch: 538, iter: 1, loss: 0.8466
# restart: 0, epoch: 539, iter: 1, loss: 0.8465
# restart: 0, epoch: 540, iter: 1, loss: 0.8464
# restart: 0, epoch: 541, iter: 1, loss: 0.8463
# restart: 0, epoch: 542, iter: 1, loss: 0.8462
# restart: 0, epoch: 543, iter: 1, loss: 0.8460
# restart: 0, epoch: 544, iter: 1, loss: 0.8459
# restart: 0, epoch: 545, iter: 1, loss: 0.8458
# restart: 0, epoch: 546, iter: 1, loss: 0.8457
# restart: 0, epoch: 547, iter: 1, loss: 0.8456
# restart: 0, epoch: 548, iter: 1, loss: 0.8455
# restart: 0, epoch: 549, iter: 1, loss: 0.8454
# restart: 0, epoch: 550, iter: 1, loss: 0.8453
# restart: 0, epoch: 551, iter: 1, loss: 0.8452
# restart: 0, epoch: 552, iter: 1, loss: 0.8451
# restart: 0, epoch: 553, iter: 1, loss: 0.8449
# restart: 0, epoch: 554, iter: 1, loss: 0.8448
# restart: 0, epoch: 555, iter: 1, loss: 0.8447
# restart: 0, epoch: 556, iter: 1, loss: 0.8446
# restart: 0, epoch: 557, iter: 1, loss: 0.8445
# restart: 0, epoch: 558, iter: 1, loss: 0.8444
# restart: 0, epoch: 559, iter: 1, loss: 0.8443
# restart: 0, epoch: 560, iter: 1, loss: 0.8442
# restart: 0, epoch: 561, iter: 1, loss: 0.8441
# restart: 0, epoch: 562, iter: 1, loss: 0.8440
# restart: 0, epoch: 563, iter: 1, loss: 0.8439
# restart: 0, epoch: 564, iter: 1, loss: 0.8438
# restart: 0, epoch: 565, iter: 1, loss: 0.8437
# restart: 0, epoch: 566, iter: 1, loss: 0.8436
# restart: 0, epoch: 567, iter: 1, loss: 0.8435
# restart: 0, epoch: 568, iter: 1, loss: 0.8434
# restart: 0, epoch: 569, iter: 1, loss: 0.8433
# restart: 0, epoch: 570, iter: 1, loss: 0.8432
# restart: 0, epoch: 571, iter: 1, loss: 0.8431
# restart: 0, epoch: 572, iter: 1, loss: 0.8430
# restart: 0, epoch: 573, iter: 1, loss: 0.8429
# restart: 0, epoch: 574, iter: 1, loss: 0.8428
# restart: 0, epoch: 575, iter: 1, loss: 0.8427
# restart: 0, epoch: 576, iter: 1, loss: 0.8426
# restart: 0, epoch: 577, iter: 1, loss: 0.8425
# restart: 0, epoch: 578, iter: 1, loss: 0.8424
# restart: 0, epoch: 579, iter: 1, loss: 0.8423
# restart: 0, epoch: 580, iter: 1, loss: 0.8422
# restart: 0, epoch: 581, iter: 1, loss: 0.8421
# restart: 0, epoch: 582, iter: 1, loss: 0.8420
# restart: 0, epoch: 583, iter: 1, loss: 0.8419
# restart: 0, epoch: 584, iter: 1, loss: 0.8418
# restart: 0, epoch: 585, iter: 1, loss: 0.8417
# restart: 0, epoch: 586, iter: 1, loss: 0.8416
# restart: 0, epoch: 587, iter: 1, loss: 0.8416
# restart: 0, epoch: 588, iter: 1, loss: 0.8415
# restart: 0, epoch: 589, iter: 1, loss: 0.8414
# restart: 0, epoch: 590, iter: 1, loss: 0.8413
# restart: 0, epoch: 591, iter: 1, loss: 0.8412
# restart: 0, epoch: 592, iter: 1, loss: 0.8410
# restart: 0, epoch: 593, iter: 1, loss: 0.8409
# restart: 0, epoch: 594, iter: 1, loss: 0.8408
# restart: 0, epoch: 595, iter: 1, loss: 0.8407
# restart: 0, epoch: 596, iter: 1, loss: 0.8406
# restart: 0, epoch: 597, iter: 1, loss: 0.8405
# restart: 0, epoch: 598, iter: 1, loss: 0.8404
# restart: 0, epoch: 599, iter: 1, loss: 0.8403
# restart: 0, epoch: 600, iter: 1, loss: 0.8402
# restart: 0, epoch: 601, iter: 1, loss: 0.8402
# restart: 0, epoch: 602, iter: 1, loss: 0.8401
# restart: 0, epoch: 603, iter: 1, loss: 0.8400
# restart: 0, epoch: 604, iter: 1, loss: 0.8399
# restart: 0, epoch: 605, iter: 1, loss: 0.8398
# restart: 0, epoch: 606, iter: 1, loss: 0.8397
# restart: 0, epoch: 607, iter: 1, loss: 0.8396
# restart: 0, epoch: 608, iter: 1, loss: 0.8395
# restart: 0, epoch: 609, iter: 1, loss: 0.8394
# restart: 0, epoch: 610, iter: 1, loss: 0.8393
# restart: 0, epoch: 611, iter: 1, loss: 0.8392
# restart: 0, epoch: 612, iter: 1, loss: 0.8391
# restart: 0, epoch: 613, iter: 1, loss: 0.8390
# restart: 0, epoch: 614, iter: 1, loss: 0.8389
# restart: 0, epoch: 615, iter: 1, loss: 0.8388
# restart: 0, epoch: 616, iter: 1, loss: 0.8387
# restart: 0, epoch: 617, iter: 1, loss: 0.8387
# restart: 0, epoch: 618, iter: 1, loss: 0.8386
# restart: 0, epoch: 619, iter: 1, loss: 0.8385
# restart: 0, epoch: 620, iter: 1, loss: 0.8384
# restart: 0, epoch: 621, iter: 1, loss: 0.8383
# restart: 0, epoch: 622, iter: 1, loss: 0.8382
# restart: 0, epoch: 623, iter: 1, loss: 0.8381
# restart: 0, epoch: 624, iter: 1, loss: 0.8380
# restart: 0, epoch: 625, iter: 1, loss: 0.8379
# restart: 0, epoch: 626, iter: 1, loss: 0.8379
# restart: 0, epoch: 627, iter: 1, loss: 0.8378
# restart: 0, epoch: 628, iter: 1, loss: 0.8377
# restart: 0, epoch: 629, iter: 1, loss: 0.8376
# restart: 0, epoch: 630, iter: 1, loss: 0.8375
# restart: 0, epoch: 631, iter: 1, loss: 0.8374
# restart: 0, epoch: 632, iter: 1, loss: 0.8373
# restart: 0, epoch: 633, iter: 1, loss: 0.8373
# restart: 0, epoch: 634, iter: 1, loss: 0.8372
# restart: 0, epoch: 635, iter: 1, loss: 0.8371
# restart: 0, epoch: 636, iter: 1, loss: 0.8370
# restart: 0, epoch: 637, iter: 1, loss: 0.8369
# restart: 0, epoch: 638, iter: 1, loss: 0.8368
# restart: 0, epoch: 639, iter: 1, loss: 0.8368
# restart: 0, epoch: 640, iter: 1, loss: 0.8367
# restart: 0, epoch: 641, iter: 1, loss: 0.8366
# restart: 0, epoch: 642, iter: 1, loss: 0.8365
# restart: 0, epoch: 643, iter: 1, loss: 0.8364
# restart: 0, epoch: 644, iter: 1, loss: 0.8364
# restart: 0, epoch: 645, iter: 1, loss: 0.8363
# restart: 0, epoch: 646, iter: 1, loss: 0.8362
# restart: 0, epoch: 647, iter: 1, loss: 0.8361
# restart: 0, epoch: 648, iter: 1, loss: 0.8360
# restart: 0, epoch: 649, iter: 1, loss: 0.8360
# restart: 0, epoch: 650, iter: 1, loss: 0.8359
# restart: 0, epoch: 651, iter: 1, loss: 0.8358
# restart: 0, epoch: 652, iter: 1, loss: 0.8357
# restart: 0, epoch: 653, iter: 1, loss: 0.8356
# restart: 0, epoch: 654, iter: 1, loss: 0.8356
# restart: 0, epoch: 655, iter: 1, loss: 0.8355
# restart: 0, epoch: 656, iter: 1, loss: 0.8354
# restart: 0, epoch: 657, iter: 1, loss: 0.8353
# restart: 0, epoch: 658, iter: 1, loss: 0.8352
# restart: 0, epoch: 659, iter: 1, loss: 0.8352
# restart: 0, epoch: 660, iter: 1, loss: 0.8351
# restart: 0, epoch: 661, iter: 1, loss: 0.8350
# restart: 0, epoch: 662, iter: 1, loss: 0.8349
# restart: 0, epoch: 663, iter: 1, loss: 0.8349
# restart: 0, epoch: 664, iter: 1, loss: 0.8348
# restart: 0, epoch: 665, iter: 1, loss: 0.8347
# restart: 0, epoch: 666, iter: 1, loss: 0.8346
# restart: 0, epoch: 667, iter: 1, loss: 0.8345
# restart: 0, epoch: 668, iter: 1, loss: 0.8345
# restart: 0, epoch: 669, iter: 1, loss: 0.8344
# restart: 0, epoch: 670, iter: 1, loss: 0.8343
# restart: 0, epoch: 671, iter: 1, loss: 0.8342
# restart: 0, epoch: 672, iter: 1, loss: 0.8342
# restart: 0, epoch: 673, iter: 1, loss: 0.8341
# restart: 0, epoch: 674, iter: 1, loss: 0.8340
# restart: 0, epoch: 675, iter: 1, loss: 0.8339
# restart: 0, epoch: 676, iter: 1, loss: 0.8339
# restart: 0, epoch: 677, iter: 1, loss: 0.8338
# restart: 0, epoch: 678, iter: 1, loss: 0.8337
# restart: 0, epoch: 679, iter: 1, loss: 0.8336
# restart: 0, epoch: 680, iter: 1, loss: 0.8336
# restart: 0, epoch: 681, iter: 1, loss: 0.8335
# restart: 0, epoch: 682, iter: 1, loss: 0.8334
# restart: 0, epoch: 683, iter: 1, loss: 0.8333
# restart: 0, epoch: 684, iter: 1, loss: 0.8333
# restart: 0, epoch: 685, iter: 1, loss: 0.8332
# restart: 0, epoch: 686, iter: 1, loss: 0.8331
# restart: 0, epoch: 687, iter: 1, loss: 0.8330
# restart: 0, epoch: 688, iter: 1, loss: 0.8330
# restart: 0, epoch: 689, iter: 1, loss: 0.8329
# restart: 0, epoch: 690, iter: 1, loss: 0.8328
# restart: 0, epoch: 691, iter: 1, loss: 0.8328
# restart: 0, epoch: 692, iter: 1, loss: 0.8327
# restart: 0, epoch: 693, iter: 1, loss: 0.8326
# restart: 0, epoch: 694, iter: 1, loss: 0.8325
# restart: 0, epoch: 695, iter: 1, loss: 0.8325
# restart: 0, epoch: 696, iter: 1, loss: 0.8324
# restart: 0, epoch: 697, iter: 1, loss: 0.8323
# restart: 0, epoch: 698, iter: 1, loss: 0.8322
# restart: 0, epoch: 699, iter: 1, loss: 0.8322
# restart: 0, epoch: 700, iter: 1, loss: 0.8321
# restart: 0, epoch: 701, iter: 1, loss: 0.8320
# restart: 0, epoch: 702, iter: 1, loss: 0.8320
# restart: 0, epoch: 703, iter: 1, loss: 0.8319
# restart: 0, epoch: 704, iter: 1, loss: 0.8318
# restart: 0, epoch: 705, iter: 1, loss: 0.8317
# restart: 0, epoch: 706, iter: 1, loss: 0.8317
# restart: 0, epoch: 707, iter: 1, loss: 0.8316
# restart: 0, epoch: 708, iter: 1, loss: 0.8315
# restart: 0, epoch: 709, iter: 1, loss: 0.8315
# restart: 0, epoch: 710, iter: 1, loss: 0.8314
# restart: 0, epoch: 711, iter: 1, loss: 0.8313
# restart: 0, epoch: 712, iter: 1, loss: 0.8313
# restart: 0, epoch: 713, iter: 1, loss: 0.8312
# restart: 0, epoch: 714, iter: 1, loss: 0.8311
# restart: 0, epoch: 715, iter: 1, loss: 0.8310
# restart: 0, epoch: 716, iter: 1, loss: 0.8310
# restart: 0, epoch: 717, iter: 1, loss: 0.8309
# restart: 0, epoch: 718, iter: 1, loss: 0.8308
# restart: 0, epoch: 719, iter: 1, loss: 0.8308
# restart: 0, epoch: 720, iter: 1, loss: 0.8307
# restart: 0, epoch: 721, iter: 1, loss: 0.8306
# restart: 0, epoch: 722, iter: 1, loss: 0.8306
# restart: 0, epoch: 723, iter: 1, loss: 0.8305
# restart: 0, epoch: 724, iter: 1, loss: 0.8304
# restart: 0, epoch: 725, iter: 1, loss: 0.8304
# restart: 0, epoch: 726, iter: 1, loss: 0.8303
# restart: 0, epoch: 727, iter: 1, loss: 0.8302
# restart: 0, epoch: 728, iter: 1, loss: 0.8302
# restart: 0, epoch: 729, iter: 1, loss: 0.8301
# restart: 0, epoch: 730, iter: 1, loss: 0.8300
# restart: 0, epoch: 731, iter: 1, loss: 0.8300
# restart: 0, epoch: 732, iter: 1, loss: 0.8299
# restart: 0, epoch: 733, iter: 1, loss: 0.8298
# restart: 0, epoch: 734, iter: 1, loss: 0.8298
# restart: 0, epoch: 735, iter: 1, loss: 0.8297
# restart: 0, epoch: 736, iter: 1, loss: 0.8296
# restart: 0, epoch: 737, iter: 1, loss: 0.8295
# restart: 0, epoch: 738, iter: 1, loss: 0.8295
# restart: 0, epoch: 739, iter: 1, loss: 0.8294
# restart: 0, epoch: 740, iter: 1, loss: 0.8293
# restart: 0, epoch: 741, iter: 1, loss: 0.8292
# restart: 0, epoch: 742, iter: 1, loss: 0.8292
# restart: 0, epoch: 743, iter: 1, loss: 0.8291
# restart: 0, epoch: 744, iter: 1, loss: 0.8290
# restart: 0, epoch: 745, iter: 1, loss: 0.8289
# restart: 0, epoch: 746, iter: 1, loss: 0.8289
# restart: 0, epoch: 747, iter: 1, loss: 0.8288
# restart: 0, epoch: 748, iter: 1, loss: 0.8287
# restart: 0, epoch: 749, iter: 1, loss: 0.8287
# restart: 0, epoch: 750, iter: 1, loss: 0.8286
# restart: 0, epoch: 751, iter: 1, loss: 0.8285
# restart: 0, epoch: 752, iter: 1, loss: 0.8284
# restart: 0, epoch: 753, iter: 1, loss: 0.8284
# restart: 0, epoch: 754, iter: 1, loss: 0.8283
# restart: 0, epoch: 755, iter: 1, loss: 0.8282
# restart: 0, epoch: 756, iter: 1, loss: 0.8282
# restart: 0, epoch: 757, iter: 1, loss: 0.8281
# restart: 0, epoch: 758, iter: 1, loss: 0.8280
# restart: 0, epoch: 759, iter: 1, loss: 0.8280
# restart: 0, epoch: 760, iter: 1, loss: 0.8279
# restart: 0, epoch: 761, iter: 1, loss: 0.8278
# restart: 0, epoch: 762, iter: 1, loss: 0.8278
# restart: 0, epoch: 763, iter: 1, loss: 0.8277
# restart: 0, epoch: 764, iter: 1, loss: 0.8276
# restart: 0, epoch: 765, iter: 1, loss: 0.8276
# restart: 0, epoch: 766, iter: 1, loss: 0.8275
# restart: 0, epoch: 767, iter: 1, loss: 0.8274
# restart: 0, epoch: 768, iter: 1, loss: 0.8274
# restart: 0, epoch: 769, iter: 1, loss: 0.8273
# restart: 0, epoch: 770, iter: 1, loss: 0.8272
# restart: 0, epoch: 771, iter: 1, loss: 0.8272
# restart: 0, epoch: 772, iter: 1, loss: 0.8271
# restart: 0, epoch: 773, iter: 1, loss: 0.8270
# restart: 0, epoch: 774, iter: 1, loss: 0.8270
# restart: 0, epoch: 775, iter: 1, loss: 0.8269
# restart: 0, epoch: 776, iter: 1, loss: 0.8269
# restart: 0, epoch: 777, iter: 1, loss: 0.8268
# restart: 0, epoch: 778, iter: 1, loss: 0.8267
# restart: 0, epoch: 779, iter: 1, loss: 0.8267
# restart: 0, epoch: 780, iter: 1, loss: 0.8266
# restart: 0, epoch: 781, iter: 1, loss: 0.8265
# restart: 0, epoch: 782, iter: 1, loss: 0.8265
# restart: 0, epoch: 783, iter: 1, loss: 0.8264
# restart: 0, epoch: 784, iter: 1, loss: 0.8263
# restart: 0, epoch: 785, iter: 1, loss: 0.8263
# restart: 0, epoch: 786, iter: 1, loss: 0.8262
# restart: 0, epoch: 787, iter: 1, loss: 0.8261
# restart: 0, epoch: 788, iter: 1, loss: 0.8261
# restart: 0, epoch: 789, iter: 1, loss: 0.8260
# restart: 0, epoch: 790, iter: 1, loss: 0.8260
# restart: 0, epoch: 791, iter: 1, loss: 0.8259
# restart: 0, epoch: 792, iter: 1, loss: 0.8258
# restart: 0, epoch: 793, iter: 1, loss: 0.8258
# restart: 0, epoch: 794, iter: 1, loss: 0.8257
# restart: 0, epoch: 795, iter: 1, loss: 0.8256
# restart: 0, epoch: 796, iter: 1, loss: 0.8256
# restart: 0, epoch: 797, iter: 1, loss: 0.8255
# restart: 0, epoch: 798, iter: 1, loss: 0.8254
# restart: 0, epoch: 799, iter: 1, loss: 0.8254
# restart: 0, epoch: 800, iter: 1, loss: 0.8253
# restart: 0, epoch: 801, iter: 1, loss: 0.8252
# restart: 0, epoch: 802, iter: 1, loss: 0.8252
# restart: 0, epoch: 803, iter: 1, loss: 0.8251
# restart: 0, epoch: 804, iter: 1, loss: 0.8250
# restart: 0, epoch: 805, iter: 1, loss: 0.8250
# restart: 0, epoch: 806, iter: 1, loss: 0.8249
# restart: 0, epoch: 807, iter: 1, loss: 0.8249
# restart: 0, epoch: 808, iter: 1, loss: 0.8248
# restart: 0, epoch: 809, iter: 1, loss: 0.8247
# restart: 0, epoch: 810, iter: 1, loss: 0.8247
# restart: 0, epoch: 811, iter: 1, loss: 0.8246
# restart: 0, epoch: 812, iter: 1, loss: 0.8245
# restart: 0, epoch: 813, iter: 1, loss: 0.8245
# restart: 0, epoch: 814, iter: 1, loss: 0.8244
# restart: 0, epoch: 815, iter: 1, loss: 0.8243
# restart: 0, epoch: 816, iter: 1, loss: 0.8243
# restart: 0, epoch: 817, iter: 1, loss: 0.8242
# restart: 0, epoch: 818, iter: 1, loss: 0.8241
# restart: 0, epoch: 819, iter: 1, loss: 0.8241
# restart: 0, epoch: 820, iter: 1, loss: 0.8240
# restart: 0, epoch: 821, iter: 1, loss: 0.8239
# restart: 0, epoch: 822, iter: 1, loss: 0.8239
# restart: 0, epoch: 823, iter: 1, loss: 0.8238
# restart: 0, epoch: 824, iter: 1, loss: 0.8237
# restart: 0, epoch: 825, iter: 1, loss: 0.8237
# restart: 0, epoch: 826, iter: 1, loss: 0.8236
# restart: 0, epoch: 827, iter: 1, loss: 0.8235
# restart: 0, epoch: 828, iter: 1, loss: 0.8235
# restart: 0, epoch: 829, iter: 1, loss: 0.8234
# restart: 0, epoch: 830, iter: 1, loss: 0.8233
# restart: 0, epoch: 831, iter: 1, loss: 0.8233
# restart: 0, epoch: 832, iter: 1, loss: 0.8232
# restart: 0, epoch: 833, iter: 1, loss: 0.8231
# restart: 0, epoch: 834, iter: 1, loss: 0.8231
# restart: 0, epoch: 835, iter: 1, loss: 0.8230
# restart: 0, epoch: 836, iter: 1, loss: 0.8229
# restart: 0, epoch: 837, iter: 1, loss: 0.8229
# restart: 0, epoch: 838, iter: 1, loss: 0.8228
# restart: 0, epoch: 839, iter: 1, loss: 0.8227
# restart: 0, epoch: 840, iter: 1, loss: 0.8226
# restart: 0, epoch: 841, iter: 1, loss: 0.8226
# restart: 0, epoch: 842, iter: 1, loss: 0.8225
# restart: 0, epoch: 843, iter: 1, loss: 0.8224
# restart: 0, epoch: 844, iter: 1, loss: 0.8224
# restart: 0, epoch: 845, iter: 1, loss: 0.8223
# restart: 0, epoch: 846, iter: 1, loss: 0.8222
# restart: 0, epoch: 847, iter: 1, loss: 0.8222
# restart: 0, epoch: 848, iter: 1, loss: 0.8221
# restart: 0, epoch: 849, iter: 1, loss: 0.8220
# restart: 0, epoch: 850, iter: 1, loss: 0.8220
# restart: 0, epoch: 851, iter: 1, loss: 0.8219
# restart: 0, epoch: 852, iter: 1, loss: 0.8218
# restart: 0, epoch: 853, iter: 1, loss: 0.8217
# restart: 0, epoch: 854, iter: 1, loss: 0.8217
# restart: 0, epoch: 855, iter: 1, loss: 0.8216
# restart: 0, epoch: 856, iter: 1, loss: 0.8215
# restart: 0, epoch: 857, iter: 1, loss: 0.8215
# restart: 0, epoch: 858, iter: 1, loss: 0.8214
# restart: 0, epoch: 859, iter: 1, loss: 0.8213
# restart: 0, epoch: 860, iter: 1, loss: 0.8213
# restart: 0, epoch: 861, iter: 1, loss: 0.8212
# restart: 0, epoch: 862, iter: 1, loss: 0.8211
# restart: 0, epoch: 863, iter: 1, loss: 0.8210
# restart: 0, epoch: 864, iter: 1, loss: 0.8209
# restart: 0, epoch: 865, iter: 1, loss: 0.8208
# restart: 0, epoch: 866, iter: 1, loss: 0.8207
# restart: 0, epoch: 867, iter: 1, loss: 0.8207
# restart: 0, epoch: 868, iter: 1, loss: 0.8206
# restart: 0, epoch: 869, iter: 1, loss: 0.8205
# restart: 0, epoch: 870, iter: 1, loss: 0.8204
# restart: 0, epoch: 871, iter: 1, loss: 0.8204
# restart: 0, epoch: 872, iter: 1, loss: 0.8203
# restart: 0, epoch: 873, iter: 1, loss: 0.8202
# restart: 0, epoch: 874, iter: 1, loss: 0.8201
# restart: 0, epoch: 875, iter: 1, loss: 0.8200
# restart: 0, epoch: 876, iter: 1, loss: 0.8199
# restart: 0, epoch: 877, iter: 1, loss: 0.8198
# restart: 0, epoch: 878, iter: 1, loss: 0.8196
# restart: 0, epoch: 879, iter: 1, loss: 0.8195
# restart: 0, epoch: 880, iter: 1, loss: 0.8194
# restart: 0, epoch: 881, iter: 1, loss: 0.8192
# restart: 0, epoch: 882, iter: 1, loss: 0.8191
# restart: 0, epoch: 883, iter: 1, loss: 0.8189
# restart: 0, epoch: 884, iter: 1, loss: 0.8188
# restart: 0, epoch: 885, iter: 1, loss: 0.8187
# restart: 0, epoch: 886, iter: 1, loss: 0.8187
# restart: 0, epoch: 887, iter: 1, loss: 0.8186
# restart: 0, epoch: 888, iter: 1, loss: 0.8185
# restart: 0, epoch: 889, iter: 1, loss: 0.8185
# restart: 0, epoch: 890, iter: 1, loss: 0.8184
# restart: 0, epoch: 891, iter: 1, loss: 0.8183
# restart: 0, epoch: 892, iter: 1, loss: 0.8182
# restart: 0, epoch: 893, iter: 1, loss: 0.8181
# restart: 0, epoch: 894, iter: 1, loss: 0.8180
# restart: 0, epoch: 895, iter: 1, loss: 0.8179
# restart: 0, epoch: 896, iter: 1, loss: 0.8178
# restart: 0, epoch: 897, iter: 1, loss: 0.8177
# restart: 0, epoch: 898, iter: 1, loss: 0.8176
# restart: 0, epoch: 899, iter: 1, loss: 0.8175
# restart: 0, epoch: 900, iter: 1, loss: 0.8175
# restart: 0, epoch: 901, iter: 1, loss: 0.8174
# restart: 0, epoch: 902, iter: 1, loss: 0.8173
# restart: 0, epoch: 903, iter: 1, loss: 0.8172
# restart: 0, epoch: 904, iter: 1, loss: 0.8171
# restart: 0, epoch: 905, iter: 1, loss: 0.8171
# restart: 0, epoch: 906, iter: 1, loss: 0.8170
# restart: 0, epoch: 907, iter: 1, loss: 0.8169
# restart: 0, epoch: 908, iter: 1, loss: 0.8168
# restart: 0, epoch: 909, iter: 1, loss: 0.8167
# restart: 0, epoch: 910, iter: 1, loss: 0.8166
# restart: 0, epoch: 911, iter: 1, loss: 0.8165
# restart: 0, epoch: 912, iter: 1, loss: 0.8165
# restart: 0, epoch: 913, iter: 1, loss: 0.8164
# restart: 0, epoch: 914, iter: 1, loss: 0.8163
# restart: 0, epoch: 915, iter: 1, loss: 0.8162
# restart: 0, epoch: 916, iter: 1, loss: 0.8162
# restart: 0, epoch: 917, iter: 1, loss: 0.8161
# restart: 0, epoch: 918, iter: 1, loss: 0.8160
# restart: 0, epoch: 919, iter: 1, loss: 0.8159
# restart: 0, epoch: 920, iter: 1, loss: 0.8158
# restart: 0, epoch: 921, iter: 1, loss: 0.8158
# restart: 0, epoch: 922, iter: 1, loss: 0.8157
# restart: 0, epoch: 923, iter: 1, loss: 0.8156
# restart: 0, epoch: 924, iter: 1, loss: 0.8155
# restart: 0, epoch: 925, iter: 1, loss: 0.8155
# restart: 0, epoch: 926, iter: 1, loss: 0.8154
# restart: 0, epoch: 927, iter: 1, loss: 0.8153
# restart: 0, epoch: 928, iter: 1, loss: 0.8152
# restart: 0, epoch: 929, iter: 1, loss: 0.8152
# restart: 0, epoch: 930, iter: 1, loss: 0.8151
# restart: 0, epoch: 931, iter: 1, loss: 0.8150
# restart: 0, epoch: 932, iter: 1, loss: 0.8149
# restart: 0, epoch: 933, iter: 1, loss: 0.8149
# restart: 0, epoch: 934, iter: 1, loss: 0.8148
# restart: 0, epoch: 935, iter: 1, loss: 0.8147
# restart: 0, epoch: 936, iter: 1, loss: 0.8146
# restart: 0, epoch: 937, iter: 1, loss: 0.8146
# restart: 0, epoch: 938, iter: 1, loss: 0.8145
# restart: 0, epoch: 939, iter: 1, loss: 0.8144
# restart: 0, epoch: 940, iter: 1, loss: 0.8144
# restart: 0, epoch: 941, iter: 1, loss: 0.8143
# restart: 0, epoch: 942, iter: 1, loss: 0.8142
# restart: 0, epoch: 943, iter: 1, loss: 0.8141
# restart: 0, epoch: 944, iter: 1, loss: 0.8141
# restart: 0, epoch: 945, iter: 1, loss: 0.8140
# restart: 0, epoch: 946, iter: 1, loss: 0.8139
# restart: 0, epoch: 947, iter: 1, loss: 0.8139
# restart: 0, epoch: 948, iter: 1, loss: 0.8138
# restart: 0, epoch: 949, iter: 1, loss: 0.8137
# restart: 0, epoch: 950, iter: 1, loss: 0.8137
# restart: 0, epoch: 951, iter: 1, loss: 0.8136
# restart: 0, epoch: 952, iter: 1, loss: 0.8135
# restart: 0, epoch: 953, iter: 1, loss: 0.8134
# restart: 0, epoch: 954, iter: 1, loss: 0.8134
# restart: 0, epoch: 955, iter: 1, loss: 0.8133
# restart: 0, epoch: 956, iter: 1, loss: 0.8132
# restart: 0, epoch: 957, iter: 1, loss: 0.8132
# restart: 0, epoch: 958, iter: 1, loss: 0.8131
# restart: 0, epoch: 959, iter: 1, loss: 0.8130
# restart: 0, epoch: 960, iter: 1, loss: 0.8130
# restart: 0, epoch: 961, iter: 1, loss: 0.8129
# restart: 0, epoch: 962, iter: 1, loss: 0.8128
# restart: 0, epoch: 963, iter: 1, loss: 0.8128
# restart: 0, epoch: 964, iter: 1, loss: 0.8127
# restart: 0, epoch: 965, iter: 1, loss: 0.8126
# restart: 0, epoch: 966, iter: 1, loss: 0.8126
# restart: 0, epoch: 967, iter: 1, loss: 0.8125
# restart: 0, epoch: 968, iter: 1, loss: 0.8124
# restart: 0, epoch: 969, iter: 1, loss: 0.8124
# restart: 0, epoch: 970, iter: 1, loss: 0.8123
# restart: 0, epoch: 971, iter: 1, loss: 0.8122
# restart: 0, epoch: 972, iter: 1, loss: 0.8122
# restart: 0, epoch: 973, iter: 1, loss: 0.8121
# restart: 0, epoch: 974, iter: 1, loss: 0.8120
# restart: 0, epoch: 975, iter: 1, loss: 0.8120
# restart: 0, epoch: 976, iter: 1, loss: 0.8119
# restart: 0, epoch: 977, iter: 1, loss: 0.8119
# restart: 0, epoch: 978, iter: 1, loss: 0.8118
# restart: 0, epoch: 979, iter: 1, loss: 0.8117
# restart: 0, epoch: 980, iter: 1, loss: 0.8117
# restart: 0, epoch: 981, iter: 1, loss: 0.8116
# restart: 0, epoch: 982, iter: 1, loss: 0.8115
# restart: 0, epoch: 983, iter: 1, loss: 0.8115
# restart: 0, epoch: 984, iter: 1, loss: 0.8114
# restart: 0, epoch: 985, iter: 1, loss: 0.8113
# restart: 0, epoch: 986, iter: 1, loss: 0.8113
# restart: 0, epoch: 987, iter: 1, loss: 0.8112
# restart: 0, epoch: 988, iter: 1, loss: 0.8112
# restart: 0, epoch: 989, iter: 1, loss: 0.8111
# restart: 0, epoch: 990, iter: 1, loss: 0.8110
# restart: 0, epoch: 991, iter: 1, loss: 0.8110
# restart: 0, epoch: 992, iter: 1, loss: 0.8109
# restart: 0, epoch: 993, iter: 1, loss: 0.8108
# restart: 0, epoch: 994, iter: 1, loss: 0.8108
# restart: 0, epoch: 995, iter: 1, loss: 0.8107
# restart: 0, epoch: 996, iter: 1, loss: 0.8106
# restart: 0, epoch: 997, iter: 1, loss: 0.8106
# restart: 0, epoch: 998, iter: 1, loss: 0.8105
# restart: 0, epoch: 999, iter: 1, loss: 0.8105
# restart: 0, epoch: 1000, iter: 1, loss: 0.8104
# restart: 0, epoch: 1001, iter: 1, loss: 0.8103
# restart: 0, epoch: 1002, iter: 1, loss: 0.8103
# restart: 0, epoch: 1003, iter: 1, loss: 0.8102
# restart: 0, epoch: 1004, iter: 1, loss: 0.8101
# restart: 0, epoch: 1005, iter: 1, loss: 0.8101
# restart: 0, epoch: 1006, iter: 1, loss: 0.8100
# restart: 0, epoch: 1007, iter: 1, loss: 0.8100
# restart: 0, epoch: 1008, iter: 1, loss: 0.8099
# restart: 0, epoch: 1009, iter: 1, loss: 0.8098
# restart: 0, epoch: 1010, iter: 1, loss: 0.8098
# restart: 0, epoch: 1011, iter: 1, loss: 0.8097
# restart: 0, epoch: 1012, iter: 1, loss: 0.8096
# restart: 0, epoch: 1013, iter: 1, loss: 0.8096
# restart: 0, epoch: 1014, iter: 1, loss: 0.8095
# restart: 0, epoch: 1015, iter: 1, loss: 0.8095
# restart: 0, epoch: 1016, iter: 1, loss: 0.8094
# restart: 0, epoch: 1017, iter: 1, loss: 0.8093
# restart: 0, epoch: 1018, iter: 1, loss: 0.8093
# restart: 0, epoch: 1019, iter: 1, loss: 0.8092
# restart: 0, epoch: 1020, iter: 1, loss: 0.8092
# restart: 0, epoch: 1021, iter: 1, loss: 0.8091
# restart: 0, epoch: 1022, iter: 1, loss: 0.8090
# restart: 0, epoch: 1023, iter: 1, loss: 0.8090
# restart: 0, epoch: 1024, iter: 1, loss: 0.8089
# restart: 0, epoch: 1025, iter: 1, loss: 0.8089
# restart: 0, epoch: 1026, iter: 1, loss: 0.8088
# restart: 0, epoch: 1027, iter: 1, loss: 0.8087
# restart: 0, epoch: 1028, iter: 1, loss: 0.8087
# restart: 0, epoch: 1029, iter: 1, loss: 0.8086
# restart: 0, epoch: 1030, iter: 1, loss: 0.8085
# restart: 0, epoch: 1031, iter: 1, loss: 0.8085
# restart: 0, epoch: 1032, iter: 1, loss: 0.8084
# restart: 0, epoch: 1033, iter: 1, loss: 0.8084
# restart: 0, epoch: 1034, iter: 1, loss: 0.8083
# restart: 0, epoch: 1035, iter: 1, loss: 0.8082
# restart: 0, epoch: 1036, iter: 1, loss: 0.8082
# restart: 0, epoch: 1037, iter: 1, loss: 0.8081
# restart: 0, epoch: 1038, iter: 1, loss: 0.8080
# restart: 0, epoch: 1039, iter: 1, loss: 0.8080
# restart: 0, epoch: 1040, iter: 1, loss: 0.8079
# restart: 0, epoch: 1041, iter: 1, loss: 0.8079
# restart: 0, epoch: 1042, iter: 1, loss: 0.8078
# restart: 0, epoch: 1043, iter: 1, loss: 0.8077
# restart: 0, epoch: 1044, iter: 1, loss: 0.8077
# ...
# restart: 0, epoch: 2161, iter: 1, loss: 0.7585
# restart: 0, epoch: 2162, iter: 1, loss: 0.7585
# restart: 0, epoch: 2163, iter: 1, loss: 0.7584
# restart: 0, epoch: 2164, iter: 1, loss: 0.7584
# restart: 0, epoch: 2165, iter: 1, loss: 0.7584
# restart: 0, epoch: 2166, iter: 1, loss: 0.7584
# restart: 0, epoch: 2167, iter: 1, loss: 0.7584
# restart: 0, epoch: 2168, iter: 1, loss: 0.7583
# restart: 0, epoch: 2169, iter: 1, loss: 0.7583
# restart: 0, epoch: 2170, iter: 1, loss: 0.7583
# restart: 0, epoch: 2171, iter: 1, loss: 0.7583
# restart: 0, epoch: 2172, iter: 1, loss: 0.7582
# restart: 0, epoch: 2173, iter: 1, loss: 0.7582
# restart: 0, epoch: 2174, iter: 1, loss: 0.7582
# restart: 0, epoch: 2175, iter: 1, loss: 0.7582
# restart: 0, epoch: 2176, iter: 1, loss: 0.7581
# restart: 0, epoch: 2177, iter: 1, loss: 0.7581
# restart: 0, epoch: 2178, iter: 1, loss: 0.7581
# restart: 0, epoch: 2179, iter: 1, loss: 0.7581
# restart: 0, epoch: 2180, iter: 1, loss: 0.7580
# restart: 0, epoch: 2181, iter: 1, loss: 0.7580
# restart: 0, epoch: 2182, iter: 1, loss: 0.7580
# restart: 0, epoch: 2183, iter: 1, loss: 0.7580
# restart: 0, epoch: 2184, iter: 1, loss: 0.7579
# restart: 0, epoch: 2185, iter: 1, loss: 0.7579
# restart: 0, epoch: 2186, iter: 1, loss: 0.7579
# restart: 0, epoch: 2187, iter: 1, loss: 0.7579
# restart: 0, epoch: 2188, iter: 1, loss: 0.7578
# restart: 0, epoch: 2189, iter: 1, loss: 0.7578
# restart: 0, epoch: 2190, iter: 1, loss: 0.7578
# restart: 0, epoch: 2191, iter: 1, loss: 0.7578
# restart: 0, epoch: 2192, iter: 1, loss: 0.7578
# restart: 0, epoch: 2193, iter: 1, loss: 0.7577
# restart: 0, epoch: 2194, iter: 1, loss: 0.7577
# restart: 0, epoch: 2195, iter: 1, loss: 0.7577
# restart: 0, epoch: 2196, iter: 1, loss: 0.7577
# restart: 0, epoch: 2197, iter: 1, loss: 0.7576
# restart: 0, epoch: 2198, iter: 1, loss: 0.7576
# restart: 0, epoch: 2199, iter: 1, loss: 0.7576
# restart: 0, epoch: 2200, iter: 1, loss: 0.7576
# restart: 0, epoch: 2201, iter: 1, loss: 0.7575
# restart: 0, epoch: 2202, iter: 1, loss: 0.7575
# restart: 0, epoch: 2203, iter: 1, loss: 0.7575
# restart: 0, epoch: 2204, iter: 1, loss: 0.7575
# restart: 0, epoch: 2205, iter: 1, loss: 0.7574
# restart: 0, epoch: 2206, iter: 1, loss: 0.7574
# restart: 0, epoch: 2207, iter: 1, loss: 0.7574
# restart: 0, epoch: 2208, iter: 1, loss: 0.7574
# restart: 0, epoch: 2209, iter: 1, loss: 0.7573
# restart: 0, epoch: 2210, iter: 1, loss: 0.7573
# restart: 0, epoch: 2211, iter: 1, loss: 0.7573
# restart: 0, epoch: 2212, iter: 1, loss: 0.7573
# restart: 0, epoch: 2213, iter: 1, loss: 0.7573
# restart: 0, epoch: 2214, iter: 1, loss: 0.7572
# restart: 0, epoch: 2215, iter: 1, loss: 0.7572
# restart: 0, epoch: 2216, iter: 1, loss: 0.7572
# restart: 0, epoch: 2217, iter: 1, loss: 0.7572
# restart: 0, epoch: 2218, iter: 1, loss: 0.7571
# restart: 0, epoch: 2219, iter: 1, loss: 0.7571
# restart: 0, epoch: 2220, iter: 1, loss: 0.7571
# restart: 0, epoch: 2221, iter: 1, loss: 0.7571
# restart: 0, epoch: 2222, iter: 1, loss: 0.7570
# restart: 0, epoch: 2223, iter: 1, loss: 0.7570
# restart: 0, epoch: 2224, iter: 1, loss: 0.7570
# restart: 0, epoch: 2225, iter: 1, loss: 0.7570
# restart: 0, epoch: 2226, iter: 1, loss: 0.7569
# restart: 0, epoch: 2227, iter: 1, loss: 0.7569
# restart: 0, epoch: 2228, iter: 1, loss: 0.7569
# restart: 0, epoch: 2229, iter: 1, loss: 0.7569
# restart: 0, epoch: 2230, iter: 1, loss: 0.7569
# restart: 0, epoch: 2231, iter: 1, loss: 0.7568
# restart: 0, epoch: 2232, iter: 1, loss: 0.7568
# restart: 0, epoch: 2233, iter: 1, loss: 0.7568
# restart: 0, epoch: 2234, iter: 1, loss: 0.7568
# restart: 0, epoch: 2235, iter: 1, loss: 0.7567
# restart: 0, epoch: 2236, iter: 1, loss: 0.7567
# restart: 0, epoch: 2237, iter: 1, loss: 0.7567
# restart: 0, epoch: 2238, iter: 1, loss: 0.7567
# restart: 0, epoch: 2239, iter: 1, loss: 0.7566
# restart: 0, epoch: 2240, iter: 1, loss: 0.7566
# restart: 0, epoch: 2241, iter: 1, loss: 0.7566
# restart: 0, epoch: 2242, iter: 1, loss: 0.7566
# restart: 0, epoch: 2243, iter: 1, loss: 0.7565
# restart: 0, epoch: 2244, iter: 1, loss: 0.7565
# restart: 0, epoch: 2245, iter: 1, loss: 0.7565
# restart: 0, epoch: 2246, iter: 1, loss: 0.7565
# restart: 0, epoch: 2247, iter: 1, loss: 0.7565
# restart: 0, epoch: 2248, iter: 1, loss: 0.7564
# restart: 0, epoch: 2249, iter: 1, loss: 0.7564
# restart: 0, epoch: 2250, iter: 1, loss: 0.7564
# restart: 0, epoch: 2251, iter: 1, loss: 0.7564
# restart: 0, epoch: 2252, iter: 1, loss: 0.7563
# restart: 0, epoch: 2253, iter: 1, loss: 0.7563
# restart: 0, epoch: 2254, iter: 1, loss: 0.7563
# restart: 0, epoch: 2255, iter: 1, loss: 0.7563
# restart: 0, epoch: 2256, iter: 1, loss: 0.7562
# restart: 0, epoch: 2257, iter: 1, loss: 0.7562
# restart: 0, epoch: 2258, iter: 1, loss: 0.7562
# restart: 0, epoch: 2259, iter: 1, loss: 0.7562
# restart: 0, epoch: 2260, iter: 1, loss: 0.7562
# restart: 0, epoch: 2261, iter: 1, loss: 0.7561
# restart: 0, epoch: 2262, iter: 1, loss: 0.7561
# restart: 0, epoch: 2263, iter: 1, loss: 0.7561
# restart: 0, epoch: 2264, iter: 1, loss: 0.7561
# restart: 0, epoch: 2265, iter: 1, loss: 0.7560
# restart: 0, epoch: 2266, iter: 1, loss: 0.7560
# restart: 0, epoch: 2267, iter: 1, loss: 0.7560
# restart: 0, epoch: 2268, iter: 1, loss: 0.7560
# restart: 0, epoch: 2269, iter: 1, loss: 0.7559
# restart: 0, epoch: 2270, iter: 1, loss: 0.7559
# restart: 0, epoch: 2271, iter: 1, loss: 0.7559
# restart: 0, epoch: 2272, iter: 1, loss: 0.7559
# restart: 0, epoch: 2273, iter: 1, loss: 0.7559
# restart: 0, epoch: 2274, iter: 1, loss: 0.7558
# restart: 0, epoch: 2275, iter: 1, loss: 0.7558
# restart: 0, epoch: 2276, iter: 1, loss: 0.7558
# restart: 0, epoch: 2277, iter: 1, loss: 0.7558
# restart: 0, epoch: 2278, iter: 1, loss: 0.7557
# restart: 0, epoch: 2279, iter: 1, loss: 0.7557
# restart: 0, epoch: 2280, iter: 1, loss: 0.7557
# restart: 0, epoch: 2281, iter: 1, loss: 0.7557
# restart: 0, epoch: 2282, iter: 1, loss: 0.7556
# restart: 0, epoch: 2283, iter: 1, loss: 0.7556
# restart: 0, epoch: 2284, iter: 1, loss: 0.7555
# restart: 0, epoch: 2285, iter: 1, loss: 0.7554
# restart: 0, epoch: 2286, iter: 1, loss: 0.7551
# restart: 0, epoch: 2287, iter: 1, loss: 0.7548
# restart: 0, epoch: 2288, iter: 1, loss: 0.7545
# restart: 0, epoch: 2289, iter: 1, loss: 0.7544
# restart: 0, epoch: 2290, iter: 1, loss: 0.7544
# restart: 0, epoch: 2291, iter: 1, loss: 0.7544
# restart: 0, epoch: 2292, iter: 1, loss: 0.7545
# restart: 0, epoch: 2293, iter: 1, loss: 0.7545
# restart: 0, epoch: 2294, iter: 1, loss: 0.7544
# restart: 0, epoch: 2295, iter: 1, loss: 0.7544
# restart: 0, epoch: 2296, iter: 1, loss: 0.7543
# restart: 0, epoch: 2297, iter: 1, loss: 0.7542
# restart: 0, epoch: 2298, iter: 1, loss: 0.7541
# restart: 0, epoch: 2299, iter: 1, loss: 0.7541
# restart: 0, epoch: 2300, iter: 1, loss: 0.7540
# restart: 0, epoch: 2301, iter: 1, loss: 0.7540
# restart: 0, epoch: 2302, iter: 1, loss: 0.7540
# restart: 0, epoch: 2303, iter: 1, loss: 0.7540
# restart: 0, epoch: 2304, iter: 1, loss: 0.7539
# restart: 0, epoch: 2305, iter: 1, loss: 0.7539
# restart: 0, epoch: 2306, iter: 1, loss: 0.7538
# restart: 0, epoch: 2307, iter: 1, loss: 0.7538
# restart: 0, epoch: 2308, iter: 1, loss: 0.7537
# restart: 0, epoch: 2309, iter: 1, loss: 0.7537
# restart: 0, epoch: 2310, iter: 1, loss: 0.7537
# restart: 0, epoch: 2311, iter: 1, loss: 0.7537
# restart: 0, epoch: 2312, iter: 1, loss: 0.7536
# restart: 0, epoch: 2313, iter: 1, loss: 0.7536
# restart: 0, epoch: 2314, iter: 1, loss: 0.7536
# restart: 0, epoch: 2315, iter: 1, loss: 0.7535
# restart: 0, epoch: 2316, iter: 1, loss: 0.7535
# restart: 0, epoch: 2317, iter: 1, loss: 0.7534
# restart: 0, epoch: 2318, iter: 1, loss: 0.7534
# restart: 0, epoch: 2319, iter: 1, loss: 0.7534
# restart: 0, epoch: 2320, iter: 1, loss: 0.7534
# restart: 0, epoch: 2321, iter: 1, loss: 0.7533
# restart: 0, epoch: 2322, iter: 1, loss: 0.7533
# restart: 0, epoch: 2323, iter: 1, loss: 0.7533
# restart: 0, epoch: 2324, iter: 1, loss: 0.7532
# restart: 0, epoch: 2325, iter: 1, loss: 0.7532
# restart: 0, epoch: 2326, iter: 1, loss: 0.7532
# restart: 0, epoch: 2327, iter: 1, loss: 0.7531
# restart: 0, epoch: 2328, iter: 1, loss: 0.7531
# restart: 0, epoch: 2329, iter: 1, loss: 0.7531
# restart: 0, epoch: 2330, iter: 1, loss: 0.7530
# restart: 0, epoch: 2331, iter: 1, loss: 0.7530
# restart: 0, epoch: 2332, iter: 1, loss: 0.7530
# restart: 0, epoch: 2333, iter: 1, loss: 0.7529
# restart: 0, epoch: 2334, iter: 1, loss: 0.7529
# restart: 0, epoch: 2335, iter: 1, loss: 0.7529
# restart: 0, epoch: 2336, iter: 1, loss: 0.7528
# restart: 0, epoch: 2337, iter: 1, loss: 0.7528
# restart: 0, epoch: 2338, iter: 1, loss: 0.7528
# restart: 0, epoch: 2339, iter: 1, loss: 0.7528
# restart: 0, epoch: 2340, iter: 1, loss: 0.7527
# restart: 0, epoch: 2341, iter: 1, loss: 0.7527
# restart: 0, epoch: 2342, iter: 1, loss: 0.7527
# restart: 0, epoch: 2343, iter: 1, loss: 0.7526
# restart: 0, epoch: 2344, iter: 1, loss: 0.7526
# restart: 0, epoch: 2345, iter: 1, loss: 0.7526
# restart: 0, epoch: 2346, iter: 1, loss: 0.7526
# restart: 0, epoch: 2347, iter: 1, loss: 0.7525
# restart: 0, epoch: 2348, iter: 1, loss: 0.7525
# restart: 0, epoch: 2349, iter: 1, loss: 0.7525
# restart: 0, epoch: 2350, iter: 1, loss: 0.7524
# restart: 0, epoch: 2351, iter: 1, loss: 0.7524
# restart: 0, epoch: 2352, iter: 1, loss: 0.7524
# restart: 0, epoch: 2353, iter: 1, loss: 0.7524
# restart: 0, epoch: 2354, iter: 1, loss: 0.7523
# restart: 0, epoch: 2355, iter: 1, loss: 0.7523
# restart: 0, epoch: 2356, iter: 1, loss: 0.7523
# restart: 0, epoch: 2357, iter: 1, loss: 0.7523
# restart: 0, epoch: 2358, iter: 1, loss: 0.7522
# restart: 0, epoch: 2359, iter: 1, loss: 0.7522
# restart: 0, epoch: 2360, iter: 1, loss: 0.7522
# restart: 0, epoch: 2361, iter: 1, loss: 0.7522
# restart: 0, epoch: 2362, iter: 1, loss: 0.7521
# restart: 0, epoch: 2363, iter: 1, loss: 0.7521
# restart: 0, epoch: 2364, iter: 1, loss: 0.7521
# restart: 0, epoch: 2365, iter: 1, loss: 0.7521
# restart: 0, epoch: 2366, iter: 1, loss: 0.7520
# restart: 0, epoch: 2367, iter: 1, loss: 0.7520
# restart: 0, epoch: 2368, iter: 1, loss: 0.7520
# restart: 0, epoch: 2369, iter: 1, loss: 0.7520
# restart: 0, epoch: 2370, iter: 1, loss: 0.7519
# restart: 0, epoch: 2371, iter: 1, loss: 0.7519
# restart: 0, epoch: 2372, iter: 1, loss: 0.7519
# restart: 0, epoch: 2373, iter: 1, loss: 0.7519
# restart: 0, epoch: 2374, iter: 1, loss: 0.7518
# restart: 0, epoch: 2375, iter: 1, loss: 0.7518
# restart: 0, epoch: 2376, iter: 1, loss: 0.7518
# restart: 0, epoch: 2377, iter: 1, loss: 0.7518
# restart: 0, epoch: 2378, iter: 1, loss: 0.7517
# restart: 0, epoch: 2379, iter: 1, loss: 0.7517
# restart: 0, epoch: 2380, iter: 1, loss: 0.7517
# restart: 0, epoch: 2381, iter: 1, loss: 0.7517
# restart: 0, epoch: 2382, iter: 1, loss: 0.7516
# restart: 0, epoch: 2383, iter: 1, loss: 0.7516
# restart: 0, epoch: 2384, iter: 1, loss: 0.7516
# restart: 0, epoch: 2385, iter: 1, loss: 0.7516
# restart: 0, epoch: 2386, iter: 1, loss: 0.7515
# restart: 0, epoch: 2387, iter: 1, loss: 0.7515
# restart: 0, epoch: 2388, iter: 1, loss: 0.7515
# restart: 0, epoch: 2389, iter: 1, loss: 0.7515
# restart: 0, epoch: 2390, iter: 1, loss: 0.7514
# restart: 0, epoch: 2391, iter: 1, loss: 0.7514
# restart: 0, epoch: 2392, iter: 1, loss: 0.7514
# restart: 0, epoch: 2393, iter: 1, loss: 0.7514
# restart: 0, epoch: 2394, iter: 1, loss: 0.7513
# restart: 0, epoch: 2395, iter: 1, loss: 0.7513
# restart: 0, epoch: 2396, iter: 1, loss: 0.7513
# restart: 0, epoch: 2397, iter: 1, loss: 0.7513
# restart: 0, epoch: 2398, iter: 1, loss: 0.7513
# restart: 0, epoch: 2399, iter: 1, loss: 0.7512
# restart: 0, epoch: 2400, iter: 1, loss: 0.7512
# restart: 0, epoch: 2401, iter: 1, loss: 0.7512
# restart: 0, epoch: 2402, iter: 1, loss: 0.7512
# restart: 0, epoch: 2403, iter: 1, loss: 0.7511
# restart: 0, epoch: 2404, iter: 1, loss: 0.7511
# restart: 0, epoch: 2405, iter: 1, loss: 0.7511
# restart: 0, epoch: 2406, iter: 1, loss: 0.7511
# restart: 0, epoch: 2407, iter: 1, loss: 0.7510
# restart: 0, epoch: 2408, iter: 1, loss: 0.7510
# restart: 0, epoch: 2409, iter: 1, loss: 0.7510
# restart: 0, epoch: 2410, iter: 1, loss: 0.7510
# restart: 0, epoch: 2411, iter: 1, loss: 0.7510
# restart: 0, epoch: 2412, iter: 1, loss: 0.7509
# restart: 0, epoch: 2413, iter: 1, loss: 0.7509
# restart: 0, epoch: 2414, iter: 1, loss: 0.7509
# restart: 0, epoch: 2415, iter: 1, loss: 0.7509
# restart: 0, epoch: 2416, iter: 1, loss: 0.7508
# restart: 0, epoch: 2417, iter: 1, loss: 0.7508
# restart: 0, epoch: 2418, iter: 1, loss: 0.7508
# restart: 0, epoch: 2419, iter: 1, loss: 0.7508
# restart: 0, epoch: 2420, iter: 1, loss: 0.7507
# restart: 0, epoch: 2421, iter: 1, loss: 0.7507
# restart: 0, epoch: 2422, iter: 1, loss: 0.7507
# restart: 0, epoch: 2423, iter: 1, loss: 0.7507
# restart: 0, epoch: 2424, iter: 1, loss: 0.7507
# restart: 0, epoch: 2425, iter: 1, loss: 0.7506
# restart: 0, epoch: 2426, iter: 1, loss: 0.7506
# restart: 0, epoch: 2427, iter: 1, loss: 0.7506
# restart: 0, epoch: 2428, iter: 1, loss: 0.7506
# restart: 0, epoch: 2429, iter: 1, loss: 0.7505
# restart: 0, epoch: 2430, iter: 1, loss: 0.7505
# restart: 0, epoch: 2431, iter: 1, loss: 0.7505
# restart: 0, epoch: 2432, iter: 1, loss: 0.7505
# restart: 0, epoch: 2433, iter: 1, loss: 0.7505
# restart: 0, epoch: 2434, iter: 1, loss: 0.7504
# restart: 0, epoch: 2435, iter: 1, loss: 0.7504
# restart: 0, epoch: 2436, iter: 1, loss: 0.7504
# restart: 0, epoch: 2437, iter: 1, loss: 0.7504
# restart: 0, epoch: 2438, iter: 1, loss: 0.7503
# restart: 0, epoch: 2439, iter: 1, loss: 0.7503
# restart: 0, epoch: 2440, iter: 1, loss: 0.7503
# restart: 0, epoch: 2441, iter: 1, loss: 0.7503
# restart: 0, epoch: 2442, iter: 1, loss: 0.7503
# restart: 0, epoch: 2443, iter: 1, loss: 0.7502
# restart: 0, epoch: 2444, iter: 1, loss: 0.7502
# restart: 0, epoch: 2445, iter: 1, loss: 0.7502
# restart: 0, epoch: 2446, iter: 1, loss: 0.7502
# restart: 0, epoch: 2447, iter: 1, loss: 0.7501
# restart: 0, epoch: 2448, iter: 1, loss: 0.7501
# restart: 0, epoch: 2449, iter: 1, loss: 0.7501
# restart: 0, epoch: 2450, iter: 1, loss: 0.7501
# restart: 0, epoch: 2451, iter: 1, loss: 0.7501
# restart: 0, epoch: 2452, iter: 1, loss: 0.7500
# restart: 0, epoch: 2453, iter: 1, loss: 0.7500
# restart: 0, epoch: 2454, iter: 1, loss: 0.7500
# restart: 0, epoch: 2455, iter: 1, loss: 0.7500
# restart: 0, epoch: 2456, iter: 1, loss: 0.7499
# restart: 0, epoch: 2457, iter: 1, loss: 0.7499
# restart: 0, epoch: 2458, iter: 1, loss: 0.7499
# restart: 0, epoch: 2459, iter: 1, loss: 0.7499
# restart: 0, epoch: 2460, iter: 1, loss: 0.7499
# restart: 0, epoch: 2461, iter: 1, loss: 0.7498
# restart: 0, epoch: 2462, iter: 1, loss: 0.7498
# restart: 0, epoch: 2463, iter: 1, loss: 0.7498
# restart: 0, epoch: 2464, iter: 1, loss: 0.7498
# restart: 0, epoch: 2465, iter: 1, loss: 0.7498
# restart: 0, epoch: 2466, iter: 1, loss: 0.7497
# restart: 0, epoch: 2467, iter: 1, loss: 0.7497
# restart: 0, epoch: 2468, iter: 1, loss: 0.7497
# restart: 0, epoch: 2469, iter: 1, loss: 0.7497
# restart: 0, epoch: 2470, iter: 1, loss: 0.7496
# restart: 0, epoch: 2471, iter: 1, loss: 0.7496
# restart: 0, epoch: 2472, iter: 1, loss: 0.7496
# restart: 0, epoch: 2473, iter: 1, loss: 0.7496
# restart: 0, epoch: 2474, iter: 1, loss: 0.7496
# restart: 0, epoch: 2475, iter: 1, loss: 0.7495
# restart: 0, epoch: 2476, iter: 1, loss: 0.7495
# restart: 0, epoch: 2477, iter: 1, loss: 0.7495
# restart: 0, epoch: 2478, iter: 1, loss: 0.7495
# restart: 0, epoch: 2479, iter: 1, loss: 0.7495
# restart: 0, epoch: 2480, iter: 1, loss: 0.7494
# restart: 0, epoch: 2481, iter: 1, loss: 0.7494
# restart: 0, epoch: 2482, iter: 1, loss: 0.7494
# restart: 0, epoch: 2483, iter: 1, loss: 0.7494
# restart: 0, epoch: 2484, iter: 1, loss: 0.7494
# restart: 0, epoch: 2485, iter: 1, loss: 0.7493
# restart: 0, epoch: 2486, iter: 1, loss: 0.7493
# restart: 0, epoch: 2487, iter: 1, loss: 0.7493
# restart: 0, epoch: 2488, iter: 1, loss: 0.7493
# restart: 0, epoch: 2489, iter: 1, loss: 0.7492
# restart: 0, epoch: 2490, iter: 1, loss: 0.7492
# restart: 0, epoch: 2491, iter: 1, loss: 0.7492
# restart: 0, epoch: 2492, iter: 1, loss: 0.7492
# restart: 0, epoch: 2493, iter: 1, loss: 0.7492
# restart: 0, epoch: 2494, iter: 1, loss: 0.7491
# restart: 0, epoch: 2495, iter: 1, loss: 0.7491
# restart: 0, epoch: 2496, iter: 1, loss: 0.7491
# restart: 0, epoch: 2497, iter: 1, loss: 0.7491
# restart: 0, epoch: 2498, iter: 1, loss: 0.7491
# restart: 0, epoch: 2499, iter: 1, loss: 0.7490
# restart: 0, epoch: 2500, iter: 1, loss: 0.7490

# %%
# model_name = "Refrigerator_trial_seq_time.pt"
# torch.save(model.state_dict(), os.path.join(
#    "models/", model_name))

# %% [markdown]
# ## Decomp

# %%
kernel1 = ScaleKernel(RBFKernel(ard_num_dims=n))
# kernel2 = ScaleKernel(RBFKernel(ard_num_dims=1,active_dims=(99)))
# kernel3 = ScaleKernel(CosineKernel(ard_num_dims=1,active_dims=(99)))

# kernel4 = kernel2*kernel3
kernel = kernel1 #ernel4
# induce_points = 512
inducing_points =  x[np.arange(0,x.shape[0],70)] 
# inducing_points = x[torch.randperm(x.shape[0])[: 1500]]

model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                      inducing_points).to("cuda")

model_name =  "Refrigerator_rbf_building6_" + str(0) + ".pt"
model.load_state_dict(torch.load(
    os.path.join("./final_models/", model_name)))
# Out:
# <All keys matched successfully>

# %%
model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
                      inducing_points).to("cuda")

# %%
pred_dist1 = model1.predict(xt[:4000].to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_mean1.shape
# Out:
# torch.Size([4000])

# %%
pred_arr =[]
pred_arr.append(np.array(pred_dist1.mean.cpu()))

# %%
y_mean1 = np.mean(pred_arr, axis =0)

# y_Std = np.std(np.array(pred_arr), axis =0)

# %%
y_mean1 = scalers[1].inverse_transform(y_mean1.reshape(-1,1)).squeeze()
# y_std = scaler_y.inverse_transform(y_Std.reshape(-1,1)).squeeze()

# %%
y_mean1.shape
# Out:
# (4000,)

# %%
y_mean_ = np.clip(y_mean1,0,y_mean1.max())
# y_sigma =  np.clip(y_mean,0,y_mean.max())

# %%
idx = 3000
plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp[:idx], scalers[].inverse_transform(xt.cpu().reshape(-1,1))[:idx], label = "Main")
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean_[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
# savefig("Uncertainity")

# %%
model2 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel4,
                      inducing_points).to("cuda")

# %%
pred_dist2 = model2.predict(xt[:4000].to("cuda"))
# print("Done ", i)

y_mean2 = pred_dist2.loc

# %%
y_mean2 = scalers[1].inverse_transform(y_mean2.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean2.shape)
# Out:
# torch.Size([16781]) (4000,)

# %%
y_mean_ = np.clip(y_mean2,0,y_mean2.max())

# %%
idx = 3000
plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp[:idx], scaler_y.inverse_transform(y.cpu().reshape(-1,1))[:idx], label = "Main")
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean_[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()

# %%
idx = 3000
# plt.figure(figsize=(10,6))
plt.plot(jnp.arange(idx),  yt.cpu().reshape(-1,1)[:idx], label = "Ground Truth", color="green")
plt.plot(jnp.arange(idx), y_mean_[:idx].reshape(-1,1), label = "Predicted")
# for i in range(2,3):
#     plt.fill_between(jnp.arange(idx), y_mean[:idx] - i*y_std[:idx], y_mean[:idx] + i*y_std[:idx],
#                     color="orange", alpha=(1/(i*3)), label=f"$\mu\pm{i}*\sigma$")
# plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.legend( prop={'size': 5.5})
plt.ylabel("Power")
sns.despine()

# %%
mae = np.mean(np.abs(np.array(yt) - y_mean))
rms = errors.rmse(jnp.array(yt), y_mean)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  27.80521506352558
# RMSE:  44.84471

# %%
try:
    from probml_utils import latexify, savefig, is_latexify_enabled
except ModuleNotFoundError:
    # %pip install git+https://github.com/probml/probml-utils.git
    from probml_utils import latexify, savefig, is_latexify_enabled

# %%
os.environ["LATEXIFY"] = "1"
os.environ["FIG_DIR"] = "./Final_plotss/"

# %%
latexify(width_scale_factor=2, fig_height=2)

# %%
idx = 2000
# plt.figure(figsize=(10,6))
plt.figure()
plt.plot(jnp.arange(idx), yt[300:idx+300], label = "Fridge True")
plt.plot(jnp.arange(idx), y_mean[300:idx+300], label = "Fridge Predicted")
plt.legend()
sns.despine()
savefig("CombinationKernel")
# Out:
# saving image to ./Final_plotss/CombinationKernel_latexified.pdf
# Figure size: [2. 2.]

# %%
model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
                       inducing_points).to("cuda")

# %%
pred_dist1 = model1.predict(xt.to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_mean1 = scalers[1].inverse_transform(y_mean1.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean1.shape)
# Out:
# torch.Size([14780]) (14780,)

# %%
idx = 2000
# plt.figure(figsize=(10,6))
plt.figure()
plt.plot(jnp.arange(idx), yt[300:idx+300], label = "Fridge True")
plt.plot(jnp.arange(idx), y_mean1[300:idx+300], label = "Fridge Predicted")
# plt.legend()
sns.despine()
savefig("RBFKernel")
# Out:
# saving image to ./Final_plotss/RBFKernel_latexified.pdf
# Figure size: [2. 2.]

# %%
# for name, params in model.named_parameters():
#   print(name, params)

# # model.mll.model.base_covar_module.kernels.base_kernel.raw_lengthscale

# %%
x.shape
# Out:
# torch.Size([55457, 100])

# %%
model2 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel4,
                       inducing_points).to("cuda")

# %%
pred_dist2 = model2.predict(xt.to("cuda"))
# print("Done ", i)

y_mean2 = pred_dist2.loc
# Out:
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/kernels/inducing_point_kernel.py:61: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352645774/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   inv_root = torch.triangular_solve(eye, chol)[0]

# %%
y_mean2 = scaler_y.inverse_transform(y_mean2.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean2.shape)
# Out:
# torch.Size([14780]) (14780,)

# %%
idx = 2000
plt.figure()
# plt.figure(figsize=(10,6))
plt.plot(jnp.arange(idx), yt[300:idx+300], label = "Fridge True")
plt.plot(jnp.arange(idx), y_mean2[300:idx+300], label = "Fridge Predicted")
# plt.legend()
sns.despine()
savefig("RBFxPeriodicKernel")
# Out:
# saving image to ./Final_plotss/RBFxPeriodicKernel_latexified.pdf
# Figure size: [2. 2.]

# %% [markdown]
# ## Normal

# %%
# kernel1 = ScaleKernel(MaternKernel(nu=2.5,ard_num_dims=n))
# # kernel2 = ScaleKernel(MaternKernel(nu=0.5,ard_num_dims=1,active_dims=(99)))
# # kernel3 = ScaleKernel(PeriodicKernel(ard_num_dims=1,active_dims=(99)))
# # # kernel5 = ScaleKernel(gpytorch.kernels.SpectralDeltaKernel(num_dims=n,ard_num_dims=n))
# # #   theta =  {'base_covar_module.kernels.0.base_kernel.lengthscale': torch.tensor(0.5),
# # #         'base_covar_module.kernels.0.outputscale': torch.tensor(5.0),
# # #         'base_covar_module.kernels.1.kernels.0.outputscale':torch.tensor(1.0),
# # #         'base_covar_module.kernels.1.kernels.0.base_kernel.lengthscale': torch.tensor(0.1),
# # #         'base_covar_module.kernels.1.kernels.1.outputscale':torch.tensor(1.0),
# # #         'base_covar_module.kernels.1.kernels.1.base_kernel.lengthscale': torch.tensor(1.0),
# # #         'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
# # #theta = { 'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
# # kernel4 = kernel2*kernel3
# kernel = kernel1 #+ kernel4
# inducing_points =  x[np.arange(0,x.shape[0],95)] 
# # inducing_points = x[torch.randperm(x.shape[0])[: 1500]]

# model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
#                       inducing_points).to("cuda")
# model_name = "Refrigerator_trial_seq_time.pt"
# # model_name =  "Refrigerator_trial_seq_time.pt"
# model.load_state_dict(torch.load(
#     os.path.join("models/", model_name)))

# %%
plt.scatter(range(7),model.mll.model.base_covar_module.base_kernel.lengthscale.cpu().detach().reshape(-1,1))

# %%
# plt.scatter(range(4),model.mll.model.base_covar_module.kernels[0].base_kernel.lengthscale.cpu().detach().reshape(-1,1)[:5])

# %%
for name, params in model.named_parameters():
  print(name, params)
# Out:
# mll.likelihood.noise_covar.raw_noise Parameter containing:
# tensor([-1.5677], device='cuda:0', requires_grad=True)
# mll.model.mean_module.constant Parameter containing:
# tensor([0.0666], device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.raw_outputscale Parameter containing:
# tensor(-1.6913, device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.base_kernel.raw_lengthscale Parameter containing:
# tensor([[-1.7932, -1.0532, -0.5801,  1.8843,  0.5480,  0.8395, -1.7932]],
#        device='cuda:0', requires_grad=True)
# mll.model.covar_module.inducing_points Parameter containing:
# tensor([[-0.1751, -0.4620,  0.1392,  ..., -0.6446,  0.8196, -0.1751],
#         [-0.2284, -0.3411, -0.5038,  ..., -0.2631, -0.4169, -0.2284],
#         [ 0.1248,  0.2689,  0.8884,  ...,  0.4355,  2.2075,  0.1248],
#         ...,
#         [ 0.5500,  0.6010,  0.1009,  ...,  0.7415, -0.2011,  0.5500],
#         [ 0.6141,  0.7824, -0.4404,  ...,  1.1619, -0.3663,  0.6141],
#         [ 0.5977,  0.5833,  1.4377,  ...,  1.1761,  0.3350,  0.5977]],
#        device='cuda:0', dtype=torch.float64, requires_grad=True)

# %%
# import numpy as np
# try:
#     from probml_utils import latexify, savefig, is_latexify_enabled
# except ModuleNotFoundError:
#     %pip install git+https://github.com/probml/probml-utils.git
#     from probml_utils import latexify, savefig, is_latexify_enabled


# os.environ["LATEXIFY"] = "1"
# os.environ["FIG_DIR"] = "./Final_plotss/"

# latexify(width_scale_factor=2, fig_height=2)

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
# arr = np.array([3.8464, 4.5094, 4.7394, 4.9024, 4.9117, 5.0150, 4.8746, 4.9372, 4.3143,
#          4.5656, 5.0050, 5.1365, 5.1490, 5.2152, 5.2837, 5.2594, 5.1965, 5.0747,
#          5.1212, 4.8200, 4.6431, 4.8732, 4.7529, 0.3853, 4.4826, 4.9550, 5.0677,
#          5.2859, 4.9612, 5.1401, 5.2131, 4.4774, 4.5654, 4.5685, 3.8310, 3.0889,
#          2.7822, 4.0948, 4.0399, 4.6180, 4.5923, 4.5015, 4.0521, 4.8423, 5.2143,
#          5.4020, 4.8021, 4.5021, 0.6626, 0.1252, 1.3779, 4.8821, 4.6781, 4.8554,
#          4.5223, 4.5568, 5.0172, 5.4072, 5.0706, 4.5916, 4.5663, 4.1121, 4.2572,
#          4.2228, 3.7784, 0.4839, 3.6554, 4.3523, 4.6682, 4.6549, 4.8291, 5.0260,
#          4.7748, 4.5609, 4.4541, 4.4165, 4.4292, 4.1279, 3.6382, 4.1110, 4.7252,
#          5.0184, 5.0391, 5.2424, 5.5062, 5.4739, 5.5326, 5.6874, 5.6897, 5.4765,
#          5.4602, 5.4513, 5.5450, 5.6225, 5.5479, 5.3580, 5.3926, 5.1536, 4.6321])
# ar1 = np.arange(0,99,1)
# plt.plot(ar1,arr,'b')
# plt.xlabel('ARD')
# plt.ylabel('Learned ARD LengthScale values')
# # plt.title("Building 6 Test")

# plt.show()
# sns.despine()
# savefig("ARD_Ref")

# %%
pred_dist = model.predict(xt.to("cuda"))
# print("Done ", i)/

# %%
y_mean = pred_dist.loc

# %%
y_mean = scalers[1].inverse_transform(y_mean.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean.shape)
# Out:
# torch.Size([3103]) (3103,)

# %%
y_mean = np.clip(y_mean,0,y_mean.max(),out=y_mean)

# %%
idx=3000
mae_arr = (np.array(yt) - y_mean)
# mae_arr = np.abs(np.array(yt) - y_mean)
plt.plot(x_test_timestamp[:idx],mae_arr[:idx])
plt.xlabel("TimeStamp")
plt.ylabel("Raw Error on Test")
# Out:
# Text(0, 0.5, 'Raw Error on Test')

# %%
idx=yt.shape[0]
mae_arr = np.abs(np.array(yt) - y_mean)
plt.plot(x_test_timestamp[:idx],yt[:idx], label = "ref")
plt.plot(x_test_timestamp[:idx],mae_arr[:idx], label="Eror")
plt.xlabel("TimeStamp")
plt.ylabel("Power and Error")
plt.legend()

# %%
sns.kdeplot(mae_arr)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
mae_arr1 = []


for i in range(len(mae_arr)):
  if (mae_arr[i]>300):
    mae_arr1.append(0)
  else:
    mae_arr1.append(mae_arr[i])

np.mean(mae_arr1)

plt.plot(x_test_timestamp[:],mae_arr1[:])
plt.xlabel("TimeStamp")
plt.ylabel("Absolute Error on Test")
# Out:
# Text(0, 0.5, 'Absolute Error on Test')

# %%
mae = np.mean(np.abs(np.array(yt) - y_mean))
rms = errors.rmse(jnp.array(yt), y_mean)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  48.096033864771876
# RMSE:  67.88684

# %%
#MAE:  28.1036

# %%
# x1 = xt[:,49]

# %%
# scalers[0].inverse_transform(x[:,:99]).min()

# %%
x1 = x_test_features[:,0].reshape(-1,1)

# %%
x2 =  x_test_features[:,1].reshape(-1,1)

# %%
# x3 = x_train_features[:,0].reshape(-1,1)
# x4 =  x_train_features[:,1].reshape(-1,1)
# print(x4.min())
# idx = 5000
# plt.figure(figsize=(10,6))
# plt.plot(x_train_timstamp[:idx], scalers[3].inverse_transform(x3)[:idx], label = "Main")
# plt.legend()
# plt.title("Train")

# %%
# idx = 3000
# plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp[:idx], scalers[3].inverse_transform(x1)[:idx], label = "Main")
# plt.plot(x_test_timestamp[:idx], scalers[-1].inverse_transform(x2)[:idx], label = "Main Ref Dif")
# plt.legend()
# plt.title("Test")

# %%
y_mean.min()
# Out:
# 0.0

# %%
y_train1 = scalers[1].inverse_transform(y_train.reshape(-1,1))
print(y_train1.min())
plt.scatter(x_train_timstamp[:idx], y_train1[:idx], label = "Refri")
# Out:
# -4.3396176e-07

# %%
idx = 500 #x2.shape[0]
start = 0
plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp[start:start+idx], scalers[3].inverse_transform(x1)[start:start+idx], label = "Main")
# plt.plot(x_test_timestamp[:idx], scalers[-1].inverse_transform(x2)[:idx], label = "Main Ref Dif")
plt.plot(x_test_timestamp[start:start+idx], yt.cpu()[start:start+idx], label = "Refri")
plt.plot(x_test_timestamp[start:start+idx], y_mean[start:start+idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
plt.title("Building 2")
sns.despine()

# %%
from scipy import stats as st
plt.plot(np.fft.fft(scalers[3].inverse_transform(x1)))
st.mode(np.fft.fft(scalers[3].inverse_transform(x1)))
# Out:
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# ModeResult(mode=array([[178.67245483+0.j]]), count=array([[2]]))

# %%
# value, count = np.unique(y_mean, return_counts=True)

# Z = [x for _,x in sorted(zip(value,count))]

# value[13000:14000].max(), count[13000:14000].max()

# %%
y_mean1 = np.array(y_mean)
for i in range(len(y_mean)):

  # if y_mean1[i]>80 and y_mean[i]<120:
    # if y_mean[i]>160:
    #   y_mean1[i] = 155
 
    # if y_mean1[i]<160 and y_mean1[i]>50:
    #   y_mean1[i] = 155

    # if y_mean1[i]<50:
    #   y_mean1[i] = 0
    if y_mean[i]>180:
      y_mean1[i] = 178
 
    if y_mean1[i]<160 and y_mean1[i]>70:
      y_mean1[i] = 178

    if y_mean1[i]<80:
      y_mean1[i] = 0

# %%
index = 500
start = 1500
plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp[start : start + index], scalers[3].inverse_transform(x1)[start : start + index], label = "Main")
# plt.plot(x_test_timestamp[:idx], scalers[-1].inverse_transform(x2)[:idx], label = "Main Ref Dif")
plt.plot(x_test_timestamp[start:start+index], yt.cpu()[start:start+index], label = "Refri")
plt.plot(x_test_timestamp[start:start+index], y_mean1[start:start+index], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
plt.title("Building 3")
sns.despine()

# %%
mae = np.mean(np.abs(np.array(yt) - y_mean1))
rms = errors.rmse(jnp.array(yt), y_mean1)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  34.88295813466897
# RMSE:  75.854904

# %%
idx=yt.shape[0]
mae_arr = np.abs(np.array(yt) - y_mean)
plt.plot(x_test_timestamp[:idx],yt[:idx], label = "ref")
plt.plot(x_test_timestamp[:idx],mae_arr[:idx], label="Eror")
plt.xlabel("TimeStamp")
plt.ylabel("Power and Error")
plt.legend()

# %%
mae_arr = np.abs(np.array(yt) - y_mean1)
mae_arr1 = []
for i in range(len(mae_arr)):
  if (mae_arr[i]>300):
    mae_arr1.append(0)
  else:
    mae_arr1.append(mae_arr[i])

np.mean(mae_arr1)
# Out:
# 32.47674506457739

# %%
# mae_arr = np.abs(np.array(yt) - y_mean1)
plt.plot(x_test_timestamp[:idx],yt[:idx], label = "ref")
plt.plot(x_test_timestamp[:idx],mae_arr1[:idx], label="Eror")
plt.xlabel("TimeStamp")
plt.ylabel("Power and Error")
plt.legend()

# %%
# idx = 3000
# plt.figure(figsize=(10,6))
# plt.plot(jnp.arange(idx), scaler_y.inverse_transform(y.cpu().reshape(-1,1))[:idx], label = "Main")
# plt.plot(jnp.arange(idx), yt.cpu()[:idx], label = "Refri")
# plt.plot(jnp.arange(idx), y_mean[:idx], label = "Predicted")
# plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
# plt.xlabel("Indexes")
# plt.ylabel("Fridge Power")
# sns.despine()

# %%
# plt.plot(np.array(test_timestamp_orig)[:300],np.array(yt)[:300])
# plt.plot(np.array(test_timestamp_orig)[:300],np.array(y_mean)[:300])

# %%
# plt.scatter(np.array(test_timestamp_orig)[:3000],np.array(y_mean)[:3000],label="True")
# plt.scatter(np.array(test_timestamp_orig)[:3000],np.array(yt)[:3000],label="Pred")
# plt.legend()
# plt.xlabel("TimeStamp")
# plt.xlabel("Refrogerator Power")

# %%
idx = x_test.shape[0]
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp, y_test[:idx], label = "Refri")
plt.plot(x_test_timestamp, y_mean[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
# savefig("CombinationKernel")
# plt.savefig("./Results/Refrigerator_building5.png", bbox_inches="tight")

# %%
model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
                      inducing_points).to("cuda")

# %%
pred_dist1 = model.predict(torch.tensor(np.array(x_train_full)).to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_mean1 = scaler_y.inverse_transform(y_mean1.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(y_train.shape, y_mean1.shape)

# %%
mae = np.mean(np.abs(np.array(y_train) - y_mean1))
rms = errors.rmse(jnp.array(y_train), y_mean1)

print("MAE: ", mae)
print("RMSE: ", rms)

# %%
idx = x_train.shape[0]
plt.figure(figsize=(10,6))
plt.plot(x_train_timstamp, y_train[:idx], label = "Refri")
plt.plot(x_train_timstamp, y_mean[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
# savefig("CombinationKernel")
# plt.savefig("./Results/Refrigerator_building5.png", bbox_inches="tight")

# %%
#MAE:  39.81858310475401 build 6
#MAE:  30.333733374869247 build 3
#MAE:  37.32115756605644 build 2
#MAE: 43.212248588857065 build 5
#MAE:  48.917852990726765

# %%
# MAE: Building 6 MAE: 35.07
# MAE: Building 3 MAE:  31.565
# MAE: Building 2 MAE: 31.089
# MAE: Building 1 MAE: 37.3657
# MAE: Building 5 MAE:  46.316869

# %%
# MAE: Building 6 MAE: 34.3709125
# MAE: Building 3 MAE: 30.919
# MAE: Building 2 MAE: 30.43776
# MAE: Building 1 MAE: 37.10209
# MAE: Building 5 MAE: 45.02767

# %%
frequency decomposition
knn for all features 
try features which have numpy inbuilt
spectral kernel
