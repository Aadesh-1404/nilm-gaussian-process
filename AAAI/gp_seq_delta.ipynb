# %%
import os
os.chdir("../")
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %%
import torch
from gpytorch.kernels import RBFKernel, ScaleKernel, PeriodicKernel, MaternKernel, CosineKernel
from skgpytorch.models import SVGPRegressor, SGPRegressor

# %%
import jax.numpy as jnp
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from utilities.fits import fit
# from utilities import plot
import tensorflow_probability.substrates.jax as tfp
dist = tfp.distributions
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from gpytorch.constraints import GreaterThan
from skgpytorch.metrics import mean_squared_error, negative_log_predictive_density
import time
import numpy as np

# from datasets.dataset_load import dataset_loader
from utilities import plot,fits,gmm,errors,predict,preprocess

# device = "cpu"
# torch.set_default_dtype(torch.float32)
# torch.set_default_tensor_type(torch.FloatTensor)

# %%
train ={1:{
                    'start_time': "2011-04-21" ,
                    'end_time': "2011-05-21"
                },
                3: {
                    'start_time': "2011-04-19" ,
                    'end_time': "2011-05-22"
                },
                2: {
                    'start_time': "2011-04-21" ,
                    'end_time': "2011-05-21"
                },
                5: {
                    'start_time': "2011-04-22" ,
                    'end_time': "2011-06-01"
                }
                }
test = {6: {
                    'start_time': "2011-05-25" ,
                    'end_time': "2011-06-13"
                }}
appliances = ["Refrigerator"]

# %%
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler


def dataset_load(appliances, train, test=None):
    x_train = []
    y_train = []
    x_train_timestamp = []
    n = 99
    units_to_pad = n // 2
    scaler_x = StandardScaler()
    scaler_y = StandardScaler()
    scaler_time = StandardScaler()
    # train
    for key, values in train.items():
        df = pd.read_csv(
            f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[0]])
        df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
        startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
        endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

        if startDate > endDate:
            raise "Start Date must be smaller than Enddate."

        df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
        df.dropna(inplace=True)
        x = df["main"].values
        y = df[appliances[0]].values
        timestamp_train = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])
        x_train.extend(x)
        y_train.extend(y)
        x_train_timestamp.extend(torch.tensor(timestamp_train))


    x_train = jnp.array(x_train)
    y_train = jnp.array(y_train).reshape(-1, 1)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(-1,1)
    x_train = scaler_x.fit_transform(x_train)
    y_train = scaler_y.fit_transform(y_train)
    x_train_timestamp = scaler_time.fit_transform(x_train_timestamp)


    # test
    x_test = []
    y_test = []
    x_test_timestamp = []
    x_test_timestamp_true =[]
    for key, values in test.items():
        df = pd.read_csv(
            f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[0]])
        df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
        startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
        endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

        if startDate > endDate:
            raise "Start Date must be smaller than Enddate."

        df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
        df.dropna(inplace=True)
        x = df["main"].values
        y = df[appliances[0]].values
        timestamp_true = df["Timestamp"].values
        timestamp = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])
        x_test.extend(x)
        y_test.extend(y)
        x_test_timestamp_true.extend(timestamp_true)
        x_test_timestamp.extend(timestamp)

    x_test = jnp.array(x_test)
    y_test = jnp.array(y_test).reshape(-1, 1)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(-1,1)

    x_test = scaler_x.transform(x_test)
    x_test_timestamp = scaler_time.transform(x_test_timestamp)
#     y_test = scaler_y.transform(y_test)

    x_train = jnp.array(x_train).reshape(x_train.shape[0], n, 1)
    y_train = jnp.array(y_train)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(x_train_timestamp.shape[0], 1)
    x_test = jnp.array(x_test).reshape(x_test.shape[0], n, 1)
    y_test = jnp.array(y_test)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(x_test_timestamp.shape[0], 1).to(torch.float64)

    return x_train, y_train, x_test, y_test, x_train_timestamp, x_test_timestamp, x_test_timestamp_true, scaler_x, scaler_y, scaler_time

# %%
x_train, y_train, x_test, y_test, x_train_timstamp, x_test_timestamp, test_timestamp_orig, scaler_x, scaler_y, scaler_time = dataset_load(appliances, train, test)

# %%
n = 99
x_train_full = jnp.concatenate((x_train.reshape(-1,n), jnp.array(np.array(x_train_timstamp))), axis=1)
x_test_full = jnp.concatenate((x_test.reshape(-1,n), jnp.array(np.array(x_test_timestamp))), axis=1)
x_train_full.shape, x_test_full.shape
# Out:
# ((53456, 100), (16781, 100))

# %%
x_train.reshape(-1,n).shape, x_test.reshape(-1,n).shape, y_train.shape, y_test.shape
# Out:
# ((53456, 99), (16781, 99), (53456, 1), (16781, 1))

# %%
# x = x_train_full[:14000]
# y = y_train[:14000]
# xt = x_train_full[14000:]
# yt = y_train[14000:]

# %%
# x.shape, y.shape

# %%
import gpytorch
indexes = 53456
x = torch.tensor(np.array(x_train.reshape(-1,n))).to(torch.float64)
y = torch.tensor(np.array(y_train)).reshape(-1,).to(torch.float64)
xt = torch.tensor(np.array(x_test.reshape(-1,n))).to(torch.float64)
yt = torch.tensor(np.array(y_test)).reshape(-1,).to(torch.float64)

if x.shape[0]>indexes:
  x1 = x[:indexes]
  y1 = y[:indexes]

# xt = xt[:16000]
# yt = yt[:16000]

# %%
x.dtype
# Out:
# torch.float64

# %%
x.shape, y.shape, xt.shape, yt.shape
# Out:
# (torch.Size([53456, 99]),
#  torch.Size([53456]),
#  torch.Size([16781, 99]),
#  torch.Size([16781]))

# %%
x.dtype
# Out:
# torch.float64

# %%
len(range(99))
# Out:
# 99

# %%
mae_arr =[]
rms_arr = []
y_pred_arr = []

batch = 512

# x_train = x_train[:4500]
# y_train = y_train[:4500]

# y_test_trans = torch.tensor(torch.tensor(scaler_x.transform(y_test.reshape(-1,1))).reshape(-1,)).contiguous().to(torch.float64)
for i in range(1):


   #nu=2.5,

  kernel1 = ScaleKernel(RBFKernel(ard_num_dims=n))
  # kernel2 = ScaleKernel(RBFKernel(ard_num_dims=1,active_dims=(99)))
  kernel3 = ScaleKernel(PeriodicKernel(ard_num_dims=1,active_dims=(99)))
  # kernel5 = ScaleKernel(gpytorch.kernels.SpectralDeltaKernel(num_dims=n,ard_num_dims=n))
#   theta =  {'base_covar_module.kernels.0.base_kernel.lengthscale': torch.tensor(0.5),
#         'base_covar_module.kernels.0.outputscale': torch.tensor(5.0),
#         'base_covar_module.kernels.1.kernels.0.outputscale':torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.0.base_kernel.lengthscale': torch.tensor(0.1),
#         'base_covar_module.kernels.1.kernels.1.outputscale':torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.1.base_kernel.lengthscale': torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
  # theta = { 'base_covar_module.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
  # kernel4 = kernel2*kernel3
  kernel = kernel1 #+ kernel3
  # induce_points = 512
  inducing_points =  x[np.arange(0,x.shape[0],95)] 
  # inducing_points = x[torch.randperm(x.shape[0])[: 1500]]
  
  model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                       inducing_points).to("cuda")
  # model.base_covar_module.base_kernel.raw_lengthscale_constraint
  # model.mll.likelihood.noise_covar.register_constraint("raw_noise", GreaterThan(1e-2))
  # for param in model.parameters():
  #   # print(param)
  #   torch.nn.init.normal_(param, 0, 1)
  # theta1 = {'likelihood.noise_covar.noise': torch.tensor(3),
  #       'covar_module.base_kernel.lengthscale': torch.tensor(0.1),
  #       'covar_module.outputscale': torch.tensor(5),}
  loss = model.fit(lr=0.001, n_epochs=2000,verbose=1,
          random_state=0, n_restarts=1)
#   loss_arr.append(loss)
  # print(loss)
  plt.plot(np.asarray(loss[0]))
  # plt.plot(np.asarray(test_loss[0]))







  # y_pred_arr.append(pred_dist.loc)
# Out:
# restart: 0, epoch: 1, iter: 1, loss: 1.4718
# restart: 0, epoch: 2, iter: 1, loss: 1.4690
# restart: 0, epoch: 3, iter: 1, loss: 1.4661
# restart: 0, epoch: 4, iter: 1, loss: 1.4634
# restart: 0, epoch: 5, iter: 1, loss: 1.4608
# restart: 0, epoch: 6, iter: 1, loss: 1.4584
# restart: 0, epoch: 7, iter: 1, loss: 1.4560
# restart: 0, epoch: 8, iter: 1, loss: 1.4538
# restart: 0, epoch: 9, iter: 1, loss: 1.4517
# restart: 0, epoch: 10, iter: 1, loss: 1.4497
# restart: 0, epoch: 11, iter: 1, loss: 1.4477
# restart: 0, epoch: 12, iter: 1, loss: 1.4458
# restart: 0, epoch: 13, iter: 1, loss: 1.4440
# restart: 0, epoch: 14, iter: 1, loss: 1.4422
# restart: 0, epoch: 15, iter: 1, loss: 1.4405
# restart: 0, epoch: 16, iter: 1, loss: 1.4388
# restart: 0, epoch: 17, iter: 1, loss: 1.4372
# restart: 0, epoch: 18, iter: 1, loss: 1.4356
# restart: 0, epoch: 19, iter: 1, loss: 1.4340
# restart: 0, epoch: 20, iter: 1, loss: 1.4325
# restart: 0, epoch: 21, iter: 1, loss: 1.4310
# restart: 0, epoch: 22, iter: 1, loss: 1.4295
# restart: 0, epoch: 23, iter: 1, loss: 1.4281
# restart: 0, epoch: 24, iter: 1, loss: 1.4267
# restart: 0, epoch: 25, iter: 1, loss: 1.4253
# restart: 0, epoch: 26, iter: 1, loss: 1.4239
# restart: 0, epoch: 27, iter: 1, loss: 1.4226
# restart: 0, epoch: 28, iter: 1, loss: 1.4213
# restart: 0, epoch: 29, iter: 1, loss: 1.4200
# restart: 0, epoch: 30, iter: 1, loss: 1.4187
# restart: 0, epoch: 31, iter: 1, loss: 1.4174
# restart: 0, epoch: 32, iter: 1, loss: 1.4161
# restart: 0, epoch: 33, iter: 1, loss: 1.4149
# restart: 0, epoch: 34, iter: 1, loss: 1.4137
# restart: 0, epoch: 35, iter: 1, loss: 1.4125
# restart: 0, epoch: 36, iter: 1, loss: 1.4113
# restart: 0, epoch: 37, iter: 1, loss: 1.4101
# restart: 0, epoch: 38, iter: 1, loss: 1.4089
# restart: 0, epoch: 39, iter: 1, loss: 1.4077
# restart: 0, epoch: 40, iter: 1, loss: 1.4066
# restart: 0, epoch: 41, iter: 1, loss: 1.4054
# restart: 0, epoch: 42, iter: 1, loss: 1.4043
# restart: 0, epoch: 43, iter: 1, loss: 1.4032
# restart: 0, epoch: 44, iter: 1, loss: 1.4021
# restart: 0, epoch: 45, iter: 1, loss: 1.4010
# restart: 0, epoch: 46, iter: 1, loss: 1.3999
# restart: 0, epoch: 47, iter: 1, loss: 1.3988
# restart: 0, epoch: 48, iter: 1, loss: 1.3978
# restart: 0, epoch: 49, iter: 1, loss: 1.3967
# restart: 0, epoch: 50, iter: 1, loss: 1.3957
# restart: 0, epoch: 51, iter: 1, loss: 1.3946
# restart: 0, epoch: 52, iter: 1, loss: 1.3936
# restart: 0, epoch: 53, iter: 1, loss: 1.3926
# restart: 0, epoch: 54, iter: 1, loss: 1.3916
# restart: 0, epoch: 55, iter: 1, loss: 1.3906
# restart: 0, epoch: 56, iter: 1, loss: 1.3896
# restart: 0, epoch: 57, iter: 1, loss: 1.3886
# restart: 0, epoch: 58, iter: 1, loss: 1.3876
# restart: 0, epoch: 59, iter: 1, loss: 1.3866
# restart: 0, epoch: 60, iter: 1, loss: 1.3857
# restart: 0, epoch: 61, iter: 1, loss: 1.3847
# restart: 0, epoch: 62, iter: 1, loss: 1.3838
# restart: 0, epoch: 63, iter: 1, loss: 1.3829
# restart: 0, epoch: 64, iter: 1, loss: 1.3819
# restart: 0, epoch: 65, iter: 1, loss: 1.3810
# restart: 0, epoch: 66, iter: 1, loss: 1.3801
# restart: 0, epoch: 67, iter: 1, loss: 1.3792
# restart: 0, epoch: 68, iter: 1, loss: 1.3783
# restart: 0, epoch: 69, iter: 1, loss: 1.3775
# restart: 0, epoch: 70, iter: 1, loss: 1.3766
# restart: 0, epoch: 71, iter: 1, loss: 1.3757
# restart: 0, epoch: 72, iter: 1, loss: 1.3749
# restart: 0, epoch: 73, iter: 1, loss: 1.3741
# restart: 0, epoch: 74, iter: 1, loss: 1.3732
# restart: 0, epoch: 75, iter: 1, loss: 1.3724
# restart: 0, epoch: 76, iter: 1, loss: 1.3716
# restart: 0, epoch: 77, iter: 1, loss: 1.3708
# restart: 0, epoch: 78, iter: 1, loss: 1.3700
# restart: 0, epoch: 79, iter: 1, loss: 1.3692
# restart: 0, epoch: 80, iter: 1, loss: 1.3684
# restart: 0, epoch: 81, iter: 1, loss: 1.3676
# restart: 0, epoch: 82, iter: 1, loss: 1.3669
# restart: 0, epoch: 83, iter: 1, loss: 1.3661
# restart: 0, epoch: 84, iter: 1, loss: 1.3653
# restart: 0, epoch: 85, iter: 1, loss: 1.3646
# restart: 0, epoch: 86, iter: 1, loss: 1.3639
# restart: 0, epoch: 87, iter: 1, loss: 1.3631
# restart: 0, epoch: 88, iter: 1, loss: 1.3624
# restart: 0, epoch: 89, iter: 1, loss: 1.3617
# restart: 0, epoch: 90, iter: 1, loss: 1.3610
# restart: 0, epoch: 91, iter: 1, loss: 1.3603
# restart: 0, epoch: 197, iter: 1, loss: 1.3085
# restart: 0, epoch: 198, iter: 1, loss: 1.3081
# restart: 0, epoch: 199, iter: 1, loss: 1.3078
# restart: 0, epoch: 200, iter: 1, loss: 1.3074
# restart: 0, epoch: 201, iter: 1, loss: 1.3071
# restart: 0, epoch: 202, iter: 1, loss: 1.3067
# restart: 0, epoch: 203, iter: 1, loss: 1.3063
# restart: 0, epoch: 204, iter: 1, loss: 1.3060
# restart: 0, epoch: 205, iter: 1, loss: 1.3056
# restart: 0, epoch: 206, iter: 1, loss: 1.3053
# restart: 0, epoch: 207, iter: 1, loss: 1.3049
# restart: 0, epoch: 208, iter: 1, loss: 1.3046
# restart: 0, epoch: 209, iter: 1, loss: 1.3042
# restart: 0, epoch: 210, iter: 1, loss: 1.3038
# restart: 0, epoch: 211, iter: 1, loss: 1.3035
# restart: 0, epoch: 212, iter: 1, loss: 1.3032
# restart: 0, epoch: 213, iter: 1, loss: 1.3028
# restart: 0, epoch: 214, iter: 1, loss: 1.3025
# restart: 0, epoch: 215, iter: 1, loss: 1.3021
# restart: 0, epoch: 216, iter: 1, loss: 1.3018
# restart: 0, epoch: 217, iter: 1, loss: 1.3014
# restart: 0, epoch: 218, iter: 1, loss: 1.3011
# restart: 0, epoch: 219, iter: 1, loss: 1.3007
# restart: 0, epoch: 220, iter: 1, loss: 1.3004
# restart: 0, epoch: 221, iter: 1, loss: 1.3001
# restart: 0, epoch: 222, iter: 1, loss: 1.2997
# restart: 0, epoch: 223, iter: 1, loss: 1.2994
# restart: 0, epoch: 224, iter: 1, loss: 1.2990
# restart: 0, epoch: 225, iter: 1, loss: 1.2987
# restart: 0, epoch: 226, iter: 1, loss: 1.2984
# restart: 0, epoch: 227, iter: 1, loss: 1.2980
# restart: 0, epoch: 228, iter: 1, loss: 1.2977
# restart: 0, epoch: 229, iter: 1, loss: 1.2974
# restart: 0, epoch: 230, iter: 1, loss: 1.2970
# restart: 0, epoch: 231, iter: 1, loss: 1.2967
# restart: 0, epoch: 232, iter: 1, loss: 1.2964
# restart: 0, epoch: 233, iter: 1, loss: 1.2961
# restart: 0, epoch: 234, iter: 1, loss: 1.2957
# restart: 0, epoch: 235, iter: 1, loss: 1.2954
# restart: 0, epoch: 236, iter: 1, loss: 1.2951
# restart: 0, epoch: 237, iter: 1, loss: 1.2948
# restart: 0, epoch: 238, iter: 1, loss: 1.2944
# restart: 0, epoch: 239, iter: 1, loss: 1.2941
# restart: 0, epoch: 240, iter: 1, loss: 1.2938
# restart: 0, epoch: 241, iter: 1, loss: 1.2935
# restart: 0, epoch: 242, iter: 1, loss: 1.2932
# restart: 0, epoch: 243, iter: 1, loss: 1.2928
# restart: 0, epoch: 244, iter: 1, loss: 1.2925
# restart: 0, epoch: 245, iter: 1, loss: 1.2922
# restart: 0, epoch: 246, iter: 1, loss: 1.2919
# restart: 0, epoch: 247, iter: 1, loss: 1.2916
# restart: 0, epoch: 248, iter: 1, loss: 1.2912
# restart: 0, epoch: 249, iter: 1, loss: 1.2909
# restart: 0, epoch: 250, iter: 1, loss: 1.2906
# restart: 0, epoch: 251, iter: 1, loss: 1.2903
# restart: 0, epoch: 252, iter: 1, loss: 1.2900
# restart: 0, epoch: 253, iter: 1, loss: 1.2897
# restart: 0, epoch: 254, iter: 1, loss: 1.2894
# restart: 0, epoch: 255, iter: 1, loss: 1.2891
# restart: 0, epoch: 256, iter: 1, loss: 1.2887
# restart: 0, epoch: 257, iter: 1, loss: 1.2884
# restart: 0, epoch: 258, iter: 1, loss: 1.2881
# restart: 0, epoch: 259, iter: 1, loss: 1.2878
# restart: 0, epoch: 260, iter: 1, loss: 1.2875
# restart: 0, epoch: 261, iter: 1, loss: 1.2872
# restart: 0, epoch: 262, iter: 1, loss: 1.2869
# restart: 0, epoch: 263, iter: 1, loss: 1.2866
# restart: 0, epoch: 264, iter: 1, loss: 1.2863
# restart: 0, epoch: 265, iter: 1, loss: 1.2860
# restart: 0, epoch: 266, iter: 1, loss: 1.2857
# restart: 0, epoch: 267, iter: 1, loss: 1.2854
# restart: 0, epoch: 268, iter: 1, loss: 1.2851
# restart: 0, epoch: 269, iter: 1, loss: 1.2848
# restart: 0, epoch: 270, iter: 1, loss: 1.2845
# restart: 0, epoch: 271, iter: 1, loss: 1.2842
# restart: 0, epoch: 272, iter: 1, loss: 1.2838
# restart: 0, epoch: 273, iter: 1, loss: 1.2835
# restart: 0, epoch: 274, iter: 1, loss: 1.2832
# restart: 0, epoch: 275, iter: 1, loss: 1.2829
# restart: 0, epoch: 276, iter: 1, loss: 1.2826
# restart: 0, epoch: 277, iter: 1, loss: 1.2823
# restart: 0, epoch: 278, iter: 1, loss: 1.2821
# restart: 0, epoch: 279, iter: 1, loss: 1.2818
# restart: 0, epoch: 280, iter: 1, loss: 1.2815
# restart: 0, epoch: 281, iter: 1, loss: 1.2812
# restart: 0, epoch: 282, iter: 1, loss: 1.2809
# restart: 0, epoch: 283, iter: 1, loss: 1.2806
# restart: 0, epoch: 284, iter: 1, loss: 1.2803
# restart: 0, epoch: 285, iter: 1, loss: 1.2800
# restart: 0, epoch: 286, iter: 1, loss: 1.2797
# restart: 0, epoch: 287, iter: 1, loss: 1.2794
# restart: 0, epoch: 288, iter: 1, loss: 1.2791
# restart: 0, epoch: 289, iter: 1, loss: 1.2788
# restart: 0, epoch: 290, iter: 1, loss: 1.2785
# restart: 0, epoch: 291, iter: 1, loss: 1.2782
# restart: 0, epoch: 292, iter: 1, loss: 1.2779
# restart: 0, epoch: 293, iter: 1, loss: 1.2776
# restart: 0, epoch: 294, iter: 1, loss: 1.2773
# restart: 0, epoch: 295, iter: 1, loss: 1.2771
# restart: 0, epoch: 296, iter: 1, loss: 1.2768
# restart: 0, epoch: 297, iter: 1, loss: 1.2765
# restart: 0, epoch: 298, iter: 1, loss: 1.2762
# restart: 0, epoch: 299, iter: 1, loss: 1.2759
# restart: 0, epoch: 300, iter: 1, loss: 1.2756
# restart: 0, epoch: 301, iter: 1, loss: 1.2753
# restart: 0, epoch: 302, iter: 1, loss: 1.2750
# restart: 0, epoch: 303, iter: 1, loss: 1.2748
# restart: 0, epoch: 304, iter: 1, loss: 1.2745
# restart: 0, epoch: 305, iter: 1, loss: 1.2742
# restart: 0, epoch: 306, iter: 1, loss: 1.2739
# restart: 0, epoch: 307, iter: 1, loss: 1.2736
# restart: 0, epoch: 308, iter: 1, loss: 1.2733
# restart: 0, epoch: 309, iter: 1, loss: 1.2730
# restart: 0, epoch: 310, iter: 1, loss: 1.2728
# restart: 0, epoch: 311, iter: 1, loss: 1.2725
# restart: 0, epoch: 312, iter: 1, loss: 1.2722
# restart: 0, epoch: 313, iter: 1, loss: 1.2719
# restart: 0, epoch: 314, iter: 1, loss: 1.2716
# restart: 0, epoch: 315, iter: 1, loss: 1.2713
# restart: 0, epoch: 316, iter: 1, loss: 1.2711
# restart: 0, epoch: 317, iter: 1, loss: 1.2708
# restart: 0, epoch: 318, iter: 1, loss: 1.2705
# restart: 0, epoch: 319, iter: 1, loss: 1.2702
# restart: 0, epoch: 320, iter: 1, loss: 1.2699
# restart: 0, epoch: 321, iter: 1, loss: 1.2697
# restart: 0, epoch: 322, iter: 1, loss: 1.2694
# restart: 0, epoch: 323, iter: 1, loss: 1.2691
# restart: 0, epoch: 324, iter: 1, loss: 1.2688
# restart: 0, epoch: 325, iter: 1, loss: 1.2685
# restart: 0, epoch: 326, iter: 1, loss: 1.2682
# restart: 0, epoch: 327, iter: 1, loss: 1.2680
# restart: 0, epoch: 328, iter: 1, loss: 1.2677
# restart: 0, epoch: 329, iter: 1, loss: 1.2674
# restart: 0, epoch: 330, iter: 1, loss: 1.2671
# restart: 0, epoch: 331, iter: 1, loss: 1.2668
# restart: 0, epoch: 332, iter: 1, loss: 1.2666
# restart: 0, epoch: 333, iter: 1, loss: 1.2663
# restart: 0, epoch: 334, iter: 1, loss: 1.2660
# restart: 0, epoch: 335, iter: 1, loss: 1.2657
# restart: 0, epoch: 336, iter: 1, loss: 1.2654
# restart: 0, epoch: 337, iter: 1, loss: 1.2652
# restart: 0, epoch: 338, iter: 1, loss: 1.2649
# restart: 0, epoch: 339, iter: 1, loss: 1.2646
# restart: 0, epoch: 340, iter: 1, loss: 1.2643
# restart: 0, epoch: 341, iter: 1, loss: 1.2641
# restart: 0, epoch: 342, iter: 1, loss: 1.2638
# restart: 0, epoch: 343, iter: 1, loss: 1.2635
# restart: 0, epoch: 344, iter: 1, loss: 1.2632
# restart: 0, epoch: 345, iter: 1, loss: 1.2629
# restart: 0, epoch: 346, iter: 1, loss: 1.2627
# restart: 0, epoch: 347, iter: 1, loss: 1.2624
# restart: 0, epoch: 348, iter: 1, loss: 1.2621
# restart: 0, epoch: 349, iter: 1, loss: 1.2618
# restart: 0, epoch: 350, iter: 1, loss: 1.2616
# restart: 0, epoch: 351, iter: 1, loss: 1.2613
# restart: 0, epoch: 352, iter: 1, loss: 1.2610
# restart: 0, epoch: 353, iter: 1, loss: 1.2607
# restart: 0, epoch: 354, iter: 1, loss: 1.2605
# restart: 0, epoch: 460, iter: 1, loss: 1.2320
# restart: 0, epoch: 461, iter: 1, loss: 1.2317
# restart: 0, epoch: 462, iter: 1, loss: 1.2314
# restart: 0, epoch: 463, iter: 1, loss: 1.2312
# restart: 0, epoch: 464, iter: 1, loss: 1.2309
# restart: 0, epoch: 465, iter: 1, loss: 1.2306
# restart: 0, epoch: 466, iter: 1, loss: 1.2304
# restart: 0, epoch: 467, iter: 1, loss: 1.2301
# restart: 0, epoch: 468, iter: 1, loss: 1.2298
# restart: 0, epoch: 469, iter: 1, loss: 1.2296
# restart: 0, epoch: 470, iter: 1, loss: 1.2293
# restart: 0, epoch: 471, iter: 1, loss: 1.2290
# restart: 0, epoch: 472, iter: 1, loss: 1.2288
# restart: 0, epoch: 473, iter: 1, loss: 1.2285
# restart: 0, epoch: 474, iter: 1, loss: 1.2283
# restart: 0, epoch: 475, iter: 1, loss: 1.2280
# restart: 0, epoch: 476, iter: 1, loss: 1.2277
# restart: 0, epoch: 477, iter: 1, loss: 1.2275
# restart: 0, epoch: 478, iter: 1, loss: 1.2272
# restart: 0, epoch: 479, iter: 1, loss: 1.2269
# restart: 0, epoch: 480, iter: 1, loss: 1.2267
# restart: 0, epoch: 481, iter: 1, loss: 1.2264
# restart: 0, epoch: 482, iter: 1, loss: 1.2262
# restart: 0, epoch: 483, iter: 1, loss: 1.2259
# restart: 0, epoch: 484, iter: 1, loss: 1.2256
# restart: 0, epoch: 485, iter: 1, loss: 1.2254
# restart: 0, epoch: 486, iter: 1, loss: 1.2251
# restart: 0, epoch: 487, iter: 1, loss: 1.2249
# restart: 0, epoch: 488, iter: 1, loss: 1.2246
# restart: 0, epoch: 489, iter: 1, loss: 1.2243
# restart: 0, epoch: 490, iter: 1, loss: 1.2241
# restart: 0, epoch: 491, iter: 1, loss: 1.2238
# restart: 0, epoch: 492, iter: 1, loss: 1.2235
# restart: 0, epoch: 493, iter: 1, loss: 1.2233
# restart: 0, epoch: 494, iter: 1, loss: 1.2230
# restart: 0, epoch: 495, iter: 1, loss: 1.2228
# restart: 0, epoch: 496, iter: 1, loss: 1.2225
# restart: 0, epoch: 497, iter: 1, loss: 1.2222
# restart: 0, epoch: 498, iter: 1, loss: 1.2220
# restart: 0, epoch: 499, iter: 1, loss: 1.2217
# restart: 0, epoch: 500, iter: 1, loss: 1.2215
# restart: 0, epoch: 501, iter: 1, loss: 1.2212
# restart: 0, epoch: 502, iter: 1, loss: 1.2210
# restart: 0, epoch: 503, iter: 1, loss: 1.2207
# restart: 0, epoch: 504, iter: 1, loss: 1.2204
# restart: 0, epoch: 505, iter: 1, loss: 1.2202
# restart: 0, epoch: 506, iter: 1, loss: 1.2199
# restart: 0, epoch: 507, iter: 1, loss: 1.2197
# restart: 0, epoch: 508, iter: 1, loss: 1.2194
# restart: 0, epoch: 509, iter: 1, loss: 1.2191
# restart: 0, epoch: 510, iter: 1, loss: 1.2189
# restart: 0, epoch: 511, iter: 1, loss: 1.2186
# restart: 0, epoch: 512, iter: 1, loss: 1.2184
# restart: 0, epoch: 513, iter: 1, loss: 1.2181
# restart: 0, epoch: 514, iter: 1, loss: 1.2178
# restart: 0, epoch: 515, iter: 1, loss: 1.2176
# restart: 0, epoch: 516, iter: 1, loss: 1.2173
# restart: 0, epoch: 517, iter: 1, loss: 1.2171
# restart: 0, epoch: 518, iter: 1, loss: 1.2168
# restart: 0, epoch: 519, iter: 1, loss: 1.2166
# restart: 0, epoch: 520, iter: 1, loss: 1.2163
# restart: 0, epoch: 521, iter: 1, loss: 1.2160
# restart: 0, epoch: 522, iter: 1, loss: 1.2158
# restart: 0, epoch: 523, iter: 1, loss: 1.2155
# restart: 0, epoch: 524, iter: 1, loss: 1.2153
# restart: 0, epoch: 525, iter: 1, loss: 1.2150
# restart: 0, epoch: 526, iter: 1, loss: 1.2148
# restart: 0, epoch: 527, iter: 1, loss: 1.2145
# restart: 0, epoch: 528, iter: 1, loss: 1.2142
# restart: 0, epoch: 529, iter: 1, loss: 1.2140
# restart: 0, epoch: 530, iter: 1, loss: 1.2137
# restart: 0, epoch: 531, iter: 1, loss: 1.2135
# restart: 0, epoch: 532, iter: 1, loss: 1.2132
# restart: 0, epoch: 533, iter: 1, loss: 1.2130
# restart: 0, epoch: 534, iter: 1, loss: 1.2127
# restart: 0, epoch: 535, iter: 1, loss: 1.2124
# restart: 0, epoch: 536, iter: 1, loss: 1.2122
# restart: 0, epoch: 537, iter: 1, loss: 1.2119
# restart: 0, epoch: 538, iter: 1, loss: 1.2117
# restart: 0, epoch: 539, iter: 1, loss: 1.2114
# restart: 0, epoch: 540, iter: 1, loss: 1.2112
# restart: 0, epoch: 541, iter: 1, loss: 1.2109
# restart: 0, epoch: 542, iter: 1, loss: 1.2106
# restart: 0, epoch: 543, iter: 1, loss: 1.2104
# restart: 0, epoch: 544, iter: 1, loss: 1.2101
# restart: 0, epoch: 545, iter: 1, loss: 1.2099
# restart: 0, epoch: 546, iter: 1, loss: 1.2096
# restart: 0, epoch: 547, iter: 1, loss: 1.2094
# restart: 0, epoch: 548, iter: 1, loss: 1.2091
# restart: 0, epoch: 549, iter: 1, loss: 1.2089
# restart: 0, epoch: 550, iter: 1, loss: 1.2086
# restart: 0, epoch: 551, iter: 1, loss: 1.2083
# restart: 0, epoch: 552, iter: 1, loss: 1.2081
# restart: 0, epoch: 553, iter: 1, loss: 1.2078
# restart: 0, epoch: 554, iter: 1, loss: 1.2076
# restart: 0, epoch: 555, iter: 1, loss: 1.2073
# restart: 0, epoch: 556, iter: 1, loss: 1.2070
# restart: 0, epoch: 557, iter: 1, loss: 1.2068
# restart: 0, epoch: 558, iter: 1, loss: 1.2065
# restart: 0, epoch: 559, iter: 1, loss: 1.2063
# restart: 0, epoch: 560, iter: 1, loss: 1.2060
# restart: 0, epoch: 561, iter: 1, loss: 1.2058
# restart: 0, epoch: 562, iter: 1, loss: 1.2055
# restart: 0, epoch: 563, iter: 1, loss: 1.2052
# restart: 0, epoch: 564, iter: 1, loss: 1.2050
# restart: 0, epoch: 932, iter: 1, loss: 1.1062
# restart: 0, epoch: 933, iter: 1, loss: 1.1059
# restart: 0, epoch: 934, iter: 1, loss: 1.1056
# restart: 0, epoch: 935, iter: 1, loss: 1.1053
# restart: 0, epoch: 936, iter: 1, loss: 1.1051
# restart: 0, epoch: 937, iter: 1, loss: 1.1048
# restart: 0, epoch: 938, iter: 1, loss: 1.1045
# restart: 0, epoch: 939, iter: 1, loss: 1.1042
# restart: 0, epoch: 940, iter: 1, loss: 1.1039
# restart: 0, epoch: 941, iter: 1, loss: 1.1036
# restart: 0, epoch: 942, iter: 1, loss: 1.1034
# restart: 0, epoch: 943, iter: 1, loss: 1.1031
# restart: 0, epoch: 944, iter: 1, loss: 1.1028
# restart: 0, epoch: 945, iter: 1, loss: 1.1025
# restart: 0, epoch: 946, iter: 1, loss: 1.1023
# restart: 0, epoch: 947, iter: 1, loss: 1.1020
# restart: 0, epoch: 948, iter: 1, loss: 1.1018
# restart: 0, epoch: 949, iter: 1, loss: 1.1015
# restart: 0, epoch: 950, iter: 1, loss: 1.1012
# restart: 0, epoch: 951, iter: 1, loss: 1.1009
# restart: 0, epoch: 952, iter: 1, loss: 1.1006
# restart: 0, epoch: 953, iter: 1, loss: 1.1003
# restart: 0, epoch: 954, iter: 1, loss: 1.1000
# restart: 0, epoch: 955, iter: 1, loss: 1.0998
# restart: 0, epoch: 956, iter: 1, loss: 1.0995
# restart: 0, epoch: 957, iter: 1, loss: 1.0992
# restart: 0, epoch: 958, iter: 1, loss: 1.0989
# restart: 0, epoch: 959, iter: 1, loss: 1.0987
# restart: 0, epoch: 960, iter: 1, loss: 1.0984
# restart: 0, epoch: 961, iter: 1, loss: 1.0981
# restart: 0, epoch: 962, iter: 1, loss: 1.0978
# restart: 0, epoch: 963, iter: 1, loss: 1.0975
# restart: 0, epoch: 964, iter: 1, loss: 1.0972
# restart: 0, epoch: 965, iter: 1, loss: 1.0970
# restart: 0, epoch: 966, iter: 1, loss: 1.0967
# restart: 0, epoch: 967, iter: 1, loss: 1.0964
# restart: 0, epoch: 968, iter: 1, loss: 1.0961
# restart: 0, epoch: 969, iter: 1, loss: 1.0959
# restart: 0, epoch: 970, iter: 1, loss: 1.0956
# restart: 0, epoch: 971, iter: 1, loss: 1.0953
# restart: 0, epoch: 972, iter: 1, loss: 1.0950
# restart: 0, epoch: 973, iter: 1, loss: 1.0947
# restart: 0, epoch: 974, iter: 1, loss: 1.0945
# restart: 0, epoch: 975, iter: 1, loss: 1.0942
# restart: 0, epoch: 976, iter: 1, loss: 1.0939
# restart: 0, epoch: 977, iter: 1, loss: 1.0936
# restart: 0, epoch: 978, iter: 1, loss: 1.0933
# restart: 0, epoch: 979, iter: 1, loss: 1.0931
# restart: 0, epoch: 980, iter: 1, loss: 1.0928
# restart: 0, epoch: 981, iter: 1, loss: 1.0925
# restart: 0, epoch: 982, iter: 1, loss: 1.0922
# restart: 0, epoch: 983, iter: 1, loss: 1.0920
# restart: 0, epoch: 984, iter: 1, loss: 1.0917
# restart: 0, epoch: 985, iter: 1, loss: 1.0914
# restart: 0, epoch: 986, iter: 1, loss: 1.0911
# restart: 0, epoch: 987, iter: 1, loss: 1.0909
# restart: 0, epoch: 988, iter: 1, loss: 1.0906
# restart: 0, epoch: 989, iter: 1, loss: 1.0903
# restart: 0, epoch: 990, iter: 1, loss: 1.0900
# restart: 0, epoch: 991, iter: 1, loss: 1.0897
# restart: 0, epoch: 992, iter: 1, loss: 1.0895
# restart: 0, epoch: 993, iter: 1, loss: 1.0892
# restart: 0, epoch: 994, iter: 1, loss: 1.0889
# restart: 0, epoch: 995, iter: 1, loss: 1.0886
# restart: 0, epoch: 996, iter: 1, loss: 1.0884
# restart: 0, epoch: 997, iter: 1, loss: 1.0881
# restart: 0, epoch: 998, iter: 1, loss: 1.0878
# restart: 0, epoch: 999, iter: 1, loss: 1.0876
# restart: 0, epoch: 1000, iter: 1, loss: 1.0873
# restart: 0, epoch: 1001, iter: 1, loss: 1.0870
# restart: 0, epoch: 1002, iter: 1, loss: 1.0867
# restart: 0, epoch: 1003, iter: 1, loss: 1.0864
# restart: 0, epoch: 1004, iter: 1, loss: 1.0862
# restart: 0, epoch: 1005, iter: 1, loss: 1.0859
# restart: 0, epoch: 1006, iter: 1, loss: 1.0856
# restart: 0, epoch: 1007, iter: 1, loss: 1.0853
# restart: 0, epoch: 1008, iter: 1, loss: 1.0851
# restart: 0, epoch: 1009, iter: 1, loss: 1.0848
# restart: 0, epoch: 1010, iter: 1, loss: 1.0845
# restart: 0, epoch: 1011, iter: 1, loss: 1.0842
# restart: 0, epoch: 1012, iter: 1, loss: 1.0839
# restart: 0, epoch: 1013, iter: 1, loss: 1.0837
# restart: 0, epoch: 1014, iter: 1, loss: 1.0834
# restart: 0, epoch: 1015, iter: 1, loss: 1.0831
# restart: 0, epoch: 1016, iter: 1, loss: 1.0829
# restart: 0, epoch: 1017, iter: 1, loss: 1.0826
# restart: 0, epoch: 1018, iter: 1, loss: 1.0823
# restart: 0, epoch: 1019, iter: 1, loss: 1.0821
# restart: 0, epoch: 1020, iter: 1, loss: 1.0818
# restart: 0, epoch: 1021, iter: 1, loss: 1.0815
# restart: 0, epoch: 1022, iter: 1, loss: 1.0813
# restart: 0, epoch: 1023, iter: 1, loss: 1.0810
# restart: 0, epoch: 1024, iter: 1, loss: 1.0807
# restart: 0, epoch: 1025, iter: 1, loss: 1.0804
# restart: 0, epoch: 1026, iter: 1, loss: 1.0801
# restart: 0, epoch: 1027, iter: 1, loss: 1.0799
# restart: 0, epoch: 1028, iter: 1, loss: 1.0796
# restart: 0, epoch: 1029, iter: 1, loss: 1.0793
# restart: 0, epoch: 1030, iter: 1, loss: 1.0790
# restart: 0, epoch: 1031, iter: 1, loss: 1.0788
# restart: 0, epoch: 1032, iter: 1, loss: 1.0785
# restart: 0, epoch: 1033, iter: 1, loss: 1.0782
# restart: 0, epoch: 1034, iter: 1, loss: 1.0779
# restart: 0, epoch: 1035, iter: 1, loss: 1.0777
# restart: 0, epoch: 1036, iter: 1, loss: 1.0774
# restart: 0, epoch: 1037, iter: 1, loss: 1.0771
# restart: 0, epoch: 1038, iter: 1, loss: 1.0768
# restart: 0, epoch: 1039, iter: 1, loss: 1.0766
# restart: 0, epoch: 1040, iter: 1, loss: 1.0763
# restart: 0, epoch: 1041, iter: 1, loss: 1.0760
# restart: 0, epoch: 1042, iter: 1, loss: 1.0758
# restart: 0, epoch: 1043, iter: 1, loss: 1.0755
# restart: 0, epoch: 1044, iter: 1, loss: 1.0752
# ...
# restart: 0, epoch: 1661, iter: 1, loss: 0.9320
# restart: 0, epoch: 1662, iter: 1, loss: 0.9318
# restart: 0, epoch: 1663, iter: 1, loss: 0.9316
# restart: 0, epoch: 1664, iter: 1, loss: 0.9314
# restart: 0, epoch: 1665, iter: 1, loss: 0.9312
# restart: 0, epoch: 1666, iter: 1, loss: 0.9310
# restart: 0, epoch: 1667, iter: 1, loss: 0.9309
# restart: 0, epoch: 1668, iter: 1, loss: 0.9307
# restart: 0, epoch: 1669, iter: 1, loss: 0.9305
# restart: 0, epoch: 1670, iter: 1, loss: 0.9304
# restart: 0, epoch: 1671, iter: 1, loss: 0.9302
# restart: 0, epoch: 1672, iter: 1, loss: 0.9300
# restart: 0, epoch: 1673, iter: 1, loss: 0.9298
# restart: 0, epoch: 1674, iter: 1, loss: 0.9296
# restart: 0, epoch: 1675, iter: 1, loss: 0.9294
# restart: 0, epoch: 1676, iter: 1, loss: 0.9292
# restart: 0, epoch: 1677, iter: 1, loss: 0.9291
# restart: 0, epoch: 1678, iter: 1, loss: 0.9289
# restart: 0, epoch: 1679, iter: 1, loss: 0.9287
# restart: 0, epoch: 1680, iter: 1, loss: 0.9285
# restart: 0, epoch: 1681, iter: 1, loss: 0.9283
# restart: 0, epoch: 1682, iter: 1, loss: 0.9282
# restart: 0, epoch: 1683, iter: 1, loss: 0.9280
# restart: 0, epoch: 1684, iter: 1, loss: 0.9278
# restart: 0, epoch: 1685, iter: 1, loss: 0.9276
# restart: 0, epoch: 1686, iter: 1, loss: 0.9274
# restart: 0, epoch: 1687, iter: 1, loss: 0.9272
# restart: 0, epoch: 1688, iter: 1, loss: 0.9271
# restart: 0, epoch: 1689, iter: 1, loss: 0.9269
# restart: 0, epoch: 1690, iter: 1, loss: 0.9267
# restart: 0, epoch: 1691, iter: 1, loss: 0.9266
# restart: 0, epoch: 1692, iter: 1, loss: 0.9264
# restart: 0, epoch: 1693, iter: 1, loss: 0.9262
# restart: 0, epoch: 1694, iter: 1, loss: 0.9260
# restart: 0, epoch: 1695, iter: 1, loss: 0.9258
# restart: 0, epoch: 1696, iter: 1, loss: 0.9257
# restart: 0, epoch: 1697, iter: 1, loss: 0.9255
# restart: 0, epoch: 1698, iter: 1, loss: 0.9253
# restart: 0, epoch: 1699, iter: 1, loss: 0.9251
# restart: 0, epoch: 1700, iter: 1, loss: 0.9250
# restart: 0, epoch: 1701, iter: 1, loss: 0.9248
# restart: 0, epoch: 1702, iter: 1, loss: 0.9246
# restart: 0, epoch: 1703, iter: 1, loss: 0.9244
# restart: 0, epoch: 1704, iter: 1, loss: 0.9242
# restart: 0, epoch: 1705, iter: 1, loss: 0.9241
# restart: 0, epoch: 1706, iter: 1, loss: 0.9239
# restart: 0, epoch: 1707, iter: 1, loss: 0.9237
# restart: 0, epoch: 1708, iter: 1, loss: 0.9236
# restart: 0, epoch: 1709, iter: 1, loss: 0.9234
# restart: 0, epoch: 1710, iter: 1, loss: 0.9232
# restart: 0, epoch: 1711, iter: 1, loss: 0.9230
# restart: 0, epoch: 1712, iter: 1, loss: 0.9229
# restart: 0, epoch: 1713, iter: 1, loss: 0.9227
# restart: 0, epoch: 1714, iter: 1, loss: 0.9225
# restart: 0, epoch: 1715, iter: 1, loss: 0.9224
# restart: 0, epoch: 1716, iter: 1, loss: 0.9222
# restart: 0, epoch: 1717, iter: 1, loss: 0.9220
# restart: 0, epoch: 1718, iter: 1, loss: 0.9218
# restart: 0, epoch: 1719, iter: 1, loss: 0.9216
# restart: 0, epoch: 1720, iter: 1, loss: 0.9215
# restart: 0, epoch: 1721, iter: 1, loss: 0.9213
# restart: 0, epoch: 1722, iter: 1, loss: 0.9211
# restart: 0, epoch: 1723, iter: 1, loss: 0.9210
# restart: 0, epoch: 1724, iter: 1, loss: 0.9208
# restart: 0, epoch: 1725, iter: 1, loss: 0.9206
# restart: 0, epoch: 1726, iter: 1, loss: 0.9205
# restart: 0, epoch: 1727, iter: 1, loss: 0.9203
# restart: 0, epoch: 1728, iter: 1, loss: 0.9201
# restart: 0, epoch: 1729, iter: 1, loss: 0.9199
# restart: 0, epoch: 1730, iter: 1, loss: 0.9198
# restart: 0, epoch: 1731, iter: 1, loss: 0.9196
# restart: 0, epoch: 1732, iter: 1, loss: 0.9194
# restart: 0, epoch: 1733, iter: 1, loss: 0.9193
# restart: 0, epoch: 1734, iter: 1, loss: 0.9191
# restart: 0, epoch: 1735, iter: 1, loss: 0.9189
# restart: 0, epoch: 1736, iter: 1, loss: 0.9188
# restart: 0, epoch: 1737, iter: 1, loss: 0.9186
# restart: 0, epoch: 1738, iter: 1, loss: 0.9185
# restart: 0, epoch: 1739, iter: 1, loss: 0.9183
# restart: 0, epoch: 1740, iter: 1, loss: 0.9181
# restart: 0, epoch: 1741, iter: 1, loss: 0.9179
# restart: 0, epoch: 1742, iter: 1, loss: 0.9177
# restart: 0, epoch: 1743, iter: 1, loss: 0.9176
# restart: 0, epoch: 1744, iter: 1, loss: 0.9174
# restart: 0, epoch: 1745, iter: 1, loss: 0.9173
# restart: 0, epoch: 1746, iter: 1, loss: 0.9171
# restart: 0, epoch: 1747, iter: 1, loss: 0.9170
# restart: 0, epoch: 1748, iter: 1, loss: 0.9168
# restart: 0, epoch: 1749, iter: 1, loss: 0.9167
# restart: 0, epoch: 1750, iter: 1, loss: 0.9165
# restart: 0, epoch: 1751, iter: 1, loss: 0.9163
# restart: 0, epoch: 1752, iter: 1, loss: 0.9161
# restart: 0, epoch: 1753, iter: 1, loss: 0.9159
# restart: 0, epoch: 1804, iter: 1, loss: 0.9077
# restart: 0, epoch: 1805, iter: 1, loss: 0.9076
# restart: 0, epoch: 1806, iter: 1, loss: 0.9074
# restart: 0, epoch: 1807, iter: 1, loss: 0.9073
# restart: 0, epoch: 1808, iter: 1, loss: 0.9071
# restart: 0, epoch: 1809, iter: 1, loss: 0.9070
# restart: 0, epoch: 1810, iter: 1, loss: 0.9068
# restart: 0, epoch: 1811, iter: 1, loss: 0.9066
# restart: 0, epoch: 1812, iter: 1, loss: 0.9065
# restart: 0, epoch: 1813, iter: 1, loss: 0.9063
# restart: 0, epoch: 1814, iter: 1, loss: 0.9062
# restart: 0, epoch: 1815, iter: 1, loss: 0.9060
# restart: 0, epoch: 1816, iter: 1, loss: 0.9058
# restart: 0, epoch: 1817, iter: 1, loss: 0.9057
# restart: 0, epoch: 1818, iter: 1, loss: 0.9056
# restart: 0, epoch: 1819, iter: 1, loss: 0.9055
# restart: 0, epoch: 1820, iter: 1, loss: 0.9053
# restart: 0, epoch: 1821, iter: 1, loss: 0.9052
# restart: 0, epoch: 1822, iter: 1, loss: 0.9050
# restart: 0, epoch: 1823, iter: 1, loss: 0.9049
# restart: 0, epoch: 1824, iter: 1, loss: 0.9047
# restart: 0, epoch: 1825, iter: 1, loss: 0.9045
# restart: 0, epoch: 1826, iter: 1, loss: 0.9043
# restart: 0, epoch: 1827, iter: 1, loss: 0.9042
# restart: 0, epoch: 1828, iter: 1, loss: 0.9040
# restart: 0, epoch: 1829, iter: 1, loss: 0.9039
# restart: 0, epoch: 1830, iter: 1, loss: 0.9037
# restart: 0, epoch: 1831, iter: 1, loss: 0.9036
# restart: 0, epoch: 1832, iter: 1, loss: 0.9034
# restart: 0, epoch: 1833, iter: 1, loss: 0.9032
# restart: 0, epoch: 1834, iter: 1, loss: 0.9031
# restart: 0, epoch: 1835, iter: 1, loss: 0.9029
# restart: 0, epoch: 1836, iter: 1, loss: 0.9028
# restart: 0, epoch: 1837, iter: 1, loss: 0.9026
# restart: 0, epoch: 1838, iter: 1, loss: 0.9025
# restart: 0, epoch: 1839, iter: 1, loss: 0.9023
# restart: 0, epoch: 1840, iter: 1, loss: 0.9022
# restart: 0, epoch: 1841, iter: 1, loss: 0.9021
# restart: 0, epoch: 1842, iter: 1, loss: 0.9019
# restart: 0, epoch: 1843, iter: 1, loss: 0.9018
# restart: 0, epoch: 1844, iter: 1, loss: 0.9016
# restart: 0, epoch: 1845, iter: 1, loss: 0.9015
# restart: 0, epoch: 1846, iter: 1, loss: 0.9013
# restart: 0, epoch: 1847, iter: 1, loss: 0.9011
# restart: 0, epoch: 1848, iter: 1, loss: 0.9010
# restart: 0, epoch: 1849, iter: 1, loss: 0.9009
# restart: 0, epoch: 1850, iter: 1, loss: 0.9007
# restart: 0, epoch: 1851, iter: 1, loss: 0.9006
# restart: 0, epoch: 1852, iter: 1, loss: 0.9004
# restart: 0, epoch: 1853, iter: 1, loss: 0.9003
# restart: 0, epoch: 1854, iter: 1, loss: 0.9001
# restart: 0, epoch: 1957, iter: 1, loss: 0.8851
# restart: 0, epoch: 1958, iter: 1, loss: 0.8850
# restart: 0, epoch: 1959, iter: 1, loss: 0.8849
# restart: 0, epoch: 1960, iter: 1, loss: 0.8847
# restart: 0, epoch: 1961, iter: 1, loss: 0.8846
# restart: 0, epoch: 1962, iter: 1, loss: 0.8844
# restart: 0, epoch: 1963, iter: 1, loss: 0.8842
# restart: 0, epoch: 1964, iter: 1, loss: 0.8841
# restart: 0, epoch: 1965, iter: 1, loss: 0.8840
# restart: 0, epoch: 1966, iter: 1, loss: 0.8838
# restart: 0, epoch: 1967, iter: 1, loss: 0.8837
# restart: 0, epoch: 1968, iter: 1, loss: 0.8835
# restart: 0, epoch: 1969, iter: 1, loss: 0.8834
# restart: 0, epoch: 1970, iter: 1, loss: 0.8833
# restart: 0, epoch: 1971, iter: 1, loss: 0.8831
# restart: 0, epoch: 1972, iter: 1, loss: 0.8830
# restart: 0, epoch: 1973, iter: 1, loss: 0.8828
# restart: 0, epoch: 1974, iter: 1, loss: 0.8827
# restart: 0, epoch: 1975, iter: 1, loss: 0.8825
# restart: 0, epoch: 1976, iter: 1, loss: 0.8824
# restart: 0, epoch: 1977, iter: 1, loss: 0.8823
# restart: 0, epoch: 1978, iter: 1, loss: 0.8822
# restart: 0, epoch: 1979, iter: 1, loss: 0.8820
# restart: 0, epoch: 1980, iter: 1, loss: 0.8819
# restart: 0, epoch: 1981, iter: 1, loss: 0.8817
# restart: 0, epoch: 1982, iter: 1, loss: 0.8816
# restart: 0, epoch: 1983, iter: 1, loss: 0.8814
# restart: 0, epoch: 1984, iter: 1, loss: 0.8813
# restart: 0, epoch: 1985, iter: 1, loss: 0.8812
# restart: 0, epoch: 1986, iter: 1, loss: 0.8810
# restart: 0, epoch: 1987, iter: 1, loss: 0.8809
# restart: 0, epoch: 1988, iter: 1, loss: 0.8807
# restart: 0, epoch: 1989, iter: 1, loss: 0.8806
# restart: 0, epoch: 1990, iter: 1, loss: 0.8805
# restart: 0, epoch: 1991, iter: 1, loss: 0.8803
# restart: 0, epoch: 1992, iter: 1, loss: 0.8802
# restart: 0, epoch: 1993, iter: 1, loss: 0.8801
# restart: 0, epoch: 1994, iter: 1, loss: 0.8799
# restart: 0, epoch: 1995, iter: 1, loss: 0.8798
# restart: 0, epoch: 1996, iter: 1, loss: 0.8796
# restart: 0, epoch: 1997, iter: 1, loss: 0.8795
# restart: 0, epoch: 1998, iter: 1, loss: 0.8794
# restart: 0, epoch: 1999, iter: 1, loss: 0.8792
# restart: 0, epoch: 2000, iter: 1, loss: 0.8791

# %%
  model_name = "Refrigerator_trial_seq_time.pt"
  torch.save(model.state_dict(), os.path.join(
   "models/", model_name))

# %% [markdown]
# ## Decomp

# %%
kernel1 = ScaleKernel(RBFKernel(ard_num_dims=n))
# kernel2 = ScaleKernel(RBFKernel(ard_num_dims=1,active_dims=(99)))
# kernel3 = ScaleKernel(CosineKernel(ard_num_dims=1,active_dims=(99)))

# kernel4 = kernel2*kernel3
kernel = kernel1 #ernel4
# induce_points = 512
inducing_points =  x[np.arange(0,x.shape[0],70)] 
# inducing_points = x[torch.randperm(x.shape[0])[: 1500]]

model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                      inducing_points).to("cuda")

model_name =  "Refrigerator_rbf_building6_" + str(0) + ".pt"
model.load_state_dict(torch.load(
    os.path.join("./final_models/", model_name)))
# Out:
# <All keys matched successfully>

# %%
model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
                      inducing_points).to("cuda")

# %%
pred_dist1 = model1.predict(xt[:4000].to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_mean1.shape
# Out:
# torch.Size([4000])

# %%
pred_arr =[]
pred_arr.append(np.array(pred_dist1.mean.cpu()))

# %%
y_mean = np.mean(pred_arr, axis =0)

# y_Std = np.std(np.array(pred_arr), axis =0)

# %%
y_mean.shape, y_Std.shape
# Out:
# ((4000,), (4000,))

# %%
y_mean = scaler_y.inverse_transform(y_mean.reshape(-1,1)).squeeze()
# y_std = scaler_y.inverse_transform(y_Std.reshape(-1,1)).squeeze()

# %%
y_mean.shape
# Out:
# (16781,)

# %%
y_mean.any() < 0
# Out:
# False

# %%
y_mean_ = np.clip(y_mean,0,y_mean.max())
# y_sigma =  np.clip(y_mean,0,y_mean.max())

# %%
idx = 3000
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp[:idx], scaler_x.inverse_transform(xt.cpu().reshape(-1,1))[:idx], label = "Main")
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean_[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
# savefig("Uncertainity")

# %%
model2 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel4,
                      inducing_points).to("cuda")

# %%
pred_dist2 = model2.predict(xt[:4000].to("cuda"))
# print("Done ", i)

y_mean2 = pred_dist2.loc

# %%
y_mean = scaler_y.inverse_transform(y_mean2.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean.shape)
# Out:
# torch.Size([16781]) (4000,)

# %%
y_mean_ = np.clip(y_mean,0,y_mean.max())

# %%
idx = 3000
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp[:idx], scaler_y.inverse_transform(y.cpu().reshape(-1,1))[:idx], label = "Main")
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean_[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()

# %%
idx = 3000
# plt.figure(figsize=(10,6))
plt.plot(jnp.arange(idx),  yt.cpu().reshape(-1,1)[:idx], label = "Ground Truth", color="green")
plt.plot(jnp.arange(idx), y_mean_[:idx].reshape(-1,1), label = "Predicted")
# for i in range(2,3):
#     plt.fill_between(jnp.arange(idx), y_mean[:idx] - i*y_std[:idx], y_mean[:idx] + i*y_std[:idx],
#                     color="orange", alpha=(1/(i*3)), label=f"$\mu\pm{i}*\sigma$")
# plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.legend( prop={'size': 5.5})
plt.ylabel("Power")
sns.despine()

# %%
mae = np.mean(np.abs(np.array(yt) - y_mean))
rms = errors.rmse(jnp.array(yt), y_mean)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  27.80521506352558
# RMSE:  44.84471

# %%
try:
    from probml_utils import latexify, savefig, is_latexify_enabled
except ModuleNotFoundError:
    # %pip install git+https://github.com/probml/probml-utils.git
    from probml_utils import latexify, savefig, is_latexify_enabled

# %%
os.environ["LATEXIFY"] = "1"
os.environ["FIG_DIR"] = "./Final_plotss/"

# %%
latexify(width_scale_factor=2, fig_height=2)

# %%
idx = 2000
# plt.figure(figsize=(10,6))
plt.figure()
plt.plot(jnp.arange(idx), yt[300:idx+300], label = "Fridge True")
plt.plot(jnp.arange(idx), y_mean[300:idx+300], label = "Fridge Predicted")
plt.legend()
sns.despine()
savefig("CombinationKernel")
# Out:
# saving image to ./Final_plotss/CombinationKernel_latexified.pdf
# Figure size: [2. 2.]

# %%
model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
                       inducing_points).to("cuda")

# %%
pred_dist1 = model1.predict(xt.to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_mean1 = scaler_y.inverse_transform(y_mean1.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean1.shape)
# Out:
# torch.Size([14780]) (14780,)

# %%
idx = 2000
# plt.figure(figsize=(10,6))
plt.figure()
plt.plot(jnp.arange(idx), yt[300:idx+300], label = "Fridge True")
plt.plot(jnp.arange(idx), y_mean1[300:idx+300], label = "Fridge Predicted")
# plt.legend()
sns.despine()
savefig("RBFKernel")
# Out:
# saving image to ./Final_plotss/RBFKernel_latexified.pdf
# Figure size: [2. 2.]

# %%
# for name, params in model.named_parameters():
#   print(name, params)

# # model.mll.model.base_covar_module.kernels.base_kernel.raw_lengthscale

# %%
x.shape
# Out:
# torch.Size([55457, 100])

# %%
model2 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel4,
                       inducing_points).to("cuda")

# %%
pred_dist2 = model2.predict(xt.to("cuda"))
# print("Done ", i)

y_mean2 = pred_dist2.loc
# Out:
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/kernels/inducing_point_kernel.py:61: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352645774/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   inv_root = torch.triangular_solve(eye, chol)[0]

# %%
y_mean2 = scaler_y.inverse_transform(y_mean2.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean2.shape)
# Out:
# torch.Size([14780]) (14780,)

# %%
idx = 2000
plt.figure()
# plt.figure(figsize=(10,6))
plt.plot(jnp.arange(idx), yt[300:idx+300], label = "Fridge True")
plt.plot(jnp.arange(idx), y_mean2[300:idx+300], label = "Fridge Predicted")
# plt.legend()
sns.despine()
savefig("RBFxPeriodicKernel")
# Out:
# saving image to ./Final_plotss/RBFxPeriodicKernel_latexified.pdf
# Figure size: [2. 2.]

# %% [markdown]
# ## Normal

# %%
kernel1 = ScaleKernel(RBFKernel(ard_num_dims=n))
# kernel2 = ScaleKernel(RBFKernel(ard_num_dims=1,active_dims=(99)))
# kernel3 = ScaleKernel(PeriodicKernel(ard_num_dims=1,active_dims=(99)))

# kernel4 = kernel2*kernel3
kernel = kernel1# + kernel4
# induce_points = 512
inducing_points =  x[np.arange(0,x.shape[0],95)] 
# inducing_points = x[torch.randperm(x.shape[0])[: 1500]]

model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                      inducing_points).to("cuda")

model_name =  "Refrigerator_trial_seq_time.pt"
model.load_state_dict(torch.load(
    os.path.join("models/", model_name)))
# Out:
# <All keys matched successfully>

# %%
plt.plot(range(99),model.mll.model.base_covar_module.base_kernel.lengthscale.cpu().detach().reshape(-1,1))

# %%
plt.plot(range(100),model.mll.model.base_covar_module.kernels[0].base_kernel.lengthscale.cpu().detach().reshape(-1,1))

# %%
for name, params in model.named_parameters():
  print(name, params)
# Out:
# mll.likelihood.noise_covar.raw_noise Parameter containing:
# tensor([-1.0096], device='cuda:0', requires_grad=True)
# mll.model.mean_module.constant Parameter containing:
# tensor([0.0197], device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.raw_outputscale Parameter containing:
# tensor(-1.5955, device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.base_kernel.raw_lengthscale Parameter containing:
# tensor([[ 1.7127,  1.7136,  1.7333,  1.7442,  1.7402,  1.7397,  1.7466,  1.7686,
#           1.7576,  1.7448,  1.7657,  1.7839,  1.7661,  1.7749,  1.7550,  1.7648,
#           1.7573,  1.7221,  1.7115,  1.7185,  1.6733,  1.6714,  1.6615,  1.6700,
#           1.6799,  1.6863,  1.7105,  1.7212,  1.7603,  1.7713,  1.7818,  1.7861,
#           1.7688,  1.7527,  1.7599,  1.7722,  1.7489,  1.7463,  1.7318,  1.7100,
#           1.7155,  1.6706,  1.6410,  1.5965,  1.5681,  1.6244,  1.5938,  1.4162,
#           0.2203, -1.4909,  0.0535,  1.4510,  1.5215,  1.5698,  1.6006,  1.6280,
#           1.6671,  1.6821,  1.7016,  1.6944,  1.6971,  1.6882,  1.6921,  1.7159,
#           1.7157,  1.6974,  1.7069,  1.6999,  1.7339,  1.7361,  1.7167,  1.7287,
#           1.6913,  1.6827,  1.6938,  1.6913,  1.7128,  1.7178,  1.7077,  1.7121,
#           1.7120,  1.7142,  1.7503,  1.7616,  1.7721,  1.7581,  1.7720,  1.8044,
#           1.7999,  1.7919,  1.7882,  1.8062,  1.7990,  1.7895,  1.7841,  1.7576,
#           1.7464,  1.7140,  1.6581]], device='cuda:0', requires_grad=True)
# mll.model.covar_module.inducing_points Parameter containing:
# tensor([[-0.6021, -0.5980, -0.5893,  ..., -0.1777, -0.1897, -0.2090],
#         [-0.2090, -0.1555, -0.1075,  ..., -0.3205, -0.3206, -0.3176],
#         [-0.3468, -0.3521, -0.3654,  ..., -0.0812, -0.1101, -0.1276],
#         ...,
#         [ 4.7876,  5.2937,  5.2859,  ...,  5.0246,  5.0475,  5.0063],
#         [ 5.0424,  5.0300,  5.0493,  ...,  0.2325,  0.2275,  0.1431],
#         [ 0.1489,  0.2328,  0.2315,  ..., -0.2765, -0.2754, -0.2741]],
#        device='cuda:0', dtype=torch.float64, requires_grad=True)

# %%
import numpy as np
try:
    from probml_utils import latexify, savefig, is_latexify_enabled
except ModuleNotFoundError:
    # %pip install git+https://github.com/probml/probml-utils.git
    from probml_utils import latexify, savefig, is_latexify_enabled


os.environ["LATEXIFY"] = "1"
os.environ["FIG_DIR"] = "./Final_plotss/"

latexify(width_scale_factor=2, fig_height=2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# arr = np.array([3.8464, 4.5094, 4.7394, 4.9024, 4.9117, 5.0150, 4.8746, 4.9372, 4.3143,
#          4.5656, 5.0050, 5.1365, 5.1490, 5.2152, 5.2837, 5.2594, 5.1965, 5.0747,
#          5.1212, 4.8200, 4.6431, 4.8732, 4.7529, 0.3853, 4.4826, 4.9550, 5.0677,
#          5.2859, 4.9612, 5.1401, 5.2131, 4.4774, 4.5654, 4.5685, 3.8310, 3.0889,
#          2.7822, 4.0948, 4.0399, 4.6180, 4.5923, 4.5015, 4.0521, 4.8423, 5.2143,
#          5.4020, 4.8021, 4.5021, 0.6626, 0.1252, 1.3779, 4.8821, 4.6781, 4.8554,
#          4.5223, 4.5568, 5.0172, 5.4072, 5.0706, 4.5916, 4.5663, 4.1121, 4.2572,
#          4.2228, 3.7784, 0.4839, 3.6554, 4.3523, 4.6682, 4.6549, 4.8291, 5.0260,
#          4.7748, 4.5609, 4.4541, 4.4165, 4.4292, 4.1279, 3.6382, 4.1110, 4.7252,
#          5.0184, 5.0391, 5.2424, 5.5062, 5.4739, 5.5326, 5.6874, 5.6897, 5.4765,
#          5.4602, 5.4513, 5.5450, 5.6225, 5.5479, 5.3580, 5.3926, 5.1536, 4.6321])
# ar1 = np.arange(0,99,1)
# plt.plot(ar1,arr,'b')
# plt.xlabel('ARD')
# plt.ylabel('Learned ARD LengthScale values')
# # plt.title("Building 6 Test")

# plt.show()
# sns.despine()
# savefig("ARD_Ref")
# Out:
# saving image to ./Final_plotss/ARD_Ref_latexified.pdf
# Figure size: [2. 2.]

# %%
pred_dist = model.predict(xt.to("cuda"))
# print("Done ", i)

y_mean = pred_dist.loc
# Out:
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/kernels/inducing_point_kernel.py:61: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352645774/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   inv_root = torch.triangular_solve(eye, chol)[0]

# %%
y_mean = scaler_y.inverse_transform(y_mean.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean.shape)
# Out:
# torch.Size([16781]) (16781,)

# %%
y_mean = np.clip(y_mean,0,y_mean.max(),out=y_mean)

# %%
mae = np.mean(np.abs(np.array(yt) - y_mean))
rms = errors.rmse(jnp.array(yt), y_mean)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  27.430542294131833
# RMSE:  46.57337

# %%
#MAE:  28.1036

# %%
x1 = xt[:,49]

# %%
idx = 3000
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp[:idx], scaler_x.inverse_transform(xt[:,:99].cpu())[:idx,74], label = "Main")
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()

# %%
idx = 3000
plt.figure(figsize=(10,6))
plt.plot(jnp.arange(idx), scaler_y.inverse_transform(y.cpu().reshape(-1,1))[:idx], label = "Main")
plt.plot(jnp.arange(idx), yt.cpu()[:idx], label = "Refri")
plt.plot(jnp.arange(idx), y_mean[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("Indexes")
plt.ylabel("Fridge Power")
sns.despine()

# %%
# plt.plot(np.array(test_timestamp_orig)[:300],np.array(yt)[:300])
# plt.plot(np.array(test_timestamp_orig)[:300],np.array(y_mean)[:300])

# %%
# plt.scatter(np.array(test_timestamp_orig)[:3000],np.array(y_mean)[:3000],label="True")
# plt.scatter(np.array(test_timestamp_orig)[:3000],np.array(yt)[:3000],label="Pred")
# plt.legend()
# plt.xlabel("TimeStamp")
# plt.xlabel("Refrogerator Power")

# %%
idx = x_test.shape[0]
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp, y_test[:idx], label = "Refri")
plt.plot(x_test_timestamp, y_mean[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
# savefig("CombinationKernel")
# plt.savefig("./Results/Refrigerator_building5.png", bbox_inches="tight")

# %%
model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
                      inducing_points).to("cuda")

# %%
pred_dist1 = model.predict(torch.tensor(np.array(x_train_full)).to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_mean1 = scaler_y.inverse_transform(y_mean1.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(y_train.shape, y_mean1.shape)

# %%
mae = np.mean(np.abs(np.array(y_train) - y_mean1))
rms = errors.rmse(jnp.array(y_train), y_mean1)

print("MAE: ", mae)
print("RMSE: ", rms)

# %%
idx = x_train.shape[0]
plt.figure(figsize=(10,6))
plt.plot(x_train_timstamp, y_train[:idx], label = "Refri")
plt.plot(x_train_timstamp, y_mean[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
# savefig("CombinationKernel")
# plt.savefig("./Results/Refrigerator_building5.png", bbox_inches="tight")

# %%
#MAE:  39.81858310475401 build 6
#MAE:  30.333733374869247 build 3
#MAE:  37.32115756605644 build 2
#MAE: 43.212248588857065 build 5
#MAE:  48.917852990726765
