# %%
import os
os.chdir("../")
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %%
import torch
from gpytorch.kernels import RBFKernel, ScaleKernel, PeriodicKernel, MaternKernel, CosineKernel
from skgpytorch.models import SVGPRegressor, SGPRegressor

# %%
import jax.numpy as jnp
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from utilities.fits import fit
# from utilities import plot
import tensorflow_probability.substrates.jax as tfp
dist = tfp.distributions
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from gpytorch.constraints import GreaterThan
from skgpytorch.metrics import mean_squared_error, negative_log_predictive_density
import time
import numpy as np

# from datasets.dataset_load import dataset_loader
from utilities import plot,fits,gmm,errors,predict,preprocess

# device = "cpu"
# torch.set_default_dtype(torch.float32)
# torch.set_default_tensor_type(torch.FloatTensor)

# %%
train ={1:{
                    'start_time': "2011-04-21" ,
                    'end_time': "2011-05-21"
                },
                3: {
                    'start_time': "2011-04-19" ,
                    'end_time': "2011-05-22"
                },
               
                
               2: {
                    'start_time': "2011-04-21" ,
                    'end_time': "2011-05-21"
                }, 5: {
                    'start_time': "2011-04-22" ,
                    'end_time': "2011-06-01"
                }
                ,
               
                }
test = {6: {
                    'start_time': "2011-05-25" ,
                    'end_time': "2011-06-13"
                },}
appliances = ["Refrigerator"]

# %%
print("######")
print("")
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from scipy.stats import kurtosis,skew
import copy



def dataset_load(appliances, train, test=None):
    x_train = []
    y_train = []
    x_train_timestamp = []
    x_train_mean = []
    x_train_std = []
    x_train_max_min = []
    x_train_main = []
    x_train_main_dif = []
    x_train_kurtosis = []
    x_train_skew = []
    x_train_max = []
    x_train_min = []
    n = 99
    units_to_pad = n // 2
    scaler_x = StandardScaler()
    scaler_y = StandardScaler()
    scaler_time = StandardScaler()
    scaler_mean = StandardScaler()
    scaler_std = StandardScaler()
    scaler_max_min = StandardScaler()
    scaler_main = StandardScaler()
    scaler_diff = StandardScaler()
    scaler_kurtosis = StandardScaler()
    scaler_skew = StandardScaler()
    scaler_max = StandardScaler()
    scaler_min = StandardScaler()
    # GV - TRAIN
    os.chdir('/home/gautam.pv/nlim')
    print(f"cwd -> {os.getcwd()}")
    for key, values in train.items():
        df = pd.read_csv(
            f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[0]])
        print(f"Building number: {key}")
        df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
        startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
        endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

        if startDate > endDate:
            raise "Start Date must be smaller than Enddate."

        df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
        df.dropna(inplace=True)
        x = df["main"].values

        x_train_main.extend(x)
        y = df[appliances[0]].values
        timestamp_train = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))

        number_of_bins = len(x)-n+1
        x_original = copy.deepcopy(x)
        x = jnp.array([x[i: i + n] for i in range(number_of_bins)])
        #############
        # Only for Max and mins we choose smaller size window size
        new_widow_size = 99
        x_new = jnp.array([x_original[i: i + new_widow_size] for i in range(number_of_bins)]) 
        x_train_max.extend(jnp.max(x_new,axis=1))
        x_train_min.extend(jnp.min(x_new,axis=1))
        #################
        print(f'post_x_shape: {x.shape}')
        x_train_mean.extend(jnp.mean(x, axis=1))
        x_train_std.extend(jnp.std(x, axis=1))
        debug_x = jnp.std(x,axis=1)
        x_train_max_min.extend(jnp.max(x, axis=1)-jnp.min(x,axis=1))
        x_train_kurtosis.extend(kurtosis(x,axis=1))
        x_train_skew.extend(skew(x,axis = 1))
        x_train.extend(x)
        y_train.extend(y)
        x_train_timestamp.extend(torch.tensor(timestamp_train))
    
    #################
    # TRAIN RESHAPING
    ##################
    print(f"Data from all building added")
    x_train = jnp.array(x_train)
    y_train = jnp.array(y_train).reshape(-1, 1)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(-1,1)
    print(f"x_train_main_shape -> {len(x_train_main)}")
    print(f"x_train_std_shape => {len(x_train_std)}")
    x_train_main = jnp.array(x_train_main).reshape(-1,1)
    x_train_mean = jnp.array(x_train_mean).reshape(-1,1)
    x_train_std =  jnp.array(x_train_std).reshape(-1,1)
    x_train_max_min =  jnp.array(x_train_max_min).reshape(-1,1)
    x_train_kurtosis = jnp.array(x_train_kurtosis).reshape(-1,1)
    x_train_skew = jnp.array(x_train_skew).reshape(-1,1)
    x_train_max = jnp.array(x_train_max).reshape(-1,1)
    x_train_min = jnp.array(x_train_min).reshape(-1,1)
    print(f"final x_train_max_shape -> {x_train_max.shape}")
    print(f"final x_train_std shape -> {x_train_std.shape}")
   

    #################################################
        # Performing Transformations
    ##################################################
    x_train = scaler_x.fit_transform(x_train)
    y_train = scaler_y.fit_transform(y_train)
    x_train_timestamp = scaler_time.fit_transform(x_train_timestamp)
    x_train_main = scaler_main.fit_transform(x_train_main)
    x_train_mean = scaler_mean.fit_transform(x_train_mean)
    x_train_std = scaler_std.fit_transform(x_train_std)
    x_train_max_min = scaler_max_min.fit_transform(x_train_max_min)
    x_train_kurtosis = scaler_kurtosis.fit_transform(x_train_kurtosis)
    x_train_skew = scaler_skew.fit_transform(x_train_skew)
    x_train_max = scaler_max.fit_transform(x_train_max)
    x_train_min = scaler_min.fit_transform(x_train_min)
    
    #############################################################################
    # TEST
    #############################################################################

    x_test = []
    y_test = []
    x_test_timestamp = []
    x_test_mean = []
    x_test_std = []
    x_test_max_min = []
    x_test_kurtosis = []
    x_test_skew = []
    x_test_timestamp_true =[]
    x_test_main = []
    x_test_max = []
    x_test_min = []

    for key, values in test.items():
        df = pd.read_csv(
            f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[0]])
        df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
        startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
        endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

        if startDate > endDate:
            raise "Start Date must be smaller than Enddate."

        df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
        df.dropna(inplace=True)
        x = df["main"].values 
        x_test_main.extend(x)
        y = df[appliances[0]].values

        timestamp_true = df["Timestamp"].values
        timestamp = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        number_of_bins = len(x)-n+1
        x_original = copy.deepcopy(x)
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])
         #############
        # Only for Max and mins we choose smaller size window size
        new_widow_size = 99
        x_new = jnp.array([x_original[i: i + new_widow_size] for i in range(number_of_bins)]) 
        print(f"x_new shape -> ")
        x_test_max.extend(jnp.max(x_new,axis=1))
        x_test_min.extend(jnp.min(x_new,axis=1))
        #################

        x_test_mean.extend(jnp.mean(x, axis=1))
        x_test_std.extend(jnp.std(x, axis=1))
        x_test_max_min.extend(jnp.max(x, axis=1)-jnp.min(x, axis=1))
        x_test_kurtosis.extend(kurtosis(x,axis=1))
        x_test_skew.extend(skew(x,axis=1))
        x_test.extend(x)
        y_test.extend(y)
        x_test_timestamp_true.extend(timestamp_true)
        x_test_timestamp.extend(timestamp)
    
    #############
    #  Flattening for test
    ##############
    x_test = jnp.array(x_test)
    y_test = jnp.array(y_test).reshape(-1, 1)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(-1,1)
    x_test_main = jnp.array(x_test_main).reshape(-1,1)
    x_test_mean = jnp.array(x_test_mean).reshape(-1,1)
    x_test_std =  jnp.array(x_test_std).reshape(-1,1)
    x_test_max_min =  jnp.array(x_test_max_min).reshape(-1,1)
    x_test_kurtosis = jnp.array(x_test_kurtosis).reshape(-1,1)
    x_test_skew = jnp.array(x_test_skew).reshape(-1,1)
    x_test_max = jnp.array(x_test_max).reshape(-1,1)
    x_test_min = jnp.array(x_test_min).reshape(-1,1)
    print(f"final x_test_max_shape -> {x_test_max.shape}")
    print(f"final x_test_std shape -> {x_test_std.shape}")

    #############
    # Scalar tranformations for test
    #############
    x_test = scaler_x.transform(x_test)
    x_test_timestamp = scaler_time.transform(x_test_timestamp)
    x_test_mean = scaler_mean.transform(x_test_mean)
    x_test_std = scaler_std.transform(x_test_std)
    x_test_max_min = scaler_max_min.transform(x_test_max_min)
    x_test_main = scaler_main.transform(x_test_main)
    x_test_kurtosis = scaler_kurtosis.transform(x_test_kurtosis)
    x_test_skew = scaler_skew.transform(x_test_skew)
    x_test_max = scaler_max.transform(x_test_max)
    x_test_min = scaler_min.transform(x_test_min)
    
    ######################
    # FINAL RESHAPING
    ######################

    x_train = jnp.array(x_train[:,1:]).reshape(x_train.shape[0], n-1)
    y_train = jnp.array(y_train)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(x_train_timestamp.shape[0], 1)
    x_test = jnp.array(x_test[:,1:]).reshape(x_test.shape[0], n-1)
    y_test = jnp.array(y_test)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(x_test_timestamp.shape[0], 1).to(torch.float64)

    #############################
    # FINAL CONCATENATATION
    #############################

    num_features_selected = 6

    x_train_features = jnp.concatenate((x_train_main, x_train_mean, x_train_max_min,x_train_kurtosis,x_train_max,x_train_min), axis=1).reshape(x_train.shape[0], num_features_selected)
    x_test_features = jnp.concatenate((x_test_main, x_test_mean, x_test_max_min,x_test_kurtosis,x_test_max, x_test_min), axis=1).reshape(x_test.shape[0], num_features_selected)

    scalers = np.array([scaler_x, scaler_y, scaler_time, scaler_main, scaler_mean, scaler_std, scaler_max_min,scaler_max,scaler_min,scaler_kurtosis])
    return x_train, y_train, x_test, y_test, x_train_features, x_test_features, x_train_timestamp, x_test_timestamp, scalers, x_test_main
# Out:
# ######

# %%
x_train, y_train, x_test, y_test, x_train_features, x_test_features, x_train_timstamp, x_test_timestamp, scalers, x_test_main = dataset_load(appliances, train, test)
# Out:
# cwd -> /home/gautam.pv/nlim
# Building number: 1
# post_x_shape: (19917, 99)
# Building number: 3
# post_x_shape: (14780, 99)
# Building number: 2
# post_x_shape: (15656, 99)
# Building number: 5
# post_x_shape: (3103, 99)
# Data from all building added
# x_train_main_shape -> 53456
# x_train_std_shape => 53456
# final x_train_max_shape -> (53456, 1)
# final x_train_std shape -> (53456, 1)
# x_new shape ->
# final x_test_max_shape -> (16781, 1)
# final x_test_std shape -> (16781, 1)

# %% [markdown]
# ### Visualization Block
#
# Use this block if you want visualize the relevance of any featue

# %%
x_train_full = jnp.concatenate((x_train_features, jnp.array(np.array(x_train_timstamp))), axis=1)
x_test_full  = jnp.concatenate((x_test_features, jnp.array(np.array(x_test_timestamp))), axis=1)

# %%
# x_train_full = jnp.concatenate((x_train.reshape(-1,n), jnp.array(np.array(x_train_timstamp))), axis=1)
# x_test_full = jnp.concatenate((x_test.reshape(-1,n), jnp.array(np.array(x_test_timestamp))), axis=1)
# x_train_full.shape, x_test_full.shape

# %%
# x_train.reshape(-1,n).shape, x_test.reshape(-1,n).shape, y_train.shape, y_test.shape

# %%
# x = x_train_full[:14000]
# y = y_train[:14000]
# xt = x_train_full[14000:]
# yt = y_train[14000:]

# %%
# x.shape, y.shape

# %% [markdown]
# ## Adding Diff as a feature

# %%
diff_scalar = StandardScaler()
x_train_diff = x_train_features[:,0]
train_diff = np.array(x_train_diff)
for i in range(1, len(x_train_diff)):
		value = x_train_diff[i] - x_train_diff[i - 1]
		train_diff[i] = value
x_train_diff = np.array(train_diff).reshape(-1,1)
x_train_diff = diff_scalar.fit_transform(x_train_diff)
x_test_diff = x_test_features[:,0]
test_diff = np.array(x_test_diff)
for i in range(1, len(x_test_diff)):
		value = x_test_diff[i] - x_test_diff[i - 1]
		test_diff[i] = value
x_test_diff = np.array(test_diff).reshape(-1,1)
x_test_diff = diff_scalar.transform(x_test_diff)
# x_train_zeros = np.zeros(x_train_diff.shape)
# x_test_zeros = np.zeros(x_test_diff.shape)
# x_train_diff = jnp.array(diff)

# %%
x_train_diff.shape,x_test_diff.shape
# Out:
# ((53456, 1), (16781, 1))

# %%
x_train_features = jnp.concatenate((x_train_features,jnp.array(x_train_diff.reshape(-1,1))), axis=1)
x_test_features  = jnp.concatenate((x_test_features, jnp.array(x_test_diff.reshape(-1,1))),  axis=1)
x_train_features.shape,x_test_features.shape
# Out:
# ((53456, 7), (16781, 7))

# %% [markdown]
# ## Adding FFT as a Feature

# %%
from scipy.fft import fft, fftfreq, fftshift

plt.plot(x_train[0:1000,0])
fft_scaler = StandardScaler()

window_size = 99
x_train_fft = x_train_features[:,0]
x_train_fft = fftshift(fftfreq(x_train_fft.shape[0]))
x_train_fft = x_train_fft.reshape(-1,1)
x_train_fft = fft_scaler.fit_transform(x_train_fft)

x_test_fft = x_test_features[:,0]
x_test_fft = fftshift(fftfreq(x_test_fft.shape[0]))
x_test_fft = x_test_fft.reshape(-1,1)
x_test_fft = fft_scaler.transform(x_test_fft)

x_train_features = jnp.concatenate((x_train_features,jnp.array(x_train_fft.reshape(-1,1))), axis=1)
x_test_features  = jnp.concatenate((x_test_features, jnp.array(x_test_fft.reshape(-1,1))),  axis=1)

x_train_features.shape,x_test_features.shape
# Out:
# ((53456, 6), (16781, 6))

# %% [markdown]
# ## Training

# %%
import gpytorch
indexes = 53456
n = 7
x  = torch.tensor(np.array(x_train_features)).to(torch.float64)
y  = torch.tensor(np.array(y_train)).reshape(-1,).to(torch.float64)
xt = torch.tensor(np.array(x_test_features)).to(torch.float64)
yt = torch.tensor(np.array(y_test)).reshape(-1,).to(torch.float64)

if x.shape[0] > indexes:
    x = x[:indexes]
    y = y[:indexes]

# xt = xt[:16000]
# yt = yt[:16000]

# %%
x.dtype
# Out:
# torch.float64

# %%
x.shape, y.shape, xt.shape, yt.shape
# Out:
# (torch.Size([53456, 7]),
#  torch.Size([53456]),
#  torch.Size([16781, 7]),
#  torch.Size([16781]))

# %% [markdown]
# ## Training Loop

# %%
mae_arr =[]
rms_arr = []
y_pred_arr = []

batch = 512

# x_train = x_train[:4500]
# y_train = y_train[:4500]

# y_test_trans = torch.tensor(torch.tensor(scaler_x.transform(y_test.reshape(-1,1))).reshape(-1,)).contiguous().to(torch.float64)
periodicity_values = [0.01,0.02,0.03,0.04]
for i in range(1):
   #nu=2.5,
  kernel1 = ScaleKernel(MaternKernel(nu=2.5, ard_num_dims=n))
  # kernel2 = ScaleKernel(MaternKernel(nu=0.5,ard_num_dims=1,active_dims=(n)))
  # kernel2 = ScaleKernel(RBFKernel(ard_num_dims=1, active_dims=(n)))
  # kernel3 = ScaleKernel(PeriodicKernel(ard_num_dims=1,active_dims=(n)))
  # kernel5 = ScaleKernel(gpytorch.kernels.SpectralDeltaKernel(num_dims=n,ard_num_dims=n))
#   theta =  {'base_covar_module.kernels.0.base_kernel.lengthscale': torch.tensor(0.5),
#         'base_covar_module.kernels.0.outputscale': torch.tensor(5.0),
#         'base_covar_module.kernels.1.kernels.0.outputscale':torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.0.base_kernel.lengthscale': torch.tensor(0.1),
#         'base_covar_module.kernels.1.kernels.1.outputscale':torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.1.base_kernel.lengthscale': torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
  theta = { 'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
  # kernel4 = kernel2*kernel3
  kernel = kernel1 #+ kernel4
  # induce_points = 512
  # GV -  What are inducing points?
  inducing_points =  x[np.arange(0,x.shape[0],95)] 
  # inducing_points = x[torch.randperm(x.shape[0])[: 1500]]
  print(f"testing -> x.shape -> {x.shape}")
  print(f"testing -> x.shape -> {y.shape}")
  model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                       inducing_points).to("cuda")
  # model.base_covar_module.base_kernel.raw_lengthscale_constraint
  # model.mll.likelihood.noise_covar.register_constraint("raw_noise", GreaterThan(1e-2))
  # for param in model.parameters():
  #   # print(param)
  #   torch.nn.init.normal_(param, 0, 1)
  # theta1 = {'likelihood.noise_covar.noise': torch.tensor(3),
  #       'covar_module.base_kernel.lengthscale': torch.tensor(0.1),
  #       'covar_module.outputscale': torch.tensor(5),}
  loss = model.fit(lr=0.001, n_epochs=3000,verbose=1, thetas = None,
          random_state=0, n_restarts=1)
#   loss_arr.append(loss)
  # print(loss)
  plt.plot(np.asarray(loss[0]))
  # plt.plot(np.asarray(test_loss[0]))





# pred_dist = model.predict(xt.to("cuda"))
# y_mean = pred_dist.loc
# y_mean = scalers[1].inverse_transform(y_mean.cpu().reshape(-1,1)).squeeze()
# # y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
# print(yt.shape, y_mean.shape)
# y_mean = np.clip(y_mean,0,y_mean.max(),out=y_mean)
# mae = np.mean(np.abs(np.array(yt) - y_mean))
# rms = errors.rmse(jnp.array(yt), y_mean)
# print("MAE: ", mae)
# print("RMSE: ", rms)

  # y_pred_arr.append(pred_dist.loc)
# Out:
# testing -> x.shape -> torch.Size([53456, 7])
# testing -> x.shape -> torch.Size([53456])
# restart: 0, epoch: 1, iter: 1, loss: 1.0168
# restart: 0, epoch: 2, iter: 1, loss: 1.0156
# restart: 0, epoch: 3, iter: 1, loss: 1.0147
# restart: 0, epoch: 4, iter: 1, loss: 1.0137
# restart: 0, epoch: 5, iter: 1, loss: 1.0128
# restart: 0, epoch: 6, iter: 1, loss: 1.0120
# restart: 0, epoch: 7, iter: 1, loss: 1.0111
# restart: 0, epoch: 8, iter: 1, loss: 1.0103
# restart: 0, epoch: 9, iter: 1, loss: 1.0095
# restart: 0, epoch: 10, iter: 1, loss: 1.0087
# restart: 0, epoch: 11, iter: 1, loss: 1.0079
# restart: 0, epoch: 12, iter: 1, loss: 1.0072
# restart: 0, epoch: 13, iter: 1, loss: 1.0065
# restart: 0, epoch: 14, iter: 1, loss: 1.0057
# restart: 0, epoch: 15, iter: 1, loss: 1.0050
# restart: 0, epoch: 16, iter: 1, loss: 1.0043
# restart: 0, epoch: 17, iter: 1, loss: 1.0036
# restart: 0, epoch: 18, iter: 1, loss: 1.0030
# restart: 0, epoch: 19, iter: 1, loss: 1.0023
# restart: 0, epoch: 20, iter: 1, loss: 1.0016
# restart: 0, epoch: 21, iter: 1, loss: 1.0010
# restart: 0, epoch: 22, iter: 1, loss: 1.0003
# restart: 0, epoch: 23, iter: 1, loss: 0.9997
# restart: 0, epoch: 24, iter: 1, loss: 0.9990
# restart: 0, epoch: 25, iter: 1, loss: 0.9984
# restart: 0, epoch: 26, iter: 1, loss: 0.9978
# restart: 0, epoch: 27, iter: 1, loss: 0.9972
# restart: 0, epoch: 28, iter: 1, loss: 0.9966
# restart: 0, epoch: 29, iter: 1, loss: 0.9960
# restart: 0, epoch: 30, iter: 1, loss: 0.9954
# restart: 0, epoch: 31, iter: 1, loss: 0.9948
# restart: 0, epoch: 32, iter: 1, loss: 0.9942
# restart: 0, epoch: 33, iter: 1, loss: 0.9936
# restart: 0, epoch: 34, iter: 1, loss: 0.9931
# restart: 0, epoch: 35, iter: 1, loss: 0.9925
# restart: 0, epoch: 36, iter: 1, loss: 0.9919
# restart: 0, epoch: 37, iter: 1, loss: 0.9914
# restart: 0, epoch: 38, iter: 1, loss: 0.9908
# restart: 0, epoch: 39, iter: 1, loss: 0.9903
# restart: 0, epoch: 40, iter: 1, loss: 0.9897
# restart: 0, epoch: 41, iter: 1, loss: 0.9892
# restart: 0, epoch: 42, iter: 1, loss: 0.9887
# restart: 0, epoch: 43, iter: 1, loss: 0.9881
# restart: 0, epoch: 44, iter: 1, loss: 0.9876
# restart: 0, epoch: 45, iter: 1, loss: 0.9871
# restart: 0, epoch: 46, iter: 1, loss: 0.9865
# restart: 0, epoch: 47, iter: 1, loss: 0.9860
# restart: 0, epoch: 48, iter: 1, loss: 0.9855
# restart: 0, epoch: 49, iter: 1, loss: 0.9850
# restart: 0, epoch: 50, iter: 1, loss: 0.9845
# restart: 0, epoch: 51, iter: 1, loss: 0.9839
# restart: 0, epoch: 52, iter: 1, loss: 0.9834
# restart: 0, epoch: 53, iter: 1, loss: 0.9829
# restart: 0, epoch: 54, iter: 1, loss: 0.9824
# restart: 0, epoch: 55, iter: 1, loss: 0.9819
# restart: 0, epoch: 56, iter: 1, loss: 0.9814
# restart: 0, epoch: 57, iter: 1, loss: 0.9809
# restart: 0, epoch: 58, iter: 1, loss: 0.9804
# restart: 0, epoch: 59, iter: 1, loss: 0.9799
# restart: 0, epoch: 60, iter: 1, loss: 0.9794
# restart: 0, epoch: 61, iter: 1, loss: 0.9789
# restart: 0, epoch: 62, iter: 1, loss: 0.9784
# restart: 0, epoch: 63, iter: 1, loss: 0.9779
# restart: 0, epoch: 64, iter: 1, loss: 0.9774
# restart: 0, epoch: 65, iter: 1, loss: 0.9770
# restart: 0, epoch: 66, iter: 1, loss: 0.9765
# restart: 0, epoch: 67, iter: 1, loss: 0.9760
# restart: 0, epoch: 68, iter: 1, loss: 0.9755
# restart: 0, epoch: 69, iter: 1, loss: 0.9750
# restart: 0, epoch: 70, iter: 1, loss: 0.9745
# restart: 0, epoch: 71, iter: 1, loss: 0.9741
# restart: 0, epoch: 72, iter: 1, loss: 0.9736
# restart: 0, epoch: 73, iter: 1, loss: 0.9731
# restart: 0, epoch: 74, iter: 1, loss: 0.9726
# restart: 0, epoch: 75, iter: 1, loss: 0.9722
# restart: 0, epoch: 76, iter: 1, loss: 0.9717
# restart: 0, epoch: 77, iter: 1, loss: 0.9712
# restart: 0, epoch: 78, iter: 1, loss: 0.9707
# restart: 0, epoch: 79, iter: 1, loss: 0.9703
# restart: 0, epoch: 80, iter: 1, loss: 0.9698
# restart: 0, epoch: 81, iter: 1, loss: 0.9693
# restart: 0, epoch: 82, iter: 1, loss: 0.9689
# restart: 0, epoch: 83, iter: 1, loss: 0.9684
# restart: 0, epoch: 84, iter: 1, loss: 0.9680
# restart: 0, epoch: 85, iter: 1, loss: 0.9675
# restart: 0, epoch: 86, iter: 1, loss: 0.9671
# restart: 0, epoch: 87, iter: 1, loss: 0.9666
# restart: 0, epoch: 88, iter: 1, loss: 0.9662
# restart: 0, epoch: 89, iter: 1, loss: 0.9657
# restart: 0, epoch: 90, iter: 1, loss: 0.9653
# restart: 0, epoch: 91, iter: 1, loss: 0.9648
# restart: 0, epoch: 92, iter: 1, loss: 0.9644
# restart: 0, epoch: 93, iter: 1, loss: 0.9639
# restart: 0, epoch: 94, iter: 1, loss: 0.9635
# restart: 0, epoch: 95, iter: 1, loss: 0.9630
# restart: 0, epoch: 96, iter: 1, loss: 0.9626
# restart: 0, epoch: 97, iter: 1, loss: 0.9622
# restart: 0, epoch: 98, iter: 1, loss: 0.9617
# restart: 0, epoch: 99, iter: 1, loss: 0.9613
# restart: 0, epoch: 100, iter: 1, loss: 0.9609
# restart: 0, epoch: 101, iter: 1, loss: 0.9605
# restart: 0, epoch: 102, iter: 1, loss: 0.9600
# restart: 0, epoch: 103, iter: 1, loss: 0.9596
# restart: 0, epoch: 104, iter: 1, loss: 0.9592
# restart: 0, epoch: 105, iter: 1, loss: 0.9588
# restart: 0, epoch: 106, iter: 1, loss: 0.9583
# restart: 0, epoch: 107, iter: 1, loss: 0.9579
# restart: 0, epoch: 108, iter: 1, loss: 0.9575
# restart: 0, epoch: 109, iter: 1, loss: 0.9571
# restart: 0, epoch: 110, iter: 1, loss: 0.9567
# restart: 0, epoch: 111, iter: 1, loss: 0.9563
# restart: 0, epoch: 112, iter: 1, loss: 0.9559
# restart: 0, epoch: 113, iter: 1, loss: 0.9555
# restart: 0, epoch: 114, iter: 1, loss: 0.9550
# restart: 0, epoch: 115, iter: 1, loss: 0.9546
# restart: 0, epoch: 116, iter: 1, loss: 0.9542
# restart: 0, epoch: 117, iter: 1, loss: 0.9538
# restart: 0, epoch: 118, iter: 1, loss: 0.9534
# restart: 0, epoch: 119, iter: 1, loss: 0.9530
# restart: 0, epoch: 120, iter: 1, loss: 0.9526
# restart: 0, epoch: 121, iter: 1, loss: 0.9522
# restart: 0, epoch: 122, iter: 1, loss: 0.9518
# restart: 0, epoch: 123, iter: 1, loss: 0.9515
# restart: 0, epoch: 124, iter: 1, loss: 0.9511
# restart: 0, epoch: 125, iter: 1, loss: 0.9507
# restart: 0, epoch: 126, iter: 1, loss: 0.9503
# restart: 0, epoch: 127, iter: 1, loss: 0.9499
# restart: 0, epoch: 128, iter: 1, loss: 0.9495
# restart: 0, epoch: 129, iter: 1, loss: 0.9491
# restart: 0, epoch: 130, iter: 1, loss: 0.9487
# restart: 0, epoch: 131, iter: 1, loss: 0.9484
# restart: 0, epoch: 132, iter: 1, loss: 0.9480
# restart: 0, epoch: 133, iter: 1, loss: 0.9476
# restart: 0, epoch: 134, iter: 1, loss: 0.9472
# restart: 0, epoch: 135, iter: 1, loss: 0.9468
# restart: 0, epoch: 136, iter: 1, loss: 0.9465
# restart: 0, epoch: 137, iter: 1, loss: 0.9461
# restart: 0, epoch: 138, iter: 1, loss: 0.9457
# restart: 0, epoch: 139, iter: 1, loss: 0.9453
# restart: 0, epoch: 140, iter: 1, loss: 0.9450
# restart: 0, epoch: 141, iter: 1, loss: 0.9446
# restart: 0, epoch: 142, iter: 1, loss: 0.9442
# restart: 0, epoch: 143, iter: 1, loss: 0.9438
# restart: 0, epoch: 144, iter: 1, loss: 0.9435
# restart: 0, epoch: 145, iter: 1, loss: 0.9431
# restart: 0, epoch: 146, iter: 1, loss: 0.9427
# restart: 0, epoch: 147, iter: 1, loss: 0.9424
# restart: 0, epoch: 148, iter: 1, loss: 0.9420
# restart: 0, epoch: 149, iter: 1, loss: 0.9416
# restart: 0, epoch: 150, iter: 1, loss: 0.9413
# restart: 0, epoch: 151, iter: 1, loss: 0.9409
# restart: 0, epoch: 152, iter: 1, loss: 0.9406
# restart: 0, epoch: 153, iter: 1, loss: 0.9402
# restart: 0, epoch: 154, iter: 1, loss: 0.9398
# restart: 0, epoch: 155, iter: 1, loss: 0.9395
# restart: 0, epoch: 156, iter: 1, loss: 0.9391
# restart: 0, epoch: 157, iter: 1, loss: 0.9387
# restart: 0, epoch: 158, iter: 1, loss: 0.9384
# restart: 0, epoch: 159, iter: 1, loss: 0.9380
# restart: 0, epoch: 160, iter: 1, loss: 0.9377
# restart: 0, epoch: 161, iter: 1, loss: 0.9373
# restart: 0, epoch: 162, iter: 1, loss: 0.9370
# restart: 0, epoch: 163, iter: 1, loss: 0.9366
# restart: 0, epoch: 164, iter: 1, loss: 0.9362
# restart: 0, epoch: 165, iter: 1, loss: 0.9359
# restart: 0, epoch: 166, iter: 1, loss: 0.9355
# restart: 0, epoch: 167, iter: 1, loss: 0.9352
# restart: 0, epoch: 168, iter: 1, loss: 0.9348
# restart: 0, epoch: 169, iter: 1, loss: 0.9345
# restart: 0, epoch: 170, iter: 1, loss: 0.9341
# restart: 0, epoch: 171, iter: 1, loss: 0.9338
# restart: 0, epoch: 172, iter: 1, loss: 0.9334
# restart: 0, epoch: 173, iter: 1, loss: 0.9331
# restart: 0, epoch: 174, iter: 1, loss: 0.9327
# restart: 0, epoch: 175, iter: 1, loss: 0.9324
# restart: 0, epoch: 176, iter: 1, loss: 0.9320
# restart: 0, epoch: 177, iter: 1, loss: 0.9316
# restart: 0, epoch: 178, iter: 1, loss: 0.9313
# restart: 0, epoch: 179, iter: 1, loss: 0.9309
# restart: 0, epoch: 180, iter: 1, loss: 0.9306
# restart: 0, epoch: 181, iter: 1, loss: 0.9303
# restart: 0, epoch: 182, iter: 1, loss: 0.9299
# restart: 0, epoch: 183, iter: 1, loss: 0.9296
# restart: 0, epoch: 184, iter: 1, loss: 0.9292
# restart: 0, epoch: 185, iter: 1, loss: 0.9289
# restart: 0, epoch: 186, iter: 1, loss: 0.9285
# restart: 0, epoch: 187, iter: 1, loss: 0.9282
# restart: 0, epoch: 188, iter: 1, loss: 0.9278
# restart: 0, epoch: 189, iter: 1, loss: 0.9275
# restart: 0, epoch: 190, iter: 1, loss: 0.9271
# restart: 0, epoch: 191, iter: 1, loss: 0.9268
# restart: 0, epoch: 192, iter: 1, loss: 0.9264
# restart: 0, epoch: 193, iter: 1, loss: 0.9261
# restart: 0, epoch: 194, iter: 1, loss: 0.9257
# restart: 0, epoch: 195, iter: 1, loss: 0.9254
# restart: 0, epoch: 196, iter: 1, loss: 0.9251
# restart: 0, epoch: 197, iter: 1, loss: 0.9247
# restart: 0, epoch: 198, iter: 1, loss: 0.9244
# restart: 0, epoch: 199, iter: 1, loss: 0.9240
# restart: 0, epoch: 200, iter: 1, loss: 0.9237
# restart: 0, epoch: 201, iter: 1, loss: 0.9233
# restart: 0, epoch: 202, iter: 1, loss: 0.9230
# restart: 0, epoch: 203, iter: 1, loss: 0.9227
# restart: 0, epoch: 204, iter: 1, loss: 0.9223
# restart: 0, epoch: 205, iter: 1, loss: 0.9220
# restart: 0, epoch: 206, iter: 1, loss: 0.9216
# restart: 0, epoch: 207, iter: 1, loss: 0.9213
# restart: 0, epoch: 208, iter: 1, loss: 0.9210
# restart: 0, epoch: 209, iter: 1, loss: 0.9206
# restart: 0, epoch: 210, iter: 1, loss: 0.9203
# restart: 0, epoch: 211, iter: 1, loss: 0.9199
# restart: 0, epoch: 212, iter: 1, loss: 0.9196
# restart: 0, epoch: 213, iter: 1, loss: 0.9193
# restart: 0, epoch: 214, iter: 1, loss: 0.9189
# restart: 0, epoch: 215, iter: 1, loss: 0.9186
# restart: 0, epoch: 216, iter: 1, loss: 0.9182
# restart: 0, epoch: 217, iter: 1, loss: 0.9179
# restart: 0, epoch: 218, iter: 1, loss: 0.9176
# restart: 0, epoch: 219, iter: 1, loss: 0.9172
# restart: 0, epoch: 220, iter: 1, loss: 0.9169
# restart: 0, epoch: 221, iter: 1, loss: 0.9165
# restart: 0, epoch: 222, iter: 1, loss: 0.9162
# restart: 0, epoch: 223, iter: 1, loss: 0.9159
# restart: 0, epoch: 224, iter: 1, loss: 0.9155
# restart: 0, epoch: 225, iter: 1, loss: 0.9152
# restart: 0, epoch: 226, iter: 1, loss: 0.9149
# restart: 0, epoch: 227, iter: 1, loss: 0.9145
# restart: 0, epoch: 228, iter: 1, loss: 0.9142
# restart: 0, epoch: 229, iter: 1, loss: 0.9139
# restart: 0, epoch: 230, iter: 1, loss: 0.9135
# restart: 0, epoch: 231, iter: 1, loss: 0.9132
# restart: 0, epoch: 232, iter: 1, loss: 0.9129
# restart: 0, epoch: 233, iter: 1, loss: 0.9125
# restart: 0, epoch: 234, iter: 1, loss: 0.9122
# restart: 0, epoch: 235, iter: 1, loss: 0.9118
# restart: 0, epoch: 236, iter: 1, loss: 0.9115
# restart: 0, epoch: 237, iter: 1, loss: 0.9112
# restart: 0, epoch: 238, iter: 1, loss: 0.9108
# restart: 0, epoch: 239, iter: 1, loss: 0.9105
# restart: 0, epoch: 240, iter: 1, loss: 0.9102
# restart: 0, epoch: 241, iter: 1, loss: 0.9098
# restart: 0, epoch: 242, iter: 1, loss: 0.9095
# restart: 0, epoch: 243, iter: 1, loss: 0.9092
# restart: 0, epoch: 244, iter: 1, loss: 0.9089
# restart: 0, epoch: 245, iter: 1, loss: 0.9085
# restart: 0, epoch: 246, iter: 1, loss: 0.9082
# restart: 0, epoch: 247, iter: 1, loss: 0.9079
# restart: 0, epoch: 248, iter: 1, loss: 0.9075
# restart: 0, epoch: 249, iter: 1, loss: 0.9072
# restart: 0, epoch: 250, iter: 1, loss: 0.9069
# restart: 0, epoch: 251, iter: 1, loss: 0.9065
# restart: 0, epoch: 252, iter: 1, loss: 0.9062
# restart: 0, epoch: 253, iter: 1, loss: 0.9059
# restart: 0, epoch: 254, iter: 1, loss: 0.9055
# restart: 0, epoch: 255, iter: 1, loss: 0.9052
# restart: 0, epoch: 256, iter: 1, loss: 0.9049
# restart: 0, epoch: 257, iter: 1, loss: 0.9045
# restart: 0, epoch: 258, iter: 1, loss: 0.9042
# restart: 0, epoch: 259, iter: 1, loss: 0.9039
# restart: 0, epoch: 260, iter: 1, loss: 0.9036
# restart: 0, epoch: 261, iter: 1, loss: 0.9032
# restart: 0, epoch: 262, iter: 1, loss: 0.9029
# restart: 0, epoch: 263, iter: 1, loss: 0.9026
# restart: 0, epoch: 264, iter: 1, loss: 0.9022
# restart: 0, epoch: 265, iter: 1, loss: 0.9019
# restart: 0, epoch: 266, iter: 1, loss: 0.9016
# restart: 0, epoch: 267, iter: 1, loss: 0.9013
# restart: 0, epoch: 268, iter: 1, loss: 0.9009
# restart: 0, epoch: 269, iter: 1, loss: 0.9006
# restart: 0, epoch: 270, iter: 1, loss: 0.9003
# restart: 0, epoch: 271, iter: 1, loss: 0.8999
# restart: 0, epoch: 272, iter: 1, loss: 0.8996
# restart: 0, epoch: 273, iter: 1, loss: 0.8993
# restart: 0, epoch: 274, iter: 1, loss: 0.8990
# restart: 0, epoch: 275, iter: 1, loss: 0.8986
# restart: 0, epoch: 276, iter: 1, loss: 0.8983
# restart: 0, epoch: 277, iter: 1, loss: 0.8980
# restart: 0, epoch: 278, iter: 1, loss: 0.8976
# restart: 0, epoch: 279, iter: 1, loss: 0.8973
# restart: 0, epoch: 280, iter: 1, loss: 0.8970
# restart: 0, epoch: 281, iter: 1, loss: 0.8967
# restart: 0, epoch: 282, iter: 1, loss: 0.8963
# restart: 0, epoch: 283, iter: 1, loss: 0.8960
# restart: 0, epoch: 284, iter: 1, loss: 0.8957
# restart: 0, epoch: 285, iter: 1, loss: 0.8954
# restart: 0, epoch: 286, iter: 1, loss: 0.8950
# restart: 0, epoch: 287, iter: 1, loss: 0.8947
# restart: 0, epoch: 288, iter: 1, loss: 0.8944
# restart: 0, epoch: 289, iter: 1, loss: 0.8940
# restart: 0, epoch: 290, iter: 1, loss: 0.8937
# restart: 0, epoch: 291, iter: 1, loss: 0.8934
# restart: 0, epoch: 292, iter: 1, loss: 0.8931
# restart: 0, epoch: 293, iter: 1, loss: 0.8927
# restart: 0, epoch: 294, iter: 1, loss: 0.8924
# restart: 0, epoch: 295, iter: 1, loss: 0.8921
# restart: 0, epoch: 296, iter: 1, loss: 0.8918
# restart: 0, epoch: 297, iter: 1, loss: 0.8914
# restart: 0, epoch: 298, iter: 1, loss: 0.8911
# restart: 0, epoch: 299, iter: 1, loss: 0.8908
# restart: 0, epoch: 300, iter: 1, loss: 0.8905
# restart: 0, epoch: 301, iter: 1, loss: 0.8901
# restart: 0, epoch: 302, iter: 1, loss: 0.8898
# restart: 0, epoch: 303, iter: 1, loss: 0.8895
# restart: 0, epoch: 304, iter: 1, loss: 0.8892
# restart: 0, epoch: 305, iter: 1, loss: 0.8888
# restart: 0, epoch: 306, iter: 1, loss: 0.8885
# restart: 0, epoch: 307, iter: 1, loss: 0.8882
# restart: 0, epoch: 308, iter: 1, loss: 0.8879
# restart: 0, epoch: 309, iter: 1, loss: 0.8875
# restart: 0, epoch: 310, iter: 1, loss: 0.8872
# restart: 0, epoch: 311, iter: 1, loss: 0.8869
# restart: 0, epoch: 312, iter: 1, loss: 0.8866
# restart: 0, epoch: 313, iter: 1, loss: 0.8862
# restart: 0, epoch: 314, iter: 1, loss: 0.8859
# restart: 0, epoch: 315, iter: 1, loss: 0.8856
# restart: 0, epoch: 316, iter: 1, loss: 0.8853
# restart: 0, epoch: 317, iter: 1, loss: 0.8850
# restart: 0, epoch: 318, iter: 1, loss: 0.8846
# restart: 0, epoch: 319, iter: 1, loss: 0.8843
# restart: 0, epoch: 320, iter: 1, loss: 0.8840
# restart: 0, epoch: 321, iter: 1, loss: 0.8837
# restart: 0, epoch: 322, iter: 1, loss: 0.8833
# restart: 0, epoch: 323, iter: 1, loss: 0.8830
# restart: 0, epoch: 324, iter: 1, loss: 0.8827
# restart: 0, epoch: 325, iter: 1, loss: 0.8824
# restart: 0, epoch: 326, iter: 1, loss: 0.8821
# restart: 0, epoch: 327, iter: 1, loss: 0.8817
# restart: 0, epoch: 328, iter: 1, loss: 0.8814
# restart: 0, epoch: 329, iter: 1, loss: 0.8811
# restart: 0, epoch: 330, iter: 1, loss: 0.8808
# restart: 0, epoch: 331, iter: 1, loss: 0.8805
# restart: 0, epoch: 332, iter: 1, loss: 0.8801
# restart: 0, epoch: 333, iter: 1, loss: 0.8798
# restart: 0, epoch: 334, iter: 1, loss: 0.8795
# restart: 0, epoch: 335, iter: 1, loss: 0.8792
# restart: 0, epoch: 336, iter: 1, loss: 0.8788
# restart: 0, epoch: 337, iter: 1, loss: 0.8785
# restart: 0, epoch: 338, iter: 1, loss: 0.8782
# restart: 0, epoch: 339, iter: 1, loss: 0.8779
# restart: 0, epoch: 340, iter: 1, loss: 0.8776
# restart: 0, epoch: 341, iter: 1, loss: 0.8772
# restart: 0, epoch: 342, iter: 1, loss: 0.8769
# restart: 0, epoch: 343, iter: 1, loss: 0.8766
# restart: 0, epoch: 344, iter: 1, loss: 0.8763
# restart: 0, epoch: 345, iter: 1, loss: 0.8760
# restart: 0, epoch: 346, iter: 1, loss: 0.8756
# restart: 0, epoch: 347, iter: 1, loss: 0.8753
# restart: 0, epoch: 348, iter: 1, loss: 0.8750
# restart: 0, epoch: 349, iter: 1, loss: 0.8747
# restart: 0, epoch: 350, iter: 1, loss: 0.8743
# restart: 0, epoch: 351, iter: 1, loss: 0.8740
# restart: 0, epoch: 352, iter: 1, loss: 0.8737
# restart: 0, epoch: 353, iter: 1, loss: 0.8734
# restart: 0, epoch: 354, iter: 1, loss: 0.8731
# restart: 0, epoch: 355, iter: 1, loss: 0.8727
# restart: 0, epoch: 356, iter: 1, loss: 0.8724
# restart: 0, epoch: 357, iter: 1, loss: 0.8721
# restart: 0, epoch: 358, iter: 1, loss: 0.8718
# restart: 0, epoch: 359, iter: 1, loss: 0.8715
# restart: 0, epoch: 360, iter: 1, loss: 0.8711
# restart: 0, epoch: 361, iter: 1, loss: 0.8708
# restart: 0, epoch: 362, iter: 1, loss: 0.8705
# restart: 0, epoch: 363, iter: 1, loss: 0.8702
# restart: 0, epoch: 364, iter: 1, loss: 0.8699
# restart: 0, epoch: 365, iter: 1, loss: 0.8695
# restart: 0, epoch: 366, iter: 1, loss: 0.8692
# restart: 0, epoch: 367, iter: 1, loss: 0.8689
# restart: 0, epoch: 368, iter: 1, loss: 0.8686
# restart: 0, epoch: 369, iter: 1, loss: 0.8683
# restart: 0, epoch: 370, iter: 1, loss: 0.8679
# restart: 0, epoch: 371, iter: 1, loss: 0.8676
# restart: 0, epoch: 372, iter: 1, loss: 0.8673
# restart: 0, epoch: 373, iter: 1, loss: 0.8670
# restart: 0, epoch: 374, iter: 1, loss: 0.8667
# restart: 0, epoch: 375, iter: 1, loss: 0.8663
# restart: 0, epoch: 376, iter: 1, loss: 0.8660
# restart: 0, epoch: 377, iter: 1, loss: 0.8657
# restart: 0, epoch: 378, iter: 1, loss: 0.8654
# restart: 0, epoch: 379, iter: 1, loss: 0.8651
# restart: 0, epoch: 380, iter: 1, loss: 0.8647
# restart: 0, epoch: 381, iter: 1, loss: 0.8644
# restart: 0, epoch: 382, iter: 1, loss: 0.8641
# restart: 0, epoch: 383, iter: 1, loss: 0.8638
# restart: 0, epoch: 384, iter: 1, loss: 0.8635
# restart: 0, epoch: 385, iter: 1, loss: 0.8632
# restart: 0, epoch: 386, iter: 1, loss: 0.8628
# restart: 0, epoch: 387, iter: 1, loss: 0.8625
# restart: 0, epoch: 388, iter: 1, loss: 0.8622
# restart: 0, epoch: 389, iter: 1, loss: 0.8619
# restart: 0, epoch: 390, iter: 1, loss: 0.8616
# restart: 0, epoch: 391, iter: 1, loss: 0.8613
# restart: 0, epoch: 392, iter: 1, loss: 0.8610
# restart: 0, epoch: 393, iter: 1, loss: 0.8606
# restart: 0, epoch: 394, iter: 1, loss: 0.8603
# restart: 0, epoch: 395, iter: 1, loss: 0.8600
# restart: 0, epoch: 396, iter: 1, loss: 0.8597
# restart: 0, epoch: 397, iter: 1, loss: 0.8594
# restart: 0, epoch: 398, iter: 1, loss: 0.8591
# restart: 0, epoch: 399, iter: 1, loss: 0.8588
# restart: 0, epoch: 400, iter: 1, loss: 0.8585
# restart: 0, epoch: 401, iter: 1, loss: 0.8581
# restart: 0, epoch: 402, iter: 1, loss: 0.8578
# restart: 0, epoch: 403, iter: 1, loss: 0.8575
# restart: 0, epoch: 404, iter: 1, loss: 0.8572
# restart: 0, epoch: 405, iter: 1, loss: 0.8569
# restart: 0, epoch: 406, iter: 1, loss: 0.8566
# restart: 0, epoch: 407, iter: 1, loss: 0.8563
# restart: 0, epoch: 408, iter: 1, loss: 0.8560
# restart: 0, epoch: 409, iter: 1, loss: 0.8557
# restart: 0, epoch: 410, iter: 1, loss: 0.8554
# restart: 0, epoch: 411, iter: 1, loss: 0.8551
# restart: 0, epoch: 412, iter: 1, loss: 0.8547
# restart: 0, epoch: 413, iter: 1, loss: 0.8544
# restart: 0, epoch: 414, iter: 1, loss: 0.8541
# restart: 0, epoch: 415, iter: 1, loss: 0.8538
# restart: 0, epoch: 416, iter: 1, loss: 0.8535
# restart: 0, epoch: 417, iter: 1, loss: 0.8532
# restart: 0, epoch: 418, iter: 1, loss: 0.8529
# restart: 0, epoch: 419, iter: 1, loss: 0.8526
# restart: 0, epoch: 420, iter: 1, loss: 0.8523
# restart: 0, epoch: 421, iter: 1, loss: 0.8520
# restart: 0, epoch: 422, iter: 1, loss: 0.8517
# restart: 0, epoch: 423, iter: 1, loss: 0.8514
# restart: 0, epoch: 424, iter: 1, loss: 0.8511
# restart: 0, epoch: 425, iter: 1, loss: 0.8508
# restart: 0, epoch: 426, iter: 1, loss: 0.8505
# restart: 0, epoch: 427, iter: 1, loss: 0.8502
# restart: 0, epoch: 428, iter: 1, loss: 0.8499
# restart: 0, epoch: 429, iter: 1, loss: 0.8496
# restart: 0, epoch: 430, iter: 1, loss: 0.8493
# restart: 0, epoch: 431, iter: 1, loss: 0.8489
# restart: 0, epoch: 432, iter: 1, loss: 0.8486
# restart: 0, epoch: 433, iter: 1, loss: 0.8483
# restart: 0, epoch: 434, iter: 1, loss: 0.8480
# restart: 0, epoch: 435, iter: 1, loss: 0.8477
# restart: 0, epoch: 436, iter: 1, loss: 0.8474
# restart: 0, epoch: 437, iter: 1, loss: 0.8471
# restart: 0, epoch: 438, iter: 1, loss: 0.8468
# restart: 0, epoch: 439, iter: 1, loss: 0.8465
# restart: 0, epoch: 440, iter: 1, loss: 0.8462
# restart: 0, epoch: 441, iter: 1, loss: 0.8459
# restart: 0, epoch: 442, iter: 1, loss: 0.8456
# restart: 0, epoch: 443, iter: 1, loss: 0.8453
# restart: 0, epoch: 444, iter: 1, loss: 0.8450
# restart: 0, epoch: 445, iter: 1, loss: 0.8447
# restart: 0, epoch: 446, iter: 1, loss: 0.8444
# restart: 0, epoch: 447, iter: 1, loss: 0.8441
# restart: 0, epoch: 448, iter: 1, loss: 0.8439
# restart: 0, epoch: 449, iter: 1, loss: 0.8436
# restart: 0, epoch: 450, iter: 1, loss: 0.8433
# restart: 0, epoch: 451, iter: 1, loss: 0.8430
# restart: 0, epoch: 452, iter: 1, loss: 0.8427
# restart: 0, epoch: 453, iter: 1, loss: 0.8424
# restart: 0, epoch: 454, iter: 1, loss: 0.8421
# restart: 0, epoch: 455, iter: 1, loss: 0.8418
# restart: 0, epoch: 456, iter: 1, loss: 0.8415
# restart: 0, epoch: 457, iter: 1, loss: 0.8412
# restart: 0, epoch: 458, iter: 1, loss: 0.8409
# restart: 0, epoch: 459, iter: 1, loss: 0.8406
# restart: 0, epoch: 460, iter: 1, loss: 0.8403
# restart: 0, epoch: 461, iter: 1, loss: 0.8400
# restart: 0, epoch: 462, iter: 1, loss: 0.8397
# restart: 0, epoch: 463, iter: 1, loss: 0.8394
# restart: 0, epoch: 464, iter: 1, loss: 0.8391
# restart: 0, epoch: 465, iter: 1, loss: 0.8389
# restart: 0, epoch: 466, iter: 1, loss: 0.8386
# restart: 0, epoch: 467, iter: 1, loss: 0.8383
# restart: 0, epoch: 468, iter: 1, loss: 0.8380
# restart: 0, epoch: 469, iter: 1, loss: 0.8377
# restart: 0, epoch: 470, iter: 1, loss: 0.8374
# restart: 0, epoch: 471, iter: 1, loss: 0.8371
# restart: 0, epoch: 472, iter: 1, loss: 0.8368
# restart: 0, epoch: 473, iter: 1, loss: 0.8365
# restart: 0, epoch: 474, iter: 1, loss: 0.8363
# restart: 0, epoch: 475, iter: 1, loss: 0.8360
# restart: 0, epoch: 476, iter: 1, loss: 0.8357
# restart: 0, epoch: 477, iter: 1, loss: 0.8354
# restart: 0, epoch: 478, iter: 1, loss: 0.8351
# restart: 0, epoch: 479, iter: 1, loss: 0.8348
# restart: 0, epoch: 480, iter: 1, loss: 0.8345
# restart: 0, epoch: 481, iter: 1, loss: 0.8343
# restart: 0, epoch: 482, iter: 1, loss: 0.8340
# restart: 0, epoch: 483, iter: 1, loss: 0.8337
# restart: 0, epoch: 484, iter: 1, loss: 0.8334
# restart: 0, epoch: 485, iter: 1, loss: 0.8331
# restart: 0, epoch: 486, iter: 1, loss: 0.8328
# restart: 0, epoch: 487, iter: 1, loss: 0.8326
# restart: 0, epoch: 488, iter: 1, loss: 0.8323
# restart: 0, epoch: 489, iter: 1, loss: 0.8320
# restart: 0, epoch: 490, iter: 1, loss: 0.8317
# restart: 0, epoch: 491, iter: 1, loss: 0.8314
# restart: 0, epoch: 492, iter: 1, loss: 0.8312
# restart: 0, epoch: 493, iter: 1, loss: 0.8309
# restart: 0, epoch: 494, iter: 1, loss: 0.8306
# restart: 0, epoch: 495, iter: 1, loss: 0.8303
# restart: 0, epoch: 496, iter: 1, loss: 0.8300
# restart: 0, epoch: 497, iter: 1, loss: 0.8298
# restart: 0, epoch: 498, iter: 1, loss: 0.8295
# restart: 0, epoch: 499, iter: 1, loss: 0.8292
# restart: 0, epoch: 500, iter: 1, loss: 0.8289
# restart: 0, epoch: 501, iter: 1, loss: 0.8287
# restart: 0, epoch: 502, iter: 1, loss: 0.8284
# restart: 0, epoch: 503, iter: 1, loss: 0.8281
# restart: 0, epoch: 504, iter: 1, loss: 0.8278
# restart: 0, epoch: 505, iter: 1, loss: 0.8276
# restart: 0, epoch: 506, iter: 1, loss: 0.8273
# restart: 0, epoch: 507, iter: 1, loss: 0.8270
# restart: 0, epoch: 508, iter: 1, loss: 0.8267
# restart: 0, epoch: 509, iter: 1, loss: 0.8265
# restart: 0, epoch: 510, iter: 1, loss: 0.8262
# restart: 0, epoch: 511, iter: 1, loss: 0.8259
# restart: 0, epoch: 512, iter: 1, loss: 0.8257
# restart: 0, epoch: 513, iter: 1, loss: 0.8254
# restart: 0, epoch: 514, iter: 1, loss: 0.8251
# restart: 0, epoch: 515, iter: 1, loss: 0.8248
# restart: 0, epoch: 516, iter: 1, loss: 0.8246
# restart: 0, epoch: 517, iter: 1, loss: 0.8243
# restart: 0, epoch: 518, iter: 1, loss: 0.8240
# restart: 0, epoch: 519, iter: 1, loss: 0.8238
# restart: 0, epoch: 520, iter: 1, loss: 0.8235
# restart: 0, epoch: 521, iter: 1, loss: 0.8232
# restart: 0, epoch: 522, iter: 1, loss: 0.8229
# restart: 0, epoch: 523, iter: 1, loss: 0.8227
# restart: 0, epoch: 524, iter: 1, loss: 0.8224
# restart: 0, epoch: 525, iter: 1, loss: 0.8221
# restart: 0, epoch: 526, iter: 1, loss: 0.8219
# restart: 0, epoch: 527, iter: 1, loss: 0.8216
# restart: 0, epoch: 528, iter: 1, loss: 0.8213
# restart: 0, epoch: 529, iter: 1, loss: 0.8211
# restart: 0, epoch: 530, iter: 1, loss: 0.8208
# restart: 0, epoch: 531, iter: 1, loss: 0.8205
# restart: 0, epoch: 532, iter: 1, loss: 0.8203
# restart: 0, epoch: 533, iter: 1, loss: 0.8200
# restart: 0, epoch: 534, iter: 1, loss: 0.8197
# restart: 0, epoch: 535, iter: 1, loss: 0.8195
# restart: 0, epoch: 536, iter: 1, loss: 0.8192
# restart: 0, epoch: 537, iter: 1, loss: 0.8189
# restart: 0, epoch: 538, iter: 1, loss: 0.8187
# restart: 0, epoch: 539, iter: 1, loss: 0.8184
# restart: 0, epoch: 540, iter: 1, loss: 0.8182
# restart: 0, epoch: 541, iter: 1, loss: 0.8179
# restart: 0, epoch: 542, iter: 1, loss: 0.8176
# restart: 0, epoch: 543, iter: 1, loss: 0.8174
# restart: 0, epoch: 544, iter: 1, loss: 0.8171
# restart: 0, epoch: 545, iter: 1, loss: 0.8168
# restart: 0, epoch: 546, iter: 1, loss: 0.8166
# restart: 0, epoch: 547, iter: 1, loss: 0.8163
# restart: 0, epoch: 548, iter: 1, loss: 0.8161
# restart: 0, epoch: 549, iter: 1, loss: 0.8158
# restart: 0, epoch: 550, iter: 1, loss: 0.8155
# restart: 0, epoch: 551, iter: 1, loss: 0.8153
# restart: 0, epoch: 552, iter: 1, loss: 0.8150
# restart: 0, epoch: 553, iter: 1, loss: 0.8147
# restart: 0, epoch: 554, iter: 1, loss: 0.8145
# restart: 0, epoch: 555, iter: 1, loss: 0.8142
# restart: 0, epoch: 556, iter: 1, loss: 0.8140
# restart: 0, epoch: 557, iter: 1, loss: 0.8137
# restart: 0, epoch: 558, iter: 1, loss: 0.8134
# restart: 0, epoch: 559, iter: 1, loss: 0.8132
# restart: 0, epoch: 560, iter: 1, loss: 0.8129
# restart: 0, epoch: 561, iter: 1, loss: 0.8127
# restart: 0, epoch: 562, iter: 1, loss: 0.8124
# restart: 0, epoch: 563, iter: 1, loss: 0.8121
# restart: 0, epoch: 564, iter: 1, loss: 0.8119
# restart: 0, epoch: 565, iter: 1, loss: 0.8116
# restart: 0, epoch: 566, iter: 1, loss: 0.8114
# restart: 0, epoch: 567, iter: 1, loss: 0.8111
# restart: 0, epoch: 568, iter: 1, loss: 0.8108
# restart: 0, epoch: 569, iter: 1, loss: 0.8106
# restart: 0, epoch: 570, iter: 1, loss: 0.8103
# restart: 0, epoch: 571, iter: 1, loss: 0.8101
# restart: 0, epoch: 572, iter: 1, loss: 0.8098
# restart: 0, epoch: 573, iter: 1, loss: 0.8095
# restart: 0, epoch: 574, iter: 1, loss: 0.8093
# restart: 0, epoch: 575, iter: 1, loss: 0.8090
# restart: 0, epoch: 576, iter: 1, loss: 0.8088
# restart: 0, epoch: 577, iter: 1, loss: 0.8085
# restart: 0, epoch: 578, iter: 1, loss: 0.8082
# restart: 0, epoch: 579, iter: 1, loss: 0.8080
# restart: 0, epoch: 580, iter: 1, loss: 0.8077
# restart: 0, epoch: 581, iter: 1, loss: 0.8075
# restart: 0, epoch: 582, iter: 1, loss: 0.8072
# restart: 0, epoch: 583, iter: 1, loss: 0.8070
# restart: 0, epoch: 584, iter: 1, loss: 0.8067
# restart: 0, epoch: 585, iter: 1, loss: 0.8064
# restart: 0, epoch: 586, iter: 1, loss: 0.8062
# restart: 0, epoch: 587, iter: 1, loss: 0.8059
# restart: 0, epoch: 588, iter: 1, loss: 0.8057
# restart: 0, epoch: 589, iter: 1, loss: 0.8054
# restart: 0, epoch: 590, iter: 1, loss: 0.8051
# restart: 0, epoch: 591, iter: 1, loss: 0.8049
# restart: 0, epoch: 592, iter: 1, loss: 0.8046
# restart: 0, epoch: 593, iter: 1, loss: 0.8044
# restart: 0, epoch: 594, iter: 1, loss: 0.8041
# restart: 0, epoch: 595, iter: 1, loss: 0.8039
# restart: 0, epoch: 596, iter: 1, loss: 0.8036
# restart: 0, epoch: 597, iter: 1, loss: 0.8033
# restart: 0, epoch: 598, iter: 1, loss: 0.8031
# restart: 0, epoch: 599, iter: 1, loss: 0.8028
# restart: 0, epoch: 600, iter: 1, loss: 0.8026
# restart: 0, epoch: 601, iter: 1, loss: 0.8023
# restart: 0, epoch: 602, iter: 1, loss: 0.8021
# restart: 0, epoch: 603, iter: 1, loss: 0.8018
# restart: 0, epoch: 604, iter: 1, loss: 0.8016
# restart: 0, epoch: 605, iter: 1, loss: 0.8013
# restart: 0, epoch: 606, iter: 1, loss: 0.8011
# restart: 0, epoch: 607, iter: 1, loss: 0.8008
# restart: 0, epoch: 608, iter: 1, loss: 0.8005
# restart: 0, epoch: 609, iter: 1, loss: 0.8003
# restart: 0, epoch: 610, iter: 1, loss: 0.8000
# restart: 0, epoch: 611, iter: 1, loss: 0.7998
# restart: 0, epoch: 612, iter: 1, loss: 0.7995
# restart: 0, epoch: 613, iter: 1, loss: 0.7993
# restart: 0, epoch: 614, iter: 1, loss: 0.7990
# restart: 0, epoch: 615, iter: 1, loss: 0.7988
# restart: 0, epoch: 616, iter: 1, loss: 0.7985
# restart: 0, epoch: 617, iter: 1, loss: 0.7983
# restart: 0, epoch: 618, iter: 1, loss: 0.7980
# restart: 0, epoch: 619, iter: 1, loss: 0.7978
# restart: 0, epoch: 620, iter: 1, loss: 0.7975
# restart: 0, epoch: 621, iter: 1, loss: 0.7973
# restart: 0, epoch: 622, iter: 1, loss: 0.7970
# restart: 0, epoch: 623, iter: 1, loss: 0.7968
# restart: 0, epoch: 624, iter: 1, loss: 0.7965
# restart: 0, epoch: 625, iter: 1, loss: 0.7963
# restart: 0, epoch: 626, iter: 1, loss: 0.7960
# restart: 0, epoch: 627, iter: 1, loss: 0.7958
# restart: 0, epoch: 628, iter: 1, loss: 0.7955
# restart: 0, epoch: 629, iter: 1, loss: 0.7953
# restart: 0, epoch: 630, iter: 1, loss: 0.7950
# restart: 0, epoch: 631, iter: 1, loss: 0.7948
# restart: 0, epoch: 632, iter: 1, loss: 0.7945
# restart: 0, epoch: 633, iter: 1, loss: 0.7943
# restart: 0, epoch: 634, iter: 1, loss: 0.7940
# restart: 0, epoch: 635, iter: 1, loss: 0.7938
# restart: 0, epoch: 636, iter: 1, loss: 0.7935
# restart: 0, epoch: 637, iter: 1, loss: 0.7933
# restart: 0, epoch: 638, iter: 1, loss: 0.7930
# restart: 0, epoch: 639, iter: 1, loss: 0.7928
# restart: 0, epoch: 640, iter: 1, loss: 0.7925
# restart: 0, epoch: 641, iter: 1, loss: 0.7923
# restart: 0, epoch: 642, iter: 1, loss: 0.7920
# restart: 0, epoch: 643, iter: 1, loss: 0.7918
# restart: 0, epoch: 644, iter: 1, loss: 0.7915
# restart: 0, epoch: 645, iter: 1, loss: 0.7913
# restart: 0, epoch: 646, iter: 1, loss: 0.7911
# restart: 0, epoch: 647, iter: 1, loss: 0.7908
# restart: 0, epoch: 648, iter: 1, loss: 0.7906
# restart: 0, epoch: 649, iter: 1, loss: 0.7903
# restart: 0, epoch: 650, iter: 1, loss: 0.7901
# restart: 0, epoch: 651, iter: 1, loss: 0.7898
# restart: 0, epoch: 652, iter: 1, loss: 0.7896
# restart: 0, epoch: 653, iter: 1, loss: 0.7893
# restart: 0, epoch: 654, iter: 1, loss: 0.7891
# restart: 0, epoch: 655, iter: 1, loss: 0.7889
# restart: 0, epoch: 656, iter: 1, loss: 0.7886
# restart: 0, epoch: 657, iter: 1, loss: 0.7884
# restart: 0, epoch: 658, iter: 1, loss: 0.7881
# restart: 0, epoch: 659, iter: 1, loss: 0.7879
# restart: 0, epoch: 660, iter: 1, loss: 0.7876
# restart: 0, epoch: 661, iter: 1, loss: 0.7874
# restart: 0, epoch: 662, iter: 1, loss: 0.7872
# restart: 0, epoch: 663, iter: 1, loss: 0.7869
# restart: 0, epoch: 664, iter: 1, loss: 0.7867
# restart: 0, epoch: 665, iter: 1, loss: 0.7864
# restart: 0, epoch: 666, iter: 1, loss: 0.7862
# restart: 0, epoch: 667, iter: 1, loss: 0.7860
# restart: 0, epoch: 668, iter: 1, loss: 0.7857
# restart: 0, epoch: 669, iter: 1, loss: 0.7855
# restart: 0, epoch: 670, iter: 1, loss: 0.7852
# restart: 0, epoch: 671, iter: 1, loss: 0.7850
# restart: 0, epoch: 672, iter: 1, loss: 0.7847
# restart: 0, epoch: 673, iter: 1, loss: 0.7845
# restart: 0, epoch: 674, iter: 1, loss: 0.7843
# restart: 0, epoch: 675, iter: 1, loss: 0.7840
# restart: 0, epoch: 676, iter: 1, loss: 0.7838
# restart: 0, epoch: 677, iter: 1, loss: 0.7835
# restart: 0, epoch: 678, iter: 1, loss: 0.7833
# restart: 0, epoch: 679, iter: 1, loss: 0.7831
# restart: 0, epoch: 680, iter: 1, loss: 0.7828
# restart: 0, epoch: 681, iter: 1, loss: 0.7826
# restart: 0, epoch: 682, iter: 1, loss: 0.7824
# restart: 0, epoch: 683, iter: 1, loss: 0.7821
# restart: 0, epoch: 684, iter: 1, loss: 0.7819
# restart: 0, epoch: 685, iter: 1, loss: 0.7816
# restart: 0, epoch: 686, iter: 1, loss: 0.7814
# restart: 0, epoch: 687, iter: 1, loss: 0.7812
# restart: 0, epoch: 688, iter: 1, loss: 0.7809
# restart: 0, epoch: 689, iter: 1, loss: 0.7807
# restart: 0, epoch: 690, iter: 1, loss: 0.7804
# restart: 0, epoch: 691, iter: 1, loss: 0.7802
# restart: 0, epoch: 692, iter: 1, loss: 0.7800
# restart: 0, epoch: 693, iter: 1, loss: 0.7797
# restart: 0, epoch: 694, iter: 1, loss: 0.7795
# restart: 0, epoch: 695, iter: 1, loss: 0.7793
# restart: 0, epoch: 696, iter: 1, loss: 0.7790
# restart: 0, epoch: 697, iter: 1, loss: 0.7788
# restart: 0, epoch: 698, iter: 1, loss: 0.7785
# restart: 0, epoch: 699, iter: 1, loss: 0.7783
# restart: 0, epoch: 700, iter: 1, loss: 0.7781
# restart: 0, epoch: 701, iter: 1, loss: 0.7778
# restart: 0, epoch: 702, iter: 1, loss: 0.7776
# restart: 0, epoch: 703, iter: 1, loss: 0.7774
# restart: 0, epoch: 704, iter: 1, loss: 0.7771
# restart: 0, epoch: 705, iter: 1, loss: 0.7769
# restart: 0, epoch: 706, iter: 1, loss: 0.7767
# restart: 0, epoch: 707, iter: 1, loss: 0.7764
# restart: 0, epoch: 708, iter: 1, loss: 0.7762
# restart: 0, epoch: 709, iter: 1, loss: 0.7760
# restart: 0, epoch: 710, iter: 1, loss: 0.7757
# restart: 0, epoch: 711, iter: 1, loss: 0.7755
# restart: 0, epoch: 712, iter: 1, loss: 0.7752
# restart: 0, epoch: 713, iter: 1, loss: 0.7750
# restart: 0, epoch: 714, iter: 1, loss: 0.7748
# restart: 0, epoch: 715, iter: 1, loss: 0.7745
# restart: 0, epoch: 716, iter: 1, loss: 0.7743
# restart: 0, epoch: 717, iter: 1, loss: 0.7741
# restart: 0, epoch: 718, iter: 1, loss: 0.7738
# restart: 0, epoch: 719, iter: 1, loss: 0.7736
# restart: 0, epoch: 720, iter: 1, loss: 0.7734
# restart: 0, epoch: 721, iter: 1, loss: 0.7731
# restart: 0, epoch: 722, iter: 1, loss: 0.7729
# restart: 0, epoch: 723, iter: 1, loss: 0.7727
# restart: 0, epoch: 724, iter: 1, loss: 0.7724
# restart: 0, epoch: 725, iter: 1, loss: 0.7722
# restart: 0, epoch: 726, iter: 1, loss: 0.7720
# restart: 0, epoch: 727, iter: 1, loss: 0.7717
# restart: 0, epoch: 728, iter: 1, loss: 0.7715
# restart: 0, epoch: 729, iter: 1, loss: 0.7713
# restart: 0, epoch: 730, iter: 1, loss: 0.7710
# restart: 0, epoch: 731, iter: 1, loss: 0.7708
# restart: 0, epoch: 732, iter: 1, loss: 0.7706
# restart: 0, epoch: 733, iter: 1, loss: 0.7703
# restart: 0, epoch: 734, iter: 1, loss: 0.7701
# restart: 0, epoch: 735, iter: 1, loss: 0.7699
# restart: 0, epoch: 736, iter: 1, loss: 0.7696
# restart: 0, epoch: 737, iter: 1, loss: 0.7694
# restart: 0, epoch: 738, iter: 1, loss: 0.7692
# restart: 0, epoch: 739, iter: 1, loss: 0.7689
# restart: 0, epoch: 740, iter: 1, loss: 0.7687
# restart: 0, epoch: 741, iter: 1, loss: 0.7685
# restart: 0, epoch: 742, iter: 1, loss: 0.7683
# restart: 0, epoch: 743, iter: 1, loss: 0.7680
# restart: 0, epoch: 744, iter: 1, loss: 0.7678
# restart: 0, epoch: 745, iter: 1, loss: 0.7676
# restart: 0, epoch: 746, iter: 1, loss: 0.7673
# restart: 0, epoch: 747, iter: 1, loss: 0.7671
# restart: 0, epoch: 748, iter: 1, loss: 0.7669
# restart: 0, epoch: 749, iter: 1, loss: 0.7666
# restart: 0, epoch: 750, iter: 1, loss: 0.7664
# restart: 0, epoch: 751, iter: 1, loss: 0.7662
# restart: 0, epoch: 752, iter: 1, loss: 0.7659
# restart: 0, epoch: 753, iter: 1, loss: 0.7657
# restart: 0, epoch: 754, iter: 1, loss: 0.7655
# restart: 0, epoch: 755, iter: 1, loss: 0.7652
# restart: 0, epoch: 756, iter: 1, loss: 0.7650
# restart: 0, epoch: 757, iter: 1, loss: 0.7648
# restart: 0, epoch: 758, iter: 1, loss: 0.7646
# restart: 0, epoch: 759, iter: 1, loss: 0.7643
# restart: 0, epoch: 760, iter: 1, loss: 0.7641
# restart: 0, epoch: 761, iter: 1, loss: 0.7639
# restart: 0, epoch: 762, iter: 1, loss: 0.7636
# restart: 0, epoch: 763, iter: 1, loss: 0.7634
# restart: 0, epoch: 764, iter: 1, loss: 0.7632
# restart: 0, epoch: 765, iter: 1, loss: 0.7630
# restart: 0, epoch: 766, iter: 1, loss: 0.7627
# restart: 0, epoch: 767, iter: 1, loss: 0.7625
# restart: 0, epoch: 768, iter: 1, loss: 0.7623
# restart: 0, epoch: 769, iter: 1, loss: 0.7620
# restart: 0, epoch: 770, iter: 1, loss: 0.7618
# restart: 0, epoch: 771, iter: 1, loss: 0.7616
# restart: 0, epoch: 772, iter: 1, loss: 0.7614
# restart: 0, epoch: 773, iter: 1, loss: 0.7611
# restart: 0, epoch: 774, iter: 1, loss: 0.7609
# restart: 0, epoch: 775, iter: 1, loss: 0.7607
# restart: 0, epoch: 776, iter: 1, loss: 0.7604
# restart: 0, epoch: 777, iter: 1, loss: 0.7602
# restart: 0, epoch: 778, iter: 1, loss: 0.7600
# restart: 0, epoch: 779, iter: 1, loss: 0.7598
# restart: 0, epoch: 780, iter: 1, loss: 0.7595
# restart: 0, epoch: 781, iter: 1, loss: 0.7593
# restart: 0, epoch: 782, iter: 1, loss: 0.7591
# restart: 0, epoch: 783, iter: 1, loss: 0.7589
# restart: 0, epoch: 784, iter: 1, loss: 0.7586
# restart: 0, epoch: 785, iter: 1, loss: 0.7584
# restart: 0, epoch: 786, iter: 1, loss: 0.7582
# restart: 0, epoch: 787, iter: 1, loss: 0.7580
# restart: 0, epoch: 788, iter: 1, loss: 0.7577
# restart: 0, epoch: 789, iter: 1, loss: 0.7575
# restart: 0, epoch: 790, iter: 1, loss: 0.7573
# restart: 0, epoch: 791, iter: 1, loss: 0.7571
# restart: 0, epoch: 792, iter: 1, loss: 0.7568
# restart: 0, epoch: 793, iter: 1, loss: 0.7566
# restart: 0, epoch: 794, iter: 1, loss: 0.7564
# restart: 0, epoch: 795, iter: 1, loss: 0.7562
# restart: 0, epoch: 796, iter: 1, loss: 0.7559
# restart: 0, epoch: 797, iter: 1, loss: 0.7557
# restart: 0, epoch: 798, iter: 1, loss: 0.7555
# restart: 0, epoch: 799, iter: 1, loss: 0.7553
# restart: 0, epoch: 800, iter: 1, loss: 0.7550
# restart: 0, epoch: 801, iter: 1, loss: 0.7548
# restart: 0, epoch: 802, iter: 1, loss: 0.7546
# restart: 0, epoch: 803, iter: 1, loss: 0.7544
# restart: 0, epoch: 804, iter: 1, loss: 0.7542
# restart: 0, epoch: 805, iter: 1, loss: 0.7539
# restart: 0, epoch: 806, iter: 1, loss: 0.7537
# restart: 0, epoch: 807, iter: 1, loss: 0.7535
# restart: 0, epoch: 808, iter: 1, loss: 0.7533
# restart: 0, epoch: 809, iter: 1, loss: 0.7530
# restart: 0, epoch: 810, iter: 1, loss: 0.7528
# restart: 0, epoch: 811, iter: 1, loss: 0.7526
# restart: 0, epoch: 812, iter: 1, loss: 0.7524
# restart: 0, epoch: 813, iter: 1, loss: 0.7522
# restart: 0, epoch: 814, iter: 1, loss: 0.7519
# restart: 0, epoch: 815, iter: 1, loss: 0.7517
# restart: 0, epoch: 816, iter: 1, loss: 0.7515
# restart: 0, epoch: 817, iter: 1, loss: 0.7513
# restart: 0, epoch: 818, iter: 1, loss: 0.7511
# restart: 0, epoch: 819, iter: 1, loss: 0.7508
# restart: 0, epoch: 820, iter: 1, loss: 0.7506
# restart: 0, epoch: 821, iter: 1, loss: 0.7504
# restart: 0, epoch: 822, iter: 1, loss: 0.7502
# restart: 0, epoch: 823, iter: 1, loss: 0.7500
# restart: 0, epoch: 824, iter: 1, loss: 0.7497
# restart: 0, epoch: 825, iter: 1, loss: 0.7495
# restart: 0, epoch: 826, iter: 1, loss: 0.7493
# restart: 0, epoch: 827, iter: 1, loss: 0.7491
# restart: 0, epoch: 828, iter: 1, loss: 0.7489
# restart: 0, epoch: 829, iter: 1, loss: 0.7486
# restart: 0, epoch: 830, iter: 1, loss: 0.7484
# restart: 0, epoch: 831, iter: 1, loss: 0.7482
# restart: 0, epoch: 832, iter: 1, loss: 0.7480
# restart: 0, epoch: 833, iter: 1, loss: 0.7478
# restart: 0, epoch: 834, iter: 1, loss: 0.7476
# restart: 0, epoch: 835, iter: 1, loss: 0.7473
# restart: 0, epoch: 836, iter: 1, loss: 0.7471
# restart: 0, epoch: 837, iter: 1, loss: 0.7469
# restart: 0, epoch: 838, iter: 1, loss: 0.7467
# restart: 0, epoch: 839, iter: 1, loss: 0.7465
# restart: 0, epoch: 840, iter: 1, loss: 0.7463
# restart: 0, epoch: 841, iter: 1, loss: 0.7460
# restart: 0, epoch: 842, iter: 1, loss: 0.7458
# restart: 0, epoch: 843, iter: 1, loss: 0.7456
# restart: 0, epoch: 844, iter: 1, loss: 0.7454
# restart: 0, epoch: 845, iter: 1, loss: 0.7452
# restart: 0, epoch: 846, iter: 1, loss: 0.7450
# restart: 0, epoch: 847, iter: 1, loss: 0.7448
# restart: 0, epoch: 848, iter: 1, loss: 0.7445
# restart: 0, epoch: 849, iter: 1, loss: 0.7443
# restart: 0, epoch: 850, iter: 1, loss: 0.7441
# restart: 0, epoch: 851, iter: 1, loss: 0.7439
# restart: 0, epoch: 852, iter: 1, loss: 0.7437
# restart: 0, epoch: 853, iter: 1, loss: 0.7435
# restart: 0, epoch: 854, iter: 1, loss: 0.7433
# restart: 0, epoch: 855, iter: 1, loss: 0.7431
# restart: 0, epoch: 856, iter: 1, loss: 0.7428
# restart: 0, epoch: 857, iter: 1, loss: 0.7426
# restart: 0, epoch: 858, iter: 1, loss: 0.7424
# restart: 0, epoch: 859, iter: 1, loss: 0.7422
# restart: 0, epoch: 860, iter: 1, loss: 0.7420
# restart: 0, epoch: 861, iter: 1, loss: 0.7418
# restart: 0, epoch: 862, iter: 1, loss: 0.7416
# restart: 0, epoch: 863, iter: 1, loss: 0.7414
# restart: 0, epoch: 864, iter: 1, loss: 0.7411
# restart: 0, epoch: 865, iter: 1, loss: 0.7409
# restart: 0, epoch: 866, iter: 1, loss: 0.7407
# restart: 0, epoch: 867, iter: 1, loss: 0.7405
# restart: 0, epoch: 868, iter: 1, loss: 0.7403
# restart: 0, epoch: 869, iter: 1, loss: 0.7401
# restart: 0, epoch: 870, iter: 1, loss: 0.7399
# restart: 0, epoch: 871, iter: 1, loss: 0.7397
# restart: 0, epoch: 872, iter: 1, loss: 0.7395
# restart: 0, epoch: 873, iter: 1, loss: 0.7393
# restart: 0, epoch: 874, iter: 1, loss: 0.7391
# restart: 0, epoch: 875, iter: 1, loss: 0.7388
# restart: 0, epoch: 876, iter: 1, loss: 0.7386
# restart: 0, epoch: 877, iter: 1, loss: 0.7384
# restart: 0, epoch: 878, iter: 1, loss: 0.7382
# restart: 0, epoch: 879, iter: 1, loss: 0.7380
# restart: 0, epoch: 880, iter: 1, loss: 0.7378
# restart: 0, epoch: 881, iter: 1, loss: 0.7376
# restart: 0, epoch: 882, iter: 1, loss: 0.7374
# restart: 0, epoch: 883, iter: 1, loss: 0.7372
# restart: 0, epoch: 884, iter: 1, loss: 0.7370
# restart: 0, epoch: 885, iter: 1, loss: 0.7368
# restart: 0, epoch: 886, iter: 1, loss: 0.7366
# restart: 0, epoch: 887, iter: 1, loss: 0.7364
# restart: 0, epoch: 888, iter: 1, loss: 0.7362
# restart: 0, epoch: 889, iter: 1, loss: 0.7359
# restart: 0, epoch: 890, iter: 1, loss: 0.7357
# restart: 0, epoch: 891, iter: 1, loss: 0.7355
# restart: 0, epoch: 892, iter: 1, loss: 0.7353
# restart: 0, epoch: 893, iter: 1, loss: 0.7351
# restart: 0, epoch: 894, iter: 1, loss: 0.7349
# restart: 0, epoch: 895, iter: 1, loss: 0.7347
# restart: 0, epoch: 896, iter: 1, loss: 0.7345
# restart: 0, epoch: 897, iter: 1, loss: 0.7343
# restart: 0, epoch: 898, iter: 1, loss: 0.7341
# restart: 0, epoch: 899, iter: 1, loss: 0.7339
# restart: 0, epoch: 900, iter: 1, loss: 0.7337
# restart: 0, epoch: 901, iter: 1, loss: 0.7335
# restart: 0, epoch: 902, iter: 1, loss: 0.7333
# restart: 0, epoch: 903, iter: 1, loss: 0.7331
# restart: 0, epoch: 904, iter: 1, loss: 0.7329
# restart: 0, epoch: 905, iter: 1, loss: 0.7327
# restart: 0, epoch: 906, iter: 1, loss: 0.7324
# restart: 0, epoch: 907, iter: 1, loss: 0.7322
# restart: 0, epoch: 908, iter: 1, loss: 0.7320
# restart: 0, epoch: 909, iter: 1, loss: 0.7318
# restart: 0, epoch: 910, iter: 1, loss: 0.7316
# restart: 0, epoch: 911, iter: 1, loss: 0.7314
# restart: 0, epoch: 912, iter: 1, loss: 0.7312
# restart: 0, epoch: 913, iter: 1, loss: 0.7310
# restart: 0, epoch: 914, iter: 1, loss: 0.7308
# restart: 0, epoch: 915, iter: 1, loss: 0.7306
# restart: 0, epoch: 916, iter: 1, loss: 0.7304
# restart: 0, epoch: 917, iter: 1, loss: 0.7302
# restart: 0, epoch: 918, iter: 1, loss: 0.7300
# restart: 0, epoch: 919, iter: 1, loss: 0.7298
# restart: 0, epoch: 920, iter: 1, loss: 0.7296
# restart: 0, epoch: 921, iter: 1, loss: 0.7294
# restart: 0, epoch: 922, iter: 1, loss: 0.7292
# restart: 0, epoch: 923, iter: 1, loss: 0.7290
# restart: 0, epoch: 924, iter: 1, loss: 0.7288
# restart: 0, epoch: 925, iter: 1, loss: 0.7286
# restart: 0, epoch: 926, iter: 1, loss: 0.7284
# restart: 0, epoch: 927, iter: 1, loss: 0.7281
# restart: 0, epoch: 928, iter: 1, loss: 0.7279
# restart: 0, epoch: 929, iter: 1, loss: 0.7277
# restart: 0, epoch: 930, iter: 1, loss: 0.7275
# restart: 0, epoch: 931, iter: 1, loss: 0.7273
# restart: 0, epoch: 932, iter: 1, loss: 0.7271
# restart: 0, epoch: 933, iter: 1, loss: 0.7269
# restart: 0, epoch: 934, iter: 1, loss: 0.7267
# restart: 0, epoch: 935, iter: 1, loss: 0.7265
# restart: 0, epoch: 936, iter: 1, loss: 0.7263
# restart: 0, epoch: 937, iter: 1, loss: 0.7261
# restart: 0, epoch: 938, iter: 1, loss: 0.7259
# restart: 0, epoch: 939, iter: 1, loss: 0.7257
# restart: 0, epoch: 940, iter: 1, loss: 0.7255
# restart: 0, epoch: 941, iter: 1, loss: 0.7253
# restart: 0, epoch: 942, iter: 1, loss: 0.7251
# restart: 0, epoch: 943, iter: 1, loss: 0.7249
# restart: 0, epoch: 944, iter: 1, loss: 0.7247
# restart: 0, epoch: 945, iter: 1, loss: 0.7245
# restart: 0, epoch: 946, iter: 1, loss: 0.7243
# restart: 0, epoch: 947, iter: 1, loss: 0.7241
# restart: 0, epoch: 948, iter: 1, loss: 0.7239
# restart: 0, epoch: 949, iter: 1, loss: 0.7237
# restart: 0, epoch: 950, iter: 1, loss: 0.7235
# restart: 0, epoch: 951, iter: 1, loss: 0.7232
# restart: 0, epoch: 952, iter: 1, loss: 0.7230
# restart: 0, epoch: 953, iter: 1, loss: 0.7228
# restart: 0, epoch: 954, iter: 1, loss: 0.7226
# restart: 0, epoch: 955, iter: 1, loss: 0.7224
# restart: 0, epoch: 956, iter: 1, loss: 0.7222
# restart: 0, epoch: 957, iter: 1, loss: 0.7220
# restart: 0, epoch: 958, iter: 1, loss: 0.7218
# restart: 0, epoch: 959, iter: 1, loss: 0.7216
# restart: 0, epoch: 960, iter: 1, loss: 0.7214
# restart: 0, epoch: 961, iter: 1, loss: 0.7212
# restart: 0, epoch: 962, iter: 1, loss: 0.7210
# restart: 0, epoch: 963, iter: 1, loss: 0.7208
# restart: 0, epoch: 964, iter: 1, loss: 0.7206
# restart: 0, epoch: 965, iter: 1, loss: 0.7204
# restart: 0, epoch: 966, iter: 1, loss: 0.7202
# restart: 0, epoch: 967, iter: 1, loss: 0.7200
# restart: 0, epoch: 968, iter: 1, loss: 0.7198
# restart: 0, epoch: 969, iter: 1, loss: 0.7196
# restart: 0, epoch: 970, iter: 1, loss: 0.7194
# restart: 0, epoch: 971, iter: 1, loss: 0.7192
# restart: 0, epoch: 972, iter: 1, loss: 0.7190
# restart: 0, epoch: 973, iter: 1, loss: 0.7188
# restart: 0, epoch: 974, iter: 1, loss: 0.7186
# restart: 0, epoch: 975, iter: 1, loss: 0.7184
# restart: 0, epoch: 976, iter: 1, loss: 0.7182
# restart: 0, epoch: 977, iter: 1, loss: 0.7180
# restart: 0, epoch: 978, iter: 1, loss: 0.7178
# restart: 0, epoch: 979, iter: 1, loss: 0.7176
# restart: 0, epoch: 980, iter: 1, loss: 0.7174
# restart: 0, epoch: 981, iter: 1, loss: 0.7172
# restart: 0, epoch: 982, iter: 1, loss: 0.7170
# restart: 0, epoch: 983, iter: 1, loss: 0.7168
# restart: 0, epoch: 984, iter: 1, loss: 0.7166
# restart: 0, epoch: 985, iter: 1, loss: 0.7164
# restart: 0, epoch: 986, iter: 1, loss: 0.7162
# restart: 0, epoch: 987, iter: 1, loss: 0.7161
# restart: 0, epoch: 988, iter: 1, loss: 0.7159
# restart: 0, epoch: 989, iter: 1, loss: 0.7157
# restart: 0, epoch: 990, iter: 1, loss: 0.7155
# restart: 0, epoch: 991, iter: 1, loss: 0.7153
# restart: 0, epoch: 992, iter: 1, loss: 0.7151
# restart: 0, epoch: 993, iter: 1, loss: 0.7149
# restart: 0, epoch: 994, iter: 1, loss: 0.7147
# restart: 0, epoch: 995, iter: 1, loss: 0.7145
# restart: 0, epoch: 996, iter: 1, loss: 0.7143
# restart: 0, epoch: 997, iter: 1, loss: 0.7141
# restart: 0, epoch: 998, iter: 1, loss: 0.7139
# restart: 0, epoch: 999, iter: 1, loss: 0.7137
# restart: 0, epoch: 1000, iter: 1, loss: 0.7135
# restart: 0, epoch: 1001, iter: 1, loss: 0.7133
# restart: 0, epoch: 1002, iter: 1, loss: 0.7131
# restart: 0, epoch: 1003, iter: 1, loss: 0.7129
# restart: 0, epoch: 1004, iter: 1, loss: 0.7127
# restart: 0, epoch: 1005, iter: 1, loss: 0.7126
# restart: 0, epoch: 1006, iter: 1, loss: 0.7124
# restart: 0, epoch: 1007, iter: 1, loss: 0.7122
# restart: 0, epoch: 1008, iter: 1, loss: 0.7120
# restart: 0, epoch: 1009, iter: 1, loss: 0.7118
# restart: 0, epoch: 1010, iter: 1, loss: 0.7116
# restart: 0, epoch: 1011, iter: 1, loss: 0.7114
# restart: 0, epoch: 1012, iter: 1, loss: 0.7112
# restart: 0, epoch: 1013, iter: 1, loss: 0.7110
# restart: 0, epoch: 1014, iter: 1, loss: 0.7108
# restart: 0, epoch: 1015, iter: 1, loss: 0.7106
# restart: 0, epoch: 1016, iter: 1, loss: 0.7104
# restart: 0, epoch: 1017, iter: 1, loss: 0.7103
# restart: 0, epoch: 1018, iter: 1, loss: 0.7101
# restart: 0, epoch: 1019, iter: 1, loss: 0.7099
# restart: 0, epoch: 1020, iter: 1, loss: 0.7097
# restart: 0, epoch: 1021, iter: 1, loss: 0.7095
# restart: 0, epoch: 1022, iter: 1, loss: 0.7093
# restart: 0, epoch: 1023, iter: 1, loss: 0.7091
# restart: 0, epoch: 1024, iter: 1, loss: 0.7089
# restart: 0, epoch: 1025, iter: 1, loss: 0.7087
# restart: 0, epoch: 1026, iter: 1, loss: 0.7085
# restart: 0, epoch: 1027, iter: 1, loss: 0.7083
# restart: 0, epoch: 1028, iter: 1, loss: 0.7082
# restart: 0, epoch: 1029, iter: 1, loss: 0.7080
# restart: 0, epoch: 1030, iter: 1, loss: 0.7078
# restart: 0, epoch: 1031, iter: 1, loss: 0.7076
# restart: 0, epoch: 1032, iter: 1, loss: 0.7074
# restart: 0, epoch: 1033, iter: 1, loss: 0.7072
# restart: 0, epoch: 1034, iter: 1, loss: 0.7070
# restart: 0, epoch: 1035, iter: 1, loss: 0.7068
# restart: 0, epoch: 1036, iter: 1, loss: 0.7066
# restart: 0, epoch: 1037, iter: 1, loss: 0.7064
# restart: 0, epoch: 1038, iter: 1, loss: 0.7063
# restart: 0, epoch: 1039, iter: 1, loss: 0.7061
# restart: 0, epoch: 1040, iter: 1, loss: 0.7059
# restart: 0, epoch: 1041, iter: 1, loss: 0.7057
# restart: 0, epoch: 1042, iter: 1, loss: 0.7055
# ...
# restart: 0, epoch: 2661, iter: 1, loss: 0.5980
# restart: 0, epoch: 2662, iter: 1, loss: 0.5980
# restart: 0, epoch: 2663, iter: 1, loss: 0.5980
# restart: 0, epoch: 2664, iter: 1, loss: 0.5980
# restart: 0, epoch: 2665, iter: 1, loss: 0.5980
# restart: 0, epoch: 2666, iter: 1, loss: 0.5979
# restart: 0, epoch: 2667, iter: 1, loss: 0.5979
# restart: 0, epoch: 2668, iter: 1, loss: 0.5979
# restart: 0, epoch: 2669, iter: 1, loss: 0.5979
# restart: 0, epoch: 2670, iter: 1, loss: 0.5979
# restart: 0, epoch: 2671, iter: 1, loss: 0.5979
# restart: 0, epoch: 2672, iter: 1, loss: 0.5979
# restart: 0, epoch: 2673, iter: 1, loss: 0.5979
# restart: 0, epoch: 2674, iter: 1, loss: 0.5979
# restart: 0, epoch: 2675, iter: 1, loss: 0.5979
# restart: 0, epoch: 2676, iter: 1, loss: 0.5979
# restart: 0, epoch: 2677, iter: 1, loss: 0.5979
# restart: 0, epoch: 2678, iter: 1, loss: 0.5979
# restart: 0, epoch: 2679, iter: 1, loss: 0.5979
# restart: 0, epoch: 2680, iter: 1, loss: 0.5979
# restart: 0, epoch: 2681, iter: 1, loss: 0.5979
# restart: 0, epoch: 2682, iter: 1, loss: 0.5979
# restart: 0, epoch: 2683, iter: 1, loss: 0.5979
# restart: 0, epoch: 2684, iter: 1, loss: 0.5979
# restart: 0, epoch: 2685, iter: 1, loss: 0.5979
# restart: 0, epoch: 2686, iter: 1, loss: 0.5979
# restart: 0, epoch: 2687, iter: 1, loss: 0.5979
# restart: 0, epoch: 2688, iter: 1, loss: 0.5979
# restart: 0, epoch: 2689, iter: 1, loss: 0.5979
# restart: 0, epoch: 2690, iter: 1, loss: 0.5979
# restart: 0, epoch: 2691, iter: 1, loss: 0.5979
# restart: 0, epoch: 2692, iter: 1, loss: 0.5979
# restart: 0, epoch: 2693, iter: 1, loss: 0.5979
# restart: 0, epoch: 2694, iter: 1, loss: 0.5979
# restart: 0, epoch: 2695, iter: 1, loss: 0.5979
# restart: 0, epoch: 2696, iter: 1, loss: 0.5979
# restart: 0, epoch: 2697, iter: 1, loss: 0.5979
# restart: 0, epoch: 2698, iter: 1, loss: 0.5979
# restart: 0, epoch: 2699, iter: 1, loss: 0.5978
# restart: 0, epoch: 2700, iter: 1, loss: 0.5978
# restart: 0, epoch: 2701, iter: 1, loss: 0.5978
# restart: 0, epoch: 2702, iter: 1, loss: 0.5978
# restart: 0, epoch: 2703, iter: 1, loss: 0.5978
# restart: 0, epoch: 2704, iter: 1, loss: 0.5978
# restart: 0, epoch: 2705, iter: 1, loss: 0.5978
# restart: 0, epoch: 2706, iter: 1, loss: 0.5978
# restart: 0, epoch: 2707, iter: 1, loss: 0.5978
# restart: 0, epoch: 2708, iter: 1, loss: 0.5978
# restart: 0, epoch: 2709, iter: 1, loss: 0.5978
# restart: 0, epoch: 2710, iter: 1, loss: 0.5978
# restart: 0, epoch: 2711, iter: 1, loss: 0.5978
# restart: 0, epoch: 2712, iter: 1, loss: 0.5978
# restart: 0, epoch: 2713, iter: 1, loss: 0.5978
# restart: 0, epoch: 2714, iter: 1, loss: 0.5978
# restart: 0, epoch: 2715, iter: 1, loss: 0.5978
# restart: 0, epoch: 2716, iter: 1, loss: 0.5978
# restart: 0, epoch: 2717, iter: 1, loss: 0.5978
# restart: 0, epoch: 2718, iter: 1, loss: 0.5978
# restart: 0, epoch: 2719, iter: 1, loss: 0.5978
# restart: 0, epoch: 2720, iter: 1, loss: 0.5978
# restart: 0, epoch: 2721, iter: 1, loss: 0.5978
# restart: 0, epoch: 2722, iter: 1, loss: 0.5978
# restart: 0, epoch: 2723, iter: 1, loss: 0.5978
# restart: 0, epoch: 2724, iter: 1, loss: 0.5978
# restart: 0, epoch: 2725, iter: 1, loss: 0.5978
# restart: 0, epoch: 2726, iter: 1, loss: 0.5978
# restart: 0, epoch: 2727, iter: 1, loss: 0.5978
# restart: 0, epoch: 2728, iter: 1, loss: 0.5978
# restart: 0, epoch: 2729, iter: 1, loss: 0.5978
# restart: 0, epoch: 2730, iter: 1, loss: 0.5978
# restart: 0, epoch: 2731, iter: 1, loss: 0.5978
# restart: 0, epoch: 2732, iter: 1, loss: 0.5978
# restart: 0, epoch: 2733, iter: 1, loss: 0.5978
# restart: 0, epoch: 2734, iter: 1, loss: 0.5978
# restart: 0, epoch: 2735, iter: 1, loss: 0.5978
# restart: 0, epoch: 2736, iter: 1, loss: 0.5978
# restart: 0, epoch: 2737, iter: 1, loss: 0.5978
# restart: 0, epoch: 2738, iter: 1, loss: 0.5978
# restart: 0, epoch: 2739, iter: 1, loss: 0.5978
# restart: 0, epoch: 2740, iter: 1, loss: 0.5978
# restart: 0, epoch: 2741, iter: 1, loss: 0.5977
# restart: 0, epoch: 2742, iter: 1, loss: 0.5977
# restart: 0, epoch: 2743, iter: 1, loss: 0.5977
# restart: 0, epoch: 2744, iter: 1, loss: 0.5977
# restart: 0, epoch: 2745, iter: 1, loss: 0.5977
# restart: 0, epoch: 2746, iter: 1, loss: 0.5977
# restart: 0, epoch: 2747, iter: 1, loss: 0.5977
# restart: 0, epoch: 2748, iter: 1, loss: 0.5977
# restart: 0, epoch: 2749, iter: 1, loss: 0.5977
# restart: 0, epoch: 2750, iter: 1, loss: 0.5977
# restart: 0, epoch: 2751, iter: 1, loss: 0.5977
# restart: 0, epoch: 2752, iter: 1, loss: 0.5977
# restart: 0, epoch: 2753, iter: 1, loss: 0.5977
# restart: 0, epoch: 2754, iter: 1, loss: 0.5977
# restart: 0, epoch: 2755, iter: 1, loss: 0.5977
# restart: 0, epoch: 2756, iter: 1, loss: 0.5977
# restart: 0, epoch: 2757, iter: 1, loss: 0.5977
# restart: 0, epoch: 2758, iter: 1, loss: 0.5977
# restart: 0, epoch: 2759, iter: 1, loss: 0.5977
# restart: 0, epoch: 2760, iter: 1, loss: 0.5977
# restart: 0, epoch: 2761, iter: 1, loss: 0.5977
# restart: 0, epoch: 2762, iter: 1, loss: 0.5977
# restart: 0, epoch: 2763, iter: 1, loss: 0.5977
# restart: 0, epoch: 2764, iter: 1, loss: 0.5977
# restart: 0, epoch: 2765, iter: 1, loss: 0.5977
# restart: 0, epoch: 2766, iter: 1, loss: 0.5977
# restart: 0, epoch: 2767, iter: 1, loss: 0.5977
# restart: 0, epoch: 2768, iter: 1, loss: 0.5977
# restart: 0, epoch: 2769, iter: 1, loss: 0.5977
# restart: 0, epoch: 2770, iter: 1, loss: 0.5977
# restart: 0, epoch: 2771, iter: 1, loss: 0.5977
# restart: 0, epoch: 2772, iter: 1, loss: 0.5977
# restart: 0, epoch: 2773, iter: 1, loss: 0.5977
# restart: 0, epoch: 2774, iter: 1, loss: 0.5977
# restart: 0, epoch: 2775, iter: 1, loss: 0.5977
# restart: 0, epoch: 2776, iter: 1, loss: 0.5977
# restart: 0, epoch: 2777, iter: 1, loss: 0.5977
# restart: 0, epoch: 2778, iter: 1, loss: 0.5977
# restart: 0, epoch: 2779, iter: 1, loss: 0.5977
# restart: 0, epoch: 2780, iter: 1, loss: 0.5977
# restart: 0, epoch: 2781, iter: 1, loss: 0.5977
# restart: 0, epoch: 2782, iter: 1, loss: 0.5977
# restart: 0, epoch: 2783, iter: 1, loss: 0.5977
# restart: 0, epoch: 2784, iter: 1, loss: 0.5977
# restart: 0, epoch: 2785, iter: 1, loss: 0.5977
# restart: 0, epoch: 2786, iter: 1, loss: 0.5977
# restart: 0, epoch: 2787, iter: 1, loss: 0.5977
# restart: 0, epoch: 2788, iter: 1, loss: 0.5977
# restart: 0, epoch: 2789, iter: 1, loss: 0.5977
# restart: 0, epoch: 2790, iter: 1, loss: 0.5977
# restart: 0, epoch: 2791, iter: 1, loss: 0.5977
# restart: 0, epoch: 2792, iter: 1, loss: 0.5977
# restart: 0, epoch: 2793, iter: 1, loss: 0.5976
# restart: 0, epoch: 2794, iter: 1, loss: 0.5976
# restart: 0, epoch: 2795, iter: 1, loss: 0.5976
# restart: 0, epoch: 2796, iter: 1, loss: 0.5976
# restart: 0, epoch: 2797, iter: 1, loss: 0.5976
# restart: 0, epoch: 2798, iter: 1, loss: 0.5976
# restart: 0, epoch: 2799, iter: 1, loss: 0.5976
# restart: 0, epoch: 2800, iter: 1, loss: 0.5976
# restart: 0, epoch: 2801, iter: 1, loss: 0.5976
# restart: 0, epoch: 2802, iter: 1, loss: 0.5976
# restart: 0, epoch: 2803, iter: 1, loss: 0.5976
# restart: 0, epoch: 2804, iter: 1, loss: 0.5976
# restart: 0, epoch: 2805, iter: 1, loss: 0.5976
# restart: 0, epoch: 2806, iter: 1, loss: 0.5976
# restart: 0, epoch: 2807, iter: 1, loss: 0.5976
# restart: 0, epoch: 2808, iter: 1, loss: 0.5976
# restart: 0, epoch: 2809, iter: 1, loss: 0.5976
# restart: 0, epoch: 2810, iter: 1, loss: 0.5976
# restart: 0, epoch: 2811, iter: 1, loss: 0.5976
# restart: 0, epoch: 2812, iter: 1, loss: 0.5976
# restart: 0, epoch: 2813, iter: 1, loss: 0.5976
# restart: 0, epoch: 2814, iter: 1, loss: 0.5976
# restart: 0, epoch: 2815, iter: 1, loss: 0.5976
# restart: 0, epoch: 2816, iter: 1, loss: 0.5976
# restart: 0, epoch: 2817, iter: 1, loss: 0.5976
# restart: 0, epoch: 2818, iter: 1, loss: 0.5976
# restart: 0, epoch: 2819, iter: 1, loss: 0.5976
# restart: 0, epoch: 2820, iter: 1, loss: 0.5976
# restart: 0, epoch: 2821, iter: 1, loss: 0.5976
# restart: 0, epoch: 2822, iter: 1, loss: 0.5976
# restart: 0, epoch: 2823, iter: 1, loss: 0.5976
# restart: 0, epoch: 2824, iter: 1, loss: 0.5976
# restart: 0, epoch: 2825, iter: 1, loss: 0.5976
# restart: 0, epoch: 2826, iter: 1, loss: 0.5976
# restart: 0, epoch: 2827, iter: 1, loss: 0.5976
# restart: 0, epoch: 2828, iter: 1, loss: 0.5976
# restart: 0, epoch: 2829, iter: 1, loss: 0.5976
# restart: 0, epoch: 2830, iter: 1, loss: 0.5976
# restart: 0, epoch: 2831, iter: 1, loss: 0.5976
# restart: 0, epoch: 2832, iter: 1, loss: 0.5976
# restart: 0, epoch: 2833, iter: 1, loss: 0.5976
# restart: 0, epoch: 2834, iter: 1, loss: 0.5976
# restart: 0, epoch: 2835, iter: 1, loss: 0.5976
# restart: 0, epoch: 2836, iter: 1, loss: 0.5976
# restart: 0, epoch: 2837, iter: 1, loss: 0.5976
# restart: 0, epoch: 2838, iter: 1, loss: 0.5976
# restart: 0, epoch: 2839, iter: 1, loss: 0.5976
# restart: 0, epoch: 2840, iter: 1, loss: 0.5976
# restart: 0, epoch: 2841, iter: 1, loss: 0.5976
# restart: 0, epoch: 2842, iter: 1, loss: 0.5976
# restart: 0, epoch: 2843, iter: 1, loss: 0.5976
# restart: 0, epoch: 2844, iter: 1, loss: 0.5976
# restart: 0, epoch: 2845, iter: 1, loss: 0.5976
# restart: 0, epoch: 2846, iter: 1, loss: 0.5976
# restart: 0, epoch: 2847, iter: 1, loss: 0.5976
# restart: 0, epoch: 2848, iter: 1, loss: 0.5976
# restart: 0, epoch: 2849, iter: 1, loss: 0.5976
# restart: 0, epoch: 2850, iter: 1, loss: 0.5976
# restart: 0, epoch: 2851, iter: 1, loss: 0.5976
# restart: 0, epoch: 2852, iter: 1, loss: 0.5976
# restart: 0, epoch: 2853, iter: 1, loss: 0.5976
# restart: 0, epoch: 2854, iter: 1, loss: 0.5976
# restart: 0, epoch: 2855, iter: 1, loss: 0.5976
# restart: 0, epoch: 2856, iter: 1, loss: 0.5975
# restart: 0, epoch: 2857, iter: 1, loss: 0.5975
# restart: 0, epoch: 2858, iter: 1, loss: 0.5975
# restart: 0, epoch: 2859, iter: 1, loss: 0.5975
# restart: 0, epoch: 2860, iter: 1, loss: 0.5975
# restart: 0, epoch: 2861, iter: 1, loss: 0.5975
# restart: 0, epoch: 2862, iter: 1, loss: 0.5975
# restart: 0, epoch: 2863, iter: 1, loss: 0.5975
# restart: 0, epoch: 2864, iter: 1, loss: 0.5975
# restart: 0, epoch: 2865, iter: 1, loss: 0.5975
# restart: 0, epoch: 2866, iter: 1, loss: 0.5975
# restart: 0, epoch: 2867, iter: 1, loss: 0.5975
# restart: 0, epoch: 2868, iter: 1, loss: 0.5975
# restart: 0, epoch: 2869, iter: 1, loss: 0.5975
# restart: 0, epoch: 2870, iter: 1, loss: 0.5975
# restart: 0, epoch: 2871, iter: 1, loss: 0.5975
# restart: 0, epoch: 2872, iter: 1, loss: 0.5975
# restart: 0, epoch: 2873, iter: 1, loss: 0.5975
# restart: 0, epoch: 2874, iter: 1, loss: 0.5975
# restart: 0, epoch: 2875, iter: 1, loss: 0.5975
# restart: 0, epoch: 2876, iter: 1, loss: 0.5975
# restart: 0, epoch: 2877, iter: 1, loss: 0.5975
# restart: 0, epoch: 2878, iter: 1, loss: 0.5975
# restart: 0, epoch: 2879, iter: 1, loss: 0.5975
# restart: 0, epoch: 2880, iter: 1, loss: 0.5975
# restart: 0, epoch: 2881, iter: 1, loss: 0.5975
# restart: 0, epoch: 2882, iter: 1, loss: 0.5975
# restart: 0, epoch: 2883, iter: 1, loss: 0.5975
# restart: 0, epoch: 2884, iter: 1, loss: 0.5975
# restart: 0, epoch: 2885, iter: 1, loss: 0.5975
# restart: 0, epoch: 2886, iter: 1, loss: 0.5975
# restart: 0, epoch: 2887, iter: 1, loss: 0.5975
# restart: 0, epoch: 2888, iter: 1, loss: 0.5975
# restart: 0, epoch: 2889, iter: 1, loss: 0.5975
# restart: 0, epoch: 2890, iter: 1, loss: 0.5975
# restart: 0, epoch: 2891, iter: 1, loss: 0.5975
# restart: 0, epoch: 2892, iter: 1, loss: 0.5975
# restart: 0, epoch: 2893, iter: 1, loss: 0.5975
# restart: 0, epoch: 2894, iter: 1, loss: 0.5975
# restart: 0, epoch: 2895, iter: 1, loss: 0.5975
# restart: 0, epoch: 2896, iter: 1, loss: 0.5975
# restart: 0, epoch: 2897, iter: 1, loss: 0.5975
# restart: 0, epoch: 2898, iter: 1, loss: 0.5975
# restart: 0, epoch: 2899, iter: 1, loss: 0.5975
# restart: 0, epoch: 2900, iter: 1, loss: 0.5975
# restart: 0, epoch: 2901, iter: 1, loss: 0.5975
# restart: 0, epoch: 2902, iter: 1, loss: 0.5975
# restart: 0, epoch: 2903, iter: 1, loss: 0.5975
# restart: 0, epoch: 2904, iter: 1, loss: 0.5974
# restart: 0, epoch: 2905, iter: 1, loss: 0.5974
# restart: 0, epoch: 2906, iter: 1, loss: 0.5974
# restart: 0, epoch: 2907, iter: 1, loss: 0.5974
# restart: 0, epoch: 2908, iter: 1, loss: 0.5974
# restart: 0, epoch: 2909, iter: 1, loss: 0.5974
# restart: 0, epoch: 2910, iter: 1, loss: 0.5974
# restart: 0, epoch: 2911, iter: 1, loss: 0.5974
# restart: 0, epoch: 2912, iter: 1, loss: 0.5974
# restart: 0, epoch: 2913, iter: 1, loss: 0.5974
# restart: 0, epoch: 2914, iter: 1, loss: 0.5974
# restart: 0, epoch: 2915, iter: 1, loss: 0.5974
# restart: 0, epoch: 2916, iter: 1, loss: 0.5974
# restart: 0, epoch: 2917, iter: 1, loss: 0.5974
# restart: 0, epoch: 2918, iter: 1, loss: 0.5974
# restart: 0, epoch: 2919, iter: 1, loss: 0.5974
# restart: 0, epoch: 2920, iter: 1, loss: 0.5974
# restart: 0, epoch: 2921, iter: 1, loss: 0.5974
# restart: 0, epoch: 2922, iter: 1, loss: 0.5974
# restart: 0, epoch: 2923, iter: 1, loss: 0.5974
# restart: 0, epoch: 2924, iter: 1, loss: 0.5974
# restart: 0, epoch: 2925, iter: 1, loss: 0.5974
# restart: 0, epoch: 2926, iter: 1, loss: 0.5974
# restart: 0, epoch: 2927, iter: 1, loss: 0.5974
# restart: 0, epoch: 2928, iter: 1, loss: 0.5974
# restart: 0, epoch: 2929, iter: 1, loss: 0.5974
# restart: 0, epoch: 2930, iter: 1, loss: 0.5974
# restart: 0, epoch: 2931, iter: 1, loss: 0.5974
# restart: 0, epoch: 2932, iter: 1, loss: 0.5974
# restart: 0, epoch: 2933, iter: 1, loss: 0.5974
# restart: 0, epoch: 2934, iter: 1, loss: 0.5973
# restart: 0, epoch: 2935, iter: 1, loss: 0.5973
# restart: 0, epoch: 2936, iter: 1, loss: 0.5973
# restart: 0, epoch: 2937, iter: 1, loss: 0.5973
# restart: 0, epoch: 2938, iter: 1, loss: 0.5973
# restart: 0, epoch: 2939, iter: 1, loss: 0.5973
# restart: 0, epoch: 2940, iter: 1, loss: 0.5973
# restart: 0, epoch: 2941, iter: 1, loss: 0.5973
# restart: 0, epoch: 2942, iter: 1, loss: 0.5973
# restart: 0, epoch: 2943, iter: 1, loss: 0.5973
# restart: 0, epoch: 2944, iter: 1, loss: 0.5973
# restart: 0, epoch: 2945, iter: 1, loss: 0.5973
# restart: 0, epoch: 2946, iter: 1, loss: 0.5973
# restart: 0, epoch: 2947, iter: 1, loss: 0.5973
# restart: 0, epoch: 2948, iter: 1, loss: 0.5973
# restart: 0, epoch: 2949, iter: 1, loss: 0.5973
# restart: 0, epoch: 2950, iter: 1, loss: 0.5973
# restart: 0, epoch: 2951, iter: 1, loss: 0.5973
# restart: 0, epoch: 2952, iter: 1, loss: 0.5973
# restart: 0, epoch: 2953, iter: 1, loss: 0.5973
# restart: 0, epoch: 2954, iter: 1, loss: 0.5973
# restart: 0, epoch: 2955, iter: 1, loss: 0.5973
# restart: 0, epoch: 2956, iter: 1, loss: 0.5973
# restart: 0, epoch: 2957, iter: 1, loss: 0.5973
# restart: 0, epoch: 2958, iter: 1, loss: 0.5973
# restart: 0, epoch: 2959, iter: 1, loss: 0.5973
# restart: 0, epoch: 2960, iter: 1, loss: 0.5973
# restart: 0, epoch: 2961, iter: 1, loss: 0.5973
# restart: 0, epoch: 2962, iter: 1, loss: 0.5973
# restart: 0, epoch: 2963, iter: 1, loss: 0.5973
# restart: 0, epoch: 2964, iter: 1, loss: 0.5973
# restart: 0, epoch: 2965, iter: 1, loss: 0.5973
# restart: 0, epoch: 2966, iter: 1, loss: 0.5973
# restart: 0, epoch: 2967, iter: 1, loss: 0.5973
# restart: 0, epoch: 2968, iter: 1, loss: 0.5973
# restart: 0, epoch: 2969, iter: 1, loss: 0.5973
# restart: 0, epoch: 2970, iter: 1, loss: 0.5973
# restart: 0, epoch: 2971, iter: 1, loss: 0.5973
# restart: 0, epoch: 2972, iter: 1, loss: 0.5973
# restart: 0, epoch: 2973, iter: 1, loss: 0.5973
# restart: 0, epoch: 2974, iter: 1, loss: 0.5973
# restart: 0, epoch: 2975, iter: 1, loss: 0.5973
# restart: 0, epoch: 2976, iter: 1, loss: 0.5973
# restart: 0, epoch: 2977, iter: 1, loss: 0.5973
# restart: 0, epoch: 2978, iter: 1, loss: 0.5973
# restart: 0, epoch: 2979, iter: 1, loss: 0.5973
# restart: 0, epoch: 2980, iter: 1, loss: 0.5973
# restart: 0, epoch: 2981, iter: 1, loss: 0.5973
# restart: 0, epoch: 2982, iter: 1, loss: 0.5973
# restart: 0, epoch: 2983, iter: 1, loss: 0.5973
# restart: 0, epoch: 2984, iter: 1, loss: 0.5973
# restart: 0, epoch: 2985, iter: 1, loss: 0.5973
# restart: 0, epoch: 2986, iter: 1, loss: 0.5973
# restart: 0, epoch: 2987, iter: 1, loss: 0.5973
# restart: 0, epoch: 2988, iter: 1, loss: 0.5973
# restart: 0, epoch: 2989, iter: 1, loss: 0.5973
# restart: 0, epoch: 2990, iter: 1, loss: 0.5973
# restart: 0, epoch: 2991, iter: 1, loss: 0.5973
# restart: 0, epoch: 2992, iter: 1, loss: 0.5973
# restart: 0, epoch: 2993, iter: 1, loss: 0.5973
# restart: 0, epoch: 2994, iter: 1, loss: 0.5973
# restart: 0, epoch: 2995, iter: 1, loss: 0.5973
# restart: 0, epoch: 2996, iter: 1, loss: 0.5973
# restart: 0, epoch: 2997, iter: 1, loss: 0.5973
# restart: 0, epoch: 2998, iter: 1, loss: 0.5973
# restart: 0, epoch: 2999, iter: 1, loss: 0.5973
# restart: 0, epoch: 3000, iter: 1, loss: 0.5973

# %%
  # model_name = "Refrigerator_trial_seq_time.pt"
  # torch.save(model.state_dict(), os.path.join(
  #  "models/", model_name))

# %% [markdown]
# ## Prediction

# %%
pred_dist = model.predict(xt.to("cuda"))

y_mean = pred_dist.loc
# print("Done ", i)/

y_mean = scalers[1].inverse_transform(y_mean.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean.shape)
y_mean = np.clip(y_mean,0,y_mean.max(),out=y_mean)
mae = np.mean(np.abs(np.array(yt) - y_mean))
rms = errors.rmse(jnp.array(yt), y_mean)
print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# torch.Size([16781]) (16781,)
# MAE:  27.35667514719976
# RMSE:  48.1613

# %% [markdown]
# ## Decomp

# %%
kernel1 = ScaleKernel(RBFKernel(ard_num_dims=n))
# kernel2 = ScaleKernel(RBFKernel(ard_num_dims=1,active_dims=(99)))
# kernel3 = ScaleKernel(CosineKernel(ard_num_dims=1,active_dims=(99)))

# kernel4 = kernel2*kernel3
kernel = kernel1 #ernel4
# induce_points = 512
inducing_points =  x[np.arange(0,x.shape[0],70)] 
# inducing_points = x[torch.randperm(x.shape[0])[: 1500]]

model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                      inducing_points).to("cuda")

model_name =  "Refrigerator_rbf_building6_" + str(0) + ".pt"
model.load_state_dict(torch.load(
    os.path.join("./final_models/", model_name)))
# Out:
# <All keys matched successfully>

# %%
model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
                      inducing_points).to("cuda")

# %%
pred_dist1 = model1.predict(xt[:4000].to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_mean1.shape
# Out:
# torch.Size([4000])

# %%
pred_arr =[]
pred_arr.append(np.array(pred_dist1.mean.cpu()))

# %%
y_mean1 = np.mean(pred_arr, axis =0)

# y_Std = np.std(np.array(pred_arr), axis =0)

# %%
y_mean1 = scalers[1].inverse_transform(y_mean1.reshape(-1,1)).squeeze()
# y_std = scaler_y.inverse_transform(y_Std.reshape(-1,1)).squeeze()

# %%
y_mean1.shape
# Out:
# (4000,)

# %%
y_mean_ = np.clip(y_mean1,0,y_mean1.max())
# y_sigma =  np.clip(y_mean,0,y_mean.max())

# %%
idx = 3000
plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp[:idx], scalers[].inverse_transform(xt.cpu().reshape(-1,1))[:idx], label = "Main")
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean_[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
# savefig("Uncertainity")

# %%
model2 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel4,
                      inducing_points).to("cuda")

# %%
pred_dist2 = model2.predict(xt[:4000].to("cuda"))
# print("Done ", i)

y_mean2 = pred_dist2.loc

# %%
y_mean2 = scalers[1].inverse_transform(y_mean2.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean2.shape)
# Out:
# torch.Size([16781]) (4000,)

# %%
y_mean_ = np.clip(y_mean2,0,y_mean2.max())

# %%
idx = 3000
plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp[:idx], scaler_y.inverse_transform(y.cpu().reshape(-1,1))[:idx], label = "Main")
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean_[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()

# %%
idx = 3000
# plt.figure(figsize=(10,6))
plt.plot(jnp.arange(idx),  yt.cpu().reshape(-1,1)[:idx], label = "Ground Truth", color="green")
plt.plot(jnp.arange(idx), y_mean_[:idx].reshape(-1,1), label = "Predicted")
# for i in range(2,3):
#     plt.fill_between(jnp.arange(idx), y_mean[:idx] - i*y_std[:idx], y_mean[:idx] + i*y_std[:idx],
#                     color="orange", alpha=(1/(i*3)), label=f"$\mu\pm{i}*\sigma$")
# plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.legend( prop={'size': 5.5})
plt.ylabel("Power")
sns.despine()

# %%
mae = np.mean(np.abs(np.array(yt) - y_mean))
rms = errors.rmse(jnp.array(yt), y_mean)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  27.80521506352558
# RMSE:  44.84471

# %%
try:
    from probml_utils import latexify, savefig, is_latexify_enabled
except ModuleNotFoundError:
    # %pip install git+https://github.com/probml/probml-utils.git
    from probml_utils import latexify, savefig, is_latexify_enabled

# %%
os.environ["LATEXIFY"] = "1"
os.environ["FIG_DIR"] = "./Final_plotss/"

# %%
latexify(width_scale_factor=2, fig_height=2)

# %%
idx = 2000
# plt.figure(figsize=(10,6))
plt.figure()
plt.plot(jnp.arange(idx), yt[300:idx+300], label = "Fridge True")
plt.plot(jnp.arange(idx), y_mean[300:idx+300], label = "Fridge Predicted")
plt.legend()
sns.despine()
savefig("CombinationKernel")
# Out:
# saving image to ./Final_plotss/CombinationKernel_latexified.pdf
# Figure size: [2. 2.]

# %%
model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
                       inducing_points).to("cuda")

# %%
pred_dist1 = model1.predict(xt.to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_mean1 = scalers[1].inverse_transform(y_mean1.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean1.shape)
# Out:
# torch.Size([14780]) (14780,)

# %%
idx = 2000
# plt.figure(figsize=(10,6))
plt.figure()
plt.plot(jnp.arange(idx), yt[300:idx+300], label = "Fridge True")
plt.plot(jnp.arange(idx), y_mean1[300:idx+300], label = "Fridge Predicted")
# plt.legend()
sns.despine()
savefig("RBFKernel")
# Out:
# saving image to ./Final_plotss/RBFKernel_latexified.pdf
# Figure size: [2. 2.]

# %%
# for name, params in model.named_parameters():
#   print(name, params)

# # model.mll.model.base_covar_module.kernels.base_kernel.raw_lengthscale

# %%
x.shape
# Out:
# torch.Size([55457, 100])

# %%
model2 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel4,
                       inducing_points).to("cuda")

# %%
pred_dist2 = model2.predict(xt.to("cuda"))
# print("Done ", i)

y_mean2 = pred_dist2.loc
# Out:
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/kernels/inducing_point_kernel.py:61: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352645774/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   inv_root = torch.triangular_solve(eye, chol)[0]

# %%
y_mean2 = scaler_y.inverse_transform(y_mean2.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean2.shape)
# Out:
# torch.Size([14780]) (14780,)

# %%
idx = 2000
plt.figure()
# plt.figure(figsize=(10,6))
plt.plot(jnp.arange(idx), yt[300:idx+300], label = "Fridge True")
plt.plot(jnp.arange(idx), y_mean2[300:idx+300], label = "Fridge Predicted")
# plt.legend()
sns.despine()
savefig("RBFxPeriodicKernel")
# Out:
# saving image to ./Final_plotss/RBFxPeriodicKernel_latexified.pdf
# Figure size: [2. 2.]

# %% [markdown]
# ## Normal

# %%
# kernel1 = ScaleKernel(MaternKernel(nu=2.5,ard_num_dims=n+1))
# kernel2 = ScaleKernel(MaternKernel(nu=0.5,ard_num_dims=1,active_dims=(99)))
# kernel3 = ScaleKernel(PeriodicKernel(ard_num_dims=1,active_dims=(99)))
# # kernel5 = ScaleKernel(gpytorch.kernels.SpectralDeltaKernel(num_dims=n,ard_num_dims=n))
# #   theta =  {'base_covar_module.kernels.0.base_kernel.lengthscale': torch.tensor(0.5),
# #         'base_covar_module.kernels.0.outputscale': torch.tensor(5.0),
# #         'base_covar_module.kernels.1.kernels.0.outputscale':torch.tensor(1.0),
# #         'base_covar_module.kernels.1.kernels.0.base_kernel.lengthscale': torch.tensor(0.1),
# #         'base_covar_module.kernels.1.kernels.1.outputscale':torch.tensor(1.0),
# #         'base_covar_module.kernels.1.kernels.1.base_kernel.lengthscale': torch.tensor(1.0),
# #         'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
# #theta = { 'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
# kernel4 = kernel2*kernel3
# kernel = kernel1 + kernel4
# # induce_points = 512
# inducing_points =  x[np.arange(0,x.shape[0],95)] 
# # inducing_points = x[torch.randperm(x.shape[0])[: 1500]]

# model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
#                     inducing_points).to("cuda")
# model_name =  "Refrigerator_trial_seq_time.pt"
# model.load_state_dict(torch.load(
#     os.path.join("models/", model_name)))

# %%
plt.scatter(range(5),model.mll.model.base_covar_module.base_kernel.lengthscale.cpu().detach().reshape(-1,1))

# %%
# plt.scatter(range(5),model.mll.model.base_covar_module.kernels[0].base_kernel.lengthscale.cpu().detach().reshape(-1,1)[:5])

# %%
for name, params in model.named_parameters():
  print(name, params)
# Out:
# mll.likelihood.noise_covar.raw_noise Parameter containing:
# tensor([-1.6414], device='cuda:0', requires_grad=True)
# mll.model.mean_module.constant Parameter containing:
# tensor([0.1491], device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.raw_outputscale Parameter containing:
# tensor(-1.8641, device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.base_kernel.raw_lengthscale Parameter containing:
# tensor([[-2.0170, -1.2695, -0.9937,  0.9573,  0.0039]], device='cuda:0',
#        requires_grad=True)
# mll.model.covar_module.inducing_points Parameter containing:
# tensor([[-0.1683, -0.2927, -0.2738, -0.4608, -0.7328],
#         [ 0.4291,  0.2614, -0.0847, -0.3989, -0.4386],
#         [ 0.1252, -0.1534,  0.5574,  2.2636,  2.2354],
#         ...,
#         [ 5.0900,  6.5897,  1.9888,  0.2504, -2.9582],
#         [ 0.2647,  2.4551,  1.7340, -0.4533, -0.4453],
#         [ 0.1507,  0.7939,  1.4491,  0.1928,  0.5327]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)

# %%
# import numpy as np
# try:
#     from probml_utils import latexify, savefig, is_latexify_enabled
# except ModuleNotFoundError:
#     %pip install git+https://github.com/probml/probml-utils.git
#     from probml_utils import latexify, savefig, is_latexify_enabled


# os.environ["LATEXIFY"] = "1"
# os.environ["FIG_DIR"] = "./Final_plotss/"

# latexify(width_scale_factor=2, fig_height=2)

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
# arr = np.array([3.8464, 4.5094, 4.7394, 4.9024, 4.9117, 5.0150, 4.8746, 4.9372, 4.3143,
#          4.5656, 5.0050, 5.1365, 5.1490, 5.2152, 5.2837, 5.2594, 5.1965, 5.0747,
#          5.1212, 4.8200, 4.6431, 4.8732, 4.7529, 0.3853, 4.4826, 4.9550, 5.0677,
#          5.2859, 4.9612, 5.1401, 5.2131, 4.4774, 4.5654, 4.5685, 3.8310, 3.0889,
#          2.7822, 4.0948, 4.0399, 4.6180, 4.5923, 4.5015, 4.0521, 4.8423, 5.2143,
#          5.4020, 4.8021, 4.5021, 0.6626, 0.1252, 1.3779, 4.8821, 4.6781, 4.8554,
#          4.5223, 4.5568, 5.0172, 5.4072, 5.0706, 4.5916, 4.5663, 4.1121, 4.2572,
#          4.2228, 3.7784, 0.4839, 3.6554, 4.3523, 4.6682, 4.6549, 4.8291, 5.0260,
#          4.7748, 4.5609, 4.4541, 4.4165, 4.4292, 4.1279, 3.6382, 4.1110, 4.7252,
#          5.0184, 5.0391, 5.2424, 5.5062, 5.4739, 5.5326, 5.6874, 5.6897, 5.4765,
#          5.4602, 5.4513, 5.5450, 5.6225, 5.5479, 5.3580, 5.3926, 5.1536, 4.6321])
# ar1 = np.arange(0,99,1)
# plt.plot(ar1,arr,'b')
# plt.xlabel('ARD')
# plt.ylabel('Learned ARD LengthScale values')
# # plt.title("Building 6 Test")

# plt.show()
# sns.despine()
# savefig("ARD_Ref")

# %%
pred_dist = model.predict(xt.to("cuda"))

# %%
y_mean = pred_dist.loc

# %%
y_mean = scalers[1].inverse_transform(y_mean.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean.shape)
# Out:
# torch.Size([16781]) (16781,)

# %%
y_mean = np.clip(y_mean,0,y_mean.max(),out=y_mean)

# %%
idx=3000
mae_arr = (np.array(yt) - y_mean)
# mae_arr = np.abs(np.array(yt) - y_mean)
plt.plot(x_test_timestamp[:idx],mae_arr[:idx])
plt.xlabel("TimeStamp")
plt.ylabel("Raw Error on Test")
# Out:
# Text(0, 0.5, 'Raw Error on Test')

# %%
idx=yt.shape[0]
mae_arr = np.abs(np.array(yt) - y_mean)
plt.plot(x_test_timestamp[:idx],yt[:idx], label = "ref")
plt.plot(x_test_timestamp[:idx],mae_arr[:idx], label="Eror")
plt.xlabel("TimeStamp")
plt.ylabel("Power and Error")
plt.legend()

# %%
sns.kdeplot(mae_arr)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
mae_arr1 = []


for i in range(len(mae_arr)):
  if (mae_arr[i]>300):
    mae_arr1.append(0)
  else:
    mae_arr1.append(mae_arr[i])

np.mean(mae_arr1)

plt.plot(x_test_timestamp[:],mae_arr1[:])
plt.xlabel("TimeStamp")
plt.ylabel("Absolute Error on Test")
# Out:
# Text(0, 0.5, 'Absolute Error on Test')

# %%
mae = np.mean(np.abs(np.array(yt) - y_mean))
rms = errors.rmse(jnp.array(yt), y_mean)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  30.236938220842944
# RMSE:  49.22505

# %%
#MAE:  28.1036

# %%
# x1 = xt[:,49]

# %%
# scalers[0].inverse_transform(x[:,:99]).min()

# %%
x1 = x_test_features[:,0].reshape(-1,1)

# %%
x2 =  x_test_features[:,1].reshape(-1,1)

# %%
# x3 = x_train_features[:,0].reshape(-1,1)
# x4 =  x_train_features[:,1].reshape(-1,1)
# print(x4.min())
# idx = 5000
# plt.figure(figsize=(10,6))
# plt.plot(x_train_timstamp[:idx], scalers[3].inverse_transform(x3)[:idx], label = "Main")
# plt.legend()
# plt.title("Train")

# %%
# idx = 3000
# plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp[:idx], scalers[3].inverse_transform(x1)[:idx], label = "Main")
# plt.plot(x_test_timestamp[:idx], scalers[-1].inverse_transform(x2)[:idx], label = "Main Ref Dif")
# plt.legend()
# plt.title("Test")

# %%
y_mean.min()
# Out:
# 0.0

# %%
y_train1 = scalers[1].inverse_transform(y_train.reshape(-1,1))
print(y_train1.min())
plt.scatter(x_train_timstamp[:idx], y_train1[:idx], label = "Refri")
# Out:
# 4.4086485e-07

# %%
idx = 3000#x2.shape[0]
start = 2000
plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp[:idx], scalers[3].inverse_transform(x1)[:idx], label = "Main")
# plt.plot(x_test_timestamp[:idx], scalers[-1].inverse_transform(x2)[:idx], label = "Main Ref Dif")
plt.plot(x_test_timestamp[start:start+idx], yt.cpu()[start:start+idx], label = "Refri")
plt.plot(x_test_timestamp[start:start+idx], y_mean[start:start+idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
plt.title("Building 6")
sns.despine()

# %%
value, count = np.unique(y_mean, return_counts=True)

Z = [x for _,x in sorted(zip(value,count))]

value[13000:14000].max(), count[13000:14000].max()
# Out:
# (418.69868118612675, 1)

# %%
y_mean1 = np.array(y_mean)
for i in range(len(y_mean)):

  # if y_mean1[i]>80 and y_mean[i]<120:
  if y_mean[i]>100:
    y_mean1[i] = 145
  if y_mean1[i]<100:
    y_mean1[i] = 0

# %%
index = 3000
start = 2000
plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp[:idx], scalers[3].inverse_transform(x1)[:idx], label = "Main")
# plt.plot(x_test_timestamp[:idx], scalers[-1].inverse_transform(x2)[:idx], label = "Main Ref Dif")
plt.plot(x_test_timestamp[start:start+index], yt.cpu()[start:start+index], label = "Refri")
plt.plot(x_test_timestamp[start:start+index], y_mean1[start:start+index], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
plt.title("Building 6")
sns.despine()

# %%
mae = np.mean(np.abs(np.array(yt) - y_mean1))
rms = errors.rmse(jnp.array(yt), y_mean1)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  27.386141059540915
# RMSE:  62.59981

# %%
# idx = 3000
# plt.figure(figsize=(10,6))
# plt.plot(jnp.arange(idx), scaler_y.inverse_transform(y.cpu().reshape(-1,1))[:idx], label = "Main")
# plt.plot(jnp.arange(idx), yt.cpu()[:idx], label = "Refri")
# plt.plot(jnp.arange(idx), y_mean[:idx], label = "Predicted")
# plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
# plt.xlabel("Indexes")
# plt.ylabel("Fridge Power")
# sns.despine()

# %%
# plt.plot(np.array(test_timestamp_orig)[:300],np.array(yt)[:300])
# plt.plot(np.array(test_timestamp_orig)[:300],np.array(y_mean)[:300])

# %%
# plt.scatter(np.array(test_timestamp_orig)[:3000],np.array(y_mean)[:3000],label="True")
# plt.scatter(np.array(test_timestamp_orig)[:3000],np.array(yt)[:3000],label="Pred")
# plt.legend()
# plt.xlabel("TimeStamp")
# plt.xlabel("Refrogerator Power")

# %%
idx = x_test.shape[0]
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp, y_test[:idx], label = "Refri")
plt.plot(x_test_timestamp, y_mean[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
# savefig("CombinationKernel")
# plt.savefig("./Results/Refrigerator_building5.png", bbox_inches="tight")

# %%
model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
                      inducing_points).to("cuda")

# %%
pred_dist1 = model.predict(torch.tensor(np.array(x_train_full)).to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_mean1 = scaler_y.inverse_transform(y_mean1.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(y_train.shape, y_mean1.shape)

# %%
mae = np.mean(np.abs(np.array(y_train) - y_mean1))
rms = errors.rmse(jnp.array(y_train), y_mean1)

print("MAE: ", mae)
print("RMSE: ", rms)

# %%
idx = x_train.shape[0]
plt.figure(figsize=(10,6))
plt.plot(x_train_timstamp, y_train[:idx], label = "Refri")
plt.plot(x_train_timstamp, y_mean[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
# savefig("CombinationKernel")
# plt.savefig("./Results/Refrigerator_building5.png", bbox_inches="tight")

# %%
#MAE:  39.81858310475401 build 6
#MAE:  30.333733374869247 build 3
#MAE:  37.32115756605644 build 2
#MAE: 43.212248588857065 build 5
#MAE:  48.917852990726765

# %%
# MAE: Building 6 MAE: 35.07
# MAE: Building 3 MAE:  31.565
# MAE: Building 2 MAE: 31.089
# MAE: Building 1 MAE: 37.3657
# MAE: Building 5 MAE:  46.316869

# %%
# MAE: Building 6 MAE: 34.3709125
# MAE: Building 3 MAE: 30.919
# MAE: Building 2 MAE: 30.43776
# MAE: Building 1 MAE: 37.10209
# MAE: Building 5 MAE: 45.02767

# %%
26.442985, 27.0600
