# %%
import os
os.chdir("../")
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %%
import torch
from gpytorch.kernels import RBFKernel, ScaleKernel, PeriodicKernel, MaternKernel, CosineKernel
from skgpytorch.models import SVGPRegressor, SGPRegressor

# %%
import jax.numpy as jnp
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from utilities.fits import fit
# from utilities import plot
import tensorflow_probability.substrates.jax as tfp
dist = tfp.distributions
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from gpytorch.constraints import GreaterThan
from skgpytorch.metrics import mean_squared_error, negative_log_predictive_density
import time
import numpy as np

# from datasets.dataset_load import dataset_loader
from utilities import plot,fits,gmm,errors,predict,preprocess

# device = "cpu"
# torch.set_default_dtype(torch.float32)
# torch.set_default_tensor_type(torch.FloatTensor)

# %%
train ={
         1: {
          'start_time': "2011-04-28" ,
          'end_time': "2011-05-15"
        },
      
   
    3: {
          'start_time': "2011-04-19" ,
          'end_time': "2011-05-22"
    },
 
}
test = {2: {
          'start_time': "2011-04-21" ,
          'end_time': "2011-05-21"
    }
     
   
}
appliances = ["Microwave"]

# %%
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler


def dataset_load(appliances, train, test=None):
    x_train = []
    y_train = []
    x_train_timestamp = []
    x_train_mean = []
    x_train_std = []
    x_train_max_min = []
    x_train_main = []
    x_train_main_dif = []
    n = 1
    units_to_pad = n // 2
    scaler_x = StandardScaler()
    scaler_y = StandardScaler()
    scaler_time = StandardScaler()
    scaler_mean = StandardScaler()
    scaler_std = StandardScaler()
    scaler_max_min = StandardScaler()
    scaler_main = StandardScaler()
    scaler_dif = StandardScaler()
    # train
    for key, values in train.items():
        df = pd.read_csv(
            f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[0]])
        df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
        startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
        endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

        if startDate > endDate:
            raise "Start Date must be smaller than Enddate."

        df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
        df.dropna(inplace=True)
        x = df["main"].values
        # for i in range(len(x)):
        #     if(x[i]>350.0):
        #         x[i]  = x[i] - 227.0
        x_train_main.extend(x)
        y = df[appliances[0]].values
        x_train_main_dif.extend(abs(x- y))
        timestamp_train = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])
        # print(0)
        x_train_mean.extend(jnp.mean(x, axis=1))
        # print(0)
        x_train_std.extend(jnp.std(x, axis=1))
        x_train_max_min.extend(jnp.max(x, axis=1)-jnp.min(x,axis=1))
        x_train.extend(x)
        y_train.extend(y)
        x_train_timestamp.extend(torch.tensor(timestamp_train))


    x_train = jnp.array(x_train)
    y_train = jnp.array(y_train).reshape(-1, 1)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(-1,1)
    x_train_main = jnp.array(x_train_main).reshape(-1,1)
    x_train_mean = jnp.array(x_train_mean).reshape(-1,1)
    x_train_std =  jnp.array(x_train_std).reshape(-1,1)
    x_train_max_min =  jnp.array(x_train_max_min).reshape(-1,1)
    x_train_main_dif = jnp.array(x_train_main_dif).reshape(-1,1)


    x_train = scaler_x.fit_transform(x_train)
    y_train = scaler_y.fit_transform(y_train)
    x_train_timestamp = scaler_time.fit_transform(x_train_timestamp)
    x_train_main = scaler_main.fit_transform(x_train_main)
    x_train_mean = scaler_mean.fit_transform(x_train_mean)
    x_train_std = scaler_std.fit_transform(x_train_std)
    x_train_max_min = scaler_max_min.fit_transform(x_train_max_min)
    x_train_main_dif = scaler_dif.fit_transform(x_train_main_dif)

    # test
    x_test = []
    y_test = []
    x_test_timestamp = []
    x_test_mean = []
    x_test_std = []
    x_test_max_min = []
    x_test_timestamp_true =[]
    x_test_main = []
    x_test_main_dif = []

    for key, values in test.items():
        df = pd.read_csv(
            f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[0]])
        df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
        startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
        endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

        if startDate > endDate:
            raise "Start Date must be smaller than Enddate."

        df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
        df.dropna(inplace=True)
        x = df["main"].values 
        # for i in range(len(x)):
            # if(x[i]>350.0):
            #     x[i]  = x[i] - 227.0
        x_test_main.extend(x)
        y = df[appliances[0]].values

        x_test_main_dif.extend(abs(x-y))
        timestamp_true = df["Timestamp"].values
        timestamp = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])

        x_test_mean.extend(jnp.mean(x, axis=1))
        x_test_std.extend(jnp.std(x, axis=1))
        x_test_max_min.extend(jnp.max(x, axis=1)-jnp.min(x, axis=1))
        x_test.extend(x)
        y_test.extend(y)
        x_test_timestamp_true.extend(timestamp_true)
        x_test_timestamp.extend(timestamp)

    x_test = jnp.array(x_test)
    y_test = jnp.array(y_test).reshape(-1, 1)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(-1,1)
    x_test_main = jnp.array(x_test_main).reshape(-1,1)
    x_test_mean = jnp.array(x_test_mean).reshape(-1,1)
    x_test_std =  jnp.array(x_test_std).reshape(-1,1)
    x_test_max_min =  jnp.array(x_test_max_min).reshape(-1,1)
    x_test_main_dif = jnp.array(x_test_main_dif).reshape(-1,1)

    x_test = scaler_x.transform(x_test)
    x_test_timestamp = scaler_time.transform(x_test_timestamp)
    x_test_mean = scaler_mean.transform(x_test_mean)
    x_test_std = scaler_std.transform(x_test_std)
    x_test_max_min = scaler_max_min.transform(x_test_max_min)
    x_test_main = scaler_main.transform(x_test_main)
    x_test_main_dif = scaler_dif.transform(x_test_main_dif)
#     y_test = scaler_y.transform(y_test)

    x_train_features = jnp.concatenate((x_train_main, x_train_main_dif), axis=1).reshape(x_train.shape[0], 2)
    x_test_features = jnp.concatenate((x_test_main,x_test_main_dif), axis=1).reshape(x_test.shape[0], 2)
    # x_train_features = x_train_main_dif
    # x_test_features = x_test_main_dif

    x_train = jnp.array(x_train).reshape(x_train.shape[0], n)
    y_train = jnp.array(y_train)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(x_train_timestamp.shape[0], 1)
    x_test = jnp.array(x_test).reshape(x_test.shape[0], n)
    y_test = jnp.array(y_test)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(x_test_timestamp.shape[0], 1).to(torch.float64)

    scalers = np.array([scaler_x, scaler_y, scaler_time, scaler_main, scaler_mean, scaler_std, scaler_max_min, scaler_dif])
    return x_train, y_train, x_test, y_test, x_train_features, x_test_features, x_train_timestamp, x_test_timestamp, scalers, x_test_main

# %%
x_train, y_train, x_test, y_test, x_train_features, x_test_features, x_train_timstamp, x_test_timestamp, scalers, x_test_main = dataset_load(appliances, train, test)

# %%
x_train_full = jnp.concatenate((x_train_features, jnp.array(np.array(x_train_timstamp))), axis=1)
x_test_full = jnp.concatenate((x_test_features, jnp.array(np.array(x_test_timestamp))), axis=1)

# %%
n = 2
# x_train_full = jnp.concatenate((x_train.reshape(-1,n), jnp.array(np.array(x_train_timstamp))), axis=1)
# x_test_full = jnp.concatenate((x_test.reshape(-1,n), jnp.array(np.array(x_test_timestamp))), axis=1)
# x_train_full.shape, x_test_full.shape

# %%
# x_train.reshape(-1,n).shape, x_test.reshape(-1,n).shape, y_train.shape, y_test.shape

# %%
# x = x_train_full[:14000]
# y = y_train[:14000]
# xt = x_train_full[14000:]
# yt = y_train[14000:]

# %%
# x.shape, y.shape

# %%
import gpytorch
indexes = 53456
x = torch.tensor(np.array(x_train_features)).to(torch.float64)
y = torch.tensor(np.array(y_train)).reshape(-1,).to(torch.float64)
xt = torch.tensor(np.array(x_test_features)).to(torch.float64)
yt = torch.tensor(np.array(y_test)).reshape(-1,).to(torch.float64)

if x.shape[0]>indexes:
  x = x[:indexes]
  y = y[:indexes]

# xt = xt[:16000]
# yt = yt[:16000]

# %%
x.dtype
# Out:
# torch.float64

# %%
x.shape, y.shape, xt.shape, yt.shape
# Out:
# (torch.Size([24918, 2]),
#  torch.Size([24918]),
#  torch.Size([15656, 2]),
#  torch.Size([15656]))

# %%
x.dtype
# Out:
# torch.float64

# %%
mae_arr =[]
rms_arr = []
y_pred_arr = []

batch = 512

# x_train = x_train[:4500]
# y_train = y_train[:4500]

# y_test_trans = torch.tensor(torch.tensor(scaler_x.transform(y_test.reshape(-1,1))).reshape(-1,)).contiguous().to(torch.float64)
for i in range(1):


   #nu=2.5,

  kernel1 = ScaleKernel(MaternKernel(nu=2.5, ard_num_dims=n))
  # kernel2 = ScaleKernel(MaternKernel(nu=0.5,ard_num_dims=1,active_dims=(n)))
  # kernel3 = ScaleKernel(PeriodicKernel(ard_num_dims=1,active_dims=(n)))
  # kernel5 = ScaleKernel(gpytorch.kernels.SpectralDeltaKernel(num_dims=n,ard_num_dims=n))
#   theta =  {'base_covar_module.kernels.0.base_kernel.lengthscale': torch.tensor(0.5),
#         'base_covar_module.kernels.0.outputscale': torch.tensor(5.0),
#         'base_covar_module.kernels.1.kernels.0.outputscale':torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.0.base_kernel.lengthscale': torch.tensor(0.1),
#         'base_covar_module.kernels.1.kernels.1.outputscale':torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.1.base_kernel.lengthscale': torch.tensor(1.0),
#         'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
  theta = { 'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
  # kernel4 = kernel2*kernel3
  kernel = kernel1 #+ kernel4
  # induce_points = 512
  inducing_points =  x[np.arange(0,x.shape[0],95)] 
  # inducing_points = x[torch.randperm(x.shape[0])[: 1500]]
  
  model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                       inducing_points).to("cuda")
  # model.base_covar_module.base_kernel.raw_lengthscale_constraint
  # model.mll.likelihood.noise_covar.register_constraint("raw_noise", GreaterThan(1e-2))
  # for param in model.parameters():
  #   # print(param)
  #   torch.nn.init.normal_(param, 0, 1)
  # theta1 = {'likelihood.noise_covar.noise': torch.tensor(3),
  #       'covar_module.base_kernel.lengthscale': torch.tensor(0.1),
  #       'covar_module.outputscale': torch.tensor(5),}
  loss = model.fit(lr=0.001, n_epochs=2000,verbose=1, thetas = None,
          random_state=0, n_restarts=1)
#   loss_arr.append(loss)
  # print(loss)
  plt.plot(np.asarray(loss[0]))
  # plt.plot(np.asarray(test_loss[0]))







  # y_pred_arr.append(pred_dist.loc)
# Out:
# restart: 0, epoch: 1, iter: 1, loss:
# restart: 0, epoch: 839, iter: 1, loss: 0.5528
# restart: 0, epoch: 840, iter: 1, loss: 0.5522
# restart: 0, epoch: 841, iter: 1, loss: 0.5518
# restart: 0, epoch: 842, iter: 1, loss: 0.5516
# restart: 0, epoch: 843, iter: 1, loss: 0.5513
# restart: 0, epoch: 844, iter: 1, loss: 0.5509
# restart: 0, epoch: 845, iter: 1, loss: 0.5505
# restart: 0, epoch: 846, iter: 1, loss: 0.5499
# restart: 0, epoch: 847, iter: 1, loss: 0.5497
# restart: 0, epoch: 848, iter: 1, loss: 0.5494
# restart: 0, epoch: 849, iter: 1, loss: 0.5491
# restart: 0, epoch: 850, iter: 1, loss: 0.5487
# restart: 0, epoch: 851, iter: 1, loss: 0.5483
# restart: 0, epoch: 852, iter: 1, loss: 0.5479
# restart: 0, epoch: 853, iter: 1, loss: 0.5474
# restart: 0, epoch: 854, iter: 1, loss: 0.5472
# restart: 0, epoch: 855, iter: 1, loss: 0.5469
# restart: 0, epoch: 856, iter: 1, loss: 0.5465
# restart: 0, epoch: 857, iter: 1, loss: 0.5460
# restart: 0, epoch: 858, iter: 1, loss: 0.5457
# restart: 0, epoch: 859, iter: 1, loss: 0.5454
# restart: 0, epoch: 860, iter: 1, loss: 0.5451
# restart: 0, epoch: 861, iter: 1, loss: 0.5447
# restart: 0, epoch: 862, iter: 1, loss: 0.5443
# restart: 0, epoch: 863, iter: 1, loss: 0.5440
# restart: 0, epoch: 864, iter: 1, loss: 0.5437
# restart: 0, epoch: 865, iter: 1, loss: 0.5433
# restart: 0, epoch: 866, iter: 1, loss: 0.5430
# restart: 0, epoch: 867, iter: 1, loss: 0.5426
# restart: 0, epoch: 868, iter: 1, loss: 0.5423
# restart: 0, epoch: 869, iter: 1, loss: 0.5419
# restart: 0, epoch: 870, iter: 1, loss: 0.5416
# restart: 0, epoch: 871, iter: 1, loss: 0.5412
# restart: 0, epoch: 872, iter: 1, loss: 0.5409
# restart: 0, epoch: 873, iter: 1, loss: 0.5405
# restart: 0, epoch: 874, iter: 1, loss: 0.5402
# restart: 0, epoch: 875, iter: 1, loss: 0.5398
# restart: 0, epoch: 876, iter: 1, loss: 0.5395
# restart: 0, epoch: 877, iter: 1, loss: 0.5391
# restart: 0, epoch: 878, iter: 1, loss: 0.5388
# restart: 0, epoch: 879, iter: 1, loss: 0.5385
# restart: 0, epoch: 880, iter: 1, loss: 0.5381
# restart: 0, epoch: 881, iter: 1, loss: 0.5378
# restart: 0, epoch: 882, iter: 1, loss: 0.5374
# restart: 0, epoch: 883, iter: 1, loss: 0.5371
# restart: 0, epoch: 884, iter: 1, loss: 0.5367
# restart: 0, epoch: 885, iter: 1, loss: 0.5364
# restart: 0, epoch: 886, iter: 1, loss: 0.5360
# restart: 0, epoch: 887, iter: 1, loss: 0.5357
# restart: 0, epoch: 888, iter: 1, loss: 0.5353
# restart: 0, epoch: 889, iter: 1, loss: 0.5350
# restart: 0, epoch: 890, iter: 1, loss: 0.5346
# restart: 0, epoch: 891, iter: 1, loss: 0.5343
# restart: 0, epoch: 997, iter: 1, loss: 0.4982
# restart: 0, epoch: 998, iter: 1, loss: 0.4978
# restart: 0, epoch: 999, iter: 1, loss: 0.4975
# restart: 0, epoch: 1000, iter: 1, loss: 0.4972
# restart: 0, epoch: 1001, iter: 1, loss: 0.4968
# restart: 0, epoch: 1002, iter: 1, loss: 0.4965
# restart: 0, epoch: 1003, iter: 1, loss: 0.4962
# restart: 0, epoch: 1004, iter: 1, loss: 0.4958
# restart: 0, epoch: 1005, iter: 1, loss: 0.4955
# restart: 0, epoch: 1006, iter: 1, loss: 0.4952
# restart: 0, epoch: 1007, iter: 1, loss: 0.4948
# restart: 0, epoch: 1008, iter: 1, loss: 0.4945
# restart: 0, epoch: 1009, iter: 1, loss: 0.4943
# restart: 0, epoch: 1010, iter: 1, loss: 0.4940
# restart: 0, epoch: 1011, iter: 1, loss: 0.4935
# restart: 0, epoch: 1012, iter: 1, loss: 0.4933
# restart: 0, epoch: 1013, iter: 1, loss: 0.4928
# restart: 0, epoch: 1014, iter: 1, loss: 0.4926
# restart: 0, epoch: 1015, iter: 1, loss: 0.4922
# restart: 0, epoch: 1016, iter: 1, loss: 0.4919
# restart: 0, epoch: 1017, iter: 1, loss: 0.4914
# restart: 0, epoch: 1018, iter: 1, loss: 0.4913
# restart: 0, epoch: 1019, iter: 1, loss: 0.4908
# restart: 0, epoch: 1020, iter: 1, loss: 0.4905
# restart: 0, epoch: 1021, iter: 1, loss: 0.4902
# restart: 0, epoch: 1022, iter: 1, loss: 0.4898
# restart: 0, epoch: 1023, iter: 1, loss: 0.4894
# restart: 0, epoch: 1024, iter: 1, loss: 0.4891
# restart: 0, epoch: 1025, iter: 1, loss: 0.4887
# restart: 0, epoch: 1026, iter: 1, loss: 0.4884
# restart: 0, epoch: 1027, iter: 1, loss: 0.4881
# ...
# restart: 0, epoch: 1661, iter: 1, loss: 0.2480
# restart: 0, epoch: 1662, iter: 1, loss: 0.2476
# restart: 0, epoch: 1663, iter: 1, loss: 0.2472
# restart: 0, epoch: 1664, iter: 1, loss: 0.2468
# restart: 0, epoch: 1665, iter: 1, loss: 0.2464
# restart: 0, epoch: 1666, iter: 1, loss: 0.2461
# restart: 0, epoch: 1667, iter: 1, loss: 0.2457
# restart: 0, epoch: 1668, iter: 1, loss: 0.2453
# restart: 0, epoch: 1669, iter: 1, loss: 0.2449
# restart: 0, epoch: 1670, iter: 1, loss: 0.2445
# restart: 0, epoch: 1671, iter: 1, loss: 0.2442
# restart: 0, epoch: 1672, iter: 1, loss: 0.2438
# restart: 0, epoch: 1673, iter: 1, loss: 0.2434
# restart: 0, epoch: 1674, iter: 1, loss: 0.2430
# restart: 0, epoch: 1675, iter: 1, loss: 0.2426
# restart: 0, epoch: 1676, iter: 1, loss: 0.2423
# restart: 0, epoch: 1677, iter: 1, loss: 0.2419
# restart: 0, epoch: 1678, iter: 1, loss: 0.2415
# restart: 0, epoch: 1679, iter: 1, loss: 0.2411
# restart: 0, epoch: 1680, iter: 1, loss: 0.2408
# restart: 0, epoch: 1681, iter: 1, loss: 0.2404
# restart: 0, epoch: 1682, iter: 1, loss: 0.2400
# restart: 0, epoch: 1683, iter: 1, loss: 0.2396
# restart: 0, epoch: 1684, iter: 1, loss: 0.2393
# restart: 0, epoch: 1685, iter: 1, loss: 0.2389
# restart: 0, epoch: 1686, iter: 1, loss: 0.2385
# restart: 0, epoch: 1687, iter: 1, loss: 0.2381
# restart: 0, epoch: 1688, iter: 1, loss: 0.2378
# restart: 0, epoch: 1689, iter: 1, loss: 0.2374
# restart: 0, epoch: 1690, iter: 1, loss: 0.2370
# restart: 0, epoch: 1691, iter: 1, loss: 0.2366
# restart: 0, epoch: 1692, iter: 1, loss: 0.2363
# restart: 0, epoch: 1693, iter: 1, loss: 0.2359
# restart: 0, epoch: 1694, iter: 1, loss: 0.2355
# restart: 0, epoch: 1695, iter: 1, loss: 0.2351
# restart: 0, epoch: 1696, iter: 1, loss: 0.2348
# restart: 0, epoch: 1697, iter: 1, loss: 0.2344
# restart: 0, epoch: 1698, iter: 1, loss: 0.2340
# restart: 0, epoch: 1699, iter: 1, loss: 0.2337
# restart: 0, epoch: 1700, iter: 1, loss: 0.2333
# restart: 0, epoch: 1701, iter: 1, loss: 0.2329
# restart: 0, epoch: 1702, iter: 1, loss: 0.2325
# restart: 0, epoch: 1703, iter: 1, loss: 0.2322
# restart: 0, epoch: 1704, iter: 1, loss: 0.2318
# restart: 0, epoch: 1705, iter: 1, loss: 0.2314
# restart: 0, epoch: 1706, iter: 1, loss: 0.2311
# restart: 0, epoch: 1707, iter: 1, loss: 0.2307
# restart: 0, epoch: 1708, iter: 1, loss: 0.2303
# restart: 0, epoch: 1709, iter: 1, loss: 0.2300
# restart: 0, epoch: 1710, iter: 1, loss: 0.2296
# restart: 0, epoch: 1711, iter: 1, loss: 0.2292
# restart: 0, epoch: 1712, iter: 1, loss: 0.2288
# restart: 0, epoch: 1713, iter: 1, loss: 0.2285
# restart: 0, epoch: 1714, iter: 1, loss: 0.2281
# restart: 0, epoch: 1715, iter: 1, loss: 0.2277
# restart: 0, epoch: 1716, iter: 1, loss: 0.2274
# restart: 0, epoch: 1717, iter: 1, loss: 0.2270
# restart: 0, epoch: 1718, iter: 1, loss: 0.2266
# restart: 0, epoch: 1719, iter: 1, loss: 0.2263
# restart: 0, epoch: 1720, iter: 1, loss: 0.2259
# restart: 0, epoch: 1721, iter: 1, loss: 0.2255
# restart: 0, epoch: 1722, iter: 1, loss: 0.2252
# restart: 0, epoch: 1723, iter: 1, loss: 0.2248
# restart: 0, epoch: 1724, iter: 1, loss: 0.2244
# restart: 0, epoch: 1725, iter: 1, loss: 0.2241
# restart: 0, epoch: 1726, iter: 1, loss: 0.2237
# restart: 0, epoch: 1727, iter: 1, loss: 0.2233
# restart: 0, epoch: 1728, iter: 1, loss: 0.2230
# restart: 0, epoch: 1729, iter: 1, loss: 0.2226
# restart: 0, epoch: 1730, iter: 1, loss: 0.2223
# restart: 0, epoch: 1731, iter: 1, loss: 0.2219
# restart: 0, epoch: 1732, iter: 1, loss: 0.2215
# restart: 0, epoch: 1733, iter: 1, loss: 0.2212
# restart: 0, epoch: 1734, iter: 1, loss: 0.2208
# restart: 0, epoch: 1735, iter: 1, loss: 0.2204
# restart: 0, epoch: 1736, iter: 1, loss: 0.2201
# restart: 0, epoch: 1737, iter: 1, loss: 0.2197
# restart: 0, epoch: 1738, iter: 1, loss: 0.2193
# restart: 0, epoch: 1739, iter: 1, loss: 0.2190
# restart: 0, epoch: 1740, iter: 1, loss: 0.2186
# restart: 0, epoch: 1741, iter: 1, loss: 0.2183
# restart: 0, epoch: 1742, iter: 1, loss: 0.2179
# restart: 0, epoch: 1743, iter: 1, loss: 0.2175
# restart: 0, epoch: 1744, iter: 1, loss: 0.2172
# restart: 0, epoch: 1745, iter: 1, loss: 0.2168
# restart: 0, epoch: 1746, iter: 1, loss: 0.2164
# restart: 0, epoch: 1747, iter: 1, loss: 0.2161
# restart: 0, epoch: 1748, iter: 1, loss: 0.2157
# restart: 0, epoch: 1749, iter: 1, loss: 0.2154
# restart: 0, epoch: 1750, iter: 1, loss: 0.2150
# restart: 0, epoch: 1751, iter: 1, loss: 0.2146
# restart: 0, epoch: 1752, iter: 1, loss: 0.2143
# restart: 0, epoch: 1753, iter: 1, loss: 0.2139
# restart: 0, epoch: 1754, iter: 1, loss: 0.2136
# restart: 0, epoch: 1755, iter: 1, loss: 0.2132
# restart: 0, epoch: 1756, iter: 1, loss: 0.2128
# restart: 0, epoch: 1757, iter: 1, loss: 0.2125
# restart: 0, epoch: 1758, iter: 1, loss: 0.2121
# restart: 0, epoch: 1759, iter: 1, loss: 0.2118
# restart: 0, epoch: 1760, iter: 1, loss: 0.2114
# restart: 0, epoch: 1761, iter: 1, loss: 0.2110
# restart: 0, epoch: 1762, iter: 1, loss: 0.2107
# restart: 0, epoch: 1763, iter: 1, loss: 0.2103
# restart: 0, epoch: 1764, iter: 1, loss: 0.2100
# restart: 0, epoch: 1765, iter: 1, loss: 0.2096
# restart: 0, epoch: 1766, iter: 1, loss: 0.2092
# restart: 0, epoch: 1767, iter: 1, loss: 0.2089
# restart: 0, epoch: 1768, iter: 1, loss: 0.2085
# restart: 0, epoch: 1769, iter: 1, loss: 0.2082
# restart: 0, epoch: 1770, iter: 1, loss: 0.2078
# restart: 0, epoch: 1771, iter: 1, loss: 0.2075
# restart: 0, epoch: 1772, iter: 1, loss: 0.2071
# restart: 0, epoch: 1773, iter: 1, loss: 0.2067
# restart: 0, epoch: 1774, iter: 1, loss: 0.2064
# restart: 0, epoch: 1775, iter: 1, loss: 0.2060
# restart: 0, epoch: 1776, iter: 1, loss: 0.2057
# restart: 0, epoch: 1777, iter: 1, loss: 0.2053
# restart: 0, epoch: 1778, iter: 1, loss: 0.2050
# restart: 0, epoch: 1779, iter: 1, loss: 0.2046
# restart: 0, epoch: 1780, iter: 1, loss: 0.2043
# restart: 0, epoch: 1781, iter: 1, loss: 0.2039
# restart: 0, epoch: 1782, iter: 1, loss: 0.2035
# restart: 0, epoch: 1783, iter: 1, loss: 0.2032
# restart: 0, epoch: 1784, iter: 1, loss: 0.2028
# restart: 0, epoch: 1785, iter: 1, loss: 0.2025
# restart: 0, epoch: 1786, iter: 1, loss: 0.2021
# restart: 0, epoch: 1787, iter: 1, loss: 0.2018
# restart: 0, epoch: 1788, iter: 1, loss: 0.2014
# restart: 0, epoch: 1789, iter: 1, loss: 0.2011
# restart: 0, epoch: 1790, iter: 1, loss: 0.2007
# restart: 0, epoch: 1791, iter: 1, loss: 0.2003
# restart: 0, epoch: 1792, iter: 1, loss: 0.2000
# restart: 0, epoch: 1793, iter: 1, loss: 0.1996
# restart: 0, epoch: 1794, iter: 1, loss: 0.1993
# restart: 0, epoch: 1795, iter: 1, loss: 0.1989
# restart: 0, epoch: 1796, iter: 1, loss: 0.1986
# restart: 0, epoch: 1797, iter: 1, loss: 0.1982
# restart: 0, epoch: 1798, iter: 1, loss: 0.1979
# restart: 0, epoch: 1799, iter: 1, loss: 0.1975
# restart: 0, epoch: 1800, iter: 1, loss: 0.1972
# restart: 0, epoch: 1801, iter: 1, loss: 0.1968
# restart: 0, epoch: 1802, iter: 1, loss: 0.1965
# restart: 0, epoch: 1803, iter: 1, loss: 0.1961
# restart: 0, epoch: 1804, iter: 1, loss: 0.1958
# restart: 0, epoch: 1805, iter: 1, loss: 0.1954
# restart: 0, epoch: 1806, iter: 1, loss: 0.1950
# restart: 0, epoch: 1807, iter: 1, loss: 0.1947
# restart: 0, epoch: 1808, iter: 1, loss: 0.1943
# restart: 0, epoch: 1809, iter: 1, loss: 0.1940
# restart: 0, epoch: 1810, iter: 1, loss: 0.1936
# restart: 0, epoch: 1811, iter: 1, loss: 0.1933
# restart: 0, epoch: 1812, iter: 1, loss: 0.1929
# restart: 0, epoch: 1813, iter: 1, loss: 0.1926
# restart: 0, epoch: 1814, iter: 1, loss: 0.1922
# restart: 0, epoch: 1815, iter: 1, loss: 0.1919
# restart: 0, epoch: 1816, iter: 1, loss: 0.1915
# restart: 0, epoch: 1817, iter: 1, loss: 0.1912
# restart: 0, epoch: 1818, iter: 1, loss: 0.1908
# restart: 0, epoch: 1819, iter: 1, loss: 0.1905
# restart: 0, epoch: 1820, iter: 1, loss: 0.1901
# restart: 0, epoch: 1821, iter: 1, loss: 0.1898
# restart: 0, epoch: 1822, iter: 1, loss: 0.1894
# restart: 0, epoch: 1823, iter: 1, loss: 0.1891
# restart: 0, epoch: 1824, iter: 1, loss: 0.1887
# restart: 0, epoch: 1825, iter: 1, loss: 0.1884
# restart: 0, epoch: 1826, iter: 1, loss: 0.1880
# restart: 0, epoch: 1827, iter: 1, loss: 0.1877
# restart: 0, epoch: 1828, iter: 1, loss: 0.1873
# restart: 0, epoch: 1829, iter: 1, loss: 0.1870
# restart: 0, epoch: 1830, iter: 1, loss: 0.1866
# restart: 0, epoch: 1831, iter: 1, loss: 0.1863
# restart: 0, epoch: 1832, iter: 1, loss: 0.1859
# restart: 0, epoch: 1833, iter: 1, loss: 0.1856
# restart: 0, epoch: 1834, iter: 1, loss: 0.1852
# restart: 0, epoch: 1835, iter: 1, loss: 0.1849
# restart: 0, epoch: 1836, iter: 1, loss: 0.1845
# restart: 0, epoch: 1837, iter: 1, loss: 0.1842
# restart: 0, epoch: 1838, iter: 1, loss: 0.1838
# restart: 0, epoch: 1839, iter: 1, loss: 0.1835
# restart: 0, epoch: 1840, iter: 1, loss: 0.1831
# restart: 0, epoch: 1841, iter: 1, loss: 0.1828
# restart: 0, epoch: 1842, iter: 1, loss: 0.1824
# restart: 0, epoch: 1843, iter: 1, loss: 0.1821
# restart: 0, epoch: 1844, iter: 1, loss: 0.1817
# restart: 0, epoch: 1845, iter: 1, loss: 0.1814
# restart: 0, epoch: 1846, iter: 1, loss: 0.1811
# restart: 0, epoch: 1847, iter: 1, loss: 0.1807
# restart: 0, epoch: 1848, iter: 1, loss: 0.1804
# restart: 0, epoch: 1849, iter: 1, loss: 0.1800
# restart: 0, epoch: 1850, iter: 1, loss: 0.1797
# restart: 0, epoch: 1851, iter: 1, loss: 0.1793
# restart: 0, epoch: 1852, iter: 1, loss: 0.1790
# restart: 0, epoch: 1853, iter: 1, loss: 0.1786
# restart: 0, epoch: 1854, iter: 1, loss: 0.1783
# restart: 0, epoch: 1855, iter: 1, loss: 0.1779
# restart: 0, epoch: 1856, iter: 1, loss: 0.1776
# restart: 0, epoch: 1857, iter: 1, loss: 0.1772
# restart: 0, epoch: 1858, iter: 1, loss: 0.1769
# restart: 0, epoch: 1859, iter: 1, loss: 0.1765
# restart: 0, epoch: 1860, iter: 1, loss: 0.1762
# restart: 0, epoch: 1861, iter: 1, loss: 0.1758
# restart: 0, epoch: 1862, iter: 1, loss: 0.1755
# restart: 0, epoch: 1863, iter: 1, loss: 0.1751
# restart: 0, epoch: 1864, iter: 1, loss: 0.1748
# restart: 0, epoch: 1865, iter: 1, loss: 0.1745
# restart: 0, epoch: 1866, iter: 1, loss: 0.1741
# restart: 0, epoch: 1867, iter: 1, loss: 0.1738
# restart: 0, epoch: 1868, iter: 1, loss: 0.1734
# restart: 0, epoch: 1869, iter: 1, loss: 0.1731
# restart: 0, epoch: 1870, iter: 1, loss: 0.1727
# restart: 0, epoch: 1871, iter: 1, loss: 0.1724
# restart: 0, epoch: 1872, iter: 1, loss: 0.1720
# restart: 0, epoch: 1873, iter: 1, loss: 0.1717
# restart: 0, epoch: 1874, iter: 1, loss: 0.1713
# restart: 0, epoch: 1875, iter: 1, loss: 0.1710
# restart: 0, epoch: 1876, iter: 1, loss: 0.1707
# restart: 0, epoch: 1877, iter: 1, loss: 0.1703
# restart: 0, epoch: 1878, iter: 1, loss: 0.1700
# restart: 0, epoch: 1879, iter: 1, loss: 0.1696
# restart: 0, epoch: 1880, iter: 1, loss: 0.1693
# restart: 0, epoch: 1881, iter: 1, loss: 0.1689
# restart: 0, epoch: 1882, iter: 1, loss: 0.1686
# restart: 0, epoch: 1934, iter: 1, loss: 0.1507
# restart: 0, epoch: 1935, iter: 1, loss: 0.1504
# restart: 0, epoch: 1936, iter: 1, loss: 0.1500
# restart: 0, epoch: 1937, iter: 1, loss: 0.1497
# restart: 0, epoch: 1938, iter: 1, loss: 0.1493
# restart: 0, epoch: 1939, iter: 1, loss: 0.1490
# restart: 0, epoch: 1940, iter: 1, loss: 0.1486
# restart: 0, epoch: 1941, iter: 1, loss: 0.1483
# restart: 0, epoch: 1942, iter: 1, loss: 0.1480
# restart: 0, epoch: 1943, iter: 1, loss: 0.1476
# restart: 0, epoch: 1944, iter: 1, loss: 0.1473
# restart: 0, epoch: 1945, iter: 1, loss: 0.1469
# restart: 0, epoch: 1946, iter: 1, loss: 0.1466
# restart: 0, epoch: 1947, iter: 1, loss: 0.1462
# restart: 0, epoch: 1948, iter: 1, loss: 0.1459
# restart: 0, epoch: 1949, iter: 1, loss: 0.1456
# restart: 0, epoch: 1950, iter: 1, loss: 0.1452
# restart: 0, epoch: 1951, iter: 1, loss: 0.1449
# restart: 0, epoch: 1952, iter: 1, loss: 0.1445
# restart: 0, epoch: 1953, iter: 1, loss: 0.1442
# restart: 0, epoch: 1954, iter: 1, loss: 0.1438
# restart: 0, epoch: 1955, iter: 1, loss: 0.1435
# restart: 0, epoch: 1956, iter: 1, loss: 0.1432
# restart: 0, epoch: 1957, iter: 1, loss: 0.1428
# restart: 0, epoch: 1958, iter: 1, loss: 0.1425
# restart: 0, epoch: 1959, iter: 1, loss: 0.1421
# restart: 0, epoch: 1960, iter: 1, loss: 0.1418
# restart: 0, epoch: 1961, iter: 1, loss: 0.1414
# restart: 0, epoch: 1962, iter: 1, loss: 0.1411
# restart: 0, epoch: 1963, iter: 1, loss: 0.1408
# restart: 0, epoch: 1964, iter: 1, loss: 0.1404
# restart: 0, epoch: 1965, iter: 1, loss: 0.1401
# restart: 0, epoch: 1966, iter: 1, loss: 0.1397
# restart: 0, epoch: 1967, iter: 1, loss: 0.1394
# restart: 0, epoch: 1968, iter: 1, loss: 0.1390
# restart: 0, epoch: 1969, iter: 1, loss: 0.1387
# restart: 0, epoch: 1970, iter: 1, loss: 0.1384
# restart: 0, epoch: 1971, iter: 1, loss: 0.1380
# restart: 0, epoch: 1972, iter: 1, loss: 0.1377
# restart: 0, epoch: 1973, iter: 1, loss: 0.1373
# restart: 0, epoch: 1974, iter: 1, loss: 0.1370
# restart: 0, epoch: 1975, iter: 1, loss: 0.1366
# restart: 0, epoch: 1976, iter: 1, loss: 0.1363
# restart: 0, epoch: 1977, iter: 1, loss: 0.1360
# restart: 0, epoch: 1978, iter: 1, loss: 0.1356
# restart: 0, epoch: 1979, iter: 1, loss: 0.1353
# restart: 0, epoch: 1980, iter: 1, loss: 0.1349
# restart: 0, epoch: 1981, iter: 1, loss: 0.1346
# restart: 0, epoch: 1982, iter: 1, loss: 0.1342
# restart: 0, epoch: 1983, iter: 1, loss: 0.1339
# restart: 0, epoch: 1984, iter: 1, loss: 0.1335
# restart: 0, epoch: 1985, iter: 1, loss: 0.1332
# restart: 0, epoch: 1986, iter: 1, loss: 0.1329
# restart: 0, epoch: 1987, iter: 1, loss: 0.1325
# restart: 0, epoch: 1988, iter: 1, loss: 0.1322
# restart: 0, epoch: 1989, iter: 1, loss: 0.1318
# restart: 0, epoch: 1990, iter: 1, loss: 0.1315
# restart: 0, epoch: 1991, iter: 1, loss: 0.1311
# restart: 0, epoch: 1992, iter: 1, loss: 0.1308
# restart: 0, epoch: 1993, iter: 1, loss: 0.1304
# restart: 0, epoch: 1994, iter: 1, loss: 0.1301
# restart: 0, epoch: 1995, iter: 1, loss: 0.1298
# restart: 0, epoch: 1996, iter: 1, loss: 0.1294
# restart: 0, epoch: 1997, iter: 1, loss: 0.1291
# restart: 0, epoch: 1998, iter: 1, loss: 0.1287
# restart: 0, epoch: 1999, iter: 1, loss: 0.1284
# restart: 0, epoch: 2000, iter: 1, loss: 0.1280

# %%
  # model_name = "Refrigerator_trial_seq_time.pt"
  # torch.save(model.state_dict(), os.path.join(
  #  "models/", model_name))

# %% [markdown]
# ## Decomp

# %%
kernel1 = ScaleKernel(RBFKernel(ard_num_dims=n))
# kernel2 = ScaleKernel(RBFKernel(ard_num_dims=1,active_dims=(99)))
# kernel3 = ScaleKernel(CosineKernel(ard_num_dims=1,active_dims=(99)))

# kernel4 = kernel2*kernel3
kernel = kernel1 #ernel4
# induce_points = 512
inducing_points =  x[np.arange(0,x.shape[0],70)] 
# inducing_points = x[torch.randperm(x.shape[0])[: 1500]]

model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                      inducing_points).to("cuda")

model_name =  "Refrigerator_rbf_building6_" + str(0) + ".pt"
model.load_state_dict(torch.load(
    os.path.join("./final_models/", model_name)))
# Out:
# <All keys matched successfully>

# %%
model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
                      inducing_points).to("cuda")

# %%
pred_dist1 = model1.predict(xt[:4000].to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_mean1.shape
# Out:
# torch.Size([4000])

# %%
pred_arr =[]
pred_arr.append(np.array(pred_dist1.mean.cpu()))

# %%
y_mean1 = np.mean(pred_arr, axis =0)

# y_Std = np.std(np.array(pred_arr), axis =0)

# %%
y_mean1 = scalers[1].inverse_transform(y_mean1.reshape(-1,1)).squeeze()
# y_std = scaler_y.inverse_transform(y_Std.reshape(-1,1)).squeeze()

# %%
y_mean1.shape
# Out:
# (4000,)

# %%
y_mean_ = np.clip(y_mean1,0,y_mean1.max())
# y_sigma =  np.clip(y_mean,0,y_mean.max())

# %%
idx = 3000
plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp[:idx], scalers[].inverse_transform(xt.cpu().reshape(-1,1))[:idx], label = "Main")
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean_[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
# savefig("Uncertainity")

# %%
model2 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel4,
                      inducing_points).to("cuda")

# %%
pred_dist2 = model2.predict(xt[:4000].to("cuda"))
# print("Done ", i)

y_mean2 = pred_dist2.loc

# %%
y_mean2 = scalers[1].inverse_transform(y_mean2.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean2.shape)
# Out:
# torch.Size([16781]) (4000,)

# %%
y_mean_ = np.clip(y_mean2,0,y_mean2.max())

# %%
idx = 3000
plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp[:idx], scaler_y.inverse_transform(y.cpu().reshape(-1,1))[:idx], label = "Main")
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean_[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()

# %%
idx = 3000
# plt.figure(figsize=(10,6))
plt.plot(jnp.arange(idx),  yt.cpu().reshape(-1,1)[:idx], label = "Ground Truth", color="green")
plt.plot(jnp.arange(idx), y_mean_[:idx].reshape(-1,1), label = "Predicted")
# for i in range(2,3):
#     plt.fill_between(jnp.arange(idx), y_mean[:idx] - i*y_std[:idx], y_mean[:idx] + i*y_std[:idx],
#                     color="orange", alpha=(1/(i*3)), label=f"$\mu\pm{i}*\sigma$")
# plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.legend( prop={'size': 5.5})
plt.ylabel("Power")
sns.despine()

# %%
mae = np.mean(np.abs(np.array(yt) - y_mean))
rms = errors.rmse(jnp.array(yt), y_mean)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  27.80521506352558
# RMSE:  44.84471

# %%
try:
    from probml_utils import latexify, savefig, is_latexify_enabled
except ModuleNotFoundError:
    # %pip install git+https://github.com/probml/probml-utils.git
    from probml_utils import latexify, savefig, is_latexify_enabled

# %%
os.environ["LATEXIFY"] = "1"
os.environ["FIG_DIR"] = "./Final_plotss/"

# %%
latexify(width_scale_factor=2, fig_height=2)

# %%
idx = 2000
# plt.figure(figsize=(10,6))
plt.figure()
plt.plot(jnp.arange(idx), yt[300:idx+300], label = "Fridge True")
plt.plot(jnp.arange(idx), y_mean[300:idx+300], label = "Fridge Predicted")
plt.legend()
sns.despine()
savefig("CombinationKernel")
# Out:
# saving image to ./Final_plotss/CombinationKernel_latexified.pdf
# Figure size: [2. 2.]

# %%
model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
                       inducing_points).to("cuda")

# %%
pred_dist1 = model1.predict(xt.to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_mean1 = scalers[1].inverse_transform(y_mean1.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean1.shape)
# Out:
# torch.Size([14780]) (14780,)

# %%
idx = 2000
# plt.figure(figsize=(10,6))
plt.figure()
plt.plot(jnp.arange(idx), yt[300:idx+300], label = "Fridge True")
plt.plot(jnp.arange(idx), y_mean1[300:idx+300], label = "Fridge Predicted")
# plt.legend()
sns.despine()
savefig("RBFKernel")
# Out:
# saving image to ./Final_plotss/RBFKernel_latexified.pdf
# Figure size: [2. 2.]

# %%
# for name, params in model.named_parameters():
#   print(name, params)

# # model.mll.model.base_covar_module.kernels.base_kernel.raw_lengthscale

# %%
x.shape
# Out:
# torch.Size([55457, 100])

# %%
model2 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel4,
                       inducing_points).to("cuda")

# %%
pred_dist2 = model2.predict(xt.to("cuda"))
# print("Done ", i)

y_mean2 = pred_dist2.loc
# Out:
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/kernels/inducing_point_kernel.py:61: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352645774/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   inv_root = torch.triangular_solve(eye, chol)[0]

# %%
y_mean2 = scaler_y.inverse_transform(y_mean2.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean2.shape)
# Out:
# torch.Size([14780]) (14780,)

# %%
idx = 2000
plt.figure()
# plt.figure(figsize=(10,6))
plt.plot(jnp.arange(idx), yt[300:idx+300], label = "Fridge True")
plt.plot(jnp.arange(idx), y_mean2[300:idx+300], label = "Fridge Predicted")
# plt.legend()
sns.despine()
savefig("RBFxPeriodicKernel")
# Out:
# saving image to ./Final_plotss/RBFxPeriodicKernel_latexified.pdf
# Figure size: [2. 2.]

# %% [markdown]
# ## Normal

# %%
# kernel1 = ScaleKernel(MaternKernel(nu=2.5,ard_num_dims=n+1))
# kernel2 = ScaleKernel(MaternKernel(nu=0.5,ard_num_dims=1,active_dims=(99)))
# kernel3 = ScaleKernel(PeriodicKernel(ard_num_dims=1,active_dims=(99)))
# # kernel5 = ScaleKernel(gpytorch.kernels.SpectralDeltaKernel(num_dims=n,ard_num_dims=n))
# #   theta =  {'base_covar_module.kernels.0.base_kernel.lengthscale': torch.tensor(0.5),
# #         'base_covar_module.kernels.0.outputscale': torch.tensor(5.0),
# #         'base_covar_module.kernels.1.kernels.0.outputscale':torch.tensor(1.0),
# #         'base_covar_module.kernels.1.kernels.0.base_kernel.lengthscale': torch.tensor(0.1),
# #         'base_covar_module.kernels.1.kernels.1.outputscale':torch.tensor(1.0),
# #         'base_covar_module.kernels.1.kernels.1.base_kernel.lengthscale': torch.tensor(1.0),
# #         'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
# #theta = { 'base_covar_module.kernels.1.kernels.1.base_kernel.period_length': torch.tensor(0.01),}
# kernel4 = kernel2*kernel3
# kernel = kernel1 + kernel4
# # induce_points = 512
# inducing_points =  x[np.arange(0,x.shape[0],95)] 
# # inducing_points = x[torch.randperm(x.shape[0])[: 1500]]

# model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
#                     inducing_points).to("cuda")
# model_name =  "Refrigerator_trial_seq_time.pt"
# model.load_state_dict(torch.load(
#     os.path.join("models/", model_name)))
# Out:
# <All keys matched successfully>

# %%
plt.scatter(range(2),model.mll.model.base_covar_module.base_kernel.lengthscale.cpu().detach().reshape(-1,1))

# %%
# plt.scatter(range(2),model.mll.model.base_covar_module.kernels[0].base_kernel.lengthscale.cpu().detach().reshape(-1,1))

# %%
for name, params in model.named_parameters():
  print(name, params)
# Out:
# mll.likelihood.noise_covar.raw_noise Parameter containing:
# tensor([-2.1231], device='cuda:0', requires_grad=True)
# mll.model.mean_module.constant Parameter containing:
# tensor([0.3088], device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.kernels.0.raw_outputscale Parameter containing:
# tensor(-1.0261, device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.kernels.0.base_kernel.raw_lengthscale Parameter containing:
# tensor([[0.2123, 2.0857, 1.7805, 0.1921, 1.8406]], device='cuda:0',
#        requires_grad=True)
# mll.model.base_covar_module.kernels.1.kernels.0.raw_outputscale Parameter containing:
# tensor(-1.6808, device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.kernels.1.kernels.0.base_kernel.raw_lengthscale Parameter containing:
# tensor([[1.3642]], device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.kernels.1.kernels.1.raw_outputscale Parameter containing:
# tensor(-1.6808, device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.kernels.1.kernels.1.base_kernel.raw_lengthscale Parameter containing:
# tensor([[0.7452]], device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.kernels.1.kernels.1.base_kernel.raw_period_length Parameter containing:
# tensor([[1.3606]], device='cuda:0', requires_grad=True)
# mll.model.covar_module.inducing_points Parameter containing:
# tensor([[-0.2777, -0.2465, -0.5519, -0.1870, -0.9639],
#         [-0.0758, -0.4629, -0.4894, -0.2404, -0.9346],
#         [-0.1859,  0.1687,  2.6663, -0.2663, -0.9415],
#         ...,
#         [ 0.3023,  0.4017,  2.3741,  0.4092,  0.1435],
#         [-0.1476, -0.1466, -0.5361, -0.3916,  0.1530],
#         [-0.0628, -0.3994, -0.4842, -0.2378,  0.1531]], device='cuda:0',
#        dtype=torch.float64, requires_grad=True)

# %%
# import numpy as np
# try:
#     from probml_utils import latexify, savefig, is_latexify_enabled
# except ModuleNotFoundError:
#     %pip install git+https://github.com/probml/probml-utils.git
#     from probml_utils import latexify, savefig, is_latexify_enabled


# os.environ["LATEXIFY"] = "1"
# os.environ["FIG_DIR"] = "./Final_plotss/"

# latexify(width_scale_factor=2, fig_height=2)

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
# arr = np.array([3.8464, 4.5094, 4.7394, 4.9024, 4.9117, 5.0150, 4.8746, 4.9372, 4.3143,
#          4.5656, 5.0050, 5.1365, 5.1490, 5.2152, 5.2837, 5.2594, 5.1965, 5.0747,
#          5.1212, 4.8200, 4.6431, 4.8732, 4.7529, 0.3853, 4.4826, 4.9550, 5.0677,
#          5.2859, 4.9612, 5.1401, 5.2131, 4.4774, 4.5654, 4.5685, 3.8310, 3.0889,
#          2.7822, 4.0948, 4.0399, 4.6180, 4.5923, 4.5015, 4.0521, 4.8423, 5.2143,
#          5.4020, 4.8021, 4.5021, 0.6626, 0.1252, 1.3779, 4.8821, 4.6781, 4.8554,
#          4.5223, 4.5568, 5.0172, 5.4072, 5.0706, 4.5916, 4.5663, 4.1121, 4.2572,
#          4.2228, 3.7784, 0.4839, 3.6554, 4.3523, 4.6682, 4.6549, 4.8291, 5.0260,
#          4.7748, 4.5609, 4.4541, 4.4165, 4.4292, 4.1279, 3.6382, 4.1110, 4.7252,
#          5.0184, 5.0391, 5.2424, 5.5062, 5.4739, 5.5326, 5.6874, 5.6897, 5.4765,
#          5.4602, 5.4513, 5.5450, 5.6225, 5.5479, 5.3580, 5.3926, 5.1536, 4.6321])
# ar1 = np.arange(0,99,1)
# plt.plot(ar1,arr,'b')
# plt.xlabel('ARD')
# plt.ylabel('Learned ARD LengthScale values')
# # plt.title("Building 6 Test")

# plt.show()
# sns.despine()
# savefig("ARD_Ref")

# %%
pred_dist = model.predict(xt.to("cuda"))
# print("Done ", i)

y_mean = pred_dist.loc

# %%
y_mean = scalers[1].inverse_transform(y_mean.cpu().reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(yt.shape, y_mean.shape, y_mean.min())
# Out:
# torch.Size([15656]) (15656,) 1.7508728178937822

# %%
y_mean = np.clip(y_mean,0,y_mean.max(),out=y_mean)

# %%
mae_arr = np.abs(np.array(yt) - y_mean)

# %%
mae_arr.shape
# Out:
# (15656,)

# %%
# val,count= np.unique(mae_arr, return_counts=True)
# val, np.where(count==count.max())

# %%
# count[178], val[178]

# %%
# ar1 = np.where(mae_arr==val[178])

# %%
# x_trial = scaler_x.inverse_transform(xt[:,:99].cpu())
# x_trial[ar1,49].min(),x_trial[ar1,49].max()

# %%
idx=xt.shape[0]
plt.plot(x_test_timestamp[:idx],mae_arr[:idx])
plt.xlabel("TimeStamp")
plt.ylabel("Absolute Error on Test")
# Out:
# Text(0, 0.5, 'Absolute Error on Test')

# %%
sns.kdeplot(mae_arr)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
mae_arr1 = []


for i in range(len(mae_arr)):
  if (mae_arr[i]>300):
    mae_arr1.append(0)
  else:
    mae_arr1.append(mae_arr[i])

# %%
np.mean(mae_arr1)
# Out:
# 1.5121854606897362

# %%
idx=xt.shape[0]
plt.plot(x_test_timestamp[:idx],mae_arr1[:idx])

# %%
mae = np.mean(np.abs(np.array(yt) - y_mean))
rms = errors.rmse(jnp.array(yt), y_mean)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  1.5121854606897362
# RMSE:  6.7165647

# %%
#MAE:  28.1036

# %%
# x1 = xt[:,49]

# %%
# scalers[0].inverse_transform(x[:,:99]).min()

# %%
x1 = x_test_features[:,0].reshape(-1,1)

# %%
x2 =  x_test_features[:,1].reshape(-1,1)

# %%
(scalers[-1].inverse_transform(x2)).min()
# Out:
# 1.6650038

# %%
x3 = x_train_features[:,0].reshape(-1,1)
x4 =  x_train_features[:,1].reshape(-1,1)
print(x4.min())
idx = 5000
plt.figure(figsize=(10,6))
plt.plot(x_train_timstamp[:idx], scalers[3].inverse_transform(x3)[:idx], label = "Main")
plt.plot(x_train_timstamp[:idx], scalers[-1].inverse_transform(x4)[:idx], label = "Main Ref Dif")
plt.legend()
plt.title("Train")
# Out:
# -0.5154625
# Text(0.5, 1.0, 'Train')

# %%
idx = 3000
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp[:idx], scalers[3].inverse_transform(x1)[:idx], label = "Main")
plt.plot(x_test_timestamp[:idx], scalers[-1].inverse_transform(x2)[:idx], label = "Main Ref Dif")
plt.legend()
plt.title("Test")
# Out:
# Text(0.5, 1.0, 'Test')

# %%
idx = x1.shape[0]
plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp[:idx], scalers[3].inverse_transform(x1)[:idx], label = "Main")
# plt.plot(x_test_timestamp[:idx], scalers[-1].inverse_transform(x2)[:idx], label = "Main Ref Dif")
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Micro")
plt.plot(x_test_timestamp[:idx], y_mean[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
plt.title("Building 2")
sns.despine()

# %%
# idx = 3000
# plt.figure(figsize=(10,6))
# plt.plot(jnp.arange(idx), scaler_y.inverse_transform(y.cpu().reshape(-1,1))[:idx], label = "Main")
# plt.plot(jnp.arange(idx), yt.cpu()[:idx], label = "Refri")
# plt.plot(jnp.arange(idx), y_mean[:idx], label = "Predicted")
# plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
# plt.xlabel("Indexes")
# plt.ylabel("Fridge Power")
# sns.despine()

# %%
# plt.plot(np.array(test_timestamp_orig)[:300],np.array(yt)[:300])
# plt.plot(np.array(test_timestamp_orig)[:300],np.array(y_mean)[:300])

# %%
# plt.scatter(np.array(test_timestamp_orig)[:3000],np.array(y_mean)[:3000],label="True")
# plt.scatter(np.array(test_timestamp_orig)[:3000],np.array(yt)[:3000],label="Pred")
# plt.legend()
# plt.xlabel("TimeStamp")
# plt.xlabel("Refrogerator Power")

# %%
# idx = x_test.shape[0]
# plt.figure(figsize=(10,6))
# plt.plot(x_test_timestamp, y_test[:idx], label = "Refri")
# plt.plot(x_test_timestamp, y_mean[:idx], label = "Predicted")
# plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
# plt.xlabel("TimeStamp test Scaled")
# plt.ylabel("Fridge  test Power")
# sns.despine()
# # savefig("CombinationKernel")
# # plt.savefig("./Results/Refrigerator_building5.png", bbox_inches="tight")

# %%
# model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
#                       inducing_points).to("cuda")

# %%
# pred_dist1 = model.predict(torch.tensor(np.array(x_train_full)).to("cuda"))
# # print("Done ", i)

# y_mean1 = pred_dist1.loc

# %%
# y_mean1 = scaler_y.inverse_transform(y_mean1.cpu().reshape(-1,1)).squeeze()
# # y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
# print(y_train.shape, y_mean1.shape)

# %%
# mae = np.mean(np.abs(np.array(y_train) - y_mean1))
# rms = errors.rmse(jnp.array(y_train), y_mean1)

# print("MAE: ", mae)
# print("RMSE: ", rms)

# %%
# idx = x_train.shape[0]
# plt.figure(figsize=(10,6))
# plt.plot(x_train_timstamp, y_train[:idx], label = "Refri")
# plt.plot(x_train_timstamp, y_mean[:idx], label = "Predicted")
# plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
# plt.xlabel("TimeStamp test Scaled")
# plt.ylabel("Fridge  test Power")
# sns.despine()
# # savefig("CombinationKernel")
# # plt.savefig("./Results/Refrigerator_building5.png", bbox_inches="tight")

# %%
#MAE:  39.81858310475401 build 6
#MAE:  30.333733374869247 build 3
#MAE:  37.32115756605644 build 2
#MAE: 43.212248588857065 build 5
#MAE:  48.917852990726765

# %%
# MAE: Building 6 MAE: 35.07
# MAE: Building 3 MAE:  31.565
# MAE: Building 2 MAE: 31.089
# MAE: Building 1 MAE: 37.3657
# MAE: Building 5 MAE:  46.316869

# %%
# MAE: Building 6 MAE: 34.3709125
# MAE: Building 3 MAE: 30.919
# MAE: Building 2 MAE: 30.43776
# MAE: Building 1 MAE: 37.10209
# MAE: Building 5 MAE: 45.02767

# %%
26.442985, 27.0600
