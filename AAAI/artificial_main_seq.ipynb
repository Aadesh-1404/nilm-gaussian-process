# %%
import os
os.chdir("../")
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import torch
from gpytorch.kernels import RBFKernel, ScaleKernel, PeriodicKernel, MaternKernel, CosineKernel
from skgpytorch.models import SVGPRegressor, SGPRegressor

# %%
import jax.numpy as jnp
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from utilities.fits import fit
# from utilities import plot
import tensorflow_probability.substrates.jax as tfp
dist = tfp.distributions
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from gpytorch.constraints import GreaterThan
from skgpytorch.metrics import mean_squared_error, negative_log_predictive_density
import time
import numpy as np

# from datasets.dataset_load import dataset_loader
from utilities import plot,fits,gmm,errors,predict,preprocess

# device = "cpu"
# torch.set_default_dtype(torch.float32)
# torch.set_default_tensor_type(torch.FloatTensor)

# %%
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler


def dataset_load(appliances, train, test=None):
    x_train = []
    y_train = []
    x_train_timestamp = []
    n = 99
    units_to_pad = n // 2
    scaler_x = StandardScaler()
    scaler_y = StandardScaler()
    scaler_time = StandardScaler()
    # train
    for key, values in train.items():
        for app in range(len(appliances)):
            df = pd.read_csv(
                f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[app]])
            df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
            startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
            endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

            if startDate > endDate:
                raise "Start Date must be smaller than Enddate."

            df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
            df.dropna(inplace=True)
            if app == 0:
                x = df[appliances[app]].values
            else:
                # print(app)
                x += df[appliances[app]].values
            if appliances[app] == "Refrigerator":
                y = df[appliances[app]].values
            # x = df["main"].values
            # y = df[appliances[app]].values
        timestamp_train = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])
        x_train.extend(x)
        y_train.extend(y)
        x_train_timestamp.extend(torch.tensor(timestamp_train))


    x_train = jnp.array(x_train)
    y_train = jnp.array(y_train).reshape(-1, 1)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(-1,1)
    x_train = scaler_x.fit_transform(x_train)
    y_train = scaler_y.fit_transform(y_train)
    x_train_timestamp = scaler_time.fit_transform(x_train_timestamp)


    # test
    x_test = []
    y_test = []
    x_test_timestamp = []
    x_test_timestamp_true =[]
    for key, values in test.items():
        for app in range(len(appliances)):
            df = pd.read_csv(
                f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[app]])
            df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
            startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
            endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

            if startDate > endDate:
                raise "Start Date must be smaller than Enddate."

            df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
            df.dropna(inplace=True)
            if app == 0:
                    x = df[appliances[app]].values
            else:
                print(app)
                x += df[appliances[app]].values
            if appliances[app] == "Refrigerator":
                y = df[appliances[app]].values
            # x = df["main"].values
            # y = df[appliances[0]].values
        timestamp_true = df["Timestamp"].values
        timestamp = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])
        x_test.extend(x)
        y_test.extend(y)
        x_test_timestamp_true.extend(timestamp_true)
        x_test_timestamp.extend(timestamp)

    x_test = jnp.array(x_test)
    y_test = jnp.array(y_test).reshape(-1, 1)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(-1,1)

    x_test = scaler_x.transform(x_test)
    x_test_timestamp = scaler_time.transform(x_test_timestamp)
#     y_test = scaler_y.transform(y_test)

    x_train = jnp.array(x_train).reshape(x_train.shape[0], n, 1)
    y_train = jnp.array(y_train)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(x_train_timestamp.shape[0], 1)
    x_test = jnp.array(x_test).reshape(x_test.shape[0], n, 1)
    y_test = jnp.array(y_test)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(x_test_timestamp.shape[0], 1).to(torch.float64)

    return x_train, y_train, x_test, y_test, x_train_timestamp, x_test_timestamp, x_test_timestamp_true, scaler_x, scaler_y, scaler_time

# %%
# def dataset_load(appliances, train, test=None):
#     x_train = []
#     y_train = []
#     x_train_timestamp = []
#     scaler_x = StandardScaler()
#     scaler_y = StandardScaler()
#     scaler_time = StandardScaler()
#     app = 0
#     # train
#     torch.set_default_dtype(torch.float64)
#     for key, values in train.items():
#         for app in range(len(appliances)):
#             df = pd.read_csv(
#                 f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[app]])
#             df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
#             startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
#             endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()
            

#             if startDate > endDate:
#                 raise "Start Date must be smaller than Enddate."

#             df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
#             df.dropna(inplace=True)
#             if app == 0:
#                 x = df[appliances[app]].values
#             else:
#                 print(app)
#                 x += df[appliances[app]].values
#             if appliances[app] == "Refrigerator":
#                 y = df[appliances[app]].values
#             # x = df["main"].values
            
        
#         timestamp_train = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values

#         x_train.extend(torch.tensor(x))
#         y_train.extend(torch.tensor(y))
#         x_train_timestamp.extend(torch.tensor(timestamp_train))


#     x_train = torch.tensor(x_train).reshape(-1, 1)
#     y_train = torch.tensor(y_train).reshape(-1, 1)
#     x_train_timestamp = torch.tensor(x_train_timestamp).reshape(-1,1)
#     x_train = scaler_x.fit_transform(x_train)
#     y_train = scaler_y.fit_transform(y_train)
#     x_train_timestamp = scaler_time.fit_transform(x_train_timestamp)



#     # test
#     x_test = []
#     y_test = []
#     x_test_timestamp = []
#     app = 0
#     for key, values in test.items():
#         for app in range(len(appliances)):
#             df = pd.read_csv(
#                 f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[app]])
#             df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
#             startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
#             endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

#             if startDate > endDate:
#                 raise "Start Date must be smaller than Enddate."

#             df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
#             df.dropna(inplace=True)
#             if app == 0:
#                 x = df[appliances[app]].values
#             else:
#                 print(app)
#                 x += df[appliances[app]].values
#             if appliances[app] == "Refrigerator":
#                 y = df[appliances[app]].values
#             # x = df["main"].values
#             # y = df[appliances[app]].values
#         timestamp = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values

#         x_test.extend(torch.tensor(x))
#         y_test.extend(torch.tensor(y))
#         x_test_timestamp.extend(timestamp)

#     x_test = torch.tensor(x_test).reshape(-1, 1)
#     y_test = torch.tensor(y_test).reshape(-1, 1)
#     x_test_timestamp = torch.tensor(x_test_timestamp).reshape(-1,1)

#     x_test = scaler_x.transform(x_test)
#     x_test_timestamp = scaler_time.transform(x_test_timestamp)

#     x_train = torch.tensor(x_train).reshape(x_train.shape[0], 1).to(torch.float64)
#     y_train = torch.tensor(y_train).reshape(-1,).to(torch.float64)
#     x_train_timestamp = torch.tensor(x_train_timestamp).reshape(x_train_timestamp.shape[0], 1).to(torch.float64)
#     x_test = torch.tensor(x_test).reshape(x_test.shape[0], 1).to(torch.float64)
#     y_test = torch.tensor(y_test).reshape(-1,).to(torch.float64)
#     x_test_timestamp = torch.tensor(x_test_timestamp).reshape(x_test_timestamp.shape[0], 1).to(torch.float64)


#     return x_train, y_train, x_test, y_test, x_train_timestamp, x_test_timestamp, scaler_x, scaler_y, scaler_time

# %%
train ={ 3: {
                'start_time': "2011-04-19" ,
                'end_time': "2011-05-22"
            },
                2: {
                    'start_time': "2011-04-21" ,
                    'end_time': "2011-05-21"
                },
      
                }
test = {  1:{
                    'start_time': "2011-04-28" ,
                    'end_time': "2011-05-15"
                },
                }

# 6: {
#                     'start_time': "2011-05-25" ,
#                     'end_time': "2011-06-13"
#                 }

# 5: {
#                     'start_time': "2011-04-22" ,
#                     'end_time': "2011-06-01"
#                 }
appliances = ["Microwave", "Refrigerator",  "Dish Washer"] #

# %%
x_train, y_train, x_test, y_test, x_train_timestamp, x_test_timestamp, x_test_time_true, scaler_x, scaler_y, scaler_time = dataset_load(appliances, train, test)
# Out:
# 1
# 2

# %%
x_train.shape, x_train_timestamp.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((30436, 99, 1),
#  torch.Size([30436, 1]),
#  (10138, 99, 1),
#  (30436, 1),
#  (10138, 1))

# %%
x_train = x_train.reshape(-1,99)
x_test = x_test.reshape(-1,99)

# %%
# plt.plot(x_train_timestamp, scaler_x.inverse_transform(x_train.reshape(-1,99)))
# plt.ylabel(f"Main Power Train")
# plt.xlabel(f"Timestamp Train")

# %%
plt.plot(x_train_timestamp, scaler_y.inverse_transform(y_train.reshape(-1,1)))
plt.ylabel(f"Ref Power Train")
plt.xlabel(f"Timestamp Train")

# %%
plt.plot(x_test_timestamp, scaler_x.inverse_transform(x_test.reshape(-1,1)))

plt.ylabel(f"Main Test")
plt.xlabel(f"Timestamp Test")

# %%
plt.plot(x_test_timestamp, y_test)
plt.ylabel(f"Ref Power test")
plt.xlabel(f"Timestamp test")

# %%
plt.scatter( scaler_x.inverse_transform(x_train), scaler_y.inverse_transform(y_train.reshape(-1,1)))
plt.xlabel("Main Train Power")
plt.ylabel("Fridge Train Power")
# Out:
# Text(0, 0.5, 'Fridge Train Power')

# %%
plt.scatter( scaler_x.inverse_transform(x_test),y_test.reshape(-1,1))
plt.xlabel("Main test Power")
plt.ylabel("Fridge test Power")
# Out:
# Text(0, 0.5, 'Fridge test Power')

# %%
x = torch.tensor(np.array(x_train)).to(torch.float32)
y = torch.tensor(np.array(y_train)).reshape(-1,).to(torch.float32)
xt = torch.tensor(np.array(x_test)).to(torch.float32)
yt = torch.tensor(np.array(y_test)).reshape(-1,).to(torch.float32)

# %%
x_train_full = torch.cat((x_train, x_train_timestamp), dim=1)
x_test_full = torch.cat((x_test, x_test_timestamp), dim=1)
x_train_full.shape, x_test_full.shape
# Out:
# (torch.Size([24918, 2]), torch.Size([15656, 2]))

# %%
mae_arr =[]
rms_arr = []
y_pred_arr = []

batch = 512

# x_train = x_train[:4500]
# y_train = y_train[:4500]

# y_test_trans = torch.tensor(torch.tensor(scaler_x.transform(y_test.reshape(-1,1))).reshape(-1,)).contiguous().to(torch.float64)
for i in range(1):


  kernel1 = ScaleKernel(RBFKernel(ard_num_dims=99)) #nu=2.5,
  # kernel2 = ScaleKernel(RBFKernel(ard_num_dims=1, active_dims=(1)))
  # kernel3 = ScaleKernel(PeriodicKernel(ard_num_dims=1, active_dims=(1)))
  # kernel4 = ScaleKernel(PeriodicKernel(ard_num_dims=2, active_dims=(0)))
  # kernel5 = ScaleKernel(CosineKernel(ard_num_dims=2, active_dims=(1)))

  kernel = kernel1# + kernel2*kernel3
  # induce_points = 512
  inducing_points =  x[np.arange(0,x.shape[0],20)] 
  #x[torch.randperm(x.shape[0])[: batch]].to("cuda")
  
  model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                       inducing_points).to("cuda")
  # model.mll.likelihood.noise_covar.register_constraint("raw_noise", GreaterThan(1e-2))
  # for param in model.parameters():
  #   # print(param)
  #   torch.nn.init.normal_(param, 0, 1)
  # theta1 = {'likelihood.noise_covar.noise': torch.tensor(3),
  #       'covar_module.base_kernel.lengthscale': torch.tensor(0.1),
  #       'covar_module.outputscale': torch.tensor(5),}
  loss = model.fit(lr=1e-2, n_epochs=1500,verbose=1,
          random_state=0)
#   loss_arr.append(loss)
  # print(loss)
  plt.plot(np.asarray(loss[0]))
  # plt.plot(np.asarray(test_loss[0]))
# Out:
# restart: 0, epoch: 1, iter: 1, loss: 1.7108
# restart: 0, epoch: 2, iter: 1, loss: 1.6964
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/kernels/inducing_point_kernel.py:61: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352645774/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   inv_root = torch.triangular_solve(eye, chol)[0]
# restart: 0, epoch: 3, iter: 1, loss: 1.6822
# restart: 0, epoch: 4, iter: 1, loss: 1.6692
# restart: 0, epoch: 5, iter: 1, loss: 1.6569
# restart: 0, epoch: 6, iter: 1, loss: 1.6450
# restart: 0, epoch: 7, iter: 1, loss: 1.6336
# restart: 0, epoch: 8, iter: 1, loss: 1.6228
# restart: 0, epoch: 9, iter: 1, loss: 1.6126
# restart: 0, epoch: 10, iter: 1, loss: 1.6028
# restart: 0, epoch: 11, iter: 1, loss: 1.5934
# restart: 0, epoch: 12, iter: 1, loss: 1.5843
# restart: 0, epoch: 13, iter: 1, loss: 1.5757
# restart: 0, epoch: 14, iter: 1, loss: 1.5674
# restart: 0, epoch: 15, iter: 1, loss: 1.5595
# restart: 0, epoch: 16, iter: 1, loss: 1.5519
# restart: 0, epoch: 17, iter: 1, loss: 1.5445
# restart: 0, epoch: 18, iter: 1, loss: 1.5375
# restart: 0, epoch: 19, iter: 1, loss: 1.5307
# restart: 0, epoch: 20, iter: 1, loss: 1.5241
# restart: 0, epoch: 21, iter: 1, loss: 1.5178
# restart: 0, epoch: 22, iter: 1, loss: 1.5116
# restart: 0, epoch: 23, iter: 1, loss: 1.5057
# restart: 0, epoch: 24, iter: 1, loss: 1.4999
# restart: 0, epoch: 25, iter: 1, loss: 1.4944
# restart: 0, epoch: 26, iter: 1, loss: 1.4890
# restart: 0, epoch: 27, iter: 1, loss: 1.4838
# restart: 0, epoch: 28, iter: 1, loss: 1.4787
# restart: 0, epoch: 29, iter: 1, loss: 1.4737
# restart: 0, epoch: 30, iter: 1, loss: 1.4690
# restart: 0, epoch: 31, iter: 1, loss: 1.4643
# restart: 0, epoch: 32, iter: 1, loss: 1.4597
# restart: 0, epoch: 33, iter: 1, loss: 1.4553
# restart: 0, epoch: 34, iter: 1, loss: 1.4510
# restart: 0, epoch: 35, iter: 1, loss: 1.4468
# restart: 0, epoch: 36, iter: 1, loss: 1.4427
# restart: 0, epoch: 37, iter: 1, loss: 1.4388
# restart: 0, epoch: 91, iter: 1, loss: 1.2913
# restart: 0, epoch: 92, iter: 1, loss: 1.2890
# restart: 0, epoch: 93, iter: 1, loss: 1.2866
# restart: 0, epoch: 94, iter: 1, loss: 1.2843
# restart: 0, epoch: 95, iter: 1, loss: 1.2820
# restart: 0, epoch: 96, iter: 1, loss: 1.2796
# restart: 0, epoch: 97, iter: 1, loss: 1.2773
# restart: 0, epoch: 98, iter: 1, loss: 1.2750
# restart: 0, epoch: 99, iter: 1, loss: 1.2726
# restart: 0, epoch: 100, iter: 1, loss: 1.2703
# restart: 0, epoch: 101, iter: 1, loss: 1.2680
# restart: 0, epoch: 102, iter: 1, loss: 1.2657
# restart: 0, epoch: 103, iter: 1, loss: 1.2634
# restart: 0, epoch: 104, iter: 1, loss: 1.2611
# restart: 0, epoch: 105, iter: 1, loss: 1.2588
# restart: 0, epoch: 106, iter: 1, loss: 1.2565
# restart: 0, epoch: 107, iter: 1, loss: 1.2542
# restart: 0, epoch: 108, iter: 1, loss: 1.2519
# restart: 0, epoch: 109, iter: 1, loss: 1.2496
# restart: 0, epoch: 110, iter: 1, loss: 1.2473
# restart: 0, epoch: 111, iter: 1, loss: 1.2450
# restart: 0, epoch: 112, iter: 1, loss: 1.2427
# restart: 0, epoch: 113, iter: 1, loss: 1.2404
# restart: 0, epoch: 114, iter: 1, loss: 1.2381
# restart: 0, epoch: 115, iter: 1, loss: 1.2358
# restart: 0, epoch: 116, iter: 1, loss: 1.2335
# restart: 0, epoch: 117, iter: 1, loss: 1.2312
# restart: 0, epoch: 118, iter: 1, loss: 1.2289
# restart: 0, epoch: 119, iter: 1, loss: 1.2266
# restart: 0, epoch: 120, iter: 1, loss: 1.2243
# restart: 0, epoch: 121, iter: 1, loss: 1.2220
# restart: 0, epoch: 122, iter: 1, loss: 1.2197
# restart: 0, epoch: 123, iter: 1, loss: 1.2174
# restart: 0, epoch: 124, iter: 1, loss: 1.2151
# restart: 0, epoch: 125, iter: 1, loss: 1.2128
# restart: 0, epoch: 126, iter: 1, loss: 1.2104
# restart: 0, epoch: 127, iter: 1, loss: 1.2081
# restart: 0, epoch: 128, iter: 1, loss: 1.2058
# restart: 0, epoch: 129, iter: 1, loss: 1.2035
# restart: 0, epoch: 130, iter: 1, loss: 1.2012
# restart: 0, epoch: 131, iter: 1, loss: 1.1988
# restart: 0, epoch: 132, iter: 1, loss: 1.1965
# restart: 0, epoch: 133, iter: 1, loss: 1.1942
# restart: 0, epoch: 134, iter: 1, loss: 1.1918
# restart: 0, epoch: 135, iter: 1, loss: 1.1895
# restart: 0, epoch: 136, iter: 1, loss: 1.1871
# restart: 0, epoch: 137, iter: 1, loss: 1.1848
# restart: 0, epoch: 138, iter: 1, loss: 1.1824
# restart: 0, epoch: 139, iter: 1, loss: 1.1800
# restart: 0, epoch: 140, iter: 1, loss: 1.1777
# restart: 0, epoch: 141, iter: 1, loss: 1.1753
# restart: 0, epoch: 142, iter: 1, loss: 1.1730
# restart: 0, epoch: 776, iter: 1, loss: 0.0253
# restart: 0, epoch: 777, iter: 1, loss: 0.0241
# restart: 0, epoch: 778, iter: 1, loss: 0.0229
# restart: 0, epoch: 779, iter: 1, loss: 0.0216
# restart: 0, epoch: 780, iter: 1, loss: 0.0205
# restart: 0, epoch: 781, iter: 1, loss: 0.0193
# restart: 0, epoch: 782, iter: 1, loss: 0.0181
# restart: 0, epoch: 783, iter: 1, loss: 0.0169
# restart: 0, epoch: 784, iter: 1, loss: 0.0158
# restart: 0, epoch: 785, iter: 1, loss: 0.0146
# restart: 0, epoch: 786, iter: 1, loss: 0.0134
# restart: 0, epoch: 787, iter: 1, loss: 0.0122
# restart: 0, epoch: 788, iter: 1, loss: 0.0111
# restart: 0, epoch: 789, iter: 1, loss: 0.0099
# restart: 0, epoch: 790, iter: 1, loss: 0.0088
# restart: 0, epoch: 791, iter: 1, loss: 0.0076
# restart: 0, epoch: 792, iter: 1, loss: 0.0064
# restart: 0, epoch: 793, iter: 1, loss: 0.0053
# restart: 0, epoch: 794, iter: 1, loss: 0.0041
# restart: 0, epoch: 795, iter: 1, loss: 0.0030
# restart: 0, epoch: 796, iter: 1, loss: 0.0018
# restart: 0, epoch: 797, iter: 1, loss: 0.0008
# restart: 0, epoch: 798, iter: 1, loss: -0.0005
# restart: 0, epoch: 799, iter: 1, loss: -0.0017
# restart: 0, epoch: 800, iter: 1, loss: -0.0027
# restart: 0, epoch: 801, iter: 1, loss: -0.0040
# restart: 0, epoch: 802, iter: 1, loss: -0.0051
# restart: 0, epoch: 803, iter: 1, loss: -0.0062
# restart: 0, epoch: 804, iter: 1, loss: -0.0074
# restart: 0, epoch: 805, iter: 1, loss: -0.0085
# restart: 0, epoch: 806, iter: 1, loss: -0.0096
# restart: 0, epoch: 807, iter: 1, loss: -0.0107
# restart: 0, epoch: 808, iter: 1, loss: -0.0118
# restart: 0, epoch: 809, iter: 1, loss: -0.0129
# restart: 0, epoch: 810, iter: 1, loss: -0.0140
# restart: 0, epoch: 811, iter: 1, loss: -0.0152
# restart: 0, epoch: 812, iter: 1, loss: -0.0163
# restart: 0, epoch: 813, iter: 1, loss: -0.0174
# restart: 0, epoch: 814, iter: 1, loss: -0.0185
# restart: 0, epoch: 815, iter: 1, loss: -0.0196
# restart: 0, epoch: 816, iter: 1, loss: -0.0207
# restart: 0, epoch: 817, iter: 1, loss: -0.0218
# restart: 0, epoch: 818, iter: 1, loss: -0.0228
# restart: 0, epoch: 819, iter: 1, loss: -0.0239
# restart: 0, epoch: 820, iter: 1, loss: -0.0250
# restart: 0, epoch: 821, iter: 1, loss: -0.0261
# restart: 0, epoch: 822, iter: 1, loss: -0.0271
# restart: 0, epoch: 823, iter: 1, loss: -0.0282
# restart: 0, epoch: 824, iter: 1, loss: -0.0293
# restart: 0, epoch: 825, iter: 1, loss: -0.0304
# restart: 0, epoch: 826, iter: 1, loss: -0.0315
# restart: 0, epoch: 827, iter: 1, loss: -0.0325
# restart: 0, epoch: 828, iter: 1, loss: -0.0336
# restart: 0, epoch: 829, iter: 1, loss: -0.0347
# restart: 0, epoch: 830, iter: 1, loss: -0.0358
# restart: 0, epoch: 831, iter: 1, loss: -0.0368
# restart: 0, epoch: 832, iter: 1, loss: -0.0379
# restart: 0, epoch: 833, iter: 1, loss: -0.0390
# restart: 0, epoch: 834, iter: 1, loss: -0.0401
# restart: 0, epoch: 835, iter: 1, loss: -0.0411
# restart: 0, epoch: 836, iter: 1, loss: -0.0422
# restart: 0, epoch: 837, iter: 1, loss: -0.0432
# restart: 0, epoch: 838, iter: 1, loss: -0.0442
# restart: 0, epoch: 839, iter: 1, loss: -0.0452
# restart: 0, epoch: 840, iter: 1, loss: -0.0462
# restart: 0, epoch: 841, iter: 1, loss: -0.0472
# restart: 0, epoch: 842, iter: 1, loss: -0.0481
# restart: 0, epoch: 843, iter: 1, loss: -0.0491
# restart: 0, epoch: 844, iter: 1, loss: -0.0501
# restart: 0, epoch: 845, iter: 1, loss: -0.0510
# restart: 0, epoch: 846, iter: 1, loss: -0.0520
# restart: 0, epoch: 847, iter: 1, loss: -0.0530
# restart: 0, epoch: 848, iter: 1, loss: -0.0540
# restart: 0, epoch: 849, iter: 1, loss: -0.0550
# restart: 0, epoch: 850, iter: 1, loss: -0.0560
# restart: 0, epoch: 851, iter: 1, loss: -0.0570
# restart: 0, epoch: 852, iter: 1, loss: -0.0580
# restart: 0, epoch: 853, iter: 1, loss: -0.0589
# restart: 0, epoch: 854, iter: 1, loss: -0.0599
# restart: 0, epoch: 855, iter: 1, loss: -0.0609
# restart: 0, epoch: 856, iter: 1, loss: -0.0619
# restart: 0, epoch: 857, iter: 1, loss: -0.0628
# restart: 0, epoch: 858, iter: 1, loss: -0.0637
# restart: 0, epoch: 859, iter: 1, loss: -0.0647
# restart: 0, epoch: 860, iter: 1, loss: -0.0656
# restart: 0, epoch: 861, iter: 1, loss: -0.0665
# restart: 0, epoch: 862, iter: 1, loss: -0.0674
# restart: 0, epoch: 863, iter: 1, loss: -0.0683
# restart: 0, epoch: 864, iter: 1, loss: -0.0692
# restart: 0, epoch: 865, iter: 1, loss: -0.0702
# restart: 0, epoch: 866, iter: 1, loss: -0.0711
# restart: 0, epoch: 867, iter: 1, loss: -0.0720
# restart: 0, epoch: 868, iter: 1, loss: -0.0730
# restart: 0, epoch: 869, iter: 1, loss: -0.0739
# restart: 0, epoch: 870, iter: 1, loss: -0.0748
# restart: 0, epoch: 871, iter: 1, loss: -0.0757
# restart: 0, epoch: 872, iter: 1, loss: -0.0766
# restart: 0, epoch: 873, iter: 1, loss: -0.0775
# restart: 0, epoch: 874, iter: 1, loss: -0.0785
# restart: 0, epoch: 875, iter: 1, loss: -0.0794
# restart: 0, epoch: 876, iter: 1, loss: -0.0803
# restart: 0, epoch: 877, iter: 1, loss: -0.0812
# restart: 0, epoch: 878, iter: 1, loss: -0.0820
# restart: 0, epoch: 879, iter: 1, loss: -0.0830
# restart: 0, epoch: 880, iter: 1, loss: -0.0839
# restart: 0, epoch: 881, iter: 1, loss: -0.0848
# restart: 0, epoch: 882, iter: 1, loss: -0.0857
# restart: 0, epoch: 883, iter: 1, loss: -0.0866
# restart: 0, epoch: 884, iter: 1, loss: -0.0875
# restart: 0, epoch: 885, iter: 1, loss: -0.0884
# restart: 0, epoch: 886, iter: 1, loss: -0.0893
# restart: 0, epoch: 887, iter: 1, loss: -0.0902
# restart: 0, epoch: 888, iter: 1, loss: -0.0911
# restart: 0, epoch: 889, iter: 1, loss: -0.0921
# restart: 0, epoch: 890, iter: 1, loss: -0.0930
# restart: 0, epoch: 891, iter: 1, loss: -0.0939
# restart: 0, epoch: 892, iter: 1, loss: -0.0948
# restart: 0, epoch: 893, iter: 1, loss: -0.0957
# restart: 0, epoch: 894, iter: 1, loss: -0.0966
# restart: 0, epoch: 895, iter: 1, loss: -0.0974
# restart: 0, epoch: 896, iter: 1, loss: -0.0984
# restart: 0, epoch: 897, iter: 1, loss: -0.0992
# restart: 0, epoch: 898, iter: 1, loss: -0.1001
# restart: 0, epoch: 899, iter: 1, loss: -0.1010
# restart: 0, epoch: 900, iter: 1, loss: -0.1020
# restart: 0, epoch: 901, iter: 1, loss: -0.1029
# restart: 0, epoch: 902, iter: 1, loss: -0.1038
# restart: 0, epoch: 903, iter: 1, loss: -0.1047
# restart: 0, epoch: 904, iter: 1, loss: -0.1056
# restart: 0, epoch: 905, iter: 1, loss: -0.1065
# restart: 0, epoch: 906, iter: 1, loss: -0.1075
# restart: 0, epoch: 907, iter: 1, loss: -0.1084
# restart: 0, epoch: 908, iter: 1, loss: -0.1093
# restart: 0, epoch: 909, iter: 1, loss: -0.1103
# restart: 0, epoch: 910, iter: 1, loss: -0.1112
# restart: 0, epoch: 911, iter: 1, loss: -0.1121
# restart: 0, epoch: 912, iter: 1, loss: -0.1130
# restart: 0, epoch: 913, iter: 1, loss: -0.1139
# restart: 0, epoch: 914, iter: 1, loss: -0.1148
# restart: 0, epoch: 915, iter: 1, loss: -0.1158
# restart: 0, epoch: 916, iter: 1, loss: -0.1167
# restart: 0, epoch: 917, iter: 1, loss: -0.1176
# restart: 0, epoch: 918, iter: 1, loss: -0.1185
# restart: 0, epoch: 919, iter: 1, loss: -0.1195
# restart: 0, epoch: 920, iter: 1, loss: -0.1204
# restart: 0, epoch: 921, iter: 1, loss: -0.1214
# restart: 0, epoch: 922, iter: 1, loss: -0.1223
# restart: 0, epoch: 923, iter: 1, loss: -0.1233
# restart: 0, epoch: 924, iter: 1, loss: -0.1242
# restart: 0, epoch: 925, iter: 1, loss: -0.1252
# restart: 0, epoch: 926, iter: 1, loss: -0.1261
# restart: 0, epoch: 927, iter: 1, loss: -0.1270
# restart: 0, epoch: 928, iter: 1, loss: -0.1279
# restart: 0, epoch: 929, iter: 1, loss: -0.1288
# restart: 0, epoch: 930, iter: 1, loss: -0.1296
# restart: 0, epoch: 931, iter: 1, loss: -0.1305
# restart: 0, epoch: 932, iter: 1, loss: -0.1314
# restart: 0, epoch: 933, iter: 1, loss: -0.1322
# restart: 0, epoch: 934, iter: 1, loss: -0.1331
# restart: 0, epoch: 935, iter: 1, loss: -0.1340
# restart: 0, epoch: 936, iter: 1, loss: -0.1348
# restart: 0, epoch: 937, iter: 1, loss: -0.1357
# restart: 0, epoch: 938, iter: 1, loss: -0.1366
# restart: 0, epoch: 939, iter: 1, loss: -0.1374
# restart: 0, epoch: 940, iter: 1, loss: -0.1382
# restart: 0, epoch: 941, iter: 1, loss: -0.1391
# restart: 0, epoch: 942, iter: 1, loss: -0.1399
# restart: 0, epoch: 943, iter: 1, loss: -0.1408
# restart: 0, epoch: 944, iter: 1, loss: -0.1416
# restart: 0, epoch: 945, iter: 1, loss: -0.1424
# restart: 0, epoch: 946, iter: 1, loss: -0.1433
# restart: 0, epoch: 947, iter: 1, loss: -0.1441
# restart: 0, epoch: 948, iter: 1, loss: -0.1449
# restart: 0, epoch: 949, iter: 1, loss: -0.1457
# restart: 0, epoch: 950, iter: 1, loss: -0.1465
# restart: 0, epoch: 951, iter: 1, loss: -0.1473
# restart: 0, epoch: 952, iter: 1, loss: -0.1482
# restart: 0, epoch: 953, iter: 1, loss: -0.1490
# restart: 0, epoch: 954, iter: 1, loss: -0.1498
# restart: 0, epoch: 955, iter: 1, loss: -0.1507
# restart: 0, epoch: 956, iter: 1, loss: -0.1515
# restart: 0, epoch: 957, iter: 1, loss: -0.1523
# restart: 0, epoch: 958, iter: 1, loss: -0.1531
# restart: 0, epoch: 959, iter: 1, loss: -0.1538
# restart: 0, epoch: 960, iter: 1, loss: -0.1546
# restart: 0, epoch: 961, iter: 1, loss: -0.1555
# restart: 0, epoch: 962, iter: 1, loss: -0.1563
# restart: 0, epoch: 963, iter: 1, loss: -0.1571
# restart: 0, epoch: 964, iter: 1, loss: -0.1580
# restart: 0, epoch: 965, iter: 1, loss: -0.1588
# restart: 0, epoch: 966, iter: 1, loss: -0.1596
# restart: 0, epoch: 967, iter: 1, loss: -0.1605
# restart: 0, epoch: 968, iter: 1, loss: -0.1613
# restart: 0, epoch: 969, iter: 1, loss: -0.1621
# restart: 0, epoch: 970, iter: 1, loss: -0.1630
# restart: 0, epoch: 971, iter: 1, loss: -0.1638
# restart: 0, epoch: 972, iter: 1, loss: -0.1646
# restart: 0, epoch: 973, iter: 1, loss: -0.1655
# restart: 0, epoch: 974, iter: 1, loss: -0.1663
# restart: 0, epoch: 975, iter: 1, loss: -0.1672
# restart: 0, epoch: 976, iter: 1, loss: -0.1680
# restart: 0, epoch: 977, iter: 1, loss: -0.1688
# restart: 0, epoch: 978, iter: 1, loss: -0.1697
# restart: 0, epoch: 979, iter: 1, loss: -0.1705
# restart: 0, epoch: 980, iter: 1, loss: -0.1713
# restart: 0, epoch: 981, iter: 1, loss: -0.1721
# restart: 0, epoch: 982, iter: 1, loss: -0.1729
# restart: 0, epoch: 983, iter: 1, loss: -0.1738
# restart: 0, epoch: 984, iter: 1, loss: -0.1746
# restart: 0, epoch: 985, iter: 1, loss: -0.1755
# restart: 0, epoch: 986, iter: 1, loss: -0.1763
# restart: 0, epoch: 987, iter: 1, loss: -0.1771
# restart: 0, epoch: 988, iter: 1, loss: -0.1780
# restart: 0, epoch: 989, iter: 1, loss: -0.1788
# restart: 0, epoch: 990, iter: 1, loss: -0.1796
# restart: 0, epoch: 991, iter: 1, loss: -0.1805
# restart: 0, epoch: 992, iter: 1, loss: -0.1813
# restart: 0, epoch: 993, iter: 1, loss: -0.1822
# restart: 0, epoch: 994, iter: 1, loss: -0.1830
# restart: 0, epoch: 995, iter: 1, loss: -0.1838
# restart: 0, epoch: 996, iter: 1, loss: -0.1845
# restart: 0, epoch: 997, iter: 1, loss: -0.1854
# restart: 0, epoch: 998, iter: 1, loss: -0.1862
# restart: 0, epoch: 999, iter: 1, loss: -0.1872
# restart: 0, epoch: 1000, iter: 1, loss: -0.1880
# restart: 0, epoch: 1001, iter: 1, loss: -0.1889
# restart: 0, epoch: 1002, iter: 1, loss: -0.1897
# restart: 0, epoch: 1003, iter: 1, loss: -0.1906
# restart: 0, epoch: 1004, iter: 1, loss: -0.1915
# restart: 0, epoch: 1005, iter: 1, loss: -0.1923
# restart: 0, epoch: 1006, iter: 1, loss: -0.1932
# restart: 0, epoch: 1007, iter: 1, loss: -0.1942
# restart: 0, epoch: 1008, iter: 1, loss: -0.1951
# restart: 0, epoch: 1009, iter: 1, loss: -0.1961
# restart: 0, epoch: 1010, iter: 1, loss: -0.1971
# restart: 0, epoch: 1011, iter: 1, loss: -0.1981
# restart: 0, epoch: 1012, iter: 1, loss: -0.1990
# restart: 0, epoch: 1013, iter: 1, loss: -0.2000
# restart: 0, epoch: 1014, iter: 1, loss: -0.2010
# restart: 0, epoch: 1015, iter: 1, loss: -0.2019
# restart: 0, epoch: 1016, iter: 1, loss: -0.2029
# restart: 0, epoch: 1017, iter: 1, loss: -0.2039
# restart: 0, epoch: 1018, iter: 1, loss: -0.2049
# restart: 0, epoch: 1019, iter: 1, loss: -0.2060
# restart: 0, epoch: 1020, iter: 1, loss: -0.2070
# restart: 0, epoch: 1021, iter: 1, loss: -0.2081
# restart: 0, epoch: 1022, iter: 1, loss: -0.2091
# restart: 0, epoch: 1023, iter: 1, loss: -0.2101
# restart: 0, epoch: 1024, iter: 1, loss: -0.2111
# restart: 0, epoch: 1025, iter: 1, loss: -0.2121
# restart: 0, epoch: 1026, iter: 1, loss: -0.2131
# ...
# restart: 0, epoch: 1168, iter: 1, loss: -0.3879
# restart: 0, epoch: 1169, iter: 1, loss: -0.3891
# restart: 0, epoch: 1170, iter: 1, loss: -0.3903
# restart: 0, epoch: 1171, iter: 1, loss: -0.3915
# restart: 0, epoch: 1172, iter: 1, loss: -0.3926
# restart: 0, epoch: 1173, iter: 1, loss: -0.3937
# restart: 0, epoch: 1174, iter: 1, loss: -0.3948
# restart: 0, epoch: 1175, iter: 1, loss: -0.3959
# restart: 0, epoch: 1176, iter: 1, loss: -0.3970
# restart: 0, epoch: 1177, iter: 1, loss: -0.3982
# restart: 0, epoch: 1178, iter: 1, loss: -0.3994
# restart: 0, epoch: 1179, iter: 1, loss: -0.4005
# restart: 0, epoch: 1180, iter: 1, loss: -0.4017
# restart: 0, epoch: 1181, iter: 1, loss: -0.4030
# restart: 0, epoch: 1182, iter: 1, loss: -0.4042
# restart: 0, epoch: 1183, iter: 1, loss: -0.4053
# restart: 0, epoch: 1184, iter: 1, loss: -0.4065
# restart: 0, epoch: 1185, iter: 1, loss: -0.4077
# restart: 0, epoch: 1186, iter: 1, loss: -0.4091
# restart: 0, epoch: 1187, iter: 1, loss: -0.4105
# restart: 0, epoch: 1188, iter: 1, loss: -0.4119
# restart: 0, epoch: 1189, iter: 1, loss: -0.4134
# restart: 0, epoch: 1190, iter: 1, loss: -0.4149
# restart: 0, epoch: 1191, iter: 1, loss: -0.4164
# restart: 0, epoch: 1192, iter: 1, loss: -0.4178
# restart: 0, epoch: 1193, iter: 1, loss: -0.4193
# restart: 0, epoch: 1194, iter: 1, loss: -0.4206
# restart: 0, epoch: 1195, iter: 1, loss: -0.4220
# restart: 0, epoch: 1196, iter: 1, loss: -0.4233
# restart: 0, epoch: 1197, iter: 1, loss: -0.4246
# restart: 0, epoch: 1198, iter: 1, loss: -0.4260
# restart: 0, epoch: 1199, iter: 1, loss: -0.4274
# restart: 0, epoch: 1200, iter: 1, loss: -0.4289
# restart: 0, epoch: 1201, iter: 1, loss: -0.4304
# restart: 0, epoch: 1202, iter: 1, loss: -0.4319
# restart: 0, epoch: 1203, iter: 1, loss: -0.4333
# restart: 0, epoch: 1204, iter: 1, loss: -0.4348
# restart: 0, epoch: 1205, iter: 1, loss: -0.4362
# restart: 0, epoch: 1206, iter: 1, loss: -0.4377
# restart: 0, epoch: 1207, iter: 1, loss: -0.4391
# restart: 0, epoch: 1208, iter: 1, loss: -0.4406
# restart: 0, epoch: 1209, iter: 1, loss: -0.4421
# restart: 0, epoch: 1210, iter: 1, loss: -0.4436
# restart: 0, epoch: 1211, iter: 1, loss: -0.4451
# restart: 0, epoch: 1212, iter: 1, loss: -0.4466
# restart: 0, epoch: 1213, iter: 1, loss: -0.4479
# restart: 0, epoch: 1214, iter: 1, loss: -0.4494
# restart: 0, epoch: 1215, iter: 1, loss: -0.4508
# restart: 0, epoch: 1216, iter: 1, loss: -0.4522
# restart: 0, epoch: 1217, iter: 1, loss: -0.4537
# restart: 0, epoch: 1218, iter: 1, loss: -0.4551
# restart: 0, epoch: 1219, iter: 1, loss: -0.4565
# restart: 0, epoch: 1220, iter: 1, loss: -0.4580
# restart: 0, epoch: 1221, iter: 1, loss: -0.4594
# restart: 0, epoch: 1222, iter: 1, loss: -0.4607
# restart: 0, epoch: 1223, iter: 1, loss: -0.4621
# restart: 0, epoch: 1224, iter: 1, loss: -0.4634
# restart: 0, epoch: 1225, iter: 1, loss: -0.4647
# restart: 0, epoch: 1226, iter: 1, loss: -0.4660
# restart: 0, epoch: 1227, iter: 1, loss: -0.4673
# restart: 0, epoch: 1228, iter: 1, loss: -0.4685
# restart: 0, epoch: 1229, iter: 1, loss: -0.4697
# restart: 0, epoch: 1230, iter: 1, loss: -0.4709
# restart: 0, epoch: 1231, iter: 1, loss: -0.4721
# restart: 0, epoch: 1232, iter: 1, loss: -0.4734
# restart: 0, epoch: 1233, iter: 1, loss: -0.4748
# restart: 0, epoch: 1234, iter: 1, loss: -0.4761
# restart: 0, epoch: 1235, iter: 1, loss: -0.4773
# restart: 0, epoch: 1236, iter: 1, loss: -0.4785
# restart: 0, epoch: 1237, iter: 1, loss: -0.4796
# restart: 0, epoch: 1238, iter: 1, loss: -0.4807
# restart: 0, epoch: 1239, iter: 1, loss: -0.4817
# restart: 0, epoch: 1240, iter: 1, loss: -0.4829
# restart: 0, epoch: 1241, iter: 1, loss: -0.4840
# restart: 0, epoch: 1242, iter: 1, loss: -0.4851
# restart: 0, epoch: 1243, iter: 1, loss: -0.4863
# restart: 0, epoch: 1244, iter: 1, loss: -0.4873
# restart: 0, epoch: 1245, iter: 1, loss: -0.4883
# restart: 0, epoch: 1246, iter: 1, loss: -0.4893
# restart: 0, epoch: 1247, iter: 1, loss: -0.4903
# restart: 0, epoch: 1248, iter: 1, loss: -0.4913
# restart: 0, epoch: 1249, iter: 1, loss: -0.4922
# restart: 0, epoch: 1250, iter: 1, loss: -0.4932
# restart: 0, epoch: 1251, iter: 1, loss: -0.4942
# restart: 0, epoch: 1252, iter: 1, loss: -0.4952
# restart: 0, epoch: 1253, iter: 1, loss: -0.4962
# restart: 0, epoch: 1254, iter: 1, loss: -0.4972
# restart: 0, epoch: 1255, iter: 1, loss: -0.4982
# restart: 0, epoch: 1256, iter: 1, loss: -0.4992
# restart: 0, epoch: 1257, iter: 1, loss: -0.5001
# restart: 0, epoch: 1258, iter: 1, loss: -0.5011
# restart: 0, epoch: 1259, iter: 1, loss: -0.5020
# restart: 0, epoch: 1260, iter: 1, loss: -0.5030
# restart: 0, epoch: 1261, iter: 1, loss: -0.5040
# restart: 0, epoch: 1262, iter: 1, loss: -0.5050
# restart: 0, epoch: 1263, iter: 1, loss: -0.5059
# restart: 0, epoch: 1264, iter: 1, loss: -0.5069
# restart: 0, epoch: 1265, iter: 1, loss: -0.5078
# restart: 0, epoch: 1266, iter: 1, loss: -0.5088
# restart: 0, epoch: 1267, iter: 1, loss: -0.5097
# restart: 0, epoch: 1268, iter: 1, loss: -0.5106
# restart: 0, epoch: 1269, iter: 1, loss: -0.5116
# restart: 0, epoch: 1270, iter: 1, loss: -0.5125
# restart: 0, epoch: 1271, iter: 1, loss: -0.5134
# restart: 0, epoch: 1272, iter: 1, loss: -0.5143
# restart: 0, epoch: 1273, iter: 1, loss: -0.5152
# restart: 0, epoch: 1274, iter: 1, loss: -0.5160
# restart: 0, epoch: 1275, iter: 1, loss: -0.5168
# restart: 0, epoch: 1276, iter: 1, loss: -0.5177
# restart: 0, epoch: 1277, iter: 1, loss: -0.5186
# restart: 0, epoch: 1278, iter: 1, loss: -0.5194
# restart: 0, epoch: 1279, iter: 1, loss: -0.5203
# restart: 0, epoch: 1280, iter: 1, loss: -0.5212
# restart: 0, epoch: 1281, iter: 1, loss: -0.5220
# restart: 0, epoch: 1282, iter: 1, loss: -0.5229
# restart: 0, epoch: 1283, iter: 1, loss: -0.5237
# restart: 0, epoch: 1284, iter: 1, loss: -0.5245
# restart: 0, epoch: 1285, iter: 1, loss: -0.5254
# restart: 0, epoch: 1286, iter: 1, loss: -0.5262
# restart: 0, epoch: 1287, iter: 1, loss: -0.5269
# restart: 0, epoch: 1288, iter: 1, loss: -0.5277
# restart: 0, epoch: 1289, iter: 1, loss: -0.5284
# restart: 0, epoch: 1290, iter: 1, loss: -0.5292
# restart: 0, epoch: 1291, iter: 1, loss: -0.5300
# restart: 0, epoch: 1292, iter: 1, loss: -0.5306
# restart: 0, epoch: 1293, iter: 1, loss: -0.5314
# restart: 0, epoch: 1294, iter: 1, loss: -0.5321
# restart: 0, epoch: 1295, iter: 1, loss: -0.5328
# restart: 0, epoch: 1296, iter: 1, loss: -0.5336
# restart: 0, epoch: 1297, iter: 1, loss: -0.5342
# restart: 0, epoch: 1298, iter: 1, loss: -0.5349
# restart: 0, epoch: 1299, iter: 1, loss: -0.5356
# restart: 0, epoch: 1300, iter: 1, loss: -0.5364
# restart: 0, epoch: 1301, iter: 1, loss: -0.5372
# restart: 0, epoch: 1302, iter: 1, loss: -0.5380
# restart: 0, epoch: 1303, iter: 1, loss: -0.5388
# restart: 0, epoch: 1304, iter: 1, loss: -0.5395
# restart: 0, epoch: 1305, iter: 1, loss: -0.5403
# restart: 0, epoch: 1306, iter: 1, loss: -0.5410
# restart: 0, epoch: 1307, iter: 1, loss: -0.5417
# restart: 0, epoch: 1308, iter: 1, loss: -0.5425
# restart: 0, epoch: 1309, iter: 1, loss: -0.5432
# restart: 0, epoch: 1310, iter: 1, loss: -0.5439
# restart: 0, epoch: 1311, iter: 1, loss: -0.5446
# restart: 0, epoch: 1312, iter: 1, loss: -0.5453
# restart: 0, epoch: 1313, iter: 1, loss: -0.5460
# restart: 0, epoch: 1314, iter: 1, loss: -0.5467
# restart: 0, epoch: 1315, iter: 1, loss: -0.5474
# restart: 0, epoch: 1316, iter: 1, loss: -0.5482
# restart: 0, epoch: 1317, iter: 1, loss: -0.5490
# restart: 0, epoch: 1318, iter: 1, loss: -0.5497
# restart: 0, epoch: 1319, iter: 1, loss: -0.5504
# restart: 0, epoch: 1320, iter: 1, loss: -0.5510
# restart: 0, epoch: 1321, iter: 1, loss: -0.5517
# restart: 0, epoch: 1322, iter: 1, loss: -0.5524
# restart: 0, epoch: 1323, iter: 1, loss: -0.5530
# restart: 0, epoch: 1324, iter: 1, loss: -0.5537
# restart: 0, epoch: 1325, iter: 1, loss: -0.5544
# restart: 0, epoch: 1326, iter: 1, loss: -0.5551
# restart: 0, epoch: 1327, iter: 1, loss: -0.5558
# restart: 0, epoch: 1328, iter: 1, loss: -0.5565
# restart: 0, epoch: 1329, iter: 1, loss: -0.5572
# restart: 0, epoch: 1330, iter: 1, loss: -0.5578
# restart: 0, epoch: 1331, iter: 1, loss: -0.5585
# restart: 0, epoch: 1332, iter: 1, loss: -0.5592
# restart: 0, epoch: 1333, iter: 1, loss: -0.5598
# restart: 0, epoch: 1334, iter: 1, loss: -0.5603
# restart: 0, epoch: 1335, iter: 1, loss: -0.5610
# restart: 0, epoch: 1336, iter: 1, loss: -0.5617
# restart: 0, epoch: 1337, iter: 1, loss: -0.5623
# restart: 0, epoch: 1338, iter: 1, loss: -0.5630
# restart: 0, epoch: 1339, iter: 1, loss: -0.5636
# restart: 0, epoch: 1340, iter: 1, loss: -0.5642
# restart: 0, epoch: 1341, iter: 1, loss: -0.5650
# restart: 0, epoch: 1342, iter: 1, loss: -0.5657
# restart: 0, epoch: 1343, iter: 1, loss: -0.5662
# restart: 0, epoch: 1344, iter: 1, loss: -0.5668
# restart: 0, epoch: 1345, iter: 1, loss: -0.5674
# restart: 0, epoch: 1346, iter: 1, loss: -0.5680
# restart: 0, epoch: 1347, iter: 1, loss: -0.5687
# restart: 0, epoch: 1348, iter: 1, loss: -0.5693
# restart: 0, epoch: 1349, iter: 1, loss: -0.5700
# restart: 0, epoch: 1350, iter: 1, loss: -0.5706
# restart: 0, epoch: 1351, iter: 1, loss: -0.5713
# restart: 0, epoch: 1352, iter: 1, loss: -0.5719
# restart: 0, epoch: 1353, iter: 1, loss: -0.5725
# restart: 0, epoch: 1354, iter: 1, loss: -0.5729
# restart: 0, epoch: 1355, iter: 1, loss: -0.5735
# restart: 0, epoch: 1356, iter: 1, loss: -0.5742
# restart: 0, epoch: 1357, iter: 1, loss: -0.5747
# restart: 0, epoch: 1358, iter: 1, loss: -0.5753
# restart: 0, epoch: 1359, iter: 1, loss: -0.5759
# restart: 0, epoch: 1360, iter: 1, loss: -0.5765
# restart: 0, epoch: 1361, iter: 1, loss: -0.5771
# restart: 0, epoch: 1362, iter: 1, loss: -0.5776
# restart: 0, epoch: 1363, iter: 1, loss: -0.5782
# restart: 0, epoch: 1364, iter: 1, loss: -0.5788
# restart: 0, epoch: 1365, iter: 1, loss: -0.5794
# restart: 0, epoch: 1366, iter: 1, loss: -0.5800
# restart: 0, epoch: 1367, iter: 1, loss: -0.5807
# restart: 0, epoch: 1368, iter: 1, loss: -0.5812
# restart: 0, epoch: 1369, iter: 1, loss: -0.5819
# restart: 0, epoch: 1370, iter: 1, loss: -0.5826
# restart: 0, epoch: 1371, iter: 1, loss: -0.5832
# restart: 0, epoch: 1372, iter: 1, loss: -0.5839
# restart: 0, epoch: 1373, iter: 1, loss: -0.5844
# restart: 0, epoch: 1374, iter: 1, loss: -0.5848
# restart: 0, epoch: 1375, iter: 1, loss: -0.5854
# restart: 0, epoch: 1376, iter: 1, loss: -0.5860
# restart: 0, epoch: 1377, iter: 1, loss: -0.5866
# restart: 0, epoch: 1378, iter: 1, loss: -0.5873
# restart: 0, epoch: 1379, iter: 1, loss: -0.5880
# restart: 0, epoch: 1380, iter: 1, loss: -0.5886
# restart: 0, epoch: 1381, iter: 1, loss: -0.5892
# restart: 0, epoch: 1382, iter: 1, loss: -0.5897
# restart: 0, epoch: 1383, iter: 1, loss: -0.5903
# restart: 0, epoch: 1384, iter: 1, loss: -0.5909
# restart: 0, epoch: 1385, iter: 1, loss: -0.5916
# restart: 0, epoch: 1386, iter: 1, loss: -0.5923
# restart: 0, epoch: 1387, iter: 1, loss: -0.5931
# restart: 0, epoch: 1388, iter: 1, loss: -0.5938
# restart: 0, epoch: 1389, iter: 1, loss: -0.5944
# restart: 0, epoch: 1390, iter: 1, loss: -0.5951
# restart: 0, epoch: 1391, iter: 1, loss: -0.5958
# restart: 0, epoch: 1392, iter: 1, loss: -0.5965
# restart: 0, epoch: 1393, iter: 1, loss: -0.5972
# restart: 0, epoch: 1394, iter: 1, loss: -0.5980
# restart: 0, epoch: 1395, iter: 1, loss: -0.5987
# restart: 0, epoch: 1396, iter: 1, loss: -0.5994
# restart: 0, epoch: 1397, iter: 1, loss: -0.6002
# restart: 0, epoch: 1398, iter: 1, loss: -0.6008
# restart: 0, epoch: 1399, iter: 1, loss: -0.6016
# restart: 0, epoch: 1400, iter: 1, loss: -0.6023
# restart: 0, epoch: 1401, iter: 1, loss: -0.6030
# restart: 0, epoch: 1402, iter: 1, loss: -0.6037
# restart: 0, epoch: 1403, iter: 1, loss: -0.6044
# restart: 0, epoch: 1404, iter: 1, loss: -0.6050
# restart: 0, epoch: 1405, iter: 1, loss: -0.6057
# restart: 0, epoch: 1406, iter: 1, loss: -0.6064
# restart: 0, epoch: 1407, iter: 1, loss: -0.6071
# restart: 0, epoch: 1408, iter: 1, loss: -0.6077
# restart: 0, epoch: 1409, iter: 1, loss: -0.6083
# restart: 0, epoch: 1410, iter: 1, loss: -0.6088
# restart: 0, epoch: 1411, iter: 1, loss: -0.6095
# restart: 0, epoch: 1412, iter: 1, loss: -0.6102
# restart: 0, epoch: 1413, iter: 1, loss: -0.6109
# restart: 0, epoch: 1414, iter: 1, loss: -0.6116
# restart: 0, epoch: 1415, iter: 1, loss: -0.6122
# restart: 0, epoch: 1416, iter: 1, loss: -0.6128
# restart: 0, epoch: 1417, iter: 1, loss: -0.6133
# restart: 0, epoch: 1418, iter: 1, loss: -0.6138
# restart: 0, epoch: 1419, iter: 1, loss: -0.6142
# restart: 0, epoch: 1420, iter: 1, loss: -0.6149
# restart: 0, epoch: 1421, iter: 1, loss: -0.6156
# restart: 0, epoch: 1422, iter: 1, loss: -0.6163
# restart: 0, epoch: 1423, iter: 1, loss: -0.6169
# restart: 0, epoch: 1424, iter: 1, loss: -0.6175
# restart: 0, epoch: 1425, iter: 1, loss: -0.6181
# restart: 0, epoch: 1426, iter: 1, loss: -0.6186
# restart: 0, epoch: 1427, iter: 1, loss: -0.6192
# restart: 0, epoch: 1428, iter: 1, loss: -0.6198
# restart: 0, epoch: 1429, iter: 1, loss: -0.6204
# restart: 0, epoch: 1430, iter: 1, loss: -0.6209
# restart: 0, epoch: 1431, iter: 1, loss: -0.6215
# restart: 0, epoch: 1432, iter: 1, loss: -0.6221
# restart: 0, epoch: 1433, iter: 1, loss: -0.6226
# restart: 0, epoch: 1434, iter: 1, loss: -0.6232
# restart: 0, epoch: 1435, iter: 1, loss: -0.6238
# restart: 0, epoch: 1436, iter: 1, loss: -0.6244
# restart: 0, epoch: 1437, iter: 1, loss: -0.6250
# restart: 0, epoch: 1438, iter: 1, loss: -0.6256
# restart: 0, epoch: 1439, iter: 1, loss: -0.6262
# restart: 0, epoch: 1440, iter: 1, loss: -0.6269
# restart: 0, epoch: 1441, iter: 1, loss: -0.6275
# restart: 0, epoch: 1442, iter: 1, loss: -0.6282
# restart: 0, epoch: 1443, iter: 1, loss: -0.6289
# restart: 0, epoch: 1444, iter: 1, loss: -0.6295
# restart: 0, epoch: 1445, iter: 1, loss: -0.6301
# restart: 0, epoch: 1446, iter: 1, loss: -0.6308
# restart: 0, epoch: 1447, iter: 1, loss: -0.6315
# restart: 0, epoch: 1448, iter: 1, loss: -0.6321
# restart: 0, epoch: 1449, iter: 1, loss: -0.6327
# restart: 0, epoch: 1450, iter: 1, loss: -0.6334
# restart: 0, epoch: 1451, iter: 1, loss: -0.6339
# restart: 0, epoch: 1452, iter: 1, loss: -0.6345
# restart: 0, epoch: 1453, iter: 1, loss: -0.6350
# restart: 0, epoch: 1454, iter: 1, loss: -0.6355
# restart: 0, epoch: 1455, iter: 1, loss: -0.6360
# restart: 0, epoch: 1456, iter: 1, loss: -0.6365
# restart: 0, epoch: 1457, iter: 1, loss: -0.6370
# restart: 0, epoch: 1458, iter: 1, loss: -0.6374
# restart: 0, epoch: 1459, iter: 1, loss: -0.6380
# restart: 0, epoch: 1460, iter: 1, loss: -0.6384
# restart: 0, epoch: 1461, iter: 1, loss: -0.6388
# restart: 0, epoch: 1462, iter: 1, loss: -0.6393
# restart: 0, epoch: 1463, iter: 1, loss: -0.6398
# restart: 0, epoch: 1464, iter: 1, loss: -0.6403
# restart: 0, epoch: 1465, iter: 1, loss: -0.6409
# restart: 0, epoch: 1466, iter: 1, loss: -0.6414
# restart: 0, epoch: 1467, iter: 1, loss: -0.6418
# restart: 0, epoch: 1468, iter: 1, loss: -0.6423
# restart: 0, epoch: 1469, iter: 1, loss: -0.6427
# restart: 0, epoch: 1470, iter: 1, loss: -0.6432
# restart: 0, epoch: 1471, iter: 1, loss: -0.6436
# restart: 0, epoch: 1472, iter: 1, loss: -0.6442
# restart: 0, epoch: 1473, iter: 1, loss: -0.6446
# restart: 0, epoch: 1474, iter: 1, loss: -0.6451
# restart: 0, epoch: 1475, iter: 1, loss: -0.6455
# restart: 0, epoch: 1476, iter: 1, loss: -0.6460
# restart: 0, epoch: 1477, iter: 1, loss: -0.6464
# restart: 0, epoch: 1478, iter: 1, loss: -0.6468
# restart: 0, epoch: 1479, iter: 1, loss: -0.6472
# restart: 0, epoch: 1480, iter: 1, loss: -0.6476
# restart: 0, epoch: 1481, iter: 1, loss: -0.6479
# restart: 0, epoch: 1482, iter: 1, loss: -0.6483
# restart: 0, epoch: 1483, iter: 1, loss: -0.6486
# restart: 0, epoch: 1484, iter: 1, loss: -0.6491
# restart: 0, epoch: 1485, iter: 1, loss: -0.6496
# restart: 0, epoch: 1486, iter: 1, loss: -0.6501
# restart: 0, epoch: 1487, iter: 1, loss: -0.6506
# restart: 0, epoch: 1488, iter: 1, loss: -0.6511
# restart: 0, epoch: 1489, iter: 1, loss: -0.6517
# restart: 0, epoch: 1490, iter: 1, loss: -0.6521
# restart: 0, epoch: 1491, iter: 1, loss: -0.6525
# restart: 0, epoch: 1492, iter: 1, loss: -0.6530
# restart: 0, epoch: 1493, iter: 1, loss: -0.6533
# restart: 0, epoch: 1494, iter: 1, loss: -0.6538
# restart: 0, epoch: 1495, iter: 1, loss: -0.6543
# restart: 0, epoch: 1496, iter: 1, loss: -0.6547
# restart: 0, epoch: 1497, iter: 1, loss: -0.6551
# restart: 0, epoch: 1498, iter: 1, loss: -0.6555
# restart: 0, epoch: 1499, iter: 1, loss: -0.6560
# restart: 0, epoch: 1500, iter: 1, loss: -0.6564

# %%
# model_name = "Refrigerator_trial_atrificial_main_only_main_fold3.pt"
# torch.save(model.state_dict(), os.path.join(
#   "models/", model_name))

# %%
# kernel1 = ScaleKernel(RBFKernel(ard_num_dims=1, active_dims=(0))) #nu=2.5,
# # kernel2 = ScaleKernel(RBFKernel(ard_num_dims=1, active_dims=(1)))
# # kernel3 = ScaleKernel(PeriodicKernel(ard_num_dims=1, active_dims=(1)))
# # kernel4 = ScaleKernel(PeriodicKernel(ard_num_dims=2, active_dims=(0)))
# # kernel5 = ScaleKernel(CosineKernel(ard_num_dims=2, active_dims=(1)))

# kernel = kernel1# + kernel2*kernel3
# # induce_points = 512
# inducing_points =  x_train[np.arange(0,x_train.shape[0],20)] 
# #x_train_full[torch.randperm(x_train_full.shape[0])[: batch]].to("cuda")

# model = SGPRegressor(x_train.to("cuda"), y_train.to("cuda"), kernel,
#                       inducing_points).to("cuda")

# model_name = "Refrigerator_trial_atrificial_main_only_main_fold3.pt"
# model.load_state_dict(torch.load(
#     os.path.join("models/", model_name)))

# %%
y_pred_arr =[]
pred_dist = model.predict(xt.to("cuda"))

y_pred_arr.append(pred_dist.loc)

# %%
y_pred_arr1 = []
for i in range(len(y_pred_arr)):
  y_pred_arr1.append(np.array(y_pred_arr[i].cpu()))

# %%
y_mean = np.mean(y_pred_arr1, axis =0)
# y_sigma = np.std(y_pred_arr1, axis=0)

y_mean.shape#, y_sigma.shape

y_mean = scaler_y.inverse_transform(y_mean.reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(y_test.shape, y_mean.shape)

y_mean = np.clip(y_mean,0,y_mean.max(),out=y_mean)
# Out:
# (10138, 1) (10138,)

# %%
mae = np.mean(np.abs(np.array(yt) - y_mean))
rms = errors.rmse(jnp.array(yt), y_mean)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  13.8347
# RMSE:  25.069845

# %%
idx = xt.shape[0]
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()

# %%
for name, params in model.named_parameters():
  print(name, params)
# Out:
# mll.likelihood.noise_covar.raw_noise Parameter containing:
# tensor([-4.5857], device='cuda:0', requires_grad=True)
# mll.model.mean_module.constant Parameter containing:
# tensor([1.0225], device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.raw_outputscale Parameter containing:
# tensor(-2.1696, device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.base_kernel.raw_lengthscale Parameter containing:
# tensor([[10.8529, 11.5294, 11.8478, 11.9762, 11.9762, 12.0841, 12.1094, 12.2192,
#          12.3236, 12.2433, 12.2944, 12.1816, 12.1442, 12.1793, 12.1100, 12.2804,
#          12.5353, 12.6548, 12.4561, 12.6861, 12.5361, 12.5176, 12.7503, 12.8226,
#          12.8785, 12.8690, 12.9469, 12.8613, 12.8698, 12.8163, 12.6896, 12.1944,
#          12.4773, 12.6018, 12.5389, 11.9237, 12.0042, 11.8610, 11.9660, 11.8486,
#          11.7586, 12.0849, 11.9569, 12.0326, 11.9451, 10.9251, 11.9894, 11.7399,
#           9.7000,  0.0409,  9.3090, 12.7258, 11.9316, 12.3491, 12.9660, 12.3601,
#          12.6374, 12.5310, 12.6177, 12.3309, 12.2320, 11.7149, 12.0509, 12.1381,
#          12.0708, 12.5524, 12.0824, 11.8513, 12.4193, 12.4565, 12.4381, 12.6400,
#          12.9643, 13.0455, 13.0588, 12.7708, 12.7454, 12.8167, 12.7001, 12.5235,
#          12.5541, 12.6029, 12.6663, 12.0984, 11.3893, 12.2643, 11.7732, 12.2919,
#          12.1471, 12.1223, 12.0761, 12.0315, 12.0940, 12.0801, 12.2299, 12.3292,
#          11.8290, 11.5400, 10.5159]], device='cuda:0', requires_grad=True)
# mll.model.covar_module.inducing_points Parameter containing:
# tensor([[-0.1637, -0.1372, -0.1119,  ...,  0.1418,  0.0176, -0.0317],
#         [ 0.3477,  0.3095,  0.2156,  ...,  1.0157,  0.9441,  0.9408],
#         [-0.3229, -0.5254,  5.1574,  ...,  3.9690,  7.2191,  7.6584],
#         ...,
#         [-0.2213, -0.1493, -0.1769,  ..., -0.2556, -0.2620, -0.2092],
#         [ 4.9192,  4.0190,  1.6179,  ..., -0.3267, -0.3146, -0.2778],
#         [ 0.0619,  0.0689, -0.2059,  ..., -0.1816, -0.0526, -0.0332]],
#        device='cuda:0', requires_grad=True)

# %%
ar = np.arange(0,99,1)
print(ar.shape)
plt.plot(ar,model.mll.model.base_covar_module.base_kernel.lengthscale.cpu().detach().numpy().reshape(-1,))
plt.xlabel("# ARD")
plt.ylabel("Learned Lengthscale Values")
# Out:
# (99,)
# Text(0, 0.5, 'Learned Lengthscale Values')

# %%
pd.plotting.autocorrelation_plot(pd.Series(y[:500].reshape(-1,)))
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
pd.plotting.autocorrelation_plot(pd.Series(yt[:500].reshape(-1,)))
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %% [markdown]
# ## Decomposition

# %%
model1 = SGPRegressor(x_train_full.to("cuda"), y_train.to("cuda"), kernel1,
                      inducing_points).to("cuda")

# %%
pred_dist1 = model1.predict(x_test_full[:4000].to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc
# Out:
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(

# %%
y_pred_arr =[]

y_pred_arr.append(pred_dist1.loc)

# %%
y_mean1.shape
# Out:
# torch.Size([4000])

# %%
y_pred_arr1 = []
for i in range(len(y_pred_arr)):
  y_pred_arr1.append(np.array(y_pred_arr[i].cpu()))

# %%
y_mean1 = np.mean(y_pred_arr1, axis =0)
# y_sigma = np.std(y_pred_arr1, axis=0)

y_mean1.shape#, y_sigma.shape

y_mean1 = scaler_y.inverse_transform(y_mean1.reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(y_test.shape, y_mean1.shape)

y_mean1 = np.clip(y_mean1,0,y_mean1.max(),out=y_mean1)
# Out:
# torch.Size([15656]) (4000,)

# %%
mae = np.mean(np.abs(np.array(y_test[:4000]) - y_mean1))
rms = errors.rmse(jnp.array(y_test[:4000]), y_mean1)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  13.221285980073695
# RMSE:  23.772297

# %%
idx = 3000
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp[:idx], y_test.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean1[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()

# %%
model2 = SGPRegressor(x_train_full.to("cuda"), y_train.to("cuda"), kernel2*kernel3,
                      inducing_points).to("cuda")

# %%
pred_dist2 = model2.predict(x_test_full[:4000].to("cuda"))
# print("Done ", i)

y_mean2 = pred_dist2.loc

# %%
y_pred_arr =[]

y_pred_arr.append(pred_dist2.loc)

# %%
y_pred_arr1 = []
for i in range(len(y_pred_arr)):
  y_pred_arr1.append(np.array(y_pred_arr[i].cpu()))

# %%
y_mean2 = np.mean(y_pred_arr1, axis =0)
# y_sigma = np.std(y_pred_arr2, axis=0)

y_mean2.shape#, y_sigma.shape

y_mean2 = scaler_y.inverse_transform(y_mean2.reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(y_test.shape, y_mean2.shape)

y_mean2 = np.clip(y_mean2,0,y_mean2.max(),out=y_mean2)
# Out:
# torch.Size([15656]) (4000,)

# %%
mae = np.mean(np.abs(np.array(y_test[:4000]) - y_mean2))
rms = errors.rmse(jnp.array(y_test[:4000]), y_mean2)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  66.97996230941146
# RMSE:  83.967285

# %%
idx = 3000
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp[:idx], y_test.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean2[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
