# %%
import os
os.chdir("../")
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %%
import torch
from gpytorch.kernels import RBFKernel, ScaleKernel, PeriodicKernel, MaternKernel, CosineKernel, LinearKernel
from skgpytorch.models import SVGPRegressor, SGPRegressor

# %%
import jax.numpy as jnp
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from utilities.fits import fit
# from utilities import plot
import tensorflow_probability.substrates.jax as tfp
dist = tfp.distributions
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from gpytorch.constraints import GreaterThan
from skgpytorch.metrics import mean_squared_error, negative_log_predictive_density
import time
import numpy as np

# from datasets.dataset_load import dataset_loader
from utilities import plot,fits,gmm,errors,predict,preprocess

# device = "cpu"
# torch.set_default_dtype(torch.float32)
# torch.set_default_tensor_type(torch.FloatTensor)

# %%
import pandas as pd
import jax.numpy as jnp
from datetime import datetime
from sklearn.preprocessing import StandardScaler


def dataset_load(appliances, train, test=None, linear = False, bias = False):
    x_train = []
    y_train = []
    train_range = []
    x_train_timestamp = []
    n = 99
    units_to_pad = n // 2
    scaler_x = StandardScaler()
    scaler_y = StandardScaler()
    scaler_time = StandardScaler()
    scaler_range = StandardScaler()

    # train
    for key, values in train.items():
        for app in range(len(appliances)):
            df = pd.read_csv(
                f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[app]])
            df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
            startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
            endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

            if startDate > endDate:
                raise "Start Date must be smaller than Enddate."

            df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
            df.dropna(inplace=True)
            if app == 0:
                x = df[appliances[app]].values
            else:
                x += df[appliances[app]].values
            if appliances[app] == "Refrigerator":
                y = df[appliances[app]].values
      
        timestamp_train = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])
        x_train.extend(x)
        y_train.extend(y)
        train_range.extend(jnp.max(x, axis=1)-jnp.min(x, axis=1))
        x_train_timestamp.extend(torch.tensor(timestamp_train))


    x_train = jnp.array(x_train)
    y_train = jnp.array(y_train).reshape(-1, 1)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(-1,1)
    x_train_range = jnp.array(train_range).reshape(-1, 1)

    x_train = scaler_x.fit_transform(x_train)
    y_train = scaler_y.fit_transform(y_train)
    x_train_timestamp = scaler_time.fit_transform(x_train_timestamp)
    x_train_range = scaler_range.fit_transform(x_train_range)


    # test
    x_test = []
    y_test = []
    test_range = []
    x_test_timestamp = []
    x_test_timestamp_true =[]
    for key, values in test.items():
        for app in range(len(appliances)):
            df = pd.read_csv(
                f"datasets/Building{key}_NILM_data_basic.csv", usecols=["Timestamp", "main", appliances[app]])
            df["date"] = pd.to_datetime(df["Timestamp"]).dt.date
            startDate = datetime.strptime(values["start_time"], "%Y-%m-%d").date()
            endDate = datetime.strptime(values["end_time"], "%Y-%m-%d").date()

            if startDate > endDate:
                raise "Start Date must be smaller than Enddate."

            df = df[(df["date"] >= startDate) & (df["date"] <= endDate)]
            df.dropna(inplace=True)
            if app == 0:
                    x = df[appliances[app]].values
            else:
                x += df[appliances[app]].values
            if appliances[app] == "Refrigerator":
                y = df[appliances[app]].values
        
        if (bias == True):
            x =  x + 100*np.ones(x.shape[0])
        timestamp_true = df["Timestamp"].values
        timestamp = (pd.to_datetime(df["Timestamp"]).astype(int)/ 10**18).values
        x = jnp.pad(x, (units_to_pad, units_to_pad),
                    'constant', constant_values=(0, 0))
        x = jnp.array([x[i: i + n] for i in range(len(x) - n + 1)])
        x_test.extend(x)
        y_test.extend(y)
        test_range.append(jnp.max(x, axis=1)-jnp.min(x, axis=1))
        x_test_timestamp_true.extend(timestamp_true)
        x_test_timestamp.extend(timestamp)

    x_test = jnp.array(x_test)
    y_test = jnp.array(y_test).reshape(-1, 1)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(-1,1)
    x_test_range = jnp.array(test_range).reshape(-1, 1)

    x_test = scaler_x.transform(x_test)
    x_test_timestamp = scaler_time.transform(x_test_timestamp)
    x_test_range = scaler_range.transform(x_test_range)

    x_train = jnp.array(x_train).reshape(x_train.shape[0], n)
    y_train = jnp.array(y_train)
    x_train_range = jnp.array(x_train_range)
    x_train_timestamp = torch.tensor(x_train_timestamp).reshape(x_train_timestamp.shape[0], 1)
    x_test = jnp.array(x_test).reshape(x_test.shape[0], n)
    y_test = jnp.array(y_test)
    x_test_timestamp = torch.tensor(x_test_timestamp).reshape(x_test_timestamp.shape[0], 1).to(torch.float64)
    x_test_range = jnp.array(x_test_range).reshape(-1,1)

    if (linear == True):
        n = 100
        x_train = jnp.concatenate((x_train, x_train_range), axis =1).reshape(x_train.shape[0],n)
        x_test = jnp.concatenate((x_test, x_test_range), axis =1).reshape(x_test.shape[0],n)

    return x_train, y_train, x_test, y_test, x_train_timestamp, x_test_timestamp, x_test_timestamp_true, scaler_x, scaler_y, scaler_time, scaler_range

# %%
train ={1:{
                    'start_time': "2011-04-28" ,
                    'end_time': "2011-05-15"
                }, 3: {
                'start_time': "2011-04-19" ,
                'end_time': "2011-05-22"
            },
                
      
                }
test = {  2: {
                    'start_time': "2011-04-21" ,
                    'end_time': "2011-05-21"
                },
                }
appliances = ["Microwave", "Refrigerator",  "Dish Washer"] #

# %%
x_train, y_train, x_test, y_test, x_train_timestamp, x_test_timestamp, x_test_time_true, scaler_x, scaler_y, scaler_time, scaler_range = dataset_load(appliances, train, test, linear=False, bias=True)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((24918, 99), (15656, 99), (24918, 1), (15656, 1))

# %%
x = torch.tensor(np.array(x_train)).to(torch.float32)
y = torch.tensor(np.array(y_train)).reshape(-1,).to(torch.float32)
xt = torch.tensor(np.array(x_test)).to(torch.float32)
yt = torch.tensor(np.array(y_test)).reshape(-1,).to(torch.float32)

# %%
kernel1 = ScaleKernel(MaternKernel(nu=2.5,ard_num_dims=100 )) #nu=2.5,
kernel2 = ScaleKernel(LinearKernel(active_dims = (99)))

kernel = kernel1 + kernel2
inducing_points =  x[np.arange(0,x.shape[0],20)] 

model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
# restart: 0, epoch: 966, iter: 1, loss: -0.1446
# restart: 0, epoch: 967, iter: 1, loss: -0.1453
# restart: 0, epoch: 968, iter: 1, loss: -0.1460
# restart: 0, epoch: 969, iter: 1, loss: -0.1466
# restart: 0, epoch: 970, iter: 1, loss: -0.1473
# restart: 0, epoch: 971, iter: 1, loss: -0.1479
# restart: 0, epoch: 972, iter: 1, loss: -0.1486
# restart: 0, epoch: 973, iter: 1, loss: -0.1492
# restart: 0, epoch: 974, iter: 1, loss: -0.1499
# restart: 0, epoch: 975, iter: 1, loss: -0.1505
# restart: 0, epoch: 976, iter: 1, loss: -0.1512
# restart: 0, epoch: 977, iter: 1, loss: -0.1518
# restart: 0, epoch: 978, iter: 1, loss: -0.1524
# restart: 0, epoch: 979, iter: 1, loss: -0.1531
# restart: 0, epoch: 980, iter: 1, loss: -0.1537
# restart: 0, epoch: 981, iter: 1, loss: -0.1544
# restart: 0, epoch: 982, iter: 1, loss: -0.1550
# restart: 0, epoch: 983, iter: 1, loss: -0.1557
# restart: 0, epoch: 984, iter: 1, loss: -0.1563
# restart: 0, epoch: 985, iter: 1, loss: -0.1569
# restart: 0, epoch: 986, iter: 1, loss: -0.1576
# restart: 0, epoch: 987, iter: 1, loss: -0.1582
# restart: 0, epoch: 988, iter: 1, loss: -0.1588
# restart: 0, epoch: 989, iter: 1, loss: -0.1594
# restart: 0, epoch: 990, iter: 1, loss: -0.1601
# restart: 0, epoch: 991, iter: 1, loss: -0.1607
# restart: 0, epoch: 992, iter: 1, loss: -0.1613
# restart: 0, epoch: 993, iter: 1, loss: -0.1619
# restart: 0, epoch: 994, iter: 1, loss: -0.1625
# restart: 0, epoch: 995, iter: 1, loss: -0.1631
# restart: 0, epoch: 996, iter: 1, loss: -0.1637
# restart: 0, epoch: 997, iter: 1, loss: -0.1644
# restart: 0, epoch: 998, iter: 1, loss: -0.1650
# restart: 0, epoch: 999, iter: 1, loss: -0.1656
# restart: 0, epoch: 1000, iter: 1, loss: -0.1662
# restart: 0, epoch: 1001, iter: 1, loss: -0.1668
# restart: 0, epoch: 1002, iter: 1, loss: -0.1674
# restart: 0, epoch: 1003, iter: 1, loss: -0.1680
# restart: 0, epoch: 1004, iter: 1, loss: -0.1686
# restart: 0, epoch: 1005, iter: 1, loss: -0.1692
# restart: 0, epoch: 1006, iter: 1, loss: -0.1698
# restart: 0, epoch: 1007, iter: 1, loss: -0.1705
# restart: 0, epoch: 1008, iter: 1, loss: -0.1711
# restart: 0, epoch: 1009, iter: 1, loss: -0.1717
# restart: 0, epoch: 1010, iter: 1, loss: -0.1723
# restart: 0, epoch: 1011, iter: 1, loss: -0.1730
# restart: 0, epoch: 1012, iter: 1, loss: -0.1736
# restart: 0, epoch: 1013, iter: 1, loss: -0.1742
# restart: 0, epoch: 1014, iter: 1, loss: -0.1749
# restart: 0, epoch: 1015, iter: 1, loss: -0.1755
# restart: 0, epoch: 1016, iter: 1, loss: -0.1762
# restart: 0, epoch: 1017, iter: 1, loss: -0.1768
# restart: 0, epoch: 1018, iter: 1, loss: -0.1774
# restart: 0, epoch: 1019, iter: 1, loss: -0.1781
# restart: 0, epoch: 1020, iter: 1, loss: -0.1787
# restart: 0, epoch: 1021, iter: 1, loss: -0.1794
# restart: 0, epoch: 1022, iter: 1, loss: -0.1800
# restart: 0, epoch: 1023, iter: 1, loss: -0.1807
# restart: 0, epoch: 1024, iter: 1, loss: -0.1813
# restart: 0, epoch: 1025, iter: 1, loss: -0.1819
# restart: 0, epoch: 1026, iter: 1, loss: -0.1826
# ...
# restart: 0, epoch: 1168, iter: 1, loss: -0.2630
# restart: 0, epoch: 1169, iter: 1, loss: -0.2635
# restart: 0, epoch: 1170, iter: 1, loss: -0.2639
# restart: 0, epoch: 1171, iter: 1, loss: -0.2644
# restart: 0, epoch: 1172, iter: 1, loss: -0.2649
# restart: 0, epoch: 1173, iter: 1, loss: -0.2654
# restart: 0, epoch: 1174, iter: 1, loss: -0.2658
# restart: 0, epoch: 1175, iter: 1, loss: -0.2663
# restart: 0, epoch: 1176, iter: 1, loss: -0.2667
# restart: 0, epoch: 1177, iter: 1, loss: -0.2672
# restart: 0, epoch: 1178, iter: 1, loss: -0.2677
# restart: 0, epoch: 1179, iter: 1, loss: -0.2682
# restart: 0, epoch: 1180, iter: 1, loss: -0.2686
# restart: 0, epoch: 1181, iter: 1, loss: -0.2691
# restart: 0, epoch: 1182, iter: 1, loss: -0.2696
# restart: 0, epoch: 1183, iter: 1, loss: -0.2700
# restart: 0, epoch: 1184, iter: 1, loss: -0.2705
# restart: 0, epoch: 1185, iter: 1, loss: -0.2709
# restart: 0, epoch: 1186, iter: 1, loss: -0.2714
# restart: 0, epoch: 1187, iter: 1, loss: -0.2718
# restart: 0, epoch: 1188, iter: 1, loss: -0.2723
# restart: 0, epoch: 1189, iter: 1, loss: -0.2727
# restart: 0, epoch: 1190, iter: 1, loss: -0.2732
# restart: 0, epoch: 1191, iter: 1, loss: -0.2736
# restart: 0, epoch: 1192, iter: 1, loss: -0.2740
# restart: 0, epoch: 1193, iter: 1, loss: -0.2745
# restart: 0, epoch: 1194, iter: 1, loss: -0.2749
# restart: 0, epoch: 1195, iter: 1, loss: -0.2753
# restart: 0, epoch: 1196, iter: 1, loss: -0.2757
# restart: 0, epoch: 1197, iter: 1, loss: -0.2762
# restart: 0, epoch: 1198, iter: 1, loss: -0.2766
# restart: 0, epoch: 1199, iter: 1, loss: -0.2770
# restart: 0, epoch: 1200, iter: 1, loss: -0.2774
# restart: 0, epoch: 1201, iter: 1, loss: -0.2778
# restart: 0, epoch: 1202, iter: 1, loss: -0.2782
# restart: 0, epoch: 1203, iter: 1, loss: -0.2787
# restart: 0, epoch: 1204, iter: 1, loss: -0.2791
# restart: 0, epoch: 1205, iter: 1, loss: -0.2795
# restart: 0, epoch: 1206, iter: 1, loss: -0.2799
# restart: 0, epoch: 1207, iter: 1, loss: -0.2803
# restart: 0, epoch: 1208, iter: 1, loss: -0.2807
# restart: 0, epoch: 1209, iter: 1, loss: -0.2811
# restart: 0, epoch: 1210, iter: 1, loss: -0.2815
# restart: 0, epoch: 1211, iter: 1, loss: -0.2819
# restart: 0, epoch: 1212, iter: 1, loss: -0.2823
# restart: 0, epoch: 1213, iter: 1, loss: -0.2827
# restart: 0, epoch: 1214, iter: 1, loss: -0.2831
# restart: 0, epoch: 1215, iter: 1, loss: -0.2835
# restart: 0, epoch: 1216, iter: 1, loss: -0.2838
# restart: 0, epoch: 1217, iter: 1, loss: -0.2842
# restart: 0, epoch: 1218, iter: 1, loss: -0.2846
# restart: 0, epoch: 1219, iter: 1, loss: -0.2850
# restart: 0, epoch: 1220, iter: 1, loss: -0.2854
# restart: 0, epoch: 1221, iter: 1, loss: -0.2858
# restart: 0, epoch: 1222, iter: 1, loss: -0.2862
# restart: 0, epoch: 1223, iter: 1, loss: -0.2866
# restart: 0, epoch: 1224, iter: 1, loss: -0.2870
# restart: 0, epoch: 1225, iter: 1, loss: -0.2874
# restart: 0, epoch: 1226, iter: 1, loss: -0.2877
# restart: 0, epoch: 1227, iter: 1, loss: -0.2881
# restart: 0, epoch: 1228, iter: 1, loss: -0.2885
# restart: 0, epoch: 1229, iter: 1, loss: -0.2889
# restart: 0, epoch: 1230, iter: 1, loss: -0.2893
# restart: 0, epoch: 1231, iter: 1, loss: -0.2897
# restart: 0, epoch: 1232, iter: 1, loss: -0.2900
# restart: 0, epoch: 1233, iter: 1, loss: -0.2904
# restart: 0, epoch: 1234, iter: 1, loss: -0.2908
# restart: 0, epoch: 1235, iter: 1, loss: -0.2912
# restart: 0, epoch: 1236, iter: 1, loss: -0.2916
# restart: 0, epoch: 1237, iter: 1, loss: -0.2920
# restart: 0, epoch: 1238, iter: 1, loss: -0.2923
# restart: 0, epoch: 1239, iter: 1, loss: -0.2927
# restart: 0, epoch: 1240, iter: 1, loss: -0.2931
# restart: 0, epoch: 1241, iter: 1, loss: -0.2935
# restart: 0, epoch: 1242, iter: 1, loss: -0.2938
# restart: 0, epoch: 1243, iter: 1, loss: -0.2942
# restart: 0, epoch: 1244, iter: 1, loss: -0.2946
# restart: 0, epoch: 1245, iter: 1, loss: -0.2950
# restart: 0, epoch: 1246, iter: 1, loss: -0.2954
# restart: 0, epoch: 1247, iter: 1, loss: -0.2958
# restart: 0, epoch: 1248, iter: 1, loss: -0.2961
# restart: 0, epoch: 1249, iter: 1, loss: -0.2965
# restart: 0, epoch: 1250, iter: 1, loss: -0.2969
# restart: 0, epoch: 1251, iter: 1, loss: -0.2973
# restart: 0, epoch: 1252, iter: 1, loss: -0.2977
# restart: 0, epoch: 1253, iter: 1, loss: -0.2981
# restart: 0, epoch: 1254, iter: 1, loss: -0.2985
# restart: 0, epoch: 1255, iter: 1, loss: -0.2989
# restart: 0, epoch: 1256, iter: 1, loss: -0.2992
# restart: 0, epoch: 1257, iter: 1, loss: -0.2997
# restart: 0, epoch: 1258, iter: 1, loss: -0.3001
# restart: 0, epoch: 1259, iter: 1, loss: -0.3004
# restart: 0, epoch: 1260, iter: 1, loss: -0.3008
# restart: 0, epoch: 1261, iter: 1, loss: -0.3012
# restart: 0, epoch: 1262, iter: 1, loss: -0.3016
# restart: 0, epoch: 1263, iter: 1, loss: -0.3020
# restart: 0, epoch: 1264, iter: 1, loss: -0.3024
# restart: 0, epoch: 1265, iter: 1, loss: -0.3028
# restart: 0, epoch: 1266, iter: 1, loss: -0.3032
# restart: 0, epoch: 1267, iter: 1, loss: -0.3036
# restart: 0, epoch: 1268, iter: 1, loss: -0.3040
# restart: 0, epoch: 1269, iter: 1, loss: -0.3044
# restart: 0, epoch: 1270, iter: 1, loss: -0.3048
# restart: 0, epoch: 1271, iter: 1, loss: -0.3052
# restart: 0, epoch: 1272, iter: 1, loss: -0.3056
# restart: 0, epoch: 1273, iter: 1, loss: -0.3060
# restart: 0, epoch: 1274, iter: 1, loss: -0.3063
# restart: 0, epoch: 1275, iter: 1, loss: -0.3067
# restart: 0, epoch: 1276, iter: 1, loss: -0.3071
# restart: 0, epoch: 1277, iter: 1, loss: -0.3075
# restart: 0, epoch: 1278, iter: 1, loss: -0.3079
# restart: 0, epoch: 1279, iter: 1, loss: -0.3083
# restart: 0, epoch: 1280, iter: 1, loss: -0.3087
# restart: 0, epoch: 1281, iter: 1, loss: -0.3090
# restart: 0, epoch: 1282, iter: 1, loss: -0.3094
# restart: 0, epoch: 1283, iter: 1, loss: -0.3098
# restart: 0, epoch: 1284, iter: 1, loss: -0.3102
# restart: 0, epoch: 1285, iter: 1, loss: -0.3105
# restart: 0, epoch: 1286, iter: 1, loss: -0.3109
# restart: 0, epoch: 1287, iter: 1, loss: -0.3113
# restart: 0, epoch: 1288, iter: 1, loss: -0.3117
# restart: 0, epoch: 1289, iter: 1, loss: -0.3120
# restart: 0, epoch: 1290, iter: 1, loss: -0.3124
# restart: 0, epoch: 1291, iter: 1, loss: -0.3128
# restart: 0, epoch: 1292, iter: 1, loss: -0.3132
# restart: 0, epoch: 1293, iter: 1, loss: -0.3136
# restart: 0, epoch: 1294, iter: 1, loss: -0.3140
# restart: 0, epoch: 1295, iter: 1, loss: -0.3144
# restart: 0, epoch: 1296, iter: 1, loss: -0.3148
# restart: 0, epoch: 1297, iter: 1, loss: -0.3151
# restart: 0, epoch: 1298, iter: 1, loss: -0.3155
# restart: 0, epoch: 1299, iter: 1, loss: -0.3159
# restart: 0, epoch: 1300, iter: 1, loss: -0.3163
# restart: 0, epoch: 1301, iter: 1, loss: -0.3167
# restart: 0, epoch: 1302, iter: 1, loss: -0.3171
# restart: 0, epoch: 1303, iter: 1, loss: -0.3175
# restart: 0, epoch: 1304, iter: 1, loss: -0.3180
# restart: 0, epoch: 1305, iter: 1, loss: -0.3183
# restart: 0, epoch: 1306, iter: 1, loss: -0.3188
# restart: 0, epoch: 1307, iter: 1, loss: -0.3192
# restart: 0, epoch: 1308, iter: 1, loss: -0.3196
# restart: 0, epoch: 1309, iter: 1, loss: -0.3200
# restart: 0, epoch: 1310, iter: 1, loss: -0.3205
# restart: 0, epoch: 1311, iter: 1, loss: -0.3209
# restart: 0, epoch: 1312, iter: 1, loss: -0.3214
# restart: 0, epoch: 1313, iter: 1, loss: -0.3218
# restart: 0, epoch: 1314, iter: 1, loss: -0.3222
# restart: 0, epoch: 1315, iter: 1, loss: -0.3227
# restart: 0, epoch: 1316, iter: 1, loss: -0.3231
# restart: 0, epoch: 1317, iter: 1, loss: -0.3236
# restart: 0, epoch: 1318, iter: 1, loss: -0.3241
# restart: 0, epoch: 1319, iter: 1, loss: -0.3245
# restart: 0, epoch: 1320, iter: 1, loss: -0.3250
# restart: 0, epoch: 1321, iter: 1, loss: -0.3255
# restart: 0, epoch: 1322, iter: 1, loss: -0.3259
# restart: 0, epoch: 1323, iter: 1, loss: -0.3264
# restart: 0, epoch: 1324, iter: 1, loss: -0.3268
# restart: 0, epoch: 1325, iter: 1, loss: -0.3273
# restart: 0, epoch: 1326, iter: 1, loss: -0.3278
# restart: 0, epoch: 1327, iter: 1, loss: -0.3282
# restart: 0, epoch: 1328, iter: 1, loss: -0.3287
# restart: 0, epoch: 1329, iter: 1, loss: -0.3291
# restart: 0, epoch: 1330, iter: 1, loss: -0.3296
# restart: 0, epoch: 1331, iter: 1, loss: -0.3300
# restart: 0, epoch: 1332, iter: 1, loss: -0.3305
# restart: 0, epoch: 1333, iter: 1, loss: -0.3309
# restart: 0, epoch: 1334, iter: 1, loss: -0.3313
# restart: 0, epoch: 1335, iter: 1, loss: -0.3318
# restart: 0, epoch: 1336, iter: 1, loss: -0.3322
# restart: 0, epoch: 1337, iter: 1, loss: -0.3326
# restart: 0, epoch: 1338, iter: 1, loss: -0.3330
# restart: 0, epoch: 1339, iter: 1, loss: -0.3335
# restart: 0, epoch: 1340, iter: 1, loss: -0.3339
# restart: 0, epoch: 1341, iter: 1, loss: -0.3343
# restart: 0, epoch: 1342, iter: 1, loss: -0.3347
# restart: 0, epoch: 1343, iter: 1, loss: -0.3351
# restart: 0, epoch: 1344, iter: 1, loss: -0.3355
# restart: 0, epoch: 1345, iter: 1, loss: -0.3359
# restart: 0, epoch: 1346, iter: 1, loss: -0.3363
# restart: 0, epoch: 1347, iter: 1, loss: -0.3367
# restart: 0, epoch: 1348, iter: 1, loss: -0.3371
# restart: 0, epoch: 1349, iter: 1, loss: -0.3375
# restart: 0, epoch: 1350, iter: 1, loss: -0.3379
# restart: 0, epoch: 1351, iter: 1, loss: -0.3383
# restart: 0, epoch: 1352, iter: 1, loss: -0.3386
# restart: 0, epoch: 1353, iter: 1, loss: -0.3390
# restart: 0, epoch: 1354, iter: 1, loss: -0.3394
# restart: 0, epoch: 1355, iter: 1, loss: -0.3398
# restart: 0, epoch: 1356, iter: 1, loss: -0.3402
# restart: 0, epoch: 1357, iter: 1, loss: -0.3406
# restart: 0, epoch: 1358, iter: 1, loss: -0.3409
# restart: 0, epoch: 1359, iter: 1, loss: -0.3413
# restart: 0, epoch: 1360, iter: 1, loss: -0.3417
# restart: 0, epoch: 1361, iter: 1, loss: -0.3421
# restart: 0, epoch: 1362, iter: 1, loss: -0.3425
# restart: 0, epoch: 1363, iter: 1, loss: -0.3429
# restart: 0, epoch: 1364, iter: 1, loss: -0.3433
# restart: 0, epoch: 1365, iter: 1, loss: -0.3437
# restart: 0, epoch: 1366, iter: 1, loss: -0.3441
# restart: 0, epoch: 1367, iter: 1, loss: -0.3445
# restart: 0, epoch: 1368, iter: 1, loss: -0.3449
# restart: 0, epoch: 1369, iter: 1, loss: -0.3453
# restart: 0, epoch: 1370, iter: 1, loss: -0.3457
# restart: 0, epoch: 1371, iter: 1, loss: -0.3461
# restart: 0, epoch: 1372, iter: 1, loss: -0.3465
# restart: 0, epoch: 1373, iter: 1, loss: -0.3468
# restart: 0, epoch: 1374, iter: 1, loss: -0.3472
# restart: 0, epoch: 1375, iter: 1, loss: -0.3477
# restart: 0, epoch: 1376, iter: 1, loss: -0.3480
# restart: 0, epoch: 1377, iter: 1, loss: -0.3485
# restart: 0, epoch: 1378, iter: 1, loss: -0.3489
# restart: 0, epoch: 1379, iter: 1, loss: -0.3493
# restart: 0, epoch: 1380, iter: 1, loss: -0.3497
# restart: 0, epoch: 1381, iter: 1, loss: -0.3500
# restart: 0, epoch: 1382, iter: 1, loss: -0.3504
# restart: 0, epoch: 1383, iter: 1, loss: -0.3508
# restart: 0, epoch: 1384, iter: 1, loss: -0.3512
# restart: 0, epoch: 1385, iter: 1, loss: -0.3516
# restart: 0, epoch: 1386, iter: 1, loss: -0.3520
# restart: 0, epoch: 1387, iter: 1, loss: -0.3524
# restart: 0, epoch: 1388, iter: 1, loss: -0.3528
# restart: 0, epoch: 1389, iter: 1, loss: -0.3532
# restart: 0, epoch: 1390, iter: 1, loss: -0.3535
# restart: 0, epoch: 1391, iter: 1, loss: -0.3539
# restart: 0, epoch: 1392, iter: 1, loss: -0.3543
# restart: 0, epoch: 1393, iter: 1, loss: -0.3546
# restart: 0, epoch: 1394, iter: 1, loss: -0.3550
# restart: 0, epoch: 1395, iter: 1, loss: -0.3554
# restart: 0, epoch: 1396, iter: 1, loss: -0.3558
# restart: 0, epoch: 1397, iter: 1, loss: -0.3561
# restart: 0, epoch: 1398, iter: 1, loss: -0.3565
# restart: 0, epoch: 1399, iter: 1, loss: -0.3569
# restart: 0, epoch: 1400, iter: 1, loss: -0.3572
# restart: 0, epoch: 1401, iter: 1, loss: -0.3576
# restart: 0, epoch: 1402, iter: 1, loss: -0.3579
# restart: 0, epoch: 1403, iter: 1, loss: -0.3583
# restart: 0, epoch: 1404, iter: 1, loss: -0.3587
# restart: 0, epoch: 1405, iter: 1, loss: -0.3590
# restart: 0, epoch: 1406, iter: 1, loss: -0.3594
# restart: 0, epoch: 1407, iter: 1, loss: -0.3597
# restart: 0, epoch: 1408, iter: 1, loss: -0.3601
# restart: 0, epoch: 1409, iter: 1, loss: -0.3604
# restart: 0, epoch: 1410, iter: 1, loss: -0.3608
# restart: 0, epoch: 1411, iter: 1, loss: -0.3611
# restart: 0, epoch: 1412, iter: 1, loss: -0.3615
# restart: 0, epoch: 1413, iter: 1, loss: -0.3618
# restart: 0, epoch: 1414, iter: 1, loss: -0.3622
# restart: 0, epoch: 1415, iter: 1, loss: -0.3625
# restart: 0, epoch: 1416, iter: 1, loss: -0.3629
# restart: 0, epoch: 1417, iter: 1, loss: -0.3632
# restart: 0, epoch: 1418, iter: 1, loss: -0.3636
# restart: 0, epoch: 1419, iter: 1, loss: -0.3639
# restart: 0, epoch: 1420, iter: 1, loss: -0.3642
# restart: 0, epoch: 1421, iter: 1, loss: -0.3646
# restart: 0, epoch: 1422, iter: 1, loss: -0.3649
# restart: 0, epoch: 1423, iter: 1, loss: -0.3652
# restart: 0, epoch: 1424, iter: 1, loss: -0.3656
# restart: 0, epoch: 1425, iter: 1, loss: -0.3659
# restart: 0, epoch: 1426, iter: 1, loss: -0.3663
# restart: 0, epoch: 1427, iter: 1, loss: -0.3666
# restart: 0, epoch: 1428, iter: 1, loss: -0.3670
# restart: 0, epoch: 1429, iter: 1, loss: -0.3673
# restart: 0, epoch: 1430, iter: 1, loss: -0.3677
# restart: 0, epoch: 1431, iter: 1, loss: -0.3680
# restart: 0, epoch: 1432, iter: 1, loss: -0.3683
# restart: 0, epoch: 1433, iter: 1, loss: -0.3687
# restart: 0, epoch: 1434, iter: 1, loss: -0.3691
# restart: 0, epoch: 1435, iter: 1, loss: -0.3694
# restart: 0, epoch: 1436, iter: 1, loss: -0.3698
# restart: 0, epoch: 1437, iter: 1, loss: -0.3702
# restart: 0, epoch: 1438, iter: 1, loss: -0.3705
# restart: 0, epoch: 1439, iter: 1, loss: -0.3709
# restart: 0, epoch: 1440, iter: 1, loss: -0.3713
# restart: 0, epoch: 1441, iter: 1, loss: -0.3716
# restart: 0, epoch: 1442, iter: 1, loss: -0.3720
# restart: 0, epoch: 1443, iter: 1, loss: -0.3724
# restart: 0, epoch: 1444, iter: 1, loss: -0.3728
# restart: 0, epoch: 1445, iter: 1, loss: -0.3733
# restart: 0, epoch: 1446, iter: 1, loss: -0.3737
# restart: 0, epoch: 1447, iter: 1, loss: -0.3741
# restart: 0, epoch: 1448, iter: 1, loss: -0.3745
# restart: 0, epoch: 1449, iter: 1, loss: -0.3749
# restart: 0, epoch: 1450, iter: 1, loss: -0.3754
# restart: 0, epoch: 1451, iter: 1, loss: -0.3758
# restart: 0, epoch: 1452, iter: 1, loss: -0.3763
# restart: 0, epoch: 1453, iter: 1, loss: -0.3767
# restart: 0, epoch: 1454, iter: 1, loss: -0.3771
# restart: 0, epoch: 1455, iter: 1, loss: -0.3776
# restart: 0, epoch: 1456, iter: 1, loss: -0.3781
# restart: 0, epoch: 1457, iter: 1, loss: -0.3785
# restart: 0, epoch: 1458, iter: 1, loss: -0.3790
# restart: 0, epoch: 1459, iter: 1, loss: -0.3794
# restart: 0, epoch: 1460, iter: 1, loss: -0.3799
# restart: 0, epoch: 1461, iter: 1, loss: -0.3803
# restart: 0, epoch: 1462, iter: 1, loss: -0.3807
# restart: 0, epoch: 1463, iter: 1, loss: -0.3812
# restart: 0, epoch: 1464, iter: 1, loss: -0.3816
# restart: 0, epoch: 1465, iter: 1, loss: -0.3821
# restart: 0, epoch: 1466, iter: 1, loss: -0.3825
# restart: 0, epoch: 1467, iter: 1, loss: -0.3829
# restart: 0, epoch: 1468, iter: 1, loss: -0.3834
# restart: 0, epoch: 1469, iter: 1, loss: -0.3838
# restart: 0, epoch: 1470, iter: 1, loss: -0.3843
# restart: 0, epoch: 1471, iter: 1, loss: -0.3847
# restart: 0, epoch: 1472, iter: 1, loss: -0.3851
# restart: 0, epoch: 1473, iter: 1, loss: -0.3856
# restart: 0, epoch: 1474, iter: 1, loss: -0.3861
# restart: 0, epoch: 1475, iter: 1, loss: -0.3865
# restart: 0, epoch: 1476, iter: 1, loss: -0.3870
# restart: 0, epoch: 1477, iter: 1, loss: -0.3874
# restart: 0, epoch: 1478, iter: 1, loss: -0.3879
# restart: 0, epoch: 1479, iter: 1, loss: -0.3883
# restart: 0, epoch: 1480, iter: 1, loss: -0.3887
# restart: 0, epoch: 1481, iter: 1, loss: -0.3892
# restart: 0, epoch: 1482, iter: 1, loss: -0.3896
# restart: 0, epoch: 1483, iter: 1, loss: -0.3901
# restart: 0, epoch: 1484, iter: 1, loss: -0.3905
# restart: 0, epoch: 1485, iter: 1, loss: -0.3909
# restart: 0, epoch: 1486, iter: 1, loss: -0.3913
# restart: 0, epoch: 1487, iter: 1, loss: -0.3918
# restart: 0, epoch: 1488, iter: 1, loss: -0.3922
# restart: 0, epoch: 1489, iter: 1, loss: -0.3926
# restart: 0, epoch: 1490, iter: 1, loss: -0.3930
# restart: 0, epoch: 1491, iter: 1, loss: -0.3934
# restart: 0, epoch: 1492, iter: 1, loss: -0.3938
# restart: 0, epoch: 1493, iter: 1, loss: -0.3943
# restart: 0, epoch: 1494, iter: 1, loss: -0.3946
# restart: 0, epoch: 1495, iter: 1, loss: -0.3951
# restart: 0, epoch: 1496, iter: 1, loss: -0.3954
# restart: 0, epoch: 1497, iter: 1, loss: -0.3958
# restart: 0, epoch: 1498, iter: 1, loss: -0.3962
# restart: 0, epoch: 1499, iter: 1, loss: -0.3966
# restart: 0, epoch: 1500, iter: 1, loss: -0.3970

# %%
model_name = "Seq_to_pt_linear_final.pt"
torch.save(model.state_dict(), os.path.join(
  "Neurips/models", model_name))

# %%
kernel1 = ScaleKernel(MaternKernel(nu=2.5,ard_num_dims=99 )) #nu=2.5,
kernel2 = ScaleKernel(LinearKernel(active_dims = (99)))


kernel = kernel1 #+ kernel2# + kernel2*kernel3
inducing_points =  x[np.arange(0,x.shape[0],20)] 
#x[torch.randperm(x.shape[0])[: batch]].to("cuda")

model = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel,
                       inducing_points).to("cuda")

model_name = "Seq_to_pt_final.pt"
model.load_state_dict(torch.load(
    os.path.join("Neurips/models", model_name)))
# Out:
# <All keys matched successfully>

# %%
y_pred_arr =[]
pred_dist = model.predict(xt.to("cuda"))

y_pred_arr.append(pred_dist.loc)
# Out:
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/kernels/inducing_point_kernel.py:61: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  /opt/conda/conda-bld/pytorch_1656352645774/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:2183.)
#   inv_root = torch.triangular_solve(eye, chol)[0]

# %%
y_pred_arr1 = []
for i in range(len(y_pred_arr)):
  y_pred_arr1.append(np.array(y_pred_arr[i].cpu()))

# %%
y_mean = np.mean(y_pred_arr1, axis =0)
# y_sigma = np.std(y_pred_arr1, axis=0)

y_mean.shape#, y_sigma.shape

y_mean = scaler_y.inverse_transform(y_mean.reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(y_test.shape, y_mean.shape)

y_mean = np.clip(y_mean,0,y_mean.max(),out=y_mean)
# Out:
# (15656, 1) (15656,)

# %%
mae = torch.abs(torch.tensor(y_mean) - yt).mean(dim=-1)
mae
# Out:
# tensor(92.8542)

# %%
from math import pi
var_pred = pred_dist.variance
var_pred = scaler_y.inverse_transform(var_pred.reshape(-1,1).detach().cpu()).squeeze()
# msll = mean_standardized_log_loss(torch.ensor(y_mean), yt)
f_var= torch.tensor(var_pred)
f_mean = torch.tensor(y_mean)
msll = 0.5 * (torch.log(2 * pi * f_var) + torch.square(yt - f_mean) / (2 * f_var)).mean(dim=-1)
msll
# Out:
# tensor(47.9159, dtype=torch.float64)

# %%
quantile = 95.0
standard_normal = torch.distributions.Normal(loc=0.0, scale=1.0)
deviation = standard_normal.icdf(torch.as_tensor(0.5 + 0.5 * (quantile / 100)))
std_pred = pred_dist.stddev
std_pred = torch.tensor(scaler_y.inverse_transform(std_pred.reshape(-1,1).detach().cpu()).squeeze())
lower = torch.tensor(y_mean) - deviation * std_pred 
upper = torch.tensor(y_mean) + deviation * std_pred 
n_samples_within_bounds = ((yt > lower) * (yt < upper)).sum(-1)
fraction = n_samples_within_bounds / yt.shape[-1]
qce = torch.abs(fraction - quantile / 100)
qce
# Out:
# tensor(0.0074)

# %%
idx = 500
fig, ax = plt.subplots(1,1, figsize=(10,5)) 
start = 4000
var_pred = pred_dist.variance
var_pred = scaler_y.inverse_transform(var_pred.reshape(-1,1).detach().cpu()).squeeze()
time_plot = scaler_time.inverse_transform(x_test_timestamp.cpu().reshape(-1,1))
# latexify(width_scale_factor=2, fig_height=1.75)
ax.plot(time_plot[start : start + idx], scaler_x.inverse_transform(xt[:,:99].cpu())[:,49][start : start + idx], label = "Main Power")
ax.plot(time_plot[start : start + idx], yt.cpu()[start : start + idx], label = "Ground Truth")
ax.plot(time_plot[start : start + idx], y_mean[start : start + idx], label = "Prediction")
ax.fill_between(time_plot[start : start + idx].flatten(), y_mean[start : start + idx].flatten() - 1.96*np.sqrt(var_pred[start : start + idx]).flatten(),  y_mean[start : start + idx].flatten() + 1.96*np.sqrt(var_pred[start : start + idx]).flatten(),  color='lightblue', alpha=1.0, label = "Confidence Interval 95%)")
ax.errorbar(time_plot[start : start + idx].flatten(), y_mean[start : start + idx].flatten(), yerr=np.sqrt(var_pred[start : start + idx]).flatten(), fmt='k*', label = "error_bar")
plt.legend(frameon=False)
ax.set_ylabel("Power" )
sns.despine()
# plt.show()

# %%
try:
    from probml_utils import latexify, savefig, is_latexify_enabled
except ModuleNotFoundError:
    # %pip install git+https://github.com/probml/probml-utils.git
    from probml_utils import latexify, savefig, is_latexify_enabled

os.environ["LATEXIFY"] = "1"
os.environ["FIG_DIR"] = "Neurips/FinalPlots/"

# %% [markdown]
# ## Scatter

# %%
# x_lin1 = jnp.sort(x_train_full, axis=1)
# x_lin1.shape
x_lin_max = 3000
x_lin = np.linspace(0,x_lin_max,15656).reshape(-1,1) # + 100*np.ones(15656).reshape(-1,1)

x_lin1 = np.array(x_lin).reshape(-1,1)
for i in range(98):
  x_lin1 = np.concatenate((x_lin1, x_lin), axis=1)

# test_range = []
# for i in range(15656):
#   test_range.append(jnp.max(x_lin1[i], axis=0)-jnp.min(x_lin1[i], axis=0))
# test_range = np.array(test_range)
x_lin1.shape
x_lin_scale = scaler_x.transform(x_lin1)
x_new = torch.tensor(np.array(x_lin_scale)).to(torch.float32)
# x_new = torch.cat((torch.tensor(x_lin_scale).reshape(-1,1).to(torch.float32), torch.tensor(x_test_timestamp).reshape(-1,1)),dim=1 ).to(torch.float32)
x_new.shape, x_new.dtype
# Out:
# (torch.Size([15656, 99]), torch.float32)

# %%
# x_new = torch.cat((torch.tensor(np.array(x_lin_scale)),torch.tensor(scaler_range.transform(test_range)) )).to(torch.float32)
# # x_new = torch.cat((torch.tensor(x_lin_scale).reshape(-1,1).to(torch.float32), torch.tensor(x_test_timestamp).reshape(-1,1)),dim=1 ).to(torch.float32)
# x_new.shape, x_new.dtype

# %%
pred_dist = model.predict(x_new.to("cuda"))
y_mean = pred_dist.loc 
y_mean = scaler_y.inverse_transform(y_mean.cpu().reshape(-1,1))

# %%
plt.figure()
latexify(width_scale_factor=2, fig_height=1.5)

start = 0
idx = 5000
plt.plot(x_lin1[:,49], y_mean, 'k', label=" Predicted Mean", alpha=0.7)
plt.scatter( scaler_x.inverse_transform(x_train_full)[:,49], scaler_y.inverse_transform(y_train.reshape(-1,1)), s = 6, label="Appliance Power")
plt.xlim(0,1500)
sns.despine()
plt.legend(bbox_to_anchor=(0.6, 0.6))
plt.xlabel("Train Mains")
plt.ylabel("Train Appliance Power")
# plt.show()
# savefig("Main_seq_vs_app_mean")
# Out:
# Text(0, 0.5, 'Train Appliance Power')

# %%
x_lin_max = 3000
x_lin = np.linspace(0,x_lin_max,15656) # + 100*np.ones(np.array(x_test).shape[0])
x_lin_scale = scaler_x.transform(x_lin.reshape(-1,1)).flatten() 

x_new = torch.cat((torch.tensor(x_lin_scale).reshape(-1,1).to(torch.float32), torch.tensor(x_test_timestamp).reshape(-1,1)),dim=1 ).to(torch.float32)
x_new.shape, x_new.dtype

# %%
idx = 300 #x2.shape[0]
start = 13000

plt.figure()
latexify(width_scale_factor=2, fig_height=1.5)
df = pd.read_csv("time_stamp.csv", index_col=0)
df.index = df["0"]
df.index = pd.to_datetime(df.index)
df.index.name = "Time"
df = df.drop(columns=["0"])
df["Main Power"] =  scaler_x.inverse_transform(xt[:,0:99])[:,49]
df["Ground Truth"] = y_test
df["Prediction"] = y_mean
df[start:start+idx].plot(rot=90, legend=False)
sns.despine()
# df.plot.( rotation=90)
# plt.legend(frameon=False, bbox_to_anchor=(0.5, 1.0))
# df.head()
plt.ylabel("Power")
# savefig("Seq_to_point_plt3")
# Out:
# Text(0, 0.5, 'Power')

# %%
idx = 500
start = 4000
plt.figure()
time_plot = scaler_time.inverse_transform(x_test_timestamp.reshape(-1,1))
latexify(width_scale_factor=2, fig_height=1.75)
plt.plot(time_plot[start : start + idx], scaler_x.inverse_transform(xt[:,0:99])[:,49][start : start + idx], label = "Main Power")
plt.plot(time_plot[start : start + idx], y_test[start : start + idx], label = "Ground Truth")
plt.plot(time_plot[start : start + idx], y_mean[start : start + idx], label = "Prediction")
# plt.legend(frameon=False, bbox_to_anchor=(0.6, 0.9))
plt.xlabel("Time")
plt.ylabel("Power")
sns.despine()
# plt.show()
savefig("Seq_to_point_main_power_seq__a_linear_plt")
# Out:
# saving image to Neurips/Plots/Seq_to_point_main_power_seq__added100_linear_plt_latexified.pdf
# Figure size: [3.   1.75]

# %%
for name, params in model.named_parameters():
  print(name, params)
# Out:
# mll.likelihood.noise_covar.raw_noise Parameter containing:
# tensor([-4.0766], device='cuda:0', requires_grad=True)
# mll.model.mean_module.constant Parameter containing:
# tensor([0.8700], device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.raw_outputscale Parameter containing:
# tensor(-2.5899, device='cuda:0', requires_grad=True)
# mll.model.base_covar_module.base_kernel.raw_lengthscale Parameter containing:
# tensor([[10.4251, 10.8671, 11.2113, 11.2482, 11.2213, 11.3358, 11.2443, 11.4213,
#          11.6552, 11.6334, 11.7098, 11.4688, 11.5728, 11.4793, 11.4923, 11.6508,
#          11.8268, 11.9869, 11.7231, 11.9634, 11.8792, 11.9776, 12.0374, 12.1292,
#          12.1015, 12.1548, 12.1259, 12.0086, 12.0525, 12.0732, 12.0210, 11.6221,
#          11.8350, 11.9144, 11.9817, 11.5319, 11.4422, 11.4816, 11.4924, 11.5062,
#          11.4141, 11.4433, 11.4957, 11.4067, 11.4078, 11.1971, 11.1387,  9.9038,
#           8.8081, -0.1963,  6.7484, 11.8245, 12.2235, 12.3450, 12.8252, 12.1872,
#          12.1993, 12.0396, 12.1630, 11.7547, 11.5037, 11.1481, 11.4272, 11.5192,
#          11.4625, 11.7511, 11.4192, 11.2371, 11.6814, 11.8072, 11.7867, 11.9044,
#          12.2247, 12.2645, 12.2657, 11.9786, 11.9037, 11.9792, 11.9128, 11.7109,
#          12.0113, 12.0382, 11.9002, 11.5900, 10.9798, 11.7662, 11.2211, 11.6867,
#          11.5052, 11.4465, 11.4364, 11.4566, 11.3606, 11.3861, 11.5726, 11.5023,
#          11.0483, 10.5532,  9.8005]], device='cuda:0', requires_grad=True)
# mll.model.covar_module.inducing_points Parameter containing:
# tensor([[-0.2210, -0.2606, -0.2952,  ..., -0.1671, -0.1171, -0.0589],
#         [-0.2255, -0.1171, -0.1774,  ...,  9.6184, 11.4964, 11.0390],
#         [-0.3582, -0.3827, -0.3867,  ...,  2.4514,  2.2701,  2.0963],
#         ...,
#         [-0.3314, -0.3764, -0.4131,  ..., -0.4002, -0.3857, -0.3721],
#         [ 0.1381,  0.1713,  0.2650,  ...,  0.2451,  0.2893,  0.3004],
#         [-0.4053, -0.4652, -0.4698,  ..., -0.0496,  0.0306,  0.1052]],
#        device='cuda:0', requires_grad=True)

# %%
ar = np.arange(0,99,1)
print(ar.shape)
plt.plot(ar,model.mll.model.base_covar_module.base_kernel.lengthscale.cpu().detach().numpy().reshape(-1,))
plt.xlabel("# ARD")
plt.ylabel("Learned Lengthscale Values")
# Out:
# (99,)
# Text(0, 0.5, 'Learned Lengthscale Values')

# %% [markdown]
# ## Decomposition

# %%
model1 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel1,
                      inducing_points).to("cuda")

# %%
pred_dist1 = model1.predict(xt[:4000].to("cuda"))
# print("Done ", i)

y_mean1 = pred_dist1.loc

# %%
y_pred_arr =[]

y_pred_arr.append(pred_dist1.loc)

# %%
y_mean1.shape
# Out:
# torch.Size([4000])

# %%
y_pred_arr1 = []
for i in range(len(y_pred_arr)):
  y_pred_arr1.append(np.array(y_pred_arr[i].cpu()))

# %%
y_mean1 = np.mean(y_pred_arr1, axis =0)
# y_sigma = np.std(y_pred_arr1, axis=0)

y_mean1.shape#, y_sigma.shape

y_mean1 = scaler_y.inverse_transform(y_mean1.reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(y_test.shape, y_mean1.shape)

y_mean1 = np.clip(y_mean1,0,y_mean1.max(),out=y_mean1)
# Out:
# (15656, 1) (4000,)

# %%
mae = np.mean(np.abs(np.array(y_test[:4000]) - y_mean1))
rms = errors.rmse(jnp.array(y_test[:4000]), y_mean1)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  112.463875
# RMSE:  130.25223

# %%
idx = 3000
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean1[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()

# %%
model2 = SGPRegressor(x.to("cuda"), y.to("cuda"), kernel2,
                      inducing_points).to("cuda")

# %%
pred_dist2 = model2.predict(xt[:4000].to("cuda"))
# print("Done ", i)

y_mean2 = pred_dist2.loc
# Out:
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-06 to the diagonal
#   warnings.warn(
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-05 to the diagonal
#   warnings.warn(
# /home/desai.aadesh/miniconda3/envs/nlim/lib/python3.10/site-packages/gpytorch/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-04 to the diagonal
#   warnings.warn(

# %%
y_pred_arr =[]

y_pred_arr.append(pred_dist2.loc)

# %%
y_pred_arr1 = []
for i in range(len(y_pred_arr)):
  y_pred_arr1.append(np.array(y_pred_arr[i].cpu()))

# %%
y_mean2 = np.mean(y_pred_arr1, axis =0)
# y_sigma = np.std(y_pred_arr2, axis=0)

y_mean2.shape#, y_sigma.shape

y_mean2 = scaler_y.inverse_transform(y_mean2.reshape(-1,1)).squeeze()
# y_sigma = scaler_y.inverse_transform(y_sigma.reshape(-1,1)).squeeze()
print(y_test.shape, y_mean2.shape)

y_mean2 = np.clip(y_mean2,0,y_mean2.max(),out=y_mean2)
# Out:
# (15656, 1) (4000,)

# %%
mae = np.mean(np.abs(np.array(y_test[:4000]) - y_mean2))
rms = errors.rmse(jnp.array(y_test[:4000]), y_mean2)

print("MAE: ", mae)
print("RMSE: ", rms)
# Out:
# MAE:  69.03289
# RMSE:  80.46555

# %%
idx = 3000
plt.figure(figsize=(10,6))
plt.plot(x_test_timestamp[:idx], yt.cpu()[:idx], label = "Refri")
plt.plot(x_test_timestamp[:idx], y_mean2[:idx], label = "Predicted")
plt.legend(bbox_to_anchor=(1, 1),fontsize=20)
plt.xlabel("TimeStamp test Scaled")
plt.ylabel("Fridge  test Power")
sns.despine()
